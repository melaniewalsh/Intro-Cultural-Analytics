# %% [markdown]
# # Named Entity Recognition for Portuguese

# %% [markdown]
# :::{note}
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# :::

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called *Named Entity Recognition* (NER) as applied to Portuguese. This method will help us computationally identify people, places, and things (of various kinds) in a text or collection of texts.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset

# %% [markdown]
# The example text for Portuguese is *Contos e Phantasias* by Maria Amália Vaz de Carvalho [from Project Gutenberg](http://www.gutenberg.org/ebooks/63406).

# %% [markdown]
# **Here's a preview of spaC's NER tagging *Contos e Phantasias*.**
#
# If you compare the results to the [English example](Named-Entity-Recognition), you'll notice that the Portuguese NER is much less good at recognizing entities, and is especially bad ata distinguishing different kinds of entities, like ORG vs LOC vs PER. You need a lot of examples to train a model to distinguish different entity types; currently, English is the only model that does a decent job of it.
#
# You can read more about the [data sources used to train Portuguese](https://spacy.io/models/pt) on the spaCy model page.

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﻿PRIMEIRA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  PARTE<br><br><br><br><br>UMA HISTORIA VERDADEIRA<br><br><br>I<br><br>Era uma physionomia incaracteristica, apagada,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tristissima
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .<br><br>Não se podia dizer a idade que tinha, nem mesmo se tinha idade.<br><br>Tanto podia ter trinta ou quarenta como setenta annos.<br><br>Curvado pela idade ou pelos desgostos?
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Encanecido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  porque os annos tinham<br>corrido por sobre a cabeça d'elle, ou porque lhe tinham pesado<br>duplamente sobre os hombros debeis?<br><br>Quem o podia dizer?<br><br>Era uma organisação acanhada e rachitica, podia mesmo chamar-se<br>incompleta.<br><br>Para elle com certeza que a adolescencia não tivera as suas madrugadas<br>azues tão gorgeadas e tão festivas, nem a virilidade tivera a fanfarra<br>estridente dos seus clarins, a florescencia escarlate dos seus
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rosaes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# <br>voluptuosos.<br><br>Tinha sempre vivido debaixo de uma estranha pressão dolorosa.<br><br>Dependêra de todos primeiro porque era fraco e inerme, depois porque<br>fôra pobre, dependente, sem aquella aspera dignidade que os atrictos da<br>vida tornam mais rude e que é a armadura moral que salvaguarda o homem<br>nos duros combates sociaes.<br><br>Nasceu n'uma casa opulenta que lhe não pertencia, cresceu no meio de um<br>luxo de que seus paes erão parasitas voluntarios e de que elle era...<br>parasita inconsciente.<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Começára
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  por ter medo de tudo e de todos; um medo que não raciocinava,<br>que não sabia, que não indagava mesmo a sua propria origem.<br><br>Nasceu assustadiço, como certos animaes silvestres, e toda a vida<br>conservou a mesma expressão inquieta e medrosa da lebre perseguida.<br><br>Em primeiro lugar tinha medo de seu pae; um homem alto, espadaúdo,<br>plethorico, de voz grossa e modos
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brutaes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , que comia como um abbade, que<br>bebia como um _lansquenete_, que praguejava como um carreiro, e que se<br>vingava nos poucos entes que tinha debaixo do seu dominio, das<br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     complacencias
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  servis que era obrigado a mostrar aos que o mantinham<br>n'aquella farta ociosidade de commensal que só goza e não paga.<br><br>Depois tinha medo de sua tia; a dona da casa, a _senhora_, a suzerana<br>ante a qual todos se curvavam submissos.<br><br>E no emtanto ella era bonita, delgada, flexivel, muito branca.<br><br>Uma figura ideal de pintor inglez.<br><br>Mas que culpa tinha elle, o pequenino parea, se os olhos d'essa graciosa<br>e delicada senhora lhe pareciam frios e metalicos, com umas<br>scintillações azuladas como as do aço fino? se as suas mãos esguias e<br>brancas se lhe affiguravam duas tenazes que podiam apertal-o, apertal-o<br>até o torcerem todo, até o esphacelarem e fazerem d'elle, do seu pequeno<br>corpo tão fraquinho, uma grotesca massa informe, que o mundo inteiro<br>pisasse, onde o mundo inteiro cuspisse!<br><br>Seria allucinação d'aquelle cerebro enfermo e condemnado ás scismas<br>doentias?<br><br>Quem sabe?<br><br>O caso é que o sentia, e que nunca pudera esquivar-se a essa<br>preoccupação intensa e dilacerante!<br><br>Um d'estes dous entes que dominaram de estranho terror a sua infancia,<br>maltratava-o nas explosões
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     brutaes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  de seu temperamento de touro bravo.<br><br>O outro--a senhora--muito altiva, muito fria, muito desdenhosa, nem<br>sequer lhe fallava.<br><br>Olhava-o ás vezes como se olha para um animal repugnante, para um sapo,<br>ou para uma carocha, e passava adiante, imperturbavel e olympica.<br><br>Havia, porém, um outro sêr, dos que mais em contacto estavam com elle,<br>que nem o maltratava, nem o desprezava com a glacial frieza do seu<br>desdem.<br><br>E comtudo era d'esse que elle tinha ainda mais medo.<br><br>Era seu tio; uma figura original, uma physionomia de titan que por um<br>engano qualquer da natureza não pôde conseguir passar de anão.<br><br>Seu tio!... Como esta individualidade extraordinariamente accentuada,<br>como este rosto ironico, irregular, convulsionado, dominou para sempre o<br>destino obscuro da infeliz creança que eu conheci já velho!<br><br>Seu tio não o perseguia nem lhe manifestava uma repugnancia muda, pelo<br>contrario.<br><br>
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chamava-o
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  continuamente para o pé de si, ensinava-lhe, quando estava só,<br>palavras, esgares, visagens grotescas que lhe fazia repetir diante de<br>gente, n'um côro de gargalhadas asperas e hostis como gumes de espadas!<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Vestia-o
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  de um modo desusado e extravagante, vestia-o de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     marujo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , de<br>escossez, com as suas pequenas pernas magras, trigueiras, ossudas, n'uma<br>nudez friorenta que lhe doia, e o fazia tiritar; vestia-o de tyrolez, o<br>que lhe dava um aspecto comico, que arrebentava com riso a criadagem.<br><br>Ás vezes nos seus dias de melhor humor sahia com elle, que tinha apenas<br>sete annos de idade, de casaca, chapéo-alto, e berloques na c

# %% [markdown]
# ---

# %% [markdown]
# ## NER with spaCy
# If you've already used the pre-processing notebook for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ### Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# We're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things, and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ### Download Language Model

# %% [markdown]
# Next we need to download the Portuguese-language model (`pt_core_news_md`), which will be processing and making predictions about our texts. You can read more about the [data sources used to train Portuguese](https://spacy.io/models/pt) on the spaCy model page.

# %%
# !python -m spacy download pt_core_news_md
# Out:
# Collecting pt-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_md-3.7.0/pt_core_news_md-3.7.0-py3-none-any.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 13.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from pt-core-news-md==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.1.1)
# Installing collected packages: pt-core-news-md
# Successfully installed pt-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')

# %% [markdown]
# ### Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# **1.** We can import the model as a module and then load it from the module.

# %%
import pt_core_news_md
nlp = pt_core_news_md.load()

# %% [markdown]
# **2.** We can load the model by name.

# %%
#nlp = spacy.load('pt_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it's advisable to use Option 1. Then you can use the model immediately. Otherwise, you'll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel.. in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document

# %% [markdown]
# We first need to process our `document` with the loaded NLP model. Most of the heavy NLP lifting is done in this line of code.
#
# After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.
#
# In the cell below, we open and the example document. Then we run`nlp()` on the text and create our document.

# %%
filepath = '../texts/pt.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## Get Named Entities

# %% [markdown]
# All the named entities in our `document` can be found in the `document.ents` property. If we check out `document.ents`, we can see all the entities from the example document.

# %%
document.ents
# Out:
# (﻿PRIMEIRA,
#  tristissima,
#  Encanecido,
#  rosaes,
#  Começára,
#  brutaes,
#  complacencias,
#  brutaes,
#  Chamava-o,
#  Vestia-o,
#  marujo,
#  Thadeu,
#  Thadeu,
#  castiçaes,
#  Sahiu d'alli,
#  Thadeu,
#  Thadeu,
#  Entregava-o,
#  marquez,
#  brutaes das aias,
#  velludo,
#  Thadeu,
#  N'aquelle,
#  Thadeu,
#  Thadeu,
#  Thadeu,
#  Thadeu,
#  d'alli,
#  fóra,
#  Thadeu,
#  arêa finissima,
#  Margarida,
#  Margarida,
#  Thadeu,
#  marujo,
#  Margarida,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Margarida,
#  comprehender,
#  Margarida,
#  d'aquelle rasgo,
#  Thadeu,
#  heroes,
#  Thadeu,
#  d'aquillo,
#  prohibiu,
#  Margarida,
#  Elle,
#  Ella,
#  Margarida,
#  Deixaram-os,
#  Thadeu,
#  terra,
#  Thadeu,
#  Margarida travessa,
#  Thadeu,
#  tanque do jardim,
#  n'agua,
#  Thadeu,
#  n'elle,
#  Elle,
#  Thadeu,
#  Margarida,
#  D'ahi,
#  Margarida,
#  paes,
#  Margarida,
#  paes,
#  n'aquelle,
#  Thadeu,
#  Viveria,
#  Margarida,
#  Seriam,
#  Ella,
#  kiosque,
#  Thadeu,
#  Elles,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  sabes?--E,
#  Paris,
#  Estive,
#  Sacré
#  Cœur,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  ido sósinho,
#  França,
#  Fôra,
#  Sacré-Cœur,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Margarida,
#  marquez,
#  folhuda,
#  Thadeu,
#  n'aquelle,
#  beijo d'aquelles,
#  Margarida,
#  Thadeu,
#  Thadeu
#  comprehendia,
#  coleras,
#  d'ella,
#  lh'as,
#  Ella,
#  Thadeu,
#  collegio,
#  vêr sem rir,
#  collegio,
#  Thadeu,
#  collegiaes,
#  brutaes,
#  Henrique de Souza,
#  Orphão,
#  collegio,
#  Henrique,
#  Thadeu,
#  Henrique,
#  Comprehendeu,
#  V
#
#  Thadeu,
#  collegio,
#  Henrique,
#  familia,
#  Occupavam,
#  Henrique,
#  Deus!
#  ,
#  Henrique,
#  Joanninha,
#  Desdobrára,
#  Thadeu,
#  Thadeu,
#  Thadeu,
#  Henrique,
#  Thadeu,
#  Margarida,
#  descripta,
#  elle vivêra,
#  Margarida!,
#  d'aquelles,
#  Margarida,
#  Henrique,
#  Joanninha,
#  martyrio,
#  Margarida,
#  d'ella,
#  Henrique,
#  VII,
#  marquez,
#  Thadeu,
#  Henrique,
#  Joanninha,
#  Joanna,
#  Margarida,
#  sr.ª D. Margarida,
#  Dormia,
#  Thadeu,
#  encontro d'ella,
#  d'antes,
#  Thadeu,
#  panno azulado,
#  Deus,
#  balouço,
#  Thadeu,
#  Graves,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Thadeu,
#  Deus,
#  Margarida,
#  Thadeu figurára,
#  Baixa,
#  Henrique,
#  Margarida,
#  casa Binder,
#  pacata Lisboa,
#  Thadeu,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Henrique de Sousa,
#  S. Carlos,
#  Norma,
#  Henrique,
#  d'antes,
#  Margarida,
#  Henrique,
#  apparencias tranquilisadoras,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Margarida!,
#  Vira-a,
#  myope,
#  Ella,
#  S. Carlos,
#  Bellini,
#  N'isto,
#  Margarida,
#  Thadeu,
#  Henrique,
#  X,
#  Margarida,
#  garridice innata,
#  Thadeu,
#  Elle,
#  poor dear boy!,
#  Thadeu,
#  Margarida,
#  Henrique,
#  Thadeu,
#  palacete dos marquezes,
#  Margarida,
#  paes,
#  Sabiam-n'a,
#  Henrique,
#  Margarida,
#  marquez,
#  elle,
#  Thadeu,
#  Margarida,
#  lagrimas,
#  Thadeu,
#  Ella,
#  jardim,
#  Conta-me,
#  Henrique,
#  Thadeu,
#  Margarida,
#  paes,
#  França,
#  Henrique,
#  marquez,
#  Via-a,
#  Margarida,
#  Henrique,
#  Margarida,
#  Henrique,
#  Thadeu,
#  martyr,
#  Thadeu,
#  ir-te,
#  educar-te,
#  Verás!,
#  Deus,
#  douda,
#  Margarida,
#  Thadeu,
#  Henrique,
#  Thadeu,
#  Henrique,
#  Buenos-Ayres,
#  Henrique,
#  Thadeu,
#  Suissa,
#  Italia,
#  d'elles,
#  marquez,
#  Henrique,
#  Thadeu,
#  Margarida,
#  d'ella,
#  Margarida,
#  Margarida,
#  déra,
#  Thadeu,
#  collossaes,
#  Margarita,
#  Thadeu,
#  Thadeu,
#  F.,
#  ámanhã,
#  lua,
#  Margarida,
#  Dous,
#  Fundia-os,
#  elles,
#  Henrique,
#  Margarida,
#  Thadeu,
#  Henrique,
#  Margarida,
#  Thadeu,
#  Thadeu,
#  XIII
#
#  Elle,
#  n'aquelle,
#  Margarida,
#  Comtudo,
#  Ella,
#  Thadeu,
#  Ella,
#  d'aquella blasphemia,
#  Margarida,
#  Thadeu,
#  Pariz,
#  Thadeu,
#  Thadeu,
#  flôr,
#  Thadeu,
#  Margarida,
#  d'ella,
#  Thadeu,
#  Henrique,
#  Margarida,
#  alli,
#  d'ahi,
#  Sahiram,
#  Thadeu,
#  Henrique,
#  Henrique,
#  soccorreu,
#  TIO SEBASTIÃO,
#  Sebastião,
#  Braga,
#  Coimbra,
#  elle,
#  Braga,
#  Aquillo,
#  Natal,
#  maçãs camoezas,
#  Joanna,
#  ámanhã,
#  ámanhã,
#  Vinha,
#  hein?,
#  Queira Deus,
#  Braga,
#  Ó Joanna,
#  sr. doutor,
#  Deus,
#  Tornava,
#  Coimbra,
#  Braga,
#  Joanna,
#  Sebastião,
#  Sebastião,
#  Sebastião,
#  ha-de,
#  Deixal-a,
#  rabuja,
#  Joanna,
#  Joanna,
#  dal-as,
#  Sebastião,
#  Moças,
#  Deus,
#  Joanna,
#  Agua molle,
#  Sebastião,
#  Brazil,
#  Sebastião,
#  fouce,
#  leôa,
#  Abrace-me,
#  Sebastião,
#  cóva,
#  Vinha,
#  Carlota,
#  Sebastião,
#  alli,
#  Carlota,
#  Sebastião,
#  Villa
#  Verde,
#  Sebastião,
#  Carlota,
#  devota soffreguidão,
#  Sebastião,
#  Carlota,
#  Sebastião,
#  Joanna,
#  Carlota,
#  Sebastião,
#  insania,
#  Joanna,
#  Prompto,
#  Sebastião,
#  Braga,
#  lyceu,
#  Brazil,
#  Carlota,
#  natal,
#  meus paes,
#  opponho,
#  Brazil,
#  Braga,
#  Coimbra,
#  Sebastião,
#  descer d'aquelle sonho,
#  andára,
#  em Portugal,
#  Rio,
#  Brazil,
#  Porto,
#  Coimbra,
#  Sebastião Alves,
#  Portugal,
#  Coimbra,
#  estroinice,
#  Sebastião,
#  Enganava,
#  Sebastião Alves,
#  Coimbra,
#  Porto,
#  Cintra,
#  Bussaco,
#  Aquella,
#  Portugal,
#  Santa Apolonia,
#  Coimbra,
#  Granja,
#  Porto,
#  Sebastião,
#  commigo,
#  Coimbra,
#  Sebastião,
#  Coimbra,
#  N'isso,
#  Ria alto,
#  Joanna,
#  Joanna,
#  Sebastião,
#  sr. Morgado,
#  fallecida,
#  Deus,
#  Sebastião,
#  Braga,
#  Representava Carlota,
#  Carlota,
#  Joanna,
#  Sebastião,
#  Coimbra,
#  Sebastião,
#  Sebastião Alves,
#  sr. Sebastião Alves,
#  Sebastião Alves,
#  sr. Sebastião,
#  Sebastião,
#  cheia de nodoas,
#  Aquillo,
#  Espera,
#  Sebastião,
#  Sebastião,
#  n'estes,
#  n'aquelle,
#  saude de teu,
#  Sebastião
#  Alves,
#  tartamudeou,
#  Sebastião,
#  Sebastião,
#  Santa Cruz,
#  Brazil,
#  Sebastião,
#  Sebastião,
#  Brazil?,
#  riso,
#  Sebastião,
#  Braga,
#  Sebastião,
#  Conega,
#  O Senhor,
#  Sebastião,
#  em Portugal,
#  Sebastião,
#  Sebastião,
#  Joanna,
#  ANNEL DO DIPLOMATA,
#  honradinho!,
#  sahe,
#  tartamudeou,
#  Christo,
#  tia
#  Joaquina,
#  redondo,
#  X***,
#  Vasconcellos,
#  Vasconcellos morrêra pobre,
#  collegas de Lisboa,
#  Porto,
#  Minho,
#  Universidade,
#  d'el-rei nosso senhor,
#  Porto,
#  acompanhára,
#  Coimbra,
#  Salesias,
#  Lisboa,
#  Antonio,
#  Antonio de Vasconcellos,
#  Coimbra,
#  Rasgou,
#  sósinha!,
#  Francisca,
#  ennovela,
#  Parece-me,
#  Coimbra,
#  Antonio,
#  Joanna,
#  d'ella,
#  Antonio de Vasconcellos,
#  falleceu,
#  Padre,
#  Filho,
#  Que Deus,
#  n'aquelle,
#  Antonio de Vasconcellos,
#  acceitou,
#  Lisboa,
#  Ir,
#  Lisboa,
#  Francisca,
#  Lisboa,
#  Lisboa,
#  taful,
#  acre,
#  Antonio de Vasconcellos,
#  Chiado,
#  Jorge de Alvim,
#  sorumbatica,
#  sôrna,
#  F.,
#  L.,
#  Vasconcellos,
#  Francisca,
#  Antonio,
#  Receber-me-ha,
#  tôlo?,
#  Deus,
#  Antonio de Vasconcellos,
#  Jorge
#  Alvim,
#  ex.ª,
#  Porto,
#  Começaremos,
#  V. Ex.ª,
#  Lisboa,
#  Antonio de Vasconcellos,
#  Vaes,
#  Antonio de Vasconcellos,
#  Prohibo-te,
#  n'aquelle,
#  Jorge de Alvim n'aquelle,
#  condessa de,
#  Jorge de Alvim,
#  Sancy,
#  Carlos,
#  Temerario,
#  Duque de Florença,
#  Prior do Crato,
#  França,
#  Harley de Sancy,
#  Harley,
#  Sancy,
#  Henrique IV de França,
#  Metz,
#  Dôls,
#  Jacques II de Inglaterra,
#  Luiz XIV,
#  V. Ex.ª,
#  Fernão Mendes,
#  V. Ex.ª,
#  Meneláu,
#  Russos,
#  Sr. Jorge de Alvim,
#  Sr. Alvim,
#  Antonio de
#  Vasconcellos,
#  Alvim,
#  Vasconcellos,
#  Deus,
#  V.
#  Ex.ᵃˢ,
#  relevarão,
#  Lisboa,
#  Ahi,
#  crystaes,
#  Antonio de Vasconcellos,
#  instincto,
#  Podia,
#  alli,
#  analysal-o,
#  miudo,
#  casaca cossada,
#  Lacenaire,
#  Antonio de Vasconcellos,
#  Jorge de Alvim,
#  Sr. Alvim,
#  Jorge de
#  Alvim,
#  Antonio de Vasconcellos,
#  n'aquelle,
#  Vasconcellos,
#  Jorge de Alvim,
#  Balzac,
#  Sr. Jorge de
#  Alvim,--e,
#  Vasconcellos,
#  Permitta-me V. Ex.ª,
#  Antonio de Vasconcellos,
#  Jorge de Alvim,
#  ESCOLHA DE GASTÃO,
#  visconde das Lagôas,
#  João do Moinho Novo,
#  João Silveira,
#  Brazil,
#  ahi,
#  aristocratico,
#  Minho,
#  Vianna,
#  alli,
#  instincto,
#  Arrás,
#  abbaciaes,
#  claustraes,
#  herva,
#  Um jardineiro inglez,
#  abysmára,
#  Aquella,
#  póde,
#  Lisboa,
#  Brazil,
#  Providencia,
#  Aline,
#  Pariz,
#  amarello,
#  S. Carlos,
#  bello,
#  Stael,
#  la Ferté,
#  Il n'y,
#  chère amie,
#  qui aie toujours raison,
#  Brazil,
#  victoria d'elle,
#  Brazil,
#  casa d'elles,
#  boçal,
#  Londres,
#  Gastão,
#  Gastão,
#  soffredôra,
#  Gastão da Silveira,
#  Europa,
#  Universidade de
#  Inglaterra,
#  Gastão,
#  industriaes,
#  Gastão,
#  Intelligente,
#  Voltava,
#  Gastão,
#  d'aquelle bello,
#  d'aquelles,
#  Gastão,
#  Podia,
#  Gastão,
#  Gastão,
#  França,
#  Pimentas,
#  Gastão,
#  Leopoldo,
#  segrêdo,
#  Gastão,
#  Gastão,
#  familia,
#  Gastão,
#  Gastão póde,
#  Gastão,
#  visconde das Lagôas,
#  Clotilde de Magalhães,
#  Magalhães,
#  visconde das
#  Lagôas,
#  comprehendeu,
#  Clotilde de Magalhães,
#  Gastão da Silveira,
#  visconde das Lagôas,
#  Clotilde,
#  Clotilde,
#  Manejava,
#  visconde das Lagôas,
#  Clotilde,
#  Clotilde,
#  Clotilde,
#  Angelina,
#  Angelina,
#  Clotilde,
#  Clotilde,
#  d'elle,
#  Magalhães,
#  banaes,
#  Gastão,
#  Deus!,
#  Clotilde.--É,
#  Clotilde,
#  Clotilde,
#  Gastão,
#  Achava-o,
#  encantava,
#  Achava-o,
#  Discordavam,
#  Clotilde,
#  Gastão,
#  Clotilde,
#  opulencias sociaes,
#  Gastão,
#  Ella,
#  Gastão,
#  Clotilde,
#  Clotilde,
#  Gastão,
#  visconde das Lagôas,
#  D. Angelina,
#  Gastão,
#  recusa-me,
#  Angelina,
#  Gastão,
#  Angelina,
#  Gastão,
#  Suissa,
#  Angelina,
#  scismar,
#  visconde das Lagôas,
#  Alto Minho,
#  Angelina,
#  Gastão,
#  poude,
#  Clotilde,
#  Clotilde,
#  Gastão,
#  galans suspirosos,
#  attender,
#  Gastão,
#  Angelina,
#  Gastão,
#  Deus,
#  Clotilde,
#  Arrazaram-se-lhe,
#  Clotilde,
#  d'ella,
#  Angelina,
#  Parece-me,
#  Angelina,
#  cahir,
#  Gastão,
#  Magalhães,
#  Gastão,
#  Clotilde,
#  Gastão,
#  Angelina,
#  Buenos-Ayres,
#  Elle,
#  Angelina,
#  Clotilde,
#  Ha,
#  ROMANCE DE ADELINA,
#  FRAGMENTOS DE CARTAS,
#  Meu,
#  affirmo-te,
#  comprehender,
#  bello,
#  Thereza,
#  D'alli,
#  paes,
#  affirmo-te,
#  meus paes,
#  affirmam,
#  Parece-me,
#  Soffrer,
#  Theresa,
#  Elles,
#  terra,
#  Alegrias,
#  Pensar,
#  Moral,
#  São Beethoven,
#  Mozart,
#  Hayden,
#  Presinto,
#  Mozart,
#  Beethoven,
#  Ó Beethoven,
#  trahida,
#  déra,
#  mananciaes,
#  Hontem,
#  Thereza,
#  Quiz,
#  Elle,
#  supportam,
#  Illudi-me,
#  illudi,
#  ainda:--,
#  brutaes,
#  bello,
#  apello,
#  Mostrei-lhes,
#  Consolai-me!,
#  Mostrei-lhes,
#  Sinto,
#  Arthur,
#  terra,
#  Arthur,
#  illumine,
#  Sahia,
#  deu-me,
#  Marido,
#  moraes,
#  indoles,
#  sociaes,
#  outomno!,
#  Arthur,
#  Converso,
#  Conto-lhes,
#  Conto-lhes,
#  bello,
#  dôce,
#  immutavel prestes,
#  Deus te abençôe,
#  trahida,
#  CIGANA,
#  Terrivel,
#  Rio de Janeiro,
#  gageiro,
#  terra,
#  Brazil,
#  Vinham,
#  Navarro,
#  Estão-me,
#  Morto,
#  Massarellos,
#  Vigo,
#  Massarellos,
#  alli,
#  capitão Navarro,
#  portaló,
#  Douro,
#  Cigana,
#  portaló,
#  Cigana,
#  Ahi,
#  Navarro,
#  galera,
#  portaló,
#  elle extremecia devéras,
#  Cigana,
#  garbosa galera,
#  affecto desapparecêra,
#  Cigana,
#  Navarro,
#  cadella,
#  Cigana,
#  Cigana,
#  Navarro,
#  Brazil,
#  Lessa,
#  Cigana,
#  Navarro,
#  n'elle,
#  N'aquelle,
#  pôpa,
#  Valha-nos o senhor de,
#  Mattosinhos,
#  Navarro,
#  sósinho,
#  Cigana,
#  Cigana,
#  largára,
#  Cigana,
#  Cigana,
#  Cigana_!,
#  Cigana,
#  Cigana,
#  Lessa,
#  Navarro,
#  Cigana,
#  Terrivel,
#  Cigana,
#  capitão Navarro,
#  sósinha,
#  Terrivel,
#  n'elles,
#  Cigana,
#  rio Lessa,
#  Luiza,
#  Joaquim Antonio Ferreira,
#  Conde da Guaratiba,
#  Gouvêa,
#  Africa,
#  Vallongo,
#  Luiza,
#  millionario Gouvêa,
#  Luiza,
#  n'ella,
#  capitão n'essa noite,
#  Luiza,
#  Cigana,
#  escriptor,
#  Cigana,
#  Luiza,
#  Luiza,
#  Cigana,
#  Cigana,
#  Cigana,
#  Cigana,
#  socega,
#  Luiza,
#  douda,
#  Cigana,
#  Luiza,
#  N'aquelle,
#  lua,
#  Luiza,
#  Cigana,
#  sr. Gouvêa,
#  Luiza,
#  Luiza,
#  Cigana,
#  Cigana,
#  Cigana_!,
#  Luiza,
#  Cigana,
#  Ella,
#  Sonhava,
#  Margarida,
#  d'elle,
#  Margarida,
#  Lisboa,
#  S. Carlos,
#  Brown,
#  Londres,
#  Margarida,
#  Eduardo de C.,
#  Elle,
#  Margarida,
#  Portugal,
#  Eduardo,
#  Margarida,
#  Minho,
#  Minho,
#  Eduardo,
#  Vianna do Castello,
#  Margarida,
#  Vianna,
#  Vianna,
#  Estado,
#  Margarida,
#  benevola indifferença,
#  banaes,
#  Eduardo de C.,
#  Vianna,
#  Lisboa,
#  Margarida,
#  Margarida,
#  Eduardo de C.,
#  Margarida,
#  Eduardo,
#  Margarida,
#  Eduardo,
#  Discutiam,
#  Margarida,
#  talisman,
#  Elle,
#  Margarida,
#  V.,
#  Margarida,
#  Eduardo,
#  bello,
#  Margarida,
#  hospedes habituaes,
#  Eduardo,
#  Margarida,
#  Margarida,
#  Eduardo,
#  Margarida,
#  sr. conde de V,
#  Margarida,
#  heroes medievicos,
#  alliava,
#  collossal,
#  conde de V,
#  Continuava,
#  Marialva,
#  Margarida,
#  Brown,
#  Margarida,
#  beneficencia,
#  Eduardo,
#  Luctara,
#  paiz,
#  Margarida,
#  Conheceste-me,
#  Presinto,
#  Lisboa,
#  Condessa de V,
#  Lisboa,
#  Deixára,
#  ...)

# %% [markdown]
# Each of the named entities in `document.ents` contains [more information about itself](https://spacy.io/usage/linguistic-features#accessing), which we can access by iterating through the `document.ents` with a simple `for` loop.
#
# For each `named_entity` in `document.ents`, we will extract the `named_entity` and its corresponding `named_entity.label_`.

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# PRIMEIRA MISC
# tristissima MISC
# Encanecido LOC
# rosaes ORG
# Começára PER
# brutaes PER
# complacencias LOC
# brutaes PER
# Chamava-o LOC
# Vestia-o PER
# marujo PER
# Thadeu PER
# Thadeu PER
# castiçaes PER
# Sahiu d'alli PER
# Thadeu PER
# Thadeu PER
# Entregava-o MISC
# marquez LOC
# brutaes das aias LOC
# velludo LOC
# Thadeu PER
# N'aquelle LOC
# Thadeu PER
# Thadeu PER
# Thadeu PER
# Thadeu PER
# d'alli PER
# fóra ORG
# Thadeu PER
# arêa finissima PER
# Margarida PER
# Margarida PER
# Thadeu PER
# marujo PER
# Margarida PER
# Margarida PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Margarida PER
# comprehender LOC
# Margarida PER
# d'aquelle rasgo PER
# Thadeu PER
# heroes MISC
# Thadeu PER
# d'aquillo PER
# prohibiu PER
# Margarida PER
# Elle MISC
# Ella PER
# Margarida PER
# Deixaram-os PER
# Thadeu PER
# terra LOC
# Thadeu PER
# Margarida travessa PER
# Thadeu PER
# tanque do jardim LOC
# n'agua PER
# Thadeu PER
# n'elle PER
# Elle MISC
# Thadeu PER
# Margarida PER
# D'ahi ORG
# Margarida PER
# paes PER
# Margarida PER
# paes PER
# n'aquelle LOC
# Thadeu PER
# Viveria PER
# Margarida PER
# Seriam PER
# Ella PER
# kiosque ORG
# Thadeu PER
# Elles PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# sabes?--E LOC
# Paris LOC
# Estive LOC
# Sacré
# Cœur LOC
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# ido sósinho PER
# França LOC
# Fôra LOC
# Sacré-Cœur MISC
# Margarida PER
# Thadeu PER
# Margarida PER
# Margarida PER
# marquez LOC
# folhuda LOC
# Thadeu PER
# n'aquelle LOC
# beijo d'aquelles MISC
# Margarida PER
# Thadeu PER
# Thadeu
# comprehendia PER
# coleras ORG
# d'ella LOC
# lh'as PER
# Ella PER
# Thadeu PER
# collegio MISC
# vêr sem rir MISC
# collegio MISC
# Thadeu PER
# collegiaes PER
# brutaes PER
# Henrique de Souza PER
# Orphão PER
# collegio MISC
# Henrique PER
# Thadeu PER
# Henrique PER
# Comprehendeu LOC
# V
#
# Thadeu MISC
# collegio LOC
# Henrique PER
# familia LOC
# Occupavam PER
# Henrique PER
# Deus!
#
#  MISC
# Henrique PER
# Joanninha PER
# Desdobrára PER
# Thadeu PER
# Thadeu PER
# Thadeu PER
# Henrique PER
# Thadeu PER
# Margarida PER
# descripta PER
# elle vivêra PER
# Margarida! MISC
# d'aquelles MISC
# Margarida PER
# Henrique PER
# Joanninha PER
# martyrio LOC
# Margarida PER
# d'ella PER
# Henrique PER
# VII PER
# marquez LOC
# Thadeu PER
# Henrique PER
# Joanninha PER
# Joanna PER
# Margarida PER
# sr.ª D. Margarida PER
# Dormia PER
# Thadeu PER
# encontro d'ella MISC
# d'antes PER
# Thadeu MISC
# panno azulado PER
# Deus PER
# balouço PER
# Thadeu PER
# Graves PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Thadeu PER
# Deus PER
# Margarida PER
# Thadeu figurára PER
# Baixa LOC
# Henrique PER
# Margarida PER
# casa Binder PER
# pacata Lisboa LOC
# Thadeu PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Henrique de Sousa PER
# S. Carlos PER
# Norma MISC
# Henrique PER
# d'antes PER
# Margarida PER
# Henrique PER
# apparencias tranquilisadoras PER
# Margarida PER
# Margarida PER
# Thadeu PER
# Margarida! MISC
# Vira-a MISC
# myope PER
# Ella PER
# S. Carlos PER
# Bellini PER
# N'isto MISC
# Margarida PER
# Thadeu PER
# Henrique PER
# X PER
# Margarida PER
# garridice innata PER
# Thadeu LOC
# Elle MISC
# poor dear boy! MISC
# Thadeu ORG
# Margarida PER
# Henrique PER
# Thadeu PER
# palacete dos marquezes LOC
# Margarida PER
# paes PER
# Sabiam-n'a LOC
# Henrique PER
# Margarida PER
# marquez LOC
# elle LOC
# Thadeu PER
# Margarida PER
# lagrimas LOC
# Thadeu PER
# Ella PER
# jardim LOC
# Conta-me ORG
# Henrique PER
# Thadeu LOC
# Margarida PER
# paes PER
# França LOC
# Henrique PER
# marquez LOC
# Via-a PER
# Margarida PER
# Henrique PER
# Margarida PER
# Henrique PER
# Thadeu PER
# martyr LOC
# Thadeu PER
# ir-te PER
# educar-te MISC
# Verás! MISC
# Deus PER
# douda LOC
# Margarida PER
# Thadeu PER
# Henrique PER
# Thadeu PER
# Henrique PER
# Buenos-Ayres LOC
# Henrique PER
# Thadeu PER
# Suissa LOC
# Italia LOC
# d'elles LOC
# marquez LOC
# Henrique PER
# Thadeu PER
# Margarida PER
# d'ella LOC
# Margarida PER
# Margarida PER
# déra PER
# Thadeu PER
# collossaes PER
# Margarita MISC
# Thadeu PER
# Thadeu PER
# F. PER
# ámanhã LOC
# lua LOC
# Margarida PER
# Dous PER
# Fundia-os PER
# elles LOC
# Henrique PER
# Margarida PER
# Thadeu PER
# Henrique PER
# Margarida PER
# Thadeu PER
# Thadeu PER
# XIII
#
# Elle MISC
# n'aquelle PER
# Margarida PER
# Comtudo ORG
# Ella PER
# Thadeu PER
# Ella PER
# d'aquella blasphemia PER
# Margarida PER
# Thadeu PER
# Pariz LOC
# Thadeu PER
# Thadeu PER
# flôr LOC
# Thadeu PER
# Margarida PER
# d'ella LOC
# Thadeu PER
# Henrique PER
# Margarida PER
# alli PER
# d'ahi ORG
# Sahiram PER
# Thadeu PER
# Henrique PER
# Henrique PER
# soccorreu ORG
# TIO SEBASTIÃO MISC
# Sebastião PER
# Braga LOC
# Coimbra LOC
# elle PER
# Braga LOC
# Aquillo PER
# Natal MISC
# maçãs camoezas PER
# Joanna PER
# ámanhã LOC
# ámanhã LOC
# Vinha LOC
# hein? MISC
# Queira Deus PER
# Braga LOC
# Ó Joanna LOC
# sr. doutor PER
# Deus MISC
# Tornava PER
# Coimbra LOC
# Braga LOC
# Joanna PER
# Sebastião PER
# Sebastião PER
# Sebastião PER
# ha-de PER
# Deixal-a LOC
# rabuja MISC
# Joanna PER
# Joanna PER
# dal-as PER
# Sebastião PER
# Moças LOC
# Deus PER
# Joanna PER
# Agua molle MISC
# Sebastião PER
# Brazil PER
# Sebastião PER
# fouce PER
# leôa PER
# Abrace-me PER
# Sebastião PER
# cóva MISC
# Vinha LOC
# Carlota PER
# Sebastião PER
# alli PER
# Carlota PER
# Sebastião PER
# Villa
# Verde LOC
# Sebastião PER
# Carlota PER
# devota soffreguidão PER
# Sebastião PER
# Carlota PER
# Sebastião PER
# Joanna PER
# Carlota PER
# Sebastião PER
# insania LOC
# Joanna PER
# Prompto MISC
# Sebastião PER
# Braga LOC
# lyceu MISC
# Brazil PER
# Carlota PER
# natal LOC
# meus paes PER
# opponho PER
# Brazil MISC
# Braga LOC
# Coimbra LOC
# Sebastião PER
# descer d'aquelle sonho PER
# andára PER
# em Portugal LOC
# Rio LOC
# Brazil MISC
# Porto LOC
# Coimbra LOC
# Sebastião Alves PER
# Portugal LOC
# Coimbra LOC
# estroinice ORG
# Sebastião PER
# Enganava PER
# Sebastião Alves PER
# Coimbra LOC
# Porto LOC
# Cintra LOC
# Bussaco LOC
# Aquella LOC
# Portugal LOC
# Santa Apolonia LOC
# Coimbra LOC
# Granja LOC
# Porto LOC
# Sebastião PER
# commigo LOC
# Coimbra LOC
# Sebastião PER
# Coimbra LOC
# N'isso PER
# Ria alto LOC
# Joanna PER
# Joanna PER
# Sebastião PER
# sr. Morgado PER
# fallecida LOC
# Deus PER
# Sebastião PER
# Braga LOC
# Representava Carlota PER
# Carlota PER
# Joanna PER
# Sebastião PER
# Coimbra LOC
# Sebastião PER
# Sebastião Alves PER
# sr. Sebastião Alves PER
# Sebastião Alves PER
# sr. Sebastião PER
# Sebastião PER
# cheia de nodoas LOC
# Aquillo LOC
# Espera PER
# Sebastião PER
# Sebastião PER
# n'estes PER
# n'aquelle PER
# saude de teu PER
# Sebastião
# Alves PER
# tartamudeou PER
# Sebastião PER
# Sebastião PER
# Santa Cruz LOC
# Brazil PER
# Sebastião PER
# Sebastião PER
# Brazil? MISC
# riso ORG
# Sebastião PER
# Braga LOC
# Sebastião PER
# Conega LOC
# O Senhor MISC
# Sebastião PER
# em Portugal LOC
# Sebastião PER
# Sebastião PER
# Joanna PER
# ANNEL DO DIPLOMATA ORG
# honradinho! MISC
# sahe PER
# tartamudeou PER
# Christo PER
# tia
# Joaquina PER
# redondo LOC
# X*** MISC
# Vasconcellos PER
# Vasconcellos morrêra pobre PER
# collegas de Lisboa LOC
# Porto LOC
# Minho LOC
# Universidade LOC
# d'el-rei nosso senhor PER
# Porto LOC
# acompanhára MISC
# Coimbra LOC
# Salesias LOC
# Lisboa LOC
# Antonio PER
# Antonio de Vasconcellos PER
# Coimbra LOC
# Rasgou PER
# sósinha! MISC
# Francisca PER
# ennovela LOC
# Parece-me PER
# Coimbra LOC
# Antonio MISC
# Joanna PER
# d'ella LOC
# Antonio de Vasconcellos PER
# falleceu PER
# Padre PER
# Filho PER
# Que Deus MISC
# n'aquelle LOC
# Antonio de Vasconcellos PER
# acceitou PER
# Lisboa LOC
# Ir LOC
# Lisboa LOC
# Francisca PER
# Lisboa LOC
# Lisboa LOC
# taful PER
# acre ORG
# Antonio de Vasconcellos PER
# Chiado LOC
# Jorge de Alvim PER
# sorumbatica LOC
# sôrna LOC
# F. PER
# L. PER
# Vasconcellos PER
# Francisca PER
# Antonio PER
# Receber-me-ha MISC
# tôlo? MISC
# Deus PER
# Antonio de Vasconcellos PER
# Jorge
# Alvim PER
# ex.ª MISC
# Porto LOC
# Começaremos LOC
# V. Ex.ª PER
# Lisboa LOC
# Antonio de Vasconcellos PER
# Vaes PER
# Antonio de Vasconcellos PER
# Prohibo-te PER
# n'aquelle PER
# Jorge de Alvim n'aquelle PER
# condessa de PER
# Jorge de Alvim PER
# Sancy PER
# Carlos PER
# Temerario PER
# Duque de Florença PER
# Prior do Crato PER
# França LOC
# Harley de Sancy PER
# Harley PER
# Sancy PER
# Henrique IV de França PER
# Metz LOC
# Dôls LOC
# Jacques II de Inglaterra PER
# Luiz XIV PER
# V. Ex.ª PER
# Fernão Mendes PER
# V. Ex.ª PER
# Meneláu LOC
# Russos LOC
# Sr. Jorge de Alvim PER
# Sr. Alvim PER
# Antonio de
# Vasconcellos PER
# Alvim PER
# Vasconcellos PER
# Deus PER
# V.
# Ex.ᵃˢ PER
# relevarão PER
# Lisboa LOC
# Ahi LOC
# crystaes ORG
# Antonio de Vasconcellos PER
# instincto LOC
# Podia ORG
# alli PER
# analysal-o ORG
# miudo PER
# casaca cossada PER
# Lacenaire PER
# Antonio de Vasconcellos PER
# Jorge de Alvim PER
# Sr. Alvim PER
# Jorge de
# Alvim PER
# Antonio de Vasconcellos PER
# n'aquelle LOC
# Vasconcellos PER
# Jorge de Alvim PER
# Balzac PER
# Sr. Jorge de
# Alvim,--e PER
# Vasconcellos LOC
# Permitta-me V. Ex.ª PER
# Antonio de Vasconcellos PER
# Jorge de Alvim PER
# ESCOLHA DE GASTÃO ORG
# visconde das Lagôas PER
# João do Moinho Novo PER
# João Silveira PER
# Brazil MISC
# ahi LOC
# aristocratico PER
# Minho LOC
# Vianna PER
# alli PER
# instincto LOC
# Arrás LOC
# abbaciaes PER
# claustraes MISC
# herva LOC
# Um jardineiro inglez MISC
# abysmára PER
# Aquella LOC
# póde PER
# Lisboa LOC
# Brazil MISC
# Providencia MISC
# Aline ORG
# Pariz LOC
# amarello PER
# S. Carlos PER
# bello ORG
# Stael PER
# la Ferté LOC
# Il n'y MISC
# chère amie PER
# qui aie toujours raison PER
# Brazil MISC
# victoria d'elle LOC
# Brazil PER
# casa d'elles PER
# boçal PER
# Londres LOC
# Gastão PER
# Gastão PER
# soffredôra LOC
# Gastão da Silveira PER
# Europa LOC
# Universidade de
# Inglaterra LOC
# Gastão PER
# industriaes PER
# Gastão PER
# Intelligente LOC
# Voltava PER
# Gastão PER
# d'aquelle bello PER
# d'aquelles PER
# Gastão PER
# Podia ORG
# Gastão PER
# Gastão PER
# França LOC
# Pimentas MISC
# Gastão PER
# Leopoldo PER
# segrêdo MISC
# Gastão PER
# Gastão LOC
# familia LOC
# Gastão PER
# Gastão póde PER
# Gastão PER
# visconde das Lagôas PER
# Clotilde de Magalhães PER
# Magalhães PER
# visconde das
# Lagôas PER
# comprehendeu LOC
# Clotilde de Magalhães PER
# Gastão da Silveira PER
# visconde das Lagôas PER
# Clotilde PER
# Clotilde PER
# Manejava LOC
# visconde das Lagôas PER
# Clotilde PER
# Clotilde PER
# Clotilde PER
# Angelina PER
# Angelina PER
# Clotilde PER
# Clotilde PER
# d'elle LOC
# Magalhães PER
# banaes PER
# Gastão PER
# Deus! MISC
# Clotilde.--É ORG
# Clotilde PER
# Clotilde PER
# Gastão PER
# Achava-o MISC
# encantava LOC
# Achava-o MISC
# Discordavam PER
# Clotilde PER
# Gastão PER
# Clotilde PER
# opulencias sociaes PER
# Gastão PER
# Ella PER
# Gastão PER
# Clotilde PER
# Clotilde PER
# Gastão PER
# visconde das Lagôas PER
# D. Angelina PER
# Gastão PER
# recusa-me ORG
# Angelina PER
# Gastão PER
# Angelina PER
# Gastão PER
# Suissa LOC
# Angelina PER
# scismar PER
# visconde das Lagôas PER
# Alto Minho LOC
# Angelina PER
# Gastão PER
# poude PER
# Clotilde PER
# Clotilde PER
# Gastão PER
# galans suspirosos MISC
# attender PER
# Gastão PER
# Angelina PER
# Gastão PER
# Deus PER
# Clotilde PER
# Arrazaram-se-lhe ORG
# Clotilde PER
# d'ella LOC
# Angelina PER
# Parece-me PER
# Angelina PER
# cahir PER
# Gastão PER
# Magalhães PER
# Gastão PER
# Clotilde PER
# Gastão PER
# Angelina PER
# Buenos-Ayres LOC
# Elle MISC
# Angelina PER
# Clotilde PER
# Ha PER
# ROMANCE DE ADELINA ORG
# FRAGMENTOS DE CARTAS MISC
# Meu PER
# affirmo-te PER
# comprehender PER
# bello PER
# Thereza PER
# D'alli PER
# paes PER
# affirmo-te PER
# meus paes PER
# affirmam PER
# Parece-me PER
# Soffrer PER
# Theresa PER
# Elles PER
# terra LOC
# Alegrias LOC
# Pensar PER
# Moral MISC
# São Beethoven PER
# Mozart PER
# Hayden PER
# Presinto LOC
# Mozart PER
# Beethoven PER
# Ó Beethoven PER
# trahida LOC
# déra PER
# mananciaes PER
# Hontem LOC
# Thereza PER
# Quiz PER
# Elle MISC
# supportam LOC
# Illudi-me LOC
# illudi PER
# ainda:-- PER
# brutaes LOC
# bello PER
# apello PER
# Mostrei-lhes LOC
# Consolai-me! MISC
# Mostrei-lhes LOC
# Sinto LOC
# Arthur PER
# terra LOC
# Arthur PER
# illumine PER
# Sahia ORG
# deu-me PER
# Marido PER
# moraes PER
# indoles LOC
# sociaes LOC
# outomno! MISC
# Arthur PER
# Converso PER
# Conto-lhes LOC
# Conto-lhes LOC
# bello ORG
# dôce MISC
# immutavel prestes PER
# Deus te abençôe MISC
# trahida LOC
# CIGANA LOC
# Terrivel ORG
# Rio de Janeiro LOC
# gageiro LOC
# terra LOC
# Brazil MISC
# Vinham PER
# Navarro PER
# Estão-me PER
# Morto PER
# Massarellos LOC
# Vigo LOC
# Massarellos LOC
# alli PER
# capitão Navarro PER
# portaló MISC
# Douro LOC
# Cigana PER
# portaló ORG
# Cigana PER
# Ahi LOC
# Navarro PER
# galera ORG
# portaló ORG
# elle extremecia devéras PER
# Cigana PER
# garbosa galera PER
# affecto desapparecêra PER
# Cigana PER
# Navarro PER
# cadella PER
# Cigana PER
# Cigana PER
# Navarro PER
# Brazil PER
# Lessa PER
# Cigana PER
# Navarro PER
# n'elle PER
# N'aquelle LOC
# pôpa MISC
# Valha-nos o senhor de LOC
# Mattosinhos LOC
# Navarro PER
# sósinho PER
# Cigana PER
# Cigana PER
# largára MISC
# Cigana PER
# Cigana PER
# Cigana_! MISC
# Cigana PER
# Cigana PER
# Lessa LOC
# Navarro PER
# Cigana PER
# Terrivel ORG
# Cigana PER
# capitão Navarro PER
# sósinha LOC
# Terrivel LOC
# n'elles PER
# Cigana PER
# rio Lessa LOC
# Luiza PER
# Joaquim Antonio Ferreira PER
# Conde da Guaratiba PER
# Gouvêa PER
# Africa LOC
# Vallongo PER
# Luiza PER
# millionario Gouvêa PER
# Luiza PER
# n'ella PER
# capitão n'essa noite PER
# Luiza PER
# Cigana PER
# escriptor PER
# Cigana PER
# Luiza PER
# Luiza PER
# Cigana PER
# Cigana PER
# Cigana PER
# Cigana PER
# socega LOC
# Luiza PER
# douda LOC
# Cigana PER
# Luiza PER
# N'aquelle LOC
# lua LOC
# Luiza PER
# Cigana PER
# sr. Gouvêa PER
# Luiza PER
# Luiza PER
# Cigana PER
# Cigana PER
# Cigana_! MISC
# Luiza PER
# Cigana PER
# Ella PER
# Sonhava PER
# Margarida PER
# d'elle LOC
# Margarida PER
# Lisboa LOC
# S. Carlos PER
# Brown PER
# Londres LOC
# Margarida PER
# Eduardo de C. PER
# Elle MISC
# Margarida PER
# Portugal LOC
# Eduardo PER
# Margarida PER
# Minho LOC
# Minho LOC
# Eduardo PER
# Vianna do Castello LOC
# Margarida PER
# Vianna PER
# Vianna PER
# Estado LOC
# Margarida PER
# benevola indifferença PER
# banaes PER
# Eduardo de C. PER
# Vianna PER
# Lisboa LOC
# Margarida PER
# Margarida PER
# Eduardo de C. PER
# Margarida PER
# Eduardo PER
# Margarida PER
# Eduardo PER
# Discutiam PER
# Margarida PER
# talisman LOC
# Elle MISC
# Margarida PER
# V. PER
# Margarida PER
# Eduardo PER
# bello PER
# Margarida PER
# hospedes habituaes PER
# Eduardo PER
# Margarida PER
# Margarida PER
# Eduardo PER
# Margarida PER
# sr. conde de V PER
# Margarida PER
# heroes medievicos MISC
# alliava LOC
# collossal PER
# conde de V PER
# Continuava PER
# Marialva PER
# Margarida PER
# Brown PER
# Margarida PER
# beneficencia LOC
# Eduardo PER
# Luctara PER
# paiz ORG
# Margarida PER
# Conheceste-me PER
# Presinto LOC
# Lisboa LOC
# Condessa de V PER
# Lisboa LOC
# Deixára PER
# levantára-se martyr PER
# Miss Brown ORG
# improba LOC
# santa expiação LOC
# Margarida PER
# n'aquelles PER
# Margarida PER
# S. Bento PER
# Lisboa LOC
# Comprehendia PER
# N'isto MISC
# Margarida PER
# Eduardo de C. PER
# Margarida PER
# Eduardo PER
# Christo PER
# Magdalena LOC
# Ella PER
# Cahia MISC
# Margarida PER
# Miss Brown PER
# Margarida PER
# Eduardo de C.
#
# Margarida PER
# Margarida PER
# Lisboa LOC
# mysterioso LOC
# Providencia MISC
# Eduardo de C. PER
# TIA IZABEL
#
#
# Conhecia-a MISC
# d'ella LOC
# flagello da familia PER
# Izabel PER
# Japão LOC
# China LOC
# Russia LOC
# iniciaes PER
# Virgem PER
# Christo PER
# Exhalava LOC
# irmãosinho Arthur PER
# Fômos PER
# Umas PER
# matinaes PER
# dôce MISC
# terra LOC
# Ella PER
# Porquê PER
# Condemnação PER
# Tambem MISC
# Estremecera LOC
# Deus PER
# Universidade LOC
# pecego MISC
# Reparou PER
# MILLIONARIO ORG
# Brazil MISC
# Portugal LOC
# Francisco PER
# sr. Francisco Cerqueira PER
# Lisboa LOC
# Mineiros LOC
# Cerqueira PER
# sr. Cerqueira PER
# Cerqueira PER
# Europa LOC
# vim creança LOC
# Europa LOC
# sr. Cerqueira PER
# nascêra LOC
# creára PER
# Orpheu PER
# Eurydices LOC
# Brazil PER
# n'elle PER
# Cerqueira PER
# em Portugal LOC
# Cerqueira LOC
# mourejando PER
# sr. Cerqueira PER
# alli PER
# Cerqueira collocou MISC
# enterrou unidos LOC
# index MISC
# Francisco Cerqueira PER
# Portugal LOC
# lettra do sobrescripto ORG
# Arrancado LOC
# sr. Cerqueira PER
# Buenos-Ayres LOC
# nhônhô LOC
# sr. Cerqueira PER
# Sahia ORG
# sr. Cerqueira PER
# morro de Santa Thereza LOC
# Botafogo ORG
# Corcovado LOC
# Brazil MISC
# Europa LOC
# Portugal LOC
# sr. Cerqueira PER
# sr. Cerqueira PER
# Cerqueira PER
# Cerqueira LOC
# n'aquelle quarto PER
# Cerqueira PER
# Ámanhã LOC
# Resolvi-me PER
# Fernandes PER
# Cerqueira LOC
# Companhia do
# Pacifico ORG
# Cerqueira PER
# bahia LOC
# Lisboa LOC
# Cintra PER
# Lisboa LOC
# Cerqueira PER
# Braga LOC
# Ponte de Lima LOC
# nascêra LOC
# Seriam PER
# Cerqueira LOC
# segando herva PER
# Bertha PER
# Deus!
#
#  MISC
# Margarida PER
# Bertha PER
# Berthazinha LOC
# Deus PER
# Naly PER
# Bertha PER
# Bertha PER
# Primo PER
# alli PER
# Tratavam-n'o MISC
# Bertha PER
# Bertha PER
# Bertha PER
# Pudéra! MISC
# d'antes PER
# Bertha PER
# Berthazinha LOC
# Bertha PER
# Bertha PER
# Bertha PER
# Bertha symptomas PER
# N'isto MISC
# perola amarrotado PER
# Fugira PER
# trophéo PER
# Bertha PER
# Elle MISC
# Naly PER
# Deus PER
# Bertha PER
# Bertha PER
# innocencia dos lyrios LOC
# Bertha PER
# Meu Deus! MISC
# Bertha d'outro PER
# Vae-te PER
# És PER
# Bertha PER
# Tiritava LOC
# Dous PER
# d'alli PER
# Bertha PER
# d'aquelle supremo abraço PER
# Perdôa-me ORG
# SEGUNDA PARTE
#
#
#
#
#  MISC
# PROPOSITO DE UM LIVRO
#
#
#  MISC
# Theorias PER
# familia LOC
# victoria LOC
# individuaes PER
# supprir PER
# Bem LOC
# confrange LOC
# Mal PER
# D'antes PER
# elles LOC
# França LOC
# Balsac ORG
# França LOC
# Pariz LOC
# alli PER
# França LOC
# Europa LOC
# Balzac PER
# Madame de Marneffe PER
# Eugenia Grandet PER
# idealisou PER
# Luciano de Rubempré PER
# Vautrin PER
# Marsay PER
# d'Arthés PER
# Cesar
# Birotteau PER
# Balzac PER
# Elle MISC
# Balsac LOC
# Balzac PER
# Emilio Zola PER
# Bolsa ORG
# fallou PER
# Pariz LOC
# Watteau PER
# Zola PER
# Zola PER
# Tlambert PER
# benedictino PER
# Acudiam-me ORG
# Feuillet PER
# Pariz LOC
# Feuillet PER
# Zola PER
# Zola PER
# bachanaes PER
# heroes MISC
# Meu Deus! MISC
# Octavio Feuillet PER
# penna d'ouro PER
# Feuillet PER
# Balzac PER
# Feuillet PER
# Zola PER
# Zola PER
# Feuillet PER
# Octavio Feuillet PER
# Le journal ORG
# Elle MISC
# esphinge LOC
# Conde de Camors PER
# Le journal d'une femme_ ORG
# Octavio Feuillet PER
# Roubar PER
# applicado LOC
# Deus PER
# bello PER
# Áquelle PER
# Octavio Feuillet PER
# Diario MISC
# lançára MISC
# d'ella PER
# douda LOC
# d'aquelle PER
# d'ella LOC
# n'outro MISC
# Restas-me MISC
# Deus PER
# MADAME MISC
# Peninsula LOC
# Paris LOC
# Hespanha LOC
# Pensei MISC
# Balsac LOC
# Madame de Balsac PER
# Arte PER
# Divida ORG
# Calumnia LOC
# Inveja MISC
# Impossivel MISC
# Pegaso do sonho MISC
# Imaginario LOC
# D. Quichote MISC
# ideaes PER
# n'ella PER
# extranha PER
# dôce PER
# Hanskan de Balsac PER
# Portugal LOC
# Portugal LOC
# Resignei-me PER
# Balsac ORG
# Correspondencia_ do grande escriptor MISC
# Calmann Levy PER
# Balsac ORG
# Balsac ORG
# Oiro MISC
# Balsac ORG
# scintilla LOC
# tremeluz LOC
# haschish LOC
# Balsac ORG
# Engano!
#
#  MISC
# Mil LOC
# Balsac ORG
# Arte PER
# phrenezi PER
# martyrio PER
# Balsac ORG
# realisou PER
# terra LOC
# penna LOC
# Balsac ORG
# Galatheia ORG
# Théophile Gauthier PER
# Balsac,--e LOC
# Balsac ORG
# iguaes PER
# Théophile Gauthier PER
# Balsac ORG
# Usava LOC
# flanella branca PER
# Luiz
# Boulanger PER
# «Gabava-se LOC
# athleta LOC
# «N'essa PER
# Balsac ORG
# Touraine LOC
# Balsac ORG
# David de Angers PER
# Madame de Girardin PER
# Balsac ORG
# Tancredo PER
# masso LOC
# turquezas LOC
# Balsac PER
# d'elle LOC
# Cahir PER
# bello PER
# Eugenia Grandet PER
# La Fossette MISC
# Mignon LOC
# Morsauf PER
# Bauseant PER
# Langeais PER
# Restaud LOC
# Dudley PER
# Valeria Marneffe PER
# Balsac ORG
# Escrevendo _ MISC
# Luiz Lambert PER
# Swedenborgistas ORG
# n'elle PER
# Fausto PER
# Curiosa PER
# Correspondencia_ de MISC
# Balsac ORG
# Hanska LOC
# Balsac LOC
# Danaides PER
# escriptor PER
# caricias ideaes PER
# industriaes PER
# bello PER
# Balsac PER
# Hanska LOC
# juba de leão PER
# corôas LOC
# succumbiu LOC
# Balsac PER
# Correspondencia_ MISC
# Madame Hanska PER
# Tu PER
# França LOC
# Vel-a-ha MISC
# LINCOLN PER
# Lisboa LOC
# sociaes PER
# apparecem PER
# lisongeie PER
# Jardim da Europa LOC
# D. Jayme PER
# D'entre PER
# Ratazzi LOC
# Shakespeares PER
# Ratazzi LOC
# Shakespeares PER
# Deus PER
# Vinha LOC
# Ulysses Grant PER
# Grant PER
# Grant PER
# Boyton PER
# Grant PER
# attrahem LOC
# High life MISC
# Price PER
# Grant PER
# Manrico PER
# Arthur MISC
# Grant PER
# Estados-Unidos da America LOC
# Lincoln PER
# Grant PER
# triumpho LOC
# Lincoln PER
# Grant PER
# triumphar LOC
# bracejar PER
# derrubal-a PER
# asylo PER
# victoria absoluta LOC
# America LOC
# condicções excepcionaes PER
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Lincoln PER
# d'antes ampla
# licença PER
# Grant PER
# Lincoln PER
# Elle conhecêra PER
# Europa LOC
# Biblia MISC
# Lincoln PER
# affirmar MISC
# Lincoln PER
# Lincoln PER
# Lincoln PER
# Estados-Unidos LOC
# Lincoln PER
# cahiu morto PER
# Washington LOC
# Springffel PER
# triumpho PER
# D'alli PER
# Lincoln PER
# Longe LOC
# Grant PER
# Estado LOC
# West-Point MISC
# sahio d'alli PER
# guerra do Mexico MISC
# Taylor PER
# Vera Cruz LOC
# Missouri LOC
# S. Luiz LOC
# Grant PER
# S. Luiz LOC
# d'aquelle grotesco figurão PER
# Estados-Unidos LOC
# Europa LOC
# Grant PER
# exercito dos Estados-Unidos ORG
# Republica LOC
# Elle MISC
# d'elle apparecer PER
# Estados-Unidos LOC
# Lee PER
# Richmond LOC
# Lincoln PER
# Grant PER
# excepcionaes MISC
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Grant PER
# Elle MISC
# flagello ORG
# America LOC
# póde PER
# Lisboa LOC
# Ha PER
# Gustavo Rivet PER
# Victor Hugo chez lui_ PER
# Lenda dos Seculos PER
# Marais LOC
# Victor Hugo PER
# d'ella esperavamos PER
# Joanninha PER
# Art d'être grand père_ immortalisou MISC
# Châtiments MISC
# Comtudo ORG
# Victor
# Hugo PER
# Victor Hugo PER
# Olympo LOC
# immortaes PER
# ideaes PER
# penna LOC
# elles PER
# lyra LOC
# palêta PER
# n'elle PER
# brutaes PER
# Circe PER
# Helena PER
# Melusina LOC
# Renascença LOC
# Imperia LOC
# Lucrecia Borgia PER
# Shakespeare PER
# Ophelia PER
# Desdemona PER
# Victor Hugo PER
# Shakspeare PER
# Victor Hugo PER
# Elle MISC
# Marius PER
# Didier PER
# Gennaro LOC
# heroes MISC
# Oh! MISC
# Didier PER
# Hernani PER
# Gennaro ORG
# Marius PER
# Hugo PER
# virginaes PER
# Hugo PER
# dôce PER
# humilde PER
# indomavel cavalleiro PER
# Sorrisos MISC
# instincto LOC
# Hespanhas LOC
# Appareça PER
# Hugo PER
# Vêde Marion PER
# d'elle LOC
# Vêde Eponine PER
# Pariz LOC
# Marius PER
# Eponine LOC
# Cosette MISC
# Marius PER
# João Valjean PER
# Magdalena LOC
# Magdalena LOC
# Esmeralda LOC
# Quasimodo!
#
#  MISC
# Umas PER
# Umas PER
# Leitora MISC
# Entristecem-te PER
# Gervasias PER
# Bovarys LOC
# Fannys LOC
# França LOC
# Victor Hugo PER
# Ellas LOC
# terra LOC
# Esmeralda LOC
# velludo LOC
# bella PER
# Cosette! MISC
# Ella PER
# póde PER
# terra LOC
# Marius PER
# Cosette louca PER
# alli PER
# Marius PER
# Ai! MISC
# Cosette PER
# Amor MISC
# Sacrificio! MISC
# Victor Hugo PER
# Déa PER
# Amada PER
# Deus!
#
#  MISC
# Abençoada LOC
# Josiane MISC
# Titan ORG
# Apollo MISC
# Polyphemo!
#
#  MISC
# Maria de Neuburgo PER
# Marion LOC
# Eponine LOC
# Cosette LOC
# Déa PER
# Oh! MISC
# instincto LOC
# d'antes PER
# bello! MISC
# n'elle PER

# %% [markdown]
# To extract just the named entities that have been identified as `PER` (person), we can add a simple `if` statement into the mix:

# %%
for named_entity in document.ents:
    if named_entity.label_ == "PER":
        print(named_entity)
# Out:
# Começára
# brutaes
# brutaes
# Vestia-o
# marujo
# Thadeu
# Thadeu
# castiçaes
# Sahiu d'alli
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# d'alli
# Thadeu
# arêa finissima
# Margarida
# Margarida
# Thadeu
# marujo
# Margarida
# Margarida
# Margarida
# Thadeu
# Margarida
# Thadeu
# Margarida
# Margarida
# Margarida
# d'aquelle rasgo
# Thadeu
# Thadeu
# d'aquillo
# prohibiu
# Margarida
# Ella
# Margarida
# Deixaram-os
# Thadeu
# Thadeu
# Margarida travessa
# Thadeu
# n'agua
# Thadeu
# penna d'ouro
# Feuillet
# Balzac
# Feuillet
# Zola
# Zola
# Feuillet
# Octavio Feuillet
# Conde de Camors
# Octavio Feuillet
# Roubar
# Deus
# bello
# Áquelle
# Octavio Feuillet
# d'ella
# d'aquelle
# Deus
# Madame de Balsac
# Arte
# ideaes
# n'ella
# extranha
# dôce
# Hanskan de Balsac
# Resignei-me
# Calmann Levy
# Arte
# phrenezi
# martyrio
# realisou
# Théophile Gauthier
# iguaes
# Théophile Gauthier
# flanella branca
# Luiz
# Boulanger
# «N'essa
# David de Angers
# Madame de Girardin
# Tancredo
# Balsac
# Cahir
# bello
# Eugenia Grandet
# Morsauf
# Bauseant
# Langeais
# Dudley
# Valeria Marneffe
# Luiz Lambert
# n'elle
# Fausto
# Curiosa
# Danaides
# escriptor
# caricias ideaes
# industriaes
# bello
# Balsac
# juba de leão
# Balsac
# Madame Hanska
# Tu
# LINCOLN
# sociaes
# apparecem
# lisongeie
# D. Jayme
# D'entre
# Shakespeares
# Shakespeares
# Deus
# Ulysses Grant
# Grant
# Grant
# Boyton
# Grant
# Price
# Grant
# Manrico
# Grant
# Lincoln
# Grant
# Lincoln
# Grant
# bracejar
# derrubal-a
# asylo
# condicções excepcionaes
# Lincoln
# Grant
# Lincoln
# Grant
# Lincoln
# d'antes ampla
# licença
# Grant
# Lincoln
# Elle conhecêra
# Lincoln
# Lincoln
# Lincoln
# Lincoln
# Lincoln
# cahiu morto
# Springffel
# triumpho
# D'alli
# Lincoln
# Grant
# sahio d'alli
# Taylor
# Grant
# d'aquelle grotesco figurão
# Grant
# d'elle apparecer
# Lee
# Lincoln
# Grant
# Lincoln
# Grant
# Lincoln
# Grant
# Grant
# póde
# Ha
# Gustavo Rivet
# Victor Hugo chez lui_
# Lenda dos Seculos
# Victor Hugo
# d'ella esperavamos
# Joanninha
# Victor
# Hugo
# Victor Hugo
# immortaes
# ideaes
# elles
# palêta
# n'elle
# brutaes
# Circe
# Helena
# Lucrecia Borgia
# Shakespeare
# Ophelia
# Desdemona
# Victor Hugo
# Shakspeare
# Victor Hugo
# Marius
# Didier
# Didier
# Hernani
# Marius
# Hugo
# virginaes
# Hugo
# dôce
# humilde
# indomavel cavalleiro
# Appareça
# Hugo
# Vêde Marion
# Vêde Eponine
# Marius
# Marius
# João Valjean
# Umas
# Umas
# Entristecem-te
# Gervasias
# Victor Hugo
# bella
# Ella
# póde
# Marius
# Cosette louca
# alli
# Marius
# Cosette
# Victor Hugo
# Déa
# Amada
# Maria de Neuburgo
# Déa
# d'antes
# n'elle

# %% [markdown]
# ## NER with Long Texts or Many Texts

# %%
import math
number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

# %%
chunked_documents = list(nlp.pipe(text_chunks))

# %% [markdown]
# ## Get People

# %% [markdown]
# To extract and count the people, we will use an `if` statement that will pull out words only if their "ent" label matches "PER."

# %%
people = []

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "PER":
            people.append(named_entity.text)

people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df
# Out:
#                         character  count
# 0                       Margarida     87
# 1                          Thadeu     70
# 2                       Sebastião     35
# 3                        Henrique     28
# 4                          Gastão     28
# 5                          Bertha     28
# 6                          Cigana     27
# 7                          Martha     21
# 8                        Clotilde     19
# 9                            Deus     17
# 10                          Grant     17
# 11                         Joanna     15
# 12                        Lincoln     15
# 13                           Ella     13
# 14                          Luiza     12
# 15                      Cerqueira     12
# 16        Antonio de Vasconcellos     11
# 17                       Angelina     11
# 18                           alli     10
# 19                         Julião     10
# 20                        Eduardo      9
# 21                          bello      8
# 22                  sr. Cerqueira      8
# 23                        Carlota      7
# 24                        Navarro      7
# 25                           Naly      7
# 26                         n'elle      6
# 27                         Brazil      6
# 28            visconde das Lagôas      6
# 29                           Zola      6
# 30                    Victor Hugo      6
# 31                         Marius      6
# 32                           paes      5
# 33                        d'antes      5
# 34                 Jorge de Alvim      5
# 35                         Balzac      5
# 36                           póde      5
# 37                  Eduardo de C.      5
# 38                      Francisco      5
# 39                       Feuillet      5
# 40                        brutaes      4
# 41                         d'alli      4
# 42                      Joanninha      4
# 43                      S. Carlos      4
# 44                Sebastião Alves      4
# 45                   Vasconcellos      4
# 46                         Vianna      4
# 47                         n'ella      4
# 48                           Umas      4
# 49                        Adriana      4
# 50               Octavio Feuillet      4
# 51                      n'aquelle      3
# 52                        Christo      3
# 53                      Francisca      3
# 54                      Parece-me      3
# 55                        V. Ex.ª      3
# 56                      Magalhães      3
# 57                         banaes      3
# 58                         Arthur      3
# 59                           flôr      3
# 60                         Balsac      3
# 61                           Hugo      3
# 62                         marujo      2
# 63                      d'aquillo      2
# 64                         Seriam      2
# 65                          Elles      2
# 66                         d'ella      2
# 67                           déra      2
# 68                             F.      2
# 69                           Dous      2
# 70                      meus paes      2
# 71                    tartamudeou      2
# 72                        Antonio      2
# 73                           Vaes      2
# 74                          Sancy      2
# 75                      Sr. Alvim      2
# 76             Gastão da Silveira      2
# 77                    industriaes      2
# 78          Clotilde de Magalhães      2
# 79                             Ha      2
# 80                     affirmo-te      2
# 81                        Thereza      2
# 82                         D'alli      2
# 83                         Mozart      2
# 84                capitão Navarro      2
# 85                      escriptor      2
# 86                          Brown      2
# 87            Francisco Cerqueira      2
# 88                      apparecem      2
# 89                       Genoveva      2
# 90         Martha de Vasconcellos      2
# 91                          Marta      2
# 92                         Fausto      2
# 93                             És      2
# 94                Eugenia Grandet      2
# 95                           Arte      2
# 96                         ideaes      2
# 97                           dôce      2
# 98             Théophile Gauthier      2
# 99                   Shakespeares      2
# 100                        Didier      2
# 101                           Déa      2
# 102                      Começára      1
# 103                      Vestia-o      1
# 104                     castiçaes      1
# 105                  Sahiu d'alli      1
# 106                arêa finissima      1
# 107               d'aquelle rasgo      1
# 108                      prohibiu      1
# 109                   Deixaram-os      1
# 110            Margarida travessa      1
# 111                        n'agua      1
# 112                       Viveria      1
# 113                   ido sósinho      1
document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "LOC":
            places.append(named_entity.text)

places_tally = Counter(places)

df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
df
# Out:
#                            place  count
# 0                         Lisboa     20
# 1                        Coimbra     13
# 2                         França      9
# 3                          Braga      9
# 4                       Portugal      9
# 5                         Europa      9
# 6                          terra      8
# 7                         d'ella      8
# 8                        marquez      6
# 9                          Pariz      6
# 10                         Porto      6
# 11                         Minho      6
# 12                     Cerqueira      5
# 13                     n'aquelle      4
# 14                     instincto      4
# 15                        d'elle      4
# 16                     N'aquelle      3
# 17                       familia      3
# 18                         douda      3
# 19                  Buenos-Ayres      3
# 20                        ámanhã      3
# 21                         Vinha      3
# 22                   em Portugal      3
# 23                     Magdalena      3
# 24                     Allemanha      3
# 25                        Balsac      3
# 26                Estados-Unidos      3
# 27                       velludo      2
# 28                         Paris      2
# 29                        Thadeu      2
# 30                      lagrimas      2
# 31                        Suissa      2
# 32                           lua      2
# 33                         elles      2
# 34                       Aquella      2
# 35                  Universidade      2
# 36                           Ahi      2
# 37                       Londres      2
# 38                       trahida      2
# 39                  Mostrei-lhes      2
# 40                       sociaes      2
# 41                    Conto-lhes      2
# 42                   Massarellos      2
# 43                        Estado      2
# 44                       nascêra      2
# 45                         Gœthe      2
# 46                         Ellas      2
# 47                   Berthazinha      2
# 48                         penna      2
# 49                        Hanska      2
# 50                       Ratazzi      2
# 51                       America      2
# 52                       S. Luiz      2
# 53                       Eponine      2
# 54                     Esmeralda      2
# 55                    Encanecido      1
# 56                 complacencias      1
# 57                     Chamava-o      1
# 58              brutaes das aias      1
# 59                  comprehender      1
# 60              tanque do jardim      1
# 61                     sabes?--E      1
# 62                        Estive      1
# 63                   Sacré\nCœur      1
# 64                          Fôra      1
# 65                       folhuda      1
# 66                  Comprehendeu      1
# 67                      collegio      1
# 68                         rdada      1
# 69                      martyrio      1
# 70                         Baixa      1
# 71                 pacata Lisboa      1
# 72        palacete dos marquezes      1
# 73                    Sabiam-n'a      1
# 74                          elle      1
# 75                        jardim      1
# 76                        martyr      1
# 77                        Italia      1
# 78                       d'elles      1
# 79                          flôr      1
# 80                      Ó Joanna      1
# 81                            qu      1
# 82                      Deixal-a      1
# 83                         Moças      1
# 84                  Villa\nVerde      1
# 85                       insania      1
# 86                         natal      1
# 87                           Rio      1
# 88                      esquinho      1
# 89                         chato      1
# 90                        Cintra      1
# 91                       Bussaco      1
# 92                Santa Apolonia      1
# 93                        Granja      1
# 94                       commigo      1
# 95                      Ria alto      1
# 96                     fallecida      1
# 97               cheia de nodoas      1
# 98                       Aquillo      1
# 99                    Santa Cruz      1
# 100                       Conega      1
# 101                      redondo      1
# 222                     triumpho      1
# 223                    triumphar      1
# 224            victoria absoluta      1
# 225                   Washington      1
# 226                        Longe      1
# 227                    Vera Cruz      1
# 228                     Missouri      1
# 229                    Republica      1
# 230                     Richmond      1
# 231                       Marais      1
# 232                       Olympo      1
# 233                         lyra      1
# 234                     Melusina      1
# 235                   Renascença      1
# 236                      Imperia      1
# 237                      Gennaro      1
# 238                    Hespanhas      1
# 239                      Bovarys      1
# 240                       Fannys      1
# 241                    Abençoada      1
# 242                       Marion      1
# 243                      Cosette      1

# %% [markdown]
# ## Get NER in Context

# %%
from IPython.display import Markdown, display
import re

def get_ner_in_context(keyword, document, desired_ner_labels= False):
    
    if desired_ner_labels != False:
        desired_ner_labels = desired_ner_labels
    else: 
        # all possible labels
        desired_ner_labels = list(nlp.get_pipe('ner').labels)   
        
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        #process each sentence
        sentence_doc = nlp(sentence.text)
        for named_entity in sentence_doc.ents:
            #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
            if keyword.lower() in named_entity.text.lower()  and named_entity.label_ in desired_ner_labels:
                #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
                #sentence_text = sentence.text
            
                sentence_text = re.sub('\n', ' ', sentence.text)
                sentence_text = re.sub(f"{named_entity.text}", f"**{named_entity.text}**", sentence_text, flags=re.IGNORECASE)

                print('---')
                display(Markdown(f"**{named_entity.label_}**"))
                display(Markdown(sentence_text))

# %%
for document in chunked_documents:
    get_ner_in_context('Lisboa', document)
# Out:
# ---
# **LOC**
# Margarida sahia de uma loja e ia a saltar ligeira, elegante com a sua graça parisiense para dentro do _coupé_ delicioso que, de proposito para a filha, o marquez havia encommendado mezes antes á casa Binder, e que dous finos cavallos inglezes esplendidamente ajaezados faziam voar pelas ruas da nossa **pacata Lisboa**.
# ---
# **LOC**
# O advogado Vasconcellos morrêra pobre, sorte de todos os causidicos de provincia, que logram vencer, quando muito, por mez, o que qualquer dos **collegas de Lisboa** e Porto dá aos seus agaloados trintanarios.
# ---
# **LOC**
# O rapaz foi para Coimbra, e a menina para o convento das Salesias em **Lisboa**, de onde recolheu quando o irmão entrava para o primeiro anno juridico.
# ---
# **LOC**
# Logo que se viu senhor dos titulos alcançados pelo seu estudo e applicação, foi á villa natal agradecer aos que o haviam tão evangelicamente amparado, e, por conselhos de um condiscipulo, dirigiu-se a **Lisboa**, onde fixou residencia, e entrou a frequentar o escriptorio de um dos advogados de mais renome no fôro da capital.
# ---
# **LOC**
# Em **Lisboa** encontraria campo mais dilatado onde desafogar as suas altas aspirações.
# ---
# **LOC**
# ...  Pobre creança!         *       *       *       *       *  N'aquella época chegara a **Lisboa**
# ---
# **LOC**
# um individuo que fôra o mais perdulario dos _leões_ da **Lisboa** de ha trinta annos, e que presentemente occupava um elevado lugar diplomatico em uma côrte estrangeira.
# ---
# **LOC**
# Em vez do arnez, do broquel, das cannelleiras e do elmo, aconselho-lhe que se vista com elegancia igual á sua gentileza, porque vae combater a féra no salão da mais elegante senhora de **Lisboa**, e ante a presença das nossas mais acentuadas celebridades politicas e litterarias.
# ---
# **LOC**
# Vou propôr a V. Ex.ᵃˢ uma cousa que lhes parecerá excentrica, mas que me relevarão, já que em **Lisboa** passo por um ente singular e extraordinario.
# ---
# **LOC**
# Em **Lisboa** não era menos rica, nem menos confortavel, a habitação do millionario.
# ---
# **LOC**
# Salvava-a isto da vulgaridade que mais ou menos contamina as mulheres ricas.  Margarida no inverno vivia em **Lisboa**.
# ---
# **LOC**
# --Foi-me apresentado este inverno em **Lisboa**;
# ---
# **LOC**
# «Pergunta-o se quizeres, a essa **Lisboa**, que assistiu ao louco esphacelar de uma fortuna enorme, com o sorriso banal e adulador que ella tem para todos os perdularios.
# ---
# **LOC**
# A brilhante Condessa de V..., a filha adorada de um dos homens mais ricos de **Lisboa**, a rainha dos salões luxuosos, a _estrella_ mais fulgurante do alto mundo, dava lições para sustentar os dous filhos que lhe restavam, unicos vestigios de um passado de pomposas mentiras.
# ---
# **LOC**
# N'uma tarde do mez de janeiro, chuvosa, humida e fria, Margarida subia a muito custo a calçada de S. Bento, em **Lisboa**, onde morava uma das suas discipulas.
# ---
# **LOC**
# Os dous orphãos de Margarida estão agora a educar-se em um dos melhores collegios de **Lisboa**, e todas as despezas da sua educação são pagas por um protector invisivel e mysterioso.
# ---
# **LOC**
# O sr. Francisco Cerqueira lembrava-se de todos os pormenores e incidentes trabalhosos da jornada que elle fizera desde a sua pequena e risonha aldeia minhota até **Lisboa**.
# ---
# **LOC**
# Na manhã do dia seguinte, no tombadilho d'um dos vapores da Companhia do Pacifico, emquanto os dous socios do Cerqueira riam e diziam facecias, deitando com ares de casquilhos atabalhoados as lunetas a algumas francezas, que, com os seus vestidos de fazendas claras animavam alegremente aquelle conjunto de pessoas possuidas de tão estranhos e contradictorios sentimentos, o nosso viajante olhava com os olhos de quem se despede de um sitio amado para os armazens, para os trapiches que se retratavam nas aguas da bahia, para as torres das egrejas que se arrendavam nitidamente no claro céo azul.         *       *       *       *       *  Em **Lisboa** pouco se demorou.
# ---
# **LOC**
# No hotel, alguns amigos quizeram prendel-o ainda, tentando-o com o theatro lyrico, com Cintra e com as poucas fascinações baratas de **Lisboa**.
# ---
# **LOC**
# Verdade é que podia ter tido novas d'ella em **Lisboa** escrevendo ao abbade, mas queria fazer uma supreza, chegar de improviso.
# ---
# **LOC**
# De vez em quando a tela monotona d'esta nossa vida de **Lisboa**, unicamente bordada de pequeninos _cancans_ politicos, litterarios e sociaes, rompe-se com a chegada, ou para melhor dizer, com a passagem de um viajante illustre.
# ---
# **LOC**
# E este homem, tão modesto na apparencia, tão laconico nas fallas, tão simples no viver, este homem que recusa recompensas apparatosas, porque julga que a suprema recompensa é a da propria consciencia, este homem que póde apresentar-se como a personalisação da democracia moderna, é o mesmo que **Lisboa** ha pouco viu passar com a estupida e distrahida indifferença que ella tem para tudo que é verdadeiramente grande, e por isso mesmo despretencioso e simples.
