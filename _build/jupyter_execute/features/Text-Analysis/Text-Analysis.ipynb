# %% [markdown]
# ## Text Analysis

# %% [markdown]
# This series of lessons will focus on text analyis methods:

# %% [markdown]
# ```{tableofcontents}
# ```

# %% [markdown]
# ```{toctree}
# :hidden:
# :titlesonly:
#
#
# TF-IDF
# Topic-Modeling
# Named-Entity-Recognition
# POS-Keywords
# ```
