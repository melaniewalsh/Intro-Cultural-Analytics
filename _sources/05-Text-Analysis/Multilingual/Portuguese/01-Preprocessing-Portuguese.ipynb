# %% [markdown]
# # Text Pre-Processing for Portuguese

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# This lesson is for anyone who wants to try the [TF-IDF](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/TF-IDF.html) or [topic modeling](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/Topic-Modeling.html) lessons on Portuguese texts. Before continuing with those lessons, you need to create a *lemmatized derivative* of your original Portuguese text, which replaces all the words with their dictionary form, which will work much better with the word-count based methods.

# %% [markdown]
# ## Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ## Download Language Model

# %%
# !python -m spacy download pt_core_news_md

# %% [markdown]
# ## Import Libraries

# %%
import spacy

# %% [markdown]
# ## Load Language Model
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# 1. We can import the model as a module and then load it from the module.

# %%
import pt_core_news_md
nlp = pt_core_news_md.load()

# %% [markdown]
# 2. We can load the model by name.

# %%
#nlp = spacy.load('pt_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it’s advisable to use Option 1. Then you can use the model immediately. Otherwise, you’ll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel… in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document
# To create a derivative text file that we can use with TF-IDF, topic modeling, or other word-count based methods, we need to use spaCy to *lemmatize* the text, replacing each word with its dictionary form. The result will be an ungrammatical text that will produce better results than the original version when used with word-count methods.
#
# The example text for Portuguese is *Contos e Phantasias* by Maria Amália Vaz de Carvalho [from Project Gutenberg](http://www.gutenberg.org/ebooks/63406).

# %% [markdown]
# Here we open the text and process it with the Portuguese spaCy model.

# %%
filepath = '../texts/pt.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# Then we loop through each token in the original text, lemmatize each token and insert a space between the tokens, and finally write them to our new derivative text file.

# %%
outname = filepath.replace('.txt', '-lemmatized.txt')

# Create a lemmatized version of the original text file
with open(outname, 'w', encoding='utf8') as out:
    for token in document:
        # Get the lemma for each token
        out.write(token.lemma_.lower())
        # Insert white space between each token
        out.write(' ')

# %% [markdown]
# ## Examine Differences
# The code cell below prints the original word in the text, a dash, then the lemmatized form that was written to the derivative text document that you'll use for TF-IDF and topic modeling. It's a good idea to take a look at this so you can see if there are places where the model consistently makes mistakes.
#
# For instance, an earlier version of spaCy often associated the Spanish preposition `para` ("for") with the verb `parar` ("to stop"). If you just took that derivative file and used it for TF-IDF or topic modeling without realizing what was happening, you might reach the surprising conclusion that "stop" is a very frequent word in your text, when actually it's lemmatization problem.

# %%
for token in document:
    print(token.text + ' - ' + token.lemma_)
# Out:
# ﻿PRIMEIRA - ﻿PRIMEIRA
# PARTE - PARTE
#
#
#
#
#
#  -
#
#
#
#
#
# UMA - UMA
# HISTORIA - HISTORIA
# VERDADEIRA - VERDADEIRA
#
#
#
#  -
#
#
#
# I - I
#
#
#  -
#
#
# Era - Era
# uma - umar
# physionomia - physionomia
# incaracteristica - incaracteristica
# , - ,
# apagada - apagar
# , - ,
# tristissima - tristissima
# . - .
#
#
#  -
#
#
# Não - Não
# se - se
# podia - poder
# dizer - dizer
# a - o
# idade - idade
# que - que
# tinha - ter
# , - ,
# nem - nem
# mesmo - mesmo
# se - se
# tinha - ter
# idade - idade
# . - .
#
#
#  -
#
#
# Tanto - Tanto
# podia - poder
# ter - ter
# trinta - trintar
# ou - ou
# quarenta - quarentar
# como - comer
# setenta - setenta
# annos - annos
# . - .
#
#
#  -
#
#
# Curvado - Curvado
# pela - pelar
# idade - idade
# ou - ou
# pelos - pelos
# desgostos - desgosto
# ? - ?
# Encanecido - Encanecido
# porque - porque
# os - o
# annos - annos
# tinham - ter
#
#  -
#
# corrido - correr
# por - por
# sobre - sobrar
# a - o
# cabeça - cabeça
# d'elle - d'elle
# , - ,
# ou - ou
# porque - porque
# lhe - lhe
# tinham - ter
# pesado - pesar
#
#  -
#
# duplamente - duplamente
# sobre - sobrar
# os - o
# hombros - hombros
# debeis - debeis
# ? - ?
#
#
#  -
#
#
# Quem - Quem
# o - o
# podia - poder
# dizer - dizer
# ? - ?
#
#
#  -
#
#
# Era - Era
# uma - umar
# organisação - organisação
# acanhada - acanhar
# e - e
# rachitica - rachitica
# , - ,
# podia - poder
# mesmo - mesmo
# chamar-se - chamar-se
#
#  -
#
# incompleta - incompleto
# . - .
#
#
#  -
#
#
# Para - Para
# elle - elle
# com - com
# certeza - certeza
# que - que
# a - o
# adolescencia - adolescencia
# não - não
# tivera - ter
# as - o
# suas - suar
# madrugadas - madrugar
#
#  -
#
# azues - azues
# tão - tão
# gorgeadas - gorgeadas
# e - e
# tão - tão
# festivas - festivo
# , - ,
# nem - nem
# a - o
# virilidade - virilidade
# tivera - ter
# a - o
# fanfarra - fanfarra
#
#  -
#
# estridente - estridente
# dos - dos
# seus - seu
# clarins - clarim
# , - ,
# a - o
# florescencia - florescencia
# escarlate - escarlate
# dos - dos
# seus - seu
# rosaes - rosaes
#
#  -
#
# voluptuosos - voluptuoso
# . - .
#
#
#  -
#
#
# Tinha - Tinha
# sempre - sempre
# vivido - viver
# debaixo - debaixo
# de - de
# uma - umar
# estranha - estranho
# pressão - pressão
# dolorosa - doloroso
# . - .
#
#
#  -
#
#
# Dependêra - Dependêra
# de - de
# todos - todo
# primeiro - primeiro
# porque - porque
# era - ser
# fraco - fraco
# e - e
# inerme - inerme
# , - ,
# depois - depois
# porque - porque
#
#  -
#
# fôra - fôra
# pobre - pobre
# , - ,
# dependente - dependente
# , - ,
# sem - sem
# aquella - aquella
# aspera - aspera
# dignidade - dignidade
# que - que
# os - o
# atrictos - atrictos
# da - da
#
#  -
#
# vida - vidar
# tornam - tornar
# mais - mais
# rude - rude
# e - e
# que - que
# é - ser
# a - o
# armadura - armadura
# moral - moral
# que - que
# salvaguarda - salvaguardar
# o - o
# homem - homem
#
#  -
#
# nos - o
# duros - duro
# combates - combater
# sociaes - sociaes
# . - .
#
#
#  -
#
#
# Nasceu - Nasceu
# n'uma - n'uma
# casa - casar
# opulenta - opulento
# que - que
# lhe - lhe
# não - não
# pertencia - pertencer
# , - ,
# cresceu - crescer
# no - o
# meio - mear
# de - de
# um - um
#
#  -
#
# luxo - luxar
# de - de
# que - que
# seus - seu
# paes - paes
# erão - erão
# parasitas - parasito
# voluntarios - voluntarios
# e - e
# de - de
# que - que
# elle - elle
# era - ser
# ... - ...
#
#  -
#
# parasita - parasito
# inconsciente - inconsciente
# . - .
#
#
#  -
#
#
# Começára - Começára
# por - por
# ter - ter
# medo - medo
# de - de
# tudo - tudo
# e - e
# de - de
# todos - todo
# ; - ;
# um - um
# medo - medo
# que - que
# não - não
# raciocinava - raciocinar
# , - ,
#
#  -
#
# que - que
# não - não
# sabia - saber
# , - ,
# que - que
# não - não
# indagava - indagar
# mesmo - mesmo
# a - o
# sua - suar
# propria - propria
# origem - origem
# . - .
#
#
#  -
#
#
# Nasceu - Nasceu
# assustadiço - assustadiço
# , - ,
# como - comer
# certos - certo
# animaes - animaes
# silvestres - silvestre
# , - ,
# e - e
# toda - todo
# a - o
# vida - vidar
#
#  -
#
# conservou - conservar
# a - o
# mesma - mesmo
# expressão - expressão
# inquieta - inquieto
# e - e
# medrosa - medroso
# da - da
# lebre - lebre
# perseguida - perseguir
# . - .
#
#
#  -
#
#
# Em - Em
# primeiro - primeiro
# lugar - lugar
# tinha - ter
# medo - medo
# de - de
# seu - seu
# pae - pae
# ; - ;
# um - um
# homem - homem
# alto - alto
# , - ,
# espadaúdo - espadaúdo
# , - ,
#
#  -
#
# plethorico - plethorico
# , - ,
# de - de
# voz - voz
# grossa - grosso
# e - e
# modos - modo
# brutaes - brutaes
# , - ,
# que - que
# comia - comer
# como - comer
# um - um
# abbade - abbade
# , - ,
# que - que
#
#  -
#
# bebia - beber
# como - comer
# um - um
# _ - _
# lansquenete - lansquenete
# _ - _
# , - ,
# que - que
# praguejava - praguejar
# como - comer
# um - um
# carreiro - carreiro
# , - ,
# e - e
# que - que
# se - se
#
#  -
#
# vingava - vingar
# nos - o
# poucos - pouco
# entes - ente
# que - que
# tinha - ter
# debaixo - debaixo
# do - do
# seu - seu
# dominio - dominio
# , - ,
# das - das
#
#  -
#
# complacencias - complacencias
# servis - servir
# que - que
# era - ser
# obrigado - obrigar
# a - o
# mostrar - mostrar
# aos - aos
# que - que
# o - o
# mantinham - manter
#
#  -
#
# n'aquella - n'aquella
# farta - farto
# ociosidade - ociosidade
# de - de
# commensal - commensal
# que - que
# só - só
# goza - gozar
# e - e
# não - não
# paga - pago
# . - .
#
#
#  -
#
#
# Depois - Depois
# tinha - ter
# medo - medo
# de - de
# sua - suar
# tia - tio
# ; - ;
# a - o
# dona - dono
# da - da
# casa - casar
# , - ,
# a - o
# _ - _
# senhora - senhor
# _ - _
# , - ,
# a - o
# suzerana - suzerana
#
#  -
#
# ante - antar
# a - o
# qual - qual
# todos - todo
# se - se
# curvavam - curvar
# submissos - submisso
# . - .
#
#
#  -
#
#
# E - E
# no - o
# emtanto - emtanto
# ella - ella
# era - ser
# bonita - bonito
# , - ,
# delgada - delgado
# , - ,
# flexivel - flexivel
# , - ,
# muito - muito
# branca - branco
# . - .
#
#
#  -
#
#
# Uma - Uma
# figura - figurar
# ideal - ideal
# de - de
# pintor - pintor
# inglez - inglez
# . - .
#
#
#  -
#
#
# Mas - Mas
# que - que
# culpa - culpar
# tinha - ter
# elle - elle
# , - ,
# o - o
# pequenino - pequenino
# parea - parea
# , - ,
# se - se
# os - o
# olhos - olho
# d'essa - d'essa
# graciosa - gracioso
#
#  -
#
# e - e
# delicada - delicado
# senhora - senhor
# lhe - lhe
# pareciam - parecer
# frios - frio
# e - e
# metalicos - metalicos
# , - ,
# com - com
# umas - umar
#
#  -
#
# scintillações - scintillações
# azuladas - azular
# como - comer
# as - o
# do - do
# aço - aço
# fino - finar
# ? - ?
# se - se
# as - o
# suas - suar
# mãos - mão
# esguias - esguio
# e - e
#
#  -
#
# brancas - branco
# se - se
# lhe - lhe
# affiguravam - affiguravam
# duas - dois
# tenazes - tenaz
# que - que
# podiam - poder
# apertal-o - apertal-o
# , - ,
# apertal-o - apertal-o
#
#  -
#
# até - até
# o - o
# torcerem - torcer
# todo - todo
# , - ,
# até - até
# o - o
# esphacelarem - esphacelarem
# e - e
# fazerem - fazer
# d'elle - d'elle
# , - ,
# do - do
# seu - seu
# pequeno - pequeno
#
#  -
#
# corpo - corpo
# tão - tão
# fraquinho - fraco
# , - ,
# uma - umar
# grotesca - grotesco
# massa - massa
# informe - informar
# , - ,
# que - que
# o - o
# mundo - mundo
# inteiro - inteirar
#
#  -
#
# pisasse - pisar
# , - ,
# onde - onde
# o - o
# mundo - mundo
# inteiro - inteirar
# cuspisse - cuspir
# ! - !
#
#
#  -
#
#
# Seria - Seria
# allucinação - allucinação
# d'aquelle - d'aquelle
# cerebro - cerebro
# enfermo - enfermar
# e - e
# condemnado - condemnado
# ás - ás
# scismas - scismas
#
#  -
#
# doentias - doentio
# ? - ?
#
#
#  -
#
#
# Quem - Quem
# sabe - saber
# ? - ?
#
#
#  -
#
#
# O - O
# caso - casar
# é - ser
# que - que
# o - o
# sentia - sentir
# , - ,
# e - e
# que - que
# nunca - nunca
# pudera - poder
# esquivar-se - esquivar-se
# a - o
# essa - esse
#
#  -
#
# preoccupação - preoccupação
# intensa - intenso
# e - e
# dilacerante - dilacerante
# ! - !
#
#
#  -
#
#
# Um - Um
# d'estes - d'estes
# dous - dois
# entes - ente
# que - que
# dominaram - dominar
# de - de
# estranho - estranhar
# terror - terror
# a - o
# sua - suar
# infancia - infancia
# , - ,
#
#  -
#
# maltratava-o - maltratava-o
# nas - o
# explosões - explosão
# brutaes - brutaes
# de - de
# seu - seu
# temperamento - temperamento
# de - de
# touro - touro
# bravo - bravo
# . - .
#
#
#  -
#
#
# O - O
# outro - outro
# -- - --
# a - o
# senhora - senhor
# -- - --
# muito - muito
# altiva - altivo
# , - ,
# muito - muito
# fria - frio
# , - ,
# muito - muito
# desdenhosa - desdenhoso
# , - ,
# nem - nem
#
#  -
#
# sequer - sequer
# lhe - lhe
# fallava - fallava
# . - .
#
#
#  -
#
#
# Olhava-o - Olhava-o
# ás - ás
# vezes - vezar
# como - comer
# se - se
# olha - olhar
# para - parir
# um - um
# animal - animal
# repugnante - repugnante
# , - ,
# para - parir
# um - um
# sapo - sapar
# , - ,
#
#  -
#
# ou - ou
# para - parir
# uma - umar
# carocha - carocha
# , - ,
# e - e
# passava - passar
# adiante - adiantar
# , - ,
# imperturbavel - imperturbavel
# e - e
# olympica - olympica
# . - .
#
#
#  -
#
#
# Havia - Havia
# , - ,
# porém - porém
# , - ,
# um - um
# outro - outro
# sêr - sêr
# , - ,
# dos - dos
# que - que
# mais - mais
# em - em
# contacto - contactar
# estavam - estar
# com - com
# elle - elle
# , - ,
#
#  -
#
# que - que
# nem - nem
# o - o
# maltratava - maltratar
# , - ,
# nem - nem
# o - o
# desprezava - desprezar
# com - com
# a - o
# glacial - glacial
# frieza - frieza
# do - do
# seu - seu
#
#  -
#
# desdem - desdem
# . - .
#
#
#  -
#
#
# E - E
# comtudo - comtudo
# era - ser
# d'esse - d'esse
# que - que
# elle - elle
# tinha - ter
# ainda - ainda
# mais - mais
# medo - medo
# . - .
#
#
#  -
#
#
# Era - Era
# seu - seu
# tio - tio
# ; - ;
# uma - umar
# figura - figurar
# original - original
# , - ,
# uma - umar
# physionomia - physionomia
# de - de
# titan - titan
# que - que
# por - por
# um - um
#
#  -
#
# engano - enganir
# qualquer - qualquer
# da - da
# natureza - natureza
# não - não
# pôde - poder
# conseguir - conseguir
# passar - passar
# de - de
# anão - anão
# . - .
#
#
#  -
#
#
# Seu - Seu
# tio - tio
# ! - !
# ... - ...
# Como - Como
# esta - este
# individualidade - individualidade
# extraordinariamente - extraordinariamente
# accentuada - accentuada
# , - ,
#
#  -
#
# como - comer
# este - este
# rosto - rostir
# ironico - ironico
# , - ,
# irregular - irregular
# , - ,
# convulsionado - convulsionar
# , - ,
# dominou - dominar
# para - parir
# sempre - sempre
# o - o
#
#  -
#
# destino - destinar
# obscuro - obscuro
# da - da
# infeliz - infeliz
# creança - creança
# que - que
# eu - eu
# conheci - conhecer
# já - já
# velho - velho
# ! - !
#
#
#  -
#
#
# Seu - Seu
# tio - tio
# não - não
# o - o
# perseguia - perseguir
# nem - nem
# lhe - lhe
# manifestava - manifestar
# uma - umar
# repugnancia - repugnancia
# muda - mudo
# , - ,
# pelo - pelar
#
#  -
#
# contrario - contrariar
# . - .
#
#
#  -
#
#
# Chamava-o - Chamava-o
# continuamente - continuamente
# para - parir
# o - o
# pé - pé
# de - de
# si - si
# , - ,
# ensinava-lhe - ensinava-lhe
# , - ,
# quando - quando
# estava - estar
# só - só
# , - ,
#
#  -
#
# palavras - palavra
# , - ,
# esgares - esgar
# , - ,
# visagens - visagem
# grotescas - grotesco
# que - que
# lhe - lhe
# fazia - fazer
# repetir - repetir
# diante - diante
# de - de
#
#  -
#
# gente - gente
# , - ,
# n'um - n'um
# côro - côro
# de - de
# gargalhadas - gargalhar
# asperas - asperas
# e - e
# hostis - hostil
# como - comer
# gumes - gume
# de - de
# espadas - espadar
# ! - !
#
#
#  -
#
#
# Vestia-o - Vestia-o
# de - de
# um - um
# modo - modo
# desusado - desusar
# e - e
# extravagante - extravagante
# , - ,
# vestia-o - vestia-o
# de - de
# marujo - marujar
# , - ,
# de - de
#
#  -
#
# escossez - escossez
# , - ,
# com - com
# as - o
# suas - suar
# pequenas - pequeno
# pernas - perna
# magras - magro
# , - ,
# trigueiras - trigueiro
# , - ,
# ossudas - ossudo
# , - ,
# n'uma - n'uma
#
#  -
#
# nudez - nudez
# friorenta - friorento
# que - que
# lhe - lhe
# doia - doia
# , - ,
# e - e
# o - o
# fazia - fazer
# tiritar - tiritar
# ; - ;
# vestia-o - vestia-o
# de - de
# tyrolez - tyrolez
# , - ,
# o - o
#
#  -
#
# que - que
# lhe - lhe
# dava - dar
# um - um
# aspecto - aspecto
# comico - comico
# , - ,
# que - que
# arrebentava - arrebentar
# com - com
# riso - riso
# a - o
# criadagem - criadagem
# . - .
#
#
#  -
#
#
# Ás - Ás
# vezes - vezar
# nos - o
# seus - seu
# dias - dia
# de - de
# melhor - melhor
# humor - humor
# sahia - sahia
# com - com
# elle - elle
# , - ,
# que - que
# tinha - ter
# apenas - apenas
#
#  -
#
# sete - sete
# annos - annos
# de - de
# idade - idade
# , - ,
# de - de
# casaca - casaca
# , - ,
# chapéo-alto - chapéo-alto
# , - ,
# e - e
# berloques - berloque
# na - o
# cadeia - cadeia
# do - do
#
#  -
#
# relogio - relogio
# . - .
#
#
#  -
#
#
# Tinha - Tinha
# tempos - tempo
# em - em
# que - que
# não - não
# podia - poder
# passar - passar
# sem - sem
# a - o
# sua - suar
# companhia - companhia
# ; - ;
# a - o
# creança - creança
# era - ser
#
#  -
#
# a - o
# unica - unica
# distracção - distracção
# do - do
# anão - anão
# . - .
#
#
#  -
#
#
# As - As
# caricias - cariciar
# d'esse - d'esse
# homem - homem
# singular - singular
# , - ,
# de - de
# olhar - olhar
# faiscante - faiscante
# , - ,
# de - de
# cabelladura - cabelladura
#
#  -
#
# revolta - revolto
# e - e
# electrica - electrica
# , - ,
# de - de
# voz - voz
# sonora - sonoro
# e - e
# rica - rico
# de - de
# inflexões - inflexão
# estranhas - estranho
# , - ,
# doíam - doer
# , - ,
#
#  -
#
# porém - porém
# , - ,
# ao - ao
# pequeno - pequeno
# muito - muito
# mais - mais
# do - do
# que - que
# os - o
# desprezos - desprezo
# ou - ou
# os - o
# máos - máos
# tratos - trato
# dos - dos
#
#  -
#
# outros - outro
# . - .
#
#
#  -
#
#
# Ao - Ao
# pé - pé
# d'estes - d'estes
# sentia-se - sentia-se
# perseguido - perseguir
# , - ,
# ao - ao
# pé - pé
# d'aquelle - d'aquelle
# sentia-se - sentia-se
# humilhado - humilhar
# . - .
#
#
#  -
#
#
# Um - Um
# dia - dia
# o - o
# marquez - marquez
# -- - --
# o - o
# tio - tio
# do - do
# pequeno - pequeno
# Thadeu - Thadeu
# era - ser
# marquez,--achou - marquez,--achou
# comico - comico
#
#  -
#
# mandar - mandar
# introduzir - introduzir
# a - o
# creança - creança
# no - o
# cofre - cofre
# acharoado - acharoar
# que - que
# havia - haver
# junto - juntar
# ao - ao
# fogão - fogão
#
#  -
#
# do - do
# gabinete - gabinete
# de - de
# trabalho - trabalhar
# , - ,
# destinado - destinar
# a - o
# guardar - guardar
# a - o
# lenha - lenhar
# ou - ou
# o - o
# carvão - carvão
# que - que
# se - se
#
#  -
#
# consumia - consumir
# . - .
#
#
#  -
#
#
# De - De
# minuto - minutar
# em - em
# minuto - minutar
# abria-se - abria-se
# a - o
# tampa - tampar
# e - e
# sahia - sahia
# a - o
# cara - caro
# vermelha - vermelho
# e - e
#
#  -
#
# congestionada - congestionar
# do - do
# pequeno - pequeno
# , - ,
# uma - umar
# cara - caro
# de - de
# animal - animal
# assustado - assustar
# , - ,
# o - o
# que - que
# divertia - divertir
#
#  -
#
# extraordinariamente - extraordinariamente
# as - o
# visitas - visitar
# . - .
#
#
#  -
#
#
# Outra - Outra
# vez - vez
# , - ,
# n'uma - n'uma
# ceia - cear
# alegre - alegrar
# em - em
# que - que
# havia - haver
# rios - rio
# de - de
# _ - _
# champagne - champagne
# _ - _
# e - e
# risadas - risada
#
#  -
#
# crystallinas - crystallinas
# de - de
# mulheres - mulher
# , - ,
# Thadeu - Thadeu
# com - com
# um - um
# fato - fato
# de - de
# meia - meio
# preta - preto
# a - o
# cobril-o - cobril-o
#
#  -
#
# todo - todo
# e - e
# dous - dois
# castiçaes - castiçaes
# nas - o
# pequenas - pequeno
# mãos - mão
# , - ,
# servia - servir
# de - de
# centro - centrar
# agachado - agachar
# n'uma - n'uma
#
#  -
#
# posição - posição
# grotesca - grotesco
# no - o
# meio - mear
# da - da
# meza - meza
# . - .
#
#
#  -
#
#
# Sahiu - Sahiu
# d'alli - d'alli
# com - com
# uma - umar
# febre - febre
# que - que
# o - o
# teve - ter
# um - um
# mez - mez
# entre - entrar
# a - o
# morte - morte
# e - e
# a - o
# vida - vidar
# , - ,
#
#  -
#
# delirante - delirante
# , - ,
# sem - sem
# conhecer - conhecer
# ninguem - ninguem
# , - ,
# com - com
# a - o
# mãe - mãe
# debulhada - debulhar
# em - em
# lagrimas - lagrimas
# á - á
#
#  -
#
# cabeceira - cabeceira
# . - .
#
#
#  -
#
#
# Mas - Mas
# Thadeu - Thadeu
# não - não
# gostava - gostar
# de - de
# sua - suar
# mãe - mãe
# . - .
#
#
#  -
#
#
# Era - Era
# uma - umar
# creatura - creatura
# tão - tão
# debil - debil
# como - comer
# elle - elle
# , - ,
# pallida - pallida
# como - comer
# uma - umar
# defunta - defunto
# , - ,
# inerme - inerme
# , - ,
#
#  -
#
# estupida - estupida
# , - ,
# sem - sem
# vontade - vontade
# . - .
#
#
#  -
#
#
# As - As
# lobas - lobo
# defendem - defender
# os - o
# seus - seu
# filhos - filho
# , - ,
# a - o
# mãe - mãe
# de - de
# Thadeu - Thadeu
# não - não
# o - o
# sabia - saber
# defender - defender
# ! - !
#
#
#  -
#
#
# Entregava-o - Entregava-o
# ás - ás
# coleras - coleras
# descompostas - descomposto
# do - do
# pae - pae
# ; - ;
# aos - aos
# desprezos - desprezo
# gelidos - gelidos
# da - da
#
#  -
#
# tia - tio
# ; - ;
# aos - aos
# caprichos - capricho
# monstruosamente - monstruosamente
# comicos - comicos
# do - do
# marquez - marquez
# ; - ;
# ás - ás
# apupadas - apupar
#
#  -
#
# brutaes - brutaes
# das - das
# aias - aio
# e - e
# dos - dos
# lacaios - lacaio
# ; - ;
# aos - aos
# risos - riso
# das - das
# visitas - visitar
# ; - ;
# ao - ao
# pasmo - pasmar
#
#  -
#
# desprezador - desprezador
# das - das
# outras - outro
# creanças - creanças
# , - ,
# que - que
# iam - ir
# áquella - áquella
# casa - casar
# opulenta - opulento
# e - e
# ruidosa - ruidoso
#
#  -
#
# acompanhadas - acompanhar
# por - por
# seus - seu
# paes - paes
# , - ,
# vestidas - vestir
# de - de
# velludo - velludo
# , - ,
# com - com
# plumas - pluma
# nos - o
# seus - seu
#
#  -
#
# lindos - lindo
# chapéus - chapéu
# , - ,
# o - o
# ar - ar
# grave - gravar
# de - de
# meninos - menino
# bem - bem
# creados - creados
# , - ,
# e - e
# que - que
# não - não
# tinham - ter
#
#  -
#
# licença - licença
# de - de
# brincar - brincar
# com - com
# aquelle - aquelle
# pequeno - pequeno
# histrião - histrião
# , - ,
# feio - feio
# , - ,
# ridiculo - ridiculo
# , - ,
# doente - doente
# , - ,
#
#  -
#
# com - com
# gesto - gesto
# de - de
# epileptico - epileptico
# , - ,
# com - com
# fatos - fato
# de - de
# palhaço - palhaço
# e - e
# com - com
# soluços - soluço
# de - de
# martyr - martyr
# . - .
#
#
#
#  -
#
#
#
# II - II
#
#
#  -
#
#
# Um - Um
# dia - dia
# , - ,
# porém - porém
# , - ,
# fez-se - fez-se
# na - o
# vida - vidar
# atormentada - atormentar
# e - e
# tempestuosa - tempestuoso
# do - do
# pequeno - pequeno
#
#  -
#
# Thadeu - Thadeu
# uma - umar
# claridade - claridade
# de - de
# luar - luar
# , - ,
# uma - umar
# claridade - claridade
# opalisada - opalisada
# e - e
# doce - doce
# . - .
#
#
#  -
#
#
# Houve - Houve
# treguas - treguas
# nos - o
# seus - seu
# varios - varios
# martyrios - martyrios
# , - ,
# e - e
# sua - suar
# mãe - mãe
# , - ,
# n'uma - n'uma
# bella - bella
# manhã - manhã
# de - de
#
#  -
#
# primavera - primaverar
# em - em
# que - que
# os - o
# passaros - passaros
# cantavam - cantar
# ao - ao
# desafio - desafiar
# nas - o
# grandes - grande
# arvores - arvorar
# do - do
#
#  -
#
# jardim - jardim
# , - ,
# levou-o - levou-o
# pela - pelar
# mão - mão
# , - ,
# pé - pé
# ante - antar
# pé - pé
# , - ,
# a - o
# um - um
# quarto - quartar
# forrado - forrar
# de - de
# setim - setim
# côr - côr
#
#  -
#
# de - de
# rosa - rosar
# , - ,
# um - um
# quarto - quartar
# digno - dignar
# de - de
# servir - servir
# de - de
# habitação - habitação
# á - á
# fada - fadar
# mais - mais
# linda - lindo
# que - que
#
#  -
#
# uma - umar
# phantasia - phantasia
# de - de
# poeta - poetar
# oriental - oriental
# houvesse - haver
# imaginado - imaginar
# . - .
#
#
#  -
#
#
# N'aquelle - N'aquelle
# quarto - quartar
# havia - haver
# um - um
# ninho - ninhar
# todo - todo
# branco - branco
# feito - fazer
# de - de
# rendas - render
# , - ,
# de - de
# fitas - fito
# de - de
#
#  -
#
# setim - setim
# , - ,
# de - de
# pennugem - pennugem
# de - de
# passaros - passaros
# , - ,
# e - e
# n'esse - n'esse
# ninho - ninhar
# dormia - dormir
# uma - umar
# creancinha - creancinha
# que - que
#
#  -
#
# parecia - parecer
# uma - umar
# rosa - rosar
# . - .
#
#
#  -
#
#
# --É - --É
# tua - teu
# prima - primo
# ; - ;
# murmurou - murmurar
# baixinho - baixo
# a - o
# mãe - mãe
# de - de
# Thadeu - Thadeu
# , - ,
# emquanto - emquanto
# este - este
# , - ,
# mudo - mudar
# , - ,
#
#  -
#
# surpreso - surpresar
# , - ,
# extasiado - extasiar
# , - ,
# fitava - fitar
# os - o
# seus - seu
# olhos - olho
# vitreos - vitreos
# , - ,
# onde - onde
# o - o
# jubilo - jubilar
# acendia - acender
#
#  -
#
# uma - umar
# luz - luzir
# desusada - desusar
# , - ,
# nos - o
# grandes - grande
# olhos - olho
# luminosos - luminoso
# e - e
# pasmados - pasmar
# do - do
# _ - _
# bébé - bébé
# _ - _
# que - que
#
#  -
#
# acordára - acordára
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# como - comer
# Thadeu - Thadeu
# adorava - adorar
# aquella - aquella
# creança - creança
# ! - !
# Como - Como
# na - o
# sua - suar
# vida - vidar
# houve - haver
# de - de
#
#  -
#
# repente - repente
# um - um
# ficto - ficto
# , - ,
# uma - umar
# esperança - esperançar
# , - ,
# uma - umar
# luz - luzir
# ! - !
#
#
#  -
#
#
# Sua - Sua
# tia - tio
# , - ,
# uma - umar
# vez - vez
# em - em
# que - que
# a - o
# _ - _
# bebé - bebé
# _ - _
# chorava - chorar
# muito - muito
# nos - o
# braços - braço
# da - da
# ama - amo
# , - ,
#
#  -
#
# dissera - dizer
# a - o
# Thadeu - Thadeu
# com - com
# uma - umar
# voz - voz
# menos - menos
# glacial - glacial
# do - do
# que - que
# o - o
# costume - costumar
# : - :
#
#
#  -
#
#
# --Thadeu - --Thadeu
# , - ,
# brinca - brincar
# com - com
# a - o
# prima - primo
# a - o
# vêr - vêr
# se - se
# ella - ella
# se - se
# cala - calar
# . - .
#
#
#  -
#
#
# E - E
# elle - elle
# fizera - fazer
# calar - calar
# a - o
# rabujenta - rabujenta
# pequerrucha - pequerrucho
# . - .
#
#
#  -
#
#
# Desde - Desde
# esse - esse
# dia - dia
# soube-se - soube-se
# que - que
# a - o
# _ - _
# menina - menino
# _ - _
# tinha - ter
# o - o
# insolito - insolito
# capricho - caprichar
# de - de
#
#  -
#
# adorar - adorar
# Thadeu - Thadeu
# , - ,
# de - de
# rir - rir
# quando - quando
# elle - elle
# estava - estar
# de - de
# joelhos - joelho
# dobrado - dobrar
# sobre - sobrar
# o - o
# seu - seu
#
#  -
#
# berço - berço
# , - ,
# de - de
# chorar - chorar
# quando - quando
# alguem - alguem
# o - o
# levava - levar
# d'alli - d'alli
# para - parir
# fóra - fóra
# . - .
#
#
#  -
#
#
# A - A
# ama - amo
# tomou - tomar
# o - o
# costume - costumar
# de - de
# o - o
# chamar - chamar
# e - e
# de - de
# o - o
# fazer - fazer
# estar - estar
# horas - horar
# e - e
# horas - horar
# a - o
#
#  -
#
# entreter - entreter
# a - o
# _ - _
# menina - menino
# _ - _
# . - .
#
#
#  -
#
#
# Ao - Ao
# principio - principiar
# elle - elle
# fazia-lhe - fazia-lhe
# carêtas - carêtas
# e - e
# momices - momice
# , - ,
# como - comer
# as - o
# que - que
# usava - usar
# fazer - fazer
#
#  -
#
# para - parir
# divertir - divertir
# seu - seu
# tio - tio
# ; - ;
# depois - depois
# , - ,
# sem - sem
# bem - bem
# perceber - perceber
# porque - porque
# , - ,
# adoptou - adoptar
# outro - outro
#
#  -
#
# systema - systema
# inteiramente - inteiramente
# opposto - opposto
# . - .
#
#
#  -
#
#
# Percebeu - Percebeu
# que - que
# a - o
# pequenina - pequenino
# não - não
# queria - querer
# um - um
# bôbo - bôbo
# , - ,
# como - comer
# esse - esse
# espirito - espiritar
# embotado - embotar
#
#  -
#
# e - e
# pervertido - perverter
# que - que
# o - o
# victimára - victimára
# com - com
# os - o
# seus - seu
# caprichos - capricho
# . - .
# O - O
# que - que
# a - o
# _ - _
# bebé - bebé
# _ - _
#
#  -
#
# queria - querer
# , - ,
# na - o
# ingenuidade - ingenuidade
# adoravel - adoravel
# do - do
# seu - seu
# despotismo - despotismo
# infantil - infantil
# , - ,
# era - ser
# um - um
#
#  -
#
# companheiro - companheiro
# de - de
# seus - seu
# brinquedos - brinquedo
# , - ,
# um - um
# socio - socio
# , - ,
# um - um
# escravo - escravo
# que - que
# a - o
# adorasse - adorar
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# era - ser
# tudo - tudo
# para - parir
# ella - ella
# : - :
# queria-o - queria-o
# perto - perto
# da - da
# grande - grande
# tina - tinir
# em - em
# que - que
# tomava - tomar
# o - o
#
#  -
#
# seu - seu
# banho - banhar
# de - de
# manhã - manhã
# ; - ;
# queria-o - queria-o
# junto - juntar
# da - da
# pequena - pequeno
# mesa - mesa
# de - de
# nacar - nacar
# onde - onde
# a - o
# ama - amo
#
#  -
#
# lhe - lhe
# dava - dar
# as - o
# sopinhas - sopa
# ; - ;
# queria-o - queria-o
# no - o
# berço - berço
# ao - ao
# adormecer - adormecer
# ; - ;
# queria-o - queria-o
# no - o
#
#  -
#
# jardim - jardim
# , - ,
# á - á
# sombra - sombra
# das - das
# arvores - arvorar
# , - ,
# sobre - sobrar
# a - o
# arêa - arêa
# finissima - finissima
# , - ,
# onde - onde
# se - se
# rolava - rolar
# , - ,
#
#  -
#
# vestida - vestir
# de - de
# rendas - render
# brancas - branco
# , - ,
# a - o
# rir - rir
# como - comer
# uma - umar
# perdida - perdido
# . - .
#
#
#  -
#
#
# Chamaram-lhe - Chamaram-lhe
# Margarida - Margarida
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# quer - querer
# dizer - dizer
# perola - perolar
# , - ,
# e - e
# Thadeu - Thadeu
# , - ,
# que - que
# vira - virar
# muitas - muito
# vezes - vezar
# sua - suar
# tia - tio
#
#  -
#
# vestida - vestir
# de - de
# baile - bailar
# , - ,
# achava - achar
# um - um
# nome - nome
# muito - muito
# bem - bem
# posto - postar
# áquella - áquella
# creança - creança
# branca - branco
# , - ,
#
#  -
#
# transparente - transparentar
# , - ,
# loura - louro
# , - ,
# idealmente - idealmente
# graciosa - gracioso
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# Thadeu - Thadeu
# ainda - ainda
# andava - andar
# muita - muito
# vez - vez
# vestido - vestir
# de - de
# marujo - marujar
# , - ,
# de - de
# granadeiro - granadeiro
# , - ,
# de - de
#
#  -
#
# tyrolez - tyrolez
# e - e
# de - de
# alferes - alferes
# , - ,
# ainda - ainda
# o - o
# introduziam - introduzir
# no - o
# cofre - cofre
# da - da
# lenha - lenhar
# , - ,
# ainda - ainda
# o - o
#
#  -
#
# faziam - fazer
# fumar - fumar
# um - um
# charuto - charuto
# depois - depois
# de - de
# jantar - jantar
# , - ,
# cheio - cheio
# de - de
# ancias - ancias
# , - ,
# de - de
# nauseas - nauseas
# , - ,
#
#  -
#
# de - de
# gritos - grito
# abafados - abafar
# de - de
# angustia - angustiar
# ! - !
# ... - ...
# Mas - Mas
# que - que
# importava - importar
# ! - !
#
#
#  -
#
#
# Logo - Logo
# que - que
# podia - poder
# escapava-se - escapava-se
# para - parir
# o - o
# quarto - quartar
# da - da
# fada - fadar
# , - ,
# para - parir
# o - o
# estojo - estojar
# côr - côr
# de - de
#
#  -
#
# rosa - rosar
# da - da
# sua - suar
# _ - _
# perola - perolar
# _ - _
# , - ,
# da - da
# sua - suar
# Margarida - Margarida
# , - ,
# e - e
# então - então
# eram - ser
# risadas - risada
# sem - sem
# fim - fim
# , - ,
#
#  -
#
# eram - ser
# corridas - corrido
# delirantes - delirante
# por - por
# sobre - sobrar
# o - o
# tapete - tapetar
# , - ,
# era - ser
# um - um
# papaguear - papaguear
# de - de
# duas - dois
#
#  -
#
# aves - ave
# felizes - feliz
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# com - com
# a - o
# idade - idade
# ia-se - ia-se
# fazendo - fazer
# despotica - despotica
# . - .
#
#
#  -
#
#
# Pudera - Pudera
# ! - !
#
#
#  -
#
#
# Ou - Ou
# ella - ella
# não - não
# fosse - ser
# mulher - mulher
# , - ,
# e - e
# estremecida - estremecido
# pelo - pelar
# seu - seu
# humilde - humildar
# escravo - escravo
# ! - !
#
#
#  -
#
#
# Mas - Mas
# era - ser
# assim - assim
# mesmo - mesmo
# que - que
# elle - elle
# a - o
# queria - querer
# . - .
#
#
#  -
#
#
# Quando - Quando
# as - o
# mãosinhas - mãosinhas
# polpudas - polpudo
# e - e
# brancas - branco
# de - de
# Margarida - Margarida
# lhe - lhe
# batiam - bater
# , - ,
# Thadeu - Thadeu
#
#  -
#
# sentia-se - sentia-se
# feliz - feliz
# como - comer
# um - um
# rei - rei
# . - .
#
#
#  -
#
#
# Quando - Quando
# ella - ella
# o - o
# obrigava - obrigar
# a - o
# agachar-se - agachar-se
# no - o
# chão - chão
# para - parir
# lhe - lhe
# servir - servir
# de - de
# jumento - jumento
# , - ,
#
#  -
#
# o - o
# rapazinho - rapaz
# tinha - ter
# tentações - tentação
# de - de
# rinchar - rinchar
# de - de
# prazer - prazer
# , - ,
# fazendo - fazer
# o - o
# passo - passar
# bem - bem
# ao - ao
#
#  -
#
# vivo - viver
# . - .
#
#
#  -
#
#
# Porque - Porque
# no - o
# fim - fim
# de - de
# contas - contar
# , - ,
# apezar - apezar
# de - de
# todas - todo
# as - o
# suas - suar
# adoraveis - adoraveis
# crueldades - crueldade
# , - ,
#
#  -
#
# Margarida - Margarida
# gostava - gostar
# d'elle - d'elle
# . - .
#
#
#  -
#
#
# A - A
# presença - presença
# de - de
# Thadeu - Thadeu
# illuminava - illuminava
# de - de
# risos - riso
# o - o
# seu - seu
# rosto - rostir
# oval - oval
# coroado - coroar
# de - de
#
#  -
#
# cabellos - cabellos
# louros - louro
# annellados - annellados
# , - ,
# o - o
# seu - seu
# rosto - rostir
# a - o
# um - um
# tempo - tempo
# angelico - angelico
# e - e
# gaiato - gaiatar
# ! - !
#
#
#  -
#
#
# Margarida - Margarida
# não - não
# o - o
# achava - achar
# feio - feio
# , - ,
# nem - nem
# tolo - tolo
# , - ,
# nem - nem
# ridiculo - ridiculo
# , - ,
# nem - nem
# doente - doente
# . - .
#
#
#  -
#
#
# Não - Não
# desprezava - desprezar
# a - o
# fraqueza - fraqueza
# dos - dos
# seus - seu
# braços - braço
# , - ,
# nem - nem
# a - o
# pobreza - pobreza
# absoluta - absoluto
# da - da
# sua - suar
#
#  -
#
# imaginação - imaginação
# . - .
#
#
#  -
#
#
# Pelo - Pelo
# contrario - contrariar
# ! - !
# Admirava - Admirava
# o - o
# ! - !
#
#
#  -
#
#
# Sim - Sim
# ; - ;
# ella - ella
# dera-lhe - dera-lhe
# essa - esse
# sensação - sensação
# poderosa - poderoso
# e - e
# extraordinaria - extraordinaria
# , - ,
# a - o
# sensação - sensação
#
#  -
#
# dos - dos
# que - que
# se - se
# vêem - ver
# admirados - admirar
# com - com
# ingenua - ingenua
# confiança - confiança
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# pedia-lhe - pedia-lhe
# cousas - cousa
# enormes - enorme
# , - ,
# com - com
# uma - umar
# serenidade - serenidade
# ineffavel - ineffavel
# de - de
#
#  -
#
# crente - crente
# ! - !
#
#
#  -
#
#
# Pedira-lhe - Pedira-lhe
# um - um
# ninho - ninhar
# de - de
# melros - melro
# , - ,
# e - e
# o - o
# que - que
# é - ser
# mais - mais
# ! - !
# conseguira - conseguir
# que - que
# elle - elle
# tão - tão
#
#  -
#
# medroso - medroso
# , - ,
# tão - tão
# debil - debil
# , - ,
# tão - tão
# assustado - assustar
# , - ,
# trepasse - trepar
# pelos - pelos
# braços - braço
# nodosos - nodoso
# de - de
# uma - umar
#
#  -
#
# grande - grande
# arvore - arvorar
# e - e
# lh'o - lh'o
# fosse - ser
# buscar - buscar
# lá - lá
# cima - cima
# . - .
#
#
#  -
#
#
# Que - Que
# triumpho - triumpho
# este - este
# d'ella - d'ella
# , - ,
# ao - ao
# ver - ver
# satisfeito - satisfazer
# o - o
# seu - seu
# capricho - caprichar
# ! - !
# mas - mas
# que - que
#
#  -
#
# triumpho - triumpho
# maior - maior
# ainda - ainda
# o - o
# d'elle - d'elle
# ao - ao
# comprehender - comprehender
# , - ,
# que - que
# alcançara - alcançar
# essa - esse
# cousa - cousa
#
#  -
#
# prodigiosa - prodigioso
# , - ,
# que - que
# nem - nem
# nos - o
# sonhos - sonho
# mais - mais
# arrojados - arrojar
# das - das
# suas - suar
# noites - noite
# de - de
# febre - febre
#
#  -
#
# elle - elle
# ousara - ousar
# até - até
# ali - ali
# conceber - conceber
# ! - !
#
#
#  -
#
#
# Um - Um
# dia - dia
# Margarida - Margarida
# , - ,
# em - em
# frente - frente
# d'aquelle - d'aquelle
# rasgo - rasgar
# assombroso - assombroso
# de - de
# valentia - valentia
# que - que
#
#  -
#
# collocara - collocara
# Thadeu - Thadeu
# ao - ao
# lado - lado
# dos - dos
# maiores - maior
# heroes - heroes
# , - ,
# puzera - puzera
# se - se
# grave - gravar
# , - ,
#
#  -
#
# meditativa - meditativo
# , - ,
# e - e
# apontando - apontar
# com - com
# serena - sereno
# magestade - magestade
# para - parir
# a - o
# lua - lua
# que - que
# se - se
# reflectia - reflectir
#
#  -
#
# n'um - n'um
# tanque - tanque
# do - do
# jardim - jardim
# , - ,
# pedira - pedir
# a - o
# lua - lua
# ao - ao
# seu - seu
# amigo - amigar
# Thadeu - Thadeu
# ! - !
#
#
#  -
#
#
# Está - Está
# claro - claro
# que - que
# elle - elle
# lh'a - lh'a
# não - não
# pôde - poder
# dar - dar
# , - ,
# mas - mas
# gostou - gostar
# d'aquillo - d'aquillo
# ! - !
#
#
#  -
#
#
# Percebeu - Percebeu
# que - que
# o - o
# julgavam - julgar
# capaz - capaz
# de - de
# cousas - cousa
# grandes - grande
# , - ,
# de - de
# levar - levar
# a - o
# cabo - cabo
#
#  -
#
# emprezas - emprezas
# impossiveis - impossiveis
# , - ,
# e - e
# esta - este
# idéa - idéa
# que - que
# alguem - alguem
# tinha - ter
# da - da
# sua - suar
# força - forçar
# , - ,
# fê-lo - fê-lo
#
#  -
#
# crescer - crescer
# aos - aos
# seus - seu
# proprios - proprios
# olhos - olho
# . - .
#
#
#  -
#
#
# O - O
# marquez - marquez
# conhecendo - conhecer
# que - que
# o - o
# pequeno - pequeno
# deixára - deixára
# de - de
# ser - ser
# seu - seu
# joguete - joguetar
# , - ,
#
#  -
#
# simplesmente - simplesmente
# para - parir
# ser - ser
# joguete - joguetar
# de - de
# sua - suar
# filha - filho
# e - e
# herdeira - herdeiro
# , - ,
# applaudiu-se - applaudiu-se
# de - de
#
#  -
#
# lhe - lhe
# haver - haver
# dado - dar
# aquella - aquella
# educação - educação
# especial - especial
# , - ,
# e - e
# prohibiu - prohibiu
# que - que
# o - o
# distrahissem - distrahissem
# , - ,
#
#  -
#
# fosse - ser
# sob - sob
# que - que
# pretexto - pretextar
# fosse - ser
# , - ,
# das - das
# suas - suar
# novas - novo
# funcções - funcções
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# era - ser
# ainda - ainda
# muito - muito
# pequenina - pequenino
# para - parir
# entreter - entreter
# os - o
# paes - paes
# . - .
#
#
#  -
#
#
# Elle - Elle
# precisava - precisar
# das - das
# excitações - excitação
# da - da
# politica - politicar
# , - ,
# das - das
# luctas - luctas
# do - do
# parlamento - parlamentar
# , - ,
# dos - dos
#
#  -
#
# sorrisos - sorriso
# falsos - falso
# ou - ou
# verdadeiros - verdadeiro
# , - ,
# caros - caro
# ou - ou
# baratos - barato
# das - das
# formosas - formoso
# mulheres - mulher
# , - ,
#
#  -
#
# do - do
# jogo - jogar
# , - ,
# da - da
# ambição - ambição
# , - ,
# do - do
# amor - amor
# , - ,
# da - da
# violencia - violencia
# corrosiva - corrosivo
# de - de
# todas - todo
# as - o
#
#  -
#
# pequenas - pequeno
# e - e
# grandes - grande
# paixões - paixão
# ! - !
#
#
#  -
#
#
# Ella - Ella
# precisava - precisar
# do - do
# luxo - luxar
# , - ,
# das - das
# joias - joias
# que - que
# scintillam - scintillam
# , - ,
# das - das
# sedas - sedar
# que - que
# se - se
#
#  -
#
# quebram - quebrar
# em - em
# ondulações - ondulação
# brilhantes - brilhante
# , - ,
# do - do
# côro - côro
# das - das
# adulações - adulação
# mentidas - mentir
# , - ,
# de - de
#
#  -
#
# todas - todo
# as - o
# ephemeras - ephemeras
# alegrias - alegria
# que - que
# só - só
# o - o
# mundo - mundo
# lhe - lhe
# podia - poder
# dar - dar
# . - .
#
#
#  -
#
#
# Para - Para
# ambos - ambos
# Margarida - Margarida
# seria - seriar
# um - um
# remorso - remorso
# , - ,
# se - se
# a - o
# não - não
# vissem - ver
# tão - tão
# nedia - nedia
# , - ,
# tão - tão
#
#  -
#
# roliça - roliço
# , - ,
# tão - tão
# alegre - alegrar
# , - ,
# com - com
# chispas - chispa
# de - de
# travessura - travessura
# maliciosa - malicioso
# no - o
# olhar - olhar
# , - ,
# sempre - sempre
#
#  -
#
# acompanhada - acompanhar
# do - do
# seu - seu
# pequeno - pequeno
# amigo - amigar
# , - ,
# submisso - submisso
# e - e
# fiel - fiel
# como - comer
# um - um
# cão - cão
# . - .
#
#
#  -
#
#
# Deixaram-os - Deixaram-os
# , - ,
# pois - pois
# , - ,
# crescer - crescer
# e - e
# viver - viver
# juntos - junto
# sob - sob
# o - o
# olhar - olhar
# das - das
# aias - aio
# , - ,
# sempre - sempre
#
#  -
#
# um - um
# pouco - pouco
# hostil - hostil
# para - parir
# Thadeu - Thadeu
# e - e
# por - por
# isso - isso
# tanto - tanto
# mais - mais
# insuspeito - insuspeito
# . - .
#
#
#  -
#
#
# Foi - Foi
# o - o
# verdadeiro - verdadeiro
# paraiso - paraiso
# que - que
# este - este
# conheceu - conhecer
# na - o
# terra - terra
# , - ,
# foi - ser
# a - o
# sua - suar
# idade - idade
# de - de
#
#  -
#
# ouro - ourar
# . - .
#
#
#  -
#
#
# Ha - Ha
# entes - ente
# que - que
# nunca - nunca
# nem - nem
# por - por
# um - um
# instante - instante
# só - só
# conheceram - conhecer
# a - o
# completa - completar
# ventura - venturo
# . - .
#
#
#  -
#
#
# São - São
# de - de
# todos - todo
# os - o
# mais - mais
# desgraçados - desgraçar
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# mais - mais
# tarde - tardar
# podia - poder
# ao - ao
# menos - menos
# recordar-se - recordar-se
# ! - !
#
#
#  -
#
#
# E - E
# elle - elle
# sabia - saber
# apreciar - apreciar
# tão - tão
# bem - bem
# aquellas - aquellas
# alegrias - alegria
# que - que
# em - em
# manhã - manhã
# abençoada - abençoar
#
#  -
#
# tinham - ter
# cahido - cahido
# sobre - sobrar
# a - o
# sua - suar
# pobre - pobre
# cabeça - cabeça
# ! - !
# ... - ...
#
#
#  -
#
#
# Um - Um
# dia - dia
# Margarida - Margarida
# travessa - travesso
# e - e
# caprichosa - caprichoso
# como - comer
# era - ser
# , - ,
# desattendendo - desattendendo
# todas - todo
# as - o
#
#  -
#
# advertencias - advertencias
# de - de
# Thadeu - Thadeu
# , - ,
# deixara-se - deixara-se
# cahir - cahir
# dentro - dentro
# do - do
# tanque - tanque
# do - do
# jardim - jardim
# . - .
#
#
#  -
#
#
# O - O
# pequeno - pequeno
# não - não
# sabia - saber
# nadar - nadar
# . - .
#
#
#  -
#
#
# Que - Que
# importa - importar
# ! - !
#
#
#  -
#
#
# Sem - Sem
# premeditação - premeditação
# , - ,
# sem - sem
# raciocinio - raciocinio
# , - ,
# obedecendo - obedecer
# a - o
# um - um
# instincto - instincto
# de - de
# dedicação - dedicação
#
#  -
#
# inteiramente - inteiramente
# canina - canino
# , - ,
# deitou-se - deitou-se
# n'agua - n'agua
# atrás - atrás
# d'ella - d'ella
# . - .
#
#
#  -
#
#
# As - As
# criadas - criar
# , - ,
# acudindo - acudir
# , - ,
# tiraram - tirar
# do - do
# tanque - tanque
# as - o
# duas - dois
# creanças - creanças
# abraçadas - abraçar
# . - .
#
#
#  -
#
#
# Imagine-se - Imagine-se
# o - o
# que - que
# iria - iriar
# em - em
# casa - casar
# ! - !
#
#
#  -
#
#
# Thadeu - Thadeu
# , - ,
# castigado - castigar
# severamente - severamente
# , - ,
# não - não
# quiz - quiz
# condemnar - condemnar
# a - o
# sua - suar
# amiguinha - amigo
# , - ,
# para - parir
#
#  -
#
# se - se
# salvar - salvar
# a - o
# si - si
# . - .
#
#
#  -
#
#
# Foi - Foi
# ella - ella
# que - que
# , - ,
# soberba - soberbo
# , - ,
# graciosa - gracioso
# , - ,
# com - com
# a - o
# sua - suar
# magestade - magestade
# de - de
# pequena - pequeno
# rainha - rei
# , - ,
#
#  -
#
# disse - dizer
# aos - aos
# paes - paes
# : - :
#
#
#  -
#
#
# --Não - --Não
# batam - bater
# n'elle - n'elle
# . - .
# Elle - Elle
# pediu-me - pediu-me
# que - que
# não - não
# fosse - ser
# . - .
# Eu - Eu
# é - ser
# que - que
# quiz - quiz
# ir - ir
# . - .
#
#
#  -
#
#
# Acharam-na - Acharam-na
# adoravel - adoravel
# ; - ;
# encheram-na - encheram-na
# de - de
# caricias - cariciar
# e - e
# de - de
# gulodices - gulodice
# , - ,
# mas - mas
# ninguem - ninguem
#
#  -
#
# pensou - pensar
# na - o
# acção - acção
# tão - tão
# simples - simples
# e - e
# tão - tão
# heroica - heroica
# do - do
# pequeno - pequeno
# Thadeu - Thadeu
# , - ,
# a - o
# quem - quem
#
#  -
#
# tinham - ter
# posto - postar
# a - o
# alcunha - alcunhar
# de - de
# _ - _
# medroso - medroso
# _ - _
# . - .
#
#
#
#  -
#
#
#
# III - III
#
#
#  -
#
#
# Foi - Foi
# assim - assim
# que - que
# Margarida - Margarida
# fez - fazer
# nove - nove
# annos - annos
# . - .
#
#
#  -
#
#
# Era - Era
# linda - lindo
# e - e
# indomita - indomita
# . - .
#
#
#  -
#
#
# Tinha - Tinha
# um - um
# corpo - corpo
# airoso - airoso
# , - ,
# flexivel - flexivel
# e - e
# forte - forte
# . - .
#
#
#  -
#
#
# Ninguem - Ninguem
# opprimira - opprimira
# nunca - nunca
# aquella - aquella
# altiva - altivo
# natureza - natureza
# aristocratica - aristocratica
# . - .
#
#
#  -
#
#
# D'ahi - D'ahi
# a - o
# sua - suar
# isenção - isenção
# , - ,
# a - o
# liberdade - liberdade
# dos - dos
# seus - seu
# movimentos - movimento
# , - ,
# o - o
# fulgor - fulgor
# radioso - radioso
#
#  -
#
# dos - dos
# seus - seu
# grandes - grande
# olhos - olho
# azues - azues
# , - ,
# onde - onde
# um - um
# observador - observador
# veria - ver
# talvez - talvez
# as - o
#
#  -
#
# scintillações - scintillações
# metallicas - metallicas
# que - que
# davam - dar
# tamanha - tamanho
# dureza - dureza
# ao - ao
# olhar - olhar
# de - de
# sua - suar
# mãe - mãe
# . - .
#
#
#  -
#
#
# Margarida - Margarida
# tinha - ter
# uma - umar
# vontade - vontade
# de - de
# ferro - ferrar
# , - ,
# e - e
# uns - um
# nervos - nervo
# de - de
# mulher - mulher
# caprichosa - caprichoso
# . - .
#
#
#  -
#
#
# Quando - Quando
# a - o
# professora - professorar
# allemã - allemã
# que - que
# seus - seu
# paes - paes
# mandaram - mandar
# buscar - buscar
# , - ,
# quiz - quiz
# sujeitar - sujeitar
#
#  -
#
# o - o
# seu - seu
# espirito - espiritar
# a - o
# uma - umar
# certa - certo
# disciplina - disciplinar
# , - ,
# Margarida - Margarida
# revoltou-se - revoltou-se
# n'um - n'um
# impeto - impeto
#
#  -
#
# de - de
# insubordinação - insubordinação
# selvatica - selvatica
# . - .
#
#
#  -
#
#
# Tivera - Tivera
# criadas - criar
# que - que
# a - o
# serviam - servir
# , - ,
# um - um
# escravo - escravo
# que - que
# tremia - tremer
# diante - diante
# d'ella - d'ella
# , - ,
# e - e
#
#  -
#
# paes - paes
# que - que
# transigiam - transigir
# com - com
# todos - todo
# os - o
# seus - seu
# pequenos - pequeno
# desejos - desejo
# de - de
# creança - creança
# . - .
#
#
#  -
#
#
# Dera-se - Dera-se
# bem - bem
# n'aquelle - n'aquelle
# meio - mear
# , - ,
# não - não
# queria - querer
# outro - outro
# , - ,
# não - não
# o - o
# aceitava - aceitar
# , - ,
# nem - nem
#
#  -
#
# curvaria - curvar
# a - o
# sua - suar
# cabecinha - cabeça
# erecta - erecto
# e - e
# firme - firmar
# com - com
# uma - umar
# aureola - aureolar
# de - de
# anneis - anneis
# de - de
#
#  -
#
# ouro - ourar
# a - o
# cerca-la - cerca-la
# , - ,
# a - o
# nenhum - nenhum
# dominio - dominio
# que - que
# não - não
# fosse - ser
# o - o
# da - da
# sua - suar
# vontade - vontade
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Um - Um
# dia - dia
# Thadeu - Thadeu
# ouviu - ouvir
# fallar - fallar
# vagamente - vagamente
# n'uma - n'uma
# viagem - viagem
# que - que
# seus - seu
# tios - tio
# iam - ir
#
#  -
#
# fazer - fazer
# ao - ao
# estrangeiro - estrangeirar
# , - ,
# e - e
# viu - ver
# começar - começar
# os - o
# preparativos - preparativo
# para - parir
# ella - ella
# . - .
#
#
#  -
#
#
# Ficou - Ficou
# no - o
# céo - céo
# . - .
#
#
#  -
#
#
# Viveria - Viveria
# só - só
# na - o
# grande - grande
# casa - casar
# com - com
# Margarida - Margarida
# e - e
# o - o
# rancho - rancho
# dos - dos
# criados - criar
# . - .
#
#
#  -
#
#
# Seriam - Seriam
# livres - livre
# . - .
#
#
#  -
#
#
# Ella - Ella
# teria - ter
# um - um
# balouço - balouçar
# no - o
# jardim - jardim
# , - ,
# uma - umar
# rede - redar
# brazileira - brazileira
# no - o
# kiosque - kiosque
# , - ,
# e - e
# um - um
#
#  -
#
# barquinho - barco
# no - o
# lago - lago
# . - .
#
#
#  -
#
#
# Eram - Eram
# os - o
# seus - seu
# tres - tres
# sonhos - sonho
# ainda - ainda
# irrealizados - irrealizados
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# dirigiria - dirigir
# todos - todo
# os - o
# trabalhos - trabalho
# . - .
#
#
#  -
#
#
# Diria - Diria
# aos - aos
# operarios - operarios
# que - que
# tinha - ter
# dezeseis - dezeseis
# annos - annos
# , - ,
# e - e
# que - que
# era - ser
# sobrinho - sobrinho
# do - do
#
#  -
#
# marquez - marquez
# . - .
#
#
#  -
#
#
# Os - Os
# operarios - operarios
# haviam - haver
# de - de
# respeital-o - respeital-o
# . - .
#
#
#  -
#
#
# Elles - Elles
# não - não
# tinham - ter
# precisão - precisão
# nenhuma - nenhum
# de - de
# se - se
# rir - rir
# do - do
# seu - seu
# corpo - corpo
# enfezado - enfezar
# e - e
#
#  -
#
# rachitico - rachitico
# . - .
#
#
#  -
#
#
# Não - Não
# é - ser
# preciso - precisar
# ser-se - ser-se
# athletico - athletico
# para - parir
# se - se
# ser - ser
# respeitado - respeitar
# pelos - pelos
# homens - homem
# a - o
#
#  -
#
# quem - quem
# se - se
# paga - pago
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# havia - haver
# de - de
# arranjar - arranjar
# algum - algum
# meio - mear
# de - de
# lhes - lhe
# pagar - pagar
# . - .
#
#
#  -
#
#
# Andava - Andava
# então - então
# doente - doente
# , - ,
# exquisito - exquisito
# , - ,
# com - com
# uma - umar
# excitação - excitação
# nervosa - nervoso
# que - que
# o - o
#
#  -
#
# torturava - torturar
# . - .
#
#
#  -
#
#
# O - O
# seu - seu
# affecto - affecto
# por - por
# Margarida - Margarida
# tivera - ter
# uma - umar
# recrudescencia - recrudescencia
# violenta - violento
# e - e
#
#  -
#
# dolorosa - doloroso
# . - .
#
#
#  -
#
#
# Tinha - Tinha
# vagos - vago
# presentimentos - presentimentos
# que - que
# o - o
# faziam - fazer
# chorar - chorar
# . - .
#
#
#  -
#
#
# Parecêra-lhe - Parecêra-lhe
# que - que
# sua - suar
# tia - tio
# , - ,
# uma - umar
# vez - vez
# , - ,
# ao - ao
# encontral-o - encontral-o
# n'um - n'um
# corredor - corredor
# , - ,
# olhára - olhára
#
#  -
#
# para - parir
# elle - elle
# com - com
# uma - umar
# aguda - agudo
# ironia - ironia
# malevola - malevola
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# --Não - --Não
# sabes - saber
# , - ,
# Thadeu - Thadeu
# ? - ?
# gritou - gritar
# Margarida - Margarida
# entrando - entrar
# como - comer
# um - um
# raio - raiar
# de - de
# sol - sol
# no - o
#
#  -
#
# quarto - quartar
# onde - onde
# costumava - costumar
# brincar - brincar
# com - com
# o - o
# primo - primar
# . - .
# Não - Não
# sabes?--E - sabes?--E
# atirou-lhe - atirou-lhe
#
#  -
#
# negligentemente - negligentemente
# aos - aos
# pés - pé
# com - com
# um - um
# feixe - feixe
# de - de
# flôres - flôres
# e - e
# de - de
# folhas - folhar
# verdes - verde
# que - que
#
#  -
#
# estivera - estar
# colhendo - colher
# na - o
# quinta.--Tambem - quinta.--Tambem
# eu - eu
# vou - ir
# com - com
# o - o
# papá - papar
# e - e
# a - o
# mamã - mamã
# . - .
# Vamos - Vamos
#
#  -
#
# a - o
# Paris - Paris
# ... - ...
# muito - muito
# longe - longe
# ... - ...
# muito - muito
# longe - longe
# ... - ...
# Estive - Estive
# á - á
# escuta - escutar
# ... - ...
# percebi - perceber
# umas - umar
#
#  -
#
# cousas - cousa
# mas - mas
# não - não
# percebi - perceber
# outras - outro
# . - .
# Fallaram - Fallaram
# n'um - n'um
# convento - convento
# ... - ...
# no - o
# _ - _
# Sacré - Sacré
#
#  -
#
# Cœur - Cœur
# _ - _
# ... - ...
# Sabes - Sabes
# o - o
# que - que
# é - ser
# ? - ?
# ... - ...
#
#
#  -
#
#
# Thadeu - Thadeu
# sabia - saber
# . - .
#
#
#  -
#
#
# Não - Não
# disse - dizer
# nada - nado
# , - ,
# mas - mas
# no - o
# outro - outro
# dia - dia
# não - não
# pôde - poder
# levantar-se - levantar-se
# da - da
# cama - cama
# . - .
#
#
#  -
#
#
# Tinha - Tinha
# dôres - dôres
# em - em
# todo - todo
# o - o
# corpo - corpo
# e - e
# um - um
# grande - grande
# cançasso - cançasso
# , - ,
# como - comer
# de - de
# quem - quem
# deu - dar
# uma - umar
#
#  -
#
# larga - largo
# caminhada - caminhar
# . - .
#
#
#  -
#
#
# Gemia - Gemia
# baixinho - baixo
# abrazado - abrazado
# em - em
# febre - febre
# , - ,
# e - e
# quando - quando
# pediu - pedir
# muito - muito
# humildemente - humildemente
# , - ,
# com - com
#
#  -
#
# medo - medo
# de - de
# recusa - recusar
# , - ,
# para - parir
# ver - ver
# Margarida - Margarida
# , - ,
# disseram-lhe - disseram-lhe
# que - que
# a - o
# doença - doença
# d'elle - d'elle
#
#  -
#
# podia - poder
# pegar-se - pegar-se
# e - e
# que - que
# as - o
# meninas - menino
# não - não
# iam - ir
# ao - ao
# quarto - quartar
# dos - dos
# homens - homem
# . - .
#
#
#  -
#
#
# Pois - Pois
# isto - isto
# é - ser
# um - um
# homem - homem
# ? - ?
# pensava - pensar
# Thadeu - Thadeu
# desolado - desolar
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Margarida - Margarida
# de - de
# endoudecida - endoudecer
# com - com
# a - o
# mudança - mudança
# , - ,
# com - com
# o - o
# movimento - movimentar
# , - ,
# com - com
# a - o
#
#  -
#
# espectativa - espectativa
# de - de
# uma - umar
# existencia - existencia
# desconhecida - desconhecido
# e - e
# nova - novo
# , - ,
# esqueceu-se - esqueceu-se
#
#  -
#
# completamente - completamente
# do - do
# enfermo - enfermar
# . - .
#
#
#  -
#
#
# Partiu - Partiu
# sem - sem
# pedir - pedir
# sequer - sequer
# para - parir
# lhe - lhe
# dizer - dizer
# adeus - adeus
# ! - !
# ... - ...
#
#
#  -
#
#
# Quando - Quando
# Thadeu - Thadeu
# ao - ao
# cabo - cabo
# de - de
# um - um
# mez - mez
# de - de
# doença - doença
# sahiu - sahiu
# do - do
# quarto - quartar
# com - com
# o - o
# rosto - rostir
#
#  -
#
# macilento - macilento
# , - ,
# abatido - abater
# , - ,
# cançado - cançado
# , - ,
# como - comer
# o - o
# de - de
# um - um
# velho - velho
# , - ,
# com - com
# a - o
# espinha - espinhar
# dobrada - dobrar
# e - e
#
#  -
#
# as - o
# magras - magro
# pernas - perna
# vacillantes - vacillantes
# , - ,
# pediu - pedir
# para - parir
# ir - ir
# ao - ao
# quarto - quartar
# onde - onde
# brincava - brincar
# com - com
#
#  -
#
# a - o
# sua - suar
# _ - _
# perola - perolar
# _ - _
# , - ,
# e - e
# agachou-se - agachou-se
# a - o
# um - um
# cantinho - canto
# a - o
# chorar - chorar
# com - com
# uns - um
# uivos - uivo
#
#  -
#
# dolorosos - doloroso
# , - ,
# com - com
# uns - um
# uivos - uivo
# caninos - canino
# que - que
# faziam - fazer
# mal - mal
# . - .
#
#
#  -
#
#
# Sentia-se - Sentia-se
# para - parir
# sempre - sempre
# só - só
# ... - ...
#
#
#
#  -
#
#
#
# IV - IV
#
#
#  -
#
#
# O - O
# marquez - marquez
# tinha - ter
# ido - ir
# sósinho - sósinho
# para - parir
# França - França
# . - .
# Fôra - Fôra
# , - ,
# ao - ao
# que - que
# se - se
# dizia - dizer
# , - ,
# buscar - buscar
# a - o
#
#  -
#
# filha - filho
# ao - ao
# _ - _
# Sacré-Cœur - Sacré-Cœur
# _ - _
# . - .
#
#
#  -
#
#
# A - A
# educação - educação
# de - de
# Margarida - Margarida
# devia - dever
# estar - estar
# completa - completar
# . - .
# Fôra-se - Fôra-se
# embora - embora
# com - com
# nove - nove
#
#  -
#
# annos - annos
# de - de
# idade - idade
# , - ,
# e - e
# haviam - haver
# já - já
# passado - passar
# sete - sete
# depois - depois
# que - que
# ella - ella
# partira - partir
# . - .
#
#
#  -
#
#
# Sete - Sete
# annos - annos
# ! - !
# que - que
# longo - longo
# periodo - periodo
# ! - !
#
#
#  -
#
#
# A - A
# casa - casar
# dos - dos
# marquezes - marquezes
# era - ser
# pouco - pouco
# mais - mais
# ou - ou
# menos - menos
# a - o
# mesma - mesmo
# cousa - cousa
# . - .
#
#
#  -
#
#
# Thadeu - Thadeu
# perdêra - perdêra
# sua - suar
# mãe - mãe
# , - ,
# mas - mas
# aquella - aquella
# figura - figurar
# apagada - apagar
# , - ,
# melancolica - melancolica
# , - ,
# de - de
# uma - umar
#
#  -
#
# debilidade - debilidade
# de - de
# valetudinaria - valetudinaria
# , - ,
# pouca - pouco
# falta - falto
# havia - haver
# feito - fazer
# no - o
# palacio - palacio
#
#  -
#
# illuminado - illuminado
# e - e
# radioso - radioso
# . - .
#
#
#  -
#
#
# O - O
# marquez - marquez
# aconselhado - aconselhar
# por - por
# alguma - algum
# pessoa - pessoa
# de - de
# juizo - juizo
# e - e
# de - de
# caridade - caridade
# tinha - ter
#
#  -
#
# consentido - consentir
# a - o
# que - que
# logo - logo
# depois - depois
# da - da
# partida - partir
# de - de
# Margarida - Margarida
# seu - seu
# sobrinho - sobrinho
#
#  -
#
# entrasse - entrar
# para - parir
# um - um
# collegio - collegio
# . - .
#
#
#  -
#
#
# Tambem - Tambem
# já - já
# lhe - lhe
# não - não
# servia - servir
# para - parir
# nada - nado
# . - .
#
#
#  -
#
#
# Com - Com
# o - o
# seu - seu
# corpo - corpo
# magro - magro
# e - e
# desengonçado - desengonçar
# , - ,
# um - um
# corpo - corpo
# de - de
# funambulo - funambulo
# , - ,
# um - um
# corpo - corpo
# de - de
#
#  -
#
# grotesco - grotesco
# , - ,
# tinha - ter
# melancolias - melancolia
# _ - _
# quixotescas - quixotesco
# _ - _
# que - que
# incommodavam - incommodavam
# quem - quem
# o - o
# via - ver
# . - .
#
#
#  -
#
#
# Os - Os
# criados - criar
# deram - dar
# por - por
# mais - mais
# de - de
# uma - umar
# vez - vez
# com - com
# o - o
# rapazola - rapazola
# a - o
# chorar - chorar
# de - de
# bruços - bruços
#
#  -
#
# n'um - n'um
# recanto - recantar
# do - do
# jardim - jardim
# , - ,
# chamado - chamar
# o - o
# _ - _
# canteiro - canteiro
# de - de
# Margarida - Margarida
# _ - _
# . - .
#
#
#  -
#
#
# Era - Era
# um - um
# pequeno - pequeno
# espaço - espaçar
# semeado - semear
# de - de
# flôres - flôres
# , - ,
# onde - onde
# principalmente - principalmente
# abundavam - abundar
#
#  -
#
# os - o
# malmequeres - malmequer
# brancos - branco
# que - que
# tinham - ter
# o - o
# poetico - poetico
# nome - nome
# da - da
# filha - filho
# do - do
# marquez - marquez
# . - .
#
#
#  -
#
#
# Havia - Havia
# ali - ali
# uma - umar
# grande - grande
# arvore - arvorar
# , - ,
# um - um
# castanheiro - castanheiro
# copado - copar
# cuja - cujo
# rama - rama
# folhuda - folhudo
#
#  -
#
# abrigava - abrigar
# as - o
# longas - longo
# scismas - scismas
# dolorosas - doloroso
# de - de
# Thadeu - Thadeu
# . - .
#
#
#  -
#
#
# Não - Não
# se - se
# podia - poder
# consolar - consolar
# ! - !
#
#
#  -
#
#
# Era - Era
# ali - ali
# n'aquelle - n'aquelle
# sitio - sitiar
# fresco - fresco
# , - ,
# esmaltado - esmaltar
# de - de
# flores - florir
# , - ,
# exhalando - exhalando
# um - um
# cheiro - cheirar
#
#  -
#
# agreste - agreste
# e - e
# sadio - sadio
# , - ,
# que - que
# elle - elle
# se - se
# deixava - deixar
# ficar - ficar
# horas - horar
# e - e
# horas - horar
# esquecido - esquecer
# de - de
#
#  -
#
# todos - todo
# , - ,
# n'uma - n'uma
# especie - especie
# de - de
# lethargo - lethargo
# bestial - bestial
# , - ,
# o - o
# lethargo - lethargo
# de - de
# um - um
# animal - animal
#
#  -
#
# ferido - ferir
# . - .
#
#
#  -
#
#
# E - E
# desfiava - desfiar
# na - o
# memoria - memoriar
# todo - todo
# o - o
# seu - seu
# passado - passar
# , - ,
# toda - todo
# a - o
# vida - vidar
# que - que
# vivêra - vivêra
# , - ,
#
#  -
#
# abandonado - abandonar
# , - ,
# desprezado - desprezar
# , - ,
# perseguido - perseguir
# de - de
# chufas - chufar
# ou - ou
# de - de
# maus - mau
# tratos - trato
# , - ,
# de - de
#
#  -
#
# caprichos - capricho
# humilhantes - humilhante
# , - ,
# ou - ou
# de - de
# observações - observação
# glacialmente - glacialmente
# desdenhosas - desdenhoso
# . - .
#
#
#  -
#
#
# Só - Só
# _ - _
# ella - ella
# _ - _
# nunca - nunca
# o - o
# ferira - ferir
# ! - !
# só - só
# ella - ella
# fôra - fôra
# no - o
# seu - seu
# viver - viver
# de - de
# cão - cão
# apedrejado - apedrejar
# um - um
#
#  -
#
# consolo - consolar
# dulcissimo - dulcissimo
# ! - !
# uma - umar
# nesga - nesga
# do - do
# céo - céo
# que - que
# se - se
# entreabrira - entreabrir
# ! - !
#
#
#  -
#
#
# Só - Só
# _ - _
# ...
# de - de
# umas - umar
# horas - horar
# de - de
#
#  -
#
# esquecimento - esquecimento
# . - .
#
#
#  -
#
#
# E - E
# em - em
# troca - trocar
# d'esse - d'esse
# consolo - consolar
# supremo - supremo
# a - o
# que - que
# se - se
# julgam - julgar
# sem - sem
# direito - direito
# , - ,
# são - ser
#
#  -
#
# capazes - capaz
# de - de
# todos - todo
# os - o
# sacrificios - sacrificios
# , - ,
# de - de
# todos - todo
# os - o
# renunciamentos - renunciamentos
# sublimes - sublime
#
#  -
#
# que - que
# inventa - inventar
# a - o
# mulher - mulher
# depois - depois
# de - de
# ter - ter
# perdido - perder
# a - o
# esperança - esperançar
# de - de
# ser - ser
# feliz - feliz
# . - .
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Leitora - Leitora
# , - ,
# estás - estar
# cansada - cansar
# das - das
# chatas - chato
# e - e
# incaracteristicas - incaracteristicas
# figuras - figurar
# que - que
# tens - ter
#
#  -
#
# encontrado - encontrar
# na - o
# vida - vidar
# real - real
# ? - ?
# Entristecem-te - Entristecem-te
# dolorosamente - dolorosamente
# os - o
# typos - typos
# hediondos - hediondo
#
#  -
#
# ou - ou
# repugnantes - repugnante
# da - da
# moderna - moderno
# arte - arte
# ? - ?
#
#
#  -
#
#
# As - As
# Gervasias - Gervasias
# , - ,
# as - o
# Bovarys - Bovarys
# , - ,
# as - o
# Fannys - Fannys
# , - ,
# as - o
# peccadoras - peccadoras
# da - da
# França - França
# juvenil - juvenil
# ? - ?
#
#
#  -
#
#
# Pois - Pois
# bem - bem
# , - ,
# deixa - deixar
# que - que
# desfile - desfilar
# por - por
# diante - diante
# do - do
# teu - teu
# olhar - olhar
# pensativo - pensativo
# a - o
# gloriosa - glorioso
#
#  -
#
# legião - legião
# das - das
# filhas - filho
# de - de
# Victor - Victor
# Hugo - Hugo
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# crê - crer
# que - que
# não - não
# aprenderás - aprender
# com - com
# ellas - ellas
# cousa - cousa
# alguma - algum
# que - que
# rebaixe - rebaixar
# o - o
# teu - teu
#
#  -
#
# espirito - espiritar
# , - ,
# que - que
# fira - ferir
# o - o
# teu - teu
# coração - coração
# , - ,
# que - que
# surprehenda - surprehenda
# cruelmente - cruelmente
# o - o
# teu - teu
#
#  -
#
# entendimento - entendimento
# . - .
#
#
#  -
#
#
# Ellas - Ellas
# sabem - saber
# todas - todo
# o - o
# que - que
# é - ser
# o - o
# amor - amor
# , - ,
# muitas - muito
# o - o
# que - que
# é - ser
# o - o
# arrependimento - arrependimento
# , - ,
# o - o
#
#  -
#
# remorso - remorso
# , - ,
# a - o
# vergonha - vergonha
# , - ,
# a - o
# expiação - expiação
# ; - ;
# nenhuma - nenhum
# sabe - saber
# o - o
# que - que
# é - ser
# o - o
# triumpho - triumpho
#
#  -
#
# impudico - impudico
# do - do
# vicio - viciar
# , - ,
# a - o
# ostentação - ostentação
# criminosa - criminoso
# das - das
# vaidades - vaidade
# mundanas - mundano
# , - ,
# a - o
#
#  -
#
# impenitencia - impenitencia
# immoral - immoral
# das - das
# que - que
# medram - medrar
# no - o
# meio - mear
# do - do
# crime - crime
# . - .
#
#
#  -
#
#
# As - As
# peccadoras - peccadoras
# contar-te-hão - contar-te-hão
# a - o
# dolorosa - doloroso
# historia - historiar
# das - das
# suas - suar
# amarguras - amargurar
# , - ,
# as - o
#
#  -
#
# virgens - virgem
# a - o
# doçura - doçura
# sonhadora - sonhador
# dos - dos
# seus - seu
# extasis - extasis
# ! - !
#
#
#  -
#
#
# Amaram - Amaram
# , - ,
# acreditaram - acreditar
# , - ,
# sentiram - sentir
# na - o
# plenitude - plenitude
# do - do
# coração - coração
# que - que
# a - o
# vida - vidar
# é - ser
# boa - bom
# , - ,
#
#  -
#
# e - e
# que - que
# o - o
# paraiso - paraiso
# póde - póde
# encontrar-se - encontrar-se
# n'um - n'um
# canto - cantar
# da - da
# terra - terra
# . - .
#
#
#  -
#
#
# Não - Não
# sabem - saber
# nada - nado
# de - de
# _ - _
# toilettes - toilette
# _ - _
# , - ,
# de - de
# pequenas - pequeno
# intrigas - intrigar
# , - ,
# de - de
# namoros - namoro
# , - ,
# de - de
#
#  -
#
# vicios - vicios
# mesquinhos - mesquinho
# , - ,
# de - de
# invejas - invejar
# e - e
# de - de
# tagarelices - tagarelice
# ; - ;
# atravessaram - atravessar
# o - o
# mundo - mundo
# com - com
#
#  -
#
# os - o
# olhos - olho
# fitos - fito
# n'outros - n'outros
# olhos - olho
# , - ,
# com - com
# as - o
# mãos - mão
# enlaçadas - enlaçar
# n'outras - n'outras
# mãos - mão
# , - ,
# com - com
#
#  -
#
# a - o
# alma - almo
# a - o
# cantar-lhes - cantar-lhes
# um - um
# _ - _
# hosanna - hosanna
# _ - _
# de - de
# mysticos - mysticos
# arroubos - arroubo
# ! - !
#
#
#  -
#
#
# Se - Se
# queres - querer
# estudar - estudar
# os - o
# escaninhos - escaninho
# caprichosos - caprichoso
# de - de
# um - um
# coração - coração
# de - de
# mulher - mulher
#
#  -
#
# bonita - bonito
# e - e
# garrida - garrir
# , - ,
# não - não
# as - o
# procures - procurar
# , - ,
# mas - mas
# tambem - tambem
# lhes - lhe
# não - não
# peças - pedir
# que - que
# te - te
#
#  -
#
# fallem - fallem
# nos - o
# nossos - nosso
# piedosos - piedoso
# e - e
# obscuros - obscuro
# deveres - dever
# de - de
# todos - todo
# os - o
# dias - dia
# . - .
#
#
#  -
#
#
# São - São
# as - o
# hallucinadas - hallucinadas
# do - do
# amor - amor
# ! - !
# Arrastou-as - Arrastou-as
# uma - umar
# tempestade - tempestade
# para - parir
# outras - outro
#
#  -
#
# espheras - espheras
# ardentes - ardente
# onde - onde
# se - se
# não - não
# vive - viver
# a - o
# vida - vidar
# que - que
# conhecemos - conhecer
# ! - !
#
#
#  -
#
#
# Vê - Vê
# tu - tu
# -- - --
# Esmeralda - Esmeralda
# ! - !
# que - que
# bem - bem
# posto - postar
# nome - nome
# ! - !
#
#
#  -
#
#
# Toda - Toda
# ella - ella
# scintilla - scintilla
# ao - ao
# sol - sol
# como - comer
# a - o
# pedra - pedrar
# preciosa - precioso
# que - que
# lhe - lhe
# serviu - servir
# de - de
#
#  -
#
# baptismo - baptismo
# ; - ;
# os - o
# seus - seu
# dedos - dedo
# de - de
# _ - _
# gitana - gitano
# _ - _
# crestados - crestar
# e - e
# finos - fino
# arrancam - arrancar
# ao - ao
#
#  -
#
# pandeiro - pandeiro
# do - do
# seu - seu
# paiz - paiz
# doidos - doido
# e - e
# extranhos - extranhos
# sons - som
# ! - !
# Fascina - Fascina
# com - com
# um - um
# olhar - olhar
#
#  -
#
# inconsciente - inconsciente
# dos - dos
# seus - seu
# olhos - olho
# de - de
# velludo - velludo
# , - ,
# com - com
# uma - umar
# nota - noto
# da - da
# sua - suar
# voz - voz
#
#  -
#
# crystallina - crystallina
# , - ,
# com - com
# um - um
# meneio - menear
# do - do
# seu - seu
# corpo - corpo
# de - de
# serpente - serpentar
# . - .
#
#
#  -
#
#
# Que - Que
# sabe - saber
# ella - ella
# da - da
# vida - vidar
# ? - ?
# Nada - Nada
# ; - ;
# a - o
# não - não
# ser - ser
# que - que
# a - o
# vida - vidar
# é - ser
# bella - bella
# , - ,
# visto - vestir
# que - que
# ha - ha
#
#  -
#
# dous - dois
# olhos - olho
# que - que
# ao - ao
# fixar - fixar
# nos - o
# seus - seu
# os - o
# banharam - banhar
# de - de
# fulgor - fulgor
# ! - !
#
#
#  -
#
#
# E - E
# Cosette - Cosette
# ! - !
# vive - viver
# ao - ao
# pé - pé
# d'ella - d'ella
# um - um
# enygma - enygma
# sombrio - sombrio
# ! - !
# um - um
# espirito - espiritar
# sobrehumano - sobrehumano
# ! - !
#
#  -
#
# um - um
# luctador - luctador
# d'estas - d'estas
# luctas - luctas
# interiores - interior
# cujo - cujo
# reflexo - reflexo
# se - se
# estampa - estampar
# na - o
# frente - frente
#
#  -
#
# que - que
# as - o
# encerra - encerrar
# . - .
#
#
#  -
#
#
# Ella - Ella
# nunca - nunca
# interrogou - interrogar
# essa - esse
# alma - almo
# , - ,
# e - e
# nunca - nunca
# tentou - tentar
# decifrar - decifrar
# esse - esse
# enygma - enygma
# , - ,
# e - e
#
#  -
#
# nunca - nunca
# sequer - sequer
# comprehendeu - comprehendeu
# a - o
# existencia - existencia
# d'essas - d'essas
# luctas - luctas
# . - .
#
#
#  -
#
#
# Ao - Ao
# seu - seu
# companheiro - companheiro
# triste - triste
# , - ,
# humilde - humildar
# , - ,
# heroico - heroico
# , - ,
# adoravel - adoravel
# ella - ella
# deve - dever
# durante - durante
#
#  -
#
# quinze - quinze
# annos - annos
# a - o
# ventura - venturo
# mais - mais
# perfeita - perfeito
# que - que
# póde - póde
# gosar-se - gosar-se
# na - o
# terra - terra
# . - .
#
#
#  -
#
#
# Satisfez-lhe - Satisfez-lhe
# todos - todo
# os - o
# desejos - desejo
# ; - ;
# todos - todo
# os - o
# brinquedos - brinquedo
# d'aquella - d'aquella
# fada - fadar
# , - ,
#
#  -
#
# encarregou-se - encarregou-se
# de - de
# os - o
# fornecer - fornecer
# a - o
# natureza - natureza
# na - o
# liberdade - liberdade
# plena - pleno
# , - ,
# nos - o
# seus - seu
#
#  -
#
# idyllios - idyllios
# primaveris - primaveril
# ! - !
# Estava - Estava
# na - o
# escuridão - escuridão
# , - ,
# e - e
# deram-lhe - deram-lhe
# luz - luzir
# ; - ;
# era - ser
# escrava - escravo
#
#  -
#
# fizeram-n'a - fizeram-n'a
# rainha - rei
# . - .
#
#
#  -
#
#
# Não - Não
# importa - importar
# ! - !
# Marius - Marius
# appareceu - appareceu
# e - e
# Cosette - Cosette
# louca - louco
# , - ,
# deslumbrada - deslumbrar
# , - ,
# esquecida - esquecido
# , - ,
#
#  -
#
# deixa - deixar
# morrer - morrer
# de - de
# dôr - dôr
# o - o
# amigo - amigar
# da - da
# sua - suar
# risonha - risonho
# mocidade - mocidade
# . - .
#
#
#  -
#
#
# É - É
# má - mau
# ? - ?
#
#
#  -
#
#
# Não - Não
# ; - ;
# é - ser
# ignorante - ignorante
# . - .
# Não - Não
# sabe - saber
# que - que
# se - se
# morre - morrer
# visto - vestir
# que - que
# elle - elle
# vive - viver
# na - o
# posse - posse
# de - de
#
#  -
#
# uma - umar
# ventura - venturo
# que - que
# nunca - nunca
# até - até
# alli - alli
# conhecera - conhecer
# . - .
#
#
#  -
#
#
# Não - Não
# sabe - saber
# que - que
# se - se
# tem - ter
# saudades - saudade
# , - ,
# porque - porque
# ao - ao
# pé - pé
# de - de
# Marius - Marius
# nunca - nunca
# esse - esse
# espinho - espinhar
#
#  -
#
# lhe - lhe
# mordeu - morder
# no - o
# coração - coração
# ! - !
#
#
#  -
#
#
# Pois - Pois
# é - ser
# possivel - possivel
# ser - ser
# desgraçado - desgraçar
# quando - quando
# eu - eu
# sou - ser
# tão - tão
# feliz - feliz
# ! - !
# pergunta - perguntar
#
#  -
#
# tacitamente - tacitamente
# com - com
# barbaridade - barbaridade
# que - que
# se - se
# ignora - ignorar
# , - ,
# cada - cada
# um - um
# dos - dos
# sorrisos - sorriso
# de - de
#
#  -
#
# ventura - venturo
# que - que
# ella - ella
# atirara - atirar
# em - em
# redor - redor
# de - de
# si - si
# , - ,
# sem - sem
# se - se
# importar - importar
# onde - onde
# lhe - lhe
# vão - ir
#
#  -
#
# cahir - cahir
# ! - !
#
#
#  -
#
#
# Ai - Ai
# ! - !
# Cosette - Cosette
# , - ,
# Cosette - Cosette
# ! - !
# eu - eu
# gosto - gostar
# de - de
# ti - ti
# , - ,
# borboleta - borboleta
# , - ,
# ébria - ébrio
# de - de
# luz - luzir
# ! - !
# és - ser
# uma - umar
#
#  -
#
# das - das
# visões - visão
# luminosas - luminoso
# que - que
# ficarás - ficar
# para - parir
# sempre - sempre
# moça - moço
# e - e
# querida - querido
# ! - !
# és - ser
# uma - umar
#
#  -
#
# estatua - estatuir
# branca - branco
# que - que
# ninguem - ninguem
# ousará - ousar
# mutilar - mutilar
# e - e
# que - que
# os - o
# seculos - seculo
# verão - ver
# erguida - erguido
#
#  -
#
# no - o
# teu - teu
# pedestal - pedestal
# de - de
# flôres - flôres
# ! - !
# Mas - Mas
# como - comer
# eu - eu
# te - te
# amaria - amar
# muito - muito
# mais - mais
# ainda - ainda
# se - se
# em - em
#
#  -
#
# vez - vez
# de - de
# seres - ser
# o - o
# Amor - Amor
# fosses - ser
# o - o
# Sacrificio - Sacrificio
# ! - !
#
#
#  -
#
#
# Um - Um
# dia - dia
# Victor - Victor
# Hugo - Hugo
# pediu - pedir
# ás - ás
# neblinas - neblinar
# matinaes - matinaes
# dos - dos
# climas - clima
# do - do
# norte - norte
# , - ,
# uma - umar
#
#  -
#
# porção - porção
# de - de
# renda - render
# branca - branco
# e - e
# transparente - transparentar
# com - com
# que - que
# ellas - ellas
# corôam - corôam
# a - o
# crista - crista
# das - das
#
#  -
#
# montanhas - montanha
# e - e
# ... - ...
# fez - fazer
# Déa - Déa
# ! - !
#
#
#  -
#
#
# Que - Que
# doce - doce
# , - ,
# vaporosa - vaporoso
# e - e
# lendaria - lendaria
# visão - visão
# ! - !
#
#
#  -
#
#
# Não - Não
# ha - ha
# n'ella - n'ella
# cousa - cousa
# alguma - algum
# que - que
# seja - ser
# realidade - realidade
# ! - !
#
#
#  -
#
#
# Toca - Toca
# na - o
# terra - terra
# ao - ao
# de - de
# leve - levar
# ; - ;
# não - não
# tanto - tanto
# que - que
# pareça - parecer
# filha - filho
# d'ella - d'ella
# , - ,
# não - não
# tão - tão
#
#  -
#
# pouco - pouco
# que - que
# lhe - lhe
# não - não
# seja - ser
# dado - dar
# consolar - consolar
# alguem - alguem
# votado - votar
# ás - ás
# dores - dor
# sem - sem
# consolo - consolar
# . - .
#
#
#  -
#
#
# É - É
# cega - cego
# ! - !
#
#
#  -
#
#
# Amada - Amada
# por - por
# um - um
# monstro - monstro
# sabe - saber
# verter-lhe - verter-lhe
# n'alma - n'alma
# as - o
# alegrias - alegria
# de - de
# um - um
# Deus - Deus
# ! - !
#
#
#  -
#
#
# Não - Não
# vê - ver
# o - o
# homem - homem
# que - que
# a - o
# ama - amo
# , - ,
# vê - ver
# o - o
# amor - amor
# de - de
# que - que
# elle - elle
# a - o
# veste - vestir
# ! - !
#
#
#  -
#
#
# Abençoada - Abençoada
# cegueira - cegueira
# que - que
# faz - fazer
# dous - dois
# felizes - feliz
# ! - !
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Ao - Ao
# lado - lado
# d'ella - d'ella
# -- - --
# supremo - supremo
# contraste!--sorri - contraste!--sorri
# Josiane - Josiane
# com - com
# o - o
# seu - seu
# sorriso - sorriso
# de - de
#
#  -
#
# deusa - deus
# pagã - pagão
# ! - !
#
#
#  -
#
#
# No - No
# olho - olhar
# azul - azul
# da - da
# patricia - patricia
# ingleza - ingleza
# scintilla - scintilla
# em - em
# chispas - chispa
# uma - umar
# diabolica - diabolica
#
#  -
#
# ironia - ironia
# . - .
#
#
#  -
#
#
# Josiane - Josiane
# é - ser
# a - o
# amante - amantar
# do - do
# impossivel - impossivel
# ! - !
# Procura - Procura
# o - o
# que - que
# nunca - nunca
# ninguem - ninguem
# achou - achar
# ! - !
#
#
#  -
#
#
# Quer - Quer
# um - um
# sonho - sonhar
# que - que
# a - o
# sacie - saciar
# , - ,
# o - o
# amor - amor
# de - de
# um - um
# Titan - Titan
# , - ,
# ou - ou
# de - de
# um - um
# cyclope - cyclope
# , - ,
# o - o
# amor - amor
#
#  -
#
# de - de
# Apollo - Apollo
# ou - ou
# de - de
# Polyphemo - Polyphemo
# ! - !
#
#
#  -
#
#
# Estranha - Estranha
# figura - figurar
# , - ,
# producto - producto
# doentio - doentio
# de - de
# uma - umar
# noite - noite
# de - de
# febre - febre
# ! - !
#
#
#         -
#
#
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#        -
# * - *
#
#
#  -
#
#
# Dona - Dona
# Sol - Sol
# , - ,
# Maria - Maria
# de - de
# Neuburgo - Neuburgo
# , - ,
# Marion - Marion
# , - ,
# Eponine - Eponine
# , - ,
# Cosette - Cosette
# , - ,
# Déa - Déa
# , - ,
# quantas - quanto
#
#  -
#
# figuras - figurar
# radiosas - radioso
# , - ,
# quantas - quanto
# humanições - humanições
# esplendidas - esplender
# da - da
# mulher - mulher
# sonhada - sonhar
# ! - !
#
#
#  -
#
#
# Nas - Nas
# horas - horar
# de - de
# desalento - desalentar
# ou - ou
# de - de
# amarga - amargo
# duvida - duvidar
# , - ,
# nas - o
# horas - horar
# em - em
# que - que
# as - o
# miserias - miserias
#
#  -
#
# que - que
# nos - o
# cercam - cercar
# , - ,
# nos - o
# fizeram - fazer
# encarar - encarar
# a - o
# vida - vidar
# pelo - pelar
# seu - seu
# aspecto - aspecto
# mais - mais
#
#  -
#
# desolado - desolar
# e - e
# mais - mais
# escuro - escuro
# olhemos - olhar
# para - parir
# ellas - ellas
# ! - !
#
#
#  -
#
#
# Dir-nos-hão - Dir-nos-hão
# os - o
# poetas - poetar
# de - de
# hoje - hoje
# que - que
# ellas - ellas
# não - não
# existem - existir
# , - ,
# e - e
# , - ,
# o - o
# que - que
# é - ser
# peior - peior
# , - ,
#
#  -
#
# que - que
# ellas - ellas
# não - não
# puderam - poder
# existir - existir
# nunca - nunca
# . - .
#
#
#  -
#
#
# Oh - Oh
# ! - !
# é - ser
# bem - bem
# triste - triste
# , - ,
# é - ser
# bem - bem
# esteril - esteril
# a - o
# arte - arte
# que - que
# só - só
# trata - tratar
# de - de
# rebaixar - rebaixar
# o - o
# que - que
# em - em
#
#  -
#
# nós - nó
# é - ser
# de - de
# mais - mais
# elevada - elevar
# essencia - essencia
# , - ,
# e - e
# só - só
# quer - querer
# que - que
# vejamos - ver
# a - o
# fatalidade - fatalidade
#
#  -
#
# brutal - brutal
# do - do
# instincto - instincto
# , - ,
# onde - onde
# viamos - viamos
# d'antes - d'antes
# a - o
# fatalidade - fatalidade
# mais - mais
# nobre - nobre
# do - do
#
#  -
#
# sentimento - sentimento
# . - .
#
#
#  -
#
#
# Não - Não
# acreditemos - acreditar
# o - o
# que - que
# elles - elles
# nos - o
# dizem - dizer
# , - ,
# porque - porque
# na - o
# sua - suar
# preoccupação - preoccupação
#
#  -
#
# exagerada - exagerar
# do - do
# horrivel - horrivel
# , - ,
# elles - elles
# mentem - mentir
# muito - muito
# mais - mais
# do - do
# que - que
# os - o
# outros - outro
# mentiam - mentir
#
#  -
#
# na - o
# sua - suar
# preoccupação - preoccupação
# exagerada - exagerar
# do - do
# bello - bello
# ! - !
#
#
#  -
#
#
# Estes - Estes
# reunindo - reunir
# todos - todo
# os - o
# vicios - vicios
# e - e
# hediondezas - hediondezas
# que - que
# encontraram - encontrar
# dispersos - disperso
#
#  -
#
# n'uma - n'uma
# só - só
# figura - figurar
# , - ,
# conseguem - conseguir
# apenas - apenas
# crear - crear
# ... - ...
# um - um
# monstro - monstro
# , - ,
# um - um
# ser - ser
# hybrido - hybrido
# e - e
#
#  -
#
# infecundo - infecundar
# que - que
# a - o
# ninguem - ninguem
# aproveita - aproveitar
# ! - !
#
#
#  -
#
#
# Os - Os
# outros - outro
# synthetisando - synthetisando
# n'uma - n'uma
# filha - filho
# do - do
# seu - seu
# genio - genio
# as - o
# harmonias - harmonia
# , - ,
# as - o
#
#  -
#
# feições - feição
# , - ,
# os - o
# encantos - encanto
# , - ,
# que - que
# estudaram - estudar
# e - e
# amaram - amarar
# em - em
# toda - todo
# a - o
# natureza - natureza
# , - ,
#
#  -
#
# conseguiram - conseguir
# alguma - algum
# coisa - coisa
# mais - mais
# ! - !
#
#
#  -
#
#
# Crearam - Crearam
# o - o
# ideal - ideal
# immutavel - immutavel
# e - e
# eterno - eternar
# e - e
# ensinaram-nos - ensinaram-nos
# a - o
# fitar - fitar
# n'elle - n'elle
# os - o
#
#  -
#
# olhos - olho
# da - da
# nossa - nosso
# alma - almo
# , - ,
# e - e
# a - o
# invocal-o - invocal-o
# como - comer
# um - um
# consolo - consolar
# adoravel - adoravel
# nas - o
# nossas - nosso
#
#  -
#
# horas - horar
# de - de
# desalento - desalentar
# e - e
# de - de
# agonia - agoniar
# . - .
