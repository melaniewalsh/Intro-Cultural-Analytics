# %% [markdown]
# # Named Entity Recognition for Portuguese

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called *Named Entity Recognition* (NER) as applied to Portuguese. This method will help us computationally identify people, places, and things (of various kinds) in a text or collection of texts.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset

# %% [markdown]
# The example text for Portuguese is *Contos e Phantasias* by Maria Amália Vaz de Carvalho [from Project Gutenberg](http://www.gutenberg.org/ebooks/63406).

# %% [markdown]
# **Here's a preview of spaC's NER tagging *Contos e Phantasias*.**
#
# If you compare the results to the [English example](Named-Entity-Recognition), you'll notice that the Portuguese NER is much less good at recognizing entities, and is especially bad ata distinguishing different kinds of entities, like ORG vs LOC vs PER. You need a lot of examples to train a model to distinguish different entity types; currently, English is the only model that does a decent job of it.
#
# You can read more about the [data sources used to train Portuguese](https://spacy.io/models/pt) on the spaCy model page.

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">﻿PRIMEIRA PARTE</br></br></br></br></br>UMA HISTORIA VERDADEIRA</br></br></br>I</br></br>Era uma physionomia incaracteristica, apagada, tristissima.</br></br>Não se podia dizer a idade que tinha, nem mesmo se tinha idade.</br></br>Tanto podia ter trinta ou quarenta como setenta annos.</br></br>Curvado pela idade ou pelos desgostos?
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Encanecido
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  porque os annos tinham</br>corrido por sobre a cabeça d'elle, ou porque lhe tinham pesado</br>duplamente sobre os hombros debeis?</br></br>Quem o podia dizer?</br></br>Era uma organisação acanhada e rachitica, podia mesmo chamar-se</br>incompleta.</br></br>Para elle com certeza que a adolescencia não tivera as suas madrugadas</br>azues tão gorgeadas e tão festivas, nem a virilidade tivera a fanfarra</br>estridente dos seus clarins, a florescencia escarlate dos seus rosaes</br>voluptuosos.</br></br>Tinha sempre vivido debaixo de uma estranha pressão dolorosa.</br></br>Dependêra de todos primeiro porque era fraco e inerme, depois porque</br>fôra pobre, dependente, sem aquella aspera dignidade que os atrictos da</br>vida tornam mais rude e que é a armadura moral que salvaguarda o homem</br>nos duros combates sociaes.</br></br>Nasceu n'uma casa opulenta que lhe não pertencia, cresceu no meio de um</br>luxo de que seus paes erão parasitas voluntarios e de que elle era...</br>parasita inconsciente.</br></br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Começára
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  por ter medo de tudo e de todos; um medo que não raciocinava,</br>que não sabia, que não indagava mesmo a sua propria origem.</br></br>Nasceu assustadiço, como certos animaes silvestres, e toda a vida</br>conservou a mesma expressão inquieta e medrosa da lebre perseguida.</br></br>Em primeiro lugar tinha medo de seu pae; um homem alto, espadaúdo,</br>plethorico, de voz grossa e modos brutaes, que comia como um abbade, que</br>bebia como um _lansquenete_, que praguejava como um carreiro, e que se</br>vingava nos poucos entes que tinha debaixo do seu dominio, das</br>complacencias servis que era obrigado a mostrar aos que o mantinham</br>n'aquella farta ociosidade de commensal que só goza e não paga.</br></br>Depois tinha medo de sua tia; a dona da casa, a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thadeu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  era marquez,--achou comico</br>mandar introduzir a creança no cofre acharoado que havia junto ao fogão</br>do gabinete de trabalho, destinado a guardar a lenha ou o carvão que se</br>consumia.</br></br>De minuto em minuto abria-se a tampa e sahia a cara vermelha e</br>congestionada do pequeno, uma cara de animal assustado, o que divertia</br>extraordinariamente as visitas.</br></br>Outra vez, n'uma ceia alegre em que havia rios de _champagne_ e risadas</br>crystallinas de mulheres,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thadeu
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  com um fato de meia preta a cobril-o</br>todo e dous castiçaes nas pequenas mãos, servia de centro agachado n'uma</br>posição grotesca no meio da meza.</br></br>
# <mark class="entity" style

# %% [markdown]
# ---

# %% [markdown]
# ## NER with spaCy
# If you've already used the pre-processing notebook for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ### Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# We're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things, and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ### Download Language Model

# %% [markdown]
# Next we need to download the Portuguese-language model (`pt_core_news_md`), which will be processing and making predictions about our texts. You can read more about the [data sources used to train Portuguese](https://spacy.io/models/pt) on the spaCy model page.

# %%
# !python -m spacy download pt_core_news_md

# %% [markdown]
# ### Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# **1.** We can import the model as a module and then load it from the module.

# %%
import pt_core_news_md
nlp = pt_core_news_md.load()

# %% [markdown]
# **2.** We can load the model by name.

# %%
#nlp = spacy.load('pt_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it's advisable to use Option 1. Then you can use the model immediately. Otherwise, you'll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel.. in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document

# %% [markdown]
# We first need to process our `document` with the loaded NLP model. Most of the heavy NLP lifting is done in this line of code.
#
# After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.
#
# In the cell below, we open and the example document. Then we run`nlp()` on the text and create our document.

# %%
filepath = '../texts/pt.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## Get Named Entities

# %% [markdown]
# All the named entities in our `document` can be found in the `document.ents` property. If we check out `document.ents`, we can see all the entities from the example document.

# %%
document.ents
# Out:
# (Encanecido,
#  Começára,
#  _,
#  Vestia-o,
#  Thadeu,
#  Thadeu,
#  Sahiu d'alli,
#  Thadeu,
#  Thadeu,
#  Thadeu,
#  N'aquelle,
#  Thadeu,
#  _,
#  Oh!,
#  Thadeu,
#  Thadeu,
#  _,
#  Thadeu,
#  _,
#  _,
#  _,
#  Thadeu,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Oh!,
#  _perola_,
#  Margarida,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Margarida,
#  Margarida,
#  collocara Thadeu,
#  Thadeu,
#  Margarida,
#  Elle,
#  Ella,
#  Margarida,
#  Deixaram-os,
#  Thadeu,
#  Ha,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Thadeu,
#  Elle,
#  Acharam-na,
#  Thadeu,
#  _,
#  _,
#  III,
#  Margarida,
#  D'ahi,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Viveria,
#  Margarida,
#  Ella,
#  Thadeu,
#  Elles,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Paris,
#  Fallaram,
#  Sacré,
#  Cœur,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  _,
#  França,
#  Fôra,
#  _Sacré-Cœur_,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Tambem,
#  _,
#  Margarida_,
#  Thadeu,
#  Margarida,
#  Ralhava-lhe,
#  Thadeu,
#  Thadeu,
#  _,
#  _fetiche_,
#  lh'as,
#  banalisar,
#  _,
#  _,
#  Ella,
#  Thadeu,
#  Thadeu cahiu,
#  Henrique de Souza,
#  Orphão,
#  Henrique,
#  Thadeu,
#  Henrique,
#  Comprehendeu,
#  V,
#  Thadeu,
#  Henrique,
#  Occupavam,
#  Henrique,
#  Deus!,
#  Henrique,
#  Joanninha,
#  Desdobrára,
#  N'este,
#  Thadeu,
#  Soffria,
#  Thadeu,
#  Ali,
#  Thadeu,
#  Henrique,
#  Thadeu,
#  Margarida,
#  Margarida!,
#  Margarida,
#  Henrique,
#  Joanninha,
#  Margarida,
#  d'ella,
#  Henrique,
#  Thadeu,
#  Henrique,
#  Joanninha,
#  Joanna,
#  Margarida,
#  Dormia,
#  Thadeu,
#  Emquanto,
#  Thadeu,
#  Vinha-lhe,
#  Thadeu,
#  _toilette,
#  _ella_,
#  _,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Baixa,
#  Henrique,
#  Margarida,
#  _,
#  casa Binder,
#  pacata Lisboa,
#  Thadeu,
#  _coquetterie,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Henrique de Sousa,
#  S. Carlos,
#  _Norma_,
#  Henrique,
#  Margarida,
#  N'este,
#  Henrique,
#  Margarida,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Vira-a,
#  Ella,
#  S. Carlos,
#  Bellini,
#  N'isto,
#  _,
#  Margarida,
#  d'ella,
#  Thadeu,
#  Henrique,
#  Margarida,
#  d'ella,
#  secco,
#  garridice innata,
#  Thadeu,
#  Elle,
#  Thadeu,
#  Margarida,
#  Henrique,
#  d'ali,
#  Thadeu,
#  Margarida,
#  Sabiam-n'a,
#  Henrique,
#  Margarida,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  Ella,
#  _,
#  Henrique,
#  Thadeu!--Anda,
#  Thadeu,
#  Margarida,
#  França,
#  Henrique,
#  Margarida,
#  Henrique,
#  Margarida,
#  Henrique,
#  Thadeu,
#  _elle_,
#  Olha,
#  Thadeu,
#  Margarida,
#  d'ella,
#  Thadeu,
#  Henrique,
#  Thadeu,
#  Henrique,
#  Buenos-Ayres,
#  Henrique,
#  Thadeu,
#  Suissa,
#  Italia,
#  _,
#  Henrique,
#  Thadeu,
#  Margarida,
#  Margarida,
#  Margarida,
#  Thadeu,
#  _,
#  _Margarita_,
#  Margarida,
#  Dous cherubins,
#  Thadeu,
#  Aquelles,
#  Fundia-os,
#  Vivia d'elles,
#  Henrique,
#  Margarida,
#  Thadeu,
#  Henrique,
#  Margarida,
#  Thadeu,
#  Thadeu,
#  Elle,
#  Margarida,
#  Comtudo,
#  Ella,
#  Thadeu,
#  Ella,
#  N'este,
#  Margarida,
#  Thadeu,
#  Pariz,
#  Thadeu,
#  Thadeu,
#  Thadeu,
#  Margarida,
#  Thadeu,
#  _,
#  Henrique,
#  Margarida,
#  d'ahi,
#  Sahiram,
#  Thadeu,
#  Henrique,
#  Henrique,
#  TIO SEBASTIÃO,
#  Sebastião,
#  Braga,
#  Coimbra,
#  Braga,
#  Aquillo,
#  Natal,
#  Joanna,
#  Queira Deus,
#  Braga,
#  Joanna,
#  Tornava,
#  Coimbra,
#  Braga,
#  Joanna,
#  Sebastião,
#  sô Sebastião,
#  tio Sebastião,
#  Emquanto,
#  Ella,
#  Deixal-a!,
#  Joanna,
#  Joanna,
#  Sebastião,
#  Moças,
#  Deus,
#  Joanna,
#  Sebastião,
#  Brazil,
#  Sebastião,
#  sô Sebastião,
#  Carlota cahiu,
#  Sebastião,
#  Carlota,
#  Sebastião soccorreu,
#  Villa,
#  Verde,
#  Sebastião,
#  Carlota,
#  Sebastião,
#  Carlota,
#  Sebastião,
#  Joanna,
#  Carlota,
#  Sebastião,
#  insania,
#  caricias,
#  Joanna,
#  Prompto,
#  Sebastião,
#  Braga,
#  N'este,
#  Brazil,
#  Carlota,
#  Quero,
#  Brazil,
#  Braga,
#  Coimbra,
#  tio Sebastião,
#  em Portugal,
#  Rio,
#  Brazil,
#  Porto,
#  Coimbra,
#  Sebastião Alves,
#  Portugal,
#  Coimbra,
#  Sebastião,
#  dous annos,
#  mesquinho,
#  chato,
#  contentes,
#  abraços da familia,
#  Sebastião Alves,
#  Coimbra,
#  Porto,
#  Cintra,
#  Bussaco,
#  Portugal,
#  Santa Apolonia,
#  Coimbra,
#  Granja,
#  Porto,
#  Sebastião,
#  Coimbra,
#  Sebastião,
#  Coimbra,
#  N'isso,
#  Ria alto,
#  d'ahi,
#  Joanna,
#  Joanna,
#  Sebastião,
#  sr. Morgado,
#  Deus,
#  Sebastião,
#  Braga,
#  Carlota,
#  Carlota,
#  Joanna,
#  Sebastião,
#  Coimbra,
#  Sebastião,
#  Sebastião Alves,
#  sr. Sebastião Alves,
#  Sebastião Alves,
#  sr. Sebastião,
#  tio Sebastião,
#  Aquillo,
#  Espera,
#  Sebastião,
#  Sebastião,
#  Sebastião,
#  Alves,
#  Sebastião,
#  Sebastião,
#  Santa Cruz,
#  Brazil,
#  Brindando,
#  Sebastião,
#  Sebastião,
#  Brazil?,
#  Sebastião,
#  Braga,
#  Sebastião,
#  Conega,
#  O Senhor,
#  Sebastião,
#  em Portugal,
#  tio Sebastião,
#  Sebastião,
#  Joanna,
#  ANNEL DO DIPLOMATA,
#  Christo!,
#  Joaquina,
#  X***,
#  Vasconcellos,
#  Vasconcellos,
#  Lisboa,
#  Porto,
#  Minho,
#  Universidade,
#  Porto,
#  Coimbra,
#  Salesias,
#  Lisboa,
#  Antonio,
#  Antonio de Vasconcellos,
#  Coimbra,
#  Francisca,
#  libello!--disse,
#  acompanhava.--,
#  Coimbra,
#  Mal,
#  Antonio,
#  Joanna,
#  Antonio de Vasconcellos,
#  Padre,
#  Filho,
#  Antonio de Vasconcellos,
#  Lisboa,
#  Lisboa,
#  Francisca,
#  Lisboa,
#  _,
#  Lisboa de ha trinta annos,
#  _,
#  _,
#  Antonio de Vasconcellos,
#  Chiado,
#  Jorge de Alvim,
#  N'este,
#  F.,
#  ministro L.,
#  Vasconcellos,
#  Francisca,
#  Antonio,
#  Receber-me-ha,
#  Deus,
#  Antonio de Vasconcellos,
#  Jorge,
#  Alvim,
#  Porto,
#  salval-o-hei,
#  V. Ex.ª,
#  Lisboa,
#  Antonio de Vasconcellos,
#  Vaes,
#  Antonio de Vasconcellos,
#  Prohibo-te,
#  Jorge de Alvim,
#  X***,
#  Fallou-se,
#  Jorge de Alvim,
#  _Sancy_,
#  Carlos o Temerario,
#  Duque de Florença,
#  Prior do Crato,
#  França,
#  Harley de Sancy,
#  Harley,
#  Sancy,
#  Henrique IV de França,
#  Metz,
#  bosque de Dôls,
#  Jacques II de Inglaterra,
#  Luiz XIV,
#  V. Ex.ª,
#  Fernão Mendes,
#  V. Ex.ª,
#  Meneláu,
#  Russos,
#  Sr. Jorge de Alvim,
#  Sr. Alvim,
#  Antonio,
#  Vasconcellos,
#  _toasts_,
#  Alvim,
#  _taça da amizade_,
#  Vasconcellos,
#  Deus,
#  V.,
#  Lisboa,
#  Antonio de Vasconcellos,
#  Lacenaire,
#  Antonio de Vasconcellos,
#  Jorge de Alvim,
#  Sr. Alvim,
#  Jorge,
#  Alvim,
#  Antonio de Vasconcellos,
#  Vasconcellos,
#  Jorge de Alvim,
#  Balzac,
#  Sr. Jorge,
#  Vasconcellos,
#  Permitta-me,
#  V. Ex.ª,
#  Antonio de Vasconcellos,
#  Jorge de Alvim,
#  ESCOLHA DE GASTÃO,
#  _,
#  visconde das Lagôas,
#  João do Moinho Novo,
#  João Silveira,
#  Brazil,
#  _,
#  _,
#  _,
#  Minho,
#  Vianna,
#  Arrás,
#  Lisboa,
#  Brazil,
#  _,
#  Pariz,
#  Timbravam,
#  Fallavam,
#  _,
#  _,
#  _,
#  traziam--,
#  _,
#  riso amarello,
#  visconde,
#  _,
#  _,
#  S. Carlos,
#  Respeitavam,
#  Desprezavam,
#  Stael,
#  Ferté,
#  Brazil,
#  Brazil,
#  Londres,
#  _gentleman rider_,
#  Fallava,
#  Gastão,
#  Gastão,
#  Gastão da Silveira,
#  Europa,
#  Universidade,
#  Inglaterra,
#  Gastão,
#  Gastão,
#  Intelligente,
#  Gastão,
#  Gastão,
#  Gastão,
#  Gastão,
#  França,
#  Pimentas,
#  Gastão,
#  _,
#  _,
#  Leopoldo,
#  _,
#  _,
#  segrêdo,
#  Gastão,
#  Gastão,
#  Gastão,
#  Gastão,
#  Gastão,
#  visconde das Lagôas,
#  Bailes,
#  _,
#  _,
#  leôa,
#  Clotilde de Magalhães,
#  _,
#  Magalhães,
#  Lagôas,
#  Clotilde de Magalhães,
#  Gastão da Silveira,
#  visconde das Lagôas,
#  Clotilde,
#  Clotilde,
#  Manejava,
#  visconde das Lagôas,
#  Clotilde,
#  _,
#  Clotilde,
#  Clotilde,
#  Angelina,
#  Angelina,
#  Clotilde,
#  Clotilde,
#  Magalhães,
#  Gastão,
#  Deus!,
#  Clotilde,
#  Clotilde,
#  Gastão,
#  Discordavam,
#  Clotilde,
#  Gastão,
#  Clotilde,
#  Gastão,
#  Ella,
#  Gastão,
#  Clotilde,
#  _,
#  _,
#  _extasis inolvidaveis_,
#  Clotilde,
#  Gastão,
#  Dançavam,
#  visconde das Lagôas,
#  senhora D. Angelina,
#  Gastão,
#  _,
#  Angelina,
#  Dóe-me,
#  Gastão,
#  Angelina,
#  Gastão,
#  Suissa,
#  Angelina,
#  visconde das Lagôas,
#  Alto Minho,
#  Angelina,
#  Gastão,
#  Clotilde,
#  Emquanto,
#  Clotilde,
#  Gastão,
#  Gastão,
#  Angelina,
#  Gastão,
#  Deus,
#  Clotilde,
#  Clotilde,
#  Angelina,
#  Ha,
#  Angelina,
#  Gastão,
#  Aquelle,
#  Magalhães,
#  _,
#  _,
#  Gastão,
#  Clotilde,
#  Gastão,
#  Angelina,
#  Buenos-Ayres,
#  Elle,
#  Angelina,
#  Clotilde,
#  Apparece,
#  Ha,
#  ROMANCE DE ADELINA,
#  FRAGMENTOS DE CARTAS,
#  Supponho,
#  _,
#  _,
#  Thereza,
#  Aquelle,
#  Quero,
#  Quero,
#  Soffrer,
#  Theresa,
#  Elles,
#  Alegrias,
#  Perguntavas-me,
#  _Moral,
#  _,
#  _,
#  _,
#  São Beethoven,
#  Mozart,
#  Hayden,
#  Presinto,
#  Ha,
#  Mozart,
#  Beethoven,
#  Ó Beethoven,
#  Acham-lhe,
#  Hontem,
#  Thereza,
#  Elle_,
#  Emquanto,
#  Hontem,
#  Naufragámos,
#  Mostrei-lhes,
#  Consolai-me!,
#  Arthur,
#  Arthur,
#  Procurava,
#  Encontrei,
#  Marido,
#  Oh!,
#  Arthur,
#  Converso,
#  Conto-lhes,
#  Conto-lhes,
#  Deus te abençôe,
#  CIGANA,
#  Terrivel_,
#  Rio de Janeiro,
#  Brazil,
#  Navarro,
#  Estão-me,
#  Massarellos,
#  Vigo,
#  Massarellos,
#  capitão Navarro,
#  Douro,
#  _Cigana_,
#  _Cigana_,
#  Navarro,
#  _Cigana_,
#  _Cigana_,
#  Navarro,
#  _Cigana_,
#  _Cigana_,
#  Navarro,
#  Brazil,
#  Lessa,
#  _Cigana_,
#  Navarro,
#  N'aquelle,
#  Estendia,
#  Mattosinhos,
#  Navarro,
#  _Cigana_,
#  _,
#  _Cigana_,
#  _,
#  _Cigana_!,
#  _Cigana_,
#  Lessa,
#  Navarro,
#  _Cigana_,
#  _Cigana_,
#  Navarro,
#  _Terrivel_,
#  _Cigana_,
#  rio Lessa,
#  Luiza,
#  Joaquim Antonio Ferreira,
#  Conde da Guaratiba,
#  Gouvêa,
#  Africa,
#  Vallongo,
#  Luiza,
#  Luiza,
#  Luiza,
#  _,
#  _Cigana_,
#  Luiza,
#  Luiza,
#  _Cigana_,
#  _,
#  _Cigana_ ouvindo-te,
#  Luiza,
#  _Cigana_,
#  Luiza,
#  N'aquelle,
#  lua,
#  Luiza,
#  _Cigana,
#  sr. Gouvêa,
#  Luiza,
#  Luiza,
#  Cigana_,
#  Cigana_,
#  _Cigana_!,
#  Luiza,
#  _Cigana_,
#  FACES DE UMA,
#  Ella,
#  Sonhava,
#  Margarida,
#  Salvava-a,
#  Margarida,
#  Lisboa,
#  S. Carlos,
#  miss Brown,
#  Londres,
#  Margarida,
#  Eduardo de C.,
#  Elle,
#  Margarida,
#  Portugal,
#  Eduardo,
#  Margarida,
#  Minho,
#  Minho,
#  Eduardo,
#  Vianna do Castello,
#  Margarida,
#  Vianna,
#  Partiram,
#  _,
#  Vianna,
#  Estado,
#  Margarida,
#  d'ella,
#  Eduardo de C.,
#  Vianna,
#  Foi-me,
#  Lisboa,
#  Margarida,
#  mentalmente:--Quem,
#  _,
#  _,
#  _,
#  _,
#  _,
#  Margarida,
#  Eduardo de C.,
#  Margarida,
#  Eduardo,
#  Margarida,
#  Eduardo,
#  Fallavam,
#  Margarida,
#  Ha,
#  Elle,
#  Olhe,
#  Margarida,
#  Tambem,
#  V.,
#  Margarida,
#  Eduardo,
#  Margarida,
#  Eduardo,
#  Margarida,
#  Margarida,
#  Eduardo,
#  N'este,
#  Margarida,
#  Margarida,
#  _toilette_,
#  conde de V,
#  _la vie,
#  _,
#  _Marialva,
#  Margarida,
#  Brown,
#  Margarida,
#  Eduardo,
#  Luctara,
#  Margarida,
#  Presinto,
#  Pergunta-o,
#  Lisboa,
#  Condessa de V,
#  Lisboa,
#  _,
#  Deixára,
#  Miss Brown,
#  Margarida,
#  Fazia,
#  Margarida,
#  S. Bento,
#  Lisboa,
#  Comprehendia,
#  N'isto,
#  Margarida,
#  Eduardo de C.,
#  Margarida,
#  Eduardo,
#  Christo,
#  Magdalena,
#  Ella,
#  Cahia,
#  Margarida sahia,
#  Miss Brown,
#  Margarida,
#  N'essa carruagem,
#  Eduardo de C.,
#  Margarida,
#  Margarida,
#  Lisboa,
#  Ha,
#  Providencia,
#  Eduardo de C.,
#  TIA IZABEL,
#  Conhecia-a,
#  Affirmavam,
#  _,
#  _,
#  _,
#  _,
#  _,
#  tia Izabel,
#  _,
#  _,
#  Japão,
#  China,
#  Russia,
#  Escolhia,
#  Andava,
#  Virgem,
#  Exhalava,
#  --Quem,
#  tia Izabel,
#  _baby_ louro,
#  irmãosinho Arthur,
#  Aquelle cortejo,
#  Umas,
#  Ella,
#  Porquê,
#  Tambem,
#  Estremecera,
#  Deus,
#  Universidade,
#  Foram-se-lhe,
#  _alguem_ invisivel,
#  _historia da tia Izabel_,
#  MILLIONARIO,
#  Brazil ha,
#  em Portugal,
#  Francisco,
#  sr. Francisco Cerqueira,
#  Lisboa,
#  Mineiros,
#  Cerqueira _,
#  sr. Cerqueira,
#  Inda,
#  _ Cerqueira,
#  Europa,
#  Europa,
#  sr. Cerqueira,
#  Orpheu,
#  Eurydices,
#  Brazil,
#  »,
#  Cerqueira,
#  em Portugal,
#  Cerqueira,
#  sr. Cerqueira,
#  Francisco Cerqueira,
#  Portugal,
#  Arrancado,
#  sr. Cerqueira,
#  Buenos-Ayres,
#  Coitado!,
#  sr. Cerqueira,
#  sr. Cerqueira,
#  _,
#  _,
#  morro de Santa Thereza,
#  Botafogo,
#  Corcovado,
#  Brazil,
#  Europa,
#  Portugal,
#  sr. Cerqueira,
#  sr. Cerqueira,
#  Cerqueira,
#  Cerqueira,
#  _ Cerqueira,
#  Ámanhã,
#  _,
#  _,
#  Fernandes,
#  Cerqueira,
#  Companhia do,
#  Pacifico,
#  Cerqueira,
#  Lisboa,
#  Cintra,
#  Lisboa,
#  Cerqueira,
#  Braga,
#  Ponte de Lima,
#  Cerqueira,
#  Cerqueira,
#  --Seu moço,
#  tia Genoveva,
#  Cerqueira,
#  Desapparecera,
#  Lisboa,
#  Áquella,
#  Minho,
#  Cerqueira,
#  --Quem,
#  Cerqueira,
#  tia Genoveva,
#  Ó Christo,
#  ...)

# %% [markdown]
# Each of the named entities in `document.ents` contains [more information about itself](https://spacy.io/usage/linguistic-features#accessing), which we can access by iterating through the `document.ents` with a simple `for` loop.
#
# For each `named_entity` in `document.ents`, we will extract the `named_entity` and its corresponding `named_entity.label_`.

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# Encanecido PER
# Começára PER
# _ MISC
# Vestia-o MISC
# Thadeu PER
# Thadeu PER
# Sahiu d'alli ORG
# Thadeu PER
# Thadeu PER
# Thadeu PER
# N'aquelle PER
# Thadeu PER
# _ MISC
# Oh! MISC
# Thadeu PER
# Thadeu PER
# _ MISC
# Thadeu PER
# _ MISC
# _ MISC
# _ MISC
# Thadeu PER
# Margarida PER
# Margarida PER
# Thadeu PER
# Oh! MISC
# _perola_ MISC
# Margarida PER
# Margarida PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Margarida PER
# Margarida PER
# collocara Thadeu PER
# Thadeu PER
# Margarida PER
# Elle PER
# Ella PER
# Margarida PER
# Deixaram-os PER
# Thadeu PER
# Ha PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Thadeu PER
# Elle PER
# Acharam-na LOC
# Thadeu PER
# _ MISC
# _ MISC
# III MISC
# Margarida PER
# D'ahi LOC
# Margarida PER
# Margarida PER
# Thadeu PER
# Viveria PER
# Margarida PER
# Ella PER
# Thadeu PER
# Elles PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Paris LOC
# Fallaram LOC
# Sacré LOC
# Cœur LOC
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# _ MISC
# França LOC
# Fôra PER
# _Sacré-Cœur_ MISC
# Margarida PER
# Thadeu PER
# Margarida PER
# Tambem PER
# _ MISC
# Margarida_ MISC
# Thadeu PER
# Margarida PER
# Ralhava-lhe LOC
# Thadeu PER
# Thadeu PER
# _ MISC
# _fetiche_ MISC
# lh'as PER
# banalisar PER
# _ MISC
# _ MISC
# Ella PER
# Thadeu PER
# Thadeu cahiu PER
# Henrique de Souza PER
# Orphão MISC
# Henrique PER
# Thadeu PER
# Henrique PER
# Comprehendeu PER
# V MISC
# Thadeu PER
# Henrique PER
# Occupavam PER
# Henrique PER
# Deus! MISC
# Henrique PER
# Joanninha PER
# Desdobrára PER
# N'este LOC
# Thadeu PER
# Soffria PER
# Thadeu PER
# Ali PER
# Thadeu PER
# Henrique PER
# Thadeu PER
# Margarida PER
# Margarida! PER
# Margarida PER
# Henrique PER
# Joanninha PER
# Margarida PER
# d'ella PER
# Henrique PER
# Thadeu PER
# Henrique PER
# Joanninha PER
# Joanna PER
# Margarida PER
# Dormia PER
# Thadeu PER
# Emquanto LOC
# Thadeu PER
# Vinha-lhe PER
# Thadeu PER
# _toilette MISC
# _ella_ MISC
# _ MISC
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Baixa LOC
# Henrique PER
# Margarida PER
# _ MISC
# casa Binder PER
# pacata Lisboa LOC
# Thadeu PER
# _coquetterie MISC
# Thadeu PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Henrique de Sousa PER
# S. Carlos PER
# _Norma_ MISC
# Henrique PER
# Margarida PER
# N'este LOC
# Henrique PER
# Margarida PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Vira-a LOC
# Ella PER
# S. Carlos PER
# Bellini PER
# N'isto MISC
# _ MISC
# Margarida PER
# d'ella PER
# Thadeu PER
# Henrique PER
# Margarida PER
# d'ella PER
# secco PER
# garridice innata MISC
# Thadeu PER
# Elle PER
# Thadeu MISC
# Margarida PER
# Henrique PER
# d'ali MISC
# Thadeu PER
# Margarida PER
# Sabiam-n'a PER
# Henrique PER
# Margarida PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# Ella PER
# _ MISC
# Henrique PER
# Thadeu!--Anda LOC
# Thadeu PER
# Margarida PER
# França LOC
# Henrique PER
# Margarida PER
# Henrique PER
# Margarida PER
# Henrique PER
# Thadeu PER
# _elle_ MISC
# Olha LOC
# Thadeu PER
# Margarida PER
# d'ella PER
# Thadeu PER
# Henrique PER
# Thadeu PER
# Henrique PER
# Buenos-Ayres MISC
# Henrique PER
# Thadeu PER
# Suissa LOC
# Italia LOC
# _ MISC
# Henrique PER
# Thadeu PER
# Margarida PER
# Margarida PER
# Margarida PER
# Thadeu PER
# _ MISC
# _Margarita_ MISC
# Margarida PER
# Dous cherubins PER
# Thadeu PER
# Aquelles PER
# Fundia-os PER
# Vivia d'elles LOC
# Henrique PER
# Margarida PER
# Thadeu PER
# Henrique PER
# Margarida PER
# Thadeu PER
# Thadeu PER
# Elle PER
# Margarida PER
# Comtudo LOC
# Ella PER
# Thadeu PER
# Ella PER
# N'este LOC
# Margarida PER
# Thadeu PER
# Pariz LOC
# Thadeu PER
# Thadeu PER
# Thadeu PER
# Margarida PER
# Thadeu PER
# _ MISC
# Henrique PER
# Margarida PER
# d'ahi LOC
# Sahiram PER
# Thadeu PER
# Henrique PER
# Henrique PER
# TIO SEBASTIÃO MISC
# Sebastião PER
# Braga LOC
# Coimbra LOC
# Braga LOC
# Aquillo PER
# Natal MISC
# Joanna PER
# Queira Deus PER
# Braga LOC
# Joanna PER
# Tornava LOC
# Coimbra LOC
# Braga LOC
# Joanna PER
# Sebastião PER
# sô Sebastião PER
# tio Sebastião PER
# Emquanto PER
# Ella PER
# Deixal-a! MISC
# Joanna PER
# Joanna PER
# Sebastião PER
# Moças LOC
# Deus PER
# Joanna PER
# Sebastião PER
# Brazil PER
# Sebastião PER
# sô Sebastião PER
# Carlota cahiu PER
# Sebastião PER
# Carlota PER
# Sebastião soccorreu PER
# Villa PER
# Verde LOC
# Sebastião PER
# Carlota PER
# Sebastião PER
# Carlota PER
# Sebastião PER
# Joanna PER
# Carlota PER
# Sebastião PER
# insania LOC
# caricias LOC
# Joanna PER
# Prompto MISC
# Sebastião PER
# Braga LOC
# N'este LOC
# Brazil PER
# Carlota PER
# Quero PER
# Brazil LOC
# Braga LOC
# Coimbra LOC
# tio Sebastião PER
# em Portugal LOC
# Rio LOC
# Brazil LOC
# Porto LOC
# Coimbra LOC
# Sebastião Alves PER
# Portugal LOC
# Coimbra LOC
# Sebastião PER
# dous annos PER
# mesquinho PER
# chato PER
# contentes PER
# abraços da familia PER
# Sebastião Alves PER
# Coimbra LOC
# Porto LOC
# Cintra LOC
# Bussaco LOC
# Portugal LOC
# Santa Apolonia LOC
# Coimbra LOC
# Granja LOC
# Porto LOC
# Sebastião PER
# Coimbra LOC
# Sebastião PER
# Coimbra LOC
# N'isso LOC
# Ria alto LOC
# d'ahi LOC
# Joanna PER
# Joanna PER
# Sebastião PER
# sr. Morgado PER
# Deus PER
# Sebastião PER
# Braga LOC
# Carlota PER
# Carlota PER
# Joanna PER
# Sebastião PER
# Coimbra LOC
# Sebastião PER
# Sebastião Alves PER
# sr. Sebastião Alves PER
# Sebastião Alves PER
# sr. Sebastião PER
# tio Sebastião PER
# Aquillo PER
# Espera PER
# Sebastião PER
# Sebastião PER
# Sebastião PER
# Alves LOC
# Sebastião PER
# Sebastião PER
# Santa Cruz LOC
# Brazil LOC
# Brindando PER
# Sebastião PER
# Sebastião PER
# Brazil? MISC
# Sebastião PER
# Braga LOC
# Sebastião PER
# Conega LOC
# O Senhor MISC
# Sebastião PER
# em Portugal LOC
# tio Sebastião PER
# Sebastião PER
# Joanna PER
# ANNEL DO DIPLOMATA ORG
# Christo! MISC
# Joaquina PER
# X*** MISC
# Vasconcellos PER
# Vasconcellos PER
# Lisboa LOC
# Porto LOC
# Minho LOC
# Universidade LOC
# Porto LOC
# Coimbra LOC
# Salesias PER
# Lisboa LOC
# Antonio PER
# Antonio de Vasconcellos PER
# Coimbra LOC
# Francisca PER
# libello!--disse LOC
# acompanhava.-- MISC
# Coimbra LOC
# Mal PER
# Antonio PER
# Joanna PER
# Antonio de Vasconcellos PER
# Padre LOC
# Filho PER
# Antonio de Vasconcellos PER
# Lisboa LOC
# Lisboa LOC
# Francisca PER
# Lisboa LOC
# _ MISC
# Lisboa de ha trinta annos LOC
# _ MISC
# _ MISC
# Antonio de Vasconcellos PER
# Chiado LOC
# Jorge de Alvim PER
# N'este LOC
# F. PER
# ministro L. PER
# Vasconcellos PER
# Francisca PER
# Antonio PER
# Receber-me-ha LOC
# Deus PER
# Antonio de Vasconcellos PER
# Jorge PER
# Alvim PER
# Porto LOC
# salval-o-hei LOC
# V. Ex.ª PER
# Lisboa LOC
# Antonio de Vasconcellos PER
# Vaes PER
# Antonio de Vasconcellos PER
# Prohibo-te PER
# Jorge de Alvim PER
# X*** MISC
# Fallou-se LOC
# Jorge de Alvim PER
# _Sancy_ MISC
# Carlos o Temerario PER
# Duque de Florença PER
# Prior do Crato PER
# França LOC
# Harley de Sancy PER
# Harley PER
# Sancy PER
# Henrique IV de França PER
# Metz LOC
# bosque de Dôls LOC
# Jacques II de Inglaterra PER
# Luiz XIV PER
# V. Ex.ª PER
# Fernão Mendes PER
# V. Ex.ª PER
# Meneláu PER
# Russos LOC
# Sr. Jorge de Alvim PER
# Sr. Alvim PER
# Antonio PER
# Vasconcellos PER
# _toasts_ MISC
# Alvim PER
# _taça da amizade_ MISC
# Vasconcellos PER
# Deus PER
# V. PER
# Lisboa LOC
# Antonio de Vasconcellos PER
# Lacenaire LOC
# Antonio de Vasconcellos PER
# Jorge de Alvim PER
# Sr. Alvim PER
# Jorge PER
# Alvim PER
# Antonio de Vasconcellos PER
# Vasconcellos PER
# Jorge de Alvim PER
# Balzac PER
# Sr. Jorge PER
# Vasconcellos LOC
# Permitta-me PER
# V. Ex.ª PER
# Antonio de Vasconcellos PER
# Jorge de Alvim PER
# ESCOLHA DE GASTÃO MISC
# _ MISC
# visconde das Lagôas PER
# João do Moinho Novo PER
# João Silveira PER
# Brazil PER
# _ MISC
# _ MISC
# _ MISC
# Minho LOC
# Vianna PER
# Arrás LOC
# Lisboa LOC
# Brazil PER
# _ MISC
# Pariz LOC
# Timbravam PER
# Fallavam PER
# _ MISC
# _ MISC
# _ MISC
# traziam-- MISC
# _ MISC
# riso amarello PER
# visconde PER
# _ MISC
# _ MISC
# S. Carlos LOC
# Respeitavam LOC
# Desprezavam PER
# Stael LOC
# Ferté LOC
# Brazil PER
# Brazil LOC
# Londres LOC
# _gentleman rider_ MISC
# Fallava LOC
# Gastão PER
# Gastão PER
# Gastão da Silveira PER
# Europa LOC
# Universidade LOC
# Inglaterra LOC
# Gastão PER
# Gastão PER
# Intelligente PER
# Gastão PER
# Gastão PER
# Gastão PER
# Gastão PER
# França LOC
# Pimentas LOC
# Gastão PER
# _ MISC
# _ MISC
# Leopoldo PER
# _ MISC
# _ MISC
# segrêdo MISC
# Gastão PER
# Gastão PER
# Gastão PER
# Gastão PER
# Gastão PER
# visconde das Lagôas PER
# Bailes PER
# _ MISC
# _ MISC
# leôa LOC
# Clotilde de Magalhães PER
# _ MISC
# Magalhães PER
# Lagôas PER
# Clotilde de Magalhães PER
# Gastão da Silveira PER
# visconde das Lagôas PER
# Clotilde PER
# Clotilde PER
# Manejava LOC
# visconde das Lagôas PER
# Clotilde PER
# _ MISC
# Clotilde PER
# Clotilde PER
# Angelina PER
# Angelina PER
# Clotilde PER
# Clotilde PER
# Magalhães PER
# Gastão PER
# Deus! MISC
# Clotilde PER
# Clotilde PER
# Gastão PER
# Discordavam PER
# Clotilde PER
# Gastão PER
# Clotilde PER
# Gastão PER
# Ella PER
# Gastão PER
# Clotilde PER
# _ MISC
# _ MISC
# _extasis inolvidaveis_ MISC
# Clotilde PER
# Gastão PER
# Dançavam PER
# visconde das Lagôas PER
# senhora D. Angelina PER
# Gastão PER
# _ MISC
# Angelina PER
# Dóe-me MISC
# Gastão PER
# Angelina PER
# Gastão PER
# Suissa LOC
# Angelina PER
# visconde das Lagôas PER
# Alto Minho LOC
# Angelina PER
# Gastão PER
# Clotilde PER
# Emquanto PER
# Clotilde PER
# Gastão PER
# Gastão PER
# Angelina PER
# Gastão PER
# Deus MISC
# Clotilde PER
# Clotilde PER
# Angelina PER
# Ha PER
# Angelina PER
# Gastão PER
# Aquelle PER
# Magalhães PER
# _ MISC
# _ MISC
# Gastão PER
# Clotilde PER
# Gastão PER
# Angelina PER
# Buenos-Ayres MISC
# Elle PER
# Angelina PER
# Clotilde PER
# Apparece LOC
# Ha PER
# ROMANCE DE ADELINA MISC
# FRAGMENTOS DE CARTAS ORG
# Supponho PER
# _ MISC
# _ MISC
# Thereza PER
# Aquelle PER
# Quero PER
# Quero PER
# Soffrer LOC
# Theresa PER
# Elles PER
# Alegrias PER
# Perguntavas-me PER
# _Moral MISC
# _ MISC
# _ MISC
# _ MISC
# São Beethoven PER
# Mozart PER
# Hayden PER
# Presinto PER
# Ha MISC
# Mozart PER
# Beethoven PER
# Ó Beethoven PER
# Acham-lhe PER
# Hontem PER
# Thereza PER
# Elle_ MISC
# Emquanto MISC
# Hontem PER
# Naufragámos PER
# Mostrei-lhes PER
# Consolai-me! MISC
# Arthur LOC
# Arthur PER
# Procurava LOC
# Encontrei MISC
# Marido MISC
# Oh! MISC
# Arthur PER
# Converso PER
# Conto-lhes PER
# Conto-lhes LOC
# Deus te abençôe PER
# CIGANA ORG
# Terrivel_ MISC
# Rio de Janeiro LOC
# Brazil LOC
# Navarro PER
# Estão-me PER
# Massarellos LOC
# Vigo LOC
# Massarellos LOC
# capitão Navarro PER
# Douro LOC
# _Cigana_ MISC
# _Cigana_ MISC
# Navarro PER
# _Cigana_ MISC
# _Cigana_ MISC
# Navarro PER
# _Cigana_ MISC
# _Cigana_ MISC
# Navarro PER
# Brazil PER
# Lessa PER
# _Cigana_ MISC
# Navarro PER
# N'aquelle PER
# Estendia MISC
# Mattosinhos LOC
# Navarro PER
# _Cigana_ MISC
# _ MISC
# _Cigana_ MISC
# _ MISC
# _Cigana_! MISC
# _Cigana_ MISC
# Lessa PER
# Navarro PER
# _Cigana_ MISC
# _Cigana_ MISC
# Navarro PER
# _Terrivel_ MISC
# _Cigana_ MISC
# rio Lessa LOC
# Luiza PER
# Joaquim Antonio Ferreira PER
# Conde da Guaratiba PER
# Gouvêa PER
# Africa LOC
# Vallongo LOC
# Luiza PER
# Luiza PER
# Luiza PER
# _ MISC
# _Cigana_ MISC
# Luiza PER
# Luiza PER
# _Cigana_ MISC
# _ MISC
# _Cigana_ ouvindo-te MISC
# Luiza PER
# _Cigana_ MISC
# Luiza PER
# N'aquelle PER
# lua LOC
# Luiza PER
# _Cigana MISC
# sr. Gouvêa PER
# Luiza PER
# Luiza PER
# Cigana_ MISC
# Cigana_ MISC
# _Cigana_! MISC
# Luiza PER
# _Cigana_ MISC
# FACES DE UMA ORG
# Ella PER
# Sonhava PER
# Margarida PER
# Salvava-a PER
# Margarida PER
# Lisboa LOC
# S. Carlos PER
# miss Brown PER
# Londres LOC
# Margarida PER
# Eduardo de C. PER
# Elle PER
# Margarida PER
# Portugal LOC
# Eduardo PER
# Margarida PER
# Minho LOC
# Minho LOC
# Eduardo PER
# Vianna do Castello LOC
# Margarida PER
# Vianna LOC
# Partiram LOC
# _ MISC
# Vianna PER
# Estado LOC
# Margarida PER
# d'ella PER
# Eduardo de C. PER
# Vianna PER
# Foi-me LOC
# Lisboa LOC
# Margarida PER
# mentalmente:--Quem PER
# _ MISC
# _ MISC
# _ MISC
# _ MISC
# _ MISC
# Margarida PER
# Eduardo de C. PER
# Margarida PER
# Eduardo PER
# Margarida PER
# Eduardo PER
# Fallavam PER
# Margarida PER
# Ha PER
# Elle PER
# Olhe PER
# Margarida PER
# Tambem PER
# V. PER
# Margarida PER
# Eduardo PER
# Margarida PER
# Eduardo PER
# Margarida PER
# Margarida PER
# Eduardo PER
# N'este LOC
# Margarida PER
# Margarida PER
# _toilette_ MISC
# conde de V PER
# _la vie MISC
# _ MISC
# _Marialva MISC
# Margarida PER
# Brown PER
# Margarida PER
# Eduardo PER
# Luctara PER
# Margarida PER
# Presinto PER
# Pergunta-o LOC
# Lisboa LOC
# Condessa de V PER
# Lisboa LOC
# _ MISC
# Deixára PER
# Miss Brown ORG
# Margarida PER
# Fazia LOC
# Margarida PER
# S. Bento PER
# Lisboa LOC
# Comprehendia MISC
# N'isto MISC
# Margarida PER
# Eduardo de C. PER
# Margarida PER
# Eduardo PER
# Christo PER
# Magdalena PER
# Ella PER
# Cahia LOC
# Margarida sahia PER
# Miss Brown PER
# Margarida PER
# N'essa carruagem PER
# Eduardo de C. PER
# Margarida PER
# Margarida PER
# Lisboa LOC
# Ha PER
# Providencia LOC
# Eduardo de C. PER
# TIA IZABEL ORG
# Conhecia-a MISC
# Affirmavam PER
# _ MISC
# _ MISC
# _ MISC
# _ MISC
# _ MISC
# tia Izabel PER
# _ MISC
# _ MISC
# Japão LOC
# China LOC
# Russia LOC
# Escolhia PER
# Andava PER
# Virgem PER
# Exhalava LOC
# --Quem LOC
# tia Izabel PER
# _baby_ louro MISC
# irmãosinho Arthur PER
# Aquelle cortejo MISC
# Umas LOC
# Ella PER
# Porquê PER
# Tambem PER
# Estremecera PER
# Deus PER
# Universidade LOC
# Foram-se-lhe MISC
# _alguem_ invisivel MISC
# _historia da tia Izabel_ MISC
# MILLIONARIO ORG
# Brazil ha MISC
# em Portugal LOC
# Francisco PER
# sr. Francisco Cerqueira PER
# Lisboa LOC
# Mineiros LOC
# Cerqueira _ MISC
# sr. Cerqueira PER
# Inda LOC
# _ Cerqueira MISC
# Europa LOC
# Europa LOC
# sr. Cerqueira PER
# Orpheu PER
# Eurydices PER
# Brazil PER
# » MISC
# Cerqueira PER
# em Portugal LOC
# Cerqueira LOC
# sr. Cerqueira PER
# Francisco Cerqueira PER
# Portugal LOC
# Arrancado LOC
# sr. Cerqueira PER
# Buenos-Ayres MISC
# Coitado! MISC
# sr. Cerqueira PER
# sr. Cerqueira PER
# _ MISC
# _ MISC
# morro de Santa Thereza LOC
# Botafogo ORG
# Corcovado LOC
# Brazil LOC
# Europa LOC
# Portugal LOC
# sr. Cerqueira PER
# sr. Cerqueira PER
# Cerqueira PER
# Cerqueira LOC
# _ Cerqueira MISC
# Ámanhã LOC
# _ MISC
# _ MISC
# Fernandes PER
# Cerqueira MISC
# Companhia do LOC
# Pacifico LOC
# Cerqueira LOC
# Lisboa LOC
# Cintra PER
# Lisboa LOC
# Cerqueira LOC
# Braga LOC
# Ponte de Lima LOC
# Cerqueira LOC
# Cerqueira LOC
# --Seu moço PER
# tia Genoveva PER
# Cerqueira LOC
# Desapparecera PER
# Lisboa LOC
# Áquella PER
# Minho LOC
# Cerqueira PER
# --Quem LOC
# Cerqueira LOC
# tia Genoveva PER
# Ó Christo PER
# Venho LOC
# --Do meu Francisco? MISC
# Deus! MISC
# Cerqueira PER
# Francisco PER
# Joanna PER
# Francisco PER
# Valha-te Deus PER
# tia Genoveva PER
# Vaes PER
# d'ahi LOC
# Guimarães LOC
# Cerqueira LOC
# Recolhiam PER
# Joanna PER
# Francisco PER
# Conversemos PER
# d'ahi LOC
# Brazil LOC
# Francisco Cerqueira PER
# Sonhou LOC
# Brazil LOC
# Europa LOC
# Portugal LOC
# Minho LOC
# Narravam PER
# Cerqueira LOC
# N'isto MISC
# Arriba LOC
# _ MISC
# _ MISC
# PERCEPTORA MISC
# Martha de Vasconcellos PER
# _Keepsake_ MISC
# _ MISC
# Gonçalves MISC
# Martha PER
# Allemanha ORG
# Europa LOC
# _burra MISC
# Martha de Vasconcellos PER
# Fulana_ MISC
# Martha PER
# Mariquinhas LOC
# Julia PER
# Marta PER
# Marta PER
# Penetrára PER
# Creação MISC
# bom Deus LOC
# Martha PER
# Martha PER
# Martha PER
# Martha PER
# Martha PER
# Gonçalves LOC
# Julião PER
# Martha PER
# Imaginava-a LOC
# Gœthe PER
# Póde PER
# Allemanha ORG
# _Fausto_ MISC
# Allemanha LOC
# Gœthe PER
# Martha PER
# Julião PER
# Julião PER
# Martha PER
# Julião PER
# Julião PER
# Martha PER
# Elle PER
# Martha PER
# Chopin PER
# Schübert PER
# Beethowen PER
# _Diario de Noticias_ MISC
# _ MISC
# Martha PER
# Julião PER
# _parvenus_ MISC
# Martha PER
# Zola PER
# Zola PER
# Meu Deus! MISC
# Octavio Feuillet PER
# penna d'ouro PER
# Feuillet PER
# Balzac PER
# _ MISC
# _ MISC
# Feuillet PER
# Zola PER
# Zola PER
# Feuillet PER
# Octavio Feuillet PER
# _Le journal d'une MISC
# Elle PER
# Conde de Camors PER
# Le journal d'une femme PER
# _escola realista MISC
# _ MISC
# Octavio Feuillet PER
# N'esta ORG
# Deus PER
# Octavio Feuillet PER
# Diario MISC
# Emquanto PER
# _ MISC
# _ MISC
# Restas-me tu MISC
# Espero PER
# Deus PER
# BALSAC MISC
# Ha PER
# Peninsula LOC
# Paris LOC
# Hespanha LOC
# Balsac PER
# Madame de Balsac PER
# Arte LOC
# Ella PER
# Divida PER
# Calumnia LOC
# Inveja LOC
# Impossivel MISC
# Pegaso MISC
# Imaginario MISC
# D. Quichote MISC
# _ MISC
# Hanskan PER
# Balsac PER
# Portugal LOC
# Portugal LOC
# Resignei-me LOC
# Balsac PER
# _Correspondencia_ MISC
# Calmann Levy PER
# Balsac PER
# Balsac PER
# _Oiro MISC
# Balsac PER
# Balsac PER
# Emquanto LOC
# _Mil e uma noites_ MISC
# Balsac PER
# Arte PER
# Balsac succumbia MISC
# _ MISC
# _ MISC
# _ MISC
# Amante PER
# Balsac PER
# Galatheia MISC
# Théophile Gauthier PER
# Balsac,--e LOC
# Balsac PER
# II MISC
# Théophile Gauthier PER
# Balsac PER
# Usava PER
# Luiz PER
# Boulanger PER
# N'essa LOC
# Balsac PER
# Touraine PER
# Balsac PER
# David PER
# Madame de Girardin PER
# Balsac_ MISC
# Tancredo PER
# Balsac PER
# Cahir PER
# Eugenia Grandet PER
# _La Fossette_ MISC
# Mignon ORG
# Morsauf LOC
# Bauseant LOC
# Langeais PER
# Restaud PER
# Dudley PER
# Valeria Marneffe PER
# Balsac LOC
# Luiz Lambert PER
# Swedenborgistas LOC
# Fausto PER
# _ MISC
# III MISC
# _Correspondencia_ MISC
# Balsac PER
# Hanska LOC
# Balsac PER
# tonnel das Danaides PER
# Balsac PER
# Hanska PER
# Balsac PER
# _Correspondencia_ MISC
# Madame Hanska PER
# _la MISC
# Comtigo LOC
# França LOC
# de Lisboa LOC
# _ MISC
# _Jardim da Europa MISC
# _ MISC
# _D. Jayme MISC
# D'entre PER
# teem LOC
# M.ᵐᵉ Ratazzi LOC
# Shakespeares LOC
# M.ᵐᵉ Ratazzi LOC
# _ MISC
# Shakespeares LOC
# Deus d'aqui MISC
# _folle du MISC
# _ MISC
# Ulysses Grant PER
# Grant PER
# Grant PER
# Boyton PER
# Grant PER
# _High life_ MISC
# Price PER
# Grant PER
# _Manrico_ MISC
# _Arthur_ MISC
# Grant PER
# Estados-Unidos da America ORG
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# N'esta LOC
# America LOC
# _ MISC
# _ MISC
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Lincoln PER
# Elle PER
# Europa LOC
# Biblia MISC
# Lincoln PER
# Lincoln PER
# Lincoln PER
# Lincoln PER
# Estados-Unidos LOC
# Lincoln PER
# Washington LOC
# Springffel LOC
# D'alli PER
# Grant PER
# Lincoln PER
# Grant PER
# Estado LOC
# West-Point LOC
# Mexico LOC
# Taylor PER
# Vera Cruz LOC
# Missouri LOC
# S. Luiz LOC
# Grant PER
# S. Luiz LOC
# Estados-Unidos LOC
# Europa LOC
# Grant PER
# Estados-Unidos LOC
# Republica ORG
# Elle PER
# Lee PER
# Richmond LOC
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Lincoln PER
# Grant PER
# Grant PER
# Procurarei LOC
# Elle PER
# America LOC
# Lisboa LOC
# VICTOR ORG
# Gustavo Rivet PER
# Victor Hugo PER
# _Lenda dos Seculos_ MISC
# _robe de chambre_ MISC
# Marais MISC
# Victor Hugo PER
# _Art d'être grand père_ MISC
# _ MISC
# Châtiments_ MISC
# Comtudo LOC
# Victor LOC
# Hugo PER
# Victor Hugo PER
# Olympo PER
# _eterno feminino_ MISC
# _porção de dominio_ MISC
# Circe PER
# Helena PER
# Melusina LOC
# Renascença LOC
# Imperia PER
# Lucrecia Borgia PER
# Shakespeare PER
# Ophelia PER
# Desdemona LOC
# Victor Hugo PER
# Shakspeare PER
# Téem LOC
# Victor Hugo PER
# Elle PER
# Marius PER
# Didier PER
# Gennaro PER
# Oh! MISC
# Didier PER
# Hernani PER
# Gennaro PER
# Marius PER
# Hugo PER
# Hugo PER
# _ MISC
# Dona Sol MISC
# Sorrisos LOC
# Hespanhas MISC
# Appareça LOC
# Hugo PER
# Vêde Marion PER
# Vêde Eponine PER
# Pariz LOC
# Marius PER
# Eponine PER
# Cosette PER
# Marius PER
# João Valjean PER
# Marion PER
# Magdalena LOC
# Magdalena LOC
# Esmeralda LOC
# Quasimodo LOC
# Umas LOC
# Umas LOC
# Leitora PER
# Entristecem-te LOC
# As Gervasias MISC
# Bovarys PER
# Fannys MISC
# França LOC
# Victor Hugo PER
# Oh! MISC
# _ MISC
# _hosanna MISC
# Arrastou-as PER
# Esmeralda LOC
# Cosette LOC
# Ella PER
# Marius PER
# Cosette louca PER
# Marius PER
# Cosette PER
# Amor PER
# Sacrificio! MISC
# Victor Hugo PER
# Déa PER
# Amada PER
# Deus! MISC
# contraste!--sorri PER
# Josiane PER
# Josiane PER
# Titan ORG
# Apollo MISC
# Polyphemo! MISC
# Dona Sol PER
# Maria de Neuburgo PER
# Marion LOC
# Eponine LOC
# Cosette LOC
# Déa PER
# Crearam PER

# %% [markdown]
# To extract just the named entities that have been identified as `PER` (person), we can add a simple `if` statement into the mix:

# %%
for named_entity in document.ents:
    if named_entity.label_ == "PER":
        print(named_entity)
# Out:
# Encanecido
# Começára
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# N'aquelle
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Thadeu
# Margarida
# Margarida
# Thadeu
# Margarida
# Margarida
# Margarida
# Thadeu
# Margarida
# Victor Hugo
# Shakspeare
# Victor Hugo
# Elle
# Marius
# Didier
# Gennaro
# Didier
# Hernani
# Gennaro
# Marius
# Hugo
# Hugo
# Hugo
# Vêde Marion
# Vêde Eponine
# Marius
# Eponine
# Cosette
# Marius
# João Valjean
# Marion
# Leitora
# Bovarys
# Victor Hugo
# Arrastou-as
# Ella
# Marius
# Cosette louca
# Marius
# Cosette
# Amor
# Victor Hugo
# Déa
# Amada
# contraste!--sorri
# Josiane
# Josiane
# Dona Sol
# Maria de Neuburgo
# Déa
# Crearam

# %% [markdown]
# ## NER with Long Texts or Many Texts

# %%
import math
number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

# %%
chunked_documents = list(nlp.pipe(text_chunks))

# %% [markdown]
# ## Get People

# %% [markdown]
# To extract and count the people, we will use an `if` statement that will pull out words only if their "ent" label matches "PER."

# %%
people = []

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "PER":
            people.append(named_entity.text)

people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df
# Out:
#                            character  count
# 0                          Margarida     88
# 1                             Thadeu     73
# 2                             Gastão     30
# 3                             Bertha     30
# 4                          Sebastião     29
# 5                           Henrique     28
# 6                             Martha     22
# 7                             Balsac     20
# 8                           Clotilde     19
# 9                              Grant     18
# 10                              Elle     16
# 11                            Joanna     16
# 12                              Ella     15
# 13                           Lincoln     15
# 14                              elle     12
# 15                             Luiza     12
# 16                            Julião     12
# 17                              Deus     11
# 18           Antonio de Vasconcellos     11
# 19                          Angelina     11
# 20                            d'ella      9
# 21                           Eduardo      9
# 22                           Navarro      8
# 23                     sr. Cerqueira      8
# 24                                Ha      7
# 25                              ella      7
# 26                            Brazil      7
# 27                           Carlota      7
# 28                       Victor Hugo      7
# 29                      Vasconcellos      6
# 30                    Jorge de Alvim      6
# 31               visconde das Lagôas      6
# 32                     Eduardo de C.      6
# 33                              Zola      6
# 34                            Marius      6
# 35                          Emquanto      5
# 36                             elles      5
# 37                         Cerqueira      5
# 38                              Naly      5
# 39                          Feuillet      5
# 40                            Tambem      4
# 41                     tio Sebastião      4
# 42                           Antonio      4
# 43                           V. Ex.ª      4
# 44                            Balzac      4
# 45                         Francisco      4
# 46                           Adriana      4
# 47                  Octavio Feuillet      4
# 48                              Hugo      4
# 49                         N'aquelle      3
# 50                         Joanninha      3
# 51                         S. Carlos      3
# 52                             Quero      3
# 53                   Sebastião Alves      3
# 54                         Francisca      3
# 55                             Alvim      3
# 56                            Vianna      3
# 57                         Magalhães      3
# 58                            Hontem      3
# 59                             Elles      2
# 60                           Aquillo      2
# 61                      sô Sebastião      2
# 62                               Mal      2
# 63                             Jorge      2
# 64                              Vaes      2
# 65                         Sr. Alvim      2
# 66                                V.      2
# 67                          Fallavam      2
# 68                Gastão da Silveira      2
# 69             Clotilde de Magalhães      2
# 70                           Aquelle      2
# 71                           Thereza      2
# 298                         Touraine      1
# 299                            David      1
# 300               Madame de Girardin      1
# 301                         Tancredo      1
# 302                            Cahir      1
# 303                         Langeais      1
# 304                          Restaud      1
# 305                           Dudley      1
# 306                 Valeria Marneffe      1
# 307                     Luiz Lambert      1
# 308                           Fausto      1
# 309              tonnel das Danaides      1
# 310                           Hanska      1
# 311                        dama póde      1
# 312                          luctara      1
# 313                      millionario      1
# 314                        succumbiu      1
# 315                    Madame Hanska      1
# 316                          D'entre      1
# 317                    Ulysses Grant      1
# 318                           Boyton      1
# 319                            Price      1
# 320                             fóra      1
# 321                        triumphar      1
# 322                         bracejar      1
# 323                           medrou      1
# 324                            asylo      1
# 325                           magoar      1
# 326                             póde      1
# 327                          sociaes      1
# 328                           D'alli      1
# 329                           Taylor      1
# 330                              Lee      1
# 331                        n'aquella      1
# 332                        triumphos      1
# 333                    Gustavo Rivet      1
# 334                           Olympo      1
# 335                     sinthethisam      1
# 336                            penna      1
# 337                     penna traços      1
# 338                         fallamos      1
# 339                          brutaes      1
# 340                            Circe      1
# 341                           Helena      1
# 342                          Imperia      1
# 343                  Lucrecia Borgia      1
# 344                      Shakespeare      1
# 345                          Ophelia      1
# 346                       Shakspeare      1
# 347                           exhala      1
# 348                          Hernani      1
# 349                      Vêde Marion      1
# 350                     Vêde Eponine      1
# 351                          Eponine      1
# 352                     João Valjean      1
# 353                           Marion      1
# 354                          Leitora      1
# 355                          Bovarys      1
# 356                      Arrastou-as      1
# 357                    Cosette louca      1
# 358                             Amor      1
# 359                            Amada      1
# 360                contraste!--sorri      1
# 361                         Dona Sol      1
# 362                Maria de Neuburgo      1
# 363                          Crearam      1

# %% [markdown]
# ## Get Places

# %% [markdown]
# To extract and count places, we can follow the same model as above, except we will change our `if` statement to check for "ent" labels that match "LOC."

# %%
places = []
for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "LOC":
            places.append(named_entity.text)

places_tally = Counter(places)

df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
df
# Out:
#                          place  count
# 0                       Lisboa     19
# 1                      Coimbra     13
# 2                       França      9
# 3                        Braga      9
# 4                       Europa      9
# 5                    Cerqueira      9
# 6                     Portugal      8
# 7                       Brazil      7
# 8                       N'este      6
# 9                        Pariz      6
# 10                       Porto      6
# 11                       Minho      6
# 12                       d'ahi      5
# 13                 em Portugal      4
# 14                Universidade      3
# 15                        Umas      3
# 16                       terra      3
# 17              Estados-Unidos      3
# 18                       Paris      2
# 19                    Emquanto      2
# 20                      Suissa      2
# 21                     Comtudo      2
# 22                     Londres      2
# 23                 Massarellos      2
# 24                      Estado      2
# 25                       Venho      2
# 26                        teem      2
# 27                M.ᵐᵉ Ratazzi      2
# 28                Shakespeares      2
# 29                     America      2
# 30                     S. Luiz      2
# 31                      lyrios      2
# 32                   Magdalena      2
# 33                   Esmeralda      2
# 34                     Cosette      2
# 35                  Acharam-na      1
# 36                       D'ahi      1
# 37                    Fallaram      1
# 38                       Sacré      1
# 39                        Cœur      1
# 159                   Hespanha      1
# 160                       Arte      1
# 161                   Calumnia      1
# 162                     Inveja      1
# 163                Resignei-me      1
# 164                        sca      1
# 165                 Balsac,--e      1
# 166                    Morsauf      1
# 167                   Bauseant      1
# 168                     Balsac      1
# 169            Swedenborgistas      1
# 170                     Hanska      1
# 171                   padecera      1
# 172                    Comtigo      1
# 173                  de Lisboa      1
# 174          hantasia do poeta      1
# 175                   repulsam      1
# 176                  apparecer      1
# 177                      vagos      1
# 178                   triumpho      1
# 179                  succumbir      1
# 180                     N'esta      1
# 181                 Washington      1
# 182                 Springffel      1
# 183                 West-Point      1
# 184                     Mexico      1
# 185                  Vera Cruz      1
# 186                   Missouri      1
# 187                   Richmond      1
# 188                 Procurarei      1
# 189                     Victor      1
# 190               heres ideaes      1
# 191                       lyra      1
# 192                 innocencia      1
# 193                  crestaria      1
# 194                   Melusina      1
# 195                 Renascença      1
# 196                  Desdemona      1
# 197                       Téem      1
# 198                       flôr      1
# 199                      ellas      1
# 200                   Sorrisos      1
# 201                   Appareça      1
# 202                   illumina      1
# 203                  Quasimodo      1
# 204             Entristecem-te      1
# 205                     Marion      1
# 206                    Eponine      1

# %% [markdown]
# ## Get NER in Context

# %%
from IPython.display import Markdown, display
import re

def get_ner_in_context(keyword, document, desired_ner_labels= False):
    
    if desired_ner_labels != False:
        desired_ner_labels = desired_ner_labels
    else:
        desired_ner_labels = ['PER', 'ORG', 'LOC']  
        
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        #process each sentence
        sentence_doc = nlp(sentence.text)
        for named_entity in sentence_doc.ents:
            #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
            if keyword.lower() in named_entity.text.lower()  and named_entity.label_ in desired_ner_labels:
                #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
                #sentence_text = sentence.text
            
                sentence_text = re.sub('\n', ' ', sentence.text)
                sentence_text = re.sub(f"{named_entity.text}", f"**{named_entity.text}**", sentence_text, flags=re.IGNORECASE)

                display(Markdown('---'))
                display(Markdown(f"**{named_entity.label_}**"))
                display(Markdown(sentence_text))

# %%
for document in chunked_documents:
    get_ner_in_context('Lisboa', document)
# Out:
# ---
# **LOC**
# Margarida sahia de uma loja e ia a saltar ligeira, elegante com a sua graça parisiense para dentro do _coupé_ delicioso que, de proposito para a filha, o marquez havia encommendado mezes antes á casa Binder, e que dous finos cavallos inglezes esplendidamente ajaezados faziam voar pelas ruas da nossa **pacata Lisboa**.
# ---
# **LOC**
# O advogado Vasconcellos morrêra pobre, sorte de todos os causidicos de provincia, que logram vencer, quando muito, por mez, o que qualquer dos collegas de **Lisboa** e Porto dá aos seus agaloados trintanarios.
# ---
# **LOC**
# O rapaz foi para Coimbra, e a menina para o convento das Salesias em **Lisboa**, de onde recolheu quando o irmão entrava para o primeiro anno juridico.
# ---
# **LOC**
# Logo que se viu senhor dos titulos alcançados pelo seu estudo e applicação, foi á villa natal agradecer aos que o haviam tão evangelicamente amparado, e, por conselhos de um condiscipulo, dirigiu-se a **Lisboa**, onde fixou residencia, e entrou a frequentar o escriptorio de um dos advogados de mais renome no fôro da capital.
# ---
# **LOC**
# Em **Lisboa** encontraria campo mais dilatado onde desafogar as suas altas aspirações.
# ---
# **LOC**
# N'aquella época chegara a **Lisboa** um individuo que fôra o mais perdulario dos _leões_ da **Lisboa** de ha trinta annos, e que presentemente occupava
# ---
# **LOC**
# N'aquella época chegara a Lisboa um individuo que fôra o mais perdulario dos _leões_ da **Lisboa de ha trinta annos**, e que presentemente occupava
# ---
# **LOC**
# Em vez do arnez, do broquel, das cannelleiras e do elmo, aconselho-lhe que se vista com elegancia igual á sua gentileza, porque vae combater a féra no salão da mais elegante senhora de **Lisboa**, e ante a presença das nossas mais acentuadas celebridades politicas e litterarias.
# ---
# **LOC**
# uma cousa que lhes parecerá excentrica, mas que me relevarão, já que em **Lisboa** passo por um ente singular e extraordinario.
# ---
# **LOC**
# Em **Lisboa** não era menos rica, nem menos confortavel, a habitação do millionario.
# ---
# **LOC**
# Margarida no inverno vivia em **Lisboa**.
# ---
# **LOC**
# Conhece-o?  --Foi-me apresentado este inverno em **Lisboa**; respondeu Margarida.
# ---
# **LOC**
# «Pergunta-o se quizeres, a essa **Lisboa**, que assistiu ao louco esphacelar de uma fortuna enorme, com o sorriso banal e adulador que ella tem para todos os perdularios.
# ---
# **LOC**
# A brilhante Condessa de V..., a filha adorada de um dos homens mais ricos de **Lisboa**, a rainha dos salões luxuosos, a _estrella_ mais fulgurante do alto mundo, dava lições para sustentar os dous filhos que lhe restavam, unicos vestigios de um passado de pomposas mentiras.
# ---
# **LOC**
# N'uma tarde do mez de janeiro, chuvosa, humida e fria, Margarida subia a muito custo a calçada de S. Bento, em **Lisboa**, onde morava uma das suas discipulas.
# ---
# **LOC**
# Os dous orphãos de Margarida estão agora a educar-se em um dos melhores collegios de **Lisboa**, e todas as despezas da sua educação são pagas por um protector invisivel e mysterioso.
# ---
# **LOC**
# O sr. Francisco Cerqueira lembrava-se de todos os pormenores e incidentes trabalhosos da jornada que elle fizera desde a sua pequena e risonha aldeia minhota até **Lisboa**.
# ---
# **LOC**
# Em **Lisboa** pouco se demorou.
# ---
# **LOC**
# No hotel, alguns amigos quizeram prendel-o ainda, tentando-o com o theatro lyrico, com Cintra e com as poucas fascinações baratas de **Lisboa**.
# ---
# **LOC**
# Verdade é que podia ter tido novas d'ella em **Lisboa** escrevendo ao abbade, mas queria fazer uma supreza, chegar de improviso.
# ---
# **LOC**
# De vez em quando a tela monotona d'esta nossa vida **de Lisboa**, unicamente bordada de pequeninos _cancans
# ---
# **LOC**
# E este homem, tão modesto na apparencia, tão laconico nas fallas, tão simples no viver, este homem que recusa recompensas apparatosas, porque julga que a suprema recompensa é a da propria consciencia, este homem que póde apresentar-se como a personalisação da democracia moderna, é o mesmo que **Lisboa** ha pouco viu passar com a estupida e distrahida indifferença que ella tem para tudo que é verdadeiramente grande, e por isso mesmo despretencioso e simples.
