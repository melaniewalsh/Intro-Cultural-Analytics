# %% [markdown]
# # Part-of-Speech Tagging for Portuguese

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# In this lesson, we're going to learn about the textual analysis methods *part-of-speech tagging* and *keyword extraction* for Portuguese texts. These methods will help us computationally parse sentences and better understand words in context.

# %% [markdown]
# ---

# %% [markdown]
# ## spaCy and Natural Language Processing (NLP)

# %% [markdown]
# To computationally identify parts of speech, we're going to use the natural language processing library spaCy. For a more extensive introduction to NLP and spaCy, see the previous lesson.
#
# To parse sentences, spaCy relies on machine learning models that were trained on large amounts of labeled text data. If you've used the preprocessing or named entity recognition notebooks for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.

# %%
# !pip install -U spacy

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# We're also going to import the `Counter` module for counting nouns, verbs, adjectives, etc., and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the Portuguese-language model (`pt_core_news_md`), which will be processing and making predictions about our texts. This is the model that was trained on both European (CETEMPúblico) and Brazilian (CETENFolha) variants. You can download the `pt_core_news_md` model by running the cell below:

# %%
# !python -m spacy download pt_core_news_md

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Russian, Italian, Dutch, Greek, Norwegian, and Lithuanian*.
#
# *spaCy offers language and tokenization support for other language via external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('pt_core_news_md')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.

# %%
filepath = '../texts/pt.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Part-of-Speech Tagging
# The tags that spaCy uses for part-of-speech are based on work done by [Universal Dependencies](https://universaldependencies.org/), an effort to create a set of part-of-speech tags that work across many different languages. Texts from various languages are annotated using this common set of tags, and contributed to a common repository that can be used to train models like spaCy.
#
# The Universal Dependencies page has information about the annotated corpora available for each language; it's worth looking into the corpora that were annotated for your language.

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# Above is a POS chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different parts of speech that spaCy can identify as well as their corresponding labels. To quickly see spaCy's POS tagging in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) on our sample `document` with the `style=` parameter set to "dep" (short for dependency parsing):

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.lemma_` attribute for each token, which gives us the un-inflected version of the word. We'll also pull out the  `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.lemma_, token.pos_, token.dep_)
# Out:
# ﻿PRIMEIRA INTJ det
# PARTE PUNCT ROOT
#
#
#
#
#
#  SPACE
# UMA DET nummod
# HISTORIA NOUN ROOT
# VERDADEIRA ADJ ROOT
#
#
#
#  SPACE
# I ADJ ROOT
#
#
#  SPACE
# Era AUX cop
# umar DET det
# physionomia NOUN ROOT
# incaracteristica ADJ amod
# , PUNCT punct
# apagar VERB acl
# , PUNCT punct
# tristissima ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# se PRON expl
# poder VERB ROOT
# dizer VERB xcomp
# o DET det
# idade NOUN obj
# que PRON obj
# ter VERB acl:relcl
# , PUNCT punct
# nem CCONJ cc
# mesmo ADV advmod
# se PRON nsubj
# ter VERB conj
# idade NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Tanto ADV advmod
# poder VERB ROOT
# ter VERB xcomp
# trintar NUM obj
# ou CCONJ cc
# quarentar NUM conj
# comer ADP case
# setenta NUM nummod
# annos NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Curvado VERB ROOT
# pelar DET case
# idade NOUN obl:agent
# ou CCONJ cc
# pelos ADP case
# desgosto NOUN conj
# ? PUNCT punct
# Encanecido VERB ROOT
# porque SCONJ mark
# o DET det
# annos PROPN nsubj
# ter VERB advcl
#
#  SPACE
# correr VERB advcl
# por ADP case
# sobrar ADP case
# o DET det
# cabeça NOUN obl:agent
# d'elle ADJ appos
# , PUNCT punct
# ou CCONJ cc
# porque SCONJ mark
# lhe PRON iobj
# ter AUX aux
# pesar VERB conj
#
#  SPACE
# duplamente ADV advmod
# sobrar ADP case
# o DET det
# hombros NOUN obl
# debeis ADJ flat:name
# ? PUNCT punct
#
#
#  SPACE
# Quem PRON nsubj
# o PRON obj
# poder VERB ROOT
# dizer VERB xcomp
# ? PUNCT punct
#
#
#  SPACE
# Era AUX cop
# umar DET det
# organisação NOUN nsubj
# acanhar VERB amod
# e CCONJ cc
# rachitica ADJ conj
# , PUNCT punct
# poder VERB ROOT
# mesmo ADV advmod
# chamar-se VERB xcomp
#
#  SPACE
# incompleto ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Para ADP case
# elle NOUN obl
# com ADP case
# certeza NOUN nmod
# que SCONJ mark
# o DET det
# adolescencia NOUN nsubj
# não ADV advmod
# ter VERB ROOT
# o DET det
# suar DET det
# madrugar NOUN obj
#
#  SPACE
# azues ADJ advcl
# tão ADV advmod
# gorgeadas ADJ amod
# e CCONJ cc
# tão ADV advmod
# festivo NOUN conj
# , PUNCT punct
# nem CCONJ cc
# o DET det
# virilidade NOUN nsubj
# ter VERB conj
# o DET det
# fanfarra NOUN obj
#
#  SPACE
# estridente ADV advmod
# dos ADP case
# seu DET det
# clarim NOUN obl
# , PUNCT punct
# o DET det
# florescencia NOUN appos
# escarlate ADJ amod
# dos ADP case
# seu DET det
# rosaes VERB nmod
#
#  SPACE
# voluptuoso ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Tinha VERB aux
# sempre ADV advmod
# viver VERB ROOT
# debaixo ADV advmod
# de ADP case
# umar DET det
# estranho ADJ amod
# pressão NOUN obl
# doloroso ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Dependêra ADV nsubj
# de ADP case
# todo PRON det
# primeiro ADJ nmod
# porque SCONJ mark
# ser AUX cop
# fraco ADJ ROOT
# e CCONJ cc
# inerme ADJ conj
# , PUNCT punct
# depois ADV advmod
# porque SCONJ mark
#
#  SPACE
# fôra AUX cop
# pobre ADJ advcl
# , PUNCT punct
# dependente ADJ conj
# , PUNCT punct
# sem ADP case
# aquella PRON obl
# aspera PUNCT conj
# dignidade NOUN obj
# que PRON mark
# o DET det
# atrictos NOUN nsubj
# da DET case
#
#  SPACE
# vidar NOUN nmod
# tornar VERB acl:relcl
# mais ADV advmod
# rude ADJ xcomp
# e CCONJ cc
# que PRON nsubj
# ser AUX cop
# o DET det
# armadura NOUN conj
# moral ADJ amod
# que PRON nsubj
# salvaguardar VERB acl:relcl
# o DET det
# homem NOUN obj
#
#  SPACE
# o ADP case
# duro ADJ amod
# combater NOUN obl
# sociaes VERB acl
# . PUNCT punct
#
#
#  SPACE
# Nasceu VERB nsubj
# n'uma ADP case
# casar NOUN nmod
# opulento ADJ amod
# que PRON nsubj
# lhe PRON iobj
# não ADV advmod
# pertencer VERB acl:relcl
# , PUNCT punct
# crescer VERB ROOT
# o DET case
# mear NOUN obl
# de ADP case
# um NUM nummod
#
#  SPACE
# luxar NOUN nmod
# de SCONJ mark
# que SCONJ mark
# seu DET det
# paes PROPN nsubj
# erão AUX aux:pass
# parasito ADJ acl:relcl
# voluntarios ADJ amod
# e CCONJ cc
# de ADP case
# que SCONJ obl
# elle PROPN advmod
# ser AUX conj
# ... PUNCT punct
#
#  SPACE
# parasito NOUN appos
# inconsciente ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Começára PROPN ROOT
# por SCONJ mark
# ter VERB advcl
# medo NOUN obj
# de ADP case
# tudo PRON nmod
# e CCONJ cc
# de ADP case
# todo PRON conj
# ; PUNCT punct
# um DET det
# medo NOUN ROOT
# que PRON obj
# não ADV advmod
# raciocinar VERB acl:relcl
# , PUNCT punct
#
#  SPACE
# que PRON nsubj
# não ADV advmod
# saber VERB acl:relcl
# , PUNCT punct
# que SCONJ nsubj
# não ADV advmod
# indagar VERB acl:relcl
# mesmo ADV advmod
# o DET det
# suar DET det
# propria ADJ amod
# origem NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Nasceu PROPN ROOT
# assustadiço PROPN flat:name
# , PUNCT punct
# comer SCONJ mark
# certo PRON nsubj
# animaes VERB advcl
# silvestre NOUN obj
# , PUNCT punct
# e CCONJ cc
# todo DET det
# o DET fixed
# vidar NOUN conj
#
#  SPACE
# conservar VERB ROOT
# o DET det
# mesmo ADJ amod
# expressão NOUN obj
# inquieto ADJ amod
# e CCONJ cc
# medroso ADJ conj
# da DET case
# lebre PROPN nmod
# perseguir VERB acl
# . PUNCT punct
#
#
#  SPACE
# Em ADP case
# primeiro ADJ amod
# lugar NOUN obl
# ter VERB ROOT
# medo NOUN obj
# de ADP case
# seu DET det
# pae NOUN nmod
# ; PUNCT punct
# um DET det
# homem NOUN ROOT
# alto ADJ amod
# , PUNCT punct
# espadaúdo NOUN conj
# , PUNCT punct
#
#  SPACE
# plethorico ADJ amod
# , PUNCT punct
# de ADP case
# voz NOUN nmod
# grosso ADJ amod
# e CCONJ cc
# modo NOUN conj
# brutaes ADJ amod
# , PUNCT punct
# que PRON nsubj
# comer VERB acl:relcl
# comer ADP case
# um DET det
# abbade NOUN obl
# , PUNCT punct
# que PRON nsubj
#
#  SPACE
# beber VERB acl:relcl
# comer ADP case
# um DET det
# _ PROPN obl
# lansquenete PROPN flat:name
# _ PROPN flat:name
# , PUNCT punct
# que PRON nsubj
# praguejar VERB acl:relcl
# comer ADP case
# um NUM det
# carreiro NOUN xcomp
# , PUNCT punct
# e CCONJ cc
# que PRON nsubj
# se PRON expl
#
#  SPACE
# vingar VERB conj
# o ADP case
# pouco DET det
# ente NOUN obj
# que PRON nsubj
# ter VERB acl:relcl
# debaixo ADV advmod
# do DET case
# seu DET det
# dominio NOUN obl
# , PUNCT punct
# das DET case
#
#  SPACE
# complacencias NOUN amod
# servir VERB obj
# que SCONJ mark
# ser AUX cop
# obrigar VERB ccomp
# o SCONJ mark
# mostrar VERB xcomp
# aos PRON obj
# que PRON nsubj
# o PRON obj
# manter VERB acl:relcl
#
#  SPACE
# n'aquella NOUN flat:name
# farto ADJ amod
# ociosidade NOUN ROOT
# de ADP case
# commensal PROPN nmod
# que PRON nsubj
# só ADV advmod
# gozar VERB acl:relcl
# e CCONJ cc
# não ADV advmod
# pago VERB conj
# . PUNCT punct
#
#
#  SPACE
# Depois ADV advmod
# ter VERB ROOT
# medo NOUN obj
# de ADP case
# suar DET det
# tio NOUN nmod
# ; PUNCT punct
# o DET det
# dono NOUN ROOT
# da DET case
# casar NOUN nmod
# , PUNCT punct
# o ADP det
# _ PROPN conj
# senhor NOUN flat:name
# _ PROPN flat:name
# , PUNCT punct
# o DET det
# suzerana PROPN appos
#
#  SPACE
# antar ADP case
# o DET det
# qual PRON obl
# todo PRON nsubj
# se PRON expl
# curvar VERB acl:relcl
# submisso ADJ xcomp
# . PUNCT punct
#
#
#  SPACE
# E CCONJ cc
# o DET case
# emtanto NOUN obl
# ella PROPN nsubj
# ser AUX cop
# bonito ADJ ROOT
# , PUNCT punct
# delgado ADJ conj
# , PUNCT punct
# flexivel ADJ amod
# , PUNCT punct
# muito ADV advmod
# branco ADJ appos
# . PUNCT punct
#
#
#  SPACE
# Uma NUM det
# figurar NOUN ROOT
# ideal ADJ amod
# de ADP case
# pintor NOUN nmod
# inglez ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Mas CCONJ cc
# que PRON obj
# culpar NOUN nsubj
# ter VERB ROOT
# elle ADV obj
# , PUNCT punct
# o DET det
# pequenino NOUN nsubj
# parea VERB appos
# , PUNCT punct
# se SCONJ mark
# o DET det
# olho NOUN nsubj
# d'essa ADP case
# gracioso ADJ nmod
#
#  SPACE
# e CCONJ cc
# delicado ADJ acl
# senhor NOUN nsubj
# lhe PRON iobj
# parecer VERB advcl
# frio NOUN xcomp
# e CCONJ cc
# metalicos ADJ conj
# , PUNCT punct
# com ADP case
# umar DET det
#
#  SPACE
# scintillações NOUN obj
# azular VERB acl
# comer ADP case
# o PRON xcomp
# do DET case
# aço NOUN nmod
# finar ADJ amod
# ? PUNCT punct
# se SCONJ mark
# o DET det
# suar DET det
# mão NOUN nsubj
# esguio ADJ amod
# e CCONJ cc
#
#  SPACE
# branco ADJ conj
# se SCONJ mark
# lhe PRON iobj
# affiguravam VERB ROOT
# dois NUM nummod
# tenaz NOUN obj
# que PRON nsubj
# poder VERB acl:relcl
# apertal-o VERB xcomp
# , PUNCT punct
# apertal-o VERB conj
#
#  SPACE
# até ADV mark
# o PRON obj
# torcer VERB advcl
# todo PRON obj
# , PUNCT punct
# até ADP advmod
# o PRON obj
# esphacelarem VERB advcl
# e CCONJ cc
# fazer VERB conj
# d'elle NOUN obj
# , PUNCT punct
# do DET case
# seu DET det
# pequeno ADJ amod
#
#  SPACE
# corpo NOUN obl
# tão ADV advmod
# fraco ADJ amod
# , PUNCT punct
# umar DET det
# grotesco ADJ nsubj
# massa NOUN flat:name
# informar ADJ ROOT
# , PUNCT punct
# que SCONJ mark
# o DET det
# mundo NOUN nsubj
# inteirar ADJ amod
#
#  SPACE
# pisar VERB ccomp
# , PUNCT punct
# onde PRON obl
# o DET det
# mundo NOUN nsubj
# inteirar ADJ amod
# cuspir VERB advcl
# ! PUNCT punct
#
#
#  SPACE
# Seria AUX cop
# allucinação NOUN ROOT
# d'aquelle PROPN punct
# cerebro NOUN nmod
# enfermar ADJ amod
# e CCONJ cc
# condemnado VERB conj
# ás DET case
# scismas PROPN obj
#
#  SPACE
# doentio NOUN ROOT
# ? PUNCT punct
#
#
#  SPACE
# Quem PRON nsubj
# saber VERB ROOT
# ? PUNCT punct
#
#
#  SPACE
# O DET det
# casar NOUN nsubj
# ser VERB ROOT
# que SCONJ mark
# o PRON obj
# sentir VERB ccomp
# , PUNCT punct
# e CCONJ cc
# que PRON nsubj
# nunca ADV advmod
# poder VERB conj
# esquivar-se VERB xcomp
# o ADP case
# esse DET det
#
#  SPACE
# preoccupação NOUN obj
# intenso ADJ amod
# e CCONJ cc
# dilacerante ADJ conj
# ! PUNCT punct
#
#
#  SPACE
# Um NUM det
# d'estes PROPN amod
# dois PROPN nummod
# ente NOUN nsubj
# que PRON nsubj
# dominar VERB acl:relcl
# de ADP case
# estranhar ADJ amod
# terror NOUN obj
# o DET det
# suar DET det
# infancia NOUN obj
# , PUNCT punct
#
#  SPACE
# maltratava-o VERB ROOT
# o DET case
# explosão NOUN obl
# brutaes ADJ acl
# de ADP case
# seu DET det
# temperamento NOUN obj
# de ADP case
# touro NOUN nmod
# bravo ADJ amod
# . PUNCT punct
#
#
#  SPACE
# O DET det
# outro PRON ROOT
# -- PUNCT punct
# o DET det
# senhor NOUN appos
# -- PUNCT punct
# muito ADV advmod
# altivo ADJ amod
# , PUNCT punct
# muito ADV advmod
# frio ADJ conj
# , PUNCT punct
# muito ADV advmod
# desdenhoso ADJ conj
# , PUNCT punct
# nem CCONJ cc
#
#  SPACE
# sequer ADV advmod
# lhe PRON iobj
# fallava VERB conj
# . PUNCT punct
#
#
#  SPACE
# Olhava-o VERB ROOT
# ás DET case
# vezar NOUN obl
# comer ADV advmod
# se PRON nsubj
# olhar VERB advcl
# parir ADP case
# um DET det
# animal NOUN obl
# repugnante ADJ amod
# , PUNCT punct
# parir ADP case
# um DET det
# sapar NOUN nmod
# , PUNCT punct
#
#  SPACE
# ou CCONJ cc
# parir ADP case
# umar DET det
# carocha NOUN conj
# , PUNCT punct
# e CCONJ cc
# passar VERB conj
# adiantar ADV advmod
# , PUNCT punct
# imperturbavel ADJ conj
# e CCONJ cc
# olympica ADJ conj
# . PUNCT punct
#
#
#  SPACE
# Havia VERB ROOT
# , PUNCT punct
# porém CCONJ cc
# , PUNCT punct
# um DET det
# outro DET det
# sêr NOUN obj
# , PUNCT punct
# dos PRON case
# que PRON nsubj
# mais ADV advmod
# em ADP case
# contactar NOUN nsubj
# estar AUX cop
# com ADP case
# elle PROPN obl
# , PUNCT punct
#
#  SPACE
# que SCONJ nsubj
# nem CCONJ advmod
# o PRON obj
# maltratar VERB ccomp
# , PUNCT punct
# nem CCONJ cc
# o DET det
# desprezar NOUN conj
# com ADP case
# o DET det
# glacial ADJ amod
# frieza NOUN nmod
# do DET case
# seu DET det
#
#  SPACE
# desdem ADP nmod
# . PUNCT punct
#
#
#  SPACE
# E CCONJ cc
# comtudo NOUN nsubj
# ser AUX cop
# d'esse NOUN ROOT
# que PRON mark
# elle PROPN nsubj
# ter VERB ccomp
# ainda ADV advmod
# mais DET det
# medo NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Era AUX cop
# seu DET det
# tio NOUN ROOT
# ; PUNCT punct
# umar DET det
# figurar NOUN appos
# original ADJ amod
# , PUNCT punct
# umar DET det
# physionomia NOUN conj
# de ADP case
# titan PROPN nmod
# que SCONJ mark
# por ADP case
# um NUM det
#
#  SPACE
# enganir NOUN obl
# qualquer DET nsubj
# da DET case
# natureza NOUN nmod
# não ADV advmod
# poder VERB acl:relcl
# conseguir VERB xcomp
# passar VERB xcomp
# de ADP case
# anão NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Seu DET det
# tio NOUN ROOT
# ! PUNCT punct
# ... PUNCT punct
# Como ADV case
# este DET det
# individualidade NOUN obl
# extraordinariamente ADV amod
# accentuada VERB acl
# , PUNCT punct
#
#  SPACE
# comer ADP case
# este DET det
# rostir NOUN obl
# ironico ADJ amod
# , PUNCT punct
# irregular ADJ conj
# , PUNCT punct
# convulsionar VERB acl
# , PUNCT punct
# dominar VERB ROOT
# parir ADP case
# sempre ADV advmod
# o DET det
#
#  SPACE
# destinar NOUN obj
# obscuro ADJ amod
# da DET case
# infeliz ADJ amod
# creança NOUN nmod
# que PRON obj
# eu PRON nsubj
# conhecer VERB acl:relcl
# já ADV advmod
# velho ADJ xcomp
# ! PUNCT punct
#
#
#  SPACE
# Seu DET det
# tio NOUN nsubj
# não ADV advmod
# o PRON obj
# perseguir VERB ROOT
# nem CCONJ advmod
# lhe PRON iobj
# manifestar VERB conj
# umar DET det
# repugnancia NOUN obj
# mudo VERB conj
# , PUNCT punct
# pelar DET case
#
#  SPACE
# contrariar ADJ obl:agent
# . PUNCT punct
#
#
#  SPACE
# Chamava-o VERB ROOT
# continuamente ADV advmod
# parir ADP case
# o DET det
# pé NOUN nmod
# de ADP case
# si PRON nmod
# , PUNCT punct
# ensinava-lhe VERB conj
# , PUNCT punct
# quando ADV advmod
# estar AUX cop
# só ADV advmod
# , PUNCT punct
#
#  SPACE
# palavra NOUN obj
# , PUNCT punct
# esgar NOUN conj
# , PUNCT punct
# visagem NOUN conj
# grotesco ADJ amod
# que PRON nsubj
# lhe PRON iobj
# fazer VERB acl:relcl
# repetir VERB xcomp
# diante ADV case
# de ADP fixed
#
#  SPACE
# gente NOUN obl
# , PUNCT punct
# n'um ADP case
# côro NOUN conj
# de ADP case
# gargalhar NOUN nmod
# asperas ADJ amod
# e CCONJ cc
# hostil ADJ conj
# comer ADP case
# gume NOUN nmod
# de ADP case
# espadar NOUN nmod
# ! PUNCT punct
#
#
#  SPACE
# Vestia-o VERB nsubj
# de ADP case
# um DET det
# modo NOUN nmod
# desusar VERB acl
# e CCONJ cc
# extravagante ADJ conj
# , PUNCT punct
# vestia-o VERB ROOT
# de ADP case
# marujar NOUN obj
# , PUNCT punct
# de ADP case
#
#  SPACE
# escossez ADJ obl
# , PUNCT punct
# com ADP case
# o DET det
# suar DET det
# pequeno ADJ amod
# perna NOUN obl
# magro ADJ amod
# , PUNCT punct
# trigueiro NOUN conj
# , PUNCT punct
# ossudo NOUN conj
# , PUNCT punct
# n'uma VERB case
#
#  SPACE
# nudez NOUN conj
# friorento ADJ amod
# que PRON nsubj
# lhe PRON iobj
# doia VERB acl:relcl
# , PUNCT punct
# e CCONJ cc
# o PRON obj
# fazer VERB conj
# tiritar VERB xcomp
# ; PUNCT punct
# vestia-o VERB ROOT
# de ADP case
# tyrolez PROPN xcomp
# , PUNCT punct
# o DET ROOT
#
#  SPACE
# que PRON nsubj
# lhe PRON iobj
# dar VERB acl:relcl
# um DET det
# aspecto NOUN obj
# comico ADJ amod
# , PUNCT punct
# que PRON nsubj
# arrebentar VERB acl:relcl
# com ADP case
# riso NOUN obl
# o DET det
# criadagem NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Ás DET case
# vezar NOUN nmod
# o ADP case
# seu DET det
# dia NOUN ROOT
# de ADP case
# melhor ADJ amod
# humor NOUN nmod
# sahia PROPN amod
# com ADP case
# elle PROPN nmod
# , PUNCT punct
# que PRON nsubj
# ter VERB acl:relcl
# apenas ADV advmod
#
#  SPACE
# sete NUM nummod
# annos PROPN obj
# de ADP case
# idade NOUN nmod
# , PUNCT punct
# de ADP case
# casaca NOUN obl
# , PUNCT punct
# chapéo-alto NOUN conj
# , PUNCT punct
# e CCONJ cc
# berloque NOUN conj
# o DET case
# cadeia NOUN nmod
# do DET case
#
#  SPACE
# relogio NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Tinha VERB ROOT
# tempo NOUN obj
# em ADP case
# que PRON obl
# não ADV advmod
# poder VERB acl:relcl
# passar VERB xcomp
# sem ADP case
# o DET det
# suar DET det
# companhia NOUN obl
# ; PUNCT punct
# o DET det
# creança NOUN nsubj
# ser AUX cop
#
#  SPACE
# o DET det
# unica ADJ amod
# distracção NOUN ROOT
# do DET case
# anão NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# As DET det
# cariciar NOUN nsubj
# d'esse PROPN appos
# homem NOUN flat:name
# singular ADJ amod
# , PUNCT punct
# de SCONJ case
# olhar NOUN nmod
# faiscante ADJ amod
# , PUNCT punct
# de ADP case
# cabelladura NOUN nmod
#
#  SPACE
# revolto VERB ROOT
# e CCONJ cc
# electrica ADJ conj
# , PUNCT punct
# de ADP case
# voz NOUN nmod
# sonoro ADJ amod
# e CCONJ cc
# rico ADJ conj
# de ADP case
# inflexão NOUN nmod
# estranho ADJ amod
# , PUNCT punct
# doer VERB conj
# , PUNCT punct
#
#  SPACE
# porém CCONJ cc
# , PUNCT punct
# ao DET case
# pequeno NOUN obl
# muito ADV advmod
# mais ADV advmod
# do ADP case
# que PRON fixed
# o DET det
# desprezo NOUN obl
# ou CCONJ cc
# o DET det
# máos PROPN conj
# trato NOUN flat:name
# dos ADP case
#
#  SPACE
# outro PRON nmod
# . PUNCT punct
#
#
#  SPACE
# Ao DET case
# pé NOUN obl
# d'estes PROPN nsubj
# sentia-se AUX ROOT
# perseguir VERB xcomp
# , PUNCT punct
# ao DET case
# pé NOUN obl
# d'aquelle PROPN nsubj
# sentia-se VERB parataxis
# humilhar VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# Um NUM nummod
# dia NOUN obl
# o DET det
# marquez NOUN appos
# -- PUNCT punct
# o DET det
# tio NOUN nsubj
# do DET case
# pequeno ADJ amod
# Thadeu PROPN nmod
# ser AUX cop
# marquez,--achou VERB advmod
# comico ADJ ROOT
#
#  SPACE
# mandar VERB ROOT
# introduzir VERB xcomp
# o DET det
# creança NOUN obj
# o DET case
# cofre NOUN obl
# acharoar VERB acl
# que PRON nsubj
# haver VERB acl:relcl
# juntar ADV advmod
# ao DET case
# fogão NOUN obl
#
#  SPACE
# do DET case
# gabinete NOUN nmod
# de ADP case
# trabalhar NOUN nmod
# , PUNCT punct
# destinar VERB acl
# o SCONJ mark
# guardar VERB xcomp
# o DET det
# lenhar NOUN obj
# ou CCONJ cc
# o DET det
# carvão NOUN conj
# que PRON obj
# se PRON expl
#
#  SPACE
# consumir VERB acl:relcl
# . PUNCT punct
#
#
#  SPACE
# De ADP case
# minutar NOUN obl
# em ADP case
# minutar NOUN nmod
# abria-se VERB ROOT
# o DET det
# tampar NOUN obj
# e CCONJ cc
# sahia PROPN conj
# o DET det
# caro NOUN nsubj
# vermelho ADJ amod
# e CCONJ cc
#
#  SPACE
# congestionar VERB conj
# do DET case
# pequeno NOUN obj
# , PUNCT punct
# umar DET det
# caro NOUN conj
# de ADP case
# animal NOUN nmod
# assustar VERB acl
# , PUNCT punct
# o PRON appos
# que PRON nsubj
# divertir VERB acl:relcl
#
#  SPACE
# extraordinariamente ADV advmod
# o DET det
# visitar NOUN nsubj
# . PUNCT punct
#
#
#  SPACE
# Outra ADP det
# vez NOUN ROOT
# , PUNCT punct
# n'uma PUNCT case
# cear NOUN nmod
# alegrar ADJ amod
# em ADP case
# que PRON obl
# haver VERB acl:relcl
# rio NOUN obj
# de ADP case
# _ PROPN nmod
# champagne PROPN flat:name
# _ PROPN flat:name
# e CCONJ cc
# risada NOUN conj
#
#  SPACE
# crystallinas NOUN flat:name
# de ADP case
# mulher NOUN nmod
# , PUNCT punct
# Thadeu PROPN appos
# com ADP case
# um DET det
# fato NOUN nmod
# de ADP case
# meio NOUN nmod
# preto ADJ amod
# o SCONJ mark
# cobril-o VERB advcl
#
#  SPACE
# todo DET appos
# e CCONJ cc
# dois PROPN conj
# castiçaes VERB appos
# o DET case
# pequeno ADJ amod
# mão NOUN nmod
# , PUNCT punct
# servir VERB ROOT
# de ADP case
# centrar NOUN obj
# agachar VERB acl
# n'uma ADP case
#
#  SPACE
# posição NOUN obj
# grotesco ADJ amod
# o DET case
# mear NOUN nmod
# da DET case
# meza NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Sahiu PROPN ROOT
# d'alli PROPN flat:name
# com ADP case
# umar DET det
# febre NOUN nmod
# que PRON nsubj
# o PRON obj
# ter VERB acl:relcl
# um DET det
# mez NOUN obj
# entrar ADP case
# o DET det
# morte NOUN obl
# e CCONJ cc
# o DET det
# vidar NOUN conj
# , PUNCT punct
#
#  SPACE
# delirante ADJ amod
# , PUNCT punct
# sem SCONJ mark
# conhecer VERB advcl
# ninguem PROPN obj
# , PUNCT punct
# com ADP case
# o DET det
# mãe NOUN obl
# debulhar VERB acl
# em ADP case
# lagrimas NOUN obl
# á DET case
#
#  SPACE
# cabeceira NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Mas CCONJ cc
# Thadeu PROPN nsubj
# não ADV advmod
# gostar VERB ROOT
# de ADP case
# suar DET det
# mãe NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Era AUX cop
# umar DET det
# creatura NOUN nsubj
# tão ADV advmod
# debil VERB ROOT
# comer ADP case
# elle PROPN obl
# , PUNCT punct
# pallida VERB acl
# comer ADP case
# umar DET det
# defunto NOUN obl
# , PUNCT punct
# inerme ADJ amod
# , PUNCT punct
#
#  SPACE
# estupida ADJ conj
# , PUNCT punct
# sem ADP case
# vontade NOUN obl
# . PUNCT punct
#
#
#  SPACE
# As DET det
# lobo NOUN nsubj
# defender VERB ROOT
# o DET det
# seu DET det
# filho NOUN obj
# , PUNCT punct
# o DET det
# mãe NOUN nsubj
# de ADP case
# Thadeu PROPN nmod
# não ADV advmod
# o PRON obj
# saber VERB ccomp
# defender VERB xcomp
# ! PUNCT punct
#
#
#  SPACE
# Entregava-o VERB ROOT
# ás DET case
# coleras NOUN obl
# descomposto ADJ amod
# do DET case
# pae NOUN nmod
# ; PUNCT punct
# aos ADP case
# desprezo NOUN nmod
# gelidos VERB acl
# da DET case
#
#  SPACE
# tio NOUN nmod
# ; PUNCT punct
# aos ADP case
# capricho NOUN nmod
# monstruosamente ADV advmod
# comicos ADJ amod
# do DET case
# marquez NOUN nmod
# ; PUNCT punct
# ás DET case
# apupar NOUN obl
#
#  SPACE
# brutaes ADJ acl:relcl
# das DET case
# aio NOUN obj
# e CCONJ cc
# dos ADP case
# lacaio NOUN conj
# ; PUNCT punct
# aos ADP case
# riso NOUN ROOT
# das DET case
# visitar NOUN nmod
# ; PUNCT punct
# ao DET case
# pasmar NOUN nmod
#
#  SPACE
# desprezador ADJ amod
# das DET case
# outro DET det
# creanças NOUN nmod
# , PUNCT punct
# que PRON nsubj
# ir AUX acl:relcl
# áquella PROPN obj
# casar NOUN flat:name
# opulento ADJ amod
# e CCONJ cc
# ruidoso ADJ conj
#
#  SPACE
# acompanhar VERB acl
# por ADP case
# seu DET det
# paes PROPN obl:agent
# , PUNCT punct
# vestir VERB acl
# de ADP case
# velludo PROPN obl
# , PUNCT punct
# com ADP case
# pluma NOUN obl
# o ADP case
# seu DET nmod
#
#  SPACE
# lindo VERB conj
# chapéu NOUN obj
# , PUNCT punct
# o DET det
# ar NOUN conj
# gravar ADJ amod
# de ADP case
# menino NOUN nmod
# bem ADV advmod
# creados VERB acl
# , PUNCT punct
# e CCONJ cc
# que SCONJ nsubj
# não ADV advmod
# ter VERB conj
#
#  SPACE
# licença NOUN obj
# de SCONJ mark
# brincar VERB acl
# com ADP case
# aquelle DET det
# pequeno ADJ amod
# histrião PROPN obl
# , PUNCT punct
# feio ADJ conj
# , PUNCT punct
# ridiculo NOUN conj
# , PUNCT punct
# doente ADJ amod
# , PUNCT punct
#
#  SPACE
# com ADP case
# gesto NOUN obl
# de ADP case
# epileptico NOUN nmod
# , PUNCT punct
# com ADP case
# fato NOUN nmod
# de ADP case
# palhaço NOUN nmod
# e CCONJ cc
# com ADP case
# soluço NOUN conj
# de ADP case
# martyr PROPN nmod
# . PUNCT punct
#
#
#
#  SPACE
# II ADJ ROOT
#
#
#  SPACE
# Um NUM nummod
# dia NOUN obl
# , PUNCT punct
# porém CCONJ cc
# , PUNCT punct
# fez-se VERB ROOT
# o DET case
# vidar NOUN obl
# atormentar VERB acl
# e CCONJ cc
# tempestuoso NOUN conj
# do DET case
# pequeno NOUN nmod
#
#  SPACE
# Thadeu PROPN flat:name
# umar DET det
# claridade NOUN obj
# de ADP case
# luar NOUN nmod
# , PUNCT punct
# umar DET det
# claridade NOUN conj
# opalisada VERB acl
# e CCONJ cc
# doce ADJ conj
# . PUNCT punct
#
#
#  SPACE
# Houve VERB advcl
# treguas NOUN obj
# o ADP case
# seu DET det
# varios ADJ amod
# martyrios NOUN obl
# , PUNCT punct
# e CCONJ cc
# suar DET det
# mãe NOUN conj
# , PUNCT punct
# n'uma ADP case
# bella PROPN nmod
# manhã NOUN obl
# de ADP case
#
#  SPACE
# primaverar NOUN nmod
# em ADP case
# que PRON obl
# o DET det
# passaros NOUN nsubj
# cantar VERB acl:relcl
# ao DET case
# desafiar NOUN obj
# o DET case
# grande ADJ amod
# arvorar NOUN obl
# do DET case
#
#  SPACE
# jardim PROPN nmod
# , PUNCT punct
# levou-o VERB ROOT
# pelar DET case
# mão NOUN obl
# , PUNCT punct
# pé NOUN obl
# antar ADP advmod
# pé NOUN fixed
# , PUNCT punct
# o ADP case
# um DET det
# quartar ADJ obl
# forrar VERB acl
# de ADP case
# setim PROPN nmod
# côr PROPN flat:name
#
#  SPACE
# de ADP case
# rosar NOUN nmod
# , PUNCT punct
# um DET det
# quartar NOUN obj
# dignar ADJ amod
# de SCONJ mark
# servir VERB xcomp
# de ADP case
# habitação NOUN obl
# á DET case
# fadar NOUN nmod
# mais ADV advmod
# lindo ADJ amod
# que PRON mark
#
#  SPACE
# umar DET det
# phantasia NOUN obj
# de ADP case
# poetar NOUN nmod
# oriental ADJ amod
# haver AUX aux
# imaginar VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# N'aquelle PROPN nsubj
# quartar PROPN flat:name
# haver VERB ROOT
# um DET det
# ninhar NOUN obj
# todo ADV advmod
# branco ADJ amod
# fazer VERB acl
# de ADP case
# render NOUN obl
# , PUNCT punct
# de ADP case
# fito NOUN nmod
# de ADP case
#
#  SPACE
# setim PROPN nmod
# , PUNCT punct
# de ADP case
# pennugem NOUN nmod
# de ADP case
# passaros NOUN nmod
# , PUNCT punct
# e CCONJ cc
# n'esse PROPN nsubj
# ninhar PROPN flat:name
# dormir VERB conj
# umar DET det
# creancinha NOUN obj
# que PRON nsubj
#
#  SPACE
# parecer VERB acl:relcl
# umar DET det
# rosar NOUN xcomp
# . PUNCT punct
#
#
#  SPACE
# --É PUNCT punct
# teu DET det
# primo NOUN ROOT
# ; PUNCT punct
# murmurar VERB ROOT
# baixo VERB xcomp
# o DET det
# mãe NOUN nsubj
# de ADP case
# Thadeu PROPN nmod
# , PUNCT punct
# emquanto ADV advmod
# este PRON nsubj
# , PUNCT punct
# mudar NOUN appos
# , PUNCT punct
#
#  SPACE
# surpresar ADJ amod
# , PUNCT punct
# extasiar VERB acl
# , PUNCT punct
# fitar VERB advcl
# o DET det
# seu DET det
# olho NOUN obj
# vitreos ADJ amod
# , PUNCT punct
# onde PRON obl
# o DET det
# jubilar NOUN nsubj
# acender VERB acl:relcl
#
#  SPACE
# umar DET det
# luzir NOUN obj
# desusar VERB acl
# , PUNCT punct
# o ADP case
# grande ADJ amod
# olho NOUN nmod
# luminoso ADJ amod
# e CCONJ cc
# pasmar VERB conj
# do DET case
# _ PROPN nmod
# bébé NOUN amod
# _ PROPN flat:name
# que SCONJ mark
#
#  SPACE
# acordára PROPN appos
# . PUNCT punct
#
#
#  SPACE
# Oh INTJ ROOT
# ! PUNCT punct
# comer SCONJ case
# Thadeu PROPN nsubj
# adorar VERB parataxis
# aquella DET det
# creança NOUN obj
# ! PUNCT punct
# Como ADV mark
# o DET case
# suar DET det
# vidar NOUN obl
# haver VERB ROOT
# de ADP case
#
#  SPACE
# repente ADV advmod
# um DET det
# ficto NOUN obj
# , PUNCT punct
# umar DET det
# esperançar NOUN conj
# , PUNCT punct
# umar DET det
# luzir NOUN conj
# ! PUNCT punct
#
#
#  SPACE
# Sua DET det
# tio NOUN nsubj
# , PUNCT punct
# umar DET mark
# vez NOUN fixed
# em ADP case
# que PRON obl
# o ADP det
# _ PROPN det
# bebé NOUN nsubj
# _ PROPN flat:name
# chorar VERB ccomp
# muito ADV advmod
# o ADP case
# braço NOUN obl
# da DET case
# amo VERB nmod
# , PUNCT punct
#
#  SPACE
# dizer VERB ccomp
# o ADP case
# Thadeu PROPN obj
# com ADP case
# umar DET det
# voz NOUN obl
# menos ADV advmod
# glacial ADJ amod
# do ADP mark
# que PRON fixed
# o DET det
# costumar NOUN nmod
# : PUNCT punct
#
#
#  SPACE
# --Thadeu SCONJ appos
# , PUNCT punct
# brincar VERB ROOT
# com ADP case
# o DET det
# primo NOUN obl
# o ADP det
# vêr PROPN nsubj
# se SCONJ mark
# ella ADV advmod
# se PRON expl
# calar VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# E CCONJ cc
# elle PROPN nsubj
# fazer VERB ROOT
# calar VERB xcomp
# o DET det
# rabujenta NOUN obj
# pequerrucho ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Desde ADP case
# esse DET det
# dia NOUN obl
# soube-se VERB ROOT
# que SCONJ mark
# o ADP det
# _ PROPN amod
# menino NOUN amod
# _ PROPN nsubj
# ter VERB ccomp
# o DET det
# insolito ADJ amod
# caprichar NOUN obj
# de SCONJ mark
#
#  SPACE
# adorar VERB acl
# Thadeu PROPN obj
# , PUNCT punct
# de SCONJ mark
# rir VERB advcl
# quando ADV advmod
# elle PROPN nsubj
# estar AUX cop
# de ADP case
# joelho NOUN ccomp
# dobrar VERB acl
# sobrar ADP case
# o DET det
# seu DET det
#
#  SPACE
# berço NOUN obl
# , PUNCT punct
# de SCONJ mark
# chorar VERB advcl
# quando SCONJ advmod
# alguem PRON nsubj
# o PRON obj
# levar VERB advcl
# d'alli PROPN obj
# parir ADP case
# fóra PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# A DET det
# amo VERB nsubj
# tomar VERB ROOT
# o DET det
# costumar NOUN obj
# de SCONJ mark
# o PRON obj
# chamar VERB acl
# e CCONJ cc
# de SCONJ mark
# o PRON obj
# fazer VERB conj
# estar AUX cop
# horar NOUN conj
# e CCONJ cc
# horar NOUN conj
# o SCONJ mark
#
#  SPACE
# entreter VERB advcl
# o ADP det
# _ PROPN obj
# menino NOUN amod
# _ PROPN flat:name
# . PUNCT punct
#
#
#  SPACE
# Ao DET case
# principiar NOUN obl
# elle ADJ flat:name
# fazia-lhe VERB ROOT
# carêtas NOUN obj
# e CCONJ cc
# momice PROPN conj
# , PUNCT punct
# comer ADP case
# o PRON obl
# que PRON nsubj
# usar VERB acl:relcl
# fazer VERB xcomp
#
#  SPACE
# parir SCONJ mark
# divertir VERB advcl
# seu DET det
# tio NOUN obj
# ; PUNCT punct
# depois ADV advmod
# , PUNCT punct
# sem SCONJ cc
# bem ADV fixed
# perceber VERB ROOT
# porque SCONJ mark
# , PUNCT punct
# adoptar VERB ccomp
# outro DET det
#
#  SPACE
# systema NOUN obj
# inteiramente ADV advmod
# opposto ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Percebeu VERB ROOT
# que SCONJ mark
# o DET det
# pequenino NOUN nsubj
# não ADV advmod
# querer VERB ccomp
# um DET det
# bôbo NOUN obj
# , PUNCT punct
# comer ADP case
# esse DET det
# espiritar NOUN obl
# embotar VERB acl
#
#  SPACE
# e CCONJ cc
# perverter ADJ conj
# que SCONJ mark
# o DET det
# victimára PROPN nmod
# com ADP case
# o DET det
# seu DET det
# capricho NOUN nmod
# . PUNCT punct
# O PRON det
# que PRON ROOT
# o ADP det
# _ PROPN amod
# bebé NOUN nmod
# _ PROPN ROOT
#
#  SPACE
# querer VERB csubj
# , PUNCT punct
# o DET case
# ingenuidade NOUN obl
# adoravel ADJ amod
# do DET case
# seu DET det
# despotismo NOUN nmod
# infantil ADJ amod
# , PUNCT punct
# ser AUX cop
# um DET det
#
#  SPACE
# companheiro NOUN ROOT
# de ADP case
# seu DET det
# brinquedo NOUN nmod
# , PUNCT punct
# um DET det
# socio NOUN conj
# , PUNCT punct
# um DET det
# escravo NOUN conj
# que PRON nsubj
# o PRON obj
# adorar VERB acl:relcl
# . PUNCT punct
#
#
#  SPACE
# Thadeu PROPN nsubj
# ser AUX cop
# tudo PRON ROOT
# parir ADP case
# ella PROPN nmod
# : PUNCT punct
# queria-o VERB ROOT
# perto ADV advmod
# da DET case
# grande ADJ amod
# tinir NOUN obl
# em ADP case
# que PRON obl
# tomar VERB acl:relcl
# o DET det
#
#  SPACE
# seu DET det
# banhar NOUN obj
# de ADP case
# manhã NOUN nmod
# ; PUNCT punct
# queria-o VERB ROOT
# juntar ADV advmod
# da DET case
# pequeno ADJ amod
# mesa NOUN obl
# de ADP case
# nacar VERB nmod
# onde PRON obl
# o PRON obj
# amo VERB acl:relcl
#
#  SPACE
# lhe PRON iobj
# dar VERB ROOT
# o DET det
# sopa NOUN obj
# ; PUNCT punct
# queria-o VERB ROOT
# o DET case
# berço NOUN obl
# ao DET mark
# adormecer VERB advcl
# ; PUNCT punct
# queria-o VERB ROOT
# o DET case
#
#  SPACE
# jardim NOUN obl
# , PUNCT punct
# á DET case
# sombra NOUN conj
# das DET case
# arvorar NOUN nmod
# , PUNCT punct
# sobrar ADP case
# o DET det
# arêa NOUN obl
# finissima ADJ amod
# , PUNCT punct
# onde PRON obl
# se PRON expl
# rolar VERB acl:relcl
# , PUNCT punct
#
#  SPACE
# vestir VERB acl
# de ADP case
# render NOUN obl
# branco ADJ amod
# , PUNCT punct
# o SCONJ mark
# rir VERB advcl
# comer ADP case
# umar DET det
# perdido NOUN xcomp
# . PUNCT punct
#
#
#  SPACE
# Chamaram-lhe DET ROOT
# Margarida PROPN obj
# . PUNCT punct
#
#
#  SPACE
# Margarida PROPN nsubj
# querer VERB ROOT
# dizer VERB xcomp
# perolar NOUN obj
# , PUNCT punct
# e CCONJ cc
# Thadeu PROPN nsubj
# , PUNCT punct
# que PRON nsubj
# virar VERB acl:relcl
# muito DET case
# vezar NOUN obl
# suar DET det
# tio NOUN obj
#
#  SPACE
# vestir VERB acl
# de ADP case
# bailar NOUN obl
# , PUNCT punct
# achar VERB conj
# um DET det
# nome NOUN obj
# muito ADV advmod
# bem ADV advmod
# postar NOUN xcomp
# áquella PROPN appos
# creança PROPN flat:name
# branco ADJ amod
# , PUNCT punct
#
#  SPACE
# transparentar ADJ amod
# , PUNCT punct
# louro NOUN conj
# , PUNCT punct
# idealmente ADV advmod
# gracioso ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Oh INTJ ROOT
# ! PUNCT punct
# Thadeu PROPN nsubj
# ainda ADV advmod
# andar VERB ROOT
# muito DET advmod
# vez NOUN fixed
# vestir VERB xcomp
# de ADP case
# marujar NOUN nmod
# , PUNCT punct
# de ADP case
# granadeiro NOUN conj
# , PUNCT punct
# de ADP mark
#
#  SPACE
# tyrolez PROPN xcomp
# e CCONJ cc
# de ADP case
# alferes NOUN conj
# , PUNCT punct
# ainda ADV advmod
# o PRON obj
# introduzir VERB advcl
# o DET case
# cofre NOUN obl
# da DET case
# lenhar NOUN nmod
# , PUNCT punct
# ainda ADV advmod
# o DET nsubj
#
#  SPACE
# fazer VERB conj
# fumar VERB xcomp
# um DET det
# charuto NOUN obj
# depois ADV mark
# de ADP fixed
# jantar NOUN advcl
# , PUNCT punct
# cheio ADJ conj
# de ADP case
# ancias NOUN obl
# , PUNCT punct
# de ADP case
# nauseas NOUN nmod
# , PUNCT punct
#
#  SPACE
# de ADP case
# grito NOUN nmod
# abafar VERB acl
# de ADP case
# angustiar NOUN nmod
# ! PUNCT punct
# ... PUNCT punct
# Mas CCONJ cc
# que PRON nsubj
# importar VERB ROOT
# ! PUNCT punct
#
#
#  SPACE
# Logo ADV advmod
# que SCONJ fixed
# poder VERB advcl
# escapava-se VERB xcomp
# parir ADP case
# o DET det
# quartar NOUN obl
# da DET case
# fadar NOUN nmod
# , PUNCT punct
# parir ADP case
# o DET det
# estojar NOUN obl
# côr NOUN appos
# de ADP case
#
#  SPACE
# rosar ADJ nmod
# da DET case
# suar DET det
# _ PROPN nmod
# perolar PROPN flat:name
# _ PROPN flat:name
# , PUNCT punct
# da DET case
# suar DET det
# Margarida PROPN nmod
# , PUNCT punct
# e CCONJ cc
# então ADV advmod
# ser AUX cop
# risada NOUN conj
# sem ADP case
# fim NOUN obl
# , PUNCT punct
#
#  SPACE
# ser AUX cop
# corrido NOUN nsubj
# delirante ADJ amod
# por ADP case
# sobrar ADP case
# o DET det
# tapetar NOUN nmod
# , PUNCT punct
# ser AUX cop
# um DET det
# papaguear VERB ROOT
# de ADP case
# dois NUM nummod
#
#  SPACE
# ave NOUN obj
# feliz ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Margarida NOUN nsubj
# com ADP case
# o DET det
# idade NOUN nmod
# ia-se VERB ROOT
# fazer VERB advcl
# despotica NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Pudera VERB ROOT
# ! PUNCT punct
#
#
#  SPACE
# Ou CCONJ cc
# ella PROPN nsubj
# não ADV advmod
# ser AUX cop
# mulher NOUN ROOT
# , PUNCT punct
# e CCONJ cc
# estremecido VERB conj
# pelar DET case
# seu DET det
# humildar ADJ amod
# escravo NOUN obl:agent
# ! PUNCT punct
#
#
#  SPACE
# Mas CCONJ cc
# ser VERB ROOT
# assim ADV advmod
# mesmo ADV advmod
# que SCONJ mark
# elle ADV nsubj
# o PRON obj
# querer VERB ccomp
# . PUNCT punct
#
#
#  SPACE
# Quando ADV mark
# o DET det
# mãosinhas ADJ amod
# polpudo NOUN nsubj
# e CCONJ cc
# branco ADJ conj
# de ADP case
# Margarida PROPN nmod
# lhe PRON iobj
# bater VERB advcl
# , PUNCT punct
# Thadeu PROPN nsubj
#
#  SPACE
# sentia-se VERB ROOT
# feliz ADJ xcomp
# comer ADP case
# um DET det
# rei NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Quando SCONJ advmod
# ella VERB nsubj
# o PRON obj
# obrigar VERB advcl
# o SCONJ mark
# agachar-se VERB xcomp
# o DET case
# chão NOUN obl
# parir SCONJ mark
# lhe PRON iobj
# servir VERB advcl
# de ADP case
# jumento NOUN obl
# , PUNCT punct
#
#  SPACE
# o DET det
# rapaz NOUN nsubj
# ter VERB ROOT
# tentação NOUN obj
# de ADP case
# rinchar PROPN nmod
# de ADP case
# prazer NOUN nmod
# , PUNCT punct
# fazer VERB advcl
# o DET det
# passar NOUN obj
# bem ADV advmod
# ao DET case
#
#  SPACE
# viver ADJ obj
# . PUNCT punct
#
#
#  SPACE
# Porque SCONJ mark
# o DET case
# fim NOUN fixed
# de ADP compound
# contar NOUN nmod
# , PUNCT punct
# apezar PROPN advcl
# de ADP case
# todo DET det
# o DET fixed
# suar DET det
# adoraveis ADJ amod
# crueldade NOUN obj
# , PUNCT punct
#
#  SPACE
# Margarida PROPN nsubj
# gostar VERB ROOT
# d'elle NOUN obj
# . PUNCT punct
#
#
#  SPACE
# A DET det
# presença NOUN nsubj
# de ADP case
# Thadeu PROPN nmod
# illuminava VERB ROOT
# de ADP case
# riso NOUN obl
# o DET det
# seu DET det
# rostir NOUN obj
# oval ADJ amod
# coroar PROPN obj
# de ADP case
#
#  SPACE
# cabellos NOUN nmod
# louro ADJ amod
# annellados VERB flat:name
# , PUNCT punct
# o DET det
# seu DET det
# rostir NOUN appos
# o ADP case
# um DET det
# tempo NOUN nmod
# angelico ADJ amod
# e CCONJ cc
# gaiatar NOUN conj
# ! PUNCT punct
#
#
#  SPACE
# Margarida PROPN nsubj
# não ADV advmod
# o PRON obj
# achar VERB ROOT
# feio ADJ xcomp
# , PUNCT punct
# nem CCONJ cc
# tolo NOUN conj
# , PUNCT punct
# nem CCONJ cc
# ridiculo NOUN conj
# , PUNCT punct
# nem CCONJ cc
# doente ADJ conj
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# desprezar VERB ROOT
# o DET det
# fraqueza NOUN obj
# dos ADP case
# seu DET det
# braço NOUN nmod
# , PUNCT punct
# nem CCONJ cc
# o DET det
# pobreza NOUN conj
# absoluto ADJ amod
# da DET case
# suar DET det
#
#  SPACE
# imaginação NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Pelo DET case
# contrariar NOUN ROOT
# ! PUNCT punct
# Admirava VERB ROOT
# o DET obj
# ! PUNCT punct
#
#
#  SPACE
# Sim ADV ROOT
# ; PUNCT punct
# ella PROPN nsubj
# dera-lhe VERB parataxis
# esse DET det
# sensação NOUN obj
# poderoso ADJ amod
# e CCONJ cc
# extraordinaria ADJ conj
# , PUNCT punct
# o DET det
# sensação NOUN parataxis
#
#  SPACE
# dos PRON nmod
# que PRON nsubj
# se PRON expl
# ver VERB acl:relcl
# admirar NOUN xcomp
# com ADP case
# ingenua ADJ amod
# confiança NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Margarida PROPN nsubj
# pedia-lhe VERB ROOT
# cousa NOUN obj
# enorme ADJ amod
# , PUNCT punct
# com ADP case
# umar DET det
# serenidade NOUN obl
# ineffavel ADJ amod
# de ADP case
#
#  SPACE
# crente ADJ nmod
# ! PUNCT punct
#
#
#  SPACE
# Pedira-lhe DET case
# um DET det
# ninhar NOUN ROOT
# de ADP case
# melro NOUN nmod
# , PUNCT punct
# e CCONJ cc
# o PRON conj
# que PRON nsubj
# ser AUX cop
# mais ADV acl:relcl
# ! PUNCT punct
# conseguir VERB ROOT
# que SCONJ mark
# elle VERB nsubj
# tão ADV advmod
#
#  SPACE
# medroso ADJ amod
# , PUNCT punct
# tão ADV advmod
# debil VERB ccomp
# , PUNCT punct
# tão ADV advmod
# assustar ADJ conj
# , PUNCT punct
# trepar VERB nsubj
# pelos ADP case
# braço NOUN nmod
# nodoso ADJ amod
# de ADP case
# umar NUM nummod
#
#  SPACE
# grande ADJ amod
# arvorar NOUN nmod
# e CCONJ cc
# lh'o PROPN conj
# ser AUX cop
# buscar VERB advcl
# lá ADV advmod
# cima ADP obj
# . PUNCT punct
#
#
#  SPACE
# Que SCONJ nsubj
# triumpho PROPN ROOT
# este DET det
# d'ella PROPN obj
# , PUNCT punct
# ao SCONJ mark
# ver VERB advcl
# satisfazer NOUN xcomp
# o DET det
# seu DET det
# caprichar NOUN obj
# ! PUNCT punct
# mas CCONJ cc
# que PRON mark
#
#  SPACE
# triumpho PROPN punct
# maior ADJ ROOT
# ainda ADV advmod
# o DET det
# d'elle NOUN obl
# ao DET case
# comprehender PROPN obl
# , PUNCT punct
# que PRON nsubj
# alcançar VERB acl:relcl
# esse DET det
# cousa NOUN obj
#
#  SPACE
# prodigioso ADJ amod
# , PUNCT punct
# que PRON nsubj
# nem CCONJ cc
# o ADP case
# sonho NOUN acl:relcl
# mais ADV advmod
# arrojar ADJ amod
# das DET case
# suar DET det
# noite NOUN obl
# de ADP case
# febre NOUN nmod
#
#  SPACE
# elle PROPN nsubj
# ousar VERB ROOT
# até ADP case
# ali ADV advmod
# conceber VERB xcomp
# ! PUNCT punct
#
#
#  SPACE
# Um NUM nummod
# dia NOUN nmod
# Margarida PROPN appos
# , PUNCT punct
# em ADP case
# frente NOUN nmod
# d'aquelle PROPN nummod
# rasgar NOUN obl
# assombroso ADJ amod
# de ADP case
# valentia NOUN nmod
# que PRON nsubj
#
#  SPACE
# collocara ADP nmod
# Thadeu PROPN flat:name
# ao DET case
# lado NOUN nmod
# dos ADP case
# maior ADJ amod
# heroes NOUN nmod
# , PUNCT punct
# puzera VERB nsubj
# se PRON expl
# gravar VERB ccomp
# , PUNCT punct
#
#  SPACE
# meditativo NOUN conj
# , PUNCT punct
# e CCONJ cc
# apontar VERB conj
# com ADP case
# sereno ADJ amod
# magestade NOUN obl
# parir ADP case
# o DET det
# lua NOUN obl
# que PRON nsubj
# se PRON expl
# reflectir VERB acl:relcl
#
#  SPACE
# n'um ADP case
# tanque NOUN nmod
# do DET case
# jardim NOUN nmod
# , PUNCT punct
# pedir VERB ROOT
# o DET det
# lua NOUN obj
# ao DET case
# seu DET det
# amigar NOUN iobj
# Thadeu PROPN appos
# ! PUNCT punct
#
#
#  SPACE
# Está AUX cop
# claro ADJ ROOT
# que SCONJ mark
# elle PROPN nsubj
# lh'a PROPN flat:name
# não ADV advmod
# poder VERB csubj
# dar VERB xcomp
# , PUNCT punct
# mas CCONJ cc
# gostar VERB conj
# d'aquillo ADV obj
# ! PUNCT punct
#
#
#  SPACE
# Percebeu VERB ROOT
# que SCONJ mark
# o PRON obj
# julgar VERB ccomp
# capaz ADJ xcomp
# de ADP case
# cousa NOUN nmod
# grande ADJ amod
# , PUNCT punct
# de SCONJ mark
# levar VERB advcl
# o ADP case
# cabo NOUN obl
#
#  SPACE
# emprezas NOUN appos
# impossiveis ADJ amod
# , PUNCT punct
# e CCONJ cc
# este DET det
# idéa NOUN conj
# que SCONJ mark
# alguem ADV nsubj
# ter VERB acl:relcl
# da DET case
# suar DET det
# forçar NOUN obj
# , PUNCT punct
# fê-lo VERB ccomp
#
#  SPACE
# crescer VERB ROOT
# aos ADP case
# seu DET det
# proprios ADJ amod
# olho NOUN obj
# . PUNCT punct
#
#
#  SPACE
# O DET det
# marquez NOUN nsubj
# conhecer VERB ROOT
# que SCONJ mark
# o DET det
# pequeno ADJ amod
# deixára NOUN nsubj
# de SCONJ mark
# ser AUX cop
# seu DET det
# joguetar NOUN acl
# , PUNCT punct
#
#  SPACE
# simplesmente ADV advmod
# parir SCONJ mark
# ser AUX cop
# joguetar NOUN ccomp
# de ADP case
# suar DET det
# filho NOUN nmod
# e CCONJ cc
# herdeiro PROPN conj
# , PUNCT punct
# applaudiu-se VERB ccomp
# de ADP mark
#
#  SPACE
# lhe PRON iobj
# haver AUX aux
# dar VERB xcomp
# aquella DET det
# educação NOUN obj
# especial ADJ amod
# , PUNCT punct
# e CCONJ cc
# prohibiu PROPN conj
# que SCONJ mark
# o DET det
# distrahissem NOUN nsubj
# , PUNCT punct
#
#  SPACE
# ser AUX cop
# sob ADP case
# que SCONJ fixed
# pretextar NOUN nsubj
# ser VERB cop
# , PUNCT punct
# das DET case
# suar DET det
# novo ADJ amod
# funcções NOUN ccomp
# . PUNCT punct
#
#
#  SPACE
# Margarida PROPN nsubj
# ser AUX cop
# ainda ADV advmod
# muito ADV advmod
# pequenino ADJ ROOT
# parir SCONJ mark
# entreter VERB advcl
# o DET det
# paes PROPN obj
# . PUNCT punct
#
#
#  SPACE
# Elle PROPN nsubj
# precisar VERB ROOT
# das DET case
# excitação NOUN obj
# da DET case
# politicar NOUN nmod
# , PUNCT punct
# das DET case
# luctas NOUN nmod
# do DET case
# parlamentar NOUN nmod
# , PUNCT punct
# dos ADP case
#
#  SPACE
# sorriso NOUN nmod
# falso ADJ amod
# ou CCONJ cc
# verdadeiro ADJ conj
# , PUNCT punct
# caro ADJ conj
# ou CCONJ cc
# barato ADJ conj
# das DET case
# formoso ADJ amod
# mulher NOUN nmod
# , PUNCT punct
#
#  SPACE
# do DET case
# jogar NOUN conj
# , PUNCT punct
# da DET case
# ambição NOUN conj
# , PUNCT punct
# do DET case
# amor NOUN nmod
# , PUNCT punct
# da DET case
# violencia NOUN conj
# corrosivo ADJ amod
# de ADP case
# todo DET det
# o DET fixed
#
#  SPACE
# pequeno ADJ amod
# e CCONJ cc
# grande ADJ conj
# paixão NOUN nmod
# ! PUNCT punct
#
#
#  SPACE
# Ella PROPN nsubj
# precisar VERB ROOT
# do DET case
# luxar NOUN obj
# , PUNCT punct
# das DET case
# joias NOUN obj
# que PRON mark
# scintillam VERB nmod
# , PUNCT punct
# das DET case
# sedar NOUN nmod
# que PRON nsubj
# se PRON expl
#
#  SPACE
# quebrar VERB acl:relcl
# em ADP case
# ondulação NOUN obl
# brilhante ADJ amod
# , PUNCT punct
# do DET case
# côro NOUN obj
# das DET case
# adulação NOUN nmod
# mentir VERB acl
# , PUNCT punct
# de ADP case
#
#  SPACE
# todo DET det
# o DET fixed
# ephemeras ADJ amod
# alegria NOUN obj
# que PRON nsubj
# só ADV advmod
# o DET det
# mundo NOUN nsubj
# lhe PRON iobj
# poder VERB acl:relcl
# dar VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# Para ADP case
# ambos DET det
# Margarida PROPN nmod
# seriar AUX cop
# um DET det
# remorso NOUN ROOT
# , PUNCT punct
# se SCONJ mark
# o SCONJ obj
# não ADV advmod
# ver VERB advcl
# tão ADV advmod
# nedia ADJ obj
# , PUNCT punct
# tão ADV advmod
#
#  SPACE
# roliço ADJ conj
# , PUNCT punct
# tão ADV advmod
# alegrar ADJ conj
# , PUNCT punct
# com ADP case
# chispa NOUN obl
# de ADP case
# travessura NOUN nmod
# malicioso ADJ amod
# o DET case
# olhar NOUN nmod
# , PUNCT punct
# sempre ADV advmod
#
#  SPACE
# acompanhar VERB advcl
# do DET case
# seu DET det
# pequeno ADJ amod
# amigar NOUN obj
# , PUNCT punct
# submisso ADJ conj
# e CCONJ cc
# fiel ADJ conj
# comer ADP case
# um DET det
# cão NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Deixaram-os INTJ ROOT
# , PUNCT punct
# pois SCONJ advmod
# , PUNCT punct
# crescer VERB advcl
# e CCONJ cc
# viver VERB conj
# junto ADV advmod
# sob ADP case
# o DET det
# olhar NOUN obl
# das DET case
# aio NOUN nmod
# , PUNCT punct
# sempre ADV advmod
#
#  SPACE
# um DET advmod
# pouco ADV fixed
# hostil ADJ amod
# parir ADP case
# Thadeu PROPN obl
# e CCONJ cc
# por ADP case
# isso PRON conj
# tanto NOUN advmod
# mais ADV advmod
# insuspeito ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Foi AUX cop
# o DET det
# verdadeiro ADJ amod
# paraiso NOUN nsubj
# que PRON obj
# este PRON nsubj
# conhecer VERB acl:relcl
# o DET case
# terra NOUN obl
# , PUNCT punct
# ser AUX cop
# o DET det
# suar DET det
# idade NOUN ROOT
# de ADP case
#
#  SPACE
# ourar NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Ha PROPN ROOT
# ente ADJ flat:name
# que PRON nsubj
# nunca ADV advmod
# nem ADV cc
# por ADP case
# um DET det
# instante NOUN obl
# só ADV advmod
# conhecer VERB acl:relcl
# o DET det
# completar ADJ amod
# venturo NOUN obj
# . PUNCT punct
#
#
#  SPACE
# São AUX cop
# de ADP case
# todo DET det
# o DET fixed
# mais ADV advmod
# desgraçar VERB ROOT
# . PUNCT punct
#
#
#  SPACE
# Thadeu PROPN nsubj
# mais ADV advmod
# tardar ADV advmod
# poder VERB ROOT
# ao DET case
# menos NOUN obl
# recordar-se VERB xcomp
# ! PUNCT punct
#
#
#  SPACE
# E CCONJ cc
# elle PROPN nsubj
# saber VERB ROOT
# apreciar VERB xcomp
# tão ADV advmod
# bem ADV advmod
# aquellas DET det
# alegria NOUN obj
# que PRON nsubj
# em ADP case
# manhã NOUN obl
# abençoar ADJ acl:relcl
#
#  SPACE
# ter AUX aux
# cahido VERB ccomp
# sobrar ADP case
# o DET det
# suar DET det
# pobre ADJ amod
# cabeça NOUN obl
# ! PUNCT punct
# ... PUNCT punct
#
#
#  SPACE
# Um NUM nummod
# dia NOUN obl
# Margarida PROPN appos
# travesso PROPN flat:name
# e CCONJ cc
# caprichoso ADJ conj
# comer ADV advmod
# ser VERB acl:relcl
# , PUNCT punct
# desattendendo VERB advcl
# todo DET det
# o DET fixed
#
#  SPACE
# advertencias NOUN obj
# de ADP case
# Thadeu PROPN nmod
# , PUNCT punct
# deixara-se VERB ROOT
# cahir VERB xcomp
# dentro ADV advmod
# do DET case
# tanque NOUN obl
# do DET case
# jardim NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# O DET det
# pequeno NOUN nsubj
# não ADV advmod
# saber VERB ROOT
# nadar VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# Que PRON nsubj
# importar VERB ROOT
# ! PUNCT punct
#
#
#  SPACE
# Sem ADP case
# premeditação NOUN obl
# , PUNCT punct
# sem ADP case
# raciocinio NOUN nmod
# , PUNCT punct
# obedecer VERB acl
# o ADP case
# um DET det
# instincto NOUN obj
# de ADP case
# dedicação NOUN nmod
#
#  SPACE
# inteiramente ADV advmod
# canino NOUN amod
# , PUNCT punct
# deitou-se VERB ROOT
# n'agua PROPN obj
# atrás ADP case
# d'ella NOUN obl
# . PUNCT punct
#
#
#  SPACE
# As DET det
# criar NOUN nsubj
# , PUNCT punct
# acudir VERB advcl
# , PUNCT punct
# tirar VERB ROOT
# do DET case
# tanque NOUN obj
# o DET det
# dois NUM nummod
# creanças NOUN obj
# abraçar VERB acl
# . PUNCT punct
#
#
#  SPACE
# Imagine-se VERB ROOT
# o PRON det
# que PRON nsubj
# iriar VERB ccomp
# em ADP case
# casar NOUN obl
# ! PUNCT punct
#
#
#  SPACE
# Thadeu PROPN nsubj
# , PUNCT punct
# castigar VERB acl
# severamente ADV advmod
# , PUNCT punct
# não ADV advmod
# quiz AUX aux
# condemnar VERB ROOT
# o DET det
# suar DET det
# amigo NOUN obj
# , PUNCT punct
# parir ADP mark
#
#  SPACE
# se PRON expl
# salvar VERB advcl
# o ADP case
# si PRON obj
# . PUNCT punct
#
#
#  SPACE
# Foi AUX cop
# ella PROPN nsubj
# que SCONJ mark
# , PUNCT punct
# soberbo NOUN obl
# , PUNCT punct
# gracioso ADJ acl:relcl
# , PUNCT punct
# com ADP case
# o DET det
# suar DET det
# magestade NOUN obl
# de ADP case
# pequeno ADJ amod
# rei NOUN nmod
# , PUNCT punct
#
#  SPACE
# dizer VERB ROOT
# aos ADP case
# paes PROPN obj
# : PUNCT punct
#
#
#  SPACE
# --Não CCONJ cc
# bater VERB parataxis
# n'elle PROPN punct
# . PUNCT punct
# Elle PROPN nsubj
# pediu-me VERB ROOT
# que SCONJ mark
# não ADV advmod
# ser VERB ccomp
# . PUNCT punct
# Eu PRON nsubj
# ser AUX discourse
# que SCONJ fixed
# quiz AUX aux
# ir VERB ROOT
# . PUNCT punct
#
#
#  SPACE
# Acharam-na VERB ROOT
# adoravel ADJ amod
# ; PUNCT punct
# encheram-na VERB parataxis
# de ADP case
# cariciar NOUN obj
# e CCONJ cc
# de ADP case
# gulodice NOUN conj
# , PUNCT punct
# mas CCONJ cc
# ninguem PROPN conj
#
#  SPACE
# pensar VERB ROOT
# o DET case
# acção NOUN obl
# tão ADV advmod
# simples ADJ amod
# e CCONJ cc
# tão ADV advmod
# heroica ADJ conj
# do DET case
# pequeno ADJ amod
# Thadeu PROPN obl
# , PUNCT punct
# o ADP case
# quem PRON obl
#
#  SPACE
# ter AUX ROOT
# postar VERB obj
# o DET case
# alcunhar NOUN obj
# de ADP case
# _ PROPN nmod
# medroso PROPN amod
# _ PROPN flat:name
# . PUNCT punct
#
#
#
#  SPACE
# III ADJ ROOT
#
#
#  SPACE
# Foi SCONJ ROOT
# assim ADV advmod
# que SCONJ mark
# Margarida PROPN nsubj
# fazer VERB advcl
# nove NUM nummod
# annos PROPN obj
# . PUNCT punct
#
#
#  SPACE
# Era AUX cop
# lindo ADJ ROOT
# e CCONJ cc
# indomita NOUN conj
# . PUNCT punct
#
#
#  SPACE
# Tinha VERB ROOT
# um DET det
# corpo NOUN obj
# airoso ADJ amod
# , PUNCT punct
# flexivel ADJ conj
# e CCONJ cc
# forte ADJ conj
# . PUNCT punct
#
#
#  SPACE
# Ninguem PROPN nsubj
# opprimira ADV amod
# nunca ADV advmod
# aquella DET det
# altivo ADJ amod
# natureza NOUN ROOT
# aristocratica ADJ amod
# . PUNCT punct
#
#
#  SPACE
# D'ahi PROPN ROOT
# o DET det
# suar DET det
# isenção NOUN obj
# , PUNCT punct
# o DET det
# liberdade NOUN conj
# dos ADP case
# seu DET det
# movimento NOUN nmod
# , PUNCT punct
# o DET det
# fulgor NOUN conj
# radioso ADJ amod
#
#  SPACE
# dos ADP case
# seu DET det
# grande ADJ amod
# olho NOUN nmod
# azues PROPN appos
# , PUNCT punct
# onde PRON obl
# um DET det
# observador NOUN nsubj
# ver VERB acl:relcl
# talvez ADV advmod
# o DET det
#
#  SPACE
# scintillações NOUN obj
# metallicas ADJ amod
# que PRON nsubj
# dar VERB acl:relcl
# tamanho ADJ amod
# dureza NOUN obj
# ao DET case
# olhar NOUN obl
# de ADP case
# suar DET det
# mãe NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Margarida PROPN nsubj
# ter VERB ROOT
# umar DET det
# vontade NOUN obj
# de ADP case
# ferrar NOUN nmod
# , PUNCT punct
# e CCONJ cc
# um DET det
# nervo NOUN conj
# de ADP case
# mulher NOUN obl
# caprichoso ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Quando SCONJ mark
# o DET det
# professorar NOUN nsubj
# allemã PROPN amod
# que PRON obj
# seu DET det
# paes PROPN nsubj
# mandar VERB acl:relcl
# buscar VERB xcomp
# , PUNCT punct
# quiz AUX aux
# sujeitar VERB advcl
#
#  SPACE
# o DET det
# seu DET det
# espiritar NOUN obj
# o ADP case
# umar DET det
# certo DET det
# disciplinar NOUN nmod
# , PUNCT punct
# Margarida PROPN nsubj
# revoltou-se VERB ROOT
# n'um ADP case
# impeto NOUN obj
#
#  SPACE
# de ADP case
# insubordinação NOUN nmod
# selvatica ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Tivera VERB aux
# criar NOUN ROOT
# que SCONJ mark
# o PRON obj
# servir VERB ccomp
# , PUNCT punct
# um DET det
# escravo NOUN appos
# que PRON nsubj
# tremer VERB acl:relcl
# diante ADV case
# d'ella PROPN obl
# , PUNCT punct
# e CCONJ cc
#
#  SPACE
# paes PROPN conj
# que PRON nsubj
# transigir VERB acl:relcl
# com ADP case
# todo DET det
# o DET fixed
# seu DET det
# pequeno ADJ amod
# desejo NOUN obj
# de ADP case
# creança NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Dera-se VERB ROOT
# bem ADV advmod
# n'aquelle PROPN dep
# mear PROPN flat:name
# , PUNCT punct
# não ADV advmod
# querer VERB ROOT
# outro PRON obj
# , PUNCT punct
# não ADV advmod
# o PRON obj
# aceitar VERB conj
# , PUNCT punct
# nem CCONJ cc
#
#  SPACE
# curvar VERB conj
# o DET det
# suar DET det
# cabeça NOUN obj
# erecto ADJ amod
# e CCONJ cc
# firmar ADJ conj
# com ADP case
# umar DET det
# aureolar NOUN obl
# de ADP case
# anneis NOUN nmod
# de ADP case
#
#  SPACE
# ourar NOUN nmod
# o SCONJ case
# cerca-la VERB nmod
# , PUNCT punct
# o ADP case
# nenhum DET det
# dominio NOUN obl
# que PRON nsubj
# não ADV advmod
# ser AUX cop
# o PRON acl:relcl
# da DET case
# suar DET det
# vontade NOUN nmod
# . PUNCT punct
#
#
#         SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT ROOT
#
#
#  SPACE
# Um NUM nummod
# dia NOUN obl
# Thadeu PROPN nsubj
# ouvir VERB ROOT
# fallar PROPN obj
# vagamente ADV advmod
# n'uma PUNCT case
# viagem NOUN obj
# que PRON obj
# seu DET det
# tio NOUN nsubj
# ir AUX aux
#
#  SPACE
# fazer VERB acl:relcl
# ao DET case
# estrangeirar NOUN iobj
# , PUNCT punct
# e CCONJ cc
# ver VERB conj
# começar VERB xcomp
# o DET det
# preparativo NOUN obj
# parir ADP case
# ella PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# Ficou VERB ROOT
# o DET case
# céo NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Viveria VERB ROOT
# só ADV advmod
# o DET case
# grande ADJ amod
# casar NOUN obl
# com ADP case
# Margarida PROPN obl
# e CCONJ cc
# o DET det
# rancho PROPN conj
# dos ADP case
# criar PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# Seriam AUX cop
# livre ADJ ROOT
# . PUNCT punct
#
#
#  SPACE
# Ella PROPN nsubj
# ter VERB ROOT
# um DET det
# balouçar NOUN obj
# o DET case
# jardim NOUN obl
# , PUNCT punct
# umar DET det
# redar NOUN obj
# brazileira ADJ amod
# o DET case
# kiosque PROPN nmod
# , PUNCT punct
# e CCONJ cc
# um NUM det
#
#  SPACE
# barco NOUN conj
# o DET case
# lago NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Eram AUX cop
# o DET det
# seu DET det
# tres ADJ amod
# sonho NOUN ROOT
# ainda ADV advmod
# irrealizados VERB acl
# . PUNCT punct
#
#
#  SPACE
# Thadeu PROPN nsubj
# dirigir VERB ROOT
# todo DET det
# o DET fixed
# trabalho NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Diria VERB ROOT
# aos ADP case
# operarios NOUN obj
# que PRON nsubj
# ter VERB acl:relcl
# dezeseis NUM nummod
# annos NOUN obj
# , PUNCT punct
# e CCONJ cc
# que PRON nsubj
# ser AUX cop
# sobrinho NOUN conj
# do DET case
#
#  SPACE
# marquez NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Os DET det
# operarios NOUN nsubj
# haver VERB ROOT
# de SCONJ case
# respeital-o VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# Elles PROPN nsubj
# não ADV advmod
# ter VERB ROOT
# precisão NOUN obj
# nenhum DET det
# de SCONJ mark
# se PRON nsubj
# rir VERB acl
# do DET case
# seu DET det
# corpo NOUN obj
# enfezar VERB acl
# e CCONJ cc
#
#  SPACE
# rachitico ADV conj
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# ser AUX cop
# precisar ADJ ROOT
# ser-se VERB cop
# athletico ADV csubj
# parir SCONJ mark
# se SCONJ mark
# ser AUX aux:pass
# respeitar VERB advcl
# pelos ADP case
# homem NOUN obl:agent
# o DET mark
#
#  SPACE
# quem PRON nsubj
# se PRON expl
# pago VERB acl
# . PUNCT punct
#
#
#  SPACE
# Thadeu PROPN nsubj
# haver VERB ROOT
# de SCONJ mark
# arranjar VERB xcomp
# algum DET det
# mear NOUN obl
# de SCONJ mark
# lhe PRON iobj
# pagar VERB acl
# . PUNCT punct
#
#
#  SPACE
# Andava VERB ROOT
# então ADV advmod
# doente ADJ xcomp
# , PUNCT punct
# exquisito ADJ conj
# , PUNCT punct
# com ADP case
# umar DET det
# excitação NOUN obl
# ...
# toilette NOUN amod
# _ PROPN amod
# , PUNCT punct
# de ADP case
# pequeno ADJ amod
# intrigar NOUN nmod
# , PUNCT punct
# de ADP case
# namoro NOUN nmod
# , PUNCT punct
# de ADP case
#
#  SPACE
# vicios NOUN obj
# mesquinho ADJ amod
# , PUNCT punct
# de ADP case
# invejar NOUN nmod
# e CCONJ cc
# de ADP case
# tagarelice NOUN conj
# ; PUNCT punct
# atravessar VERB ROOT
# o DET det
# mundo NOUN obj
# com ADP case
#
#  SPACE
# o DET det
# olho NOUN obl
# fito VERB acl
# n'outros NOUN nummod
# olho ADJ appos
# , PUNCT punct
# com ADP case
# o DET det
# mão NOUN nmod
# enlaçar VERB acl
# n'outras ADJ nmod
# mão NOUN compound
# , PUNCT punct
# com ADP case
#
#  SPACE
# o DET det
# almo NOUN obl
# o ADP case
# cantar-lhes NOUN nmod
# um DET det
# _ PROPN ROOT
# hosanna PROPN flat:name
# _ PROPN flat:name
# de ADP case
# mysticos ADJ nmod
# arroubo NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE
# Se SCONJ mark
# querer VERB advcl
# estudar VERB xcomp
# o DET det
# escaninho NOUN obj
# caprichoso ADJ amod
# de ADP case
# um DET det
# coração NOUN nmod
# de ADP case
# mulher NOUN nmod
#
#  SPACE
# bonito ADJ amod
# e CCONJ cc
# garrir VERB conj
# , PUNCT punct
# não ADV advmod
# o DET obj
# procurar NOUN ROOT
# , PUNCT punct
# mas CCONJ cc
# tambem PROPN conj
# lhe PRON iobj
# não ADV advmod
# pedir NOUN xcomp
# que PRON nsubj
# te VERB obj
#
#  SPACE
# fallem VERB acl:relcl
# o ADP case
# nosso DET det
# piedoso NOUN obl
# e CCONJ cc
# obscuro ADJ det
# dever NOUN conj
# de ADP case
# todo DET det
# o ADP fixed
# dia NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# São AUX cop
# o DET det
# hallucinadas NOUN ROOT
# do DET case
# amor NOUN nmod
# ! PUNCT punct
# Arrastou-as VERB ROOT
# umar DET det
# tempestade NOUN obj
# parir ADP case
# outro PRON det
#
#  SPACE
# espheras NOUN ROOT
# ardente ADJ amod
# onde PRON obl
# se SCONJ nsubj
# não ADV advmod
# viver VERB acl:relcl
# o DET det
# vidar NOUN obj
# que PRON obj
# conhecer VERB acl:relcl
# ! PUNCT punct
#
#
#  SPACE
# Vê VERB ROOT
# tu INTJ ROOT
# -- PUNCT punct
# Esmeralda PROPN parataxis
# ! PUNCT punct
# que SCONJ mark
# bem ADV advmod
# postar ADJ ROOT
# nome ADJ obj
# ! PUNCT punct
#
#
#  SPACE
# Toda PROPN det
# ella PROPN ROOT
# scintilla PROPN flat:name
# ao DET case
# sol NOUN nmod
# comer ADP case
# o DET det
# pedrar NOUN nmod
# precioso ADJ amod
# que PRON nsubj
# lhe PRON iobj
# servir VERB acl:relcl
# de ADP case
#
#  SPACE
# baptismo NOUN obl
# ; PUNCT punct
# o DET det
# seu DET det
# dedo NOUN nsubj
# de ADP case
# _ PROPN nmod
# gitano NOUN flat:name
# _ PROPN flat:name
# crestar VERB acl
# e CCONJ cc
# fino ADJ conj
# arrancar VERB ROOT
# ao DET case
#
#  SPACE
# pandeiro NOUN obl
# do DET case
# seu DET det
# paiz NOUN advmod
# doido VERB nmod
# e CCONJ cc
# extranhos NOUN conj
# som NOUN amod
# ! PUNCT punct
# Fascina VERB ROOT
# com ADP case
# um DET det
# olhar NOUN obl
#
#  SPACE
# inconsciente ADJ amod
# dos ADP case
# seu DET det
# olho NOUN nmod
# de ADP mark
# velludo PROPN nmod
# , PUNCT punct
# com ADP case
# umar DET det
# noto NOUN obl
# da DET case
# suar DET det
# voz NOUN nmod
#
#  SPACE
# crystallina ADJ appos
# , PUNCT punct
# com ADP case
# um DET det
# menear NOUN nmod
# do DET case
# seu DET det
# corpo NOUN nmod
# de ADP case
# serpentar NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Que PRON nsubj
# saber VERB ROOT
# ella NOUN obj
# da DET case
# vidar NOUN nmod
# ? PUNCT punct
# Nada PRON ROOT
# ; PUNCT punct
# o ADP mark
# não ADV fixed
# ser VERB fixed
# que SCONJ fixed
# o DET det
# vidar NOUN nsubj
# ser AUX cop
# bella ADJ parataxis
# , PUNCT punct
# vestir SCONJ mark
# que SCONJ fixed
# ha PROPN parataxis
#
#  SPACE
# dois NUM det
# olho NOUN csubj
# que PRON nsubj
# ao SCONJ mark
# fixar VERB acl:relcl
# o ADP case
# seu DET det
# o PRON obj
# banhar VERB obl
# de ADP case
# fulgor NOUN nmod
# ! PUNCT punct
#
#
#  SPACE
# E CCONJ cc
# Cosette PROPN ROOT
# ! PUNCT punct
# viver VERB ROOT
# ao DET case
# pé NOUN obl
# d'ella PROPN obj
# um DET det
# enygma NOUN obj
# sombrio ADJ amod
# ! PUNCT punct
# um DET det
# espiritar NOUN ROOT
# sobrehumano ADJ amod
# ! PUNCT punct
#
#  SPACE
# um DET det
# luctador NOUN ROOT
# d'estas PROPN appos
# luctas PROPN acl
# interior ADJ amod
# cujo DET det
# reflexo NOUN nsubj
# se PRON expl
# estampar VERB ROOT
# o DET case
# frente NOUN obl
#
#  SPACE
# que SCONJ nsubj
# o PRON obj
# encerrar VERB ccomp
# . PUNCT punct
#
#
#  SPACE
# Ella PROPN nsubj
# nunca ADV advmod
# interrogar VERB ROOT
# esse DET det
# almo NOUN obj
# , PUNCT punct
# e CCONJ cc
# nunca ADV advmod
# tentar VERB conj
# decifrar VERB xcomp
# esse DET det
# enygma PROPN obj
# , PUNCT punct
# e CCONJ cc
#
#  SPACE
# nunca ADV advmod
# sequer ADV advmod
# comprehendeu ADJ conj
# o DET det
# existencia NOUN obj
# d'essas ADJ appos
# luctas ADJ acl
# . PUNCT punct
#
#
#  SPACE
# Ao DET case
# seu DET det
# companheiro NOUN obl
# triste ADJ amod
# , PUNCT punct
# humildar ADJ conj
# , PUNCT punct
# heroico NOUN conj
# , PUNCT punct
# adoravel PROPN appos
# ella PROPN flat:name
# dever VERB ROOT
# durante ADP case
#
#  SPACE
# quinze NUM nummod
# annos PROPN obl
# o DET det
# venturo NOUN obj
# mais ADV advmod
# perfeito ADJ amod
# que SCONJ mark
# póde PROPN acl:relcl
# gosar-se VERB xcomp
# o DET case
# terra NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Satisfez-lhe VERB ROOT
# todo DET det
# o DET det
# desejo NOUN obj
# ; PUNCT punct
# todo DET det
# o DET fixed
# brinquedo NOUN nsubj
# d'aquella PROPN flat:name
# fadar PROPN flat:name
# , PUNCT punct
#
#  SPACE
# encarregou-se VERB ROOT
# de SCONJ mark
# o PRON obj
# fornecer VERB xcomp
# o DET det
# natureza NOUN obj
# o DET case
# liberdade NOUN obl
# pleno ADJ amod
# , PUNCT punct
# o ADP case
# seu DET det
#
#  SPACE
# idyllios PROPN amod
# primaveril PROPN obj
# ! PUNCT punct
# Estava AUX cop
# o DET case
# escuridão NOUN obl
# , PUNCT punct
# e CCONJ cc
# deram-lhe VERB conj
# luzir NOUN obj
# ; PUNCT punct
# ser AUX cop
# escravo ADJ ROOT
#
#  SPACE
# fizeram-n'a DET ROOT
# rei NOUN flat:name
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# importar VERB ROOT
# ! PUNCT punct
# Marius PROPN nsubj
# appareceu VERB amod
# e CCONJ cc
# Cosette PROPN conj
# louco ADJ amod
# , PUNCT punct
# deslumbrar VERB acl
# , PUNCT punct
# esquecido VERB conj
# , PUNCT punct
#
#  SPACE
# deixar VERB ROOT
# morrer VERB xcomp
# de ADP case
# dôr NOUN obl
# o DET det
# amigar NOUN nsubj
# da DET case
# suar DET det
# risonho ADJ amod
# mocidade NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# É AUX cop
# mau ADJ ROOT
# ? PUNCT punct
#
#
#  SPACE
# Não INTJ advmod
# ; PUNCT punct
# ser AUX cop
# ignorante ADJ ROOT
# . PUNCT punct
# Não ADV advmod
# saber VERB ROOT
# que SCONJ mark
# se PRON nsubj
# morrer VERB ccomp
# vestir SCONJ xcomp
# que SCONJ mark
# elle PROPN nsubj
# viver VERB ccomp
# o DET case
# posse NOUN obl
# de ADP case
#
#  SPACE
# umar DET det
# venturo NOUN nmod
# que PRON nsubj
# nunca ADV advmod
# até ADP case
# alli PROPN obl
# conhecer VERB acl:relcl
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# saber VERB ROOT
# que SCONJ mark
# se PRON nsubj
# ter VERB ccomp
# saudade NOUN obj
# , PUNCT punct
# porque SCONJ case
# ao DET case
# pé NOUN obl
# de ADP case
# Marius PROPN nmod
# nunca ADV advmod
# esse DET det
# espinhar NOUN nsubj
#
#  SPACE
# lhe PRON iobj
# morder VERB ccomp
# o DET case
# coração NOUN obl
# ! PUNCT punct
#
#
#  SPACE
# Pois ADV advmod
# ser AUX cop
# possivel ADJ ROOT
# ser AUX aux:pass
# desgraçar VERB csubj
# quando ADV mark
# eu PRON nsubj
# ser AUX cop
# tão ADV advmod
# feliz ADJ advcl
# ! PUNCT punct
# perguntar NOUN ROOT
#
#  SPACE
# tacitamente ADV advmod
# com ADP case
# barbaridade NOUN ROOT
# que PRON nsubj
# se PRON expl
# ignorar VERB acl:relcl
# , PUNCT punct
# cada DET nsubj
# um NUM fixed
# dos ADP case
# sorriso NOUN nmod
# de ADP case
#
#  SPACE
# venturo VERB nmod
# que PRON mark
# ella PROPN nsubj
# atirar VERB ccomp
# em ADP case
# redor NOUN obl
# de ADP case
# si PRON nmod
# , PUNCT punct
# sem SCONJ mark
# se PRON nsubj
# importar VERB advcl
# onde ADV advmod
# lhe PRON fixed
# ir VERB aux
#
#  SPACE
# cahir ADJ ROOT
# ! PUNCT punct
#
#
#  SPACE
# Ai INTJ ROOT
# ! PUNCT punct
# Cosette PROPN ROOT
# , PUNCT punct
# Cosette PROPN conj
# ! PUNCT punct
# eu PRON nsubj
# gostar VERB ROOT
# de ADP case
# ti PRON obj
# , PUNCT punct
# borboleta NOUN conj
# , PUNCT punct
# ébrio VERB conj
# de ADP case
# luzir NOUN obl
# ! PUNCT punct
# ser AUX cop
# umar NUM ROOT
#
#  SPACE
# das DET case
# visão NOUN nmod
# luminoso ADJ amod
# que PRON nsubj
# ficar VERB acl:relcl
# parir ADP case
# sempre ADV advmod
# moço NOUN obj
# e CCONJ cc
# querido ADJ conj
# ! PUNCT punct
# ser AUX cop
# umar DET nummod
#
#  SPACE
# estatuir NOUN ROOT
# branco ADJ amod
# que PRON obj
# ninguem PROPN nsubj
# ousar VERB acl:relcl
# mutilar VERB xcomp
# e CCONJ cc
# que SCONJ mark
# o DET det
# seculo NOUN nsubj
# ver VERB amod
# erguido VERB conj
#
#  SPACE
# o DET case
# teu DET det
# pedestal NOUN obl
# de ADP case
# flôres NOUN nmod
# ! PUNCT punct
# Mas CCONJ cc
# comer ADV mark
# eu PRON nsubj
# te PRON iobj
# amar VERB ROOT
# muito ADV advmod
# mais ADV advmod
# ainda ADV advmod
# se SCONJ dep
# em ADP punct
#
#  SPACE
# vez NOUN ROOT
# de ADP case
# ser NOUN nmod
# o DET det
# Amor PROPN nsubj
# ser PROPN cop
# o DET det
# Sacrificio PROPN nsubj
# ! PUNCT punct
#
#
#  SPACE
# Um NUM nummod
# dia NOUN obl
# Victor PROPN nsubj
# Hugo PROPN flat:name
# pedir VERB ccomp
# ás DET case
# neblinar NOUN obj
# matinaes VERB amod
# dos ADP case
# clima PROPN nmod
# do DET case
# norte NOUN nmod
# , PUNCT punct
# umar DET det
#
#  SPACE
# porção NOUN obj
# de ADP case
# render NOUN nmod
# branco ADJ amod
# e CCONJ cc
# transparentar ADJ conj
# com ADP case
# que PRON nmod
# ellas PROPN flat:name
# corôam PROPN flat:name
# o DET flat:name
# crista NOUN flat:name
# das DET case
#
#  SPACE
# montanha NOUN nmod
# e CCONJ cc
# ... PUNCT punct
# fazer VERB ROOT
# Déa PROPN nsubj
# ! PUNCT punct
#
#
#  SPACE
# Que SCONJ det
# doce ADJ amod
# , PUNCT punct
# vaporoso ADJ conj
# e CCONJ cc
# lendaria ADJ conj
# visão NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# ha NOUN nsubj
# n'ella ADJ flat:name
# cousa NOUN advmod
# algum DET det
# que PRON fixed
# ser AUX cop
# realidade NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE
# Toca NOUN ROOT
# o DET case
# terra NOUN nmod
# ao DET nmod
# de ADP case
# levar NOUN nmod
# ; PUNCT punct
# não ADV advmod
# tanto ADV advmod
# que SCONJ mark
# parecer VERB ROOT
# filho NOUN nsubj
# d'ella ADJ flat:name
# , PUNCT punct
# não ADV advmod
# tão ADV advmod
#
#  SPACE
# pouco ADV advmod
# que SCONJ mark
# lhe PRON iobj
# não ADV advmod
# ser AUX aux:pass
# dar VERB acl:relcl
# consolar VERB nsubj:pass
# alguem ADV nsubj:pass
# votar VERB acl
# ás DET case
# dor NOUN obl
# sem ADP case
# consolar PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# É AUX cop
# cego ADJ ROOT
# ! PUNCT punct
#
#
#  SPACE
# Amada VERB nsubj
# por ADP case
# um DET det
# monstro NOUN obl:agent
# saber VERB ROOT
# verter-lhe PUNCT xcomp
# n'alma NOUN ROOT
# o DET det
# alegria NOUN ROOT
# de ADP case
# um DET det
# Deus PROPN nmod
# ! PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# ver VERB ROOT
# o DET det
# homem NOUN obj
# que PRON nsubj
# o PRON obj
# amo VERB acl:relcl
# , PUNCT punct
# ver VERB conj
# o DET det
# amor NOUN obj
# de SCONJ mark
# que PRON obj
# elle ADV nsubj
# o PRON obj
# vestir VERB acl
# ! PUNCT punct
#
#
#  SPACE
# Abençoada ADJ amod
# cegueira NOUN ROOT
# que PRON nsubj
# fazer VERB acl:relcl
# dois PROPN obj
# feliz NOUN amod
# ! PUNCT punct
#
#
#         SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT punct
#
#
#  SPACE
# Ao ADP case
# lado NOUN ROOT
# d'ella PROPN appos
# -- PUNCT punct
# supremo PROPN appos
# contraste!--sorri PROPN flat:name
# Josiane PROPN ROOT
# com ADP case
# o DET det
# seu DET det
# sorriso NOUN nmod
# de ADP case
#
#  SPACE
# deus NOUN nmod
# pagão ADJ amod
# ! PUNCT punct
#
#
#  SPACE
# No DET case
# olhar NOUN ROOT
# azul ADJ amod
# da DET case
# patricia PROPN nmod
# ingleza PROPN flat:name
# scintilla PROPN flat:name
# em ADP case
# chispa NOUN nmod
# umar DET det
# diabolica NOUN ROOT
#
#  SPACE
# ironia NOUN ROOT
# . PUNCT punct
#
#
#  SPACE
# Josiane PROPN nsubj
# ser AUX cop
# o DET det
# amantar NOUN ROOT
# do DET case
# impossivel NOUN nmod
# ! PUNCT punct
# Procura VERB ROOT
# o PRON obj
# que PRON obj
# nunca ADV advmod
# ninguem PROPN nsubj
# achar VERB acl:relcl
# ! PUNCT punct
#
#
#  SPACE
# Quer CCONJ ROOT
# um DET det
# sonhar NOUN obj
# que PRON mark
# o DET det
# saciar NOUN acl:relcl
# , PUNCT punct
# o DET det
# amor NOUN conj
# de ADP case
# um DET det
# Titan PROPN nmod
# , PUNCT punct
# ou CCONJ cc
# de ADP case
# um DET det
# cyclope PROPN conj
# , PUNCT punct
# o DET det
# amor NOUN appos
#
#  SPACE
# de ADP case
# Apollo PROPN nmod
# ou CCONJ cc
# de ADP case
# Polyphemo PROPN conj
# ! PUNCT punct
#
#
#  SPACE
# Estranha NOUN amod
# figurar VERB ROOT
# , PUNCT punct
# producto NOUN appos
# doentio ADJ amod
# de ADP case
# umar DET det
# noite NOUN nmod
# de ADP case
# febre NOUN nmod
# ! PUNCT punct
#
#
#         SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT dep
#        SPACE
# * PUNCT ROOT
#        SPACE
# * PUNCT ROOT
#
#
#  SPACE
# Dona PROPN ROOT
# Sol PROPN flat:name
# , PUNCT punct
# Maria PROPN appos
# de ADP case
# Neuburgo PROPN nmod
# , PUNCT punct
# Marion PROPN conj
# , PUNCT punct
# Eponine PROPN conj
# , PUNCT punct
# Cosette PROPN conj
# , PUNCT punct
# Déa PROPN conj
# , PUNCT punct
# quanto PRON det
#
#  SPACE
# figurar NOUN conj
# radioso ADJ amod
# , PUNCT punct
# quanto DET det
# humanições NOUN conj
# esplender VERB acl
# da DET case
# mulher NOUN obj
# sonhar VERB acl
# ! PUNCT punct
#
#
#  SPACE
# Nas DET case
# horar NOUN obl
# de ADP case
# desalentar NOUN nmod
# ou CCONJ cc
# de ADP case
# amargo ADJ conj
# duvidar NOUN nmod
# , PUNCT punct
# o DET case
# horar NOUN obl
# em ADP case
# que PRON obl
# o DET det
# miserias NOUN nsubj
#
#  SPACE
# que PRON nsubj
# o PRON obj
# cercar VERB acl:relcl
# , PUNCT punct
# o PRON mark
# fazer VERB acl:relcl
# encarar VERB xcomp
# o DET det
# vidar NOUN obj
# pelar DET case
# seu DET det
# aspecto NOUN obl
# mais ADV advmod
#
#  SPACE
# desolar VERB acl
# e CCONJ cc
# mais ADV advmod
# escuro ADJ conj
# olhar VERB ROOT
# parir ADP case
# ellas PROPN obl
# ! PUNCT punct
#
#
#  SPACE
# Dir-nos-hão ADV case
# o DET det
# poetar NOUN ROOT
# de ADP case
# hoje ADV advmod
# que SCONJ obj
# ellas PROPN nsubj
# não ADV advmod
# existir VERB acl:relcl
# , PUNCT punct
# e CCONJ cc
# , PUNCT punct
# o PRON appos
# que PRON nsubj
# ser AUX cop
# peior ADJ acl:relcl
# , PUNCT punct
#
#  SPACE
# que SCONJ nsubj
# ellas PROPN nsubj
# não ADV advmod
# poder VERB acl:relcl
# existir VERB xcomp
# nunca ADV advmod
# . PUNCT punct
#
#
#  SPACE
# Oh INTJ ROOT
# ! PUNCT punct
# ser AUX cop
# bem ADV advmod
# triste ADJ ROOT
# , PUNCT punct
# ser AUX cop
# bem ADV advmod
# esteril ADJ conj
# o DET det
# arte NOUN nsubj
# que PRON nsubj
# só ADV advmod
# tratar VERB acl:relcl
# de SCONJ mark
# rebaixar VERB xcomp
# o PRON obj
# que PRON nsubj
# em ADP case
#
#  SPACE
# nó PRON nsubj
# ser AUX cop
# de ADP case
# mais ADV advmod
# elevar VERB amod
# essencia NOUN acl:relcl
# , PUNCT punct
# e CCONJ cc
# só ADV advmod
# querer VERB conj
# que SCONJ mark
# ver VERB ccomp
# o DET det
# fatalidade NOUN obj
#
#  SPACE
# brutal ADJ amod
# do DET case
# instincto NOUN obl
# , PUNCT punct
# onde PRON obl
# viamos VERB acl:relcl
# d'antes NOUN nsubj
# o DET det
# fatalidade NOUN nsubj
# mais ADV advmod
# nobre ADJ amod
# do DET case
#
#  SPACE
# sentimento NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Não ADV advmod
# acreditar VERB ROOT
# o PRON obj
# que PRON nsubj
# elles PROPN acl:relcl
# o PRON obj
# dizer VERB advcl
# , PUNCT punct
# porque SCONJ mark
# o DET case
# suar DET det
# preoccupação NOUN obl
#
#  SPACE
# exagerar VERB acl
# do DET case
# horrivel NOUN nmod
# , PUNCT punct
# elles PROPN nsubj
# mentir VERB advcl
# muito ADV advmod
# mais ADV advmod
# do ADP mark
# que PRON fixed
# o DET det
# outro PRON nsubj
# mentir VERB advcl
#
#  SPACE
# o DET case
# suar DET det
# preoccupação NOUN obl
# exagerar VERB acl
# do DET case
# bello PROPN nmod
# ! PUNCT punct
#
#
#  SPACE
# Estes DET ROOT
# reunir VERB advcl
# todo DET det
# o DET fixed
# vicios NOUN obj
# e CCONJ cc
# hediondezas NOUN conj
# que PRON nsubj
# encontrar VERB acl:relcl
# disperso ADJ xcomp
#
#  SPACE
# n'uma ADP case
# só ADV amod
# figurar NOUN obl
# , PUNCT punct
# conseguir VERB ROOT
# apenas ADV advmod
# crear VERB xcomp
# ... PUNCT punct
# um DET det
# monstro NOUN ROOT
# , PUNCT punct
# um DET obj
# ser NOUN aux
# hybrido VERB acl:relcl
# e CCONJ cc
#
#  SPACE
# infecundar VERB conj
# que SCONJ mark
# o DET det
# ninguem PROPN nsubj
# aproveitar VERB ccomp
# ! PUNCT punct
#
#
#  SPACE
# Os DET det
# outro DET det
# synthetisando NOUN nsubj
# n'uma ADP case
# filho NOUN nmod
# do DET case
# seu DET det
# genio NOUN nmod
# o DET det
# harmonia NOUN conj
# , PUNCT punct
# o DET det
#
#  SPACE
# feição NOUN flat:name
# , PUNCT punct
# o DET det
# encanto NOUN conj
# , PUNCT punct
# que PRON nsubj
# estudar VERB acl:relcl
# e CCONJ cc
# amarar VERB conj
# em ADP case
# todo DET det
# o DET det
# natureza NOUN obl
# , PUNCT punct
#
#  SPACE
# conseguir VERB ROOT
# algum DET det
# coisa NOUN obj
# mais ADV advmod
# ! PUNCT punct
#
#
#  SPACE
# Crearam VERB ROOT
# o DET det
# ideal ADJ obj
# immutavel ADJ amod
# e CCONJ cc
# eternar ADJ conj
# e CCONJ cc
# ensinaram-nos VERB conj
# o SCONJ mark
# fitar VERB xcomp
# n'elle PROPN obj
# o DET det
#
#  SPACE
# olho NOUN obj
# da DET case
# nosso DET det
# almo NOUN nmod
# , PUNCT punct
# e CCONJ cc
# o SCONJ det
# invocal-o VERB conj
# comer ADP case
# um DET det
# consolar NOUN xcomp
# adoravel ADJ amod
# o DET case
# nosso DET nummod
#
#  SPACE
# horar NOUN obl
# de ADP case
# desalentar NOUN nmod
# e CCONJ cc
# de ADP case
# agoniar NOUN conj
# . PUNCT punct

# %% [markdown]
# ## Practicing with the example text
# When working with languages that have inflection, we typically use `token.lemma_` instead of `token.text` like you'll find in the English examples. This is important when we're counting, so that differently-inflected forms of a word (e.g. masculine vs. feminine or singular vs. plural) aren't counted as if they were different words.

# %%
filepath = "../texts/pt.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# ## Get Adjectives

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |

# %% [markdown]
# To extract and count the adjectives in the example text, we will follow the same model as above, except we'll add an `if` statement that will pull out words only if their POS label matches "ADJ."

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# While we demonstrate how to extract parts of speech in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.
# </div>

# %% [markdown]
# Here we make a list of the adjectives identified in the example text:

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.lemma_)

# %%
adjs
# Out:
# ['VERDADEIRA',
#  'I',
#  'incaracteristica',
#  'tristissima',
#  "d'elle",
#  'debeis',
#  'rachitica',
#  'incompleto',
#  'azues',
#  'gorgeadas',
#  'escarlate',
#  'voluptuoso',
#  'estranho',
#  'doloroso',
#  'primeiro',
#  'fraco',
#  'inerme',
#  'pobre',
#  'dependente',
#  'rude',
#  'moral',
#  'duro',
#  'opulento',
#  'parasito',
#  'voluntarios',
#  'inconsciente',
#  'propria',
#  'mesmo',
#  'inquieto',
#  'medroso',
#  'primeiro',
#  'alto',
#  'plethorico',
#  'grosso',
#  'brutaes',
#  'farto',
#  'submisso',
#  'bonito',
#  'delgado',
#  'flexivel',
#  'branco',
#  'ideal',
#  'inglez',
#  'gracioso',
#  'delicado',
#  'metalicos',
#  'finar',
#  'esguio',
#  'branco',
#  'pequeno',
#  'fraco',
#  'grotesco',
#  'informar',
#  'inteirar',
#  'inteirar',
#  'enfermar',
#  'intenso',
#  'dilacerante',
#  'estranhar',
#  'brutaes',
#  'bravo',
#  'altivo',
#  'frio',
#  'desdenhoso',
#  'repugnante',
#  'imperturbavel',
#  'olympica',
#  'glacial',
#  'original',
#  'ironico',
#  'irregular',
#  'obscuro',
#  'infeliz',
#  'velho',
#  'contrariar',
#  'grotesco',
#  'asperas',
#  'hostil',
#  'extravagante',
#  'escossez',
#  'pequeno',
#  'magro',
#  'friorento',
#  'comico',
#  'melhor',
#  'unica',
#  'singular',
#  'faiscante',
#  'electrica',
#  'sonoro',
#  'rico',
#  'estranho',
#  'pequeno',
#  'comico',
#  'vermelho',
#  'alegrar',
#  'preto',
#  'pequeno',
#  'grotesco',
#  'delirante',
#  'inerme',
#  'estupida',
#  'descomposto',
#  'comicos',
#  'brutaes',
#  'desprezador',
#  'opulento',
#  'ruidoso',
#  'gravar',
#  'pequeno',
#  'feio',
#  'doente',
#  'II',
#  'doce',
#  'varios',
#  'grande',
#  'quartar',
#  'dignar',
#  'lindo',
#  'oriental',
#  'branco',
#  'surpresar',
#  'vitreos',
#  'grande',
#  'luminoso',
#  'glacial',
#  'pequerrucho',
#  'insolito',
#  'elle',
#  'opposto',
#  'perverter',
#  'adoravel',
#  'infantil',
#  'grande',
#  'pequeno',
#  'finissima',
#  'branco',
#  'branco',
#  'transparentar',
#  'gracioso',
#  'cheio',
#  'rosar',
#  'delirante',
#  'feliz',
#  'humildar',
#  'mãosinhas',
#  'branco',
#  'feliz',
#  'viver',
#  'adoraveis',
#  'oval',
#  'louro',
#  'angelico',
#  'feio',
#  'doente',
#  'absoluto',
#  'poderoso',
#  'extraordinaria',
#  'ingenua',
#  'enorme',
#  'ineffavel',
#  'crente',
#  'medroso',
#  'assustar',
#  'nodoso',
#  'grande',
#  'maior',
#  'prodigioso',
#  'arrojar',
#  'assombroso',
#  'maior',
#  'sereno',
#  'claro',
#  'capaz',
#  'grande',
#  'impossiveis',
#  'proprios',
#  'pequeno',
#  'especial',
#  'novo',
#  'pequenino',
#  'falso',
#  'verdadeiro',
#  'caro',
#  'barato',
#  'formoso',
#  'corrosivo',
#  'pequeno',
#  'grande',
#  'brilhante',
#  'ephemeras',
#  'nedia',
#  'roliço',
#  'alegrar',
#  'malicioso',
#  'pequeno',
#  'submisso',
#  'fiel',
#  'hostil',
#  'insuspeito',
#  'verdadeiro',
#  'ente',
#  'completar',
#  'abençoar',
#  'pobre',
#  'caprichoso',
#  'gracioso',
#  'pequeno',
#  'adoravel',
#  'simples',
#  'heroica',
#  'pequeno',
#  'III',
#  'lindo',
#  'airoso',
#  'flexivel',
#  'forte',
#  'altivo',
#  'aristocratica',
#  'radioso',
#  'grande',
#  'metallicas',
#  'tamanho',
#  'caprichoso',
#  'selvatica',
#  'pequeno',
#  'erecto',
#  'firmar',
#  'grande',
#  'livre',
#  'brazileira',
#  'tres',
#  'precisar',
#  'doente',
#  'exquisito',
#  'nervoso',
#  'violento',
#  'doloroso',
#  'vago',
#  'presentimentos',
#  'agudo',
#  'quartar',
#  'verde',
#  'grande',
#  'largo',
#  'caminhar',
#  "d'elle",
#  'novo',
#  'macilento',
#  'velho',
#  'magro',
#  'vacillantes',
#  'doloroso',
#  'canino',
#  'IV',
#  'sósinho',
#  'Fôra',
#  'completar',
#  'passar',
#  'longo',
#  'mesmo',
#  'melancolica',
#  'illuminado',
#  'radioso',
#  'magro',
#  'grotesco',
#  'pequeno',
#  'branco',
#  'poetico',
#  'grande',
#  'longo',
#  'doloroso',
#  'fresco',
#  'sadio',
#  'mau',
#  'humilhante',
#  'glacialmente',
#  'desdenhoso',
#  'primeiro',
#  'primeiro',
#  'fresco',
#  'feio',
#  'rachitico',
#  'estupido',
#  'alto',
#  'bom',
#  'forte',
#  'grande',
#  'poderoso',
#  'mimoso',
#  'rico',
#  'sinistro',
#  'romano',
#  'rapidos',
#  'bom',
#  'exclusivo',
#  'negro',
#  'intimar',
#  'verdadeiro',
#  '_',
#  '_',
#  'costumar',
#  'inutil',
#  'primeiro',
#  'segundar',
#  'fixo',
#  'primeiro',
#  'extraordinario',
#  'severo',
#  'nervoso',
#  'magro',
#  'cambar',
#  'timido',
#  'acanhar',
#  'medroso',
#  'proprios',
#  'expiatorio',
#  'perverso',
#  'estupefacto',
#  'velho',
#  'valente',
#  'brutaes',
#  'pobre',
#  'primeiro',
#  'temer',
#  'primeiro',
#  'forte',
#  'destemer',
#  'insano',
#  'velho',
#  'fixar',
#  'triste',
#  'humilde',
#  'meigo',
#  'viril',
#  'forte',
#  'desgraçar',
#  'estudante',
#  'inglez',
#  'minguar',
#  'pequeno',
#  'desaffogadamente',
#  'pequenino',
#  'novo',
#  'quintal',
#  'canteiro',
#  'alegre',
#  'sereno',
#  'doce',
#  'formoso',
#  'unico',
#  'possivel',
#  'formoso',
#  'doce',
#  'casto',
#  'physionomia',
#  'grande',
#  'melancolicos',
#  'esmagador',
#  'alegria',
#  'alto',
#  'interior',
#  'casto',
#  'doloroso',
#  'comprehendeu',
#  'mesmo',
#  'justar',
#  'identificar',
#  'desolador',
#  'physica',
#  'incapaz',
#  'violentar',
#  'lucta',
#  'util',
#  "n'aquella",
#  'collossal',
#  'grande',
#  'sublimar',
#  'humildar',
#  'VI',
#  'violento',
#  'descripta',
#  'louco',
#  'querido',
#  'extase',
#  'intacto',
#  'luminoso',
#  'transparente',
#  'pequenino',
#  'gordo',
#  'nedios',
#  'musical',
#  'aquelle',
#  "d'elle",
#  'pequenino',
#  'perverso',
#  'rosar',
#  'feliz',
#  'querer',
#  'esbelto',
#  'gracioso',
#  'curtir',
#  'simples',
#  'branco',
#  'azul',
#  'vermelho',
#  'espesso',
#  'louro',
#  "d'ella",
#  'maternal',
#  'martyrio',
#  'louco',
#  'adorar',
#  'lindo',
#  'mimoso',
#  'unica',
#  'VII',
#  'seguinte',
#  'brilhante',
#  'intimar',
#  'pequenino',
#  'capaz',
#  'desgraçar',
#  'cançada',
#  'perverso',
#  'phreneticas',
#  'pobre',
#  'secundario',
#  'fiel',
#  'impacientar',
#  'largo',
#  'Deus',
#  'comica',
#  'esperto',
#  'castanheiro',
#  'politicos',
#  'volumoso',
#  'severo',
#  'elegante',
#  'alegre',
#  'contente',
#  'novo',
#  'contente',
#  "d'esse",
#  'encantador',
#  'modelar',
#  'franzino',
#  'moderno',
#  'justar',
#  'elegante',
#  'lourar',
#  'vermelho',
#  'rosar',
#  'altivo',
#  'fixo',
#  'metallicos',
#  'menor',
#  'testo',
#  'curto',
#  'pequenino',
#  'antigo',
#  'irresistivel',
#  'aquella',
#  'menor',
#  'menor',
#  'fixo',
#  'credo',
#  'primar',
#  'estupido',
#  'pobre',
#  'ultimar',
#  'VIII',
#  'insignificante',
#  'ligeiro',
#  'elegante',
#  'parisiense',
#  'delicioso',
#  'fino',
#  'cavallos',
#  'ajaezar',
#  'ridiculos',
#  'horroroso',
#  'povoar',
#  'novo',
#  'ironicas',
#  'malicioso',
#  'ingrato',
#  'estranhar',
#  'irresistivel',
#  'esguio',
#  'fino',
#  'pellica',
#  'intraduzivel',
#  'interrogador',
#  'fascinante',
#  'banal',
#  'magnetico',
#  'bella',
#  'viril',
#  'mudar',
#  'inexplicavel',
#  'IX',
#  'lyrica',
#  'vogar',
#  'proprio',
#  'adoravel',
#  'verdadeiro',
#  'musical',
#  'nervoso',
#  'inquietar',
#  'nervoso',
#  'equilibrar',
#  'harmonico',
#  'impossiveis',
#  'bom',
#  'rico',
#  'aristocratica',
#  'especial',
#  'caracteristico',
#  'suave',
#  'desdens',
#  'raro',
#  'luxuoso',
#  'louro',
#  'franzino',
#  'curto',
#  'pisco',
#  'felino',
#  'cruel',
#  'vermelho',
#  'flexivel',
#  'estranho',
#  'liso',
#  'tranquilisadoras',
#  'grotesco',
#  'inchar',
#  'pobre',
#  'louco',
#  'elegante',
#  'desdenhoso',
#  'fidalgo',
#  'fino',
#  'pequeno',
#  'elegancias',
#  'pequeno',
#  'humilhante',
#  "N'aquella",
#  'sentimental',
#  'enervante',
#  'ocioso',
#  'rico',
#  'nervoso',
#  'alegre',
#  'unico',
#  'contrariar',
#  'estranho',
#  'fino',
#  'moderno',
#  'fragil',
#  'quebradiço',
#  'velho',
#  'irresistivel',
#  'vêl-o',
#  'bom',
#  'excellente',
#  'Pobre',
#  'bondoso',
#  'protector',
#  'bom',
#  'velho',
#  'immensa',
#  'gracioso',
#  'maternal',
#  'encantador',
#  'austero',
#  'voluntarioso',
#  'cheio',
#  'generoso',
#  'rico',
#  'cynico',
#  'excellente',
#  'proprias',
#  'perturbador',
#  'novo',
#  'picante',
#  'imprevisto',
#  'celeste',
#  'tratar',
#  'angelicas',
#  'selvagem',
#  'mesquinho',
#  'alto',
#  'esbeltar',
#  'forte',
#  'idiota',
#  'alegrar',
#  'radioso',
#  'cheio',
#  'flexiveis',
#  'rosar',
#  'louro',
#  'triste',
#  'endiabrar',
#  'pobre',
#  "d'elle",
#  'meigo',
#  'electrica',
#  'fascinador',
#  'magro',
#  'intimar',
#  'longo',
#  'magno',
#  'ardente',
#  'juvenil',
#  'abatido',
#  'triste',
#  'rico',
#  'sublimar',
#  'impudor',
#  'opulento',
#  'formoso',
#  'aristocratica',
#  'rico',
#  'nobre',
#  'inteiro',
#  'obscuro',
#  'fidalgo',
#  'adorar',
#  "d'ella",
#  'passar',
#  'mesquinho',
#  'grande',
#  'forte',
#  'orgulhoso',
#  'dignar',
#  'calar',
#  'querer',
#  'mau',
#  'primeiro',
#  'sorriso',
#  "d'elle",
#  'bom',
#  'similhante',
#  'primeiro',
#  'pobre',
#  'malfadar',
#  'rico',
#  'rico',
#  'tres',
#  'rico',
#  'primeiro',
#  'amplo',
#  'supremo',
#  "n'estas",
#  'incoherentes',
#  'eterno',
#  'agudo',
#  'quartar',
#  'humildar',
#  'pobre',
#  'ente',
#  'dilacerante',
#  'humano',
#  'horrivel',
#  'finar',
#  'principesco',
#  'XI',
#  'espaçoso',
#  'lindissima',
#  'meigo',
#  'bom',
#  'fiel',
#  'paciente',
#  'alto',
#  'politicar',
#  'amadurecer',
#  "d'ella",
#  'delicado',
#  'nervoso',
#  'infantil',
#  'doce',
#  'bom',
#  'superficial',
#  'egoista',
#  'adoravel',
#  'deleteria',
#  'covarde',
#  'primeiro',
#  'radiante',
#  'vermelho',
#  'fino',
#  'esguio',
#  'suave',
#  'amor',
#  'paralysadora',
#  'superior',
#  'completar',
#  'quentar',
#  'phantasia',
#  'raro',
#  'alto',
#  'requestadissima',
#  'propria',
#  'grave',
#  'embrutecedor',
#  'collossaes',
#  'principesco',
#  'pequenino',
#  'activo',
#  'gracioso',
#  'phantasista',
#  'oriental',
#  'curto',
#  'teimoso',
#  'insaciado',
#  'pária',
#  'minimo',
#  'minima',
#  'affectuosa',
#  'inacessiveis',
#  'meigo',
#  'tranquillos',
#  'melancolica',
#  'precoce',
#  'mesmo',
#  'timida',
#  'louro',
#  'unica',
#  'suave',
#  'obscuro',
#  'sublimar',
#  'turbulento',
#  'crueis',
#  'inconsciente',
#  'poderoso',
#  'divino',
#  'occultas',
#  'coração',
#  'ulcerára',
#  'XII',
#  'inquietar',
#  'finissimo',
#  'fiel',
#  'desconhecer',
#  'bom',
#  'sério',
#  'pensativo',
#  'forte',
#  'buliçoso',
#  'inquieto',
#  'cheio',
#  'infantil',
#  'ruidoso',
#  'subitas',
#  'fôfa',
#  'discreto',
#  'amor',
#  'dois',
#  'XIII',
#  'sentar',
#  'scisma',
#  'obscuro',
#  'doloroso',
#  'branco',
#  'delicioso',
#  'pequeno',
#  'feliz',
#  'chymerica',
#  'pobre',
#  'bom',
#  'util',
#  'pobre',
#  'grande',
#  'indescriptivel',
#  'rouco',
#  'ámanhã',
#  'perdido',
#  'perdido',
#  'miúdo',
#  'pallido',
#  'lourar',
#  'pleno',
#  'vagar',
#  'subtil',
#  'grande',
#  'exoticos',
#  'serpentino',
#  'branco',
#  'esbelto',
#  'ultimar',
#  'XIV',
#  'quietar',
#  'odioso',
#  'velho',
#  'pequenino',
#  'convidar',
#  'fóra',
#  'estupida',
#  'ridiculos',
#  'junto',
#  'diarios',
#  'mesquinho',
#  'degradante',
#  'insignificante',
#  'I',
#  'intraduzivel',
#  'espelhava-se-lhe',
#  'aquillo',
#  'louvor',
#  'melhor',
#  'proprios',
#  'melhor',
#  'mau',
#  'lettra',
#  'primeiro',
#  'pequeno',
#  'só',
#  'bom',
#  'doce',
#  'caridoso',
#  'anciosa',
#  'reportorio',
#  'jubiloso',
#  'forte',
#  'camoezas',
#  "n'aquella",
#  'bastante',
#  'mimoso',
#  'precisar',
#  'aquillo',
#  'antigo',
#  'bom',
#  'ámanhã',
#  'rutilante',
#  'pobre',
#  'benevolo',
#  'affavel',
#  'grandissimo',
#  'affecto',
#  'melhor',
#  'frio',
#  'antigo',
#  'velho',
#  'cheio',
#  'mesmo',
#  'precisar',
#  'velho',
#  'rabugento',
#  'rijo',
#  'vivo',
#  "n'aquella",
#  'vivo',
#  'solteiro',
#  'ella',
#  'verdadeiro',
#  'novo',
#  'antigo',
#  'perder',
#  'perfeito',
#  'comtigo',
#  'duro',
#  'orphã',
#  'pobre',
#  'madrugadôra',
#  'formidavel',
#  'bondoso',
#  'unica',
#  'ultimar',
#  'melancolico',
#  'cheio',
#  'ocioso',
#  "d'aquelle",
#  'melhor',
#  'alto',
#  'caricioso',
#  'longo',
#  'enamorar',
#  'adoravel',
#  'viver',
#  'pequeno',
#  'rodear',
#  'cuidar',
#  'pequeno',
#  'despotico',
#  'velho',
#  'cego',
#  'primeiro',
#  'novo',
#  'prior',
#  'cheio',
#  'primeiro',
#  'duro',
#  'deante',
#  'plangente',
#  'alegre',
#  'primeiro',
#  'pequeno',
#  'natal',
#  'solteiro',
#  'doente',
#  'bonito',
#  "d'elle",
#  'importante',
#  'singular',
#  'exemplarissimo',
#  'franco',
#  'precisar',
#  'nobre',
#  'excessivo',
#  'inaudito',
#  'estudante',
#  'fidalguia',
#  'restituido',
#  'abundante',
#  'caro',
#  'incompativel',
#  'falso',
#  '_',
#  'mesquinhar',
#  'chato',
#  'contente',
#  'alegre',
#  'inutil',
#  'grotesco',
#  'pesar',
#  'entranhar',
#  'querer',
#  'amantissimo',
#  'velho',
#  'II',
#  'melhor',
#  'vêr',
#  'alto',
#  'casar',
#  'bonito',
#  'guloso',
#  'doce',
#  'melhor',
#  'velho',
#  'accesos',
#  'primeiro',
#  'vestir',
#  'preto',
#  'lustroso',
#  'cheio',
#  'enorme',
#  'largar',
#  'nús',
#  'chinellas',
#  'cheio',
#  'descançava',
#  'grosso',
#  'reluzente',
#  'absorver',
#  'superior',
#  'grande',
#  'pequeno',
#  'seguinte',
#  'mesmo',
#  'cheio',
#  'adoentar',
#  "d'elle",
#  'bom',
#  'aberto',
#  'fino',
#  'ceiar',
#  'ancioso',
#  'vel-o',
#  'silencioso',
#  'raro',
#  'primeiro',
#  'rapaz',
#  'sentencioso',
#  'grande',
#  'vivo',
#  'freneticos',
#  'vermelho',
#  'largo',
#  'fumegante',
#  'elle',
#  'magro',
#  "d'elle",
#  'cheio',
#  'rico',
#  'inflammado',
#  'repetir',
#  'velho',
#  'sentar',
#  'distanciar',
#  "n'estes",
#  'obrigar',
#  'honrar',
#  'fóra',
#  'envergonhar',
#  'distante',
#  'monstruoso',
#  'gigante',
#  'franco',
#  'generoso',
#  'mau',
#  ...]

# %% [markdown]
# Then we count the unique adjectives in this list with the `Counter()` module:

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('grande', 87),
#  ('bom', 65),
#  ('pequeno', 55),
#  ('pobre', 48),
#  ('velho', 48),
#  ('cheio', 39),
#  ('primeiro', 38),
#  ('alto', 36),
#  ('mesmo', 31),
#  ('pequenino', 31),
#  ('feliz', 30),
#  ('branco', 29),
#  ('doce', 29),
#  ('rico', 28),
#  ('novo', 25),
#  ("d'elle", 23),
#  ('elegante', 22),
#  ('moderno', 21),
#  ('longo', 20),
#  ('doloroso', 19),
#  ('forte', 19),
#  ('verdadeiro', 18),
#  ('intimar', 18),
#  ('_', 18),
#  ('querido', 18),
#  ('bonito', 17),
#  ('triste', 17),
#  ('altivo', 16),
#  ('brilhante', 16),
#  ('fino', 16),
#  ('mau', 15),
#  ("d'ella", 15),
#  ('gracioso', 14),
#  ('precisar', 14),
#  ('antigo', 14),
#  ('superior', 14),
#  ('obscuro', 13),
#  ('melhor', 13),
#  ('humildar', 13),
#  ('capaz', 13),
#  ('formoso', 13),
#  ('simples', 13),
#  ('negro', 13),
#  ('proprio', 13),
#  ('raro', 13),
#  ('puro', 13),
#  ('luminoso', 12),
#  ('adoravel', 12),
#  ('nervoso', 12),
#  ('querer', 12),
#  ('ultimar', 12),
#  ('louro', 11),
#  ('completar', 11),
#  ('largo', 11),
#  ('meigo', 11),
#  ('irresistivel', 11),
#  ('feio', 10),
#  ('dignar', 10),
#  ('unico', 10),
#  ('azul', 10),
#  ('divino', 10),
#  ('modesto', 10),
#  ('sombrio', 10),
#  ('estranho', 9),
#  ('inconsciente', 9),
#  ('delicado', 9),
#  ('singular', 9),
#  ('alegrar', 9),
#  ('enorme', 9),
#  ('claro', 9),
#  ('fiel', 9),
#  ('radioso', 9),
#  ('inteiro', 9),
#  ('supremo', 9),
#  ('vivo', 9),
#  ('profundo', 9),
#  ('implacavel', 9),
#  ('opulento', 8),
#  ('grotesco', 8),
#  ('estranhar', 8),
#  ('desdenhoso', 8),
#  ('unica', 8),
#  ('doente', 8),
#  ('infantil', 8),
#  ('maior', 8),
#  ('caprichoso', 8),
#  ('melancolica', 8),
#  ('delicioso', 8),
#  ('eterno', 8),
#  ("d'estas", 8),
#  ('profundar', 8),
#  ('digno', 8),
#  ('mundano', 8),
#  ('escuro', 8),
#  ('ambicioso', 8),
#  ('robusto', 8),
#  ('ideal', 7),
#  ('magro', 7),
#  ('sonoro', 7),
#  ('vermelho', 7),
#  ('gravar', 7),
#  ('sereno', 7),
#  ('fresco', 7),
#  ('alegre', 7),
#  ('casto', 7),
#  ('seguinte', 7),
#  ('suave', 7),
#  ('nobre', 7),
#  ('pleno', 7),
#  ('caridoso', 7),
#  ('silencioso', 7),
#  ('diverso', 7),
#  ('curioso', 7),
#  ('propria', 6),
#  ('grosso', 6),
#  ('dilacerante', 6),
#  ('absoluto', 6),
#  ('poderoso', 6),
#  ('ineffavel', 6),
#  ('aristocratica', 6),
#  ('tres', 6),
#  ('violento', 6),
#  ('passar', 6),
#  ('viril', 6),
#  ('comprehendeu', 6),
#  ('sublimar', 6),
#  ('louco', 6),
#  ('bella', 6),
#  ('mesquinho', 6),
#  ('amplo', 6),
#  ('humano', 6),
#  ('radiante', 6),
#  ('pensativo', 6),
#  ('brutal', 6),
#  ('precioso', 6),
#  ('mysteriosa', 6),
#  ('intelligente', 6),
#  ('mear', 6),
#  ('terrivel', 6),
#  ('rude', 5),
#  ('duro', 5),
#  ('inquieto', 5),
#  ('delgado', 5),
#  ('inglez', 5),
#  ('frio', 5),
#  ('preto', 5),
#  ('lindo', 5),
#  ('viver', 5),
#  ('falso', 5),
#  ('caro', 5),
#  ('sadio', 5),
#  ('inutil', 5),
#  ('valente', 5),
#  ('aquelle', 5),
#  ('maternal', 5),
#  ('menor', 5),
#  ('aquella', 5),
#  ('intraduzivel', 5),
#  ('bondoso', 5),
#  ('proprias', 5),
#  ('ardente', 5),
#  ('quentar', 5),
#  ('discreto', 5),
#  ('sentar', 5),
#  ('só', 5),
#  ('contentar', 5),
#  ('sympathico', 5),
#  ('ingleza', 5),
#  ('tranquillo', 5),
#  ('criminoso', 5),
#  ('indispensavel', 5),
#  ('gentil', 5),
#  ('ignorante', 5),
#  ('medroso', 4),
#  ('brutaes', 4),
#  ('flexivel', 4),
#  ('esguio', 4),
#  ('glacial', 4),
#  ('original', 4),
#  ('hostil', 4),
#  ('ruidoso', 4),
#  ('elle', 4),
#  ('rosar', 4),
#  ('impossiveis', 4),
#  ('proprios', 4),
#  ('especial', 4),
#  ('mimoso', 4),
#  ('extraordinario', 4),
#  ('possivel', 4),
#  ('interior', 4),
#  ('desolador', 4),
#  ("n'aquella", 4),
#  ('collossal', 4),
#  ('musical', 4),
#  ('contente', 4),
#  ('encantador', 4),
#  ('insignificante', 4),
#  ('ingrato', 4),
#  ('fidalgo', 4),
#  ('enervante', 4),
#  ('ocioso', 4),
#  ('excellente', 4),
#  ('Pobre', 4),
#  ('austero', 4),
#  ('generoso', 4),
#  ('principesco', 4),
#  ('politicar', 4),
#  ('egoista', 4),
#  ('solteiro', 4),
#  ('ella', 4),
#  ('glorioso', 4),
#  ('vigoroso', 4),
#  ('franceza', 4),
#  ('fecundo', 4),
#  ('praticar', 4),
#  ("n'esses", 4),
#  ('impossivel', 4),
#  ('magestosa', 4),
#  ('illustre', 4),
#  ('laborioso', 4),
#  ('difficil', 4),
#  ('harmonioso', 4),
#  ('risonho', 4),
#  ('maravilhoso', 4),
#  ('intellectual', 4),
#  ('feminino', 4),
#  ('artista', 4),
#  ('complexo', 4),
#  ('realistar', 4),
#  ('póde', 4),
#  ('real', 4),
#  ('I', 3),
#  ('azues', 3),
#  ('voluptuoso', 3),
#  ('fraco', 3),
#  ('moral', 3),
#  ('submisso', 3),
#  ('finar', 3),
#  ('inteirar', 3),
#  ('intenso', 3),
#  ('repugnante', 3),
#  ('ironico', 3),
#  ('infeliz', 3),
#  ('contrariar', 3),
#  ('extravagante', 3),
#  ('friorento', 3),
#  ('electrica', 3),
#  ('II', 3),
#  ('quartar', 3),
#  ('oriental', 3),
#  ('transparentar', 3),
#  ('adoraveis', 3),
#  ('extraordinaria', 3),
#  ('ingenua', 3),
#  ('ephemeras', 3),
#  ('malicioso', 3),
#  ('heroica', 3),
#  ('firmar', 3),
#  ('agudo', 3),
#  ('estupido', 3),
#  ('sinistro', 3),
#  ('exclusivo', 3),
#  ('segundar', 3),
#  ('fixo', 3),
#  ('severo', 3),
#  ('timido', 3),
#  ('perverso', 3),
#  ('humilde', 3),
#  ('desgraçar', 3),
#  ('estudante', 3),
#  ('violentar', 3),
#  ('util', 3),
#  ('intacto', 3),
#  ('transparente', 3),
#  ('esbelto', 3),
#  ('espesso', 3),
#  ('adorar', 3),
#  ('curto', 3),
#  ('primar', 3),
#  ('banal', 3),
#  ('inexplicavel', 3),
#  ('luxuoso', 3),
#  ('cruel', 3),
#  ('fragil', 3),
#  ('horrivel', 3),
#  ('grave', 3),
#  ('phantasista', 3),
#  ('dois', 3),
#  ('rouco', 3),
#  ('perdido', 3),
#  ('pallido', 3),
#  ('fóra', 3),
#  ('junto', 3),
#  ('perfeito', 3),
#  ('melancolico', 3),
#  ('caricioso', 3),
#  ('natal', 3),
#  ('excessivo', 3),
#  ('pesar', 3),
#  ('largar', 3),
#  ('rapaz', 3),
#  ('sentencioso', 3),
#  ('limpo', 3),
#  ('inevitavel', 3),
#  ('serenar', 3),
#  ('trabalhoso', 3),
#  ('variar', 3),
#  ('concentrar', 3),
#  ('desprezar', 3),
#  ('angustioso', 3),
#  ('vasto', 3),
#  ('saudoso', 3),
#  ('livrar', 3),
#  ('correcto', 3),
#  ('necessario', 3),
#  ('admiravel', 3),
#  ('facil', 3),
#  ('honestar', 3),
#  ('romantica', 3),
#  ('artificial', 3),
#  ("d'estes", 3),
#  ('perigoso', 3),
#  ('insalubre', 3),
#  ('immutavel', 3),
#  ('bello', 3),
#  ("n'esse", 3),
#  ("n'essas", 3),
#  ('direito', 3),
#  ('tenaz', 3),
#  ('amar', 3),
#  ("d'aquella", 3),
#  ('vulgar', 3),
#  ('excepcional', 3),
#  ('mysterioso', 3),
#  ('sympathica', 3),
#  ('melhorar', 3),
#  ('macio', 3),
#  ('futurar', 3),
#  ("n'outras", 3),
#  ('humanar', 3),
#  ('fulvo', 3),
#  ('natural', 3),
#  ('mudo', 3),
#  ('dolorido', 3),
#  ('delicadeza', 3),
#  ('ideaes', 3),
#  ('universal', 3),
#  ('perfazer', 3),
#  ('gigantesco', 3),
#  ('vastar', 3),
#  ('americano', 3),
#  ('escravo', 3),
#  ('incompleto', 2),
#  ('inerme', 2),
#  ('farto', 2),
#  ('enfermar', 2),
#  ('olympica', 2),
#  ('irregular', 2),
#  ('comico', 2),
#  ('delirante', 2),
#  ('estupida', 2),
#  ('finissima', 2),
#  ('mãosinhas', 2),
#  ('prodigioso', 2),
#  ('arrojar', 2),
#  ('assombroso', 2),
#  ('barato', 2),
#  ('corrosivo', 2),
#  ('ente', 2),
#  ('III', 2),
#  ('livre', 2),
#  ('brazileira', 2),
#  ('sósinho', 2),
#  ('poetico', 2),
#  ('humilhante', 2),
#  ('rapidos', 2),
#  ('acanhar', 2),
#  ('destemer', 2),
#  ('esmagador', 2),
#  ('alegria', 2),
#  ('justar', 2),
#  ('physica', 2),
#  ('incapaz', 2),
#  ('curtir', 2),
#  ('cançada', 2),
#  ('phreneticas', 2),
#  ('secundario', 2),
#  ('impacientar', 2),
#  ('politicos', 2),
#  ('franzino', 2),
#  ('lourar', 2),
#  ('testo', 2),
#  ('ligeiro', 2),
#  ('parisiense', 2),
#  ('cavallos', 2),
#  ('ridiculos', 2),
#  ('povoar', 2),
#  ('fascinante', 2),
#  ('mudar', 2),
#  ('inquietar', 2),
#  ('liso', 2),
#  ('protector', 2),
#  ('imprevisto', 2),
#  ('angelicas', 2),
#  ('selvagem', 2),
#  ('esbeltar', 2),
#  ('fascinador', 2),
#  ('juvenil', 2),
#  ('orgulhoso', 2),
#  ('calar', 2),
#  ("n'estas", 2),
#  ('paciente', 2),
#  ('covarde', 2),
#  ('amor', 2),
#  ('teimoso', 2),
#  ('pária', 2),
#  ('inacessiveis', 2),
#  ('precoce', 2),
#  ('timida', 2),
#  ('occultas', 2),
#  ('sério', 2),
#  ('ámanhã', 2),
#  ('miúdo', 2),
#  ('vagar', 2),
#  ('aquillo', 2),
#  ('anciosa', 2),
#  ('affecto', 2),
#  ('rodear', 2),
#  ('cego', 2),
#  ('importante', 2),
#  ('franco', 2),
#  ('inaudito', 2),
#  ('abundante', 2),
#  ('mesquinhar', 2),
#  ('chato', 2),
#  ('vêr', 2),
#  ('casar', 2),
#  ('guloso', 2),
#  ('accesos', 2),
#  ('reluzente', 2),
#  ('aberto', 2),
#  ('honrar', 2),
#  ('envergonhar', 2),
#  ('gigante', 2),
#  ('subito', 2),
#  ('palpitante', 2),
#  ('sahe', 2),
#  ('cerebral', 2),
#  ('estudioso', 2),
#  ('ridente', 2),
#  ('clamoroso', 2),
#  ('tranquilla', 2),
#  ('elevar', 2),
#  ('estrangeiro', 2),
#  ('expirante', 2),
#  ('gulosar', 2),
#  ('quente', 2),
#  ("N'esse", 2),
#  ('geral', 2),
#  ('primitivar', 2),
#  ('invejoso', 2),
#  ('enfadonho', 2),
#  ('plebeu', 2),
#  ('monastica', 2),
#  ('phantasticas', 2),
#  ('irritante', 2),
#  ('confortavel', 2),
#  ('insolente', 2),
#  ('opulentar', 2),
#  ('respeitavel', 2),
#  ('seccas', 2),
#  ('requintar', 2),
#  ('instincto', 2),
#  ('soffredora', 2),
#  ('mediocre', 2),
#  ('apparatoso', 2),
#  ('romanticas', 2),
#  ('indignar', 2),
#  ('italiano', 2),
#  ('numeroso', 2),
#  ('mysteriosos', 2),
#  ('noivar', 2),
#  ('pomposo', 2),
#  ('romanesco', 2),
#  ('funestar', 2),
#  ('galante', 2),
#  ('educar', 2),
#  ('indefinido', 2),
#  ('emfim', 2),
#  ('calmo', 2),
#  ('amargo', 2),
#  ('piedoso', 2),
#  ('ultimos', 2),
#  ('monotono', 2),
#  ('enganoso', 2),
#  ('amargar', 2),
#  ('religioso', 2),
#  ('posterior', 2),
#  ('virtuoso', 2),
#  ('tremendo', 2),
#  ('febril', 2),
#  ('magico', 2),
#  ('baixo', 2),
#  ('vibrante', 2),
#  ('capitão', 2),
#  ('familia', 2),
#  ('unicos', 2),
#  ('morto', 2),
#  ('millionario', 2),
#  ('artistico', 2),
#  ('inaccessivel', 2),
#  ('primoroso', 2),
#  ('distrahido', 2),
#  ('banaes', 2),
#  ('lisboeta', 2),
#  ('redondo', 2),
#  ('artistica', 2),
#  ('mentiroso', 2),
#  ('vencedor', 2),
#  ('plumbea', 2),
#  ('satanico', 2),
#  ('invisivel', 2),
#  ('irrequieto', 2),
#  ("N'essas", 2),
#  ('innocente', 2),
#  ('despreoccupada', 2),
#  ('apparatosas', 2),
#  ('penetrante', 2),
#  ('triumphante', 2),
#  ('subitos', 2),
#  ('mysteriosas', 2),
#  ('fradar', 2),
#  ('claustral', 2),
#  ('amantissima', 2),
#  ('trajar', 2),
#  ('postar', 2),
#  ('extremoso', 2),
#  ('burgueza', 2),
#  ('vaidoso', 2),
#  ('paterno', 2),
#  ('surdir', 2),
#  ('deploravel', 2),
#  ('confuso', 2),
#  ('inferior', 2),
#  ('nocturno', 2),
#  ('futuro', 2),
#  ('substancioso', 2),
#  ('feroz', 2),
#  ('olho', 2),
#  ('pessoal', 2),
#  ('indiscreto', 2),
#  ('riquissimo', 2),
#  ('disperso', 2),
#  ('sublime', 2),
#  ('triumphantes', 2),
#  ('carinhoso', 2),
#  ('occulta', 2),
#  ('solidar', 2),
#  ('rapido', 2),
#  ('quadrar', 2),
#  ('differentes', 2),
#  ('admirar', 2),
#  ('permanente', 2),
#  ('prestigioso', 2),
#  ('rubro', 2),
#  ('luctador', 2),
#  ('XIX', 2),
#  ('fecundar', 2),
#  ('consciencioso', 2),
#  ('medonho', 2),
#  ("d'esses", 2),
#  ('immoral', 2),
#  ('romantico', 2),
#  ('dramatico', 2),
#  ('visivel', 2),
#  ('positivar', 2),
#  ('vertiginoso', 2),
#  ('aristocraticos', 2),
#  ('magnetica', 2),
#  ('primo', 2),
#  ('expressivo', 2),
#  ('admiraveis', 2),
#  ('infatigavel', 2),
#  ('sedento', 2),
#  ('grandioso', 2),
#  ('interessante', 2),
#  ('justo', 2),
#  ('democratica', 2),
#  ('fatal', 2),
#  ('popular', 2),
#  ('francez', 2),
#  ('pagão', 2),
#  ("d'essas", 2),
#  ('VERDADEIRA', 1),
#  ('incaracteristica', 1),
#  ('tristissima', 1),
#  ('debeis', 1),
#  ('rachitica', 1),
#  ('gorgeadas', 1),
#  ('escarlate', 1),
#  ('dependente', 1),
#  ('parasito', 1),
#  ('voluntarios', 1),
#  ('plethorico', 1),
#  ('metalicos', 1),
#  ('informar', 1),
#  ('bravo', 1),
#  ('imperturbavel', 1),
#  ('asperas', 1),
#  ('escossez', 1),
#  ('faiscante', 1),
#  ('descomposto', 1),
#  ('comicos', 1),
#  ('desprezador', 1),
#  ('varios', 1),
#  ('surpresar', 1),
#  ('vitreos', 1),
#  ('pequerrucho', 1),
#  ('insolito', 1),
#  ('opposto', 1),
#  ('perverter', 1),
#  ('oval', 1),
#  ('angelico', 1),
#  ('crente', 1),
#  ('assustar', 1),
#  ('nodoso', 1),
#  ('nedia', 1),
#  ('roliço', 1),
#  ('insuspeito', 1),
#  ('abençoar', 1),
#  ('airoso', 1),
#  ('metallicas', 1),
#  ('tamanho', 1),
#  ('selvatica', 1),
#  ('erecto', 1),
#  ('exquisito', 1),
#  ('vago', 1),
#  ('presentimentos', 1),
#  ('verde', 1),
#  ('caminhar', 1),
#  ('macilento', 1),
#  ('vacillantes', 1),
#  ('canino', 1),
#  ('IV', 1),
#  ('Fôra', 1),
#  ('illuminado', 1),
#  ('glacialmente', 1),
#  ('rachitico', 1),
#  ('romano', 1),
#  ('costumar', 1),
#  ('cambar', 1),
#  ('expiatorio', 1),
#  ('estupefacto', 1),
#  ('temer', 1),
#  ('insano', 1),
#  ('fixar', 1),
#  ('minguar', 1),
#  ('desaffogadamente', 1),
#  ('quintal', 1),
#  ('canteiro', 1),
#  ('physionomia', 1),
#  ('melancolicos', 1),
#  ('identificar', 1),
#  ('lucta', 1),
#  ('VI', 1),
#  ('descripta', 1),
#  ('extase', 1),
#  ('gordo', 1),
#  ('nedios', 1),
#  ('martyrio', 1),
#  ('VII', 1),
#  ('Deus', 1),
#  ('comica', 1),
#  ('esperto', 1),
#  ('castanheiro', 1),
#  ('volumoso', 1),
#  ("d'esse", 1),
#  ('modelar', 1),
#  ('metallicos', 1),
#  ('credo', 1),
#  ('VIII', 1),
#  ('ajaezar', 1),
#  ('horroroso', 1),
#  ('ironicas', 1),
#  ('pellica', 1),
#  ('interrogador', 1),
#  ('magnetico', 1),
#  ('IX', 1),
#  ('lyrica', 1),
#  ('vogar', 1),
#  ('equilibrar', 1),
#  ('harmonico', 1),
#  ('caracteristico', 1),
#  ('desdens', 1),
#  ('pisco', 1),
#  ('felino', 1),
#  ('tranquilisadoras', 1),
#  ('inchar', 1),
#  ('elegancias', 1),
#  ("N'aquella", 1),
#  ('sentimental', 1),
#  ('quebradiço', 1),
#  ('vêl-o', 1),
#  ('immensa', 1),
#  ('voluntarioso', 1),
#  ('cynico', 1),
#  ('perturbador', 1),
#  ('picante', 1),
#  ('celeste', 1),
#  ('tratar', 1),
#  ('idiota', 1),
#  ('flexiveis', 1),
#  ('endiabrar', 1),
#  ('magno', 1),
#  ('abatido', 1),
#  ('impudor', 1),
#  ('sorriso', 1),
#  ('similhante', 1),
#  ('malfadar', 1),
#  ('incoherentes', 1),
#  ('XI', 1),
#  ('espaçoso', 1),
#  ('lindissima', 1),
#  ('amadurecer', 1),
#  ('superficial', 1),
#  ('deleteria', 1),
#  ('paralysadora', 1),
#  ('phantasia', 1),
#  ('requestadissima', 1),
#  ('embrutecedor', 1),
#  ('collossaes', 1),
#  ('activo', 1),
#  ('insaciado', 1),
#  ('minimo', 1),
#  ('minima', 1),
#  ('affectuosa', 1),
#  ('tranquillos', 1),
#  ('turbulento', 1),
#  ('crueis', 1),
#  ('coração', 1),
#  ('ulcerára', 1),
#  ('XII', 1),
#  ('finissimo', 1),
#  ('desconhecer', 1),
#  ('buliçoso', 1),
#  ('subitas', 1),
#  ('fôfa', 1),
#  ('XIII', 1),
#  ('scisma', 1),
#  ('chymerica', 1),
#  ('indescriptivel', 1),
#  ('subtil', 1),
#  ('exoticos', 1),
#  ('serpentino', 1),
#  ('XIV', 1),
#  ('quietar', 1),
#  ('odioso', 1),
#  ('convidar', 1),
#  ('diarios', 1),
#  ('degradante', 1),
#  ('espelhava-se-lhe', 1),
#  ('louvor', 1),
#  ('lettra', 1),
#  ('reportorio', 1),
#  ('jubiloso', 1),
#  ('camoezas', 1),
#  ('bastante', 1),
#  ('rutilante', 1),
#  ('benevolo', 1),
#  ('affavel', 1),
#  ('grandissimo', 1),
#  ('rabugento', 1),
#  ('rijo', 1),
#  ('perder', 1),
#  ('comtigo', 1),
#  ('orphã', 1),
#  ('madrugadôra', 1),
#  ('formidavel', 1),
#  ("d'aquelle", 1),
#  ('enamorar', 1),
#  ('cuidar', 1),
#  ('despotico', 1),
#  ('prior', 1),
#  ('deante', 1),
#  ('plangente', 1),
#  ('exemplarissimo', 1),
#  ('fidalguia', 1),
#  ('restituido', 1),
#  ('incompativel', 1),
#  ('entranhar', 1),
#  ('amantissimo', 1),
#  ('vestir', 1),
#  ('lustroso', 1),
#  ('nús', 1),
#  ('chinellas', 1),
#  ('descançava', 1),
#  ('absorver', 1),
#  ('adoentar', 1),
#  ('ceiar', 1),
#  ('ancioso', 1),
#  ('vel-o', 1),
#  ('freneticos', 1),
#  ('fumegante', 1),
#  ('inflammado', 1),
#  ('repetir', 1),
#  ('distanciar', 1),
#  ("n'estes", 1),
#  ('obrigar', 1),
#  ('distante', 1),
#  ('monstruoso', 1),
#  ('tropegas', 1),
#  ('caseiro', 1),
#  ('livido', 1),
#  ('pungitivo', 1),
#  ('tropego', 1),
#  ('amigar', 1),
#  ('pertencente', 1),
#  ('ver', 1),
#  ('encarnar', 1),
#  ('quintanista', 1),
#  ('companheiro', 1),
#  ('esmerar', 1),
#  ('juridico', 1),
#  ('ignobeis', 1),
#  ('amanuense', 1),
#  ('necessarios', 1),
#  ('sisudo', 1),
#  ('telegraphica', 1),
#  ('curvar', 1),
#  ('mettido', 1),
#  ('lutuoso', 1),
#  ('amoravel', 1),
#  ('hystericos', 1),
#  ('menino', 1),
#  ('proxima', 1),
#  ('quieto', 1),
#  ('juridicas', 1),
#  ('fero', 1),
#  ('rijar', 1),
#  ('temporal', 1),
#  ('circumvisinhanças', 1),
#  ('sagrar', 1),
#  ('dilatar', 1),
#  ('diplomatico', 1),
#  ('Espirituoso', 1),
#  ('acabar', 1),
#  ('mysterios', 1),
#  ('sorumbatica', 1),
#  ('sôrna', 1),
#  ('dormir', 1),
#  ('remunerar', 1),
#  ('igual', 1),
#  ('acentuar', 1),
#  ('jornalista', 1),
#  ('diamante', 1),
#  ('magnificar', 1),
#  ('lindissimo', 1),
#  ('tomára', 1),
#  ('esquerdo', 1),
#  ('turbulentamente', 1),
#  ('reservar', 1),
#  ('--Peço', 1),
#  ('cerravam-se-lhe', 1),
#  ('empastavam-se-lhe', 1),
#  ('secundar', 1),
#  ('impertinente', 1),
#  ('alheio', 1),
#  ('aristocratico', 1),
#  ('ennegrecida', 1),
#  ('damninhos', 1),
#  ('errante', 1),
#  ('contradictorio', 1),
#  ('publicos', 1),
#  ('complacente', 1),
#  ('apainelladas', 1),
#  ('pannos', 1),
#  ('extincta', 1),
#  ('arruinar', 1),
#  ('phantasioso', 1),
#  ('illuminuras', 1),
#  ('mortalhar', 1),
#  ('silvestre', 1),
#  ('possante', 1),
#  ('verde-negra', 1),
#  ('gasto', 1),
#  ('luxar', 1),
#  ('inquietador', 1),
#  ('acre', 1),
#  ('esmeraldino', 1),
#  ('invejavel', 1),
#  ('muitissimo', 1),
#  ('bizarro', 1),
#  ('alcatifar', 1),
#  ('côrte', 1),
#  ('influente', 1),
#  ('conhecer', 1),
#  ('anemicas', 1),
#  ('sincero', 1),
#  ('auctoritaria', 1),
#  ('bancaria', 1),
#  ('extrangeiros', 1),
#  ('intervallos', 1),
#  ('transcendente', 1),
#  ('sacudir', 1),
#  ('pedestal', 1),
#  ('masculino', 1),
#  ('soffredôra', 1),
#  ('inglezes', 1),
#  ('laconicas', 1),
#  ('realisavel', 1),
#  ('domesticar', 1),
#  ('persistente', 1),
#  ('inglesar', 1),
#  ('infallivel', 1),
#  ('distinctas', 1),
#  ('scientificos', 1),
#  ('agradavel', 1),
#  ('irreprehensiveis', 1),
#  ('vesgo', 1),
#  ('incommodo', 1),
#  ('esplender', 1),
#  ('titular', 1),
#  ('donativo', 1),
#  ('promettido', 1),
#  ('lisongeira', 1),
#  ('peninsular', 1),
#  ('trovador', 1),
#  ('dominador', 1),
#  ('fallecida', 1),
#  ('refinar', 1),
#  ('duplo', 1),
#  ('passivo', 1),
#  ('sobresahir', 1),
#  ('esposar', 1),
#  ('lorpa', 1),
#  ('limpido', 1),
#  ('innata', 1),
#  ('sacrificar', 1),
#  ('capitoso', 1),
#  ('consentir', 1),
#  ('ridiculo', 1),
#  ('cubiçavel', 1),
#  ('terno', 1),
#  ('ecletico', 1),
#  ('ridicula', 1),
#  ('decente', 1),
#  ('inolvidaveis', 1),
#  ('seriar', 1),
#  ('logico', 1),
#  ('recto', 1),
#  ('delicadissima', 1),
#  ('extranho', 1),
#  ('mulher', 1),
#  ('cabellos', 1),
#  ('setinosa', 1),
#  ('honesto', 1),
#  ('inconveniente', 1),
#  ('creaturas', 1),
#  ('Activa', 1),
#  ('festivo', 1),
#  ('artificios', 1),
#  ('imcomparavel', 1),
#  ('suspiroso', 1),
#  ('ciumar', 1),
#  ('definitivo', 1),
#  ('chamára', 1),
#  ('irreprehensivel', 1),
#  ('economica', 1),
#  ('millionarios', 1),
#  ('idealisar', 1),
#  ('ha', 1),
#  ('deliciar', 1),
#  ('aristocrata', 1),
#  ('grosseiro', 1),
#  ('soffrimentos', 1),
#  ('robustez', 1),
#  ('denso', 1),
#  ('soffredor', 1),
#  ('infinito', 1),
#  ('purpurea', 1),
#  ('crystallinas', 1),
#  ('naturaes', 1),
#  ('completo', 1),
#  ('dôres', 1),
#  ('ineffaveis', 1),
#  ('maliciosamente', 1),
#  ('predilecto', 1),
#  ('desmoralisador', 1),
#  ('traiçoeiro', 1),
#  ('ephemero', 1),
#  ('illumina', 1),
#  ('affeiçoado', 1),
#  ('innumeros', 1),
#  ('heroico', 1),
#  ('recente', 1),
#  ('desamparar', 1),
#  ('desprezivel', 1),
#  ('irascivel', 1),
#  ('consolar', 1),
#  ('partir', 1),
#  ...]

# %% [markdown]
# Then we make a dataframe from this list:

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#              adj  count
# 0         grande     87
# 1            bom     65
# 2        pequeno     55
# 3          pobre     48
# 4          velho     48
# 5          cheio     39
# 6       primeiro     38
# 7           alto     36
# 8          mesmo     31
# 9      pequenino     31
# 10         feliz     30
# 11        branco     29
# 12          doce     29
# 13          rico     28
# 14          novo     25
# 15        d'elle     23
# 16      elegante     22
# 17       moderno     21
# 18         longo     20
# 19      doloroso     19
# 20         forte     19
# 21    verdadeiro     18
# 22       intimar     18
# 23             _     18
# 24       querido     18
# 25        bonito     17
# 26        triste     17
# 27        altivo     16
# 28     brilhante     16
# 29          fino     16
# 30           mau     15
# 31        d'ella     15
# 32      gracioso     14
# 33      precisar     14
# 34        antigo     14
# 35      superior     14
# 36       obscuro     13
# 37        melhor     13
# 38      humildar     13
# 39         capaz     13
# 40       formoso     13
# 41       simples     13
# 42         negro     13
# 43       proprio     13
# 44          raro     13
# 45          puro     13
# 46      luminoso     12
# 47      adoravel     12
# 48       nervoso     12
# 49        querer     12
# 50       ultimar     12
# 51         louro     11
# 52     completar     11
# 53         largo     11
# 54         meigo     11
# 55  irresistivel     11
# 56          feio     10
# 57        dignar     10
# 58         unico     10
# 59          azul     10
# 60        divino     10
# 61       modesto     10
# 62       sombrio     10
# 63      estranho      9
# 64  inconsciente      9
# 65      delicado      9
# 66      singular      9
# 67       alegrar      9
# 68        enorme      9
# 69         claro      9
# 70          fiel      9
# 71       radioso      9
# 72       inteiro      9
# 73       supremo      9
# 74          vivo      9
# 75      profundo      9
# 76    implacavel      9
# 77      opulento      8
# 78      grotesco      8
# 79     estranhar      8
# 80    desdenhoso      8
# 81         unica      8
# 82        doente      8
# 83      infantil      8
# 84         maior      8
# 85    caprichoso      8
# 86   melancolica      8
# 87     delicioso      8
# 88        eterno      8
# 89       d'estas      8
# 90     profundar      8
# 91         digno      8
# 92       mundano      8
# 93        escuro      8
# 94     ambicioso      8
# 95       robusto      8
# 96         ideal      7
# 97         magro      7
# 98        sonoro      7
# 99      vermelho      7

# %% [markdown]
# ## Get Nouns

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |

# %% [markdown]
# To extract and count nouns, we can follow the same model as above, except we will change our `if` statement to check for POS labels that match "NOUN".

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.lemma_)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#          noun  count
# 0       vidar    131
# 1         dia    130
# 2       casar    109
# 3      mulher    105
# 4       homem     97
# 5       filho     91
# 6        olho     88
# 7         mãe     75
# 8       cousa     74
# 9         pae     68
# 10      horar     68
# 11       almo     67
# 12        voz     66
# 13      tempo     62
# 14      vezar     61
# 15        mão     60
# 16      olhar     58
# 17       amor     52
# 18    coração     48
# 19       mear     45
# 20      rapaz     45
# 21        vez     42
# 22    alegria     42
# 23         pé     40
# 24     senhor     39
# 25      irmão     39
# 26     filhar     39
# 27        tio     38
# 28    palavra     37
# 29      noite     37
# 30      mundo     36
# 31      terra     36
# 32      amigo     36
# 33       sala     36
# 34      braço     35
# 35  espiritar     35
# 36       moço     34
# 37    capitão     32
# 38       modo     31
# 39     cabeça     30
# 40      corpo     30
# 41     menino     30
# 42     pessoa     30
# 43      annos     29
# 44     forçar     29
# 45    familia     29
# 46      gente     27
# 47     cartar     27
# 48   visconde     27
# 49     contar     26
# 50    sorriso     26
# 51    verdade     26
# 52    creança     25
# 53   lagrimas     25
# 54       lado     25
# 55  trabalhar     24
# 56    musicar     24
# 57     poetar     23
# 58      luzir     23
# 59    direito     23
# 60     livrar     23
# 61     paixão     22
# 62     partir     22
# 63    saudade     22
# 64     portar     22
# 65      velho     22
# 66       nome     21
# 67      graça     21
# 68     rostir     20
# 69       riso     20
# 70    quartar     20
# 71     jardim     20
# 72     jantar     20
# 73        fim     20
# 74     passar     20
# 75    momento     20
# 76     amigar     19
# 77   instante     19
# 78        sr.     19
# 79        rei     18
# 80     mestre     18
# 81  historiar     18
# 82  estudante     18
# 83         ha     18
# 84   dinheiro     18
# 85    artista     18
# 86       medo     17
# 87    figurar     17
# 88         ar     17
# 89    arvorar     17
# 90   educação     17
# 91     viagem     17
# 92      visão     17
# 93    estudar     17
# 94      dever     17
# 95  escriptor     17
# 96    vontade     16
# 97      louro     16
# 98     vestir     16
# 99      festa     16

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the POS label "VERB").

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of verbs in a single line of code! Closely examine the first line of code below:
# </div>

# %%
verbs = [token.lemma_ for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#           verb  count
# 0          ter    316
# 1        fazer    166
# 2        dizer    148
# 3        saber    144
# 4        haver    111
# 5          dar    104
# 6          ver     87
# 7          ser     83
# 8        poder     80
# 9          vir     74
# 10      querer     71
# 11      passar     54
# 12    conhecer     52
# 13      deixar     49
# 14      sentir     47
# 15       viver     46
# 16     parecer     45
# 17          ir     44
# 18       ficar     36
# 19      morrer     36
# 20       levar     34
# 21      gostar     32
# 22      chegar     32
# 23       olhar     31
# 24      chorar     29
# 25       andar     29
# 26         rir     28
# 27       ouvir     28
# 28      entrar     28
# 29      tornar     27
# 30       pedir     27
# 31      chamar     26
# 32   perguntar     25
# 33       Tinha     23
# 34      vestir     23
# 35      pensar     23
# 36          ha     23
# 37     receber     22
# 38      voltar     22
# 39       achar     21
# 40     lembrar     21
# 41     esperar     21
# 42   encontrar     21
# 43       dever     20
# 44           _     20
# 45        amar     20
# 46         ler     20
# 47       tocar     19
# 48    perceber     18
# 49    entender     18
# 50      trazer     18
# 51      perder     18
# 52      mandar     17
# 53  acompanhar     17
# 54   responder     17
# 55   trabalhar     17
# 56      contar     17
# 57       estar     17
# 58      cantar     16
# 59     estudar     16
# 60      julgar     15
# 61     começar     15
# 62        elle     14
# 63      partir     14
# 64       parar     14
# 65    levantar     14
# 66        crer     14
# 67    murmurar     13
# 68      tentar     13
# 69   conversar     13
# 70       casar     13
# 71   continuar     13
# 72    escrever     13
# 73     desejar     13
# 74     repetir     12
# 75    imaginar     12
# 76       virar     12
# 77    entravar     12
# 78       subir     12
# 79       abrir     12
# 80   conservar     11
# 81      servir     11
# 82   conseguir     11
# 83       n'uma     11
# 84       tomar     11
# 85       tirar     11
# 86      gritar     11
# 87      deitar     11
# 88  apresentar     11
# 89    arrastar     11
# 90      seguir     11
# 91         pôr     11
# 92      faltar     11
# 93      correr     10
# 94       Havia     10
# 95      adorar     10
# 96     dirigir     10
# 97      tratar     10
# 98   descobrir     10
# 99      fingir     10

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ## Get Sentences with Keyword

# %% [markdown]
# spaCy can also identify sentences in a document. To access sentences, we can iterate through `document.sents` and pull out the `.text` of each sentence.

# %% [markdown]
# We can use spaCy's sentence-parsing capabilities to extract sentences that contain particular keywords, such as in the function below. Note that the function assumes that the keyword provided will be exactly the same as it appears in the text (e.g. matching all inflection for case, number, gender, etc. As a Spanish example, if you use `bueno` as the keyboard, it won't match `buena` or `buenos`.)
#
# With the function `find_sentences_with_keyword()`, we will iterate through `document.sents` and pull out any sentence that contains a particular "keyword." Then we will display these sentence with the keywords bolded.

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="bom", document=document)
# Out:
# Todos o conheciam, todos o repetiam em alto e **bom** som para que elle o não ignorasse, mas _ella_ amava-o;
# Tudo que houvera **bom** na sua vida lhe tinha vindo d'ella.
# a imaginar quanto seria **bom** ser muito rico, viver na alta roda, n'aquella esphera aristocratica e distincta em que se não trabalha, em que se falla de um modo especial e caracteristico, com termos escolhidos, com inflexões muito mais suaves, com uns certos desdens que d'antes lhe pareciam ridiculos e que lhe estavam agora parecendo superiormente requintados.
# vêl-o porque soube que tem sido muito **bom** para Thadeu, excellente mesmo.
# Sempre é **bom**.
# Vê como elle é **bom**.
# Henrique pedira com tão meigas e sentidas palavras a Thadeu para que elle os não deixasse, que depois da viagem de rigor feita pelos noivos á Suissa e á Italia o _**bom** cão fiel_ foi viver junto d'elles.
# Henrique sempre **bom**, sério, pensativo, de uma indulgencia de forte, de uma doçura de heroe.
# --Obrigado, vae **bom**!
# --Não que elle gosta do que é **bom**!
# Tornava o **bom** do lavrador, com as lagrimas nos olhos.
# Que eram horas d'elle estar a estudar; que não era **bom**
# --E olhe que era um **bom** homem!
# Filho segundo de uma casa de **bom** nome na provincia do Minho, cursava
# d'elle ás suas, mostrar lhe bem claro, que o adorava pelo que elle transmittia a sua vida de elegante e de superior, mas que o considerava um objecto raro adquirido por muito **bom** preço, e do qual dispunha absolutamente.
# A casa do visconde das Lagôas tornou-se a _mansão de todos os prazeres_, como o **bom** do homem dizia na praça aos seus amigos titulares e merceeiros.
# É que a mulher que gosta de brilhar, não sabe o que é sacrificio e abnegação, é que para mim todos os encantos que se apreciam nas salas, não valem um **bom** e candido coração que saiba amar-me e viver só para mim.
# Gosto do **bom** que ha em todas as escolas.
# A uma aspiração delicada, a tudo que é bello e **bom**.
# Sabes quem são os meus mestres do **bom** e do bello?
# Com mil **bom**bas!
# O contra-mestre olhava de cima aquelle quadro e murmurava entre alegre e melancolico:  --Parece que é **bom** ter familia e ter uma pequerrucha bonita como a do capitão que nos venha dar um abraço quando vimos de longe...
# --A modo que elle não estava **bom**!
# **bom** nadador é elle, dizia o contra-mestre, mas se ha tubarões assim!
# O capitão apesar de **bom** nadador já estava velho
# um **bom** sorriso beatifico e dourado de mocidade que lhe illuminou o semblante.
# O presunto vamos com Deus, que tambem me sahiu **bom**.
# que **bom** e que intimo foi aquelle jantar!
# --Ha quarenta annos que não durmo um somno tão **bom**, minha mãe!
# No meio d'isto, despretenciosa e simples, julgando-se a mais ignorante das creaturinhas do **bom** Deus, não sabendo que era artista, que era intelligente, que tinha alma capaz de entender todas as grandes cousas.
# emquanto a _commendadora_ meditava o rol d'aquelle dia, digerindo um **bom** jantar, e um ataque de furia contra as suas criadas presentes e futuras, emquanto as meninas debruçadas á janella, trocavam substanciosos commentarios
# A MORTE DE BERTHA  (A NALY)   Minha Naly, ás vezes nos teus dias de **bom** humor, e sobre tudo nos raros dias em que estás um pouco menos traquinas, vens sentar-te ao pé de mim, n'um banco pequenino, e pegando n'um livro,--o teu livro de grandes bonecos coloridos--, finges que estás lendo umas cousas que a tua inquieta phantasiasinha de duende te representa, escriptas n'aquellas paginas ainda mudas para os olhos da tua intelligencia.
# a alma de Bertha expandia-se naturalmente para tudo que é **bom** e que é bello.
# Ellas dão sombra, dão frescura, dão fructos, dão flôr, dão um **bom** cheiro sadio, que reconforta e alegra;
# Bertha, ora ennovellada aos pés da mãe, nas felpas avelludadas do tapete, e com os grandes olhos curiosos fitos nos d'ella, ora folheando um grande livro de imagens--como o teu, minha Naly--, ora empoleirada no espaldar da larga poltrona onde o pae estava sentado, e passando-lhe a pequenina mão crestada pela cabelladura revolta e crespa, Bertha era a mais feliz das creaturinhas do **bom** Deus!
# Que **bom**!
# Como é **bom** ir para o céo!
# Os outros não téem o talento d'elle, não téem o alcance funesto ou **bom**, mas em todo o caso poderosissimo da sua obra, não téem a sua paciencia de benedictino, exercida com os processos da nova escola.
# E depois são taes os exageros e desmandos da chamada _escola realista_, é tal o amesquinhamento a que ella reduz a humanidade, que é **bom** que um escriptor de tão prestigiosa eloquencia como é _Octavio Feuillet
# N'esta era de transformação e de incerta claridade, é **bom** que uma voz se erga e diga bem alto que a paixão só é criminosa quando mal dirigida, que o excesso do sentimento só é ridiculo quando mal applicado, que a abnegação inteira e absoluta tem gozos superiores a todos os gozos da materia, e que as almas boas e as almas grandes descobriram uma linguagem mysteriosa, na qual fallam com Deus.
# sympathico, **bom**, com vaidades inoffensivas, e austeros orgulhos, sedento de um affecto _unico_, e de uma _celebridade_ que fosse só d'elle.
# porque elle, que soube pintar tão bem os cynicos, os depravados, os terriveis escarnecedores, cujo riso corroia como um caustico, era no intimo **bom**, quasi infantil; depois confidencias, esperanças, sonhos politicos, sonhos financeiros, sonhos industriaes, planos gigantescos de trabalho, phantasias de artista, desejos de mulher garrida e bonita, observações profundas, divagações poeticas, melancolias de alma
# Será **bom** que a gente peça a Deus d'aqui por diante nas suas orações mais fervorosas não excitar a dedicada admiração d'aquella illustre, mas indiscreta dama!
# É **bom** que tenhamos isto sempre bem presente, para que não sejamos accintosamente inimigos do que foi, nem loucamente vaidosos do que vai ser.
# É **bom** que o repitamos:
# Nunca se deu ao trabalho de improvisar arrojos de eloquencia, tinha sempre ao serviço das suas convicções umas anecdotas a um tempo cheias de graça e de **bom** senso, umas pequenas historias que deitavam por terra
# Não que elle fizesse nenhum d'esses discursos tribunicios que arrastam e enthusiasmam as massas, mas sempre pela força irresistivel do seu **bom**
# Marion, de Magdalena impudica e triumphante, levanta-se Magdalena arrependida e piedosa, e Esmeralda não tem a esmola, a caridade de um sorriso **bom** para Quasimodo!

# %% [markdown]
# ## Get Keyword in Context

# %% [markdown]
# We can also find out about a keyword's more immediate context — its neighboring words to the left and right — and we can fine-tune our search with POS tagging.
#
# To do so, we will first create a list of what's called *ngrams*. "Ngrams" are any sequence of *n* tokens in a text. They're an important concept in computational linguistics and NLP. (Have you ever played with [Google's *Ngram* Viewer](https://books.google.com/ngrams)?)
#
# Below we're going to make a list of *bigrams*, that is, all the two-word combinations from the sample text. We're going to use these bigrams to find the neighboring words that appear alongside particular keywords.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %% [markdown]
# Let's take a peek at the bigrams:

# %%
bigrams[5:20]
# Out:
# [[('Era', 'AUX'), ('uma', 'DET')],
#  [('uma', 'DET'), ('physionomia', 'NOUN')],
#  [('physionomia', 'NOUN'), ('incaracteristica', 'ADJ')],
#  [('incaracteristica', 'ADJ'), ('apagada', 'VERB')],
#  [('apagada', 'VERB'), ('tristissima', 'ADJ')],
#  [('tristissima', 'ADJ'), ('Não', 'ADV')],
#  [('Não', 'ADV'), ('se', 'PRON')],
#  [('se', 'PRON'), ('podia', 'VERB')],
#  [('podia', 'VERB'), ('dizer', 'VERB')],
#  [('dizer', 'VERB'), ('a', 'DET')],
#  [('a', 'DET'), ('idade', 'NOUN')],
#  [('idade', 'NOUN'), ('que', 'PRON')],
#  [('que', 'PRON'), ('tinha', 'VERB')],
#  [('tinha', 'VERB'), ('nem', 'CCONJ')],
#  [('nem', 'CCONJ'), ('mesmo', 'ADV')]]

# %% [markdown]
# Now that we have our list of bigrams, we're going to make a function `get_neighbor_words()`. This function will return the most frequent words that appear next to a particular keyword. The function can also be fine-tuned to return neighbor words that match a certain part of speech by changing the `pos_label` parameter.

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("bom", bigrams)
# Out:
# [('é', 10),
#  ('que', 8),
#  ('e', 7),
#  ('do', 6),
#  ('um', 6),
#  ('de', 4),
#  ('o', 3),
#  ('na', 2),
#  ('muito', 2),
#  ('para', 2),
#  ('nadador', 2),
#  ('sorriso', 2),
#  ('deus', 2),
#  ('senso', 2),
#  ('som', 1),
#  ('houvera', 1),
#  ('seria', 1),
#  ('ser', 1),
#  ('agora', 1),
#  ('eu', 1),
#  ('cão', 1),
#  ('sempre', 1),
#  ('sério', 1),
#  ('vae', 1),
#  ('era', 1),
#  ('das', 1),
#  ('homem', 1),
#  ('nome', 1),
#  ('preço', 1),
#  ('a', 1),
#  ('ter', 1),
#  ('estava', 1),
#  ('disse', 1),
#  ('capitão', 1),
#  ('sahiu', 1),
#  ('vaes', 1),
#  ('tão', 1),
#  ('minha', 1),
#  ('jantar', 1),
#  ('humor', 1),
#  ('cheiro', 1),
#  ('ir', 1),
#  ('ou', 1),
#  ('mas', 1),
#  ('sympathico', 1),
#  ('com', 1),
#  ('intimo', 1),
#  ('quasi', 1),
#  ('será', 1),
#  ('seu', 1)]

# %%
get_neighbor_words("bom", bigrams, pos_label='VERB')
# Out:
# [('houvera', 1), ('ter', 1), ('disse', 1), ('ir', 1)]

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Try out `find_sentences_with_keyword()` and `get_neighbor_words` with your own keywords of interest.

# %%
find_sentences_with_keyword(keyword="YOUR KEY WORD", document=document)

# %%
get_neighbor_words(keyword="YOUR KEY WORD", bigrams, pos_label=None)
