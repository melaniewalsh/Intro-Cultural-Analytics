# %% [markdown]
# # Part-of-Speech Tagging for Spanish

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# In this lesson, we're going to learn about the textual analysis methods *part-of-speech tagging* and *keyword extraction* for Spanish-language texts. These methods will help us computationally parse sentences and better understand words in context.

# %% [markdown]
# ---

# %% [markdown]
# ## spaCy and Natural Language Processing (NLP)

# %% [markdown]
# To computationally identify parts of speech, we're going to use the natural language processing library spaCy. For a more extensive introduction to NLP and spaCy, see the previous lesson.
#
# To parse sentences, spaCy relies on machine learning models that were trained on large amounts of labeled text data. If you've used the preprocessing or named entity recognition notebooks for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.

# %%
# !pip install -U spacy

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# We're also going to import the `Counter` module for counting nouns, verbs, adjectives, etc., and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the Spanish-language model (`es_core_news_md`), which will be processing and making predictions about our texts. This is the model that was trained on the annotated ["AnCora" corpus](http://clic.ub.edu/corpus/). You can download the `es_core_news_md` model by running the cell below:

# %%
# !python -m spacy download es_core_news_md
# Out:
# Collecting es-core-news-md==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.1.0/es_core_news_md-3.1.0-py3-none-any.whl (42.7 MB)
#      |████████████████████████████████| 42.7 MB 6.3 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from es-core-news-md==3.1.0) (3.1.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (8.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.0.8)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.7.4)
# Requirement already satisfied: pathy>=0.3.5 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.6.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.20.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.25.1)
# Requirement already satisfied: jinja2 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.11.3)
# Requirement already satisfied: setuptools in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (52.0.0.post20210125)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.0.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (20.9)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (4.59.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/melwalsh/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->es-core-news-md==3.1.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including Chinese, German, French, Spanish, Portuguese, Russian, Italian, Dutch, Greek, Norwegian, and Lithuanian*.
#
# *spaCy offers language and tokenization support for other language via external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('es_core_news_md')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.

# %%
filepath = '../texts/es.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Part-of-Speech Tagging
# The tags that spaCy uses for part-of-speech are based on work done by [Universal Dependencies](https://universaldependencies.org/), an effort to create a set of part-of-speech tags that work across many different languages. Texts from various languages are annotated using this common set of tags, and contributed to a common repository that can be used to train models like spaCy.
#
# The Universal Dependencies page has information about the annotated corpora available for each language; it's worth looking into the corpora that were annotated for your language.

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# Above is a POS chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different parts of speech that spaCy can identify as well as their corresponding labels. To quickly see spaCy's POS tagging in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) on our sample `document` with the `style=` parameter set to "dep" (short for dependency parsing):

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.lemma_` attribute for each token, which gives us the un-inflected version of the word. We'll also pull out the  `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.lemma_, token.pos_, token.dep_)
# Out:
# ﻿INTRODUCCION PROPN ROOT
# . PUNCT punct
#
#
#
#  SPACE ROOT
# economía NOUN nsubj
# político ADJ amod
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# sombrío ADJ amod
# Prudhon PROPN nsubj
# , PUNCT punct
# imbuído ADJ amod
# , PUNCT punct
# sin ADP advmod
# duda NOUN fixed
# , PUNCT punct
# en ADP case
# el DET det
# idea NOUN nmod
# de ADP case
# el DET det
# Santos PROPN nmod
#
#  SPACE punct
# Padres PROPN nsubj
# de ADP case
# el DET det
# Iglesia PROPN nmod
# que PRON nsubj
# predicar VERB acl
# el DET det
# desden PROPN obj
# por ADP case
# el DET det
# bien NOUN obl
#
#  SPACE obj
# terrenal ADJ obj
# , PUNCT punct
# decir VERB ROOT
# que SCONJ mark
# el DET det
# pobreza NOUN nsubj
# ser AUX cop
# uno DET det
# ley NOUN ccomp
# de ADP case
# nuestro DET det
# naturaleza NOUN nmod
# , PUNCT punct
#
#  SPACE case
# ley NOUN obl
# bajo ADP case
# el DET det
# cual PRON obl
# haber AUX aux
# ser AUX aux
# constituer VERB acl
# , PUNCT punct
# de ADP mark
# donde PRON obl
# él PRON obj
# deducir VERB acl
# que SCONJ mark
# el DET det
#
#  SPACE nsubj
# pauperismo NOUN nmod
# ser AUX cop
# mal ADV ccomp
# que SCONJ mark
# no ADV advmod
# tener VERB advcl
# remedio NOUN obj
# ni CCONJ cc
# cura NOUN conj
# . PUNCT punct
#
#
#  SPACE ROOT
# mucho ADV advmod
# desconsolado ADJ obj
# deber VERB aux
# quedar VERB advcl
# el DET det
# menesteroso NOUN nsubj
# con ADP case
# tanto ADV advmod
# ingrato ADJ amod
#
#  SPACE punct
# noticia NOUN ROOT
# , PUNCT punct
# pero CCONJ cc
# el DET det
# actividad NOUN nsubj
# humano ADJ amod
# , PUNCT punct
# que PRON nsubj
# no ADV advmod
# siempre ADV advmod
# él PRON obj
# llevar VERB acl
# de ADP case
# teoría NOUN obl
# , PUNCT punct
#
#  SPACE dep
# haber AUX aux
# venir VERB conj
# á ADP mark
# confortar VERB advcl
# á ADP case
# el DET det
# aflijido NOUN obj
# trayéndoles VERB acl
# más ADV advmod
# plausibl ADJ obj
# nuevo ADJ amod
#
#  SPACE obj
# y CCONJ cc
# mucho ADV advmod
# eficaz ADJ amod
# promesa NOUN conj
# . PUNCT punct
# el DET det
# industria NOUN nsubj
# , PUNCT punct
# con ADP case
# su DET det
# innúmera ADJ amod
# palanca NOUN nmod
# de ADP case
#
#  SPACE nmod
# impulsion PROPN amod
# ; PUNCT punct
# el DET det
# ciencia NOUN appos
# , PUNCT punct
# con ADP case
# su DET det
# multiplicado ADJ amod
# alfiler NOUN nmod
# de ADP case
# exámen NOUN nmod
# ; PUNCT punct
# el DET det
#
#  SPACE appos
# cálculo NOUN amod
# , PUNCT punct
# con ADP case
# su DET det
# prevision NOUN nmod
# y CCONJ cc
# su DET det
# aritmética NOUN conj
# ; PUNCT punct
# todo DET det
# este DET det
# agente NOUN appos
# de ADP case
# el DET det
#
#  SPACE nmod
# vitalidad NOUN nmod
# social ADJ amod
# , PUNCT punct
# haber AUX aux
# venir VERB ROOT
# á ADP mark
# operar VERB xcomp
# el DET det
# milagro NOUN obj
# de ADP case
# el DET det
# multiplicacion PROPN nmod
#
#  SPACE appos
# del ADP case
# pan NOUN nmod
# y CCONJ cc
# el DET det
# aumento NOUN conj
# del ADP case
# vino NOUN nmod
# , PUNCT punct
# sustentar VERB advcl
# anchamente ADV advmod
# á ADP case
# el DET det
# hambriento NOUN obj
#
#  SPACE obj
# y CCONJ cc
# engordar VERB conj
# , PUNCT punct
# hasta ADP case
# más ADV advmod
# no ADV advmod
# poder NOUN xcomp
# , PUNCT punct
# á ADP case
# el DET det
# harto NOUN obl
# . PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# manera NOUN nsubj
# de ADP mark
# realizar VERB acl
# el DET det
# prodigio NOUN obj
# él PRON obj
# haber AUX aux
# dar VERB ROOT
# á ADP case
# conocer VERB compound
# ese DET det
# venerable ADJ nsubj
#
#  SPACE punct
# matrona NOUN fixed
# , PUNCT punct
# que SCONJ mark
# el DET det
# entendido ADJ nsubj
# en ADP case
# materia NOUN nmod
# grave ADJ amod
# creer VERB advcl
# que SCONJ mark
# denominar VERB ccomp
#
#  SPACE nsubj
# _ ADJ amod
# Economía PROPN nsubj
# político ADJ amod
# _ ADJ amod
# . PUNCT punct
# este DET det
# tutriz NOUN nsubj
# moralizadoro ADJ amod
# de ADP case
# el DET det
# sociedad NOUN nmod
# , PUNCT punct
#
#  SPACE aux
# evidenciar VERB acl
# el DET det
# fecundidad NOUN obj
# del ADP case
# trabajo NOUN nmod
# y CCONJ cc
# el DET det
# beneficio NOUN conj
# del ADP case
# ahorro NOUN nmod
# , PUNCT punct
# él PRON iobj
#
#  SPACE appos
# haber AUX aux
# proponer VERB ROOT
# dignificar VERB xcomp
# al ADP case
# hombre NOUN obj
# otorgar él VERB advcl
# el DET det
# medio NOUN obj
# de ADP mark
# sacudir VERB acl
# el DET det
#
#  SPACE obj
# vasallaje NOUN flat
# servil NOUN flat
# de ADP case
# el DET det
# indigencia NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# ahorro NOUN nsubj
# , PUNCT punct
# tomar VERB acl
# forma NOUN obj
# colectivo ADJ amod
# , PUNCT punct
# haber AUX aux
# dar VERB conj
# orígen NOUN obj
# á ADP case
# el DET det
# más ADV advmod
# precioso ADJ amod
# de ADP case
#
#  SPACE nmod
# el DET det
# combinación NOUN obj
# especulativo ADJ amod
# : PUNCT punct
# á ADP mark
# el DET det
# que PRON nsubj
# tener VERB advcl
# por ADP case
# objeto NOUN obl
# asegurar VERB acl
# el DET det
#
#  SPACE amod
# bienestar NOUN obj
# individual ADJ amod
# en ADP case
# vida NOUN nmod
# y CCONJ cc
# garantir VERB conj
# el DET det
# porvenir NOUN obj
# de ADP mark
# el DET det
# que PRON nsubj
# quedar VERB acl
# , PUNCT punct
#
#  SPACE dep
# despues PROPN flat
# de ADP case
# concluido ADJ flat
# el DET det
# jornada NOUN nsubj
# . PUNCT punct
#
#
#  SPACE ROOT
# este DET det
# tema NOUN nsubj
# , PUNCT punct
# abstracto ADJ amod
# de ADP case
# suyo DET nmod
# , PUNCT punct
# y CCONJ cc
# que PRON nsubj
# parecer VERB conj
# ageno NOUN obj
# al ADP case
# dominio NOUN obj
# del ADP case
# arte NOUN nmod
# , PUNCT punct
#
#  SPACE dep
# acabar VERB ROOT
# de ADP mark
# ser AUX aux
# desenvolver VERB xcomp
# por ADP case
# el DET det
# ilustre ADJ amod
# escritora NOUN obl
# cuyo PRON nmod
# nombre NOUN nsubj
# ocupar VERB acl
# tanto ADV advmod
#
#  SPACE obj
# elevado ADJ amod
# rango NOUN obj
# en ADP case
# el DET det
# gerarquía NOUN obl
# del ADP case
# movimiento NOUN nmod
# intelectual ADJ amod
# americano ADJ amod
# . PUNCT punct
#
#
#  SPACE nsubj
# ser AUX cop
# atributo NOUN ROOT
# de ADP case
# el DET det
# inteligencia NOUN nmod
# creador ADJ amod
# trasformar VERB advcl
# y CCONJ cc
# embellecer VERB conj
#
#  SPACE appos
# el DET det
# idea NOUN obj
# que PRON nsubj
# pasar VERB acl
# por ADP case
# su DET det
# espíritu NOUN obj
# ; PUNCT punct
# parecer VERB advcl
# que SCONJ mark
# poseer VERB ccomp
# ese DET det
# don NOUN nsubj
#
#  SPACE aux
# vivificador NOUN xcomp
# de ADP case
# el DET det
# lujuriós ADJ amod
# primavera NOUN nmod
# que SCONJ mark
# todo DET det
# él PRON det
# hermosear VERB advcl
# , PUNCT punct
# él PRON obj
# cubrir VERB advcl
# de ADP case
#
#  SPACE obl
# flor NOUN flat
# y CCONJ cc
# él PRON det
# esmalta NOUN conj
# de ADP case
# celaj NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# Por ADP mark
# si SCONJ mark
# existir VERB advcl
# incrédulo NOUN nsubj
# que SCONJ mark
# poner VERB csubj
# en ADP case
# duda NOUN compound
# el DET det
# aserto NOUN nsubj
# , PUNCT punct
# invoco ADJ amod
# por ADP case
#
#  SPACE nmod
# testigo NOUN nsubj
# , PUNCT punct
# en ADP case
# mi DET det
# abono NOUN obl
# , PUNCT punct
# el DET det
# presente ADJ amod
# libro NOUN appos
# . PUNCT punct
#
#
#  SPACE ROOT
# su DET det
# autora NOUN nsubj
# comprobar VERB advcl
# , PUNCT punct
# bajo ADP case
# el DET det
# forma NOUN obl
# atrayente ADJ amod
# de ADP case
# el DET det
# novela NOUN nmod
# , PUNCT punct
# el DET det
#
#  SPACE conj
# beneficio NOUN nmod
# que PRON nsubj
# reportar VERB acl
# el DET det
# trabajo NOUN obj
# , PUNCT punct
# el DET det
# perseverancia NOUN appos
# y CCONJ cc
# el DET det
# ahorro NOUN conj
# ; PUNCT punct
# nunca ADV advmod
#
#  SPACE case
# uno DET det
# tema NOUN nmod
# económico ADJ amod
# haber AUX aux
# ser AUX aux
# tratar VERB advcl
# con ADP case
# más ADV advmod
# galanura NOUN obl
# , PUNCT punct
# con ADP case
# más ADV advmod
# gracia NOUN obl
#
#  SPACE case
# picarezca PROPN nmod
# , PUNCT punct
# ni CCONJ cc
# con ADP case
# más ADV advmod
# natural ADJ amod
# é CCONJ advmod
# ingénuo ADJ amod
# intrigo ADJ conj
# . PUNCT punct
#
#
#  SPACE nsubj
# Despues PROPN flat
# de ADP mark
# recorrer VERB acl
# este DET det
# trozo NOUN obj
# de ADP case
# historia NOUN nmod
# social ADJ amod
# , PUNCT punct
# cuyo PRON nmod
# trama NOUN iobj
# él PRON obj
# formar VERB acl
#
#  SPACE ROOT
# el DET det
# peripecia NOUN nsubj
# de ADP case
# dos NUM nummod
# caractér NOUN nmod
# noble ADJ amod
# y CCONJ cc
# fuerte ADJ conj
# , PUNCT punct
# él PRON obj
# encontrar VERB ccomp
# no ADV advmod
# saber VERB xcomp
#
#  SPACE dep
# qué PRON ROOT
# de ADP case
# consolatorio NOUN nmod
# , PUNCT punct
# de ADP case
# purificador NOUN conj
# , PUNCT punct
# en ADP case
# medio NOUN fixed
# de ADP fixed
# el DET det
# arenoso ADJ amod
# senda NOUN nmod
# por ADP case
#
#  SPACE nmod
# donde PRON obl
# yo PRON obj
# conducir VERB acl
# diariamente ADV advmod
# el DET det
# mano NOUN obj
# de ADP case
# el DET det
# tristeza NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# Si SCONJ mark
# el DET det
# mision NOUN nsubj
# de ADP case
# el DET det
# cultor NOUN nmod
# privilegiado ADJ amod
# del ADP case
# arte NOUN nmod
# ser AUX cop
# el DET det
# de ADP mark
# alentar VERB acl
# , PUNCT punct
#
#  SPACE punct
# el DET det
# de ADP case
# consolar VERB nmod
# , PUNCT punct
# el DET det
# de ADP case
# dilatar VERB acl
# el DET det
# horizonte NOUN obj
# de ADP case
# el DET det
# esperanza NOUN nmod
# , PUNCT punct
# el DET det
#
#  SPACE appos
# prestigioso ADJ amod
# autora NOUN obj
# de ADP case
# este DET det
# página NOUN nmod
# haber AUX aux
# saber VERB advcl
# encerrar VERB xcomp
# en ADP case
# él PRON obl
# , PUNCT punct
#
#  SPACE conj
# suficiente ADJ amod
# rayo NOUN obj
# de ADP case
# luz NOUN nmod
# para ADP mark
# satisfacer VERB advcl
# el DET det
# ansiedad NOUN obj
# de ADP case
# el DET det
# alma NOUN nmod
#
#  SPACE appos
# soñadora ADJ amod
# , PUNCT punct
# y CCONJ cc
# bastante DET det
# rosa NOUN conj
# para ADP mark
# coronar VERB acl
# , PUNCT punct
# aunque SCONJ mark
# él PRON nsubj
# no ADV advmod
# él PRON obj
# querer VERB advcl
# , PUNCT punct
#
#  SPACE case
# el DET det
# adusta ADJ amod
# efigie NOUN conj
# de ADP case
# el DET det
# más ADV advmod
# hipocondriaco NOUN nmod
# economista ADJ amod
# . PUNCT punct
#
#
#                                                 SPACE nmod
# s. NOUN ROOT
# vaca-guzman NOUN flat
# . PUNCT punct
#
#
#      SPACE ROOT
# Diciembre PROPN appos
# 22 NUM compound
# de ADP case
# 1887 NUM compound
# . PUNCT punct
#
#
#
#
#
#                        SPACE amod
# OASIS PROPN ROOT
# EN ADP case
# el DET det
# VIDA PROPN flat
# . PUNCT punct
#
#
#                       SPACE ROOT
# Á PROPN flat
# « PUNCT punct
# el DET det
# BUENOS PROPN appos
# AIRES PROPN flat
# » PUNCT punct
#
#
#                                        SPACE flat
# _ ADJ flat
# el DET det
# autora NOUN appos
# . PUNCT punct
# _ PROPN nsubj
#
#
#
#
#
#  SPACE ROOT
# OASIS PROPN obj
# EN ADP case
# el DET det
# VIDA PROPN obl
# . PUNCT punct
#
#
#
#
#
#  SPACE ROOT
# I CCONJ obj
#
#
#
#  SPACE amod
# --¡Bah!--exclamó PROPN punct
# Mauricio PROPN nsubj
# Ridel PROPN flat
# , PUNCT punct
# arrojar VERB advcl
# el DET det
# pluma PROPN obj
# despues PROPN appos
# de ADP mark
# escribir VERB acl
#
#  SPACE nsubj
# el DET det
# palabra NOUN obj
# Fin PROPN appos
# bajo ADP case
# el DET det
# último ADJ amod
# línea NOUN obl
# de ADP case
# uno DET det
# cuartilla NOUN nmod
# marcado ADJ amod
# con ADP case
# el DET det
#
#  SPACE obj
# guarismo NOUN appos
# 60 NUM compound
# . PUNCT punct
#
#
#  SPACE nsubj
# --¿qué AUX punct
# ser AUX cop
# eso?--interrogar VERB ROOT
# uno DET det
# jóven NOUN nsubj
# que PRON nsubj
# escribir VERB acl
# allí ADV advmod
# cerca ADV advmod
# . PUNCT punct
#
#
#  SPACE ROOT
# --El PUNCT punct
# postrer NOUN obj
# párrafo NOUN compound
# del ADP case
# folletin--respondeír VERB nmod
# Mauricio PROPN appos
# , PUNCT punct
# alargar VERB acl
# el DET det
#
#  SPACE obj
# hoja NOUN amod
# á ADP case
# uno DET det
# cajista NOUN obj
# que PRON obj
# aguardar VERB acl
# . PUNCT punct
#
#
#  SPACE ROOT
# --¡cómo NUM nummod
# ! PUNCT punct
# ¿ PUNCT punct
# mañana ADV advmod
# acabar VERB advcl
# chamusquinas ADJ obj
# DE ADP case
# AMOR PROPN obl
# ? PUNCT punct
# hoy ADV advmod
# quedar VERB ROOT
# su DET det
# héroe NOUN nsubj
#
#  SPACE nsubj
# en ADP case
# uno DET det
# situacion NOUN obl
# extremo ADJ amod
# : PUNCT punct
# el DET det
# mano NOUN nsubj
# armado ADJ amod
# de ADP case
# uno DET det
# revólver NOUN nmod
# , PUNCT punct
# esperar VERB advcl
#
#  SPACE obj
# para ADP mark
# morir VERB advcl
# el DET det
# primero ADJ amod
# rayo NOUN obj
# de ADP case
# sol NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# ya ADV advmod
# , PUNCT punct
# este PRON nsubj
# comenzar VERB conj
# á ADP mark
# dorar VERB xcomp
# el DET det
#
#  SPACE nsubj
# copa NOUN obl
# de ADP case
# el DET det
# árbol NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# al ADP mark
# ver él VERB advcl
# , PUNCT punct
# « PUNCT det
# Enrique PROPN nsubj
# apoyar VERB conj
# el DET det
# arma NOUN obj
# contra ADP case
# el DET det
#
#  SPACE nmod
# corazon PROPN flat
# , PUNCT punct
# enviar VERB advcl
# á ADP case
# María PROPN obj
# su DET det
# último ADJ amod
# pensamiento NOUN obj
# ; PUNCT punct
# á ADP case
# Dios PROPN appos
# su DET det
# último ADJ amod
#
#  SPACE flat
# plegaria NOUN nmod
# . PUNCT punct
# »--¿muere ADV ROOT
# ? PUNCT punct
#
#
#  SPACE ROOT
# --no ADV advmod
# ; PUNCT punct
# porque--«de VERB conj
# repente NOUN advmod
# , PUNCT punct
# uno DET det
# brazo NOUN nsubj
# cariñoso ADJ amod
# rodear VERB conj
# su DET det
# cuello NOUN obj
# ; PUNCT punct
# uno DET det
# rostro NOUN nsubj
#
#  SPACE advmod
# pálido ADJ amod
# y CCONJ cc
# mojado ADJ conj
# de ADP case
# lágrima NOUN nmod
# él PRON obj
# apoyar VERB advcl
# en ADP case
# su DET det
# rostro NOUN obl
# ... PUNCT punct
#
#
#  SPACE nsubj
# --¡Perdon PROPN flat
# ! PUNCT punct
#
#
#  SPACE flat
# --¡perdon!--se NUM appos
# oir VERB ROOT
# á ADV advmod
# el DET fixed
# vez NOUN fixed
# ... PUNCT punct
#
#
#  SPACE punct
# « PUNCT punct
# Y CCONJ cc
# el DET det
# primero ADJ amod
# rayo NOUN nsubj
# de ADP case
# sol NOUN nmod
# aguardado ADJ amod
# como SCONJ mark
# uno DET det
# señal NOUN obl
# de ADP case
# muerte NOUN nmod
# , PUNCT punct
# fué AUX cop
# el DET det
#
#  SPACE advcl
# auroro ADJ nmod
# de ADP case
# su DET det
# felicidad NOUN nmod
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE punct
# --¡bien NUM punct
# ! PUNCT punct
# ¡ PUNCT punct
# oh INTJ obj
# ! PUNCT punct
# ¡ PUNCT punct
# qué PRON obj
# bien!--aplaudeír VERB dep
# el DET det
# otro PRON nsubj
# ; PUNCT punct
# y CCONJ cc
# añadir VERB conj
# con ADP case
# dramático ADJ amod
#
#  SPACE obj
# ademan PROPN obj
# : PUNCT punct
#
#
#  SPACE appos
# --¡ah NUM nmod
# ! PUNCT punct
# que SCONJ mark
# no ADV advmod
# haber AUX advcl
# para ADP case
# yo PRON obl
# , PUNCT punct
# pária NOUN conj
# del ADP case
# destino NOUN nmod
# , PUNCT punct
# ¡ PUNCT punct
# uno DET det
# rayo NOUN obj
# de ADP case
# sol NOUN nmod
#
#  SPACE appos
# que SCONJ mark
# venir VERB ccomp
# á ADP mark
# redimir yo VERB advcl
# ! PUNCT punct
#
#
#  SPACE ROOT
# --sí ADV obj
# : PUNCT punct
# y CCONJ cc
# más ADV conj
# que SCONJ mark
# uno PRON obl
# : PUNCT punct
# dos--repuso NOUN advmod
# Mauricio.--La PROPN appos
# resignacion PROPN flat
# y CCONJ cc
# el DET det
# trabajo NOUN conj
# . PUNCT punct
#
#
#  SPACE nsubj
# --¡la NUM punct
# resignacion PROPN obj
# ! PUNCT punct
# ¡ PUNCT punct
# el DET det
# trabajo!--replicar VERB ROOT
# el DET det
# interlocutor NOUN obj
# con ADP case
# forzado ADJ amod
#
#  SPACE punct
# risa.--solo ADJ amod
# tú PRON obj
# poder AUX aux
# decir VERB advcl
# ese PRON nsubj
# ; PUNCT punct
# tú PRON nsubj
# , PUNCT punct
# que PRON nsubj
# no ADV advmod
# contento ADJ acl
# con ADP case
# el DET det
# tarea NOUN obl
#
#  SPACE advmod
# diario ADJ amod
# , PUNCT punct
# él PRON obj
# haber AUX aux
# subir VERB advcl
# á ADP case
# catorce NUM nummod
# hora NOUN obl
# . PUNCT punct
# catorce NUM nummod
# hora NOUN obl
# , PUNCT punct
# pluma NOUN appos
# en ADP case
# mano NOUN nmod
# , PUNCT punct
#
#  SPACE aux
# encorvado ADJ ROOT
# sobre ADP case
# el DET det
# implacable ADJ amod
# cuartilla NOUN obl
# , PUNCT punct
# y CCONJ cc
# precisamente ADV conj
# , PUNCT punct
# apenas ADV advmod
# en ADP case
#
#  SPACE nmod
# convalecencia NOUN nmod
# de ADP case
# el DET det
# terrible ADJ amod
# herida NOUN nmod
# que PRON nsubj
# casi ADV advmod
# tú PRON obj
# llevar VERB acl
# al ADP case
# sepulcro NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# --sin NUM advmod
# embargo NOUN fixed
# , PUNCT punct
# ya ADV advmod
# él PRON det
# vés PROPN ROOT
# : PUNCT punct
# estar AUX cop
# sano ADJ advcl
# y CCONJ cc
# fuerte ADJ conj
# . PUNCT punct
# uno DET advmod
# poco ADV fixed
# de ADP case
# sueño NOUN fixed
# ; PUNCT punct
# á ADP cc
#
#  SPACE advmod
# vez NOUN fixed
# , PUNCT punct
# uno DET det
# poco ADV obj
# de ADP case
# fatiga NOUN nmod
# ; PUNCT punct
# pero CCONJ cc
# él PRON obj
# pensar VERB conj
# en ADP case
# el DET det
# fin NOUN obl
# propuesto ADJ amod
# , PUNCT punct
# y CCONJ dep
# todo PRON dep
#
#  SPACE punct
# ese PRON nsubj
# volar VERB ccomp
# y CCONJ cc
# él PRON dep
# desvanece.-- PROPN conj
#
#
#  SPACE compound
# hablar VERB advcl
# así ADV advmod
# , PUNCT punct
# Mauricio PROPN nsubj
# consultar VERB ROOT
# su DET det
# reloj NOUN obj
# . PUNCT punct
#
#
#  SPACE obl
# --las NUM punct
# siete--y NOUN nsubj
# levantar él VERB ccomp
# , PUNCT punct
# fué AUX ROOT
# á ADP mark
# tomar VERB ccomp
# de ADP case
# uno DET det
# percha NOUN obj
# su DET det
# sombrero NOUN obj
# . PUNCT punct
#
#
#  SPACE nsubj
# --¡Las PROPN flat
# siete NUM compound
# ! PUNCT punct
# ¡ PUNCT punct
# Con ADP case
# qué DET det
# desenfado NOUN obl
# él PRON obj
# decir VERB advcl
# ! PUNCT punct
# ¿ PUNCT punct
# saber VERB parataxis
# que SCONJ mark
# haber AUX aux
# estar AUX cop
#
#  SPACE aux
# sentar VERB ccomp
# ahí ADV advmod
# , PUNCT punct
# escribir VERB advcl
# desde ADP case
# el DET det
# nueve NOUN obl
# ? PUNCT punct
# ¡ PUNCT punct
# diez NUM nummod
# hora NOUN appos
# ! PUNCT punct
# ¡ PUNCT punct
# Ah INTJ flat
# ! PUNCT punct
# hombre NOUN dep
#
#  SPACE punct
# como SCONJ mark
# este PRON nsubj
# ser AUX cop
# uno DET det
# pésimo ADJ amod
# ejemplo NOUN ROOT
# en ADP case
# el DET det
# Redaccion PROPN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# --Y PROPN nsubj
# tú PRON flat
# , PUNCT punct
# que PRON nsubj
# así ADV advmod
# hablar VERB acl
# , PUNCT punct
# querido ADJ amod
# Emilio PROPN obj
# , PUNCT punct
# ser AUX cop
# uno PRON nsubj
# de ADP case
# su DET det
# mejor ADJ amod
# obrero NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# --a DET advmod
# más ADV advmod
# no ADV advmod
# poder NOUN advcl
# : PUNCT punct
# Sábelo PROPN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# --notificado--decir VERB punct
# Mauricio PROPN conj
# , PUNCT punct
# sonriendo.--ruégote NOUN appos
# que PRON nsubj
# al ADP mark
# salir VERB advcl
# diga NOUN nsubj
# al ADP case
#
#  SPACE obl
# Regente PROPN acl
# que SCONJ mark
# yo PRON obj
# tener VERB ccomp
# lista NOUN obj
# el DET det
# prueba NOUN obj
# para ADP case
# el DET det
# once NUM nummod
# . PUNCT punct
#
#
#  SPACE ROOT
# --Y PROPN det
# correccion NOUN nsubj
# hasta ADP case
# el DET det
# dos NUM nummod
# de ADP case
# el DET det
# mañana NOUN nmod
# . PUNCT punct
# sumar VERB ROOT
# : PUNCT punct
# ¡ PUNCT punct
# catorce NUM nummod
# hora NOUN appos
# ! PUNCT punct
# ... PUNCT punct
#
#  SPACE advmod
# ¡ PUNCT punct
# Adios PROPN obj
# , PUNCT punct
# escriba NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE amod
# --adio NOUN ROOT
# , PUNCT punct
# fariseo.-- PROPN appos
#
#
#  SPACE flat
# Y CCONJ cc
# ambos NUM nsubj
# reír VERB advcl
# . PUNCT punct
#
#
#  SPACE nsubj
# Mauricio PROPN flat
# cerrar VERB ROOT
# su DET det
# carpeta NOUN obj
# y CCONJ cc
# él PRON obj
# fué VERB conj
# . PUNCT punct
#
#
#  SPACE nsubj
# Emilio PROPN flat
# él PRON obj
# extender VERB ROOT
# perezosamente ADV advmod
# en ADP case
# su DET det
# silla NOUN obl
# ; PUNCT punct
# encender VERB advcl
# uno DET det
# cigarro NOUN obj
# , PUNCT punct
# que PRON nsubj
#
#  SPACE nsubj
# aspirar VERB acl
# con ADP case
# ánsia PROPN obl
# ; PUNCT punct
# y CCONJ cc
# arrojar VERB conj
# uno DET det
# largo ADJ amod
# espiral NOUN obj
# de ADP case
# humo NOUN nmod
# , PUNCT punct
# entornar VERB advcl
#
#  SPACE punct
# el DET det
# ojos--¡deliciosa NOUN obl
# fruicion!--exclamó:--¿qué NOUN nmod
# no ADV advmod
# hacer VERB advcl
# tú PRON nsubj
# olvidar VERB xcomp
# ? PUNCT punct
# ... PUNCT punct
#
#  SPACE ROOT
# Y CCONJ advmod
# sin ADP advmod
# embargo NOUN fixed
# , PUNCT punct
# Mauricio PROPN nsubj
# tú PRON obj
# desdeñar VERB conj
# . PUNCT punct
# uncido ADJ ROOT
# á ADP case
# uno DET det
# rudo ADJ amod
# trabajo NOUN nmod
# , PUNCT punct
# pegado ADJ amod
#
#  SPACE punct
# ahí ADV ROOT
# , PUNCT punct
# á ADP case
# ese DET det
# mesa NOUN obl
# de ADP case
# redaccion PROPN nmod
# , PUNCT punct
# hasta ADP case
# el DET det
# codo NOUN obl
# en ADP case
# el DET det
# seccion NOUN nmod
# editorial ADJ amod
# ; PUNCT punct
#
#  SPACE case
# cronista NOUN conj
# , PUNCT punct
# traductor NOUN conj
# , PUNCT punct
# folletinista ADJ conj
# , PUNCT punct
# corrector ADJ conj
# de ADP case
# prueba NOUN nmod
# : PUNCT punct
# ¿ PUNCT punct
# á ADP case
# qué PRON obj
#
#  SPACE advmod
# móvil NOUN compound
# obedecer VERB advcl
# ese DET det
# anhelo NOUN obj
# de ADP mark
# aglomerar VERB acl
# sueldo NOUN obj
# ? PUNCT punct
# él PRON nsubj
# , PUNCT punct
# no ADV advmod
# ser AUX cop
# avaro ADJ ROOT
# ni CCONJ cc
#
#  SPACE conj
# derrochador ADJ amod
# ; PUNCT punct
# no ADV advmod
# frecuentar VERB conj
# club NOUN nsubj
# ni CCONJ cc
# baile NOUN conj
# ; PUNCT punct
# por ADP conj
# tanto NOUN fixed
# , PUNCT punct
# ni CCONJ cc
# jugar VERB conj
# ni ADV advmod
#
#  SPACE xcomp
# galantea NOUN obj
# . PUNCT punct
# en ADP case
# el DET det
# teatro NOUN obl
# tener VERB ROOT
# el DET det
# entrada NOUN obj
# de ADP case
# periodista NOUN nmod
# . PUNCT punct
# ¿ PUNCT punct
# A ADP case
# qué PRON ROOT
# tanto ADV advmod
#
#  SPACE aux
# afan NOUN nsubj
# de ADP mark
# ganar VERB acl
# dinero NOUN obj
# ? PUNCT punct
# ¿ PUNCT punct
# qué PRON obj
# hacer VERB ROOT
# de ADP case
# él PRON obj
# ? PUNCT punct
# no ADV advmod
# ser AUX cop
# mucho ADV ROOT
# , PUNCT punct
# en ADP advmod
# verdad NOUN fixed
# ; PUNCT punct
# pero CCONJ cc
#
#  SPACE conj
# ¿ PUNCT punct
# qué PRON obj
# hacer VERB ccomp
# de ADP case
# él PRON obj
# ? PUNCT punct
# enigmo PRON csubj
# insoluble ADJ amod
# ser AUX cop
# para ADP case
# yo PRON obl
# este DET det
# jóven NOUN xcomp
# , PUNCT punct
# tanto ADV advmod
# franco ADJ amod
# , PUNCT punct
#
#  SPACE punct
# sin ADP conj
# embargo NOUN fixed
# , PUNCT punct
# y CCONJ cc
# tanto ADV advmod
# bueno ADJ conj
# ... PUNCT punct
#
#
#  SPACE nsubj
# Y CCONJ cc
# Emilio PROPN conj
# dejar VERB advcl
# el DET det
# pluma NOUN obj
# en ADP case
# largo ADJ amod
# holgorio NOUN obl
# , PUNCT punct
# quedóse VERB ROOT
# engolfado ADJ obj
# en ADP case
# su DET det
#
#  SPACE obl
# pensamiento NOUN obj
# y CCONJ cc
# en ADP case
# el DET det
# humo NOUN conj
# de ADP case
# su DET det
# cigarro NOUN nmod
# . PUNCT punct
#
#
#
#
#
#  SPACE ROOT
# II PROPN obj
#
#
#
#  SPACE flat
# Mauricio PROPN appos
# él PRON obj
# alejar VERB advcl
# con ADP case
# el DET det
# paso NOUN obl
# presuroso ADJ amod
# , PUNCT punct
# habitual ADJ amod
# en ADP case
# aquel PRON nmod
# que PRON dep
#
#  SPACE aux
# tener VERB advcl
# contado ADJ obj
# el DET det
# tiempo NOUN obj
# . PUNCT punct
#
#
#  SPACE punct
# Aunque SCONJ mark
# en ADP case
# el DET det
# plácido ADJ amod
# edad NOUN obl
# de ADP case
# veinte NUM nummod
# año NOUN nmod
# , PUNCT punct
# y CCONJ cc
# bello ADJ conj
# y CCONJ cc
# apuesto ADJ conj
# , PUNCT punct
# haber AUX ROOT
# en ADP case
# el DET det
#
#  SPACE obj
# expresion NOUN compound
# de ADP case
# su DET det
# semblante NOUN nmod
# ese DET det
# gravedad NOUN obj
# melancólico ADJ amod
# , PUNCT punct
# signo NOUN appos
# de ADP case
# uno DET det
# destino NOUN nmod
#
#  SPACE appos
# adverso ADJ amod
# . PUNCT punct
#
#
#  SPACE nsubj
# En ADP advmod
# verdad NOUN fixed
# , PUNCT punct
# adverso ADJ amod
# haber AUX aux
# ser AUX cop
# el DET det
# destino NOUN ROOT
# para ADP case
# Mauricio PROPN nmod
# : PUNCT punct
# adverso ADJ appos
# desde ADP case
#
#  SPACE fixed
# el DET det
# cuna NOUN nmod
# , PUNCT punct
# mecido ADJ amod
# por ADP case
# mano NOUN obl
# extraño ADJ amod
# , PUNCT punct
# desierto ADJ amod
# de ADP case
# cuidado NOUN obj
# y CCONJ cc
# caricia NOUN conj
# . PUNCT punct
#
#
#  SPACE nsubj
# Y CCONJ advmod
# no ADV advmod
# fué AUX cop
# este PRON conj
# solo ADJ amod
# ¡ PUNCT punct
# ay INTJ dep
# ! PUNCT punct
# no ADV advmod
# fué AUX cop
# este PRON ROOT
# solo ADJ amod
# . PUNCT punct
#
#
#  SPACE nsubj
# cárlos VERB csubj
# Ridel PROPN obj
# , PUNCT punct
# subyugado ADJ amod
# por ADP case
# uno DET det
# pasion NOUN obj
# que PRON nsubj
# causar VERB acl
# el DET det
# muerte NOUN obj
# á ADP case
# su DET det
# esposa NOUN nmod
# , PUNCT punct
#
#  SPACE aux
# llevar VERB advcl
# todavía ADV advmod
# el DET det
# luto NOUN obj
# de ADP case
# el DET det
# viudez NOUN nmod
# , PUNCT punct
# deír VERB ROOT
# uno DET det
# sucesora NOUN obj
# á ADP case
# el DET det
# difunta NOUN obl
# ; PUNCT punct
# á ADP cc
#
#  SPACE fixed
# su DET det
# hijo NOUN obj
# uno DET det
# madrastra NOUN appos
# . PUNCT punct
#
#
#  SPACE nsubj
# ¡ PUNCT punct
# Madrastra PROPN obj
# ! PUNCT punct
# Al ADP mark
# solo NOUN fixed
# pronunciar VERB advcl
# este DET det
# palabra NOUN obj
# de ADP case
# aspereza NOUN nmod
# siniestro ADJ amod
# , PUNCT punct
#
#  SPACE obj
# compréndese VERB ROOT
# el DET det
# tristura NOUN obj
# de ADP case
# ese DET det
# pobre ADJ amod
# niño NOUN nmod
# que PRON nsubj
# crecer VERB acl
# temeroso ADJ obj
# , PUNCT punct
#
#  SPACE appos
# acoquinado ADJ amod
# , PUNCT punct
# bajo ADP case
# aquel DET det
# sombra NOUN obl
# fatídico ADJ amod
# . PUNCT punct
#
#
#  SPACE punct
# Para ADP case
# él PRON obl
# no ADV advmod
# existir VERB ROOT
# el DET det
# alegría NOUN nsubj
# del ADP case
# hogar NOUN nmod
# . PUNCT punct
# siempre ADV advmod
# espiado ADJ ROOT
# por ADP case
# el DET det
#
#  SPACE obj
# mirada NOUN obl
# suspicaz ADJ amod
# de ADP case
# uno DET det
# fiscal NOUN nmod
# inexorable ADJ amod
# que PRON nsubj
# él PRON obj
# achacar VERB acl
# á ADP case
# delito NOUN obj
# su DET det
#
#  SPACE obj
# gozós ADJ amod
# turbulencia NOUN appos
# , PUNCT punct
# su DET det
# inocente ADJ amod
# espontaneidad NOUN obj
# , PUNCT punct
# vuelven él VERB advcl
# taciturno NOUN obj
# , PUNCT punct
#
#  SPACE conj
# desconfiado ADJ amod
# ; PUNCT punct
# ocúltanse ADJ advmod
# para ADP mark
# reir PROPN nmod
# ; PUNCT punct
# ocúltanse ADJ advmod
# para ADP mark
# llorar VERB acl
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# el DET det
#
#  SPACE nmod
# primero ADJ amod
# albor NOUN conj
# de ADP case
# el DET det
# vida NOUN nmod
# , PUNCT punct
# aprender VERB conj
# ese DET det
# triste ADJ amod
# ciencia NOUN obj
# de ADP case
# el DET det
# vejez NOUN nmod
# : PUNCT punct
# el DET det
#
#  SPACE amod
# disimulo NOUN appos
# . PUNCT punct
# ¿ PUNCT punct
# Ni CCONJ cc
# qué DET obj
# otro DET det
# recurso NOUN nsubj
# él PRON obj
# quedar VERB ROOT
# ? PUNCT punct
# ¿ PUNCT punct
# A ADP case
# quién PRON obj
# volver VERB ROOT
# su DET det
# ojo NOUN obj
# ? PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# casa PROPN nsubj
# paterna PROPN flat
# él PRON obj
# haber AUX aux
# tornar VERB ROOT
# para ADP case
# él PRON obl
# en ADP case
# campo NOUN obl
# enemigo ADJ amod
# , PUNCT punct
# donde PRON obl
# todo PRON appos
#
#  SPACE punct
# él PRON obj
# ser AUX cop
# hostil ADJ advcl
# , PUNCT punct
# hasta ADP case
# su DET det
# mismo DET det
# padre NOUN obl
# á ADP mark
# quien PRON nsubj
# no ADV advmod
# él PRON obj
# ser AUX aux
# dar VERB acl
# mostrársel NOUN obj
#
#  SPACE punct
# propicio ADJ obj
# , PUNCT punct
# so ADP case
# pena NOUN obl
# de ADP mark
# despertar VERB acl
# celo NOUN obj
# retrospectivo ADJ amod
# , PUNCT punct
# que PRON nsubj
# empeorar VERB acl
# el DET det
#
#  SPACE obj
# situacion NOUN nmod
# tristísima ADJ amod
# de ADP case
# ese DET det
# náufrago NOUN nmod
# de ADP case
# el DET det
# vida NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# tal DET det
# suerte NOUN obj
# cupo NOUN amod
# á ADP case
# Mauricio PROPN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# Víctima PROPN flat
# de ADP case
# uno DET det
# semejanza NOUN nmod
# que PRON nsubj
# importunar VERB acl
# á ADP case
# su DET det
# padre NOUN obj
# como SCONJ cc
# uno DET det
#
#  SPACE obj
# remordimiento NOUN amod
# , PUNCT punct
# á ADP case
# su DET det
# madrastra NOUN conj
# como SCONJ mark
# uno DET det
# vision NOUN obl
# de ADP case
# ultratumba NOUN nmod
# , PUNCT punct
# vióse NOUN appos
# uno DET det
#
#  SPACE amod
# dia NOUN appos
# arrebatado ADJ amod
# de ADP case
# su DET det
# casa NOUN obl
# y CCONJ cc
# entregar VERB conj
# al ADP case
# capitan NOUN obj
# de ADP case
# uno DET det
# buque NOUN nmod
# inglés ADJ amod
# , PUNCT punct
#
#  SPACE conj
# que SCONJ mark
# él PRON obj
# llevar VERB ccomp
# á ADP case
# Europa PROPN obl
# y CCONJ cc
# él PRON obj
# encerrar VERB conj
# en ADP case
# uno DET det
# colegio NOUN obl
# . PUNCT punct
#
#
#  SPACE ROOT
# Aunque SCONJ mark
# del ADP case
# hogar NOUN obl
# de ADP case
# su DET det
# padre NOUN nmod
# , PUNCT punct
# el DET det
# pobre ADJ amod
# niño NOUN appos
# , PUNCT punct
# solo ADV advmod
# guardar VERB advcl
# cruel ADJ obj
#
#  SPACE case
# recuerdo NOUN nmod
# , PUNCT punct
# el DET det
# lengua NOUN obj
# materno ADJ amod
# , PUNCT punct
# el DET det
# suelo NOUN obj
# de ADP case
# el DET det
# patria NOUN nmod
# , PUNCT punct
# su DET det
# aire NOUN appos
# , PUNCT punct
# su DET det
# luz NOUN appos
# , PUNCT punct
#
#  SPACE conj
# éranle PROPN nmod
# necesario ADJ amod
# , PUNCT punct
# y CCONJ cc
# languideceír VERB conj
# , PUNCT punct
# echar él VERB advcl
# de ADP case
# menos ADV advmod
# . PUNCT punct
#
#
#  SPACE nsubj
# Por ADP case
# dicha NOUN obl
# suyo DET punct
# fué AUX cop
# el DET det
# « PUNCT punct
# bello ADJ amod
# país NOUN ROOT
# de ADP case
# Francia PROPN nmod
# , PUNCT punct
# » PUNCT punct
# el DET det
# hospitalaria NOUN appos
# Paris PROPN appos
# , PUNCT punct
#
#  SPACE case
# el DET det
# lugar NOUN conj
# de ADP case
# su DET det
# destierro NOUN nmod
# . PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# bondad NOUN nsubj
# característico ADJ amod
# de ADP case
# el DET det
# hijo NOUN nmod
# de ADP case
# aquel DET det
# tierra NOUN nmod
# , PUNCT punct
# tener VERB ROOT
# , PUNCT punct
# en ADP obl
#
#  SPACE fixed
# todo DET det
# el DET det
# clase NOUN obj
# social ADJ amod
# , PUNCT punct
# desde ADP case
# el DET det
# aristócrata NOUN obl
# hasta ADP case
# el DET det
# obrero NOUN nmod
# , PUNCT punct
# uno DET obj
#
#  SPACE fixed
# gracia NOUN nmod
# irresistible ADJ amod
# que PRON nsubj
# cautivar VERB acl
# el DET det
# alma NOUN obj
# y CCONJ cc
# matar VERB conj
# todo DET det
# nostalgia NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# Desde ADP case
# el DET det
# sábio NOUN amod
# Blain PROPN obl
# , PUNCT punct
# director NOUN appos
# del ADP case
# colegio NOUN nmod
# donde PRON obl
# fuar VERB acl
# el DET det
# niño NOUN nsubj
#
#  SPACE flat
# consignado ADJ amod
# , PUNCT punct
# hasta ADP case
# el DET det
# ama NOUN conj
# de ADP case
# llave NOUN nmod
# , PUNCT punct
# el DET det
# buen ADJ amod
# Colombe PROPN appos
# ; PUNCT punct
# desde ADP case
# el DET det
# alumno NOUN nmod
#
#  SPACE flat
# hasta ADP case
# el DET det
# profesor NOUN obl
# : PUNCT punct
# todo PRON nsubj
# acogiéronlo VERB advcl
# con ADP case
# tanto ADV advmod
# benévolo ADJ amod
# conmiseracion NOUN obl
# , PUNCT punct
#
#  SPACE mark
# que SCONJ mark
# primero ADV advmod
# el DET det
# serenidad NOUN nsubj
# y CCONJ cc
# luego ADV advmod
# el DET det
# alegría NOUN conj
# , PUNCT punct
# venir VERB advcl
# como SCONJ mark
# nunca ADV advmod
# , PUNCT punct
#
#  SPACE dep
# expansivo ADJ amod
# á ADP case
# aquel DET det
# pobre ADJ amod
# corazon NOUN obl
# , PUNCT punct
# por ADP case
# tanto DET det
# tiempo NOUN obl
# oprimido ADJ amod
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# desterrado NOUN nsubj
# comenzar VERB ROOT
# á ADP mark
# encontrar él VERB xcomp
# feliz ADJ advmod
# en ADP case
# su DET det
# nuevo ADJ amod
# familia NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# --¡ah!--pensar VERB ROOT
# , PUNCT punct
# recordar VERB advcl
# el DET det
# pasado--¿así NOUN nsubj
# él PRON obj
# amar VERB ccomp
# , PUNCT punct
# él PRON obj
# acariciar VERB conj
# y CCONJ cc
# él PRON conj
#
#  SPACE advcl
# proteger VERB advcl
# ? PUNCT punct
# ¿ PUNCT punct
# Por ADP case
# qué PRON obl
# no ADV advmod
# haber AUX aux
# conocer VERB ROOT
# yo PRON nsubj
# hasta ADP case
# hoy ADV advmod
# , PUNCT punct
# este DET det
# bien NOUN nsubj
# ? PUNCT punct
#
#
#  SPACE ROOT
# Y CCONJ cc
# refugiábar VERB conj
# en ADP case
# ese DET det
# atmósfera NOUN obl
# de ADP case
# caluroso ADJ amod
# afecto NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# sentir VERB conj
# el DET det
# dulce ADJ obj
#
#  SPACE punct
# bienestar VERB flat
# del ADP case
# que PRON nsubj
# renacer VERB acl
# á ADP case
# el DET det
# salud NOUN obl
# despues PROPN appos
# de ADP case
# uno DET det
# largo ADJ amod
# enfermedad NOUN obl
# . PUNCT punct
#
#
#
#
#
#  SPACE ROOT
# III PROPN nsubj
#
#
#
#  SPACE compound
# el DET det
# año NOUN obl
# trascurreír VERB advcl
# así ADV advmod
# , PUNCT punct
# con ADP case
# su DET det
# época NOUN obl
# clásico ADJ amod
# , PUNCT punct
# en ADP case
# el DET det
# vida NOUN conj
# del ADP case
#
#  SPACE nmod
# niño NOUN nmod
# . PUNCT punct
# el DET det
# examen NOUN ROOT
# ; PUNCT punct
# el DET det
# premio NOUN appos
# ; PUNCT punct
# el DET det
# paso NOUN appos
# á ADP case
# estudio NOUN nmod
# superior ADJ amod
# ; PUNCT punct
# el DET det
# del ADP case
#
#  SPACE appos
# vestido ADJ compound
# infantil ADJ obj
# al ADP case
# traje NOUN nmod
# viril ADJ amod
# ; PUNCT punct
# el DET det
# primero ADJ amod
# comunion NOUN appos
# ..... PUNCT punct
#
#
#  SPACE nsubj
# ¡ PUNCT punct
# qué DET det
# ceremonia NOUN obj
# , PUNCT punct
# á ADP case
# el DET det
# vez NOUN nmod
# tanto ADV advmod
# imponente ADJ amod
# y CCONJ cc
# tierno ADJ conj
# ! PUNCT punct
#
#
#  SPACE obj
# cumplido ADJ advmod
# en ADP case
# él PRON obj
# , PUNCT punct
# el DET det
# divino ADJ amod
# misterio NOUN appos
# , PUNCT punct
# de ADP case
# rodilla NOUN obl
# ante ADP case
# el DET det
# altar NOUN nmod
# , PUNCT punct
# el DET det
# niño NOUN obj
#
#  SPACE appos
# tender VERB ROOT
# el DET det
# mano NOUN obj
# sobre ADP case
# el DET det
# Sagrado PROPN nmod
# Libro PROPN flat
# y CCONJ cc
# jura NOUN conj
# ser AUX cop
# virtuoso ADJ advcl
# y CCONJ cc
# bueno ADJ conj
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# celebrante ADJ nsubj
# él PRON det
# bendizar VERB obj
# y CCONJ cc
# colocar VERB conj
# en ADP case
# su DET det
# pecho NOUN obl
# uno DET det
# reliquia NOUN obj
# . PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# voz NOUN nsubj
# del ADP case
# órgano NOUN nmod
# derrama ADJ nmod
# gozosa ADJ amod
# nota NOUN appos
# ; PUNCT punct
# nube NOUN appos
# de ADP case
# incienso NOUN nmod
# él PRON obj
# elevar VERB ROOT
# á ADP advmod
#
#  SPACE obl
# él PRON det
# alto ADJ obj
# de ADP case
# el DET det
# bóveda NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# el DET det
# nave NOUN obl
# central ADJ amod
# , PUNCT punct
# el DET det
# madre NOUN nsubj
# aguardar VERB conj
# con ADP case
# el DET det
#
#  SPACE obj
# llanto NOUN obj
# en ADP case
# el DET det
# ojo NOUN nmod
# , PUNCT punct
# en ADP case
# el DET det
# lábio NOUN nmod
# el DET det
# sonrisa NOUN appos
# . PUNCT punct
#
#
#  SPACE nsubj
# Mauricio PROPN flat
# ver VERB ROOT
# á ADP case
# su DET det
# compañero NOUN iobj
# ir VERB xcomp
# hácia NOUN obl
# él PRON obj
# y CCONJ cc
# caer VERB conj
# en ADP case
# su DET det
# brazo NOUN obl
# . PUNCT punct
#
#
#  SPACE ROOT
# ¡ PUNCT punct
# Ay INTJ obj
# ! PUNCT punct
# ¡ PUNCT punct
# él PRON nsubj
# estar AUX cop
# solo ADJ conj
# ! PUNCT punct
#
#
#  SPACE ROOT
# Ni CCONJ cc
# padre NOUN conj
# ni CCONJ cc
# madre NOUN conj
# que SCONJ mark
# él PRON obj
# aguardar VERB advcl
# ; PUNCT punct
# solo ADV ROOT
# en ADP case
# ese DET det
# hora NOUN nmod
# solemne ADJ amod
# de ADP case
# el DET det
#
#  SPACE conj
# vida NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# ¿ PUNCT punct
# solo ADJ obj
# ? PUNCT punct
#
#
#  SPACE ROOT
# no ADV advmod
# : PUNCT punct
# ahí ADV advmod
# estar VERB advcl
# mr ADJ nsubj
# . PUNCT punct
# Blain PROPN nsubj
# que PRON nsubj
# él PRON obj
# sonreiar VERB acl
# ; PUNCT punct
# ahí ADV advmod
# estar VERB ROOT
# el DET det
# buen ADJ amod
# Colombe PROPN nsubj
#
#  SPACE nsubj
# que SCONJ mark
# él PRON obj
# tender VERB ccomp
# el DET det
# brazo NOUN nsubj
# y CCONJ cc
# él PRON obj
# contemplar VERB conj
# enternecido ADJ iobj
# . PUNCT punct
#
#
#  SPACE ROOT
# --Ama--díjole PROPN flat
# mauricio--¿quieres DET dep
# que SCONJ mark
# tú PRON obj
# dar VERB acl
# mi DET det
# reliquia NOUN nsubj
# ? PUNCT punct
# Mírala PROPN ROOT
# : PUNCT punct
# ser AUX cop
# mucho ADV advmod
#
#  SPACE ccomp
# lindo ADJ xcomp
# : PUNCT punct
# _ NOUN amod
# Notre PROPN appos
# Dame PROPN flat
# du NOUN flat
# bon ADP case
# Secour PROPN nmod
# _ PROPN flat
# . PUNCT punct
#
#
#  SPACE dep
# --no ADV advmod
# , PUNCT punct
# hijo NOUN nsubj
# mio--respondeír VERB csubj
# el DET det
# viejo ADJ amod
# sirvienta NOUN obj
# , PUNCT punct
# volver VERB acl
# el DET det
# reliquia NOUN obj
# al ADP case
#
#  SPACE obj
# pecho NOUN obl
# del ADP case
# niño.--este NOUN nmod
# recuerdo ADJ obj
# él PRON obj
# ser AUX cop
# debido ADJ case
# á ADP fixed
# mamá NOUN ROOT
# . PUNCT punct
# Envíaselo PROPN nsubj
# dentro ADV advmod
# de ADP case
#
#  SPACE obl
# tu DET det
# primero ADJ amod
# carta.-- PROPN obl
#
#
#  SPACE flat
# el DET det
# hora NOUN appos
# , PUNCT punct
# el DET det
# lugar NOUN appos
# , PUNCT punct
# el DET det
# escena NOUN appos
# imponente ADJ amod
# en ADP case
# que PRON obl
# acabar VERB acl
# de ADP mark
# actuar VERB xcomp
# ; PUNCT punct
# el DET det
#
#  SPACE conj
# voz NOUN compound
# del ADP case
# órgano NOUN nmod
# ; PUNCT punct
# el DET det
# humo NOUN appos
# del ADP case
# incienso NOUN nmod
# ; PUNCT punct
# el DET det
# sagrada NOUN appos
# prez ADJ amod
# ; PUNCT punct
# todo DET det
# este PRON nsubj
#
#  SPACE mark
# despertar VERB ROOT
# en ADP case
# el DET det
# alma NOUN obl
# del ADP case
# niño NOUN nmod
# uno DET det
# emocion NOUN obj
# profundo ADJ amod
# , PUNCT punct
# al ADP mark
# oir VERB acl
# el DET det
# palabra NOUN obj
#
#  SPACE obj
# de ADP case
# el DET det
# viejo ADJ amod
# Colombe PROPN nmod
# . PUNCT punct
# el DET det
# luz NOUN nsubj
# de ADP case
# uno DET det
# lejano ADJ amod
# recuerdo NOUN nmod
# brillar VERB ROOT
# en ADP case
# su DET det
# mente NOUN obl
# , PUNCT punct
#
#  SPACE aux
# mostrar él VERB advcl
# allá ADV advmod
# , PUNCT punct
# como SCONJ mark
# entre ADP case
# el DET det
# niebla NOUN obl
# de ADP case
# uno DET det
# ensueño NOUN nmod
# , PUNCT punct
# el DET det
# figura NOUN nsubj
#
#  SPACE appos
# angelical ADJ amod
# de ADP case
# uno DET det
# mujer NOUN nmod
# que PRON nsubj
# él PRON obj
# mirar VERB acl
# sonreir VERB advcl
# . PUNCT punct
#
#
#  SPACE ROOT
# Sonrióle PROPN flat
# él PRON flat
# tambien PROPN nmod
# , PUNCT punct
# y CCONJ cc
# dos NUM nummod
# lágrima NOUN nsubj
# él PRON obj
# desprender VERB conj
# de ADP case
# su DET det
# ojo NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# Colombe PROPN flat
# él PRON obj
# comprender VERB ROOT
# . PUNCT punct
# besar VERB advcl
# el DET det
# santo ADJ amod
# imágen NOUN obj
# ; PUNCT punct
# guardóla NOUN conj
# en ADP case
# su DET det
# seno NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# en ADP case
#
#  SPACE fixed
# el DET det
# noche NOUN conj
# , PUNCT punct
# á ADP case
# el DET det
# hora NOUN obl
# de ADP mark
# acostar él VERB acl
# , PUNCT punct
# Mauricio PROPN nsubj
# él PRON obj
# encontrar VERB ROOT
# á ADP case
# el DET det
# cabecera NOUN iobj
# de ADP case
#
#  SPACE nmod
# su DET det
# cama NOUN obj
# . PUNCT punct
#
#
#
#
#
#  SPACE advcl
# iv NOUN obj
#
#
#
#  SPACE amod
# Desde ADP case
# ese DET det
# dia NOUN obl
# uno DET det
# notable ADJ amod
# cambio NOUN nsubj
# él PRON obj
# efectuar VERB ROOT
# en ADP case
# su DET det
# carácter NOUN obl
# . PUNCT punct
# a ADP case
# el DET det
#
#  SPACE fixed
# inquieto ADJ amod
# turbulencia NOUN obl
# del ADP case
# niño NOUN nmod
# , PUNCT punct
# suceder VERB ROOT
# el DET det
# mesura NOUN obj
# y CCONJ cc
# el DET det
# reflexion NOUN conj
# del ADP case
#
#  SPACE nmod
# hombre NOUN appos
# ; PUNCT punct
# al ADP case
# gusto NOUN fixed
# por ADP case
# el DET det
# juegos PROPN nmod
# , PUNCT punct
# el DET det
# amor NOUN appos
# al ADP case
# estudio NOUN nmod
# ; PUNCT punct
# á ADP case
# su DET det
# indiferencia NOUN obl
#
#  SPACE appos
# cosmopolita ADJ amod
# , PUNCT punct
# el DET det
# sentimiento NOUN appos
# exaltado ADJ amod
# de ADP case
# el DET det
# nacionalidad NOUN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# Cuando SCONJ mark
# en ADP case
# el DET det
# dia NOUN obl
# clásico ADJ amod
# , PUNCT punct
# al ADP mark
# flamear VERB acl
# de ADP case
# el DET det
# bandera NOUN obj
# tricolor ADJ amod
# , PUNCT punct
# su DET det
#
#  SPACE case
# compañero NOUN nsubj
# cantar VERB ROOT
# : PUNCT punct
# « PUNCT punct
# _ ADJ obj
# Allons PROPN obj
# enfants PROPN flat
# de ADP case
# el DET det
# patrie NOUN nmod
# _ ADJ amod
# , PUNCT punct
# » PUNCT punct
# Mauricio PROPN nsubj
# buscar VERB advcl
#
#  SPACE obj
# en ADP case
# el DET det
# cielo NOUN obl
# , PUNCT punct
# el DET det
# azul ADJ conj
# pabellon PROPN appos
# ; PUNCT punct
# y CCONJ cc
# del ADP case
# fondo NOUN obl
# de ADP case
# su DET det
# alma NOUN nmod
# exhalábar VERB conj
# el DET det
#
#  SPACE obj
# grito NOUN compound
# sagrado ADJ amod
# del ADP case
# himno NOUN nmod
# nacional ADJ amod
# . PUNCT punct
# allá ADV advmod
# , PUNCT punct
# surgir VERB ROOT
# de ADP case
# el DET det
# bruma NOUN obj
# del ADP case
#
#  SPACE nmod
# lejano ADJ amod
# pasado NOUN amod
# , PUNCT punct
# el DET det
# imágen NOUN obj
# de ADP case
# el DET det
# patria NOUN nmod
# aparecíale ADJ amod
# con ADP case
# su DET det
# inmenso ADJ amod
# pampa NOUN nmod
# , PUNCT punct
#
#  SPACE punct
# su DET det
# magestuoso ADJ amod
# rio NOUN det
# , PUNCT punct
# su DET det
# cerúlea ADJ amod
# lontananza NOUN obj
# , PUNCT punct
# llamar él VERB advcl
# con ADP case
# poderoso ADJ obl
#
#  SPACE punct
# reclamo NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# Pero CCONJ advmod
# ¡ PUNCT punct
# ah INTJ conj
# ! PUNCT punct
# siempre ADV mark
# que SCONJ fixed
# este DET det
# luminoso ADJ amod
# imagen NOUN nsubj
# visitar VERB advcl
# su DET det
# mente NOUN obj
# , PUNCT punct
# uno DET det
#
#  SPACE nsubj
# siniestro ADJ amod
# recuerdo NOUN appos
# venir VERB conj
# á ADP case
# oscurecerlas PROPN obl
# . PUNCT punct
#
#
#  SPACE ROOT
# su DET det
# madrastra NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# este DET det
# sentimiento NOUN nsubj
# de ADP case
# repulsion PROPN nmod
# crecer VERB ROOT
# más ADV advmod
# todavía ADV advmod
# , PUNCT punct
# cuando SCONJ mark
# Mauricio PROPN nsubj
#
#  SPACE flat
# comprender VERB advcl
# por ADP case
# el DET det
# carta NOUN obj
# de ADP case
# su DET det
# padre NOUN nmod
# , PUNCT punct
# el DET det
# humillante ADJ amod
# dependencia NOUN appos
# en ADP case
#
#  SPACE nmod
# que SCONJ mark
# yacer VERB acl
# . PUNCT punct
# cada DET det
# frase NOUN nsubj
# parecer VERB ROOT
# consultado ADJ obj
# , PUNCT punct
# corregido ADJ conj
# ó CCONJ cc
# dictado ADJ conj
# por ADP case
# el DET det
#
#  SPACE obj
# déspoto ADJ amod
# que PRON nsubj
# leer VERB acl
# sobre ADP case
# su DET det
# hombro NOUN obl
# . PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# jóven NOUN nsubj
# verter VERB ROOT
# sobre ADP case
# él PRON obl
# lágrima NOUN obj
# de ADP case
# indignacion NOUN nmod
# y CCONJ cc
# de ADP case
# dolor NOUN conj
# ; PUNCT punct
# y CCONJ cc
# uno DET det
#
#  SPACE amod
# palabra NOUN conj
# de ADP case
# uno PRON nmod
# ú NOUN cc
# otro PRON conj
# , PUNCT punct
# contener VERB advcl
# su DET det
# respuesta NOUN obj
# . PUNCT punct
#
#
#  SPACE ROOT
# así ADV advmod
# , PUNCT punct
# el DET det
# correspondencia NOUN obj
# entre ADP case
# padre NOUN nmod
# é CCONJ cc
# hijo NOUN conj
# tomar VERB conj
# uno DET det
# carácter NOUN obj
# de ADP case
# acritud NOUN nmod
#
#  SPACE dep
# que SCONJ mark
# , PUNCT punct
# poco ADV advmod
# á ADP fixed
# poco ADV fixed
# , PUNCT punct
# degenerar VERB ccomp
# en ADP case
# frialdad NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# Y CCONJ cc
# , PUNCT punct
# cuando SCONJ mark
# á ADP case
# el DET det
# edad NOUN obl
# de ADP case
# diez NUM nummod
# y CCONJ cc
# ocho NUM conj
# año NOUN nmod
# , PUNCT punct
# acabado ADJ dep
# su DET det
# estudio NOUN conj
# y CCONJ cc
#
#  SPACE conj
# rendido ADJ amod
# con ADP case
# brillo NOUN obl
# el DET det
# último ADJ amod
# exámen NOUN obj
# , PUNCT punct
# su DET det
# padre NOUN nsubj
# él PRON obj
# hablar VERB ROOT
# de ADP case
# regreso NOUN obj
# . PUNCT punct
#
#
#  SPACE nsubj
# --Amo PROPN punct
# á ADP case
# mi DET det
# patria NOUN nmod
# y CCONJ cc
# anhelar VERB conj
# volver VERB xcomp
# á INTJ advmod
# verla--respondeír VERB ROOT
# mauricio,--amo NOUN nsubj
# á PROPN flat
#
#  SPACE flat
# mi DET det
# padre NOUN obj
# y CCONJ cc
# desear VERB conj
# estrechar él VERB xcomp
# en ADP case
# mi DET det
# brazo NOUN obl
# ; PUNCT punct
# pero CCONJ cc
# no ADV advmod
# poder AUX aux
# presenciar VERB conj
#
#  SPACE obj
# el DET det
# espectáculo NOUN obj
# vergonzoso ADJ amod
# de ADP case
# su DET det
# servidumbre NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# porque SCONJ mark
# él PRON obj
# amar VERB conj
# ; PUNCT punct
# y CCONJ cc
# porque SCONJ mark
#
#  SPACE aux
# él PRON det
# respetar VERB fixed
# , PUNCT punct
# preferir VERB conj
# uno DET det
# eterno ADJ amod
# destierro NOUN obj
# . PUNCT punct
#
#
#  SPACE nsubj
# A ADP case
# este DET det
# declaracion NOUN obl
# seguir VERB ROOT
# uno DET det
# profundo ADJ amod
# silencio NOUN obj
# ; PUNCT punct
# y CCONJ cc
# como SCONJ mark
# único ADJ amod
# respuesta NOUN conj
#
#  SPACE appos
# Mauricio PROPN nsubj
# recibir VERB conj
# uno DET det
# carta NOUN obj
# que PRON nsubj
# contener VERB acl
# inesperado ADJ amod
# revelación NOUN obj
# . PUNCT punct
#
#  SPACE case
# Suscribíala PROPN ROOT
# el DET det
# escribano NOUN appos
# D PROPN appos
# ... PUNCT punct
# , PUNCT punct
# uno PRON appos
# de ADP case
# el DET det
# hombre NOUN nmod
# más ADV advmod
# honorable ADJ amod
# de ADP case
#
#  SPACE nmod
# Buenos PROPN appos
# Aires PROPN flat
# . PUNCT punct
#
#
#    SPACE nsubj
# --«alejado ADJ amod
# y CCONJ cc
# sin ADP mark
# conocer yo VERB conj
# uno PRON obj
# á ADP case
# otro--decíale ADJ nmod
# éste--úneno NOUN obj
# , PUNCT punct
#
#    SPACE appos
# sinembargo ADV advmod
# , PUNCT punct
# el DET det
# mandato NOUN appos
# de ADP case
# uno DET det
# persona NOUN nmod
# que PRON nsubj
# ya ADV advmod
# no ADV advmod
# existir VERB acl
# ; PUNCT punct
# y CCONJ cc
# que PRON nsubj
# para ADP case
#
#    SPACE obl
# yo PRON nsubj
# fué AUX cop
# por ADP case
# este PRON obl
# , PUNCT punct
# más ADV advmod
# sagrado.--y ADJ nsubj
# proseguir VERB conj
# : PUNCT punct
#
#
#    SPACE appos
# --«Hace PROPN punct
# quince NUM nummod
# año NOUN nmod
# , PUNCT punct
# fuir AUX aux
# llamar VERB ROOT
# uno DET det
# dia NOUN obj
# á ADP case
# casa NOUN obl
# del ADP case
# señor NOUN nmod
# Cárlos PROPN advcl
#
#    SPACE obj
# Ridel PROPN obj
# , PUNCT punct
# cuyo PRON nmod
# esposa NOUN nsubj
# , PUNCT punct
# en ADP case
# trance NOUN obl
# de ADP case
# muerte NOUN nmod
# , PUNCT punct
# deber AUX aux
# otorgar VERB xcomp
# testamento NOUN obj
# . PUNCT punct
#
#
#    SPACE obl
# « PUNCT punct
# mi DET det
# colega NOUN nsubj
# , PUNCT punct
# el DET det
# señor NOUN appos
# R PROPN appos
# ... PUNCT punct
# , PUNCT punct
# autorizar VERB ROOT
# el DET det
# acto NOUN obj
# ; PUNCT punct
# y CCONJ cc
# yo PRON nsubj
# creer VERB conj
# haber AUX ccomp
#
#    SPACE obj
# ser AUX aux
# requerir VERB ccomp
# como SCONJ mark
# testigo NOUN obl
# , PUNCT punct
# cuando SCONJ mark
# el DET det
# testante ADV advmod
# , PUNCT punct
# haber AUX aux
# declarar VERB advcl
#
#    SPACE obj
# que PRON nsubj
# dejar VERB acl
# á ADP case
# su DET det
# hijo NOUN obj
# único ADJ amod
# , PUNCT punct
# Mauricio PROPN appos
# Ridel PROPN flat
# , PUNCT punct
# el DET det
# valor NOUN obj
# de ADP case
# dosciento NOUN nmod
#
#    SPACE compound
# mil NUM nummod
# pesos NOUN appos
# en ADP case
# propiedad NOUN nmod
# urbano ADJ amod
# y CCONJ cc
# rural ADJ conj
# , PUNCT punct
# volver él VERB advcl
# á ADP case
# su DET det
#
#    SPACE obl
# esposo ADJ amod
# , PUNCT punct
# pidióle ADJ advmod
# permiso NOUN obj
# para ADP mark
# instituir yo VERB advcl
# á ADP case
# yo PRON obj
# , PUNCT punct
# hasta ADP case
# el DET det
# mayoría NOUN nmod
# de ADP case
#
#    SPACE nmod
# aquel PRON det
# , PUNCT punct
# guardador NOUN conj
# de ADP case
# dicho ADJ amod
# bien NOUN nmod
# . PUNCT punct
#
#
#    SPACE ROOT
# « PUNCT punct
# Repugnábame PROPN appos
# uno DET det
# mision NOUN appos
# visiblemente ADV advmod
# motivado ADJ amod
# por ADP case
# disensión NOUN obl
#
#    SPACE appos
# conyugal ADJ amod
# ; PUNCT punct
# pero CCONJ cc
# el DET det
# ojo NOUN nsubj
# de ADP case
# el DET det
# moribunda NOUN nmod
# enviáronme VERB conj
# uno DET det
# mirada NOUN obj
# de ADP case
#
#    SPACE nmod
# angustioso ADJ amod
# ruego NOUN appos
# , PUNCT punct
# que SCONJ mark
# yo PRON obj
# hacer VERB acl
# aceptar él VERB xcomp
# . PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# él PRON det
# entónces ADV advmod
# suspirar VERB ROOT
# como SCONJ mark
# aliviado ADJ obj
# de ADP case
# uno DET det
# grave ADJ amod
# preocupacion NOUN obl
# ; PUNCT punct
#
#    SPACE nsubj
# estrechar VERB advcl
# mi DET det
# mano NOUN obj
# con ADP case
# gratitud NOUN nmod
# , PUNCT punct
# y CCONJ cc
# morir VERB conj
# en ADP case
# paz NOUN obl
# . PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# yo PRON nsubj
# haber AUX aux
# cumplir VERB advcl
# fielmente ADV advmod
# el DET det
# deber NOUN obj
# que PRON mark
# yo PRON obj
# impusar VERB acl
# : PUNCT punct
# haber AUX aux
# administrar VERB advcl
#
#    SPACE obj
# ese DET det
# bien NOUN nsubj
# con ADP case
# el DET det
# acierto NOUN obl
# que PRON nsubj
# dar VERB acl
# uno DET det
# largo ADJ amod
# experiencia NOUN obj
# en ADP case
# el DET det
#
#    SPACE obl
# negocios PROPN flat
# ; PUNCT punct
# él PRON obj
# haber AUX aux
# conservar VERB advcl
# , PUNCT punct
# él PRON iobj
# haber AUX aux
# hacer VERB ROOT
# fructificar VERB xcomp
# : PUNCT punct
# pero CCONJ cc
# siempre ADV advmod
#
#    SPACE conj
# en ADP case
# el DET det
# limite NOUN obl
# que SCONJ mark
# mi DET det
# delicadeza NOUN nsubj
# yo PRON obj
# prescribir VERB acl
# : PUNCT punct
# no ADV advmod
# como SCONJ mark
# guardador NOUN obl
# , PUNCT punct
#
#    SPACE conj
# sino CCONJ cc
# como SCONJ mark
# administrador NOUN conj
# , PUNCT punct
# rendir VERB advcl
# cuenta NOUN obj
# de ADP case
# mi DET det
# cometido NOUN nmod
# y CCONJ cc
#
#    SPACE conj
# entregar VERB advcl
# al ADP case
# señor NOUN obj
# Ridel PROPN appos
# el DET det
# fuerte ADJ amod
# suma NOUN obj
# que PRON obj
# producir VERB acl
# . PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# hoy ADV advmod
# yo PRON obj
# haber AUX aux
# hacer VERB ROOT
# saber VERB xcomp
# que SCONJ mark
# V. PROPN nsubj
# él PRON obj
# haber AUX aux
# emancipar VERB ccomp
# ; PUNCT punct
# y CCONJ cc
# que SCONJ mark
# , PUNCT punct
# por ADP advmod
# tanto NOUN fixed
# , PUNCT punct
#
#    SPACE advcl
# el DET det
# ingerencia NOUN nsubj
# que PRON obj
# yo PRON nsubj
# él PRON obj
# dar VERB acl
# en ADP case
# el DET det
# asunto NOUN obl
# de ADP case
# su DET det
# hijo NOUN nmod
# , PUNCT punct
# haber AUX aux
# cesar VERB conj
# . PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# Por ADP case
# consecuencia NOUN fixed
# , PUNCT punct
# y CCONJ cc
# persuadido ADJ conj
# de ADP mark
# que SCONJ mark
# él PRON nsubj
# haber AUX aux
# informar VERB ccomp
# á ADP case
# V. PROPN obj
# del ADP case
#
#    SPACE obj
# estado AUX cop
# floreciente ADJ obj
# de ADP case
# su DET det
# fortuna NOUN nmod
# , PUNCT punct
# no PART cc
# solo NOUN fixed
# por ADP case
# mi DET det
# buen ADJ amod
# voluntad NOUN fixed
# en ADP case
#
#    SPACE nmod
# su DET det
# administracion NOUN obl
# , PUNCT punct
# sino CCONJ cc
# á ADP fixed
# causa NOUN fixed
# del ADP case
# subido ADJ amod
# precio NOUN obl
# que PRON obj
# haber AUX aux
# adquirir VERB acl
#
#    SPACE obj
# el DET det
# propiedad NOUN nsubj
# , PUNCT punct
# réstame ADJ conj
# solo ADV advmod
# poner él VERB acl
# á ADP case
# su DET det
# disposicion NOUN obl
# , PUNCT punct
# y CCONJ cc
# pedir él VERB conj
# él PRON det
#
#    SPACE obj
# sirvo VERB ROOT
# impartir yo VERB xcomp
# su DET det
# órden NOUN obj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE ROOT
# este DET det
# carta NOUN nsubj
# de ADP case
# uno DET det
# tutor NOUN nmod
# hasta ADP case
# entónces ADV advmod
# ignorado ADJ advmod
# , PUNCT punct
# fué AUX cop
# uno DET det
# rayo NOUN obj
# de ADP case
# luz NOUN nmod
# en ADP case
#
#  SPACE nmod
# el DET det
# misterio NOUN obj
# que PRON nsubj
# rodear VERB acl
# el DET det
# pasado NOUN obj
# de ADP case
# Mauricio PROPN nmod
# , PUNCT punct
# y CCONJ cc
# efectuar VERB conj
# uno DET det
# cambio NOUN obj
#
#  SPACE amod
# favorable ADJ amod
# en ADP case
# su DET det
# destino NOUN nmod
# . PUNCT punct
#
#
#  SPACE dep
# alejado ADJ advmod
# ...
# ó CCONJ cc
# vivir VERB amod
# , PUNCT punct
# habrás ADJ aux
# de ADP mark
# perdonar VERB ROOT
# mi DET det
# primero ADJ amod
# y CCONJ cc
# único ADJ conj
#
#    SPACE obj
# desobediencia NOUN nmod
# , PUNCT punct
# en ADP case
# gracia NOUN fixed
# del ADP fixed
# motivo NOUN obl
# que PRON iobj
# él PRON obj
# inspirar VERB acl
# ; PUNCT punct
# hélo VERB advcl
# aquí ADV advmod
# : PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# tener VERB advcl
# por ADP case
# todo DET det
# institucion NOUN obl
# benéfico ADJ amod
# , PUNCT punct
# el DET det
# más ADV advmod
# alto ADJ nsubj
# estimar VERB advcl
# ; PUNCT punct
# y CCONJ cc
#
#    SPACE conj
# profundo ADJ amod
# gratitud NOUN obj
# por ADP case
# el DET det
# que PRON obl
# él PRON obj
# levantar VERB acl
# en ADP case
# nuestro DET det
# país NOUN obl
# . PUNCT punct
#
#
#    SPACE ROOT
# « PUNCT punct
# Entre ADP case
# este DET obl
# , PUNCT punct
# el DET det
# Compañías PROPN nsubj
# de ADP case
# Seguros PROPN flat
# sónmir VERB advcl
# especialmente ADV advmod
#
#    SPACE obj
# simpático ADJ amod
# , PUNCT punct
# sobretodo NOUN appos
# , PUNCT punct
# « PUNCT punct
# el DET det
# Buenos PROPN appos
# Aires PROPN flat
# » PUNCT punct
# , PUNCT punct
# por ADP case
# su DET det
# importancia NOUN obl
# y CCONJ cc
#
#    SPACE conj
# valioso ADJ amod
# organizacion NOUN flat
# . PUNCT punct
#
#
#    SPACE nsubj
# « PUNCT punct
# así ADV advmod
# , PUNCT punct
# en ADP mark
# tanto NOUN fixed
# que SCONJ fixed
# yo PRON iobj
# permitas VERB ROOT
# ser AUX cop
# su DET det
# accionista NOUN xcomp
# , PUNCT punct
# haber AUX aux
# querer VERB advcl
#
#    SPACE obj
# pertenecer él VERB xcomp
# , PUNCT punct
# al ADP advmod
# menos ADV fixed
# , PUNCT punct
# por ADP case
# uno DET det
# seguro NOUN obj
# » PUNCT punct
# ...... PUNCT punct
#
#
#  SPACE nsubj
# Mauricio PROPN nsubj
# no ADV advmod
# poder AUX aux
# leer VERB ROOT
# más ADV advmod
# . PUNCT punct
#
#
#  SPACE advcl
# uno DET det
# ola NOUN nsubj
# amargo ADJ amod
# subir VERB ROOT
# á ADP case
# su DET det
# corazon NOUN obl
# despertar VERB advcl
# todo DET det
# el DET det
# antiguo ADJ obj
#
#  SPACE punct
# dolor NOUN ROOT
# filial ADJ amod
# . PUNCT punct
#
#
#  SPACE amod
# En ADP case
# el DET det
# vida NOUN obl
# como SCONJ mark
# en ADP case
# el DET det
# eternidad NOUN conj
# , PUNCT punct
# siempre ADV advmod
# el DET det
# sombra NOUN appos
# fatídico ADJ amod
# de ADP case
# su DET det
#
#  SPACE nmod
# madrastra NOUN nsubj
# venir VERB ROOT
# á ADP mark
# colocar él VERB xcomp
# entre ADP case
# él PRON obl
# y CCONJ cc
# su DET det
# padre NOUN conj
# .... PUNCT punct
#
#
#  SPACE ROOT
# Pero CCONJ cc
# , PUNCT punct
# luego ADV advmod
# , PUNCT punct
# el DET det
# imágen NOUN conj
# de ADP case
# Julia PROPN nmod
# , PUNCT punct
# como SCONJ mark
# uno DET det
# rayo NOUN nmod
# de ADP case
# luz NOUN nmod
# , PUNCT punct
# borró VERB acl
# aquel DET det
#
#  SPACE obj
# penoso ADJ amod
# impresion NOUN obj
# . PUNCT punct
#
#
#
#
#
#  SPACE ROOT
# xxxi NOUN obj
#
#
#
#  SPACE compound
# --la DET det
# Capilla PROPN obj
# de ADP case
# nuestro DET det
# Señora PROPN flat
# de ADP case
# el DET det
# Victorias PROPN flat
# tener VERB advcl
# hoy ADV advmod
# uno DET det
# aspecto NOUN obj
#
#  SPACE amod
# imponente ADJ amod
# . PUNCT punct
# llenábalar VERB ROOT
# el DET det
# cortejo NOUN obj
# de ADP case
# uno DET det
# boda.-- PROPN nmod
#
#
#  SPACE flat
# así ADV advmod
# llegar VERB advcl
# decir VERB xcomp
# el DET det
# joven NOUN obj
# de ADP case
# vuelta NOUN nmod
# de ADP case
# misa NOUN nmod
# de ADP case
# ocho NUM nummod
# . PUNCT punct
#
#
#  SPACE advcl
# ¡ PUNCT punct
# uno DET det
# boda NOUN obj
# ! PUNCT punct
# sonar VERB ROOT
# tanto ADV advmod
# bien ADV advmod
# este DET det
# mágico ADJ amod
# palabra NOUN nsubj
# , PUNCT punct
# que PRON nsubj
# mucho ADV advmod
# luego ADV advmod
# tener VERB acl
# todo PRON obj
#
#  SPACE punct
# el DET det
# casa NOUN obj
# por ADP case
# auditorio NOUN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# Y CCONJ cc
# el DET det
# joven NOUN nsubj
# continuar VERB ROOT
# , PUNCT punct
# y CCONJ cc
# en ADP case
# su DET det
# entusiasta ADJ amod
# lenguaje NOUN conj
# : PUNCT punct
#
#
#  SPACE obj
# --¡Qué PROPN nmod
# bello ADJ amod
# pareja!--decir VERB acl
# . PUNCT punct
#
#
#  SPACE ROOT
# --El PUNCT punct
# , PUNCT punct
# todo DET det
# uno DET det
# buen ADJ amod
# mozo NOUN nsubj
# ; PUNCT punct
# con ADP case
# uno DET det
# aire NOUN obl
# tanto ADV advmod
# sério ADJ amod
# y CCONJ cc
# distinguido ADJ conj
# . PUNCT punct
#
#
#  SPACE dep
# --¡Ella PROPN obj
# ! PUNCT punct
# ¡ PUNCT punct
# morén ADJ amod
# más ADV advmod
# lindo ADJ amod
# ! PUNCT punct
# qué DET det
# alianza NOUN obj
# encantador ADJ amod
# de ADP case
# él PRON det
# blanco ADJ nmod
# de ADP case
# el DET det
#
#  SPACE nmod
# piel NOUN nmod
# y CCONJ cc
# él PRON det
# negro ADJ conj
# de ADP case
# ojo NOUN nmod
# y CCONJ cc
# cabello NOUN conj
# ! PUNCT punct
#
#
#  SPACE amod
# --¡muchachos PRON appos
# ! PUNCT punct
# ¡ PUNCT punct
# no ADV advmod
# haber AUX ROOT
# que SCONJ cc
# exagerar VERB conj
# ! PUNCT punct
#
#
#  SPACE obj
# --¡oh NOUN obl
# ! PUNCT punct
# si SCONJ mark
# nada PRON obj
# haber AUX aux
# decir VERB ROOT
# todavía ADV advmod
# . PUNCT punct
# Escucha.-- PROPN nsubj
#
#
#  SPACE appos
# Y CCONJ cc
# dejar VERB conj
# por ADP case
# aquí ADV advmod
# y CCONJ cc
# por ADP case
# allí ADV conj
# , PUNCT punct
# sombrero NOUN obj
# , PUNCT punct
# guant ADJ conj
# y CCONJ cc
# abanico ADJ conj
# , PUNCT punct
#
#  SPACE nsubj
# continuar VERB ROOT
# , PUNCT punct
# quitar él VERB advcl
# uno PRON obj
# á ADP case
# otro DET obj
# el DET det
# palabra NOUN obj
# : PUNCT punct
#
#
#  SPACE nsubj
# --Que PROPN nsubj
# bien ADV advmod
# estar AUX cop
# el DET det
# lindo ADJ amod
# morocha NOUN appos
# , PUNCT punct
# en ADP case
# su DET det
# vestido NOUN nmod
# de ADP case
# faya PROPN nmod
# , PUNCT punct
# tanto ADV advmod
# sencillo ADJ advmod
#
#  SPACE punct
# como SCONJ mark
# elegante ADJ ROOT
# , PUNCT punct
# y CCONJ cc
# su DET det
# velo NOUN conj
# de ADP case
# tul PROPN nmod
# de ADP case
# seda NOUN nmod
# liso ADJ amod
# : PUNCT punct
# el DET det
# todo PRON appos
# sin ADP case
# más ADV advmod
# adorno NOUN nmod
#
#  SPACE punct
# que SCONJ mark
# azahar NOUN nmod
# natural ADJ amod
# . PUNCT punct
#
#
#  SPACE nsubj
# --un VERB cop
# pié NOUN ROOT
# de ADP case
# Cendrillon PROPN nmod
# calzar VERB advcl
# uno DET det
# zapatito NOUN obj
# de ADP case
# raso PROPN nmod
# blanco ADJ flat
# , PUNCT punct
# adornado ADJ advmod
#
#  SPACE obj
# tambien NOUN obj
# con ADP case
# azahar NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# --un VERB punct
# precioso ADJ amod
# abanico NOUN ROOT
# formado ADJ amod
# de ADP case
# mariposa NOUN obl
# trasparent ADJ amod
# : PUNCT punct
# y CCONJ cc
# chico NOUN conj
# , PUNCT punct
# á ADP cc
# el DET det
#
#  SPACE conj
# último ADJ amod
# moda NOUN nmod
# . PUNCT punct
#
#
#  SPACE ROOT
# --poca ADJ nummod
# señora NOUN nsubj
# ; PUNCT punct
# mucho ADV advmod
# elegante ADJ amod
# todo PRON amod
# . PUNCT punct
#
#
#  SPACE ROOT
# --pero NUM punct
# ¡ PUNCT punct
# qué DET det
# gran ADJ amod
# séquito NOUN nsubj
# de ADP case
# caballero NOUN nmod
# ! PUNCT punct
# todo DET det
# el DET det
# prensa NOUN nsubj
# : PUNCT punct
# el DET det
# general NOUN appos
#
#  SPACE appos
# Mitre PROPN appos
# , PUNCT punct
# Bartolito PROPN conj
# , PUNCT punct
# Dávila PROPN conj
# , PUNCT punct
# Lainez PROPN conj
# , PUNCT punct
# Vedia PROPN conj
# , PUNCT punct
# Laurencena PROPN conj
# , PUNCT punct
# Lalanne PROPN conj
# , PUNCT punct
# Walls PROPN conj
# , PUNCT punct
#
#  SPACE appos
# Ribaumont PROPN flat
# , PUNCT punct
# Ortega PROPN appos
# , PUNCT punct
# Alberú PROPN conj
# , PUNCT punct
# Mulhall PROPN appos
# y CCONJ cc
# tanto DET det
# otro PRON conj
# . PUNCT punct
#
#
#  SPACE nsubj
# --estar VERB ROOT
# tambien NOUN obj
# Eduardo PROPN appos
# Coll PROPN flat
# y CCONJ cc
# Emilio PROPN conj
# Casares PROPN flat
# que PRON nsubj
# fué AUX cop
# el DET det
# padrino NOUN acl
# y CCONJ cc
#
#  SPACE conj
# que PRON mark
# decir VERB obj
# haber AUX aux
# hacer VERB advcl
# uno DET det
# régio NOUN obj
# obsequio NOUN amod
# á ADP case
# el DET det
# novia NOUN nmod
# . PUNCT punct
#
#
#  SPACE punct
# --mucho NOUN nummod
# literato NOUN ROOT
# ; PUNCT punct
# el DET det
# general NOUN appos
# Sarmiento PROPN appos
# , PUNCT punct
# Santiago PROPN appos
# Estrada PROPN flat
# , PUNCT punct
# José PROPN appos
# María PROPN flat
#
#  SPACE flat
# Zuviría PROPN flat
# , PUNCT punct
# el DET det
# ministro NOUN appos
# de ADP case
# Bolivia PROPN nmod
# doctor ADJ amod
# Vaca PROPN appos
# Guzman PROPN flat
# y CCONJ cc
# tanto DET det
# otro PRON conj
# , PUNCT punct
#
#  SPACE appos
# hija NOUN appos
# , PUNCT punct
# que PRON obj
# yo PRON nsubj
# no ADV advmod
# conocer VERB acl
# . PUNCT punct
# apenas ADV advmod
# cabíar VERB ROOT
# en ADP case
# el DET det
# capilla NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# --El PUNCT punct
# celebrante ADJ appos
# , PUNCT punct
# que PRON nsubj
# ser AUX cop
# el DET det
# elocuentísimo ADJ acl
# padre NOUN appos
# Pera PROPN appos
# unir VERB ROOT
# á ADP case
# el DET det
#
#  SPACE iobj
# contrayent ADJ obj
# con ADP case
# el DET det
# palabra NOUN nmod
# sacramental ADJ amod
# , PUNCT punct
# pronunciado ADJ amod
# con ADP case
# uncion PROPN obj
#
#  SPACE amod
# conmovedor ADJ amod
# . PUNCT punct
#
#
#  SPACE nsubj
# Despues PROPN flat
# , PUNCT punct
# volver él VERB advcl
# al ADP case
# auditorio NOUN obl
# , PUNCT punct
# hablar VERB ccomp
# de ADP case
# el DET det
# excelencia NOUN obj
# del ADP case
#
#  SPACE nmod
# matrimonio NOUN nmod
# , PUNCT punct
# de ADP case
# su DET det
# orígen NOUN nmod
# divino ADJ amod
# , PUNCT punct
# de ADP case
# su DET det
# utilidad NOUN conj
# en ADP case
# el DET det
# comunion NOUN nmod
# humano ADJ amod
# , PUNCT punct
#
#  SPACE appos
# de ADP case
# el DET det
# santidad NOUN nmod
# de ADP case
# su DET det
# fin NOUN nmod
# , PUNCT punct
# del ADP case
# viático NOUN amod
# de ADP case
# virtud NOUN nmod
# que PRON acl
# á ADP case
# él PRON nmod
# deber AUX advcl
#
#  SPACE ROOT
# llevar él VERB xcomp
# . PUNCT punct
#
#
#  SPACE nsubj
# --Señores,--añadió--permitidme PROPN flat
# presentar tú VERB ROOT
# uno DET det
# modelo NOUN obj
# de ADP case
# ese DET det
# virtud NOUN nmod
#
#  SPACE obj
# en ADP case
# el DET det
# cónyugu NOUN obl
# que PRON iobj
# acabar VERB acl
# de ADP mark
# unir VERB xcomp
# : PUNCT punct
# dos NUM nummod
# hijo NOUN appos
# animoso ADJ amod
# del ADP case
# trabajo NOUN nmod
# . PUNCT punct
#
#  SPACE case
# el DET det
# uno PRON ROOT
# , PUNCT punct
# despojar él VERB acl
# de ADP case
# uno DET det
# gran ADJ amod
# fortuna NOUN obl
# para ADP mark
# salvar VERB advcl
# de ADP case
# el DET det
# deshonra NOUN obj
#
#  SPACE appos
# el DET det
# memoria NOUN obj
# de ADP case
# uno DET det
# padre NOUN nmod
# ; PUNCT punct
# el DET det
# otro PRON appos
# , PUNCT punct
# en ADP case
# el DET det
# débil ADJ amod
# adolescencia NOUN nmod
# , PUNCT punct
# luchar VERB advcl
#
#  SPACE obj
# valerosamente ADV advmod
# con ADP case
# el DET det
# dificultad NOUN obl
# de ADP case
# el DET det
# vida NOUN nmod
# y CCONJ cc
# el DET det
# desamparo NOUN conj
# de ADP case
# el DET det
#
#  SPACE nmod
# orfandad NOUN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# él PRON obj
# amar VERB ROOT
# . PUNCT punct
# Libres PROPN nsubj
# , PUNCT punct
# poder AUX aux
# unir él VERB ROOT
# el DET det
# uno PRON nsubj
# al ADP case
# otro PRON obj
# . PUNCT punct
#
#
#  SPACE nsubj
# Pero CCONJ cc
# ser AUX cop
# pobre ADJ ROOT
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# el DET det
# rectitud NOUN obl
# de ADP case
# su DET det
# corazon NOUN nmod
# , PUNCT punct
# querer VERB conj
# preparar VERB xcomp
# el DET det
#
#  SPACE obj
# hogar NOUN nmod
# , PUNCT punct
# antes ADV advmod
# de ADP mark
# traer VERB advcl
# el DET det
# familia NOUN obj
# ; PUNCT punct
# y CCONJ cc
# dar VERB conj
# al ADP case
# trabajo NOUN obl
# , PUNCT punct
# aguardar VERB advcl
# , PUNCT punct
# en ADP case
#
#  SPACE obl
# ese DET det
# penoso ADJ amod
# retardo NOUN obj
# á ADP case
# su DET det
# dicho ADJ nmod
# , PUNCT punct
# resignado ADJ amod
# , PUNCT punct
# confiar VERB acl
# en ADP case
# Dios PROPN obj
# y CCONJ cc
# en ADP case
# el DET det
#
#  SPACE conj
# fortaleza NOUN obj
# de ADP case
# su DET det
# alma NOUN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# Mas PROPN flat
# , PUNCT punct
# no ADV advmod
# en ADP advmod
# vano NOUN fixed
# confiar VERB ROOT
# en ADP case
# « PUNCT punct
# aquel PRON obj
# que PRON nsubj
# formar VERB acl
# de ADP case
# el DET det
# piedra NOUN obj
# hijos PROPN appos
# á ADV advmod
#
#  SPACE punct
# Abraham PROPN ROOT
# » PUNCT punct
# .... PUNCT punct
#
#
#  SPACE nsubj
# existir VERB ROOT
# varios DET det
# institución NOUN nsubj
# creado ADJ amod
# con ADP case
# capital NOUN obl
# formado ADJ amod
# por ADP case
# el DET det
#
#  SPACE obl
# honradez NOUN nmod
# y CCONJ cc
# el DET det
# trabajo NOUN conj
# , PUNCT punct
# que PRON nsubj
# con ADP case
# el DET det
# modesto ADJ amod
# nombre NOUN obl
# de ADP case
# Compañías PROPN nmod
# de ADP case
#
#  SPACE nmod
# Seguros PROPN flat
# , PUNCT punct
# ejercer VERB acl
# el DET det
# más ADV advmod
# benéfico ADJ amod
# influencia NOUN obj
# en ADP case
# el DET det
# vida NOUN nmod
# económico ADJ amod
# de ADP case
# el DET det
#
#  SPACE nmod
# pueblo NOUN nmod
# ; PUNCT punct
# porque SCONJ mark
# , PUNCT punct
# cualquiera PRON nsubj
# que PRON nsubj
# ser AUX cop
# el DET det
# forma NOUN acl
# en ADP case
# que PRON obl
# él PRON obj
# tomar VERB acl
# , PUNCT punct
# el DET det
# seguro NOUN nsubj
#
#  SPACE nmod
# encerrar VERB advcl
# el DET det
# bienestar NOUN obj
# futuro ADJ amod
# de ADP case
# el DET det
# familia NOUN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# En ADP case
# el DET det
# seno NOUN obl
# de ADP case
# uno PRON nmod
# de ADP case
# ese DET det
# asociación NOUN nmod
# tutelar ADJ amod
# , PUNCT punct
# « PUNCT punct
# el DET det
# Buenos PROPN appos
# Aires PROPN flat
# » PUNCT punct
# , PUNCT punct
#
#  SPACE punct
# el DET det
# Providencia PROPN nsubj
# guardar VERB ROOT
# uno DET det
# tesoro NOUN obj
# que PRON nsubj
# á ADP case
# su DET det
# hora NOUN obl
# , PUNCT punct
# hacer VERB acl
# surgir VERB xcomp
# para ADP mark
#
#  SPACE fixed
# recompensar VERB advcl
# el DET det
# abnegacion PROPN obj
# filial NOUN amod
# y CCONJ cc
# dar VERB conj
# el DET det
# felicidad NOUN obj
# á ADP mark
# el DET det
# que PRON nsubj
# , PUNCT punct
#
#  SPACE aux
# creer VERB advcl
# en ADP case
# él PRON obj
# , PUNCT punct
# esperar VERB ccomp
# . PUNCT punct
#
#
#  SPACE nsubj
# --¡Que PROPN flat
# el DET det
# altísimo ADJ obj
# tú PRON obj
# bendiga!-- PUNCT det
#
#
#  SPACE obl
# Y CCONJ cc
# caer VERB conj
# de ADP case
# rodilla NOUN obl
# , PUNCT punct
# el DET det
# hombre NOUN nsubj
# de ADP case
# Dios PROPN nmod
# él PRON obj
# absorber VERB ROOT
# en ADP case
# mental NOUN obl
#
#  SPACE appos
# plegaria NOUN obj
# .... PUNCT punct
#
#
#  SPACE aux
# --corrir VERB ROOT
# al ADP case
# pórtico NOUN nmod
# para ADP mark
# ver VERB advcl
# el DET det
# desfile NOUN obj
# de ADP case
# el DET det
# comitiva NOUN nmod
# . PUNCT punct
#
#
#  SPACE punct
# veinte NUM nummod
# carruaj NOUN nsubj
# aguardar VERB ROOT
# alineado ADJ obj
# , PUNCT punct
# al ADP case
# borde NOUN fixed
# de ADP fixed
# el DET det
# vereda NOUN obl
# . PUNCT punct
#
#
#  SPACE dep
# el DET det
# esposo NOUN nsubj
# , PUNCT punct
# entrelazado ADJ amod
# el DET det
# brazo NOUN obj
# , PUNCT punct
# salir VERB ROOT
# seguido ADJ obj
# del ADP case
# cortejo NOUN obl
# , PUNCT punct
#
#  SPACE advcl
# que SCONJ mark
# él PRON obj
# reunir VERB ccomp
# delante ADV advmod
# del ADP case
# coche NOUN obl
# nupcial ADJ amod
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# novio NOUN nsubj
# estrechar VERB advcl
# con ADP case
# efusion PROPN obl
# el DET det
# mano NOUN obj
# á ADP case
# Coll PROPN nmod
# . PUNCT punct
#
#
#  SPACE nsubj
# --¡Noble PROPN flat
# corazon!--le ADJ flat
# dijo--¡que SCONJ punct
# el DET det
# espectáculo NOUN appos
# de ADP case
# nuestro DET det
# felicidad NOUN nmod
#
#  SPACE punct
# ser AUX cop
# su DET det
# recompensa NOUN nsubj
# ! PUNCT punct
#
#
#  SPACE amod
# Y CCONJ cc
# volver él VERB conj
# á ADP case
# el DET det
# comitiva NOUN obj
# cambiar VERB ROOT
# con ADP case
# él PRON obl
# uno DET det
# mirada NOUN obj
# de ADP case
# inteligencia NOUN nmod
# ; PUNCT punct
#
#  SPACE obl
# luego ADV advmod
# dirigir él VERB advcl
# al ADP case
# cochero NOUN obj
# . PUNCT punct
#
#
#  SPACE nummod
# --¡al NUM punct
# muelle NOUN ROOT
# de ADP mark
# pasageros!--ordenó NOUN acl
# . PUNCT punct
#
#
#  SPACE ROOT
# el DET det
# novia NOUN nsubj
# mirar él VERB csubj
# sorprendido ADJ obj
# . PUNCT punct
#
#
#  SPACE nummod
# --¡al NUM punct
# muelle NOUN obl
# de ADP case
# pasageros!--repitió--¿dónde PRON nmod
# ir VERB ROOT
# , PUNCT punct
# pues SCONJ mark
# ? PUNCT punct
#
#
#  SPACE ROOT
# --A ADP case
# Francia PROPN nsubj
# , PUNCT punct
# amado ADJ amod
# mia PROPN flat
# , PUNCT punct
# para ADP mark
# pedir VERB advcl
# al ADP case
# sepulcro NOUN obj
# el DET det
# resto NOUN obj
# que PRON nsubj
# lloras VERB acl
# y CCONJ cc
#
#  SPACE conj
# devolver él VERB xcomp
# á ADP case
# el DET det
# tierra NOUN obj
# de ADP case
# el DET det
# patria NOUN nmod
# . PUNCT punct
#
#
#  SPACE xcomp
# el DET det
# jóven ADJ nsubj
# exhalar VERB ROOT
# uno DET det
# gemido NOUN obj
# y CCONJ cc
# arrojar él VERB conj
# en ADP case
# el DET det
# brazo NOUN obl
# del ADP case
# esposo NOUN nmod
# , PUNCT punct
#
#  SPACE aux
# esconder VERB advcl
# el DET det
# frente NOUN obj
# en ADP case
# su DET det
# seno NOUN obl
# . PUNCT punct
#
#
#  SPACE nsubj
# todo PRON flat
# llorar VERB ROOT
# .... PUNCT punct
#
#
#  SPACE obj
# yo PRON nsubj
# tambien PROPN flat
# llorar VERB ROOT
# . PUNCT punct

# %% [markdown]
# ## Practicing with the example text
# When working with languages that have inflection, we typically use `token.lemma_` instead of `token.text` like you'll find in the English examples. This is important when we're counting, so that differently-inflected forms of a word (e.g. masculine vs. feminine or singular vs. plural) aren't counted as if they were different words.

# %%
filepath = "../texts/es.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# ## Get Adjectives

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |

# %% [markdown]
# To extract and count the adjectives in the example text, we will follow the same model as above, except we'll add an `if` statement that will pull out words only if their POS label matches "ADJ."

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# While we demonstrate how to extract parts of speech in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.
# </div>

# %% [markdown]
# Here we make a list of the adjectives identified in the example text:

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.lemma_)

# %%
adjs
# Out:
# ['político',
#  'sombrío',
#  'imbuído',
#  'terrenal',
#  'desconsolado',
#  'ingrato',
#  'humano',
#  'plausibl',
#  'nuevo',
#  'eficaz',
#  'innúmera',
#  'multiplicado',
#  'social',
#  'venerable',
#  'entendido',
#  'grave',
#  '_',
#  'político',
#  '_',
#  'moralizadoro',
#  'colectivo',
#  'precioso',
#  'especulativo',
#  'individual',
#  'concluido',
#  'abstracto',
#  'ilustre',
#  'elevado',
#  'intelectual',
#  'americano',
#  'creador',
#  'lujuriós',
#  'invoco',
#  'presente',
#  'atrayente',
#  'económico',
#  'natural',
#  'ingénuo',
#  'intrigo',
#  'social',
#  'noble',
#  'fuerte',
#  'arenoso',
#  'privilegiado',
#  'prestigioso',
#  'suficiente',
#  'soñadora',
#  'adusta',
#  'economista',
#  '_',
#  'último',
#  'marcado',
#  'chamusquinas',
#  'extremo',
#  'armado',
#  'primero',
#  'último',
#  'último',
#  'cariñoso',
#  'pálido',
#  'mojado',
#  'primero',
#  'aguardado',
#  'auroro',
#  'dramático',
#  'forzado',
#  'risa.--solo',
#  'contento',
#  'diario',
#  'encorvado',
#  'implacable',
#  'terrible',
#  'sano',
#  'fuerte',
#  'propuesto',
#  'pésimo',
#  'querido',
#  'mejor',
#  'largo',
#  'uncido',
#  'rudo',
#  'pegado',
#  'editorial',
#  'folletinista',
#  'corrector',
#  'avaro',
#  'derrochador',
#  'insoluble',
#  'franco',
#  'bueno',
#  'largo',
#  'engolfado',
#  'presuroso',
#  'habitual',
#  'contado',
#  'plácido',
#  'bello',
#  'apuesto',
#  'melancólico',
#  'adverso',
#  'adverso',
#  'adverso',
#  'mecido',
#  'extraño',
#  'desierto',
#  'solo',
#  'solo',
#  'subyugado',
#  'siniestro',
#  'pobre',
#  'temeroso',
#  'acoquinado',
#  'fatídico',
#  'espiado',
#  'suspicaz',
#  'inexorable',
#  'gozós',
#  'inocente',
#  'desconfiado',
#  'ocúltanse',
#  'ocúltanse',
#  'primero',
#  'triste',
#  'enemigo',
#  'hostil',
#  'propicio',
#  'retrospectivo',
#  'tristísima',
#  'arrebatado',
#  'inglés',
#  'pobre',
#  'cruel',
#  'materno',
#  'necesario',
#  'bello',
#  'característico',
#  'social',
#  'irresistible',
#  'consignado',
#  'buen',
#  'benévolo',
#  'expansivo',
#  'pobre',
#  'oprimido',
#  'feliz',
#  'nuevo',
#  'caluroso',
#  'dulce',
#  'largo',
#  'clásico',
#  'superior',
#  'vestido',
#  'infantil',
#  'viril',
#  'primero',
#  'imponente',
#  'tierno',
#  'cumplido',
#  'divino',
#  'virtuoso',
#  'bueno',
#  'celebrante',
#  'derrama',
#  'gozosa',
#  'alto',
#  'central',
#  'solo',
#  'solemne',
#  'solo',
#  'mr',
#  'buen',
#  'enternecido',
#  'lindo',
#  'viejo',
#  'recuerdo',
#  'debido',
#  'primero',
#  'imponente',
#  'prez',
#  'profundo',
#  'viejo',
#  'lejano',
#  'angelical',
#  'santo',
#  'notable',
#  'inquieto',
#  'cosmopolita',
#  'exaltado',
#  'clásico',
#  'tricolor',
#  '_',
#  '_',
#  'azul',
#  'sagrado',
#  'nacional',
#  'lejano',
#  'aparecíale',
#  'inmenso',
#  'magestuoso',
#  'cerúlea',
#  'poderoso',
#  'luminoso',
#  'siniestro',
#  'humillante',
#  'consultado',
#  'corregido',
#  'dictado',
#  'déspoto',
#  'acabado',
#  'rendido',
#  'último',
#  'vergonzoso',
#  'eterno',
#  'profundo',
#  'único',
#  'inesperado',
#  'honorable',
#  '--«alejado',
#  'otro--decíale',
#  'sagrado.--y',
#  'único',
#  'urbano',
#  'rural',
#  'esposo',
#  'pidióle',
#  'dicho',
#  'motivado',
#  'conyugal',
#  'angustioso',
#  'aliviado',
#  'grave',
#  'largo',
#  'fuerte',
#  'persuadido',
#  'floreciente',
#  'buen',
#  'subido',
#  'réstame',
#  'ignorado',
#  'favorable',
#  'alejado',
#  'funesta',
#  'hostil',
#  'desechado',
#  'previsoro',
#  'moribundo',
#  'forzoso',
#  'independiente',
#  'profundo',
#  'honrado',
#  'doloroso',
#  'doble',
#  'cumplido',
#  'pleno',
#  'desamparado',
#  'melancólico',
#  'bullicioso',
#  'libre',
#  'independiente',
#  'pródigo',
#  'intelectual',
#  'activo',
#  'principal',
#  'brillante',
#  'firmado',
#  'pálido',
#  'ardiente',
#  'ideal',
#  'evocado',
#  'latente',
#  'activo',
#  'americano',
#  'intelectual',
#  'íntimo',
#  'cansado',
#  'empobrecido',
#  'rico',
#  'jóven',
#  'vano',
#  'idéntico',
#  'portador',
#  'nuevo',
#  'fuerte',
#  'resignado',
#  'querido',
#  'carta.--por',
#  'envuelto',
#  'producido',
#  'sócio',
#  'bribon',
#  'fulminante',
#  'munido',
#  'numerario',
#  'existente',
#  'enorme',
#  'pasivo',
#  'particular',
#  'infame',
#  'impuesto',
#  'súbita',
#  'desventurado',
#  'silencioso',
#  'alto',
#  'muerto',
#  'verdadero',
#  'humano',
#  'acompañado',
#  'especial',
#  'buen',
#  'nacional',
#  'cobrado',
#  'nacional',
#  'adjunto',
#  'noble',
#  'rara',
#  'inmenso',
#  'solo',
#  'nacional',
#  'puro',
#  'ardiente',
#  'severo',
#  'pobre',
#  'desterrado',
#  'tambien',
#  'desamparado',
#  'tutelar',
#  'intelectual',
#  'riente',
#  'hospitalario',
#  'adio',
#  'antiguo',
#  'sábio',
#  'buen',
#  'buen',
#  'maternal',
#  'helado',
#  'pobre',
#  'pequeño',
#  'largo',
#  'inglés',
#  'larga',
#  'frio',
#  'inmenso',
#  'desconocido',
#  'gris',
#  'piadosa',
#  'tratado',
#  'tierno',
#  'cuidado',
#  'reconcentrado',
#  'entumecido',
#  'dulce',
#  'plácido',
#  'necesario',
#  'perpétuo',
#  'amable',
#  'anciano',
#  'digno',
#  'argentino',
#  'halagado',
#  'francés',
#  'porteño',
#  'jóven',
#  'cariñoso',
#  'conocido',
#  'noble',
#  'neutral',
#  'fuerte',
#  'fuerte',
#  'jóven',
#  'musical',
#  'europeo',
#  'llegado',
#  'pobre',
#  'solo',
#  'hundido',
#  'rendido',
#  'último',
#  'viejo',
#  'útil',
#  'solo',
#  'agradable',
#  'mala',
#  'fuerte',
#  'impuesto',
#  'mayor',
#  'enternecido',
#  'noble',
#  'servicial',
#  'benéfico',
#  'venido',
#  'solo',
#  'sentado',
#  'vestido',
#  'largo',
#  'grande',
#  'negro',
#  'fijo',
#  'lejano',
#  'caluroso',
#  'tristísima',
#  'inglés',
#  'desconocido',
#  'lloroso',
#  'lontananza',
#  'perpétuo',
#  'exhalóse',
#  'bullicioso',
#  'alegre',
#  'despabilado',
#  'doloroso',
#  'oculto',
#  'ruidoso',
#  'insignificante',
#  'solitario',
#  'incierto',
#  'jóven',
#  'enlutado',
#  'nocturno',
#  'jóven',
#  'indiscreta',
#  'sagrado',
#  'solitario',
#  'cubierto',
#  'largo',
#  'sentado',
#  'primero',
#  'propio',
#  'interesante',
#  'jóven',
#  'anciano',
#  'implacable',
#  'temible',
#  'nublado',
#  'surto',
#  'natal',
#  'extraño',
#  'mejor',
#  'forastero',
#  'forastero',
#  'gran',
#  'buena',
#  'gran',
#  'mejor',
#  'gran',
#  '_',
#  'triste',
#  'grandioso',
#  'grande',
#  'glorioso',
#  'nivelada',
#  'lleno',
#  'surcada',
#  'férreo',
#  'ancho',
#  'rico',
#  'renovado',
#  'transformado',
#  'adornado',
#  'fabuloso',
#  'suntuoso',
#  'visitado',
#  'régio',
#  'tutelar',
#  'aglomerado',
#  'vasto',
#  'poderoso',
#  'fuerte',
#  'nacional',
#  'extranjero',
#  'pobre',
#  'desconocido',
#  'nacional',
#  'suntuoso',
#  'hecho',
#  'lúgubre',
#  'triste',
#  'solo',
#  'colocado',
#  'amargo',
#  'ceniza',
#  'opuesto',
#  'aislado',
#  'solitario',
#  'severo',
#  '_',
#  '_',
#  'siguiente',
#  'caro',
#  'indicado',
#  'instalado',
#  'acreditado',
#  'distinguido',
#  'literato',
#  'jóven',
#  'amable',
#  'alentadoro',
#  'importante',
#  'editorial',
#  'frecuente',
#  'material',
#  'intimado',
#  'nuevo',
#  'domicilio',
#  'pensionado',
#  'francés',
#  'cercano',
#  'francés',
#  'amable',
#  'viejo',
#  'agrado',
#  'gran',
#  'imposible',
#  'pensionado',
#  'femenino',
#  'general',
#  'excluido',
#  'verdadero',
#  'antiguo',
#  'célebre',
#  'querido',
#  'contínuo',
#  'invisible',
#  'terrible',
#  'contentaré',
#  'invisible',
#  'fuerte',
#  'expuesto',
#  'espontáneo',
#  'francés',
#  '--reunido',
#  'atenuant',
#  'jóven',
#  'adverso',
#  'viejo',
#  'rigoroso',
#  'de--forzós',
#  '_',
#  'primero',
#  '_',
#  'único',
#  'pequeño',
#  'aseado',
#  'azul',
#  'blanco',
#  'empapelado',
#  'clavado',
#  'alto',
#  'oculto',
#  'azul',
#  'vecino',
#  'blanco',
#  'cómodo',
#  'central',
#  'modesto',
#  'pequeño',
#  'deficiente',
#  'buen',
#  'parisiense',
#  '_',
#  'encantado',
#  'nuevo',
#  'encendido',
#  'abierto',
#  'mullido',
#  'sahumado',
#  'alhucema',
#  'preparado',
#  'damasco',
#  'azul',
#  'cómodo',
#  'blanco',
#  'benéfico',
#  'ramilletito',
#  'pobre',
#  'proscrito',
#  'distraido',
#  'larga',
#  'reunido',
#  'casual',
#  'humano',
#  'esperado',
#  'fortuito',
#  'solemne',
#  'trivial',
#  'entero',
#  'silencioso',
#  'ligero',
#  'suavísimo',
#  'ténue',
#  'seguido',
#  'primero',
#  'inmóvil',
#  'misterioso',
#  'léjo',
#  'primaveral',
#  'fantástico',
#  'aéreo',
#  'misterioso',
#  'cuarto',
#  'vecino',
#  'silencioso',
#  'encantado',
#  'bello',
#  'cierto',
#  'encargado',
#  'necesario',
#  'encerrado',
#  'exterior',
#  'establecido',
#  '_',
#  '_',
#  'bello',
#  'buen',
#  'encerrado',
#  'rigoroso',
#  'vecino',
#  'tonto',
#  'dábame',
#  'ideal',
#  'malo',
#  'gran',
#  '_',
#  'entero',
#  'espiritual',
#  'colaborador',
#  'suscrito',
#  'principal',
#  'oculto',
#  'camarero',
#  'ocupado',
#  'pesado',
#  'quejumbroso',
#  'dulcísimo',
#  'pesado',
#  '--¡por',
#  'brutal',
#  'delicado',
#  'insoportable',
#  'necesario',
#  'preciso',
#  'loco',
#  'dulce',
#  'jóven',
#  'florido',
#  'lijera',
#  'sencillo',
#  'mismo',
#  'lindo!--añado',
#  'último',
#  'odiós',
#  'único',
#  'mismo',
#  'buen',
#  'malo',
#  'quédate',
#  '--imposible',
#  'vestido',
#  'largo',
#  'corbatita',
#  'teatral',
#  'interior',
#  'joven',
#  'entero',
#  'excelente',
#  'picante',
#  'pintoresco',
#  'gracioso',
#  '_',
#  '_',
#  'sencillo',
#  'caprichoso',
#  'griego',
#  'romano',
#  '--esquisito',
#  'condensado',
#  'mágico',
#  'maravilloso',
#  'emporio',
#  'rico',
#  'suculento',
#  'bello',
#  'grande',
#  'acreditado',
#  'destinado',
#  'decorado',
#  'reservado',
#  'amable',
#  'insoportable',
#  'pestilente',
#  'frecuentado',
#  'cuarto',
#  'profundo',
#  'inclinado',
#  'azul',
#  'servido',
#  'dorado',
#  'apetitoso',
#  'frio',
#  'exquisito',
#  'resentido',
#  'ofendido',
#  'solo',
#  'primaveral',
#  'agrupada',
#  'perfume--gústano',
#  'buena',
#  'avergonzado',
#  'nuevo',
#  'agachado',
#  'fisgón',
#  'francés',
#  'dorado',
#  'lábio',
#  'pegado',
#  'entendido',
#  'pegado',
#  'muerto',
#  'astuto',
#  'quietecito',
#  'absorto',
#  'gran',
#  'deseado',
#  'buen',
#  'inocente',
#  'dulcísimo',
#  'cierto',
#  'ocupado',
#  'extático',
#  'cierto',
#  'excelente',
#  'verdadero',
#  'francés',
#  'honrado',
#  'natural',
#  'solo',
#  'encerrado',
#  'fresco',
#  'femenino',
#  'penoso',
#  'confuso',
#  'avergonzado',
#  'íntimo',
#  'misterioso',
#  'sirviento',
#  'ideal',
#  'dulcísimo',
#  'ruidoso',
#  'inmediato',
#  'inteligente',
#  'único',
#  'francés',
#  'picado',
#  'precioso',
#  'limeño',
#  'partidario',
#  'firmado',
#  'literario',
#  'vino»--y',
#  'primero',
#  'equivocado',
#  'pleno',
#  'evangélico',
#  'teólogo',
#  'remoto',
#  'presente',
#  'humano',
#  'último',
#  'repugnante',
#  'odioso',
#  'alto',
#  'doble',
#  'largo',
#  'femenil',
#  'mismo',
#  'angosta',
#  'mayor',
#  'mismo',
#  'autoritario',
#  'eterno',
#  'desventurado',
#  'triste',
#  'solo',
#  'alegre',
#  'contento',
#  '--de',
#  'buen',
#  'mejor',
#  'poderoso',
#  'querido',
#  'memoria!--oyóse',
#  'piadoso',
#  'explícito',
#  'implícito',
#  'integrante',
#  'destinado',
#  'humano',
#  'deliciós',
#  'mismo',
#  'radioso',
#  'disipado',
#  'apasionado',
#  'encarnado',
#  'misterioso',
#  'elevado',
#  'concluido',
#  'enrollado',
#  'avergonzado',
#  'urgente',
#  'central',
#  'cerrado',
#  'misterioso',
#  'insoluble',
#  'claro',
#  'sencillo',
#  'seguido',
#  'biográfica',
#  'cronológico',
#  'alegrísimo',
#  'rico',
#  'estanciero',
#  'innumerable',
#  'referente',
#  'desordenado',
#  'inagotable',
#  'antiguo',
#  'fundado',
#  'servido',
#  'recto',
#  'limpio',
#  '_',
#  'siguiente',
#  'delatado',
#  'profesoro',
#  'tranquilo',
#  'profundo',
#  'abierto',
#  'dulcísimo',
#  'todas--pues',
#  'grande',
#  'rosado',
#  'pálido',
#  'rubio',
#  'último',
#  'ofrenda',
#  'jóven',
#  'morén',
#  'esbelto',
#  'oval',
#  'elevado',
#  'abundoso',
#  'vestido',
#  'elegante',
#  'severo',
#  'cruzado',
#  'grande',
#  'negro',
#  'ténue',
#  'juvenil',
#  'reflexivo',
#  'indefinible',
#  'negro',
#  'absorto',
#  'alzáronse',
#  'tímido',
#  'desnudo',
#  'angustioso',
#  'guiado',
#  'ahogado',
#  'cerrado',
#  'encarado',
#  'tercero',
#  'primero',
#  'libre',
#  'guiado',
#  'herido',
#  'empecinado',
#  'largo',
#  'entre',
#  'acostado',
#  'cubierto',
#  'sordo',
#  'persistente',
#  'espeso',
#  'sentado',
#  'gran',
#  'negro',
#  'único',
#  'sentado',
#  'blanco',
#  'fino',
#  'satinado',
#  'rosado',
#  'transparente',
#  'bello',
#  'presente',
#  'primero',
#  'agudo',
#  'dulce',
#  'amoroso',
#  'desconocido',
#  'aterrado',
#  'largo',
#  'inmóvil',
#  'dulce',
#  'desvarío',
#  'vecino',
#  'diagnóstico',
#  'anciana--un',
#  'automático',
#  'inmóvil',
#  'herido',
#  'natural',
#  'necesario',
#  'completo',
#  'hábil',
#  'buen',
#  'radioso',
#  'adorable',
#  'feliz!--concluyó--¡rodeado',
#  'bello',
#  'desalmado',
#  'nacional',
#  'central',
#  'femenil',
#  'claro',
#  'oscuro',
#  'blanco',
#  'pálido',
#  'extraida',
#  'seda',
#  'abierto',
#  'inútil--díjole',
#  'cortesito',
#  'convertido',
#  'grande',
#  'sábán',
#  'natal',
#  'aguardábale',
#  'gran',
#  'necesario',
#  'mismo',
#  'amante',
#  'adio',
#  'fúnebre',
#  'junto',
#  'amado',
#  'desaparecido',
#  'misio',
#  'éco',
#  'delicioso',
#  'deliciós',
#  'malsano',
#  'mejor',
#  'magnífico',
#  'delicado',
#  'afabl',
#  'cortés',
#  'xxiii',
#  'empleado',
#  'preciso',
#  'distinguido',
#  'femenino',
#  'galante',
#  'mias,--dijo',
#  'solo',
#  'rodeado',
#  'amable',
#  'verdadero',
#  'silencio--repuso',
#  'laurencia.--pero',
#  'fuerte',
#  'espiritual',
#  'editorial',
#  'folletinista--le',
#  'romanz',
#  'furtivo',
#  'esbelto',
#  'dulcísimo',
#  'final',
#  'misterioso',
#  'alto',
#  'juvenil',
#  'fortificante',
#  'convalecencias--añadió',
#  'cómico',
#  'autoridad;--diz',
#  'delicioso',
#  'solo',
#  'primero',
#  'buen',
#  'jóven',
#  'mismo',
#  'cicatrizado',
#  'increible',
#  'buen',
#  'convaleciente',
#  'ido--por',
#  'excelente',
#  'decaido',
#  ...]

# %% [markdown]
# Then we count the unique adjectives in this list with the `Counter()` module:

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('_', 18),
#  ('solo', 16),
#  ('buen', 16),
#  ('primero', 15),
#  ('jóven', 13),
#  ('último', 11),
#  ('largo', 11),
#  ('bello', 11),
#  ('gran', 11),
#  ('fuerte', 10),
#  ('pobre', 10),
#  ('único', 9),
#  ('mismo', 9),
#  ('blanco', 8),
#  ('misterioso', 8),
#  ('nuevo', 7),
#  ('dulce', 7),
#  ('profundo', 7),
#  ('nacional', 7),
#  ('desconocido', 7),
#  ('francés', 7),
#  ('humano', 6),
#  ('querido', 6),
#  ('mejor', 6),
#  ('necesario', 6),
#  ('alto', 6),
#  ('viejo', 6),
#  ('antiguo', 6),
#  ('grande', 6),
#  ('negro', 6),
#  ('natural', 5),
#  ('azul', 5),
#  ('verdadero', 5),
#  ('amable', 5),
#  ('dulcísimo', 5),
#  ('amado', 5),
#  ('intelectual', 4),
#  ('presente', 4),
#  ('noble', 4),
#  ('pálido', 4),
#  ('adverso', 4),
#  ('triste', 4),
#  ('vestido', 4),
#  ('central', 4),
#  ('inmenso', 4),
#  ('rico', 4),
#  ('silencioso', 4),
#  ('benéfico', 4),
#  ('sentado', 4),
#  ('vecino', 4),
#  ('sencillo', 4),
#  ('cerrado', 4),
#  ('social', 3),
#  ('grave', 3),
#  ('precioso', 3),
#  ('elevado', 3),
#  ('contento', 3),
#  ('pegado', 3),
#  ('editorial', 3),
#  ('inglés', 3),
#  ('feliz', 3),
#  ('imponente', 3),
#  ('divino', 3),
#  ('solemne', 3),
#  ('lindo', 3),
#  ('lejano', 3),
#  ('poderoso', 3),
#  ('eterno', 3),
#  ('ideal', 3),
#  ('particular', 3),
#  ('severo', 3),
#  ('tutelar', 3),
#  ('helado', 3),
#  ('pequeño', 3),
#  ('oculto', 3),
#  ('solitario', 3),
#  ('lleno', 3),
#  ('distinguido', 3),
#  ('femenino', 3),
#  ('abierto', 3),
#  ('entero', 3),
#  ('seguido', 3),
#  ('inmóvil', 3),
#  ('primaveral', 3),
#  ('cierto', 3),
#  ('encerrado', 3),
#  ('excelente', 3),
#  ('avergonzado', 3),
#  ('penoso', 3),
#  ('rosado', 3),
#  ('elegante', 3),
#  ('junto', 3),
#  ('político', 2),
#  ('entendido', 2),
#  ('concluido', 2),
#  ('americano', 2),
#  ('económico', 2),
#  ('cariñoso', 2),
#  ('implacable', 2),
#  ('terrible', 2),
#  ('sano', 2),
#  ('insoluble', 2),
#  ('bueno', 2),
#  ('plácido', 2),
#  ('melancólico', 2),
#  ('extraño', 2),
#  ('siniestro', 2),
#  ('fatídico', 2),
#  ('inocente', 2),
#  ('ocúltanse', 2),
#  ('hostil', 2),
#  ('tristísima', 2),
#  ('cruel', 2),
#  ('benévolo', 2),
#  ('caluroso', 2),
#  ('clásico', 2),
#  ('tierno', 2),
#  ('cumplido', 2),
#  ('celebrante', 2),
#  ('enternecido', 2),
#  ('sagrado', 2),
#  ('rendido', 2),
#  ('dicho', 2),
#  ('angustioso', 2),
#  ('persuadido', 2),
#  ('favorable', 2),
#  ('independiente', 2),
#  ('honrado', 2),
#  ('doloroso', 2),
#  ('doble', 2),
#  ('pleno', 2),
#  ('desamparado', 2),
#  ('bullicioso', 2),
#  ('libre', 2),
#  ('activo', 2),
#  ('principal', 2),
#  ('firmado', 2),
#  ('ardiente', 2),
#  ('íntimo', 2),
#  ('idéntico', 2),
#  ('resignado', 2),
#  ('impuesto', 2),
#  ('desventurado', 2),
#  ('muerto', 2),
#  ('acompañado', 2),
#  ('adio', 2),
#  ('larga', 2),
#  ('frio', 2),
#  ('perpétuo', 2),
#  ('anciano', 2),
#  ('digno', 2),
#  ('mayor', 2),
#  ('alegre', 2),
#  ('ruidoso', 2),
#  ('cubierto', 2),
#  ('propio', 2),
#  ('natal', 2),
#  ('forastero', 2),
#  ('buena', 2),
#  ('adornado', 2),
#  ('suntuoso', 2),
#  ('amargo', 2),
#  ('siguiente', 2),
#  ('acreditado', 2),
#  ('pensionado', 2),
#  ('invisible', 2),
#  ('rigoroso', 2),
#  ('cómodo', 2),
#  ('modesto', 2),
#  ('encantado', 2),
#  ('proscrito', 2),
#  ('suavísimo', 2),
#  ('ténue', 2),
#  ('cuarto', 2),
#  ('malo', 2),
#  ('espiritual', 2),
#  ('ocupado', 2),
#  ('pesado', 2),
#  ('delicado', 2),
#  ('insoportable', 2),
#  ('preciso', 2),
#  ('griego', 2),
#  ('mágico', 2),
#  ('destinado', 2),
#  ('servido', 2),
#  ('dorado', 2),
#  ('absorto', 2),
#  ('femenil', 2),
#  ('deliciós', 2),
#  ('radioso', 2),
#  ('claro', 2),
#  ('tranquilo', 2),
#  ('morén', 2),
#  ('esbelto', 2),
#  ('juvenil', 2),
#  ('guiado', 2),
#  ('herido', 2),
#  ('fino', 2),
#  ('satinado', 2),
#  ('hábil', 2),
#  ('delicioso', 2),
#  ('trasparent', 2),
#  ('nupcial', 2),
#  ('encantador', 2),
#  ('curioso', 2),
#  ('simpático', 2),
#  ('formado', 2),
#  ('sombrío', 1),
#  ('imbuído', 1),
#  ('terrenal', 1),
#  ('desconsolado', 1),
#  ('ingrato', 1),
#  ('plausibl', 1),
#  ('eficaz', 1),
#  ('innúmera', 1),
#  ('multiplicado', 1),
#  ('venerable', 1),
#  ('moralizadoro', 1),
#  ('colectivo', 1),
#  ('especulativo', 1),
#  ('individual', 1),
#  ('abstracto', 1),
#  ('ilustre', 1),
#  ('creador', 1),
#  ('lujuriós', 1),
#  ('invoco', 1),
#  ('atrayente', 1),
#  ('ingénuo', 1),
#  ('intrigo', 1),
#  ('arenoso', 1),
#  ('privilegiado', 1),
#  ('prestigioso', 1),
#  ('suficiente', 1),
#  ('soñadora', 1),
#  ('adusta', 1),
#  ('economista', 1),
#  ('marcado', 1),
#  ('chamusquinas', 1),
#  ('extremo', 1),
#  ('armado', 1),
#  ('mojado', 1),
#  ('aguardado', 1),
#  ('auroro', 1),
#  ('dramático', 1),
#  ('forzado', 1),
#  ('risa.--solo', 1),
#  ('diario', 1),
#  ('encorvado', 1),
#  ('propuesto', 1),
#  ('pésimo', 1),
#  ('uncido', 1),
#  ('rudo', 1),
#  ('folletinista', 1),
#  ('corrector', 1),
#  ('avaro', 1),
#  ('derrochador', 1),
#  ('franco', 1),
#  ('engolfado', 1),
#  ('presuroso', 1),
#  ('habitual', 1),
#  ('contado', 1),
#  ('apuesto', 1),
#  ('mecido', 1),
#  ('desierto', 1),
#  ('subyugado', 1),
#  ('temeroso', 1),
#  ('acoquinado', 1),
#  ('espiado', 1),
#  ('suspicaz', 1),
#  ('inexorable', 1),
#  ('gozós', 1),
#  ('desconfiado', 1),
#  ('enemigo', 1),
#  ('propicio', 1),
#  ('retrospectivo', 1),
#  ('arrebatado', 1),
#  ('materno', 1),
#  ('característico', 1),
#  ('irresistible', 1),
#  ('consignado', 1),
#  ('expansivo', 1),
#  ('oprimido', 1),
#  ('superior', 1),
#  ('infantil', 1),
#  ('viril', 1),
#  ('virtuoso', 1),
#  ('derrama', 1),
#  ('gozosa', 1),
#  ('mr', 1),
#  ('recuerdo', 1),
#  ('debido', 1),
#  ('prez', 1),
#  ('angelical', 1),
#  ('santo', 1),
#  ('notable', 1),
#  ('inquieto', 1),
#  ('cosmopolita', 1),
#  ('exaltado', 1),
#  ('tricolor', 1),
#  ('aparecíale', 1),
#  ('magestuoso', 1),
#  ('cerúlea', 1),
#  ('luminoso', 1),
#  ('humillante', 1),
#  ('consultado', 1),
#  ('corregido', 1),
#  ('dictado', 1),
#  ('déspoto', 1),
#  ('acabado', 1),
#  ('vergonzoso', 1),
#  ('inesperado', 1),
#  ('honorable', 1),
#  ('--«alejado', 1),
#  ('otro--decíale', 1),
#  ('sagrado.--y', 1),
#  ('urbano', 1),
#  ('rural', 1),
#  ('esposo', 1),
#  ('pidióle', 1),
#  ('motivado', 1),
#  ('conyugal', 1),
#  ('aliviado', 1),
#  ('floreciente', 1),
#  ('subido', 1),
#  ('réstame', 1),
#  ('ignorado', 1),
#  ('alejado', 1),
#  ('funesta', 1),
#  ('desechado', 1),
#  ('previsoro', 1),
#  ('moribundo', 1),
#  ('forzoso', 1),
#  ('pródigo', 1),
#  ('brillante', 1),
#  ('evocado', 1),
#  ('latente', 1),
#  ('cansado', 1),
#  ('empobrecido', 1),
#  ('vano', 1),
#  ('portador', 1),
#  ('carta.--por', 1),
#  ('envuelto', 1),
#  ('producido', 1),
#  ('sócio', 1),
#  ('bribon', 1),
#  ('fulminante', 1),
#  ('munido', 1),
#  ('numerario', 1),
#  ('existente', 1),
#  ('enorme', 1),
#  ('pasivo', 1),
#  ('infame', 1),
#  ('súbita', 1),
#  ('especial', 1),
#  ('cobrado', 1),
#  ('adjunto', 1),
#  ('rara', 1),
#  ('puro', 1),
#  ('desterrado', 1),
#  ('tambien', 1),
#  ('riente', 1),
#  ('hospitalario', 1),
#  ('sábio', 1),
#  ('maternal', 1),
#  ('gris', 1),
#  ('piadosa', 1),
#  ('tratado', 1),
#  ('cuidado', 1),
#  ('reconcentrado', 1),
#  ('entumecido', 1),
#  ('argentino', 1),
#  ('halagado', 1),
#  ('porteño', 1),
#  ('conocido', 1),
#  ('neutral', 1),
#  ('musical', 1),
#  ('europeo', 1),
#  ('llegado', 1),
#  ('hundido', 1),
#  ('útil', 1),
#  ('agradable', 1),
#  ('mala', 1),
#  ('servicial', 1),
#  ('venido', 1),
#  ('fijo', 1),
#  ('lloroso', 1),
#  ('lontananza', 1),
#  ('exhalóse', 1),
#  ('despabilado', 1),
#  ('insignificante', 1),
#  ('incierto', 1),
#  ('enlutado', 1),
#  ('nocturno', 1),
#  ('indiscreta', 1),
#  ('interesante', 1),
#  ('temible', 1),
#  ('nublado', 1),
#  ('surto', 1),
#  ('grandioso', 1),
#  ('glorioso', 1),
#  ('nivelada', 1),
#  ('surcada', 1),
#  ('férreo', 1),
#  ('ancho', 1),
#  ('renovado', 1),
#  ('transformado', 1),
#  ('fabuloso', 1),
#  ('visitado', 1),
#  ('régio', 1),
#  ('aglomerado', 1),
#  ('vasto', 1),
#  ('extranjero', 1),
#  ('hecho', 1),
#  ('lúgubre', 1),
#  ('colocado', 1),
#  ('ceniza', 1),
#  ('opuesto', 1),
#  ('aislado', 1),
#  ('caro', 1),
#  ('indicado', 1),
#  ('instalado', 1),
#  ('literato', 1),
#  ('alentadoro', 1),
#  ('importante', 1),
#  ('frecuente', 1),
#  ('material', 1),
#  ('intimado', 1),
#  ('domicilio', 1),
#  ('cercano', 1),
#  ('agrado', 1),
#  ('imposible', 1),
#  ('general', 1),
#  ('excluido', 1),
#  ('célebre', 1),
#  ('contínuo', 1),
#  ('contentaré', 1),
#  ('expuesto', 1),
#  ('espontáneo', 1),
#  ('--reunido', 1),
#  ('atenuant', 1),
#  ('de--forzós', 1),
#  ('aseado', 1),
#  ('empapelado', 1),
#  ('clavado', 1),
#  ('deficiente', 1),
#  ('parisiense', 1),
#  ('encendido', 1),
#  ('mullido', 1),
#  ('sahumado', 1),
#  ('alhucema', 1),
#  ('preparado', 1),
#  ('damasco', 1),
#  ('ramilletito', 1),
#  ('distraido', 1),
#  ('reunido', 1),
#  ('casual', 1),
#  ('esperado', 1),
#  ('fortuito', 1),
#  ('trivial', 1),
#  ('ligero', 1),
#  ('léjo', 1),
#  ('fantástico', 1),
#  ('aéreo', 1),
#  ('encargado', 1),
#  ('exterior', 1),
#  ('establecido', 1),
#  ('tonto', 1),
#  ('dábame', 1),
#  ('colaborador', 1),
#  ('suscrito', 1),
#  ('camarero', 1),
#  ('quejumbroso', 1),
#  ('--¡por', 1),
#  ('brutal', 1),
#  ('loco', 1),
#  ('florido', 1),
#  ('lijera', 1),
#  ('lindo!--añado', 1),
#  ('odiós', 1),
#  ('quédate', 1),
#  ('--imposible', 1),
#  ('corbatita', 1),
#  ('teatral', 1),
#  ('interior', 1),
#  ('joven', 1),
#  ('picante', 1),
#  ('pintoresco', 1),
#  ('gracioso', 1),
#  ('caprichoso', 1),
#  ('romano', 1),
#  ('--esquisito', 1),
#  ('condensado', 1),
#  ('maravilloso', 1),
#  ('emporio', 1),
#  ('suculento', 1),
#  ('decorado', 1),
#  ('reservado', 1),
#  ('pestilente', 1),
#  ('frecuentado', 1),
#  ('inclinado', 1),
#  ('apetitoso', 1),
#  ('exquisito', 1),
#  ('resentido', 1),
#  ('ofendido', 1),
#  ('agrupada', 1),
#  ('perfume--gústano', 1),
#  ('agachado', 1),
#  ('fisgón', 1),
#  ('lábio', 1),
#  ('astuto', 1),
#  ('quietecito', 1),
#  ('deseado', 1),
#  ('extático', 1),
#  ('fresco', 1),
#  ('confuso', 1),
#  ('sirviento', 1),
#  ('inmediato', 1),
#  ('inteligente', 1),
#  ('picado', 1),
#  ('limeño', 1),
#  ('partidario', 1),
#  ('literario', 1),
#  ('vino»--y', 1),
#  ('equivocado', 1),
#  ('evangélico', 1),
#  ('teólogo', 1),
#  ('remoto', 1),
#  ('repugnante', 1),
#  ('odioso', 1),
#  ('angosta', 1),
#  ('autoritario', 1),
#  ('--de', 1),
#  ('memoria!--oyóse', 1),
#  ('piadoso', 1),
#  ('explícito', 1),
#  ('implícito', 1),
#  ('integrante', 1),
#  ('disipado', 1),
#  ('apasionado', 1),
#  ('encarnado', 1),
#  ('enrollado', 1),
#  ('urgente', 1),
#  ('biográfica', 1),
#  ('cronológico', 1),
#  ('alegrísimo', 1),
#  ('estanciero', 1),
#  ('innumerable', 1),
#  ('referente', 1),
#  ('desordenado', 1),
#  ('inagotable', 1),
#  ('fundado', 1),
#  ('recto', 1),
#  ('limpio', 1),
#  ('delatado', 1),
#  ('profesoro', 1),
#  ('todas--pues', 1),
#  ('rubio', 1),
#  ('ofrenda', 1),
#  ('oval', 1),
#  ('abundoso', 1),
#  ('cruzado', 1),
#  ('reflexivo', 1),
#  ('indefinible', 1),
#  ('alzáronse', 1),
#  ('tímido', 1),
#  ('desnudo', 1),
#  ('ahogado', 1),
#  ('encarado', 1),
#  ('tercero', 1),
#  ('empecinado', 1),
#  ('entre', 1),
#  ('acostado', 1),
#  ('sordo', 1),
#  ('persistente', 1),
#  ('espeso', 1),
#  ('transparente', 1),
#  ('agudo', 1),
#  ('amoroso', 1),
#  ('aterrado', 1),
#  ('desvarío', 1),
#  ('diagnóstico', 1),
#  ('anciana--un', 1),
#  ('automático', 1),
#  ('completo', 1),
#  ('adorable', 1),
#  ('feliz!--concluyó--¡rodeado', 1),
#  ('desalmado', 1),
#  ('oscuro', 1),
#  ('extraida', 1),
#  ('seda', 1),
#  ('inútil--díjole', 1),
#  ('cortesito', 1),
#  ('convertido', 1),
#  ('sábán', 1),
#  ('aguardábale', 1),
#  ('amante', 1),
#  ('fúnebre', 1),
#  ('desaparecido', 1),
#  ('misio', 1),
#  ('éco', 1),
#  ('malsano', 1),
#  ('magnífico', 1),
#  ('afabl', 1),
#  ('cortés', 1),
#  ('xxiii', 1),
#  ('empleado', 1),
#  ('galante', 1),
#  ('mias,--dijo', 1),
#  ('rodeado', 1),
#  ('silencio--repuso', 1),
#  ('laurencia.--pero', 1),
#  ('folletinista--le', 1),
#  ('romanz', 1),
#  ('furtivo', 1),
#  ('final', 1),
#  ('fortificante', 1),
#  ('convalecencias--añadió', 1),
#  ('cómico', 1),
#  ('autoridad;--diz', 1),
#  ('cicatrizado', 1),
#  ('increible', 1),
#  ('convaleciente', 1),
#  ('ido--por', 1),
#  ('decaido', 1),
#  ('mejillas--yo', 1),
#  ('comprendido', 1),
#  ('aceptado', 1),
#  ('bajo', 1),
#  ('--¡paro', 1),
#  ('radiosa', 1),
#  ('sobrenatural', 1),
#  ('terrestre', 1),
#  ('visible', 1),
#  ('sobrefalda', 1),
#  ('hermoso', 1),
#  ('mias--dijo', 1),
#  ('conmovido--¡cuánto', 1),
#  ('pícaro', 1),
#  ('--condenado', 1),
#  ('negado', 1),
#  ('--honorable', 1),
#  ('sentenciado', 1),
#  ('manecita', 1),
#  ('discreto', 1),
#  ('túnica', 1),
#  ('perdido', 1),
#  ('caballeresca', 1),
#  ('posible', 1),
#  ('figurin', 1),
#  ('cegado', 1),
#  ('julia,--pero', 1),
#  ('ausente', 1),
#  ('listo', 1),
#  ('tendido', 1),
#  ('inundado', 1),
#  ('semejante', 1),
#  ('novio', 1),
#  ('inminente', 1),
#  ('rápido', 1),
#  ('inquietándolo', 1),
#  ('holgado', 1),
#  ('idolatrado', 1),
#  ('seguro', 1),
#  ('lento', 1),
#  ('audaz', 1),
#  ('tenebrosa', 1),
#  ('surjir', 1),
#  ('áspero', 1),
#  ('ella--pero', 1),
#  ('restante', 1),
#  ('empleado--con', 1),
#  ('caracterizado', 1),
#  ('atraido', 1),
#  ('ocurrido', 1),
#  ('accionista', 1),
#  ('presentado', 1),
#  ('demandado', 1),
#  ('perteneciente', 1),
#  ('grato', 1),
#  ('depositado', 1),
#  ('encontráronse', 1),
#  ('endosado', 1),
#  ('segundo', 1),
#  ('lucrecia,--decía', 1),
#  ('habrás', 1),
#  ('valioso', 1),
#  ('filial', 1),
#  ('entusiasta', 1),
#  ('sério', 1),
#  ('guant', 1),
#  ('abanico', 1),
#  ('liso', 1),
#  ('--poca', 1),
#  ('doctor', 1),
#  ('elocuentísimo', 1),
#  ('contrayent', 1),
#  ('sacramental', 1),
#  ('pronunciado', 1),
#  ('conmovedor', 1),
#  ('animoso', 1),
#  ('débil', 1),
#  ('creado', 1),
#  ('futuro', 1),
#  ('altísimo', 1),
#  ('alineado', 1),
#  ('entrelazado', 1),
#  ('corazon!--le', 1),
#  ('sorprendido', 1)]

# %% [markdown]
# Then we make a dataframe from this list:

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#             adj  count
# 0             _     18
# 1          solo     16
# 2          buen     16
# 3       primero     15
# 4         jóven     13
# 5        último     11
# 6         largo     11
# 7         bello     11
# 8          gran     11
# 9        fuerte     10
# 10        pobre     10
# 11        único      9
# 12        mismo      9
# 13       blanco      8
# 14   misterioso      8
# 15        nuevo      7
# 16        dulce      7
# 17     profundo      7
# 18     nacional      7
# 19  desconocido      7
# 20      francés      7
# 21       humano      6
# 22      querido      6
# 23        mejor      6
# 24    necesario      6
# 25         alto      6
# 26        viejo      6
# 27      antiguo      6
# 28       grande      6
# 29        negro      6
# 30      natural      5
# 31         azul      5
# 32    verdadero      5
# 33       amable      5
# 34    dulcísimo      5
# 35        amado      5
# 36  intelectual      4
# 37     presente      4
# 38        noble      4
# 39       pálido      4
# 40      adverso      4
# 41       triste      4
# 42      vestido      4
# 43      central      4
# 44      inmenso      4
# 45         rico      4
# 46   silencioso      4
# 47     benéfico      4
# 48      sentado      4
# 49       vecino      4
# 50     sencillo      4
# 51      cerrado      4
# 52       social      3
# 53        grave      3
# 54     precioso      3
# 55      elevado      3
# 56     contento      3
# 57       pegado      3
# 58    editorial      3
# 59       inglés      3
# 60        feliz      3
# 61    imponente      3
# 62       divino      3
# 63      solemne      3
# 64        lindo      3
# 65       lejano      3
# 66     poderoso      3
# 67       eterno      3
# 68        ideal      3
# 69   particular      3
# 70       severo      3
# 71      tutelar      3
# 72       helado      3
# 73      pequeño      3
# 74       oculto      3
# 75    solitario      3
# 76        lleno      3
# 77  distinguido      3
# 78     femenino      3
# 79      abierto      3
# 80       entero      3
# 81      seguido      3
# 82      inmóvil      3
# 83   primaveral      3
# 84       cierto      3
# 85    encerrado      3
# 86    excelente      3
# 87  avergonzado      3
# 88       penoso      3
# 89       rosado      3
# 90     elegante      3
# 91        junto      3
# 92     político      2
# 93    entendido      2
# 94    concluido      2
# 95    americano      2
# 96    económico      2
# 97     cariñoso      2
# 98   implacable      2
# 99     terrible      2

# %% [markdown]
# ## Get Nouns

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |

# %% [markdown]
# To extract and count nouns, we can follow the same model as above, except we will change our `if` statement to check for POS labels that match "NOUN".

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.lemma_)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#            noun  count
# 0          mano     48
# 1         señor     32
# 2          hora     28
# 3          casa     27
# 4       trabajo     25
# 5        señora     25
# 6          vida     24
# 7         padre     23
# 8        hombre     22
# 9           voz     22
# 10         alma     20
# 11          ojo     20
# 12          vez     19
# 13        mujer     17
# 14          año     16
# 15         hijo     16
# 16       tiempo     15
# 17       mirada     15
# 18          dia     15
# 19      corazon     14
# 20       puerta     14
# 21       cuarto     13
# 22      palabra     12
# 23         niño     12
# 24       doctor     12
# 25       nombre     11
# 26      lágrima     11
# 27       muerte     11
# 28        tanto     11
# 29        carta     11
# 30        dolor     11
# 31     señorita     11
# 32          luz     10
# 33        brazo     10
# 34      destino     10
# 35      embargo     10
# 36       patria     10
# 37        noche     10
# 38  sentimiento     10
# 39      fortuna     10
# 40        joven     10
# 41      tambien     10
# 42         mesa      9
# 43       verdad      9
# 44         paso      9
# 45        órden      9
# 46       diario      9
# 47         idea      8
# 48         vino      8
# 49        poder      8
# 50    felicidad      8
# 51      familia      8
# 52        madre      8
# 53         cama      8
# 54        calle      8
# 55         bien      7
# 56         rayo      7
# 57        jóven      7
# 58    semblante      7
# 59        hácia      7
# 60        mente      7
# 61        gusto      7
# 62     silencio      7
# 63      momento      7
# 64        amigo      7
# 65     camarera      7
# 66       médico      7
# 67       gracia      6
# 68     sepulcro      6
# 69       esposa      6
# 70     recuerdo      6
# 71         aire      6
# 72        lugar      6
# 73        pecho      6
# 74    compañero      6
# 75         amor      6
# 76      persona      6
# 77        valor      6
# 78     gratitud      6
# 79        parte      6
# 80        torno      6
# 81          pié      6
# 82        --¡oh      6
# 83         velo      6
# 84      huésped      6
# 85         dedo      6
# 86      paquete      6
# 87      enfermo      6
# 88          pan      5
# 89     espíritu      5
# 90        libro      5
# 91       página      5
# 92  pensamiento      5
# 93       cuello      5
# 94       rostro      5
# 95        sueño      5
# 96        hogar      5
# 97      colegio      5
# 98         país      5
# 99        clase      5

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the POS label "VERB").

# %% [markdown]
# <div class="admonition pythonreview" name="html-admonition" style="background: lightgreen; padding: 10px">
# <p class="title">Python Review</p>
#
# We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of verbs in a single line of code! Closely examine the first line of code below:
# </div>

# %%
verbs = [token.lemma_ for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#            verb  count
# 0         hacer     55
# 1         decir     37
# 2         tener     33
# 3           dar     27
# 4           ver     22
# 5         venir     21
# 6         saber     21
# 7         creer     20
# 8        querer     20
# 9        hablar     20
# 10       llegar     18
# 11        dejar     17
# 12        tomar     15
# 13       volver     15
# 14     escuchar     15
# 15    encontrar     14
# 16       quedar     13
# 17       sentir     13
# 18       llevar     12
# 19     escribir     12
# 20           ir     12
# 21      parecer     11
# 22        salir     11
# 23        estar     11
# 24         leer     11
# 25      conocer     10
# 26       pensar     10
# 27    despertar     10
# 28      guardar     10
# 29        poner      9
# 30       buscar      9
# 31       seguir      9
# 32      recibir      9
# 33        pasar      8
# 34     aguardar      8
# 35       llorar      8
# 36         caer      8
# 37       llamar      8
# 38        abrir      8
# 39       entrar      8
# 40     comenzar      7
# 41     entregar      7
# 42        vivir      7
# 43       llenar      7
# 44        pedir      7
# 45          oir      6
# 46     recordar      6
# 47         amar      6
# 48    volver él      6
# 49    estrechar      6
# 50         reir      6
# 51       acabar      5
# 52       cubrir      5
# 53      existir      5
# 54       ver él      5
# 55       cerrar      5
# 56   contemplar      5
# 57   comprender      5
# 58         unir      5
# 59    presentar      5
# 60        echar      5
# 61        deber      4
# 62       ocupar      4
# 63       formar      4
# 64     encerrar      4
# 65      arrojar      4
# 66        morir      4
# 67       apoyar      4
# 68       enviar      4
# 69       alejar      4
# 70       tender      4
# 71      visitar      4
# 72      anhelar      4
# 73     declarar      4
# 74        alzar      4
# 75    continuar      4
# 76       lograr      4
# 77        fijar      4
# 78   encontróse      4
# 79     decir él      4
# 80     almorzar      4
# 81  interrumpir      4
# 82     realizar      3
# 83     recorrer      3
# 84      esperar      3
# 85       rodear      3
# 86    consultar      3
# 87         reír      3
# 88     extender      3
# 89     obedecer      3
# 90         deír      3
# 91       tornar      3
# 92      colocar      3
# 93        mirar      3
# 94     efectuar      3
# 95        yacer      3
# 96     contener      3
# 97       desear      3
# 98     preferir      3
# 99   prescribir      3

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ## Get Sentences with Keyword

# %% [markdown]
# spaCy can also identify sentences in a document. To access sentences, we can iterate through `document.sents` and pull out the `.text` of each sentence.

# %% [markdown]
# We can use spaCy's sentence-parsing capabilities to extract sentences that contain particular keywords, such as in the function below. Note that the function assumes that the keyword provided will be exactly the same as it appears in the text (e.g. matching all inflection for case, number, gender, etc. As a Spanish example, if you use `bueno` as the keyboard, it won't match `buena` or `buenos`.)
#
# With the function `find_sentences_with_keyword()`, we will iterate through `document.sents` and pull out any sentence that contains a particular "keyword." Then we will display these sentence with the keywords bolded.

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="bueno", document=document)
# Out:
#                        Á «LA **bueno**S AIRES»                                        _LA AUTORA.
# Enigma insoluble es para mí este jóven, tan franco, sin embargo, y tan **bueno**...  Y Emilio dejando la pluma en largo holgorio, quedóse engolfado en sus pensamientos y en el humo de su cigarro.
#   ¡Qué ceremonia, á la vez tan imponente y tierna!  Cumplido en él, el divino misterio, de rodillas ante el altar, el niño tiende la mano sobre el Sagrado Libro y jura ser virtuoso y **bueno**.
#  Suscribíala el escribano D..., uno de los hombres más honorables de **bueno**s Aires.
#   En el momento que Mauricio preparaba la realizacion de tan lisongero propósito, una carta de **bueno**s Aires, portadora de fatales nuevas, vino á destruir sus proyectos y sus esperanzas.
# Además, en **bueno**s Aires que se agita á   impulsos de un inmenso progreso, podrá Vd. con el trabajo rehacer   su fortuna».
#   Por los diarios de **bueno**s Aires y su propia correspondencia, éranle conocidas sus desgracias y su noble abnegacion.
# ¡Ah! hé ahí, por ejemplo, un modelo de valor y de resignacion: esta jóven hija de **bueno**s Aires, vino hace tres años para perfeccionarse en sus estudios musicales.
# Su padre, ingeniero en comision, regresó á **bueno**s Aires dejándola en casa de una parienta lejana.
# Rendidos al padre los últimos deberes, vuelve á **bueno**s Aires, donde vá á buscar en el trabajo la subsistencia......
#   De la **bueno**s Aires de sus recuerdos, solo reconocía el nombre: tan grande y bella, la gloriosa metrópoli habíase tornado.
# millares de edificios aglomerados en aquel vasto conjunto, brillaba la placa de la Compañía de Seguros «La **bueno**s Aires», poderosa asociacion que cuenta en su seno á los más fuertes capitalistas nacionales y extranjeros.
#   Una vez instalado, buscó trabajo en uno de los diarios más acreditados de **bueno**s Aires.
#   --**bueno** ó malo, déjelas Vd. en él.
#   --El señor Eduardo M. Coll, hijo mio, es Gerente de «La **bueno**s Aires», Compañía de Seguros en la que yo mismo soy accionista ¿qué será ello?
#      XXX   Antes de aquel término el Gerente de «La **bueno**s Aires» recibía una citacion del Banco Nacional con motivo del aviso que por su órden registraban «La Prensa» y «La Tribuna Nacional».
#   Acudió el Gerente, y supo que allí se hallaba, depositado por el señor Cárlos Ridel, un paquete cerrado, que en Junio de 1888 debía ser entregado á la Compañía de Seguros «La **bueno**s Aires».
#   Abierto el paquete, encontráronse con la póliza de seguro sobre la vida de Cárlos Ridel, por 20,000 $ m/n. en 20 años, y en la que constaba el abono de la primera anualidad de 792 $ m/n.; una carta á su esposa, y en defecto de ésta, á su hijo Mauricio; y una letra por 792 $ m/n. á la órden de Cárlos Ridel y endosada por éste á «La **bueno**s Aires», como la segunda cuota que debía pagar por su póliza.
#     «Entre estas, las Compañías de Seguros sónme especialmente   simpáticas, sobretodo, «La **bueno**s Aires», por su importancia y   valiosa organizacion.
#   En el seno de una de esas asociaciones tutelares, «La **bueno**s Aires», la Providencia guardaba un tesoro que á su hora, hizo surgir para recompensar la abnegacion filial y dar la felicidad á los que, creyendo en ella, esperaban.

# %% [markdown]
# ## Get Keyword in Context

# %% [markdown]
# We can also find out about a keyword's more immediate context — its neighboring words to the left and right — and we can fine-tune our search with POS tagging.
#
# To do so, we will first create a list of what's called *ngrams*. "Ngrams" are any sequence of *n* tokens in a text. They're an important concept in computational linguistics and NLP. (Have you ever played with [Google's *Ngram* Viewer](https://books.google.com/ngrams)?)
#
# Below we're going to make a list of *bigrams*, that is, all the two-word combinations from the sample text. We're going to use these bigrams to find the neighboring words that appear alongside particular keywords.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %% [markdown]
# Let's take a peek at the bigrams:

# %%
bigrams[5:20]
# Out:
# [[('imbuído', 'ADJ'), ('sin', 'ADP')],
#  [('sin', 'ADP'), ('duda', 'NOUN')],
#  [('duda', 'NOUN'), ('en', 'ADP')],
#  [('en', 'ADP'), ('las', 'DET')],
#  [('las', 'DET'), ('ideas', 'NOUN')],
#  [('ideas', 'NOUN'), ('de', 'ADP')],
#  [('de', 'ADP'), ('los', 'DET')],
#  [('los', 'DET'), ('Santos', 'PROPN')],
#  [('Santos', 'PROPN'), ('Padres', 'PROPN')],
#  [('Padres', 'PROPN'), ('de', 'ADP')],
#  [('de', 'ADP'), ('la', 'DET')],
#  [('la', 'DET'), ('Iglesia', 'PROPN')],
#  [('Iglesia', 'PROPN'), ('que', 'PRON')],
#  [('que', 'PRON'), ('predicaban', 'VERB')],
#  [('predicaban', 'VERB'), ('el', 'DET')]]

# %% [markdown]
# Now that we have our list of bigrams, we're going to make a function `get_neighbor_words()`. This function will return the most frequent words that appear next to a particular keyword. The function can also be fine-tuned to return neighbor words that match a certain part of speech by changing the `pos_label` parameter.

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("bien", bigrams)
# Out:
# [('más', 2),
#  ('que', 2),
#  ('así', 1),
#  ('fuerte', 1),
#  ('y', 1),
#  ('ya', 1),
#  ('invisible', 1),
#  ('pudiera', 1),
#  ('distraido', 1),
#  ('lo', 1),
#  ('te', 1),
#  ('cosa', 1),
#  ('duerme', 1),
#  ('charlábamos', 1),
#  ('vá', 1),
#  ('no', 1),
#  ('si', 1),
#  ('seguro', 1),
#  ('mi', 1),
#  ('amada', 1),
#  ('tan', 1),
#  ('esta', 1),
#  ('palabra', 1),
#  ('estaba', 1)]

# %%
get_neighbor_words("bien", bigrams, pos_label='VERB')
# Out:
# [('duerme', 1), ('charlábamos', 1), ('vá', 1)]

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Try out `find_sentences_with_keyword()` and `get_neighbor_words` with your own keywords of interest.

# %%
find_sentences_with_keyword(keyword="YOUR KEY WORD", document=document)

# %%
get_neighbor_words(keyword="YOUR KEY WORD", bigrams, pos_label=None)
