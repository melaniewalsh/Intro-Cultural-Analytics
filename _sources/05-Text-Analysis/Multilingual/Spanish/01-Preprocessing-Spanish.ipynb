# %% [markdown]
# # Text Pre-Processing for Spanish

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# This lesson is for anyone who wants to try the [TF-IDF](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/TF-IDF.html) or [topic modeling](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/Topic-Modeling.html) lessons on Spanish texts. Before continuing with those lessons, you need to create a *lemmatized derivative* of your original Spanish text, which replaces all the words with their dictionary form, which will work much better with the word-count based methods.

# %% [markdown]
# ## Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ## Download Language Model

# %%
# !python -m spacy download es_core_news_md

# %% [markdown]
# ## Import Libraries

# %%
import spacy

# %% [markdown]
# ## Load Language Model
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# 1. We can import the model as a module and then load it from the module.

# %%
import es_core_news_md
nlp = es_core_news_md.load()

# %% [markdown]
# 2. We can load the model by name.

# %%
#nlp = spacy.load('es_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it’s advisable to use Option 1. Then you can use the model immediately. Otherwise, you’ll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel… in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document
# To create a derivative text file that we can use with TF-IDF, topic modeling, or other word-count based methods, we need to use spaCy to *lemmatize* the text, replacing each word with its dictionary form. The result will be an ungrammatical text that will produce better results than the original version when used with word-count methods.
#
# The example text for Spanish is *Oasis en la vida* by Juana Manuela Gorriti [from Project Gutenberg](http://www.gutenberg.org/ebooks/62564).

# %% [markdown]
# Here we open the text and process it with the Spanish spaCy model.

# %%
filepath = '../texts/es.txt'
# Open and read text
text = open(filepath, encoding='utf-8').read()
# Process text with spaCy
document = nlp(text)

# %% [markdown]
# Then we loop through each token in the original text, lemmatize each token and insert a space between the tokens, and finally write them to our new segmented derivative text file.

# %%
outname = filepath.replace('.txt', '-lemmatized.txt')

# Create a lemmatized version of the original text file
with open(outname, 'w', encoding='utf8') as out:
    for token in document:
        # Get the lemma for each token
        out.write(token.lemma_.lower())
        # Insert white space between each token
        out.write(' ')

# %% [markdown]
# ## Examine Differences
# The code cell below prints the original word in the text, a dash, then the lemmatized form that was written to the derivative text document that you'll use for TF-IDF and topic modeling. It's a good idea to take a look at this so you can see if there are places where the model consistently makes mistakes.
#
# For instance, an earlier version of spaCy often associated the Spanish preposition `para` ("for") with the verb `parar` ("to stop"). If you just took that derivative file and used it for TF-IDF or topic modeling without realizing what was happening, you might reach the surprising conclusion that "stop" is a very frequent word in your text, when actually it's a lemmatization problem.

# %%
for token in document:
    print(token.text + ' - ' + token.lemma_)
# Out:
# ﻿INTRODUCCION - ﻿INTRODUCCION
# . - .
#
#
#
#  -
#
#
#
# ECONOMÍA - economía
# POLÍTICA - político
# . - .
#
#
#  -
#
#
# El - el
# sombrío - sombrío
# Prudhon - Prudhon
# , - ,
# imbuído - imbuído
# , - ,
# sin - sin
# duda - duda
# , - ,
# en - en
# las - el
# ideas - idea
# de - de
# los - el
# Santos - Santos
#
#  -
#
# Padres - Padres
# de - de
# la - el
# Iglesia - Iglesia
# que - que
# predicaban - predicar
# el - el
# desden - desden
# por - por
# los - el
# bienes - bien
#
#  -
#
# terrenales - terrenal
# , - ,
# decía - decir
# que - que
# la - el
# pobreza - pobreza
# es - ser
# una - uno
# ley - ley
# de - de
# nuestra - nuestro
# naturaleza - naturaleza
# , - ,
#
#  -
#
# ley - ley
# bajo - bajo
# la - el
# cual - cual
# hemos - haber
# sido - ser
# constituídos - constituer
# , - ,
# de - de
# donde - donde
# se - él
# deduce - deducir
# que - que
# el - el
#
#  -
#
# pauperismo - pauperismo
# es - ser
# mal - mal
# que - que
# no - no
# tiene - tener
# remedio - remedio
# ni - ni
# cura - cura
# . - .
#
#
#  -
#
#
# Muy - mucho
# desconsolados - desconsolado
# debieron - deber
# quedar - quedar
# los - el
# menesterosos - menesteroso
# con - con
# tan - tanto
# ingrata - ingrato
#
#  -
#
# noticia - noticia
# , - ,
# pero - pero
# la - el
# actividad - actividad
# humana - humano
# , - ,
# que - que
# no - no
# siempre - siempre
# se - él
# lleva - llevar
# de - de
# teorías - teoría
# , - ,
#
#  -
#
# ha - haber
# venido - venir
# á - á
# confortar - confortar
# á - á
# los - el
# aflijidos - aflijido
# trayéndoles - trayéndoles
# más - más
# plausibles - plausibl
# nuevas - nuevo
#
#  -
#
# y - y
# muy - mucho
# eficaces - eficaz
# promesas - promesa
# . - .
# La - el
# industria - industria
# , - ,
# con - con
# sus - su
# innúmeras - innúmera
# palancas - palanca
# de - de
#
#  -
#
# impulsion - impulsion
# ; - ;
# las - el
# ciencias - ciencia
# , - ,
# con - con
# sus - su
# multiplicados - multiplicado
# alfileres - alfiler
# de - de
# exámen - exámen
# ; - ;
# el - el
#
#  -
#
# cálculo - cálculo
# , - ,
# con - con
# su - su
# prevision - prevision
# y - y
# su - su
# aritmética - aritmética
# ; - ;
# todos - todo
# estos - este
# agentes - agente
# de - de
# la - el
#
#  -
#
# vitalidad - vitalidad
# social - social
# , - ,
# han - haber
# venido - venir
# á - á
# operar - operar
# el - el
# milagro - milagro
# de - de
# la - el
# multiplicacion - multiplicacion
#
#  -
#
# del - del
# pan - pan
# y - y
# el - el
# aumento - aumento
# del - del
# vino - vino
# , - ,
# sustentando - sustentar
# anchamente - anchamente
# á - á
# los - el
# hambrientos - hambriento
#
#  -
#
# y - y
# engordando - engordar
# , - ,
# hasta - hasta
# más - más
# no - no
# poder - poder
# , - ,
# á - á
# los - el
# hartos - harto
# . - .
#
#
#  -
#
#
# La - el
# manera - manera
# de - de
# realizar - realizar
# el - el
# prodigio - prodigio
# lo - él
# ha - haber
# dado - dar
# á - á
# conocer - conocer
# esa - ese
# venerable - venerable
#
#  -
#
# matrona - matrona
# , - ,
# que - que
# los - el
# entendidos - entendido
# en - en
# materias - materia
# graves - grave
# creo - creer
# que - que
# denominan - denominar
#
#  -
#
# _ - _
# Economía - Economía
# política - político
# _ - _
# . - .
# Esta - este
# tutriz - tutriz
# moralizadora - moralizadoro
# de - de
# la - el
# sociedad - sociedad
# , - ,
#
#  -
#
# evidenciando - evidenciar
# la - el
# fecundidad - fecundidad
# del - del
# trabajo - trabajo
# y - y
# los - el
# beneficios - beneficio
# del - del
# ahorro - ahorro
# , - ,
# se - él
#
#  -
#
# ha - haber
# propuesto - proponer
# dignificar - dignificar
# al - al
# hombre - hombre
# otorgándole - otorgar él
# los - el
# medios - medio
# de - de
# sacudir - sacudir
# el - el
#
#  -
#
# vasallaje - vasallaje
# servil - servil
# de - de
# la - el
# indigencia - indigencia
# . - .
#
#
#  -
#
#
# El - el
# ahorro - ahorro
# , - ,
# tomando - tomar
# forma - forma
# colectiva - colectivo
# , - ,
# ha - haber
# dado - dar
# orígen - orígen
# á - á
# la - el
# más - más
# preciosa - precioso
# de - de
#
#  -
#
# las - el
# combinaciones - combinación
# especulativas - especulativo
# : - :
# á - á
# la - el
# que - que
# tiene - tener
# por - por
# objeto - objeto
# asegurar - asegurar
# el - el
#
#  -
#
# bienestar - bienestar
# individual - individual
# en - en
# vida - vida
# y - y
# garantir - garantir
# el - el
# porvenir - porvenir
# de - de
# los - el
# que - que
# quedan - quedar
# , - ,
#
#  -
#
# despues - despues
# de - de
# concluida - concluido
# la - el
# jornada - jornada
# . - .
#
#
#  -
#
#
# Este - este
# tema - tema
# , - ,
# abstracto - abstracto
# de - de
# suyo - suyo
# , - ,
# y - y
# que - que
# parece - parecer
# ageno - ageno
# al - al
# dominio - dominio
# del - del
# arte - arte
# , - ,
#
#  -
#
# acaba - acabar
# de - de
# ser - ser
# desenvuelto - desenvolver
# por - por
# la - el
# ilustre - ilustre
# escritora - escritora
# cuyo - cuyo
# nombre - nombre
# ocupa - ocupar
# tan - tanto
#
#  -
#
# elevado - elevado
# rango - rango
# en - en
# la - el
# gerarquía - gerarquía
# del - del
# movimiento - movimiento
# intelectual - intelectual
# americano - americano
# . - .
#
#
#  -
#
#
# Es - ser
# atributo - atributo
# de - de
# las - el
# inteligencias - inteligencia
# creadoras - creador
# trasformar - trasformar
# y - y
# embellecer - embellecer
#
#  -
#
# las - el
# ideas - idea
# que - que
# pasan - pasar
# por - por
# su - su
# espíritu - espíritu
# ; - ;
# parece - parecer
# que - que
# poseyeran - poseer
# ese - ese
# don - don
#
#  -
#
# vivificador - vivificador
# de - de
# la - el
# lujuriosa - lujuriós
# primavera - primavera
# que - que
# todo - todo
# lo - él
# hermosea - hermosear
# , - ,
# lo - él
# cubre - cubrir
# de - de
#
#  -
#
# flores - flor
# y - y
# lo - él
# esmalta - esmalta
# de - de
# celajes - celaj
# . - .
#
#
#  -
#
#
# Por - Por
# si - si
# existe - existir
# incrédulo - incrédulo
# que - que
# ponga - poner
# en - en
# duda - duda
# el - el
# aserto - aserto
# , - ,
# invoco - invoco
# por - por
#
#  -
#
# testigo - testigo
# , - ,
# en - en
# mi - mi
# abono - abono
# , - ,
# el - el
# presente - presente
# libro - libro
# . - .
#
#
#  -
#
#
# Su - su
# autora - autora
# comprueba - comprobar
# , - ,
# bajo - bajo
# la - el
# forma - forma
# atrayente - atrayente
# de - de
# la - el
# novela - novela
# , - ,
# los - el
#
#  -
#
# beneficios - beneficio
# que - que
# reportan - reportar
# el - el
# trabajo - trabajo
# , - ,
# la - el
# perseverancia - perseverancia
# y - y
# el - el
# ahorro - ahorro
# ; - ;
# nunca - nunca
#
#  -
#
# un - uno
# tema - tema
# económico - económico
# ha - haber
# sido - ser
# tratado - tratar
# con - con
# más - más
# galanura - galanura
# , - ,
# con - con
# más - más
# gracia - gracia
#
#  -
#
# picarezca - picarezca
# , - ,
# ni - ni
# con - con
# más - más
# natural - natural
# é - é
# ingénua - ingénuo
# intriga - intrigo
# . - .
#
#
#  -
#
#
# Despues - Despues
# de - de
# recorrer - recorrer
# este - este
# trozo - trozo
# de - de
# historia - historia
# social - social
# , - ,
# cuya - cuyo
# trama - trama
# la - él
# forman - formar
#
#  -
#
# las - el
# peripecias - peripecia
# de - de
# dos - dos
# caractéres - caractér
# nobles - noble
# y - y
# fuertes - fuerte
# , - ,
# se - él
# encuentra - encontrar
# no - no
# sé - saber
#
#  -
#
# qué - qué
# de - de
# consolatorio - consolatorio
# , - ,
# de - de
# purificador - purificador
# , - ,
# en - en
# medio - medio
# de - de
# la - el
# arenosa - arenoso
# senda - senda
# por - por
#
#  -
#
# donde - donde
# nos - yo
# conduce - conducir
# diariamente - diariamente
# la - el
# mano - mano
# de - de
# la - el
# tristeza - tristeza
# . - .
#
#
#  -
#
#
# Si - Si
# la - el
# mision - mision
# de - de
# los - el
# cultores - cultor
# privilegiados - privilegiado
# del - del
# arte - arte
# es - ser
# la - el
# de - de
# alentar - alentar
# , - ,
#
#  -
#
# la - el
# de - de
# consolar - consolar
# , - ,
# la - el
# de - de
# dilatar - dilatar
# el - el
# horizonte - horizonte
# de - de
# la - el
# esperanza - esperanza
# , - ,
# la - el
#
#  -
#
# prestigiosa - prestigioso
# autora - autora
# de - de
# estas - este
# páginas - página
# ha - haber
# sabido - saber
# encerrar - encerrar
# en - en
# ellas - él
# , - ,
#
#  -
#
# suficientes - suficiente
# rayos - rayo
# de - de
# luz - luz
# para - para
# satisfacer - satisfacer
# la - el
# ansiedad - ansiedad
# de - de
# las - el
# almas - alma
#
#  -
#
# soñadoras - soñadora
# , - ,
# y - y
# bastantes - bastante
# rosas - rosa
# para - para
# coronar - coronar
# , - ,
# aunque - aunque
# ellos - él
# no - no
# lo - él
# quieran - querer
# , - ,
#
#  -
#
# la - el
# adusta - adusta
# efigie - efigie
# de - de
# los - el
# más - más
# hipocondriacos - hipocondriaco
# economistas - economista
# . - .
#
#
#                                                 -
#
#
# S. - s.
# VACA-GUZMAN - vaca-guzman
# . - .
#
#
#      -
#
#
# Diciembre - Diciembre
# 22 - 22
# de - de
# 1887 - 1887
# . - .
#
#
#
#
#
#                        -
#
#
#
#
#
# OASIS - OASIS
# EN - EN
# LA - el
# VIDA - VIDA
# . - .
#
#
#                       -
#
#
# Á - Á
# « - «
# LA - el
# BUENOS - BUENOS
# AIRES - AIRES
# » - »
#
#
#                                        -
#
#
# _ - _
# LA - el
# AUTORA - autora
# . - .
# _ - _
#
#
#
#
#
#  -
#
#
#
#
#
# OASIS - OASIS
# EN - EN
# LA - el
# VIDA - VIDA
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# I - I
#
#
#
#  -
#
#
#
# --¡Bah!--exclamó - --¡Bah!--exclamó
# Mauricio - Mauricio
# Ridel - Ridel
# , - ,
# arrojando - arrojar
# la - el
# pluma - pluma
# despues - despues
# de - de
# escribir - escribir
#
#  -
#
# la - el
# palabra - palabra
# Fin - Fin
# bajo - bajo
# la - el
# última - último
# línea - línea
# de - de
# una - uno
# cuartilla - cuartilla
# marcada - marcado
# con - con
# el - el
#
#  -
#
# guarismo - guarismo
# 60 - 60
# . - .
#
#
#  -
#
#
# --¿Qué - --¿qué
# es - ser
# eso?--interrogó - eso?--interrogar
# un - uno
# jóven - jóven
# que - que
# escribía - escribir
# allí - allí
# cerca - cerca
# . - .
#
#
#  -
#
#
# --El - --El
# postrer - postrer
# párrafo - párrafo
# del - del
# folletin--respondió - folletin--respondeír
# Mauricio - Mauricio
# , - ,
# alargando - alargar
# la - el
#
#  -
#
# hoja - hoja
# á - á
# un - uno
# cajista - cajista
# que - que
# aguardaba - aguardar
# . - .
#
#
#  -
#
#
# --¡Cómo - --¡cómo
# ! - !
# ¿ - ¿
# Mañana - mañana
# acaba - acabar
# CHAMUSQUINAS - chamusquinas
# DE - DE
# AMOR - AMOR
# ? - ?
# Hoy - hoy
# quedaba - quedar
# su - su
# héroe - héroe
#
#  -
#
# en - en
# una - uno
# situacion - situacion
# extrema - extremo
# : - :
# la - el
# mano - mano
# armada - armado
# de - de
# un - uno
# revólver - revólver
# , - ,
# esperando - esperar
#
#  -
#
# para - para
# morir - morir
# el - el
# primer - primero
# rayo - rayo
# de - de
# sol - sol
# ; - ;
# y - y
# ya - ya
# , - ,
# este - este
# comenzaba - comenzar
# á - á
# dorar - dorar
# las - el
#
#  -
#
# copas - copa
# de - de
# los - el
# árboles - árbol
# ; - ;
# y - y
# al - al
# verlo - ver él
# , - ,
# « - «
# Enrique - Enrique
# apoya - apoyar
# el - el
# arma - arma
# contra - contra
# el - el
#
#  -
#
# corazon - corazon
# , - ,
# enviando - enviar
# á - á
# María - María
# su - su
# último - último
# pensamiento - pensamiento
# ; - ;
# á - á
# Dios - Dios
# su - su
# última - último
#
#  -
#
# plegaria - plegaria
# . - .
# »--¿Muere - »--¿muere
# ? - ?
#
#
#  -
#
#
# --No - --no
# ; - ;
# porque--«De - porque--«de
# repente - repente
# , - ,
# un - uno
# brazo - brazo
# cariñoso - cariñoso
# rodeó - rodear
# su - su
# cuello - cuello
# ; - ;
# un - uno
# rostro - rostro
#
#  -
#
# pálido - pálido
# y - y
# mojado - mojado
# de - de
# lágrimas - lágrima
# se - él
# apoyó - apoyar
# en - en
# su - su
# rostro - rostro
# ... - ...
#
#
#  -
#
#
# --¡Perdon - --¡Perdon
# ! - !
#
#
#  -
#
#
# --¡Perdon!--se - --¡perdon!--se
# oyó - oir
# á - á
# la - el
# vez - vez
# ... - ...
#
#
#  -
#
#
# « - «
# Y - Y
# el - el
# primer - primero
# rayo - rayo
# de - de
# sol - sol
# aguardado - aguardado
# como - como
# una - uno
# señal - señal
# de - de
# muerte - muerte
# , - ,
# fué - fué
# la - el
#
#  -
#
# aurora - auroro
# de - de
# su - su
# felicidad - felicidad
# » - »
# . - .
#
#
#  -
#
#
# --¡Bien - --¡bien
# ! - !
# ¡ - ¡
# oh - oh
# ! - !
# ¡ - ¡
# Qué - qué
# bien!--aplaudió - bien!--aplaudeír
# el - el
# otro - otro
# ; - ;
# y - y
# añadió - añadir
# con - con
# dramático - dramático
#
#  -
#
# ademan - ademan
# : - :
#
#
#  -
#
#
# --¡Ah - --¡ah
# ! - !
# que - que
# no - no
# haya - haber
# para - para
# nosotros - yo
# , - ,
# párias - pária
# del - del
# destino - destino
# , - ,
# ¡ - ¡
# un - uno
# rayo - rayo
# de - de
# sol - sol
#
#  -
#
# que - que
# venga - venir
# á - á
# redimirnos - redimir yo
# ! - !
#
#
#  -
#
#
# --Sí - --sí
# : - :
# y - y
# más - más
# que - que
# uno - uno
# : - :
# dos--repuso - dos--repuso
# Mauricio.--La - Mauricio.--La
# resignacion - resignacion
# y - y
# el - el
# trabajo - trabajo
# . - .
#
#
#  -
#
#
# --¡La - --¡la
# resignacion - resignacion
# ! - !
# ¡ - ¡
# el - el
# trabajo!--replicó - trabajo!--replicar
# el - el
# interlocutor - interlocutor
# con - con
# forzada - forzado
#
#  -
#
# risa.--Solo - risa.--solo
# tú - tú
# puedes - poder
# decir - decir
# eso - ese
# ; - ;
# tú - tú
# , - ,
# que - que
# no - no
# contento - contento
# con - con
# la - el
# tarea - tarea
#
#  -
#
# diaria - diario
# , - ,
# la - él
# has - haber
# subido - subir
# á - á
# catorce - catorce
# horas - hora
# . - .
# Catorce - catorce
# horas - hora
# , - ,
# pluma - pluma
# en - en
# mano - mano
# , - ,
#
#  -
#
# encorvado - encorvado
# sobre - sobre
# la - el
# implacable - implacable
# cuartilla - cuartilla
# , - ,
# y - y
# precisamente - precisamente
# , - ,
# apenas - apenas
# en - en
#
#  -
#
# convalecencia - convalecencia
# de - de
# la - el
# terrible - terrible
# herida - herida
# que - que
# casi - casi
# te - tú
# lleva - llevar
# al - al
# sepulcro - sepulcro
# . - .
#
#
#  -
#
#
# --Sin - --sin
# embargo - embargo
# , - ,
# ya - ya
# lo - él
# vés - vés
# : - :
# estoy - estar
# sano - sano
# y - y
# fuerte - fuerte
# . - .
# Un - uno
# poco - poco
# de - de
# sueño - sueño
# ; - ;
# á - á
#
#  -
#
# veces - vez
# , - ,
# un - uno
# poco - poco
# de - de
# fatiga - fatiga
# ; - ;
# pero - pero
# se - él
# piensa - pensar
# en - en
# el - el
# fin - fin
# propuesto - propuesto
# , - ,
# y - y
# todo - todo
#
#  -
#
# eso - ese
# vuela - volar
# y - y
# se - él
# desvanece.-- - desvanece.--
#
#
#  -
#
#
# Hablando - hablar
# así - así
# , - ,
# Mauricio - Mauricio
# consultó - consultar
# su - su
# reloj - reloj
# . - .
#
#
#  -
#
#
# --Las - --las
# siete--Y - siete--y
# levantándose - levantar él
# , - ,
# fué - fué
# á - á
# tomar - tomar
# de - de
# una - uno
# percha - percha
# su - su
# sombrero - sombrero
# . - .
#
#
#  -
#
#
# --¡Las - --¡Las
# siete - siete
# ! - !
# ¡ - ¡
# Con - Con
# qué - qué
# desenfado - desenfado
# lo - él
# dices - decir
# ! - !
# ¿ - ¿
# Sabes - saber
# que - que
# has - haber
# estado - estar
#
#  -
#
# sentado - sentar
# ahí - ahí
# , - ,
# escribiendo - escribir
# desde - desde
# las - el
# nueve - nueve
# ? - ?
# ¡ - ¡
# Diez - diez
# horas - hora
# ! - !
# ¡ - ¡
# Ah - Ah
# ! - !
# hombres - hombre
#
#  -
#
# como - como
# este - este
# son - ser
# un - uno
# pésimo - pésimo
# ejemplo - ejemplo
# en - en
# la - el
# Redaccion - Redaccion
# . - .
#
#
#  -
#
#
# --Y - --Y
# tú - tú
# , - ,
# que - que
# así - así
# hablas - hablar
# , - ,
# querido - querido
# Emilio - Emilio
# , - ,
# eres - ser
# uno - uno
# de - de
# sus - su
# mejores - mejor
# obreros - obrero
# . - .
#
#
#  -
#
#
# --A - --a
# más - más
# no - no
# poder - poder
# : - :
# Sábelo - Sábelo
# . - .
#
#
#  -
#
#
# --Notificado--dijo - --notificado--decir
# Mauricio - Mauricio
# , - ,
# sonriendo.--Ruégote - sonriendo.--ruégote
# que - que
# al - al
# salir - salir
# digas - diga
# al - al
#
#  -
#
# Regente - Regente
# que - que
# me - yo
# tenga - tener
# listas - lista
# las - el
# pruebas - prueba
# para - para
# las - el
# once - once
# . - .
#
#
#  -
#
#
# --Y - --Y
# correccion - correccion
# hasta - hasta
# las - el
# dos - dos
# de - de
# la - el
# mañana - mañana
# . - .
# Suma - sumar
# : - :
# ¡ - ¡
# catorce - catorce
# horas - hora
# ! - !
# ... - ...
#
#  -
#
# ¡ - ¡
# Adios - Adios
# , - ,
# escriba - escriba
# ! - !
#
#
#  -
#
#
# --Adios - --adio
# , - ,
# fariseo.-- - fariseo.--
#
#
#  -
#
#
# Y - Y
# ambos - ambos
# rieron - reír
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# cerró - cerrar
# su - su
# carpeta - carpeta
# y - y
# se - él
# fué - fué
# . - .
#
#
#  -
#
#
# Emilio - Emilio
# se - él
# extendió - extender
# perezosamente - perezosamente
# en - en
# su - su
# silla - silla
# ; - ;
# encendió - encender
# un - uno
# cigarro - cigarro
# , - ,
# que - que
#
#  -
#
# aspiró - aspirar
# con - con
# ánsia - ánsia
# ; - ;
# y - y
# arrojando - arrojar
# una - uno
# larga - largo
# espiral - espiral
# de - de
# humo - humo
# , - ,
# entornando - entornar
#
#  -
#
# los - el
# ojos--¡Deliciosa - ojos--¡deliciosa
# fruicion!--exclamó:--¿qué - fruicion!--exclamó:--¿qué
# no - no
# haces - hacer
# tú - tú
# olvidar - olvidar
# ? - ?
# ... - ...
#
#  -
#
# Y - Y
# sin - sin
# embargo - embargo
# , - ,
# Mauricio - Mauricio
# te - tú
# desdeña - desdeñar
# . - .
# Uncido - uncido
# á - á
# un - uno
# rudo - rudo
# trabajo - trabajo
# , - ,
# pegado - pegado
#
#  -
#
# ahí - ahí
# , - ,
# á - á
# esa - ese
# mesa - mesa
# de - de
# redaccion - redaccion
# , - ,
# hasta - hasta
# los - el
# codos - codo
# en - en
# la - el
# seccion - seccion
# editorial - editorial
# ; - ;
#
#  -
#
# cronista - cronista
# , - ,
# traductor - traductor
# , - ,
# folletinista - folletinista
# , - ,
# corrector - corrector
# de - de
# pruebas - prueba
# : - :
# ¿ - ¿
# á - á
# qué - qué
#
#  -
#
# móvil - móvil
# obedecerá - obedecer
# ese - ese
# anhelo - anhelo
# de - de
# aglomerar - aglomerar
# sueldos - sueldo
# ? - ?
# Él - él
# , - ,
# no - no
# es - ser
# avaro - avaro
# ni - ni
#
#  -
#
# derrochador - derrochador
# ; - ;
# no - no
# frecuenta - frecuentar
# clubs - club
# ni - ni
# bailes - baile
# ; - ;
# por - por
# tanto - tanto
# , - ,
# ni - ni
# juega - jugar
# ni - ni
#
#  -
#
# galantea - galantea
# . - .
# En - en
# los - el
# teatros - teatro
# tiene - tener
# las - el
# entradas - entrada
# de - de
# periodista - periodista
# . - .
# ¿ - ¿
# A - A
# qué - qué
# tanto - tanto
#
#  -
#
# afan - afan
# de - de
# ganar - ganar
# dinero - dinero
# ? - ?
# ¿ - ¿
# qué - qué
# hace - hacer
# de - de
# él - él
# ? - ?
# No - no
# es - ser
# mucho - mucho
# , - ,
# en - en
# verdad - verdad
# ; - ;
# pero - pero
#
#  -
#
# ¿ - ¿
# qué - qué
# hace - hacer
# de - de
# él - él
# ? - ?
# Enigma - enigmo
# insoluble - insoluble
# es - ser
# para - para
# mí - yo
# este - este
# jóven - jóven
# , - ,
# tan - tanto
# franco - franco
# , - ,
#
#  -
#
# sin - sin
# embargo - embargo
# , - ,
# y - y
# tan - tanto
# bueno - bueno
# ... - ...
#
#
#  -
#
#
# Y - Y
# Emilio - Emilio
# dejando - dejar
# la - el
# pluma - pluma
# en - en
# largo - largo
# holgorio - holgorio
# , - ,
# quedóse - quedóse
# engolfado - engolfado
# en - en
# sus - su
#
#  -
#
# pensamientos - pensamiento
# y - y
# en - en
# el - el
# humo - humo
# de - de
# su - su
# cigarro - cigarro
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# II - II
#
#
#
#  -
#
#
#
# Mauricio - Mauricio
# se - él
# alejó - alejar
# con - con
# el - el
# paso - paso
# presuroso - presuroso
# , - ,
# habitual - habitual
# en - en
# aquellos - aquel
# que - que
#
#  -
#
# tienen - tener
# contado - contado
# el - el
# tiempo - tiempo
# . - .
#
#
#  -
#
#
# Aunque - Aunque
# en - en
# la - el
# plácida - plácido
# edad - edad
# de - de
# veinte - veinte
# años - año
# , - ,
# y - y
# bello - bello
# y - y
# apuesto - apuesto
# , - ,
# hay - haber
# en - en
# la - el
#
#  -
#
# expresion - expresion
# de - de
# su - su
# semblante - semblante
# esa - ese
# gravedad - gravedad
# melancólica - melancólico
# , - ,
# signo - signo
# de - de
# un - uno
# destino - destino
#
#  -
#
# adverso - adverso
# . - .
#
#
#  -
#
#
# En - En
# verdad - verdad
# , - ,
# adverso - adverso
# había - haber
# sido - ser
# el - el
# destino - destino
# para - para
# Mauricio - Mauricio
# : - :
# adverso - adverso
# desde - desde
#
#  -
#
# la - el
# cuna - cuna
# , - ,
# mecida - mecido
# por - por
# manos - mano
# extrañas - extraño
# , - ,
# desierta - desierto
# de - de
# cuidados - cuidado
# y - y
# caricias - caricia
# . - .
#
#
#  -
#
#
# Y - Y
# no - no
# fué - fué
# esto - este
# solo - solo
# ¡ - ¡
# ay - ay
# ! - !
# no - no
# fué - fué
# esto - este
# solo - solo
# . - .
#
#
#  -
#
#
# Cárlos - cárlos
# Ridel - Ridel
# , - ,
# subyugado - subyugado
# por - por
# una - uno
# pasion - pasion
# que - que
# causó - causar
# la - el
# muerte - muerte
# á - á
# su - su
# esposa - esposa
# , - ,
#
#  -
#
# llevando - llevar
# todavía - todavía
# el - el
# luto - luto
# de - de
# la - el
# viudez - viudez
# , - ,
# dió - deír
# una - uno
# sucesora - sucesora
# á - á
# la - el
# difunta - difunta
# ; - ;
# á - á
#
#  -
#
# su - su
# hijo - hijo
# una - uno
# madrastra - madrastra
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Madrastra - Madrastra
# ! - !
# Al - Al
# solo - solo
# pronunciar - pronunciar
# esta - este
# palabra - palabra
# de - de
# aspereza - aspereza
# siniestra - siniestro
# , - ,
#
#  -
#
# compréndese - compréndese
# la - el
# tristura - tristura
# de - de
# esos - ese
# pobres - pobre
# niños - niño
# que - que
# crecen - crecer
# temerosos - temeroso
# , - ,
#
#  -
#
# acoquinados - acoquinado
# , - ,
# bajo - bajo
# aquella - aquel
# sombra - sombra
# fatídica - fatídico
# . - .
#
#
#  -
#
#
# Para - Para
# ellos - él
# no - no
# existen - existir
# las - el
# alegrías - alegría
# del - del
# hogar - hogar
# . - .
# Siempre - siempre
# espiados - espiado
# por - por
# la - el
#
#  -
#
# mirada - mirada
# suspicaz - suspicaz
# de - de
# un - uno
# fiscal - fiscal
# inexorable - inexorable
# que - que
# les - él
# achaca - achacar
# á - á
# delito - delito
# su - su
#
#  -
#
# gozosa - gozós
# turbulencia - turbulencia
# , - ,
# su - su
# inocente - inocente
# espontaneidad - espontaneidad
# , - ,
# vuélvense - vuelven él
# taciturnos - taciturno
# , - ,
#
#  -
#
# desconfiados - desconfiado
# ; - ;
# ocúltanse - ocúltanse
# para - para
# reir - reir
# ; - ;
# ocúltanse - ocúltanse
# para - para
# llorar - llorar
# ; - ;
# y - y
# en - en
# el - el
#
#  -
#
# primer - primero
# albor - albor
# de - de
# la - el
# vida - vida
# , - ,
# aprenden - aprender
# esa - ese
# triste - triste
# ciencia - ciencia
# de - de
# la - el
# vejez - vejez
# : - :
# el - el
#
#  -
#
# disimulo - disimulo
# . - .
# ¿ - ¿
# Ni - Ni
# qué - qué
# otro - otro
# recurso - recurso
# les - él
# queda - quedar
# ? - ?
# ¿ - ¿
# A - A
# quién - quién
# volver - volver
# sus - su
# ojos - ojo
# ? - ?
#
#
#  -
#
#
# La - el
# casa - casa
# paterna - paterna
# se - él
# ha - haber
# tornado - tornar
# para - para
# ellos - él
# en - en
# campo - campo
# enemigo - enemigo
# , - ,
# donde - donde
# todo - todo
#
#  -
#
# les - él
# es - ser
# hostil - hostil
# , - ,
# hasta - hasta
# su - su
# mismo - mismo
# padre - padre
# á - á
# quien - quien
# no - no
# le - él
# es - ser
# dado - dar
# mostrárseles - mostrársel
#
#  -
#
# propicio - propicio
# , - ,
# so - so
# pena - pena
# de - de
# despertar - despertar
# celos - celo
# retrospectivos - retrospectivo
# , - ,
# que - que
# empeoren - empeorar
# la - el
#
#  -
#
# situacion - situacion
# tristísima - tristísima
# de - de
# esos - ese
# náufragos - náufrago
# de - de
# la - el
# vida - vida
# . - .
#
#
#  -
#
#
# Tal - tal
# suerte - suerte
# cupo - cupo
# á - á
# Mauricio - Mauricio
# . - .
#
#
#  -
#
#
# Víctima - Víctima
# de - de
# una - uno
# semejanza - semejanza
# que - que
# importunaba - importunar
# á - á
# su - su
# padre - padre
# como - como
# un - uno
#
#  -
#
# remordimiento - remordimiento
# , - ,
# á - á
# su - su
# madrastra - madrastra
# como - como
# una - uno
# vision - vision
# de - de
# ultratumba - ultratumba
# , - ,
# vióse - vióse
# un - uno
#
#  -
#
# dia - dia
# arrebatado - arrebatado
# de - de
# su - su
# casa - casa
# y - y
# entregado - entregar
# al - al
# capitan - capitan
# de - de
# un - uno
# buque - buque
# inglés - inglés
# , - ,
#
#  -
#
# que - que
# lo - él
# llevó - llevar
# á - á
# Europa - Europa
# y - y
# lo - él
# encerró - encerrar
# en - en
# un - uno
# colegio - colegio
# . - .
#
#
#  -
#
#
# Aunque - Aunque
# del - del
# hogar - hogar
# de - de
# sus - su
# padres - padre
# , - ,
# el - el
# pobre - pobre
# niño - niño
# , - ,
# solo - solo
# guardara - guardar
# crueles - cruel
#
#  -
#
# recuerdos - recuerdo
# , - ,
# la - el
# lengua - lengua
# materna - materno
# , - ,
# el - el
# suelo - suelo
# de - de
# la - el
# patria - patria
# , - ,
# su - su
# aire - aire
# , - ,
# su - su
# luz - luz
# , - ,
#
#  -
#
# éranle - éranle
# necesarios - necesario
# , - ,
# y - y
# languideció - languideceír
# , - ,
# echándolos - echar él
# de - de
# menos - menos
# . - .
#
#
#  -
#
#
# Por - Por
# dicha - dicha
# suya - suyo
# fué - fué
# el - el
# « - «
# bello - bello
# país - país
# de - de
# Francia - Francia
# , - ,
# » - »
# la - el
# hospitalaria - hospitalaria
# Paris - Paris
# , - ,
#
#  -
#
# el - el
# lugar - lugar
# de - de
# su - su
# destierro - destierro
# . - .
#
#
#  -
#
#
# La - el
# bondad - bondad
# característica - característico
# de - de
# los - el
# hijos - hijo
# de - de
# aquella - aquel
# tierra - tierra
# , - ,
# tiene - tener
# , - ,
# en - en
#
#  -
#
# todas - todo
# las - el
# clases - clase
# sociales - social
# , - ,
# desde - desde
# el - el
# aristócrata - aristócrata
# hasta - hasta
# el - el
# obrero - obrero
# , - ,
# una - uno
#
#  -
#
# gracia - gracia
# irresistible - irresistible
# que - que
# cautiva - cautivar
# el - el
# alma - alma
# y - y
# mata - matar
# toda - todo
# nostalgia - nostalgia
# . - .
#
#
#  -
#
#
# Desde - Desde
# el - el
# sábio - sábio
# Blain - Blain
# , - ,
# director - director
# del - del
# colegio - colegio
# donde - donde
# fué - fuar
# el - el
# niño - niño
#
#  -
#
# consignado - consignado
# , - ,
# hasta - hasta
# el - el
# ama - ama
# de - de
# llaves - llave
# , - ,
# la - el
# buena - buen
# Colombe - Colombe
# ; - ;
# desde - desde
# los - el
# alumnos - alumno
#
#  -
#
# hasta - hasta
# los - el
# profesores - profesor
# : - :
# todos - todo
# acogiéronlo - acogiéronlo
# con - con
# tan - tanto
# benévola - benévolo
# conmiseracion - conmiseracion
# , - ,
#
#  -
#
# que - que
# primero - primero
# la - el
# serenidad - serenidad
# y - y
# luego - luego
# la - el
# alegría - alegría
# , - ,
# vinieron - venir
# como - como
# nunca - nunca
# , - ,
#
#  -
#
# expansivas - expansivo
# á - á
# aquel - aquel
# pobre - pobre
# corazon - corazon
# , - ,
# por - por
# tanto - tanto
# tiempo - tiempo
# oprimido - oprimido
# . - .
#
#
#  -
#
#
# El - el
# desterrado - desterrado
# comenzó - comenzar
# á - á
# encontrarse - encontrar él
# feliz - feliz
# en - en
# su - su
# nueva - nuevo
# familia - familia
# . - .
#
#
#  -
#
#
# --¡Ah!--pensaba - --¡ah!--pensar
# , - ,
# recordando - recordar
# el - el
# pasado--¿así - pasado--¿así
# se - él
# ama - amar
# , - ,
# se - él
# acaricia - acariciar
# y - y
# se - él
#
#  -
#
# protege - proteger
# ? - ?
# ¿ - ¿
# Por - Por
# qué - qué
# no - no
# he - haber
# conocido - conocer
# yo - yo
# hasta - hasta
# hoy - hoy
# , - ,
# estos - este
# bienes - bien
# ? - ?
#
#
#  -
#
#
# Y - Y
# refugiábase - refugiábar
# en - en
# esa - ese
# atmósfera - atmósfera
# de - de
# calurosos - caluroso
# afectos - afecto
# ; - ;
# y - y
# sentía - sentir
# el - el
# dulce - dulce
#
#  -
#
# bienestar - bienestar
# del - del
# que - que
# renace - renacer
# á - á
# la - el
# salud - salud
# despues - despues
# de - de
# una - uno
# larga - largo
# enfermedad - enfermedad
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# III - III
#
#
#
#  -
#
#
#
# Los - el
# años - año
# trascurrieron - trascurreír
# así - así
# , - ,
# con - con
# sus - su
# épocas - época
# clásicas - clásico
# , - ,
# en - en
# la - el
# vida - vida
# del - del
#
#  -
#
# niño - niño
# . - .
# Los - el
# exámenes - examen
# ; - ;
# los - el
# premios - premio
# ; - ;
# el - el
# paso - paso
# á - á
# estudios - estudio
# superiores - superior
# ; - ;
# el - el
# del - del
#
#  -
#
# vestido - vestido
# infantil - infantil
# al - al
# traje - traje
# viril - viril
# ; - ;
# la - el
# primera - primero
# comunion - comunion
# ..... - .....
#
#
#  -
#
#
# ¡ - ¡
# Qué - qué
# ceremonia - ceremonia
# , - ,
# á - á
# la - el
# vez - vez
# tan - tanto
# imponente - imponente
# y - y
# tierna - tierno
# ! - !
#
#
#  -
#
#
# Cumplido - cumplido
# en - en
# él - él
# , - ,
# el - el
# divino - divino
# misterio - misterio
# , - ,
# de - de
# rodillas - rodilla
# ante - ante
# el - el
# altar - altar
# , - ,
# el - el
# niño - niño
#
#  -
#
# tiende - tender
# la - el
# mano - mano
# sobre - sobre
# el - el
# Sagrado - Sagrado
# Libro - Libro
# y - y
# jura - jura
# ser - ser
# virtuoso - virtuoso
# y - y
# bueno - bueno
# . - .
#
#
#  -
#
#
# El - el
# celebrante - celebrante
# lo - él
# bendice - bendizar
# y - y
# coloca - colocar
# en - en
# su - su
# pecho - pecho
# una - uno
# reliquia - reliquia
# . - .
#
#
#  -
#
#
# La - el
# voz - voz
# del - del
# órgano - órgano
# derrama - derrama
# gozosas - gozosa
# notas - nota
# ; - ;
# nubes - nube
# de - de
# incienso - incienso
# se - él
# elevan - elevar
# á - á
#
#  -
#
# lo - él
# alto - alto
# de - de
# la - el
# bóveda - bóveda
# ; - ;
# y - y
# en - en
# la - el
# nave - nave
# central - central
# , - ,
# las - el
# madres - madre
# aguardan - aguardar
# con - con
# el - el
#
#  -
#
# llanto - llanto
# en - en
# los - el
# ojos - ojo
# , - ,
# en - en
# el - el
# lábio - lábio
# la - el
# sonrisa - sonrisa
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# vió - ver
# á - á
# sus - su
# compañeros - compañero
# ir - ir
# hácia - hácia
# ellas - él
# y - y
# caer - caer
# en - en
# sus - su
# brazos - brazo
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Ay - Ay
# ! - !
# ¡ - ¡
# él - él
# estaba - estar
# solo - solo
# ! - !
#
#
#  -
#
#
# Ni - Ni
# padre - padre
# ni - ni
# madre - madre
# que - que
# lo - él
# aguardaran - aguardar
# ; - ;
# solo - solo
# en - en
# esa - ese
# hora - hora
# solemne - solemne
# de - de
# la - el
#
#  -
#
# vida - vida
# . - .
#
#
#  -
#
#
# ¿ - ¿
# Solo - solo
# ? - ?
#
#
#  -
#
#
# No - no
# : - :
# ahí - ahí
# estaba - estar
# Mr - mr
# . - .
# Blain - Blain
# que - que
# le - él
# sonreia - sonreiar
# ; - ;
# ahí - ahí
# estaba - estar
# la - el
# buena - buen
# Colombe - Colombe
#
#  -
#
# que - que
# le - él
# tiende - tender
# los - el
# brazos - brazo
# y - y
# lo - él
# contempla - contemplar
# enternecida - enternecido
# . - .
#
#
#  -
#
#
# --Ama--díjole - --Ama--díjole
# Mauricio--¿Quieres - mauricio--¿quieres
# que - que
# te - tú
# dé - dar
# mi - mi
# reliquia - reliquia
# ? - ?
# Mírala - Mírala
# : - :
# es - ser
# muy - mucho
#
#  -
#
# linda - lindo
# : - :
# _ - _
# Notre - Notre
# Dame - Dame
# du - du
# bon - bon
# Secour - Secour
# _ - _
# . - .
#
#
#  -
#
#
# --No - --no
# , - ,
# hijo - hijo
# mio--respondió - mio--respondeír
# la - el
# vieja - viejo
# sirvienta - sirvienta
# , - ,
# volviendo - volver
# la - el
# reliquia - reliquia
# al - al
#
#  -
#
# pecho - pecho
# del - del
# niño.--Este - niño.--este
# recuerdo - recuerdo
# le - él
# es - ser
# debido - debido
# á - á
# mamá - mamá
# . - .
# Envíaselo - Envíaselo
# dentro - dentro
# de - de
#
#  -
#
# tu - tu
# primera - primero
# carta.-- - carta.--
#
#
#  -
#
#
# La - el
# hora - hora
# , - ,
# el - el
# lugar - lugar
# , - ,
# la - el
# escena - escena
# imponente - imponente
# en - en
# que - que
# acababa - acabar
# de - de
# actuar - actuar
# ; - ;
# la - el
#
#  -
#
# voz - voz
# del - del
# órgano - órgano
# ; - ;
# el - el
# humo - humo
# del - del
# incienso - incienso
# ; - ;
# las - el
# sagradas - sagrada
# preces - prez
# ; - ;
# todo - todo
# esto - este
#
#  -
#
# despertó - despertar
# en - en
# el - el
# alma - alma
# del - del
# niño - niño
# una - uno
# emocion - emocion
# profunda - profundo
# , - ,
# al - al
# oir - oir
# las - el
# palabras - palabra
#
#  -
#
# de - de
# la - el
# vieja - viejo
# Colombe - Colombe
# . - .
# La - el
# luz - luz
# de - de
# un - uno
# lejano - lejano
# recuerdo - recuerdo
# brilló - brillar
# en - en
# su - su
# mente - mente
# , - ,
#
#  -
#
# mostrándole - mostrar él
# allá - allá
# , - ,
# como - como
# entre - entre
# las - el
# nieblas - niebla
# de - de
# un - uno
# ensueño - ensueño
# , - ,
# la - el
# figura - figura
#
#  -
#
# angelical - angelical
# de - de
# una - uno
# mujer - mujer
# que - que
# lo - él
# miraba - mirar
# sonriendo - sonreir
# . - .
#
#
#  -
#
#
# Sonrióle - Sonrióle
# él - él
# tambien - tambien
# , - ,
# y - y
# dos - dos
# lágrimas - lágrima
# se - él
# desprendieron - desprender
# de - de
# sus - su
# ojos - ojo
# . - .
#
#
#  -
#
#
# Colombe - Colombe
# las - él
# comprendió - comprender
# . - .
# Besó - besar
# la - el
# santa - santo
# imágen - imágen
# ; - ;
# guardóla - guardóla
# en - en
# su - su
# seno - seno
# ; - ;
# y - y
# en - en
#
#  -
#
# la - el
# noche - noche
# , - ,
# á - á
# la - el
# hora - hora
# de - de
# acostarse - acostar él
# , - ,
# Mauricio - Mauricio
# la - él
# encontró - encontrar
# á - á
# la - el
# cabecera - cabecera
# de - de
#
#  -
#
# su - su
# cama - cama
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# IV - iv
#
#
#
#  -
#
#
#
# Desde - Desde
# ese - ese
# dia - dia
# un - uno
# notable - notable
# cambio - cambio
# se - él
# efectuó - efectuar
# en - en
# su - su
# carácter - carácter
# . - .
# A - a
# la - el
#
#  -
#
# inquieta - inquieto
# turbulencia - turbulencia
# del - del
# niño - niño
# , - ,
# sucedieron - suceder
# la - el
# mesura - mesura
# y - y
# la - el
# reflexion - reflexion
# del - del
#
#  -
#
# hombre - hombre
# ; - ;
# al - al
# gusto - gusto
# por - por
# los - el
# juegos - juegos
# , - ,
# el - el
# amor - amor
# al - al
# estudio - estudio
# ; - ;
# á - á
# su - su
# indiferencia - indiferencia
#
#  -
#
# cosmopolita - cosmopolita
# , - ,
# el - el
# sentimiento - sentimiento
# exaltado - exaltado
# de - de
# la - el
# nacionalidad - nacionalidad
# . - .
#
#
#  -
#
#
# Cuando - Cuando
# en - en
# los - el
# dias - dia
# clásicos - clásico
# , - ,
# al - al
# flamear - flamear
# de - de
# la - el
# bandera - bandera
# tricolor - tricolor
# , - ,
# sus - su
#
#  -
#
# compañeros - compañero
# cantaban - cantar
# : - :
# « - «
# _ - _
# Allons - Allons
# enfants - enfants
# de - de
# la - el
# patrie - patrie
# _ - _
# , - ,
# » - »
# Mauricio - Mauricio
# buscaba - buscar
#
#  -
#
# en - en
# el - el
# cielo - cielo
# , - ,
# el - el
# azul - azul
# pabellon - pabellon
# ; - ;
# y - y
# del - del
# fondo - fondo
# de - de
# su - su
# alma - alma
# exhalábase - exhalábar
# el - el
#
#  -
#
# grito - grito
# sagrado - sagrado
# del - del
# himno - himno
# nacional - nacional
# . - .
# Allá - allá
# , - ,
# surgiendo - surgir
# de - de
# las - el
# brumas - bruma
# del - del
#
#  -
#
# lejano - lejano
# pasado - pasado
# , - ,
# la - el
# imágen - imágen
# de - de
# la - el
# patria - patria
# aparecíale - aparecíale
# con - con
# su - su
# inmensa - inmenso
# pampa - pampa
# , - ,
#
#  -
#
# su - su
# magestuoso - magestuoso
# rio - rio
# , - ,
# sus - su
# cerúleas - cerúlea
# lontananzas - lontananza
# , - ,
# llamándolo - llamar él
# con - con
# poderoso - poderoso
#
#  -
#
# reclamo - reclamo
# . - .
#
#
#  -
#
#
# Pero - Pero
# ¡ - ¡
# ah - ah
# ! - !
# siempre - siempre
# que - que
# estas - este
# luminosas - luminoso
# imágenes - imagen
# visitaban - visitar
# su - su
# mente - mente
# , - ,
# un - uno
#
#  -
#
# siniestro - siniestro
# recuerdo - recuerdo
# venía - venir
# á - á
# oscurecerlas - oscurecerlas
# . - .
#
#
#  -
#
#
# Su - su
# madrastra - madrastra
# . - .
#
#
#  -
#
#
# Este - este
# sentimiento - sentimiento
# de - de
# repulsion - repulsion
# creció - crecer
# más - más
# todavía - todavía
# , - ,
# cuando - cuando
# Mauricio - Mauricio
#
#  -
#
# comprendió - comprender
# por - por
# las - el
# cartas - carta
# de - de
# su - su
# padre - padre
# , - ,
# la - el
# humillante - humillante
# dependencia - dependencia
# en - en
#
#  -
#
# que - que
# yacía - yacer
# . - .
# Cada - cada
# frase - frase
# parecía - parecer
# consultada - consultado
# , - ,
# corregida - corregido
# ó - ó
# dictada - dictado
# por - por
# el - el
#
#  -
#
# déspota - déspoto
# que - que
# leía - leer
# sobre - sobre
# su - su
# hombro - hombro
# . - .
#
#
#  -
#
#
# El - el
# jóven - jóven
# vertía - verter
# sobre - sobre
# ella - él
# lágrimas - lágrima
# de - de
# indignacion - indignacion
# y - y
# de - de
# dolor - dolor
# ; - ;
# y - y
# una - uno
#
#  -
#
# palabra - palabra
# de - de
# uno - uno
# ú - ú
# otro - otro
# , - ,
# contenían - contener
# sus - su
# respuestas - respuesta
# . - .
#
#
#  -
#
#
# Así - así
# , - ,
# la - el
# correspondencia - correspondencia
# entre - entre
# padre - padre
# é - é
# hijo - hijo
# tomó - tomar
# un - uno
# carácter - carácter
# de - de
# acritud - acritud
#
#  -
#
# que - que
# , - ,
# poco - poco
# á - á
# poco - poco
# , - ,
# degeneró - degenerar
# en - en
# frialdad - frialdad
# . - .
#
#
#  -
#
#
# Y - Y
# , - ,
# cuando - cuando
# á - á
# la - el
# edad - edad
# de - de
# diez - diez
# y - y
# ocho - ocho
# años - año
# , - ,
# acabados - acabado
# sus - su
# estudios - estudio
# y - y
#
#  -
#
# rendido - rendido
# con - con
# brillo - brillo
# el - el
# último - último
# exámen - exámen
# , - ,
# su - su
# padre - padre
# le - él
# habló - hablar
# de - de
# regreso - regreso
# . - .
#
#
#  -
#
#
# --Amo - --Amo
# á - á
# mi - mi
# patria - patria
# y - y
# anhelo - anhelar
# volver - volver
# á - á
# verla--respondió - verla--respondeír
# Mauricio,--amo - mauricio,--amo
# á - á
#
#  -
#
# mi - mi
# padre - padre
# y - y
# deseo - desear
# estrecharlo - estrechar él
# en - en
# mis - mi
# brazos - brazo
# ; - ;
# pero - pero
# no - no
# podría - poder
# presenciar - presenciar
#
#  -
#
# el - el
# espectáculo - espectáculo
# vergonzoso - vergonzoso
# de - de
# su - su
# servidumbre - servidumbre
# ; - ;
# y - y
# porque - porque
# lo - él
# amo - amar
# ; - ;
# y - y
# porque - porque
#
#  -
#
# lo - él
# respeto - respetar
# , - ,
# prefiero - preferir
# un - uno
# eterno - eterno
# destierro - destierro
# . - .
#
#
#  -
#
#
# A - A
# esta - este
# declaracion - declaracion
# siguió - seguir
# un - uno
# profundo - profundo
# silencio - silencio
# ; - ;
# y - y
# como - como
# única - único
# respuesta - respuesta
#
#  -
#
# Mauricio - Mauricio
# recibió - recibir
# una - uno
# carta - carta
# que - que
# contenía - contener
# inesperadas - inesperado
# revelaciones - revelación
# . - .
#
#  -
#
# Suscribíala - Suscribíala
# el - el
# escribano - escribano
# D - D
# ... - ...
# , - ,
# uno - uno
# de - de
# los - el
# hombres - hombre
# más - más
# honorables - honorable
# de - de
#
#  -
#
# Buenos - Buenos
# Aires - Aires
# . - .
#
#
#    -
#
#
# --«Alejados - --«alejado
# y - y
# sin - sin
# conocernos - conocer yo
# uno - uno
# á - á
# otro--decíale - otro--decíale
# éste--únenos - éste--úneno
# , - ,
#
#    -
#
# sinembargo - sinembargo
# , - ,
# el - el
# mandato - mandato
# de - de
# una - uno
# persona - persona
# que - que
# ya - ya
# no - no
# existe - existir
# ; - ;
# y - y
# que - que
# para - para
#
#    -
#
# mí - yo
# fué - fué
# por - por
# esto - este
# , - ,
# más - más
# sagrado.--Y - sagrado.--y
# proseguía - proseguir
# : - :
#
#
#    -
#
#
# --«Hace - --«Hace
# quince - quince
# años - año
# , - ,
# fuí - fuir
# llamado - llamar
# un - uno
# dia - dia
# á - á
# casa - casa
# del - del
# señor - señor
# Cárlos - Cárlos
#
#    -
#
# Ridel - Ridel
# , - ,
# cuya - cuyo
# esposa - esposa
# , - ,
# en - en
# trance - trance
# de - de
# muerte - muerte
# , - ,
# debía - deber
# otorgar - otorgar
# testamento - testamento
# . - .
#
#
#    -
#
#
# « - «
# Mi - mi
# colega - colega
# , - ,
# el - el
# señor - señor
# R - R
# ... - ...
# , - ,
# autorizaba - autorizar
# el - el
# acto - acto
# ; - ;
# y - y
# yo - yo
# creía - creer
# haber - haber
#
#    -
#
# sido - ser
# requerido - requerir
# como - como
# testigo - testigo
# , - ,
# cuando - cuando
# la - el
# testante - testante
# , - ,
# habiendo - haber
# declarado - declarar
#
#    -
#
# que - que
# dejaba - dejar
# á - á
# su - su
# hijo - hijo
# único - único
# , - ,
# Mauricio - Mauricio
# Ridel - Ridel
# , - ,
# el - el
# valor - valor
# de - de
# doscientos - dosciento
#
#    -
#
# mil - mil
# pesos - pesos
# en - en
# propiedades - propiedad
# urbanas - urbano
# y - y
# rurales - rural
# , - ,
# volviéndose - volver él
# á - á
# su - su
#
#    -
#
# esposo - esposo
# , - ,
# pidióle - pidióle
# permiso - permiso
# para - para
# instituirme - instituir yo
# á - á
# mí - yo
# , - ,
# hasta - hasta
# la - el
# mayoría - mayoría
# de - de
#
#    -
#
# aquel - aquel
# , - ,
# guardador - guardador
# de - de
# dichos - dicho
# bienes - bien
# . - .
#
#
#    -
#
#
# « - «
# Repugnábame - Repugnábame
# una - uno
# mision - mision
# visiblemente - visiblemente
# motivada - motivado
# por - por
# disensiones - disensión
#
#    -
#
# conyugales - conyugal
# ; - ;
# pero - pero
# los - el
# ojos - ojo
# de - de
# la - el
# moribunda - moribunda
# enviáronme - enviáronme
# una - uno
# mirada - mirada
# de - de
#
#    -
#
# angustioso - angustioso
# ruego - ruego
# , - ,
# que - que
# me - yo
# hizo - hacer
# aceptarla - aceptar él
# . - .
#
#
#    -
#
#
# « - «
# Ella - él
# entónces - entónces
# suspiró - suspirar
# como - como
# aliviada - aliviado
# de - de
# una - uno
# grave - grave
# preocupacion - preocupacion
# ; - ;
#
#    -
#
# estrechó - estrechar
# mi - mi
# mano - mano
# con - con
# gratitud - gratitud
# , - ,
# y - y
# murió - morir
# en - en
# paz - paz
# . - .
#
#
#    -
#
#
# « - «
# Yo - yo
# he - haber
# cumplido - cumplir
# fielmente - fielmente
# el - el
# deber - deber
# que - que
# me - yo
# impuse - impusar
# : - :
# he - haber
# administrado - administrar
#
#    -
#
# esos - ese
# bienes - bien
# con - con
# el - el
# acierto - acierto
# que - que
# dá - dar
# una - uno
# larga - largo
# experiencia - experiencia
# en - en
# los - el
#
#    -
#
# negocios - negocios
# ; - ;
# los - él
# he - haber
# conservado - conservar
# , - ,
# los - él
# he - haber
# hecho - hacer
# fructificar - fructificar
# : - :
# pero - pero
# siempre - siempre
#
#    -
#
# en - en
# el - el
# limite - limite
# que - que
# mi - mi
# delicadeza - delicadeza
# me - yo
# prescribía - prescribir
# : - :
# no - no
# como - como
# guardador - guardador
# , - ,
#
#    -
#
# sino - sino
# como - como
# administrador - administrador
# , - ,
# rindiendo - rendir
# cuentas - cuenta
# de - de
# mi - mi
# cometido - cometido
# y - y
#
#    -
#
# entregando - entregar
# al - al
# señor - señor
# Ridel - Ridel
# las - el
# fuertes - fuerte
# sumas - suma
# que - que
# producen - producir
# . - .
#
#
#    -
#
#
# « - «
# Hoy - hoy
# me - yo
# ha - haber
# hecho - hacer
# saber - saber
# que - que
# V. - V.
# se - él
# ha - haber
# emancipado - emancipar
# ; - ;
# y - y
# que - que
# , - ,
# por - por
# tanto - tanto
# , - ,
#
#    -
#
# la - el
# ingerencia - ingerencia
# que - que
# yo - yo
# le - él
# daba - dar
# en - en
# los - el
# asuntos - asunto
# de - de
# su - su
# hijo - hijo
# , - ,
# ha - haber
# cesado - cesar
# . - .
#
#
#    -
#
#
# « - «
# Por - Por
# consecuencia - consecuencia
# , - ,
# y - y
# persuadido - persuadido
# de - de
# que - que
# él - él
# habrá - haber
# informado - informar
# á - á
# V. - V.
# del - del
#
#    -
#
# estado - estado
# floreciente - floreciente
# de - de
# su - su
# fortuna - fortuna
# , - ,
# no - no
# solo - solo
# por - por
# mi - mi
# buena - buen
# voluntad - voluntad
# en - en
#
#    -
#
# su - su
# administracion - administracion
# , - ,
# sino - sino
# á - á
# causa - causa
# del - del
# subido - subido
# precio - precio
# que - que
# ha - haber
# adquirido - adquirir
#
#    -
#
# la - el
# propiedad - propiedad
# , - ,
# réstame - réstame
# solo - solo
# ponerla - poner él
# á - á
# su - su
# disposicion - disposicion
# , - ,
# y - y
# pedirle - pedir él
# se - él
#
#    -
#
# sirvo - sirvo
# impartirme - impartir yo
# sus - su
# órdenes - órden
# » - »
# . - .
#
#
#  -
#
#
# Esta - este
# carta - carta
# de - de
# un - uno
# tutor - tutor
# hasta - hasta
# entónces - entónces
# ignorado - ignorado
# , - ,
# fué - fué
# un - uno
# rayo - rayo
# de - de
# luz - luz
# en - en
#
#  -
#
# el - el
# misterio - misterio
# que - que
# rodeaba - rodear
# el - el
# pasado - pasado
# de - de
# Mauricio - Mauricio
# , - ,
# y - y
# efectuó - efectuar
# un - uno
# cambio - cambio
#
#  -
#
# favorable - favorable
# en - en
# su - su
# destino - destino
# . - .
#
#
#  -
#
#
# Alejado - alejado
# de - de
# su - su
# padre - padre
# , - ,
# por - por
# la - el
# funesta - funesta
# influencia - influencia
# que - que
# se - él
# alzaba - alzar
# hostil - hostil
#
#  -
#
# entre - entre
# ambos - ambos
# , - ,
# el - el
# hijo - hijo
# desechado - desechado
# , - ,
# bendijo - bendijo
# la - el
# ternura - ternura
# previsora - previsoro
# de - de
# aquella - aquel
#
#  -
#
# madre - madre
# moribunda - moribundo
# , - ,
# que - que
# viendo - ver
# cernerse - cerner él
# la - el
# desgracia - desgracia
# sobre - sobre
# la - el
# cuna - cuna
# del - del
#
#  -
#
# niño - niño
# que - que
# le - él
# era - ser
# forzoso - forzoso
# abandonar - abandonar
# , - ,
# había - haber
# querido - querer
# , - ,
# asegurándole - asegurar él
# una - uno
#
#  -
#
# fortuna - fortuna
# independiente - independiente
# , - ,
# preservarlo - preservar él
# en - en
# los - el
# azares - azar
# del - del
# porvenir - porvenir
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# expresó - expresar
# su - su
# profunda - profundo
# gratitud - gratitud
# al - al
# honrado - honrado
# escribano - escribano
# ; - ;
# confióle - confióle
#
#  -
#
# los - el
# dolorosos - doloroso
# motivos - motivo
# de - de
# su - su
# doble - doble
# ostracismo - ostracismo
# ; - ;
# y - y
# le - él
# suplicó - suplicar
# , - ,
# en - en
# nombre - nombre
#
#  -
#
# de - de
# aquella - aquel
# cuyo - cuyo
# encargo - encargo
# había - haber
# tan - tanto
# noblemente - noblemente
# cumplido - cumplido
# , - ,
# quisiera - querer
#
#  -
#
# favorecerlo - favorecer él
# á - á
# él - él
# , - ,
# continuando - continuar
# en - en
# la - el
# administracion - administracion
# de - de
# aquellos - aquel
# bienes - bien
# , - ,
#
#  -
#
# para - para
# lo - él
# cual - cual
# le - él
# confirió - conferir
# un - uno
# pleno - pleno
# poder - poder
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# V - V
#
#
#
#  -
#
#
#
# Las - el
# lágrimas - lágrima
# de - de
# una - uno
# infancia - infancia
# desamparada - desamparado
# y - y
# las - el
# tristezas - tristeza
# de - de
# su - su
#
#  -
#
# juventud - juventud
# , - ,
# sin - sin
# patria - patria
# , - ,
# ni - ni
# hogar - hogar
# , - ,
# habían - haber
# dado - dar
# al - al
# carácter - carácter
# de - de
# Mauricio - Mauricio
# una - uno
#
#  -
#
# gravedad - gravedad
# melancólica - melancólico
# que - que
# , - ,
# alejándolo - alejándolo
# de - de
# los - el
# placeres - placer
# bulliciosos - bullicioso
# de - de
# sus - su
#
#  -
#
# compañeros - compañero
# , - ,
# lo - él
# preservó - preservar
# de - de
# la - el
# disipacion - disipacion
# . - .
#
#
#  -
#
#
# Así - así
# , - ,
# cuando - cuando
# libre - libre
# y - y
# en - en
# posesion - posesion
# de - de
# una - uno
# fortuna - fortuna
# independiente - independiente
# , - ,
# podía - poder
#
#  -
#
# entregarse - entregar él
# á - á
# los - el
# goces - goz
# que - que
# Paris - Paris
# ofrece - ofrecer
# con - con
# mano - mano
# pródiga - pródigo
# , - ,
# él - él
# , - ,
# sin - sin
#
#  -
#
# esfuerzo - esfuerzo
# , - ,
# sin - sin
# sacrificio - sacrificio
# , - ,
# consagróse - consagróse
# , - ,
# á - á
# una - uno
# vida - vida
# de - de
# labor - labor
# intelectual - intelectual
# . - .
#
#  -
#
# Frecuentó - frecuentar
# la - el
# Sorbona - Sorbona
# , - ,
# los - el
# Institutos - Institutos
# , - ,
# las - el
# academias - academia
# y - y
# las - el
# bibliotecas - biblioteca
# . - .
#
#  -
#
# Arrojóse - Arrojóse
# en - en
# el - el
# periodismo - periodismo
# y - y
# tomó - tomar
# activa - activo
# parte - parte
# en - en
# los - el
# trabajos - trabajo
# de - de
# uno - uno
# de - de
#
#  -
#
# los - el
# principales - principal
# diarios - diario
# de - de
# Paris - Paris
# , - ,
# haciéndose - hacer él
# notar - notar
# por - por
# su - su
# brillante - brillante
#
#  -
#
# estilo - estilo
# y - y
# la - el
# originalidad - originalidad
# de - de
# sus - su
# ideas - idea
# . - .
#
#
#  -
#
#
# Ensayó - Ensayó
# la - el
# novela - novela
# ; - ;
# y - y
# muy - mucho
# pronto - pronto
# los - el
# folletines - folletín
# firmados - firmado
# por - por
# Valerio--su - Valerio--su
#
#  -
#
# seudónimo,--fueron - seudónimo,--ser
# leidos - leer
# con - con
# entusiasmo - entusiasmo
# , - ,
# sobre - sobre
# todo - todo
# por - por
# las - el
# jóvenes - joven
# , - ,
#
#  -
#
# que - que
# encontraban - encontrar
# en - en
# sus - su
# páginas - página
# , - ,
# á - á
# vueltas - vuelta
# de - de
# los - el
# pálidos - pálido
# excepticismos - excepticismo
#
#  -
#
# de - de
# la - el
# época - época
# , - ,
# el - el
# color - color
# ardiente - ardiente
# de - de
# la - el
# pasion - pasion
# . - .
#
#
#  -
#
#
# Era - ser
# que - que
# el - el
# ideal - ideal
# evocado - evocado
# en - en
# sus - su
# creaciones - creación
# despertaba - despertar
# y - y
# hacía - hacer
# palpitar - palpitar
#
#  -
#
# un - uno
# sentimiento - sentimiento
# que - que
# hasta - hasta
# entónces - entónces
# yacía - yacer
# latente - latente
# en - en
# el - el
# alma - alma
# de - de
# Mauricio - Mauricio
# : - :
#
#
#  -
#
#
# --El - --El
# amor.-- - amor.--
#
#
#  -
#
#
# Y - Y
# aunque - aunque
# más - más
# de - de
# una - uno
# vez - vez
# , - ,
# las - el
# seducciones - seducción
# de - de
# la - el
# mujer - mujer
# habían - haber
# deslumbrado - deslumbrar
#
#  -
#
# sus - su
# ojos - ojo
# , - ,
# rozado - rozar
# su - su
# epidermis - epidermis
# , - ,
# jamás - jamás
# lograron - lograr
# llegar - llegar
# á - á
# su - su
# corazon - corazon
# . - .
#
#
#  -
#
#
# Tres - tres
# años - año
# pasaron - pasar
# para - para
# Mauricio - Mauricio
# en - en
# aquella - aquel
# vida - vida
# activa - activo
# del - del
# espíritu - espíritu
# . - .
#
#  -
#
# Proponíase - Proponíase
# ensancharla - ensanchar él
# con - con
# viajes - viaje
# de - de
# recreo - recreo
# en - en
# torno - torno
# á - á
# Europa - Europa
# y - y
# con - con
#
#  -
#
# la - el
# fundacion - fundacion
# de - de
# un - uno
# periódico - periódico
# de - de
# espíritu - espíritu
# americano - americano
# , - ,
# que - que
# uniese - unir
# en - en
# un - uno
#
#  -
#
# contacto - contacto
# intelectual - intelectual
# más - más
# íntimo - íntimo
# , - ,
# los - el
# dos - dos
# continentes - continente
# ; - ;
# trasfusionando - trasfusionar
#
#  -
#
# en - en
# la - el
# savia - savia
# cansada - cansado
# y - y
# empobrecida - empobrecido
# del - del
# uno - uno
# , - ,
# la - el
# savia - savia
# rica - rico
# y - y
# jóven - jóven
# del - del
#
#  -
#
# otro - otro
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Ah - Ah
# ! - !
# de - de
# todas - todo
# las - el
# vanidades - vanidad
# que - que
# deplora - deplorar
# el - el
# Sagrado - Sagrado
# Libro - Libro
# , - ,
# ¡ - ¡
# ninguna - ninguno
# tan - tanto
#
#  -
#
# vana - vano
# como - como
# nuestros - nuestro
# proyectos - proyecto
# ! - !
#
#
#  -
#
#
# Creo - creer
# haberlo - haberlo
# dicho - decir
# ya - ya
# , - ,
# en - en
# otra - otro
# ocasion - ocasion
# . - .
# No - no
# importa - importar
# : - :
# las - el
# frases - frase
# son - ser
# las - el
#
#  -
#
# mismas - mismo
# , - ,
# cuando - cuando
# es - ser
# idéntica - idéntico
# la - el
# situacion - situacion
# . - .
#
#
#  -
#
#
# En - En
# el - el
# momento - momento
# que - que
# Mauricio - Mauricio
# preparaba - preparar
# la - el
# realizacion - realizacion
# de - de
# tan - tanto
# lisongero - lisongero
#
#  -
#
# propósito - propósito
# , - ,
# una - uno
# carta - carta
# de - de
# Buenos - Buenos
# Aires - Aires
# , - ,
# portadora - portador
# de - de
# fatales - fatal
# nuevas - nuevo
# , - ,
# vino - vino
#
#  -
#
# á - á
# destruir - destruir
# sus - su
# proyectos - proyecto
# y - y
# sus - su
# esperanzas - esperanza
# . - .
#
#
#    -
#
#
# « - «
# Deber - deber
# del - del
# hombre - hombre
# es - ser
# ser - ser
# fuerte - fuerte
# y - y
# resignado - resignado
# , - ,
# mi - mi
# querido - querido
#
#    -
#
# Mauricio--decía - Mauricio--decía
# el - el
# escribano - escribano
# D - D
# ... - ...
# en - en
# aquella - aquel
# carta.--Por - carta.--por
# tanto - tanto
# , - ,
#
#    -
#
# valor - valor
# y - y
# resignacion - resignacion
# . - .
#
#
#    -
#
#
# « - «
# El - el
# padre - padre
# de - de
# Vd. - Vd.
# ha - haber
# muerto - morir
# . - .
#
#
#    -
#
#
# « - «
# Envuelto - envuelto
# en - en
# una - uno
# quiebra - quiebra
# producida - producido
# por - por
# la - el
# fuga - fuga
# de - de
# un - uno
# sócio - sócio
# bribon - bribon
# , - ,
#
#    -
#
# falleció - fallecer
# víctima - víctima
# de - de
# una - uno
# congestion - congestion
# fulminante - fulminante
# . - .
#
#
#    -
#
#
# « - «
# Los - el
# acreedores - acreedor
# se - él
# presentaron - presentar
# munidos - munido
# de - de
# sus - su
# derechos - derecho
# , - ,
# y - y
#
#    -
#
# obtuvieron - obtener
# la - el
# liquidacion - liquidacion
# . - .
#
#
#    -
#
#
# « - «
# Pero - Pero
# como - como
# el - el
# sócio - sócio
# ( - (
# hermano - hermano
# de - de
# la - el
# señora - señora
# Ridel - Ridel
# ) - )
# había - haber
# sustraido - sustraer
#
#    -
#
# en - en
# su - su
# fuga - fuga
# todo - todo
# el - el
# numerario - numerario
# existente - existente
# en - en
# caja - caja
# , - ,
# quedó - quedar
# un - uno
# enorme - enorme
#
#    -
#
# pasivo - pasivo
# , - ,
# que - que
# toda - todo
# la - el
# fortuna - fortuna
# particular - particular
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# no - no
# ha - haber
# sido - ser
#
#    -
#
# bastante - bastante
# á - á
# cubrir - cubrir
# . - .
#
#
#    -
#
#
# « - «
# Bajo - Bajo
# el - el
# peso - peso
# de - de
# tres - tres
# catástrofes - catástrofe
# : - :
# la - el
# infame - infame
# fuga - fuga
# de - de
# aquel - aquel
# hermano - hermano
# , - ,
#
#    -
#
# impuesto - impuesto
# por - por
# ella - él
# á - á
# la - el
# sumision - sumision
# de - de
# su - su
# marido - marido
# ; - ;
# la - el
# súbita - súbita
# muerte - muerte
# de - de
#
#    -
#
# éste - este
# , - ,
# y - y
# la - el
# miseria - miseria
# que - que
# le - él
# aparecía - aparecer
# con - con
# su - su
# séquito - séquito
# de - de
# humillaciones - humillación
# , - ,
#
#    -
#
# la - el
# desventurada - desventurado
# mujer - mujer
# enloqueció - enloqueceír
# . - .
#
#
#    -
#
#
# « - «
# Silenciosa - silencioso
# , - ,
# sin - sin
# lágrimas - lágrima
# , - ,
# huraño - huraño
# el - el
# ademan - ademan
# y - y
# fija - fijar
# la - el
# mirada - mirada
# , - ,
#
#    -
#
# escuchó - escuchar
# la - el
# intimacion - intimacion
# de - de
# desalojo - desalojo
# ; - ;
# y - y
# cuando - cuando
# intentaron - intentar
# hacerla - hacer él
#
#    -
#
# salir - salir
# de - de
# su - su
# casa - casa
# , - ,
# subióse - subióse
# á - á
# lo - él
# alto - alto
# del - del
# mirador - mirador
# que - que
# coronaba - coronar
# el - el
#
#    -
#
# edificio - edificio
# , - ,
# abrió - abrir
# un - uno
# balcon - balcon
# y - y
# se - él
# arrojó - arrojar
# á - á
# la - el
# calle - calle
# . - .
#
#
#    -
#
#
# ...
# suple - soplar
# la - el
# falta - falta
# de - de
# la - el
# póliza - póliza
# . - .
# Bastaría - bastar
# un - uno
# documento - documento
# del - del
# señor - señor
# , - ,
# con - con
# la - el
#
#  -
#
# declaracion - declaracion
# de - de
# único - único
# heredero - heredero
# ; - ;
# el - el
# certificado - certificado
# del - del
# médico - médico
# y - y
# la - el
# partida - partida
#
#  -
#
# de - de
# defuncion - defuncion
# . - .
# Veremos - ver
# la - el
# resolucion - resolucion
# del - del
# Directorio - Directorio
# . - .
# Si - si
# fuera - ser
# favorable - favorable
# , - ,
#
#  -
#
# para - para
# llenar - llenar
# ciertas - cierto
# fórmulas - fórmula
# , - ,
# se - él
# pondrán - poner
# avisos - aviso
# por - por
# seis - seis
# dias - dias
# , - ,
#
#  -
#
# solicitando - solicitar
# la - el
# póliza - póliza
# de - de
# vida - vida
# del - del
# señor - señor
# Cárlos - Cárlos
# Ridel - Ridel
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# XXX - XXX
#
#
#
#  -
#
#
#
# Antes - antes
# de - de
# aquel - aquel
# término - término
# el - el
# Gerente - Gerente
# de - de
# « - «
# La - el
# Buenos - Buenos
# Aires - Aires
# » - »
# recibía - recibir
# una - uno
#
#  -
#
# citacion - citacion
# del - del
# Banco - Banco
# Nacional - Nacional
# con - con
# motivo - motivo
# del - del
# aviso - aviso
# que - que
# por - por
# su - su
# órden - órden
#
#  -
#
# registraban - registrar
# « - «
# La - el
# Prensa - Prensa
# » - »
# y - y
# « - «
# La - el
# Tribuna - Tribuna
# Nacional - Nacional
# » - »
# . - .
#
#
#  -
#
#
# Acudió - acudir
# el - el
# Gerente - Gerente
# , - ,
# y - y
# supo - saber
# que - que
# allí - allí
# se - él
# hallaba - hallar
# , - ,
# depositado - depositado
# por - por
# el - el
# señor - señor
#
#  -
#
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# un - uno
# paquete - paquete
# cerrado - cerrado
# , - ,
# que - que
# en - en
# Junio - junio
# de - de
# 1888 - 1888
# debía - deber
# ser - ser
#
#  -
#
# entregado - entregar
# á - á
# la - el
# Compañía - Compañía
# de - de
# Seguros - Seguros
# « - «
# La - el
# Buenos - Buenos
# Aires - Aires
# » - »
# . - .
#
#
#  -
#
#
# Abierto - Abierto
# el - el
# paquete - paquete
# , - ,
# encontráronse - encontráronse
# con - con
# la - el
# póliza - póliza
# de - de
# seguro - seguro
# sobre - sobre
# la - el
# vida - vida
#
#  -
#
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# por - por
# 20,000 - 20.000
# $ - $
# m - m
# / - /
# n. - n.
# en - en
# 20 - 20
# años - año
# , - ,
# y - y
# en - en
# la - el
# que - que
# constaba - constar
# el - el
#
#  -
#
# abono - abono
# de - de
# la - el
# primera - primero
# anualidad - anualidad
# de - de
# 792 - 792
# $ - $
# m - m
# / - /
# n. - n.
# ; - ;
# una - uno
# carta - carta
# á - á
# su - su
# esposa - esposa
# , - ,
# y - y
#
#  -
#
# en - en
# defecto - defecto
# de - de
# ésta - este
# , - ,
# á - á
# su - su
# hijo - hijo
# Mauricio - Mauricio
# ; - ;
# y - y
# una - uno
# letra - letra
# por - por
# 792 - 792
# $ - $
# m - m
# / - /
# n. - n.
# á - á
# la - el
#
#  -
#
# órden - órden
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# y - y
# endosada - endosado
# por - por
# éste - este
# á - á
# « - «
# La - el
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
# como - como
# la - el
#
#  -
#
# segunda - segundo
# cuota - cuota
# que - que
# debía - deber
# pagar - pagar
# por - por
# su - su
# póliza - póliza
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# leyó - leer
# la - el
# carta - carta
# que - que
# acompañaba - acompañar
# estos - este
# documentos - documento
# . - .
#
#
#    -
#
#
# « - «
# Cuando - Cuando
# leas - leas
# estas - este
# líneas - línea
# , - ,
# mi - mi
# bien - bien
# amada - amado
# Lucrecia,--decía - lucrecia,--decía
# Ridel - Ridel
# á - á
#
#    -
#
# su - su
# esposa--muerto - esposa--muerto
# ó - ó
# vivo - vivir
# , - ,
# habrás - habrás
# de - de
# perdonar - perdonar
# mi - mi
# primera - primero
# y - y
# única - único
#
#    -
#
# desobediencia - desobediencia
# , - ,
# en - en
# gracia - gracia
# del - del
# motivo - motivo
# que - que
# la - él
# inspiró - inspirar
# ; - ;
# hélo - hélo
# aquí - aquí
# : - :
#
#
#    -
#
#
# « - «
# Tengo - tener
# por - por
# toda - todo
# institucion - institucion
# benéfica - benéfico
# , - ,
# la - el
# más - más
# alta - alto
# estima - estimar
# ; - ;
# y - y
#
#    -
#
# profunda - profundo
# gratitud - gratitud
# por - por
# las - el
# que - que
# se - él
# levantan - levantar
# en - en
# nuestro - nuestro
# país - país
# . - .
#
#
#    -
#
#
# « - «
# Entre - Entre
# estas - este
# , - ,
# las - el
# Compañías - Compañías
# de - de
# Seguros - Seguros
# sónme - sónmir
# especialmente - especialmente
#
#    -
#
# simpáticas - simpático
# , - ,
# sobretodo - sobretodo
# , - ,
# « - «
# La - el
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
# por - por
# su - su
# importancia - importancia
# y - y
#
#    -
#
# valiosa - valioso
# organizacion - organizacion
# . - .
#
#
#    -
#
#
# « - «
# Así - así
# , - ,
# en - en
# tanto - tanto
# que - que
# me - yo
# permitas - permitas
# ser - ser
# su - su
# accionista - accionista
# , - ,
# he - haber
# querido - querer
#
#    -
#
# pertenecerle - pertenecer él
# , - ,
# al - al
# menos - menos
# , - ,
# por - por
# un - uno
# seguro - seguro
# » - »
# ...... - ......
#
#
#  -
#
#
# Mauricio - Mauricio
# no - no
# pudo - poder
# leer - leer
# más - más
# . - .
#
#
#  -
#
#
# Una - uno
# ola - ola
# amarga - amargo
# subió - subir
# á - á
# su - su
# corazon - corazon
# despertando - despertar
# todos - todo
# los - el
# antiguos - antiguo
#
#  -
#
# dolores - dolor
# filiales - filial
# . - .
#
#
#  -
#
#
# En - En
# la - el
# vida - vida
# como - como
# en - en
# la - el
# eternidad - eternidad
# , - ,
# siempre - siempre
# la - el
# sombra - sombra
# fatídica - fatídico
# de - de
# su - su
#
#  -
#
# madrastra - madrastra
# venía - venir
# á - á
# colocarse - colocar él
# entre - entre
# él - él
# y - y
# su - su
# padre - padre
# .... - ....
#
#
#  -
#
#
# Pero - Pero
# , - ,
# luego - luego
# , - ,
# la - el
# imágen - imágen
# de - de
# Julia - Julia
# , - ,
# como - como
# un - uno
# rayo - rayo
# de - de
# luz - luz
# , - ,
# borró - borró
# aquella - aquel
#
#  -
#
# penosa - penoso
# impresion - impresion
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# XXXI - xxxi
#
#
#
#  -
#
#
#
# --La - --la
# Capilla - Capilla
# de - de
# Nuestra - nuestro
# Señora - Señora
# de - de
# las - el
# Victorias - Victorias
# tenía - tener
# hoy - hoy
# un - uno
# aspecto - aspecto
#
#  -
#
# imponente - imponente
# . - .
# Llenábala - llenábalar
# el - el
# cortejo - cortejo
# de - de
# una - uno
# boda.-- - boda.--
#
#
#  -
#
#
# Así - así
# llegaron - llegar
# diciendo - decir
# las - el
# jóvenes - joven
# de - de
# vuelta - vuelta
# de - de
# misa - misa
# de - de
# ocho - ocho
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Una - uno
# boda - boda
# ! - !
# Suena - sonar
# tan - tanto
# bien - bien
# esta - este
# mágica - mágico
# palabra - palabra
# , - ,
# que - que
# muy - mucho
# luego - luego
# tuvo - tener
# toda - todo
#
#  -
#
# la - el
# casa - casa
# por - por
# auditorio - auditorio
# . - .
#
#
#  -
#
#
# Y - Y
# las - el
# jóvenes - joven
# continuaban - continuar
# , - ,
# y - y
# en - en
# su - su
# entusiasta - entusiasta
# lenguaje - lenguaje
# : - :
#
#
#  -
#
#
# --¡Qué - --¡Qué
# bella - bello
# pareja!--decían - pareja!--decir
# . - .
#
#
#  -
#
#
# --El - --El
# , - ,
# todo - todo
# un - uno
# buen - buen
# mozo - mozo
# ; - ;
# con - con
# un - uno
# aire - aire
# tan - tanto
# sério - sério
# y - y
# distinguido - distinguido
# . - .
#
#
#  -
#
#
# --¡Ella - --¡Ella
# ! - !
# ¡ - ¡
# morena - morén
# más - más
# linda - lindo
# ! - !
# Qué - qué
# alianza - alianza
# encantadora - encantador
# de - de
# lo - él
# blanco - blanco
# de - de
# la - el
#
#  -
#
# piel - piel
# y - y
# lo - él
# negro - negro
# de - de
# ojos - ojo
# y - y
# cabellos - cabello
# ! - !
#
#
#  -
#
#
# --¡Muchachas - --¡muchachos
# ! - !
# ¡ - ¡
# no - no
# hay - haber
# que - que
# exagerar - exagerar
# ! - !
#
#
#  -
#
#
# --¡Oh - --¡oh
# ! - !
# si - si
# nada - nada
# hemos - haber
# dicho - decir
# todavía - todavía
# . - .
# Escucha.-- - Escucha.--
#
#
#  -
#
#
# Y - Y
# dejando - dejar
# por - por
# aquí - aquí
# y - y
# por - por
# allí - allí
# , - ,
# sombreros - sombrero
# , - ,
# guantes - guant
# y - y
# abanicos - abanico
# , - ,
#
#  -
#
# continuaron - continuar
# , - ,
# quitándose - quitar él
# unas - uno
# á - á
# otras - otro
# la - el
# palabra - palabra
# : - :
#
#
#  -
#
#
# --Que - --Que
# bien - bien
# estaba - estar
# la - el
# linda - lindo
# morocha - morocha
# , - ,
# en - en
# su - su
# vestido - vestido
# de - de
# faya - faya
# , - ,
# tan - tanto
# sencillo - sencillo
#
#  -
#
# como - como
# elegante - elegante
# , - ,
# y - y
# su - su
# velo - velo
# de - de
# tul - tul
# de - de
# seda - seda
# liso - liso
# : - :
# el - el
# todo - todo
# sin - sin
# más - más
# adornos - adorno
#
#  -
#
# que - que
# azahares - azahar
# naturales - natural
# . - .
#
#
#  -
#
#
# --Un - --un
# pié - pié
# de - de
# Cendrillon - Cendrillon
# calzando - calzar
# un - uno
# zapatito - zapatito
# de - de
# raso - raso
# blanco - blanco
# , - ,
# adornado - adornado
#
#  -
#
# tambien - tambien
# con - con
# azahares - azahar
# . - .
#
#
#  -
#
#
# --Un - --un
# precioso - precioso
# abanico - abanico
# formado - formado
# de - de
# mariposas - mariposa
# trasparentes - trasparent
# : - :
# y - y
# chico - chico
# , - ,
# á - á
# la - el
#
#  -
#
# última - último
# moda - moda
# . - .
#
#
#  -
#
#
# --Pocas - --poca
# señoras - señora
# ; - ;
# muy - mucho
# elegantes - elegante
# todas - todo
# . - .
#
#
#  -
#
#
# --Pero - --pero
# ¡ - ¡
# qué - qué
# gran - gran
# séquito - séquito
# de - de
# caballeros - caballero
# ! - !
# Toda - todo
# la - el
# prensa - prensa
# : - :
# el - el
# general - general
#
#  -
#
# Mitre - Mitre
# , - ,
# Bartolito - Bartolito
# , - ,
# Dávila - Dávila
# , - ,
# Lainez - Lainez
# , - ,
# Vedia - Vedia
# , - ,
# Laurencena - Laurencena
# , - ,
# Lalanne - Lalanne
# , - ,
# Walls - Walls
# , - ,
#
#  -
#
# Ribaumont - Ribaumont
# , - ,
# Ortega - Ortega
# , - ,
# Alberú - Alberú
# , - ,
# Mulhall - Mulhall
# y - y
# tantos - tanto
# otros - otro
# . - .
#
#
#  -
#
#
# --Estaban - --estar
# tambien - tambien
# Eduardo - Eduardo
# Coll - Coll
# y - y
# Emilio - Emilio
# Casares - Casares
# que - que
# fué - fué
# el - el
# padrino - padrino
# y - y
#
#  -
#
# que - que
# dicen - decir
# ha - haber
# hecho - hacer
# un - uno
# régio - régio
# obsequio - obsequio
# á - á
# la - el
# novia - novia
# . - .
#
#
#  -
#
#
# --Muchos - --mucho
# literatos - literato
# ; - ;
# el - el
# general - general
# Sarmiento - Sarmiento
# , - ,
# Santiago - Santiago
# Estrada - Estrada
# , - ,
# José - José
# María - María
#
#  -
#
# Zuviría - Zuviría
# , - ,
# el - el
# ministro - ministro
# de - de
# Bolivia - Bolivia
# doctor - doctor
# Vaca - Vaca
# Guzman - Guzman
# y - y
# tantos - tanto
# otros - otro
# , - ,
#
#  -
#
# hija - hija
# , - ,
# que - que
# yo - yo
# no - no
# conozco - conocer
# . - .
# Apenas - apenas
# cabíamos - cabíar
# en - en
# la - el
# capilla - capilla
# . - .
#
#
#  -
#
#
# --El - --El
# celebrante - celebrante
# , - ,
# que - que
# era - ser
# el - el
# elocuentísimo - elocuentísimo
# padre - padre
# Pera - Pera
# unió - unir
# á - á
# los - el
#
#  -
#
# contrayentes - contrayent
# con - con
# las - el
# palabras - palabra
# sacramentales - sacramental
# , - ,
# pronunciadas - pronunciado
# con - con
# uncion - uncion
#
#  -
#
# conmovedora - conmovedor
# . - .
#
#
#  -
#
#
# Despues - Despues
# , - ,
# volviéndose - volver él
# al - al
# auditorio - auditorio
# , - ,
# habló - hablar
# de - de
# la - el
# excelencia - excelencia
# del - del
#
#  -
#
# matrimonio - matrimonio
# , - ,
# de - de
# su - su
# orígen - orígen
# divino - divino
# , - ,
# de - de
# su - su
# utilidad - utilidad
# en - en
# la - el
# comunion - comunion
# humana - humano
# , - ,
#
#  -
#
# de - de
# la - el
# santidad - santidad
# de - de
# su - su
# fin - fin
# , - ,
# del - del
# viático - viático
# de - de
# virtudes - virtud
# que - que
# á - á
# él - él
# debe - deber
#
#  -
#
# llevarse - llevar él
# . - .
#
#
#  -
#
#
# --Señores,--añadió--permitidme - --Señores,--añadió--permitidme
# presentaros - presentar tú
# un - uno
# modelo - modelo
# de - de
# esas - ese
# virtudes - virtud
#
#  -
#
# en - en
# los - el
# cónyugues - cónyugu
# que - que
# acabo - acabar
# de - de
# unir - unir
# : - :
# dos - dos
# hijos - hijo
# animosos - animoso
# del - del
# trabajo - trabajo
# . - .
#
#  -
#
# El - el
# uno - uno
# , - ,
# despojándose - despojar él
# de - de
# una - uno
# gran - gran
# fortuna - fortuna
# para - para
# salvar - salvar
# de - de
# la - el
# deshonra - deshonra
#
#  -
#
# la - el
# memoria - memoria
# de - de
# un - uno
# padre - padre
# ; - ;
# el - el
# otro - otro
# , - ,
# en - en
# la - el
# débil - débil
# adolescencia - adolescencia
# , - ,
# luchando - luchar
#
#  -
#
# valerosamente - valerosamente
# con - con
# las - el
# dificultades - dificultad
# de - de
# la - el
# vida - vida
# y - y
# el - el
# desamparo - desamparo
# de - de
# la - el
#
#  -
#
# orfandad - orfandad
# . - .
#
#
#  -
#
#
# Se - él
# amaban - amar
# . - .
# Libres - Libres
# , - ,
# podían - poder
# unirse - unir él
# el - el
# uno - uno
# al - al
# otro - otro
# . - .
#
#
#  -
#
#
# Pero - Pero
# eran - ser
# pobres - pobre
# ; - ;
# y - y
# en - en
# la - el
# rectitud - rectitud
# de - de
# su - su
# corazon - corazon
# , - ,
# querían - querer
# preparar - preparar
# el - el
#
#  -
#
# hogar - hogar
# , - ,
# antes - antes
# de - de
# traer - traer
# la - el
# familia - familia
# ; - ;
# y - y
# dados - dar
# al - al
# trabajo - trabajo
# , - ,
# aguardaban - aguardar
# , - ,
# en - en
#
#  -
#
# ese - ese
# penoso - penoso
# retardo - retardo
# á - á
# su - su
# dicha - dicho
# , - ,
# resignados - resignado
# , - ,
# confiando - confiar
# en - en
# Dios - Dios
# y - y
# en - en
# la - el
#
#  -
#
# fortaleza - fortaleza
# de - de
# sus - su
# almas - alma
# . - .
#
#
#  -
#
#
# Mas - Mas
# , - ,
# no - no
# en - en
# vano - vano
# confiaron - confiar
# en - en
# « - «
# Aquel - aquel
# que - que
# forma - formar
# de - de
# las - el
# piedras - piedra
# hijos - hijos
# á - á
#
#  -
#
# Abraham - Abraham
# » - »
# .... - ....
#
#
#  -
#
#
# Existen - existir
# varias - varios
# instituciones - institución
# creadas - creado
# con - con
# capitales - capital
# formados - formado
# por - por
# la - el
#
#  -
#
# honradez - honradez
# y - y
# el - el
# trabajo - trabajo
# , - ,
# que - que
# con - con
# el - el
# modesto - modesto
# nombre - nombre
# de - de
# Compañías - Compañías
# de - de
#
#  -
#
# Seguros - Seguros
# , - ,
# ejercen - ejercer
# la - el
# más - más
# benéfica - benéfico
# influencia - influencia
# en - en
# la - el
# vida - vida
# económica - económico
# de - de
# los - el
#
#  -
#
# pueblos - pueblo
# ; - ;
# porque - porque
# , - ,
# cualquiera - cualquiera
# que - que
# sea - ser
# la - el
# forma - forma
# en - en
# que - que
# se - él
# tome - tomar
# , - ,
# el - el
# seguro - seguro
#
#  -
#
# encierra - encerrar
# el - el
# bienestar - bienestar
# futuro - futuro
# de - de
# la - el
# familia - familia
# . - .
#
#
#  -
#
#
# En - En
# el - el
# seno - seno
# de - de
# una - uno
# de - de
# esas - ese
# asociaciones - asociación
# tutelares - tutelar
# , - ,
# « - «
# La - el
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
#
#  -
#
# la - el
# Providencia - Providencia
# guardaba - guardar
# un - uno
# tesoro - tesoro
# que - que
# á - á
# su - su
# hora - hora
# , - ,
# hizo - hacer
# surgir - surgir
# para - para
#
#  -
#
# recompensar - recompensar
# la - el
# abnegacion - abnegacion
# filial - filial
# y - y
# dar - dar
# la - el
# felicidad - felicidad
# á - á
# los - el
# que - que
# , - ,
#
#  -
#
# creyendo - creer
# en - en
# ella - él
# , - ,
# esperaban - esperar
# . - .
#
#
#  -
#
#
# --¡Que - --¡Que
# el - el
# Altísimo - altísimo
# os - tú
# bendiga!-- - bendiga!--
#
#
#  -
#
#
# Y - Y
# cayendo - caer
# de - de
# rodillas - rodilla
# , - ,
# el - el
# hombre - hombre
# de - de
# Dios - Dios
# se - él
# absorbió - absorber
# en - en
# mental - mental
#
#  -
#
# plegaria - plegaria
# .... - ....
#
#
#  -
#
#
# --Corrimos - --corrir
# al - al
# pórtico - pórtico
# para - para
# ver - ver
# el - el
# desfile - desfile
# de - de
# la - el
# comitiva - comitiva
# . - .
#
#
#  -
#
#
# Veinte - veinte
# carruajes - carruaj
# aguardaban - aguardar
# alineados - alineado
# , - ,
# al - al
# borde - borde
# de - de
# la - el
# vereda - vereda
# . - .
#
#
#  -
#
#
# Los - el
# esposos - esposo
# , - ,
# entrelazados - entrelazado
# los - el
# brazos - brazo
# , - ,
# salieron - salir
# seguidos - seguido
# del - del
# cortejo - cortejo
# , - ,
#
#  -
#
# que - que
# se - él
# reunió - reunir
# delante - delante
# del - del
# coche - coche
# nupcial - nupcial
# . - .
#
#
#  -
#
#
# El - el
# novio - novio
# estrechando - estrechar
# con - con
# efusion - efusion
# la - el
# mano - mano
# á - á
# Coll - Coll
# . - .
#
#
#  -
#
#
# --¡Noble - --¡Noble
# corazon!--le - corazon!--le
# dijo--¡que - dijo--¡que
# el - el
# espectáculo - espectáculo
# de - de
# nuestra - nuestro
# felicidad - felicidad
#
#  -
#
# sea - ser
# su - su
# recompensa - recompensa
# ! - !
#
#
#  -
#
#
# Y - Y
# volviéndose - volver él
# á - á
# la - el
# comitiva - comitiva
# cambió - cambiar
# con - con
# ella - él
# una - uno
# mirada - mirada
# de - de
# inteligencia - inteligencia
# ; - ;
#
#  -
#
# luego - luego
# dirigiéndose - dirigir él
# al - al
# cochero - cochero
# . - .
#
#
#  -
#
#
# --¡Al - --¡al
# muelle - muelle
# de - de
# pasageros!--ordenó - pasageros!--ordenó
# . - .
#
#
#  -
#
#
# La - el
# novia - novia
# mirándolo - mirar él
# sorprendida - sorprendido
# . - .
#
#
#  -
#
#
# --¡Al - --¡al
# muelle - muelle
# de - de
# pasageros!--repitió--¿Dónde - pasageros!--repitió--¿dónde
# vamos - ir
# , - ,
# pues - pues
# ? - ?
#
#
#  -
#
#
# --A - --A
# Francia - Francia
# , - ,
# amada - amado
# mia - mia
# , - ,
# para - para
# pedir - pedir
# al - al
# sepulcro - sepulcro
# los - el
# restos - resto
# que - que
# lloras - lloras
# y - y
#
#  -
#
# devolverlos - devolver él
# á - á
# la - el
# tierra - tierra
# de - de
# la - el
# patria - patria
# . - .
#
#
#  -
#
#
# La - el
# jóven - jóven
# exhaló - exhalar
# un - uno
# gemido - gemido
# y - y
# arrojándose - arrojar él
# en - en
# los - el
# brazos - brazo
# del - del
# esposo - esposo
# , - ,
#
#  -
#
# escondió - esconder
# la - el
# frente - frente
# en - en
# su - su
# seno - seno
# . - .
#
#
#  -
#
#
# Todos - todo
# lloramos - llorar
# .... - ....
#
#
#  -
#
#
# Yo - yo
# tambien - tambien
# lloraba - llorar
# . - .
