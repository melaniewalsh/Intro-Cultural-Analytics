# %% [markdown]
# # Named Entity Recognition for Spanish

# %% [markdown]
# :::{note}
# This section, "Working in Languages Beyond English," is co-authored with <a href="http://www.quinndombrowski.com/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# :::

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called *Named Entity Recognition* (NER) as applied to Spanish. This method will help us computationally identify people, places, and things (of various kinds) in a text or collection of texts.

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset

# %% [markdown]
# The example text for Spanish is *Oasis en la vida* by Juana Manuela Gorriti [from Project Gutenberg](http://www.gutenberg.org/ebooks/62564).

# %% [markdown]
# **Here's a preview of spaC's NER tagging *Oasis en la vida*.**
#
# If you compare the results to the [English example](Named-Entity-Recognition), you'll notice that the Spanish NER is much less good at recognizing entities, and is especially bad at distinguishing different kinds of entities, like ORG vs LOC vs PER. You need a lot of examples to train a model to distinguish different entity types; currently, English is the only model that does a decent job of it.
#
# You can read more about the [data sources used to train Spanish](https://spacy.io/models/es) on the spaCy model page.

# %%
displacy.render(document, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ﻿INTRODUCCION
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .<br><br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECONOMÍA POLÍTICA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# .<br><br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El sombrío Prudhon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# ,
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     imbuído
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , sin duda, en las ideas de los
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santos
# Padres de la Iglesia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  que predicaban el desden por los bienes<br>terrenales, decía que la pobreza es una ley de nuestra naturaleza,<br>ley bajo la cual hemos sido constituídos, de donde se deduce que el<br>pauperismo es mal que no tiene remedio ni cura.<br><br>Muy desconsolados debieron quedar los menesterosos con tan ingrata<br>noticia, pero la actividad humana, que no siempre se lleva de
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     teorías
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,<br>ha venido á confortar á los aflijidos trayéndoles más plausibles nuevas<br>y muy eficaces promesas.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     La industria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
# , con sus innúmeras palancas de<br>impulsion; las ciencias, con sus multiplicados alfileres de exámen; el<br>cálculo, con su prevision y su aritmética; todos estos agentes de la<br>vitalidad social, han venido á operar el milagro de la multiplicacion<br>del pan y el aumento del vino, sustentando anchamente á los hambrientos<br>y engordando, hasta más no poder, á los hartos.<br><br>La manera de realizar el prodigio lo ha dado á conocer esa venerable<br>matrona, que los entendidos en materias graves creo que denominan<br>_Economía política_. Esta tutriz moralizadora de la sociedad,<br>evidenciando la fecundidad del trabajo y los beneficios del ahorro, se<br>ha propuesto dignificar al hombre otorgándole los medios de sacudir el<br>vasallaje servil de la indigencia.<br><br>El ahorro, tomando forma colectiva, ha dado orígen á la más preciosa de<br>las combinaciones especulativas: á la que tiene por objeto asegurar el<br>bienestar individual en vida y garantir el porvenir de los que quedan,<br>despues de concluida la jornada.<br><br>Este tema, abstracto de suyo, y que parece ageno al dominio del arte,<br>acaba de ser desenvuelto por la ilustre escritora cuyo nombre ocupa tan<br>elevado rango en la gerarquía del movimiento intelectual americano.<br><br>Es atributo de las inteligencias creadoras trasformar y embellecer<br>las ideas que pasan por su espíritu; parece que poseyeran ese don<br>vivificador de la lujuriosa primavera que todo lo hermosea, lo cubre de<br>flores y lo esmalta de celajes.<br><br>Por si existe incrédulo que ponga en duda el aserto, invoco por<br>testigo, en mi abono, el presente libro.<br><br>Su autora comprueba, bajo la forma atrayente de la novela, los<br>beneficios que reportan el trabajo, la perseverancia y el ahorro; nunca<br>un tema económico ha sido tratado con más galanura, con más gracia<br>picarezca, ni con más natural é ingénua intriga.<br><br>Despues de recorrer este trozo de historia social, cuya trama la forman<br>las peripecias de dos caractéres nobles y fuertes, se encuentra no sé<br>qué de consolatorio, de purificador, en medio de la arenosa senda por<br>donde nos conduce diariamente la mano de la tristeza.<br><br>Si la mision de los cultores privilegiados del arte es la de alentar,<br>la de consolar, la de dilatar el horizonte de la esperanza, la<br>prestigiosa autora de estas páginas ha sabido encerrar en ellas,<br>suficientes rayos de luz para satisfacer la ansiedad de las almas<br>soñadoras, y bastantes rosas para coronar, aunque ellos no lo quieran,<br>la adusta efigie de los más hipocondriacos economistas.<br><br>                                               S.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VACA-GUZMAN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .<br><br>    Diciembre 22 de 1887.<br><br><br><br><br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     OASIS EN
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  LA VIDA.<br><br>                     Á «LA BUENOS AIRES»<br><br>                                      _LA
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AUTORA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ._<br><br><br><br><br>OASIS EN LA VIDA.<br><br><br><br><br>I<br><br><br>--¡Bah!--exclamó
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mauricio Ridel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , arrojando la pluma despues de escribir<br>la palabra
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MISC</span>
# </mark>
#  bajo la última línea de una cuartilla marcada con el<br>guarismo 60.<br><br>--¿Qué es eso?--interrogó un jóven que escribía allí cerca.<br><br>--El postrer párrafo del folletin--respondió
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mauricio
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , alargando la<br>hoja á un cajista que aguardaba.<br><br>--¡Cómo! ¿Mañana acaba CHAMUSQUINAS DE AMOR? Hoy quedaba su héroe<br>en una situacion extrema: la mano armada de un revólver, esperando<br>para morir el primer rayo de sol; y ya, este comenzaba á do

# %% [markdown]
# ---

# %% [markdown]
# ## NER with spaCy
# If you've already used the pre-processing notebook for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ### Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ### Import Libraries

# %% [markdown]
# We're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things, and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ### Download Language Model

# %% [markdown]
# Next we need to download the Spanish-language model (`es_core_news_md`), which will be processing and making predictions about our texts. You can read more about the [data sources used to train Spanish](https://spacy.io/models/es) on the spaCy model page.

# %%
# !python -m spacy download es_core_news_md
# Out:
# Collecting es-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_md-3.7.0/es_core_news_md-3.7.0-py3-none-any.whl (42.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 MB 41.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from es-core-news-md==3.7.0) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.10.8)
# Requirement already satisfied: jinja2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.1.2)
# Requirement already satisfied: setuptools in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2023.11.17)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/melwalsh/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->es-core-news-md==3.7.0) (2.1.1)
# Installing collected packages: es-core-news-md
# Successfully installed es-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_md')

# %% [markdown]
# ### Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# **1.** We can import the model as a module and then load it from the module.

# %%
import es_core_news_md
nlp = es_core_news_md.load()

# %% [markdown]
# **2.** We can load the model by name.

# %%
#nlp = spacy.load('es_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it's advisable to use Option 1. Then you can use the model immediately. Otherwise, you'll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel.. in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document

# %% [markdown]
# We first need to process our `document` with the loaded NLP model. Most of the heavy NLP lifting is done in this line of code.
#
# After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.
#
# In the cell below, we open and the example document. Then we run`nlp()` on the text and create our document.

# %%
filepath = '../texts/es.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## Get Named Entities

# %% [markdown]
# All the named entities in our `document` can be found in the `document.ents` property. If we check out `document.ents`, we can see all the entities from the example document.

# %%
document.ents
# Out:
# (﻿INTRODUCCION,
#  ECONOMÍA POLÍTICA,
#  El sombrío Prudhon,
#  imbuído,
#  Santos
#  Padres de la Iglesia,
#  teorías,
#  La industria,
#  VACA-GUZMAN,
#  OASIS EN,
#  AUTORA,
#  Mauricio Ridel,
#  Fin,
#  Mauricio,
#  copas de los árboles,
#  Enrique,
#  María,
#  Catorce horas,
#  Un poco de sueño,
#  Mauricio,
#  Diez horas! ¡Ah!,
#  Redaccion,
#  Emilio,
#  Sábelo,
#  Mauricio,
#  Regente,
#  Suma: ¡catorce horas!...
#  ¡Adios,
#  fariseo.--,
#  Mauricio,
#  Emilio,
#  ánsia,
#  Mauricio,
#  Uncido,
#  En los teatros,
#  Enigma,
#  Emilio,
#  Mauricio,
#  Cárlos Ridel,
#  ¡Madrastra!,
#  Siempre espiados por la
#  mirada,
#  Mauricio,
#  Víctima de una semejanza,
#  Europa,
#  Francia,
#  Paris,
#  sábio Blain,
#  Colombe,
#  Los exámenes,
#  Sagrado Libro,
#  Mauricio,
#  Mr,
#  Blain,
#  Colombe,
#  Notre Dame du bon Secour,
#  Envíaselo dentro de
#  tu primera,
#  La hora,
#  Colombe,
#  La luz de un lejano,
#  Sonrióle,
#  Colombe,
#  Besó la santa imágen,
#  guardóla,
#  Mauricio,
#  A la
#  inquieta turbulencia del niño,
#  Mauricio,
#  Allá,
#  Mauricio,
#  Mauricio,
#  Suscribíala,
#  Buenos Aires,
#  otro--decíale,
#  Cárlos,
#  Ridel,
#  Mauricio Ridel,
#  Ridel,
#  réstame,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Paris,
#  consagróse,
#  Frecuentó la Sorbona,
#  Institutos,
#  Arrojóse,
#  Paris,
#  Ensayó,
#  Valerio--su,
#  Mauricio,
#  Mauricio,
#  Europa,
#  Sagrado Libro,
#  No importa: las frases,
#  Mauricio,
#  Buenos Aires,
#  Vd.,
#  sócio bribon,
#  sócio,
#  Ridel,
#  Cárlos Ridel,
#  Silenciosa,
#  subióse,
#  Mauricio,
#  Juez,
#  Cárlos Ridel,
#  honor--escribía á,
#  Mauricio,
#  Victoria,
#  Cuyo,
#  El Rosal,
#  Había,
#  El regreso,
#  Además,
#  Buenos Aires,
#  Vd.,
#  Mauricio,
#  apresuróse,
#  Mauricio,
#  Francia,
#  sábio Blain,
#  Colombe,
#  Paris,
#  Mauricio,
#  Diciembre,
#  El pobre niño,
#  Tenía
#  frio,
#  Lloraba,
#  Acojido,
#  abrióse,
#  Burdeos,
#  Senegal,
#  Pouillac,
#  Mauricio,
#  Plata,
#  Sr. Santa Coloma,
#  Vice-Cónsul Argentino,
#  Burdeos,
#  cariñosa
#  conmiseracion,
#  Buenos Aires,
#  Deploró,
#  Providencia,
#  amengua,
#  Vd,
#  Buenos Aires,
#  Su padre,
#  Buenos Aires,
#  Julia,
#  Rio Janeiro,
#  La pobre niña,
#  Rendidos,
#  Buenos Aires,
#  Además,
#  Julia Lopez,
#  Pero, hijo mio,
#  Pouillac,
#  Escríbame,
#  Por su parte,
#  Dios,
#  Mauricio,
#  Burdeos,
#  Pouillac,
#  Mauricio,
#  Lejos del tumulto,
#  Julia Lopez,
#  Mauricio,
#  Mauricio,
#  Pouillac,
#  Pouillac,
#  exhalóse,
#  La campana del comedor,
#  Mauricio,
#  Mauricio,
#  Julia
#  Lopez,
#  Vice-Cónsul Argentino,
#  Burdeos,
#  Mauricio,
#  Senegal,
#  Rio Janeiro,
#  Mauricio,
#  léjos,
#  Vice-Cónsul,
#  Mauricio,
#  Senegal,
#  Balizas Exteriores,
#  ánsia,
#  Nada más,
#  extraño,
#  Avenida Montes de Oca,
#  señor?--preguntó el automedon,
#  Mauricio,
#  amargura.--Sí,
#  Gran Hotel,
#  Gran Hotel,
#  Lleve Vd.,
#  Gran Hotel?,
#  Reconquista,
#  Mauricio,
#  Avenida Montes de Oca,
#  Buenos Aires,
#  la India,
#  Compañía de Seguros «,
#  Buenos Aires,
#  Mauricio,
#  Grutas,
#  habríanle,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Buenos Aires,
#  Ofrecióle,
#  Mauricio,
#  Mauricio,
#  madame Bazan,
#  Contento de esta circunstancia,
#  Madame Bazan,
#  Mauricio,
#  Mi
#  pensionado,
#  Capricho,
#  Port Royal,
#  Pero--insistió Mauricio--mi querida madame,
#  Pero ¿qué hacer?,
#  Son veinte,
#  madame Bazan,
#  Mauricio,
#  La seccion jóven,
#  zaguan,
#  Mauricio,
#  damasco azul,
#  Mauricio,
#  madame Bazan,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Steinway,
#  Julieta,
#  Mauricio,
#  Senegal,
#  Pouillac,
#  Rio Janeiro,
#  Mauricio,
#  Ora,
#  Julieta,
#  Mauricio,
#  Mauricio,
#  Julieta,
#  Mauricio,
#  Mauricio,
#  .......
#  ,
#  Paris,
#  Renata,
#  ¿Sabe Vd.,
#  Jesucristo,
#  Renata,
#  madame,
#  Paris,
#  Aquí unos hablan el francés,
#  Como parisienses muy pocos,
#  Barrieres,
#  El señor habla,
#  Mr,
#  Ribeaumont,
#  Le Courrier de la Plata,
#  Le Courrier de la Plata»!,
#  A mí me encantan los libros,
#  Mi
#  madre,
#  madame Arnaud,
#  Valois,
#  Yo les guardaba las novelas,
#  Paris,
#  Le Petit Journal,
#  Mauricio,
#  Renata,
#  Mauricio,
#  astrakan,
#  Cienfuegos,
#  Wort,
#  Bowctlaw,
#  Renata déme Vd.,
#  Gracias,
#  Julia Lopez,
#  servidora.--
#
#  Mauricio,
#  La Estacion,
#  --He,
#  Renata,
#  Renata,
#  Julia,
#  .......
#  ,
#  mi hijita,
#  Renata haga Vd.,
#  Alicia,
#  Así, ¿vés?,
#  Toilette,
#  La
#  túnica griega,
#  .....
#  ,
#  Ayer la llevé,
#  Por más señas,
#  Simula,
#  Producto de la Confitería
#  del Lampo,
#  Qué manos mágicas,
#  Entre ellas,
#  Partiano,
#  Mauricio,
#  damasco
#  azul,
#  Mauricio,
#  Nosotras,
#  Renata,
#  lábio,
#  tocado.--
#
#  ¡Nada! Mauricio,
#  Un cachito de pan,
#  Jesús,
#  Mauricio,
#  La astuta camarera,
#  Fruslerías,
#  Mauricio,
#  Porque, señor,
#  --El señor me favorece,
#  Pero en verdad,
#  Un jóven se
#  encuentra solo,
#  A fé mia,
#  --Ya,
#  Mauricio,
#  Julia
#  Lopez,
#  Risas,
#  Dios,
#  Rosita,
#  Mauricio,
#  Perdóneme el arte esta
#  blasfemia,
#  Rosita,
#  Emancipacion de la Mujer,
#  Zeballos,
#  El otro dia,
#  Cristo,
#  Caná,
#  Santos Evangelios,
#  San Juan,
#  Jesús,
#  Oyóse,
#  Alicia,
#  Jesús,
#  Jesús,
#  criados:--«Haced,
#  Jesús,
#  Cámara,
#  al--«Creced,
#  Génesis,
#  Córdoba,
#  Nada en él,
#  Recorramos,
#  Emilio Castelar,
#  Risas,
#  Dios,
#  Laurencia,
#  fuerza.--,
#  allí--Ya sé--Ya,
#  Usted,
#  calle de
#  Esmeralda,
#  Sin embargo,
#  Yo no podía sufrir,
#  Hace daño el espectáculo de
#  tales desequilibrios,
#  Aquel eterno contrariar,
#  Fué pocos dias,
#  Salía,
#  --De,
#  Julia Lopez,
#  Julia?
#
#  --Yo,
#  Todo humano,
#  Creador,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  apresuróse,
#  Mauricio,
#  Rusia,
#  --Hé,
#  Mauricio,
#  El album,
#  Sanabria,
#  Sanabria,
#  Para poner á sus anchas,
#  Sociedad de Señoras de la Misericordia,
#  Hermanas del Huerto,
#  Zárate,
#  Jesús,
#  Madre,
#  la Ley,
#  Señora,
#  Ley,
#  Señor Jesucristo,
#  Mauricio,
#  Mauricio,
#  Un cerco de viñetas,
#  Vestida de negro,
#  Mauricio,
#  Pouillac,
#  Rio Janeiro,
#  Gritos de alarma,
#  Vuelto de su abstraccion,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Renata,
#  Mauricio,
#  Mauricio,
#  La distinguiría entre mil otras manos
#  bellas,
#  Pouillac,
#  Mauricio,
#  una--¡Quietud,
#  Mauricio,
#  dulce
#  conmiseracion,
#  Mauricio,
#  Esa inmovilidad,
#  Esta noche haré,
#  Julia,
#  Mauricio,
#  Sin él nos
#  habrían degollado aquellos desalmados,
#  Ido,
#  formóse,
#  Julia,
#  Mauricio,
#  Sanabria.--Yo,
#  Fernando B,
#  Fernando B,
#  Barcelona,
#  Valencia,
#  Sevilla,
#  Encantados,
#  Carmencita,
#  Madrid,
#  Corte,
#  Reemplazaban,
#  Julia,
#  Mauricio,
#  Julia,
#  constituian,
#  Querer,
#  Laurencia,
#  Julia,
#  Hablemos de otra cosa,
#  Mauricio,
#  Julia,
#  Mauricio,
#  Renata,
#  Vaya V.,
#  Confitería,
#  La Gema,
#  Al volver, compre Vd.,
#  Porque el hielo
#  dentro del líquido,
#  La Gema,
#  Baez,
#  Director,
#  Mauricio,
#  Grande,
#  Director rió del chiste,
#  Mauricio,
#  Julia,
#  Julia,
#  Mauricio,
#  Director,
#  Sonrió,
#  convalecencias--añadió,
#  Sanabria,
#  Mauricio--jamás,
#  Señoras,
#  Julia,
#  Julia?,
#  Magnífico... Veamos,
#  Mauricio,
#  Mañana,
#  Julia,
#  --¡Ah!--respondió Julia,
#  Julia,
#  Mauricio,
#  siempre?--demandó,
#  Mauricio,
#  Mauricio,
#  Julia,
#  Mauricio,
#  --He,
#  bendicion.--,
#  Mauricio,
#  Ovidio,
#  Mauricio,
#  Razon,
#  Dios!,
#  Las viejas,
#  Mauricio,
#  figurin,
#  La Estacion,
#  Julieta,
#  Julia,--pero,
#  La campana del comedor,
#  Mauricio,
#  Renata,
#  Armada,
#  Dios!--exclamó--He,
#  Vd.,
#  Julia,
#  Mauricio,
#  Oyóse,
#  madame Bazan,
#  Mauricio,
#  Mauricio,
#  Emilio,
#  Julia,
#  Mauricio,
#  Mauricio,
#  Emilio á Mauricio,
#  Quizá es de,
#  Francia,
#  Mauricio,
#  Correo,
#  Mauricio,
#  Mauricio,
#  Mauricio,
#  Cárlos Ridel,
#  Cárlos Ridel,
#  128 Rivadavia,
#  Perplejo,
#  Coll--leyó,
#  Mauricio,
#  Eduardo M. Coll,
#  Gerente de «La Buenos Aires,
#  Compañía de Seguros,
#  Emilio N. Casares,
#  Gerente,
#  Mauricio Ridel,
#  Gerente,
#  Cárlos Ridel,
#  Compañía,
#  Ridel,
#  Veremos,
#  Directorio,
#  Cárlos Ridel,
#  Gerente de «La Buenos Aires,
#  Banco Nacional,
#  La Prensa,
#  Acudió el Gerente,
#  Cárlos Ridel,
#  Junio,
#  Compañía de Seguros «,
#  Buenos Aires,
#  Cárlos Ridel,
#  Mauricio,
#  Cárlos,
#  Ridel,
#  Buenos Aires,
#  Mauricio,
#  Ridel,
#  hélo,
#  Tengo,
#  Compañías,
#  Seguros,
#  Mauricio,
#  Julia,
#  Capilla de Nuestra Señora de las Victorias,
#  Llenábala,
#  pareja!--decían,
#  Escucha.--,
#  Cendrillon,
#  general
#  Mitre,
#  Bartolito,
#  Dávila,
#  Lainez,
#  Vedia,
#  Laurencena,
#  Lalanne,
#  Walls,
#  Ribaumont,
#  Ortega,
#  Alberú,
#  Mulhall,
#  Eduardo Coll,
#  Emilio Casares,
#  régio,
#  Sarmiento,
#  Santiago Estrada,
#  José María
#  Zuviría,
#  Bolivia,
#  Vaca Guzman,
#  Pera,
#  uncion,
#  Libres,
#  Dios,
#  Abraham,
#  Compañías,
#  Seguros,
#  Altísimo os,
#  El novio estrechando con efusion,
#  Coll,
#  pasageros!--ordenó,
#  pasageros!--repitió--¿Dónde,
#  Francia,
#  La jóven exhaló un gemido)

# %% [markdown]
# Each of the named entities in `document.ents` contains [more information about itself](https://spacy.io/usage/linguistic-features#accessing), which we can access by iterating through the `document.ents` with a simple `for` loop.
#
# For each `named_entity` in `document.ents`, we will extract the `named_entity` and its corresponding `named_entity.label_`.

# %%
for named_entity in document.ents:
    print(named_entity, named_entity.label_)
# Out:
# INTRODUCCION MISC
# ECONOMÍA POLÍTICA MISC
# El sombrío Prudhon MISC
# imbuído LOC
# Santos
# Padres de la Iglesia ORG
# teorías PER
# La industria MISC
# VACA-GUZMAN ORG
# OASIS EN ORG
# AUTORA ORG
# Mauricio Ridel PER
# Fin MISC
# Mauricio LOC
# copas de los árboles MISC
# Enrique PER
# María PER
# Catorce horas MISC
# Un poco de sueño MISC
# Mauricio LOC
# Diez horas! ¡Ah! MISC
# Redaccion MISC
# Emilio PER
# Sábelo LOC
# Mauricio LOC
# Regente PER
# Suma: ¡catorce horas!...
# ¡Adios MISC
# fariseo.-- MISC
# Mauricio LOC
# Emilio PER
# ánsia LOC
# Mauricio PER
# Uncido PER
# En los teatros MISC
# Enigma MISC
# Emilio PER
# Mauricio LOC
# Cárlos Ridel PER
# ¡Madrastra! MISC
# Siempre espiados por la
# mirada MISC
# Mauricio PER
# Víctima de una semejanza MISC
# Europa LOC
# Francia LOC
# Paris PER
# sábio Blain PER
# Colombe LOC
# Los exámenes MISC
# Sagrado Libro MISC
# Mauricio PER
# Mr PER
# Blain PER
# Colombe PER
# Notre Dame du bon Secour LOC
# Envíaselo dentro de
# tu primera MISC
# La hora MISC
# Colombe LOC
# La luz de un lejano MISC
# Sonrióle PER
# Colombe PER
# Besó la santa imágen MISC
# guardóla PER
# Mauricio LOC
# A la
# inquieta turbulencia del niño MISC
# Mauricio LOC
# Allá MISC
# Mauricio PER
# Mauricio PER
# Suscribíala LOC
# Buenos Aires LOC
# otro--decíale MISC
# Cárlos PER
# Ridel PER
# Mauricio Ridel PER
# Ridel PER
# réstame PER
# Mauricio LOC
# Mauricio PER
# Mauricio LOC
# Paris PER
# consagróse PER
# Frecuentó la Sorbona MISC
# Institutos LOC
# Arrojóse PER
# Paris PER
# Ensayó MISC
# Valerio--su PER
# Mauricio LOC
# Mauricio LOC
# Europa LOC
# Sagrado Libro MISC
# No importa: las frases MISC
# Mauricio LOC
# Buenos Aires LOC
# Vd. PER
# sócio bribon PER
# sócio PER
# Ridel PER
# Cárlos Ridel PER
# Silenciosa MISC
# subióse PER
# Mauricio PER
# Juez ORG
# Cárlos Ridel PER
# honor--escribía á LOC
# Mauricio LOC
# Victoria LOC
# Cuyo LOC
# El Rosal LOC
# Había PER
# El regreso MISC
# Además LOC
# Buenos Aires LOC
# Vd. MISC
# Mauricio PER
# apresuróse PER
# Mauricio PER
# Francia LOC
# sábio Blain PER
# Colombe PER
# Paris PER
# Mauricio PER
# Diciembre PER
# El pobre niño MISC
# Tenía
# frio MISC
# Lloraba PER
# Acojido PER
# abrióse PER
# Burdeos LOC
# Senegal LOC
# Pouillac ORG
# Mauricio LOC
# Plata LOC
# Sr. Santa Coloma PER
# Vice-Cónsul Argentino PER
# Burdeos LOC
# cariñosa
# conmiseracion PER
# Buenos Aires LOC
# Deploró LOC
# Providencia LOC
# amengua LOC
# Vd PER
# Buenos Aires LOC
# Su padre MISC
# Buenos Aires LOC
# Julia PER
# Rio Janeiro LOC
# La pobre niña MISC
# Rendidos PER
# Buenos Aires LOC
# Además PER
# Julia Lopez PER
# Pero, hijo mio MISC
# Pouillac ORG
# Escríbame MISC
# Por su parte MISC
# Dios MISC
# Mauricio LOC
# Burdeos LOC
# Pouillac ORG
# Mauricio LOC
# Lejos del tumulto MISC
# Julia Lopez PER
# Mauricio PER
# Mauricio PER
# Pouillac ORG
# Pouillac LOC
# exhalóse PER
# La campana del comedor MISC
# Mauricio PER
# Mauricio LOC
# Julia
# Lopez PER
# Vice-Cónsul Argentino ORG
# Burdeos LOC
# Mauricio LOC
# Senegal LOC
# Rio Janeiro LOC
# Mauricio LOC
# léjos LOC
# Vice-Cónsul PER
# Mauricio LOC
# Senegal LOC
# Balizas Exteriores LOC
# ánsia LOC
# Nada más MISC
# extraño MISC
# Avenida Montes de Oca LOC
# señor?--preguntó el automedon PER
# Mauricio PER
# amargura.--Sí PER
# Gran Hotel LOC
# Gran Hotel LOC
# Lleve Vd. MISC
# Gran Hotel? LOC
# Reconquista MISC
# Mauricio PER
# Avenida Montes de Oca LOC
# Buenos Aires LOC
# la India LOC
# Compañía de Seguros « ORG
# Buenos Aires LOC
# Mauricio LOC
# Grutas LOC
# habríanle PER
# Mauricio PER
# Mauricio PER
# Mauricio LOC
# Mauricio LOC
# Buenos Aires LOC
# Ofrecióle MISC
# Mauricio LOC
# Mauricio LOC
# madame Bazan PER
# Contento de esta circunstancia MISC
# Madame Bazan PER
# Mauricio PER
# Mi
# pensionado MISC
# Capricho PER
# Port Royal LOC
# Pero--insistió Mauricio--mi querida madame MISC
# Pero ¿qué hacer? MISC
# Son veinte MISC
# madame Bazan PER
# Mauricio LOC
# La seccion jóven MISC
# zaguan LOC
# Mauricio PER
# damasco azul PER
# Mauricio LOC
# madame Bazan PER
# Mauricio PER
# Mauricio LOC
# Mauricio PER
# Mauricio PER
# Steinway MISC
# Julieta MISC
# Mauricio LOC
# Senegal LOC
# Pouillac ORG
# Rio Janeiro LOC
# Mauricio PER
# Ora LOC
# Julieta MISC
# Mauricio PER
# Mauricio LOC
# Julieta MISC
# Mauricio LOC
# Mauricio LOC
# .......
#
#  MISC
# Paris PER
# Renata PER
# ¿Sabe Vd. MISC
# Jesucristo PER
# Renata PER
# madame MISC
# Paris LOC
# Aquí unos hablan el francés MISC
# Como parisienses muy pocos MISC
# Barrieres PER
# El señor habla MISC
# Mr MISC
# Ribeaumont LOC
# Le Courrier de la Plata PER
# Le Courrier de la Plata»! MISC
# A mí me encantan los libros MISC
# Mi
# madre MISC
# madame Arnaud PER
# Valois LOC
# Yo les guardaba las novelas MISC
# Paris PER
# Le Petit Journal MISC
# Mauricio PER
# Renata PER
# Mauricio LOC
# astrakan PER
# Cienfuegos LOC
# Wort LOC
# Bowctlaw LOC
# Renata déme Vd. PER
# Gracias LOC
# Julia Lopez PER
# servidora.--
#
# Mauricio MISC
# La Estacion MISC
# --He MISC
# Renata PER
# Renata PER
# Julia PER
# .......
#
#  MISC
# mi hijita PER
# Renata haga Vd. PER
# Alicia PER
# Así, ¿vés? MISC
# Toilette MISC
# La
# túnica griega MISC
# .....
#
#  PER
# Ayer la llevé MISC
# Por más señas MISC
# Simula MISC
# Producto de la Confitería
# del Lampo PER
# Qué manos mágicas MISC
# Entre ellas MISC
# Partiano LOC
# Mauricio LOC
# damasco
# azul PER
# Mauricio PER
# Nosotras MISC
# Renata PER
# lábio PER
# tocado.--
#
# ¡Nada! Mauricio MISC
# Un cachito de pan MISC
# Jesús PER
# Mauricio LOC
# La astuta camarera MISC
# Fruslerías LOC
# Mauricio LOC
# Porque, señor MISC
# --El señor me favorece MISC
# Pero en verdad MISC
# Un jóven se
# encuentra solo MISC
# A fé mia MISC
# --Ya PER
# Mauricio LOC
# Julia
# Lopez PER
# Risas PER
# Dios MISC
# Rosita MISC
# Mauricio PER
# Perdóneme el arte esta
# blasfemia MISC
# Rosita MISC
# Emancipacion de la Mujer PER
# Zeballos PER
# El otro dia MISC
# Cristo PER
# Caná PER
# Santos Evangelios ORG
# San Juan LOC
# Jesús PER
# Oyóse PER
# Alicia PER
# Jesús PER
# Jesús PER
# criados:--«Haced MISC
# Jesús PER
# Cámara LOC
# al--«Creced ORG
# Génesis MISC
# Córdoba LOC
# Nada en él
#  MISC
# Recorramos MISC
# Emilio Castelar PER
# Risas PER
# Dios MISC
# Laurencia LOC
# fuerza.-- MISC
# allí--Ya sé--Ya PER
# Usted PER
# calle de
# Esmeralda LOC
# Sin embargo MISC
# Yo no podía sufrir MISC
# Hace daño el espectáculo de
# tales desequilibrios MISC
# Aquel eterno contrariar MISC
# Fué pocos dias MISC
# Salía PER
# --De MISC
# Julia Lopez PER
# Julia?
#
# --Yo PER
# Todo humano MISC
# Creador PER
# Mauricio PER
# Mauricio LOC
# Mauricio PER
# Mauricio PER
# apresuróse PER
# Mauricio LOC
# Rusia LOC
# --Hé PER
# Mauricio LOC
# El album MISC
# Sanabria LOC
# Sanabria LOC
# Para poner á sus anchas MISC
# Sociedad de Señoras de la Misericordia ORG
# Hermanas del Huerto PER
# Zárate LOC
# Jesús PER
# Madre PER
# la Ley LOC
# Señora LOC
# Ley LOC
# Señor Jesucristo PER
# Mauricio LOC
# Mauricio PER
# Un cerco de viñetas MISC
# Vestida de negro MISC
# Mauricio PER
# Pouillac ORG
# Rio Janeiro LOC
# Gritos de alarma MISC
# Vuelto de su abstraccion MISC
# Mauricio LOC
# Mauricio PER
# Mauricio PER
# Mauricio LOC
# Mauricio PER
# Renata PER
# Mauricio PER
# Mauricio LOC
# La distinguiría entre mil otras manos
# bellas MISC
# Pouillac ORG
# Mauricio PER
# una--¡Quietud MISC
# Mauricio LOC
# dulce
# conmiseracion PER
# Mauricio LOC
# Esa inmovilidad MISC
# Esta noche haré MISC
# Julia PER
# Mauricio PER
# Sin él nos
# habrían degollado aquellos desalmados MISC
# Ido MISC
# formóse PER
# Julia PER
# Mauricio LOC
# Sanabria.--Yo PER
# Fernando B PER
# Fernando B MISC
# Barcelona LOC
# Valencia LOC
# Sevilla LOC
# Encantados PER
# Carmencita PER
# Madrid LOC
# Corte ORG
# Reemplazaban MISC
# Julia PER
# Mauricio PER
# Julia PER
# constituian PER
# Querer PER
# Laurencia LOC
# Julia PER
# Hablemos de otra cosa MISC
# Mauricio PER
# Julia PER
# Mauricio LOC
# Renata PER
# Vaya V. PER
# Confitería MISC
# La Gema MISC
# Al volver, compre Vd. MISC
# Porque el hielo
# dentro del líquido MISC
# La Gema MISC
# Baez PER
# Director MISC
# Mauricio PER
# Grande LOC
# Director rió del chiste MISC
# Mauricio LOC
# Julia PER
# Julia PER
# Mauricio LOC
# Director PER
# Sonrió PER
# convalecencias--añadió MISC
# Sanabria LOC
# Mauricio--jamás ORG
# Señoras MISC
# Julia PER
# Julia? PER
# Magnífico... Veamos MISC
# Mauricio PER
# Mañana PER
# Julia PER
# --¡Ah!--respondió Julia MISC
# Julia PER
# Mauricio LOC
# siempre?--demandó ORG
# Mauricio LOC
# Mauricio PER
# Julia PER
# Mauricio PER
# --He LOC
# bendicion.-- LOC
# Mauricio PER
# Ovidio PER
# Mauricio LOC
# Razon PER
# Dios! MISC
# Las viejas MISC
# Mauricio LOC
# figurin PER
# La Estacion MISC
# Julieta MISC
# Julia,--pero LOC
# La campana del comedor MISC
# Mauricio PER
# Renata PER
# Armada ORG
# Dios!--exclamó--He LOC
# Vd. MISC
# Julia PER
# Mauricio LOC
# Oyóse PER
# madame Bazan PER
# Mauricio LOC
# Mauricio PER
# Emilio PER
# Julia PER
# Mauricio PER
# Mauricio PER
# Emilio á Mauricio PER
# Quizá es de MISC
# Francia LOC
# Mauricio LOC
# Correo ORG
# Mauricio LOC
# Mauricio LOC
# Mauricio PER
# Cárlos Ridel PER
# Cárlos Ridel PER
# 128 Rivadavia LOC
# Perplejo LOC
# Coll--leyó PER
# Mauricio LOC
# Eduardo M. Coll PER
# Gerente de «La Buenos Aires MISC
# Compañía de Seguros ORG
# Emilio N. Casares PER
# Gerente LOC
# Mauricio Ridel PER
# Gerente MISC
# Cárlos Ridel PER
# Compañía ORG
# Ridel PER
# Veremos MISC
# Directorio LOC
# Cárlos Ridel PER
# Gerente de «La Buenos Aires MISC
# Banco Nacional ORG
# La Prensa MISC
# Acudió el Gerente PER
# Cárlos Ridel PER
# Junio LOC
# Compañía de Seguros « ORG
# Buenos Aires LOC
# Cárlos Ridel PER
# Mauricio PER
# Cárlos PER
# Ridel PER
# Buenos Aires LOC
# Mauricio PER
# Ridel PER
# hélo PER
# Tengo MISC
# Compañías ORG
# Seguros ORG
# Mauricio PER
# Julia PER
# Capilla de Nuestra Señora de las Victorias LOC
# Llenábala LOC
# pareja!--decían PER
# Escucha.-- PER
# Cendrillon PER
# general
# Mitre PER
# Bartolito PER
# Dávila PER
# Lainez PER
# Vedia LOC
# Laurencena LOC
# Lalanne LOC
# Walls MISC
# Ribaumont LOC
# Ortega LOC
# Alberú LOC
# Mulhall PER
# Eduardo Coll PER
# Emilio Casares PER
# régio PER
# Sarmiento PER
# Santiago Estrada PER
# José María
# Zuviría PER
# Bolivia LOC
# Vaca Guzman PER
# Pera PER
# uncion MISC
# Libres MISC
# Dios MISC
# Abraham PER
# Compañías ORG
# Seguros ORG
# Altísimo os MISC
# El novio estrechando con efusion MISC
# Coll PER
# pasageros!--ordenó PER
# pasageros!--repitió--¿Dónde PER
# Francia LOC
# La jóven exhaló un gemido MISC

# %% [markdown]
# To extract just the named entities that have been identified as `PER` (person), we can add a simple `if` statement into the mix:

# %%
for named_entity in document.ents:
    if named_entity.label_ == "PER":
        print(named_entity)
# Out:
# teorías
# Mauricio Ridel
# Enrique
# María
# Emilio
# Regente
# Emilio
# Mauricio
# Uncido
# Emilio
# Cárlos Ridel
# Mauricio
# Paris
# sábio Blain
# Mauricio
# Mr
# Blain
# Colombe
# Sonrióle
# Colombe
# guardóla
# Mauricio
# Mauricio
# Cárlos
# Ridel
# Mauricio Ridel
# Ridel
# réstame
# Mauricio
# Paris
# consagróse
# Arrojóse
# Paris
# Valerio--su
# Vd.
# sócio bribon
# sócio
# Ridel
# Cárlos Ridel
# subióse
# Mauricio
# Cárlos Ridel
# Había
# Mauricio
# apresuróse
# Mauricio
# sábio Blain
# Colombe
# Paris
# Mauricio
# Diciembre
# Lloraba
# Acojido
# abrióse
# Sr. Santa Coloma
# Vice-Cónsul Argentino
# cariñosa
# conmiseracion
# Vd
# Julia
# Rendidos
# Además
# Julia Lopez
# Julia Lopez
# Mauricio
# Mauricio
# exhalóse
# Mauricio
# Julia
# Lopez
# Vice-Cónsul
# señor?--preguntó el automedon
# Mauricio
# amargura.--Sí
# Mauricio
# habríanle
# Mauricio
# Mauricio
# madame Bazan
# Madame Bazan
# Mauricio
# Capricho
# madame Bazan
# Mauricio
# damasco azul
# madame Bazan
# Mauricio
# Mauricio
# Mauricio
# Mauricio
# Mauricio
# Paris
# Renata
# Jesucristo
# Renata
# Barrieres
# Le Courrier de la Plata
# madame Arnaud
# Paris
# Mauricio
# Renata
# astrakan
# Renata déme Vd.
# Julia Lopez
# Renata
# Renata
# Julia
# mi hijita
# Renata haga Vd.
# Alicia
# .....
#
#
# Producto de la Confitería
# del Lampo
# damasco
# azul
# Mauricio
# Renata
# lábio
# Jesús
# --Ya
# Julia
# Lopez
# Risas
# Mauricio
# Emancipacion de la Mujer
# Zeballos
# Cristo
# Caná
# Jesús
# Oyóse
# Alicia
# Jesús
# Jesús
# Jesús
# Emilio Castelar
# Risas
# allí--Ya sé--Ya
# Usted
# Salía
# Julia Lopez
# Julia?
#
# --Yo
# Creador
# Mauricio
# Mauricio
# Mauricio
# apresuróse
# --Hé
# Hermanas del Huerto
# Jesús
# Madre
# Señor Jesucristo
# Mauricio
# Mauricio
# Mauricio
# Mauricio
# Mauricio
# Renata
# Mauricio
# Mauricio
# dulce
# conmiseracion
# Julia
# Mauricio
# formóse
# Julia
# Sanabria.--Yo
# Fernando B
# Encantados
# Carmencita
# Julia
# Mauricio
# Julia
# constituian
# Querer
# Julia
# Mauricio
# Julia
# Renata
# Vaya V.
# Baez
# Mauricio
# Julia
# Julia
# Director
# Sonrió
# Julia
# Julia?
# Mauricio
# Mañana
# Julia
# Julia
# Mauricio
# Julia
# Mauricio
# Mauricio
# Ovidio
# Razon
# figurin
# Mauricio
# Renata
# Julia
# Oyóse
# madame Bazan
# Mauricio
# Emilio
# Julia
# Mauricio
# Mauricio
# Emilio á Mauricio
# Mauricio
# Cárlos Ridel
# Cárlos Ridel
# Coll--leyó
# Eduardo M. Coll
# Emilio N. Casares
# Mauricio Ridel
# Cárlos Ridel
# Ridel
# Cárlos Ridel
# Acudió el Gerente
# Cárlos Ridel
# Cárlos Ridel
# Mauricio
# Cárlos
# Ridel
# Mauricio
# Ridel
# hélo
# Mauricio
# Julia
# pareja!--decían
# Escucha.--
# Cendrillon
# general
# Mitre
# Bartolito
# Dávila
# Lainez
# Mulhall
# Eduardo Coll
# Emilio Casares
# régio
# Sarmiento
# Santiago Estrada
# José María
# Zuviría
# Vaca Guzman
# Pera
# Abraham
# Coll
# pasageros!--ordenó
# pasageros!--repitió--¿Dónde

# %% [markdown]
# ## NER with Long Texts or Many Texts

# %%
import math
number_of_chunks = 80

chunk_size = math.ceil(len(text) / number_of_chunks)

text_chunks = []

for number in range(0, len(text), chunk_size):
    text_chunk = text[number:number+chunk_size]
    text_chunks.append(text_chunk)

# %%
chunked_documents = list(nlp.pipe(text_chunks))

# %% [markdown]
# ## Get People

# %% [markdown]
# To extract and count the people, we will use an `if` statement that will pull out words only if their "ent" label matches "PER."

# %% [markdown]
# :::{admonition} Pandas Review
# :class: pandasreview
#  Do you need a refresher or introduction to the Python data analysis library Pandas? Be sure to check out <a href="https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Analysis/Pandas-Basics-Part1.html"> Pandas Basics (1-3) </a> in this textbook!
# :::

# %%
people = []

for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "PER":
            people.append(named_entity.text)

people_tally = Counter(people)

df = pd.DataFrame(people_tally.most_common(), columns=['character', 'count'])
df
# Out:
#                                 character  count
# 0                                Mauricio     52
# 1                                   Julia     17
# 2                            Cárlos Ridel      9
# 3                                  Renata      9
# 4                                   Paris      6
# 5                                   Ridel      6
# 6                                   Jesús      6
# 7                                  Emilio      4
# 8                             Julia Lopez      4
# 9                            madame Bazan      4
# 10                         Mauricio Ridel      3
# 11                                Colombe      3
# 12                            sábio Blain      2
# 13                                 Cárlos      2
# 14                             apresuróse      2
# 15                                 Alicia      2
# 16                                  Risas      2
# 17                                  Oyóse      2
# 18                                teorías      1
# 19                                Enrique      1
# 20                                  María      1
# 21                                      l      1
# 22                                Regente      1
# 23                                 Uncido      1
# 24                                   alma      1
# 25                                     Mr      1
# 26                                  Blain      1
# 27                               Sonrióle      1
# 28                               guardóla      1
# 29                                réstame      1
# 30                             consagróse      1
# 31                               Arrojóse      1
# 32                            Valerio--su      1
# 33                                    Vd.      1
# 34                           sócio bribon      1
# 35                                  sócio      1
# 36                                subióse      1
# 37                                  Había      1
# 38                              Diciembre      1
# 39                                    cio      1
# 40                                Lloraba      1
# 41                                Acojido      1
# 42                                abrióse      1
# 43                       Sr. Santa Coloma      1
# 44                  Vice-Cónsul Argentino      1
# 45                cariñosa\nconmiseracion      1
# 46                                     Vd      1
# 47                               Rendidos      1
# 48                                 Además      1
# 49                               exhalóse      1
# 50                           Julia\nLopez      1
# 51                            Vice-Cónsul      1
# 52          señor?--preguntó el automedon      1
# 53                          amargura.--Sí      1
# 54                              habríanle      1
# 55                                pitafio      1
# 56                                   cesa      1
# 57                           Madame Bazan      1
# 58                               Capricho      1
# 59                           damasco azul      1
# 60                             Jesucristo      1
# 61                              Barrieres      1
# 62                Le Courrier de la Plata      1
# 63                          madame Arnaud      1
# 64                               astrakan      1
# 65                        Renata déme Vd.      1
# 66                              mi hijita      1
# 67                        Renata haga Vd.      1
# 68                              .....\n\n      1
# 69   Producto de la Confitería\ndel Lampo      1
# 70                          damasco\nazul      1
# 71                                  lábio      1
# 72                                   --Ya      1
# 73                             Julia\nLop      1
# 74               Emancipacion de la Mujer      1
# 75                               Zeballos      1
# 76                                 Cristo      1
# 77                                   Caná      1
# 78                        Emilio Castelar      1
# 79                        allí--Ya sé--Ya      1
# 80                                  Usted      1
# 81                                  Salía      1
# 82                         Julia?\n\n--Yo      1
# 83                                Creador      1
# 84                                   --Hé      1
# 85                    Hermanas del Huerto      1
# 86                                  Madre      1
# 87                       Señor Jesucristo      1
# 88                   dulce\nconmiseracion      1
# 89                                formóse      1
# 90                          Sanabria.--Yo      1
# 91                             Fernando B      1
# 92                             Encantados      1
# 93                             Carmencita      1
# 94                            constituian      1
# 95                                 Querer      1
# 96                                Vaya V.      1
# 97                                   Baez      1
# 98                                    ino      1
# 99                               Director      1
# 100                                Sonrió      1
# 101                                    o.      1
# 102                                Julia?      1
# 103                                Mañana      1
# 104                                Ovidio      1
# 105                                 Razon      1
# 106                               figurin      1
# 107                                   Mau      1
# 108                                 ricio      1
# 109                     Emilio á Mauricio      1
# 110                    ardo M. Coll--leyó      1
# 111                       Eduardo M. Coll      1
# 112                     Emilio N. Casares      1
# 113                     Acudió el Gerente      1
# 114                                  hélo      1
# 115                       pareja!--decían      1
# 116                            Escucha.--      1
# 117                            Cendrillon      1
# 118                        general\nMitre      1
# 119                             Bartolito      1
# 120                                Dávila      1
# 121                                Lainez      1
# 122                               Mulhall      1
# 123                          Eduardo Coll      1
# 124                        Emilio Casares      1
# 125                                 régio      1
# 126                             Sarmiento      1
# 127                      Santiago Estrada      1
# 128                   José María\nZuviría      1
# 129                           Vaca Guzman      1
# 130                                  Pera      1
# 131                               Abraham      1
# 132                                  Coll      1
# 133                    pasageros!--ordenó      1
# 134           pasageros!--repitió--¿Dónde      1

# %% [markdown]
# ## Get Places

# %% [markdown]
# To extract and count places, we can follow the same model as above, except we will change our `if` statement to check for "ent" labels that match "LOC."

# %%
places = []
for document in chunked_documents:
    for named_entity in document.ents:
        if named_entity.label_ == "LOC":
            places.append(named_entity.text)

places_tally = Counter(places)

df = pd.DataFrame(places_tally.most_common(), columns=['place', 'count'])
df
# Out:
#                                          place  count
# 0                                     Mauricio     60
# 1                                 Buenos Aires     12
# 2                                      Francia      4
# 3                                      Burdeos      4
# 4                                      Senegal      4
# 5                                  Rio Janeiro      4
# 6                                     Sanabria      3
# 7                                        ánsia      2
# 8                                       Europa      2
# 9                                      Colombe      2
# 10                                  Gran Hotel      2
# 11                                  Ribeaumont      2
# 12                                   Laurencia      2
# 13                                     imbuído      1
# 14                                      Sábelo      1
# 15                          iencia de la vejez      1
# 16                    Notre Dame du bon Secour      1
# 17                                 Suscribíala      1
# 18                                  Institutos      1
# 19                           honor--escribía á      1
# 20                                    Victoria      1
# 21                                        Cuyo      1
# 22                                    El Rosal      1
# 23                                      Además      1
# 24                                       Plata      1
# 25                                     Deploró      1
# 26                                 Providencia      1
# 27                                     amengua      1
# 28                                    Pouillac      1
# 29                                       léjos      1
# 30                          Balizas Exteriores      1
# 31                       Avenida Montes de Oca      1
# 32                                 Gran Hotel?      1
# 33                                          Av      1
# 34                               Montes de Oca      1
# 35                                    la India      1
# 36                                      Grutas      1
# 37                                  Port Royal      1
# 38                                      zaguan      1
# 39                                         Ora      1
# 40                                       Paris      1
# 41                                      Valois      1
# 42                                  Cienfuegos      1
# 43                                        Wort      1
# 44                                    Bowctlaw      1
# 45                                     Gracias      1
# 46                                    Partiano      1
# 47                                  Fruslerías      1
# 48                                    San Juan      1
# 49                                      Cámara      1
# 50                                     Córdoba      1
# 51                         calle de\nEsmeralda      1
# 52                                       Rusia      1
# 53                                      Zárate      1
# 54                                      la Ley      1
# 55                                      Señora      1
# 56                                         Ley      1
# 57                                   Barcelona      1
# 58                                    Valencia      1
# 59                                     Sevilla      1
# 60                                      Madrid      1
# 61                                      Grande      1
# 62                                      uncion      1
# 63                                        --He      1
# 64                                bendicion.--      1
# 65                                Julia,--pero      1
# 66                          Dios!--exclamó--He      1
# 67                                        Maur      1
# 68                               128 Rivadavia      1
# 69                                    Perplejo      1
# 70                                     Gerente      1
# 71                                  Directorio      1
# 72                                       Junio      1
# 73  Capilla de Nuestra Señora de las Victorias      1
# 74                                   Llenábala      1
# 75                                       Vedia      1
# 76                                  Laurencena      1
# 77                                     Lalanne      1
# 78                                   Ribaumont      1
# 79                                      Ortega      1
# 80                                      Alberú      1
# 81                                     Bolivia      1

# %% [markdown]
# ## Get NER in Context

# %%
from IPython.display import Markdown, display
import re

def get_ner_in_context(keyword, document, desired_ner_labels= False):
    
    if desired_ner_labels != False:
        desired_ner_labels = desired_ner_labels
    else:
         # all possible labels
        desired_ner_labels = list(nlp.get_pipe('ner').labels)  
        
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        #process each sentence
        sentence_doc = nlp(sentence.text)
        for named_entity in sentence_doc.ents:
            #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
            if keyword.lower() in named_entity.text.lower()  and named_entity.label_ in desired_ner_labels:
                #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
                #sentence_text = sentence.text
            
                sentence_text = re.sub('\n', ' ', sentence.text)
                sentence_text = re.sub(f"{named_entity.text}", f"**{named_entity.text}**", sentence_text, flags=re.IGNORECASE)

                print('---')
                display(Markdown(f"**{named_entity.label_}**"))
                display(Markdown(sentence_text))

# %%
for document in chunked_documents:
    get_ner_in_context('Francia', document)
# Out:
# ---
# **LOC**
# Aunque del hogar de sus padres, el pobre niño, solo guardara crueles recuerdos, la lengua materna, el suelo de la patria, su aire, su luz, éranle necesarios, y languideció, echándolos de menos.  Por dicha suya fué el «bello país de **Francia**,» la hospitalaria Paris, el lugar de su destierro.
# ---
# **LOC**
# Sin embargo, Mauricio amaba tambien la **Francia**.
