# %% [markdown]
# # Text Pre-Processing for Spanish

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is authored by <a href="https://dlcl.stanford.edu/people/quinn-dombrowski/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# This notebook is for anyone who wants to try the [TF-IDF](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/TF-IDF.html) or [topic modeling](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Text-Analysis/Topic-Modeling.html) lessons on Spanish texts. Before continuing with those lessons, you need to create a *lemmatized derivative* of your original Spanish text, which replaces all the words with their dictionary form, which will work much better with the word-count based methods.

# %% [markdown]
# ## Install spaCy

# %%
# !pip install -U spacy

# %% [markdown]
# ## Download Language Model

# %%
# !python -m spacy download es_core_news_md

# %% [markdown]
# ## Import Libraries

# %%
import spacy

# %% [markdown]
# ## Load Language Model
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# 1. We can import the model as a module and then load it from the module.

# %%
import es_core_news_md
nlp = es_core_news_md.load()

# %% [markdown]
# 2. We can load the model by name.

# %%
#nlp = spacy.load('es_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it’s advisable to use Option 1. Then you can use the model immediately. Otherwise, you’ll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel… in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document
# To create a derivative text file that we can use with TF-IDF, topic modeling, or other word-count based methods, we need to use spaCy to *lemmatize* the text, replacing each word with its dictionary form. The result will be an ungrammatical text that will produce better results than the original version when used with word-count methods.
#
# The example text for Spanish is *Oasis en la vida* by Juana Manuela Gorriti [from Project Gutenberg](http://www.gutenberg.org/ebooks/62564).

# %%
filepath = '../texts/other-languages/es.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %%
outname = filepath.replace('.txt', '-lemmatized.txt')
with open(outname, 'w', encoding='utf8') as out:
    for token in document:
        out.write(token.lemma_.lower())
        out.write(' ')

# %% [markdown]
# ## Examine Differences
# The code cell below prints the original word in the text, a dash, then the lemmatized form that was written to the derivative text document that you'll use for TF-IDF and topic modeling. It's a good idea to take a look at this so you can see if there are places where the model consistently makes mistakes.
#
# For instance, an earlier version of spaCy often associated the Spanish preposition `para` 'for' with the verb `parar` 'to stop'. If you just took that derivative file and used it for TF-IDF or topic modeling without realizing what was happening, you might reach the surprising conclusion that "stop" is a very frequent word in your text, when actually it's lemmatization problem.

# %%
for token in document:
    print(token.text + ' - ' + token.lemma_)
# Out:
# ﻿INTRODUCCION - ﻿INTRODUCCION
# . - .
#
#
#
#  -
#
#
#
# ECONOMÍA - ECONOMÍA
# POLÍTICA - POLÍTICA
# . - .
#
#
#  -
#
#
# El - El
# sombrío - sombrío
# Prudhon - Prudhon
# , - ,
# imbuído - imbuído
# , - ,
# sin - sin
# duda - dudar
# , - ,
# en - en
# las - los
# ideas - ideo
# de - de
# los - lo
# Santos - Santos
#
#  -
#
# Padres - Padres
# de - de
# la - lo
# Iglesia - Iglesia
# que - que
# predicaban - predicar
# el - el
# desden - desden
# por - por
# los - lo
# bienes - bien
#
#  -
#
# terrenales - terrenal
# , - ,
# decía - decir
# que - que
# la - lo
# pobreza - pobreza
# es - ser
# una - uno
# ley - ley
# de - de
# nuestra - nuestro
# naturaleza - naturaleza
# , - ,
#
#  -
#
# ley - ley
# bajo - bajar
# la - lo
# cual - cual
# hemos - hemo
# sido - ser
# constituídos - constituídos
# , - ,
# de - de
# donde - donde
# se - se
# deduce - deducir
# que - que
# el - el
#
#  -
#
# pauperismo - pauperismo
# es - ser
# mal - mal
# que - que
# no - no
# tiene - tener
# remedio - remediar
# ni - ni
# cura - curar
# . - .
#
#
#  -
#
#
# Muy - Muy
# desconsolados - desconsolar
# debieron - deber
# quedar - quedar
# los - lo
# menesterosos - menesteroso
# con - con
# tan - tan
# ingrata - ingrato
#
#  -
#
# noticia - noticiar
# , - ,
# pero - pero
# la - lo
# actividad - actividad
# humana - humano
# , - ,
# que - que
# no - no
# siempre - siempre
# se - se
# lleva - llevar
# de - de
# teorías - teoría
# , - ,
#
#  -
#
# ha - haber
# venido - venir
# á - á
# confortar - confortar
# á - á
# los - lo
# aflijidos - aflijidos
# trayéndoles - trayéndoles
# más - más
# plausibles - plausible
# nuevas - nuevo
#
#  -
#
# y - y
# muy - muy
# eficaces - eficaz
# promesas - promesa
# . - .
# La - La
# industria - industriar
# , - ,
# con - con
# sus - su
# innúmeras - innúmero
# palancas - palanca
# de - de
#
#  -
#
# impulsion - impulsion
# ; - ;
# las - los
# ciencias - ciencia
# , - ,
# con - con
# sus - su
# multiplicados - multiplicar
# alfileres - alfiler
# de - de
# exámen - exámen
# ; - ;
# el - el
#
#  -
#
# cálculo - cálculo
# , - ,
# con - con
# su - su
# prevision - prevision
# y - y
# su - su
# aritmética - aritmético
# ; - ;
# todos - todo
# estos - este
# agentes - agente
# de - de
# la - lo
#
#  -
#
# vitalidad - vitalidad
# social - social
# , - ,
# han - haber
# venido - venir
# á - á
# operar - operar
# el - el
# milagro - milagro
# de - de
# la - lo
# multiplicacion - multiplicacion
#
#  -
#
# del - del
# pan - pan
# y - y
# el - el
# aumento - aumentar
# del - del
# vino - venir
# , - ,
# sustentando - sustentar
# anchamente - anchamente
# á - á
# los - lo
# hambrientos - hambriento
#
#  -
#
# y - y
# engordando - engordar
# , - ,
# hasta - hasta
# más - más
# no - no
# poder - poder
# , - ,
# á - á
# los - lo
# hartos - harto
# . - .
#
#
#  -
#
#
# La - La
# manera - manera
# de - de
# realizar - realizar
# el - el
# prodigio - prodigio
# lo - el
# ha - haber
# dado - dar
# á - á
# conocer - conocer
# esa - ese
# venerable - venerable
#
#  -
#
# matrona - matrona
# , - ,
# que - que
# los - lo
# entendidos - entendido
# en - en
# materias - materia
# graves - grave
# creo - creer
# que - que
# denominan - denominar
#
#  -
#
# _ - _
# Economía - Economía
# política - político
# _ - _
# . - .
# Esta - Esta
# tutriz - tutriz
# moralizadora - moralizador
# de - de
# la - lo
# sociedad - sociedad
# , - ,
#
#  -
#
# evidenciando - evidenciar
# la - lo
# fecundidad - fecundidad
# del - del
# trabajo - trabajar
# y - y
# los - lo
# beneficios - beneficio
# del - del
# ahorro - ahorrar
# , - ,
# se - se
#
#  -
#
# ha - haber
# propuesto - proponer
# dignificar - dignificar
# al - al
# hombre - hombre
# otorgándole - otorgándole
# los - lo
# medios - medio
# de - de
# sacudir - sacudir
# el - el
#
#  -
#
# vasallaje - vasallaje
# servil - servil
# de - de
# la - lo
# indigencia - indigencia
# . - .
#
#
#  -
#
#
# El - El
# ahorro - ahorrar
# , - ,
# tomando - tomar
# forma - formar
# colectiva - colectivo
# , - ,
# ha - haber
# dado - dar
# orígen - orígen
# á - á
# la - lo
# más - más
# preciosa - precioso
# de - de
#
#  -
#
# las - los
# combinaciones - combinación
# especulativas - especulativo
# : - :
# á - á
# la - lo
# que - que
# tiene - tener
# por - por
# objeto - objetar
# asegurar - asegurar
# el - el
#
#  -
#
# bienestar - bienestar
# individual - individual
# en - en
# vida - vida
# y - y
# garantir - garantir
# el - el
# porvenir - porvenir
# de - de
# los - lo
# que - que
# quedan - quedar
# , - ,
#
#  -
#
# despues - despues
# de - de
# concluida - concluir
# la - lo
# jornada - jornada
# . - .
#
#
#  -
#
#
# Este - Este
# tema - temer
# , - ,
# abstracto - abstracto
# de - de
# suyo - suyo
# , - ,
# y - y
# que - que
# parece - parecer
# ageno - ageno
# al - al
# dominio - dominio
# del - del
# arte - arte
# , - ,
#
#  -
#
# acaba - acabar
# de - de
# ser - ser
# desenvuelto - desenvolver
# por - por
# la - lo
# ilustre - ilustrar
# escritora - escritor
# cuyo - cuyo
# nombre - nombrar
# ocupa - ocupar
# tan - tan
#
#  -
#
# elevado - elevar
# rango - rango
# en - en
# la - lo
# gerarquía - gerarquía
# del - del
# movimiento - movimiento
# intelectual - intelectual
# americano - americano
# . - .
#
#
#  -
#
#
# Es - Es
# atributo - atributo
# de - de
# las - los
# inteligencias - inteligencia
# creadoras - creador
# trasformar - trasformar
# y - y
# embellecer - embellecer
#
#  -
#
# las - los
# ideas - ideo
# que - que
# pasan - pasar
# por - por
# su - su
# espíritu - espíritu
# ; - ;
# parece - parecer
# que - que
# poseyeran - poseer
# ese - ese
# don - don
#
#  -
#
# vivificador - vivificador
# de - de
# la - lo
# lujuriosa - lujurioso
# primavera - primavera
# que - que
# todo - todo
# lo - el
# hermosea - hermosear
# , - ,
# lo - el
# cubre - cubrir
# de - de
#
#  -
#
# flores - flor
# y - y
# lo - el
# esmalta - esmaltar
# de - de
# celajes - celaje
# . - .
#
#
#  -
#
#
# Por - Por
# si - si
# existe - existir
# incrédulo - incrédulo
# que - que
# ponga - poner
# en - en
# duda - dudar
# el - el
# aserto - aserto
# , - ,
# invoco - invocar
# por - por
#
#  -
#
# testigo - testigo
# , - ,
# en - en
# mi - mi
# abono - abonar
# , - ,
# el - el
# presente - presentar
# libro - librar
# . - .
#
#
#  -
#
#
# Su - Su
# autora - autor
# comprueba - comprobar
# , - ,
# bajo - bajar
# la - lo
# forma - formar
# atrayente - atrayente
# de - de
# la - lo
# novela - novelar
# , - ,
# los - lo
#
#  -
#
# beneficios - beneficio
# que - que
# reportan - reportar
# el - el
# trabajo - trabajar
# , - ,
# la - lo
# perseverancia - perseverancia
# y - y
# el - el
# ahorro - ahorrar
# ; - ;
# nunca - nunca
#
#  -
#
# un - uno
# tema - temer
# económico - económico
# ha - haber
# sido - ser
# tratado - tratar
# con - con
# más - más
# galanura - galanura
# , - ,
# con - con
# más - más
# gracia - gracia
#
#  -
#
# picarezca - picarezca
# , - ,
# ni - ni
# con - con
# más - más
# natural - natural
# é - é
# ingénua - ingénua
# intriga - intrigar
# . - .
#
#
#  -
#
#
# Despues - Despues
# de - de
# recorrer - recorrer
# este - este
# trozo - trozar
# de - de
# historia - historia
# social - social
# , - ,
# cuya - cuyo
# trama - tramar
# la - lo
# forman - formar
#
#  -
#
# las - los
# peripecias - peripecia
# de - de
# dos - do
# caractéres - caractéres
# nobles - noble
# y - y
# fuertes - fuerte
# , - ,
# se - se
# encuentra - encontrar
# no - no
# sé - ser
#
#  -
#
# qué - qué
# de - de
# consolatorio - consolatorio
# , - ,
# de - de
# purificador - purificador
# , - ,
# en - en
# medio - mediar
# de - de
# la - lo
# arenosa - arenoso
# senda - senda
# por - por
#
#  -
#
# donde - donde
# nos - no
# conduce - conducir
# diariamente - diariamente
# la - lo
# mano - manir
# de - de
# la - lo
# tristeza - tristeza
# . - .
#
#
#  -
#
#
# Si - Si
# la - lo
# mision - mision
# de - de
# los - lo
# cultores - cultores
# privilegiados - privilegiar
# del - del
# arte - arte
# es - ser
# la - lo
# de - de
# alentar - alentar
# , - ,
#
#  -
#
# la - lo
# de - de
# consolar - consolar
# , - ,
# la - lo
# de - de
# dilatar - dilatar
# el - el
# horizonte - horizonte
# de - de
# la - lo
# esperanza - esperanzar
# , - ,
# la - lo
#
#  -
#
# prestigiosa - prestigioso
# autora - autor
# de - de
# estas - este
# páginas - página
# ha - haber
# sabido - saber
# encerrar - encerrar
# en - en
# ellas - ellos
# , - ,
#
#  -
#
# suficientes - suficiente
# rayos - rayo
# de - de
# luz - luz
# para - parir
# satisfacer - satisfacer
# la - lo
# ansiedad - ansiedad
# de - de
# las - los
# almas - alma
#
#  -
#
# soñadoras - soñador
# , - ,
# y - y
# bastantes - bastante
# rosas - rosa
# para - parir
# coronar - coronar
# , - ,
# aunque - aunque
# ellos - ellos
# no - no
# lo - el
# quieran - querer
# , - ,
#
#  -
#
# la - lo
# adusta - adusto
# efigie - efigie
# de - de
# los - lo
# más - más
# hipocondriacos - hipocondríaco
# economistas - economista
# . - .
#
#
#                                                 -
#
#
# S. - S.
# VACA-GUZMAN - VACA-GUZMAN
# . - .
#
#
#      -
#
#
# Diciembre - Diciembre
# 22 - 22
# de - de
# 1887 - 1887
# . - .
#
#
#
#
#
#                        -
#
#
#
#
#
# OASIS - OASIS
# EN - EN
# LA - LA
# VIDA - VIDA
# . - .
#
#
#                       -
#
#
# Á - Á
# « - «
# LA - LA
# BUENOS - BUENOS
# AIRES - AIRES
# » - »
#
#
#                                        -
#
#
# _ - _
# LA - LA
# AUTORA - AUTORA
# . - .
# _ - _
#
#
#
#
#
#  -
#
#
#
#
#
# OASIS - OASIS
# EN - EN
# LA - LA
# VIDA - VIDA
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# I - I
#
#
#
#  -
#
#
#
# --¡Bah!--exclamó - --¡Bah!--exclamó
# Mauricio - Mauricio
# Ridel - Ridel
# , - ,
# arrojando - arrojar
# la - lo
# pluma - pluma
# despues - despues
# de - de
# escribir - escribir
#
#  -
#
# la - lo
# palabra - palabra
# Fin - Fin
# bajo - bajar
# la - lo
# última - último
# línea - líneo
# de - de
# una - uno
# cuartilla - cuartilla
# marcada - marcar
# con - con
# el - el
#
#  -
#
# guarismo - guarismo
# 60 - 60
# . - .
#
#
#  -
#
#
# --¿Qué - --¿Qué
# es - ser
# eso?--interrogó - eso?--interrogó
# un - uno
# jóven - jóven
# que - que
# escribía - escribir
# allí - allí
# cerca - cercar
# . - .
#
#
#  -
#
#
# --El - --El
# postrer - postrer
# párrafo - párrafo
# del - del
# folletin--respondió - folletin--respondió
# Mauricio - Mauricio
# , - ,
# alargando - alargar
# la - lo
#
#  -
#
# hoja - hoja
# á - á
# un - uno
# cajista - cajista
# que - que
# aguardaba - aguardar
# . - .
#
#
#  -
#
#
# --¡Cómo - --¡Cómo
# ! - !
# ¿ - ¿
# Mañana - Mañana
# acaba - acabar
# CHAMUSQUINAS - CHAMUSQUINAS
# DE - DE
# AMOR - AMOR
# ? - ?
# Hoy - Hoy
# quedaba - quedar
# su - su
# héroe - héroe
#
#  -
#
# en - en
# una - uno
# situacion - situacion
# extrema - extremo
# : - :
# la - lo
# mano - manir
# armada - armar
# de - de
# un - uno
# revólver - revólver
# , - ,
# esperando - esperar
#
#  -
#
# para - parir
# morir - morir
# el - el
# primer - ﻿1
# rayo - rayar
# de - de
# sol - sol
# ; - ;
# y - y
# ya - ya
# , - ,
# este - este
# comenzaba - comenzar
# á - á
# dorar - dorar
# las - los
#
#  -
#
# copas - copar
# de - de
# los - lo
# árboles - árbol
# ; - ;
# y - y
# al - al
# verlo - verlo
# , - ,
# « - «
# Enrique - Enrique
# apoya - apoyar
# el - el
# arma - armar
# contra - contra
# el - el
#
#  -
#
# corazon - corazon
# , - ,
# enviando - enviar
# á - á
# María - María
# su - su
# último - último
# pensamiento - pensamiento
# ; - ;
# á - á
# Dios - Dios
# su - su
# última - último
#
#  -
#
# plegaria - plegaria
# . - .
# »--¿Muere - »--¿Muere
# ? - ?
#
#
#  -
#
#
# --No - --No
# ; - ;
# porque--«De - porque--«De
# repente - repente
# , - ,
# un - uno
# brazo - brazo
# cariñoso - cariñoso
# rodeó - rodear
# su - su
# cuello - cuello
# ; - ;
# un - uno
# rostro - rostro
#
#  -
#
# pálido - pálido
# y - y
# mojado - mojar
# de - de
# lágrimas - lágrima
# se - se
# apoyó - apoyar
# en - en
# su - su
# rostro - rostro
# ... - ...
#
#
#  -
#
#
# --¡Perdon - --¡Perdon
# ! - !
#
#
#  -
#
#
# --¡Perdon!--se - --¡Perdon!--se
# oyó - oír
# á - á
# la - lo
# vez - vez
# ... - ...
#
#
#  -
#
#
# « - «
# Y - Y
# el - el
# primer - ﻿1
# rayo - rayar
# de - de
# sol - sol
# aguardado - aguardar
# como - comer
# una - uno
# señal - señal
# de - de
# muerte - muerte
# , - ,
# fué - fué
# la - lo
#
#  -
#
# aurora - aurora
# de - de
# su - su
# felicidad - felicidad
# » - »
# . - .
#
#
#  -
#
#
# --¡Bien - --¡Bien
# ! - !
# ¡ - ¡
# oh - oh
# ! - !
# ¡ - ¡
# Qué - Qué
# bien!--aplaudió - bien!--aplaudió
# el - el
# otro - otro
# ; - ;
# y - y
# añadió - añadir
# con - con
# dramático - dramático
#
#  -
#
# ademan - ademar
# : - :
#
#
#  -
#
#
# --¡Ah - --¡Ah
# ! - !
# que - que
# no - no
# haya - haber
# para - parir
# nosotros - nosotros
# , - ,
# párias - párias
# del - del
# destino - destinar
# , - ,
# ¡ - ¡
# un - uno
# rayo - rayar
# de - de
# sol - sol
#
#  -
#
# que - que
# venga - venir
# á - á
# redimirnos - redimirnos
# ! - !
#
#
#  -
#
#
# --Sí - --Sí
# : - :
# y - y
# más - más
# que - que
# uno - unir
# : - :
# dos--repuso - dos--repuso
# Mauricio.--La - Mauricio.--La
# resignacion - resignacion
# y - y
# el - el
# trabajo - trabajar
# . - .
#
#
#  -
#
#
# --¡La - --¡La
# resignacion - resignacion
# ! - !
# ¡ - ¡
# el - el
# trabajo!--replicó - trabajo!--replicó
# el - el
# interlocutor - interlocutor
# con - con
# forzada - forzar
#
#  -
#
# risa.--Solo - risa.--Solo
# tú - tú
# puedes - poder
# decir - decir
# eso - ese
# ; - ;
# tú - tú
# , - ,
# que - que
# no - no
# contento - contentar
# con - con
# la - lo
# tarea - tarea
#
#  -
#
# diaria - diario
# , - ,
# la - lo
# has - haber
# subido - subir
# á - á
# catorce - catorce
# horas - hora
# . - .
# Catorce - Catorce
# horas - hora
# , - ,
# pluma - pluma
# en - en
# mano - manir
# , - ,
#
#  -
#
# encorvado - encorvar
# sobre - sobrar
# la - lo
# implacable - implacable
# cuartilla - cuartilla
# , - ,
# y - y
# precisamente - precisamente
# , - ,
# apenas - apenar
# en - en
#
#  -
#
# convalecencia - convalecencia
# de - de
# la - lo
# terrible - terrible
# herida - herir
# que - que
# casi - casi
# te - te
# lleva - llevar
# al - al
# sepulcro - sepulcro
# . - .
#
#
#  -
#
#
# --Sin - --Sin
# embargo - embargar
# , - ,
# ya - ya
# lo - el
# vés - vés
# : - :
# estoy - estar
# sano - sanar
# y - y
# fuerte - fuerte
# . - .
# Un - Un
# poco - poco
# de - de
# sueño - soñar
# ; - ;
# á - á
#
#  -
#
# veces - vez
# , - ,
# un - uno
# poco - poco
# de - de
# fatiga - fatigar
# ; - ;
# pero - pero
# se - se
# piensa - pensar
# en - en
# el - el
# fin - fin
# propuesto - proponer
# , - ,
# y - y
# todo - todo
#
#  -
#
# eso - ese
# vuela - volar
# y - y
# se - se
# desvanece.-- - desvanece.--
#
#
#  -
#
#
# Hablando - Hablando
# así - asir
# , - ,
# Mauricio - Mauricio
# consultó - consultar
# su - su
# reloj - reloj
# . - .
#
#
#  -
#
#
# --Las - --Las
# siete--Y - siete--Y
# levantándose - levantándose
# , - ,
# fué - fué
# á - á
# tomar - tomar
# de - de
# una - uno
# percha - perchar
# su - su
# sombrero - sombrero
# . - .
#
#
#  -
#
#
# --¡Las - --¡Las
# siete - siete
# ! - !
# ¡ - ¡
# Con - Con
# qué - qué
# desenfado - desenfadar
# lo - el
# dices - decir
# ! - !
# ¿ - ¿
# Sabes - Sabes
# que - que
# has - haber
# estado - estar
#
#  -
#
# sentado - sentar
# ahí - ahí
# , - ,
# escribiendo - escribir
# desde - desde
# las - los
# nueve - nueve
# ? - ?
# ¡ - ¡
# Diez - Diez
# horas - hora
# ! - !
# ¡ - ¡
# Ah - Ah
# ! - !
# hombres - hombre
#
#  -
#
# como - comer
# este - este
# son - ser
# un - uno
# pésimo - malo
# ejemplo - ejemplo
# en - en
# la - lo
# Redaccion - Redaccion
# . - .
#
#
#  -
#
#
# --Y - --Y
# tú - tú
# , - ,
# que - que
# así - asir
# hablas - hablar
# , - ,
# querido - querer
# Emilio - Emilio
# , - ,
# eres - ser
# uno - unir
# de - de
# sus - su
# mejores - mejorar
# obreros - obrero
# . - .
#
#
#  -
#
#
# --A - --A
# más - más
# no - no
# poder - poder
# : - :
# Sábelo - Sábelo
# . - .
#
#
#  -
#
#
# --Notificado--dijo - --Notificado--dijo
# Mauricio - Mauricio
# , - ,
# sonriendo.--Ruégote - sonriendo.--Ruégote
# que - que
# al - al
# salir - salir
# digas - decir
# al - al
#
#  -
#
# Regente - Regente
# que - que
# me - me
# tenga - tener
# listas - listo
# las - los
# pruebas - prueba
# para - parir
# las - los
# once - once
# . - .
#
#
#  -
#
#
# --Y - --Y
# correccion - correccion
# hasta - hasta
# las - los
# dos - do
# de - de
# la - lo
# mañana - mañana
# . - .
# Suma - Suma
# : - :
# ¡ - ¡
# catorce - catorce
# horas - hora
# ! - !
# ... - ...
#
#  -
#
# ¡ - ¡
# Adios - Adios
# , - ,
# escriba - escribir
# ! - !
#
#
#  -
#
#
# --Adios - --Adios
# , - ,
# fariseo.-- - fariseo.--
#
#
#  -
#
#
# Y - Y
# ambos - ambos
# rieron - reír
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# cerró - cerrar
# su - su
# carpeta - carpeta
# y - y
# se - se
# fué - fué
# . - .
#
#
#  -
#
#
# Emilio - Emilio
# se - se
# extendió - extender
# perezosamente - perezosamente
# en - en
# su - su
# silla - silla
# ; - ;
# encendió - encender
# un - uno
# cigarro - cigarro
# , - ,
# que - que
#
#  -
#
# aspiró - aspirar
# con - con
# ánsia - ánsia
# ; - ;
# y - y
# arrojando - arrojar
# una - uno
# larga - largo
# espiral - espiral
# de - de
# humo - humo
# , - ,
# entornando - entornar
#
#  -
#
# los - lo
# ojos--¡Deliciosa - ojos--¡Deliciosa
# fruicion!--exclamó:--¿qué - fruicion!--exclamó:--¿qué
# no - no
# haces - haz
# tú - tú
# olvidar - olvidar
# ? - ?
# ... - ...
#
#  -
#
# Y - Y
# sin - sin
# embargo - embargar
# , - ,
# Mauricio - Mauricio
# te - te
# desdeña - desdeñar
# . - .
# Uncido - Uncido
# á - á
# un - uno
# rudo - rudo
# trabajo - trabajar
# , - ,
# pegado - pegar
#
#  -
#
# ahí - ahí
# , - ,
# á - á
# esa - ese
# mesa - mesar
# de - de
# redaccion - redaccion
# , - ,
# hasta - hasta
# los - lo
# codos - codo
# en - en
# la - lo
# seccion - seccion
# editorial - editorial
# ; - ;
#
#  -
#
# cronista - cronista
# , - ,
# traductor - traductor
# , - ,
# folletinista - folletinista
# , - ,
# corrector - corrector
# de - de
# pruebas - prueba
# : - :
# ¿ - ¿
# á - á
# qué - qué
#
#  -
#
# móvil - móvil
# obedecerá - obedecer
# ese - ese
# anhelo - anhelar
# de - de
# aglomerar - aglomerar
# sueldos - sueldo
# ? - ?
# Él - Él
# , - ,
# no - no
# es - ser
# avaro - avaro
# ni - ni
#
#  -
#
# derrochador - derrochador
# ; - ;
# no - no
# frecuenta - frecuentar
# clubs - club
# ni - ni
# bailes - baile
# ; - ;
# por - por
# tanto - tanto
# , - ,
# ni - ni
# juega - jugar
# ni - ni
#
#  -
#
# galantea - galantear
# . - .
# En - En
# los - lo
# teatros - teatro
# tiene - tener
# las - los
# entradas - entrar
# de - de
# periodista - periodista
# . - .
# ¿ - ¿
# A - A
# qué - qué
# tanto - tanto
#
#  -
#
# afan - afan
# de - de
# ganar - ganar
# dinero - dinero
# ? - ?
# ¿ - ¿
# qué - qué
# hace - hacer
# de - de
# él - él
# ? - ?
# No - No
# es - ser
# mucho - mucho
# , - ,
# en - en
# verdad - verdad
# ; - ;
# pero - pero
#
#  -
#
# ¿ - ¿
# qué - qué
# hace - hacer
# de - de
# él - él
# ? - ?
# Enigma - Enigma
# insoluble - insoluble
# es - ser
# para - parir
# mí - mí
# este - este
# jóven - jóven
# , - ,
# tan - tan
# franco - franco
# , - ,
#
#  -
#
# sin - sin
# embargo - embargar
# , - ,
# y - y
# tan - tan
# bueno - bueno
# ... - ...
#
#
#  -
#
#
# Y - Y
# Emilio - Emilio
# dejando - dejar
# la - lo
# pluma - pluma
# en - en
# largo - largar
# holgorio - holgorio
# , - ,
# quedóse - quedóse
# engolfado - engolfar
# en - en
# sus - su
#
#  -
#
# pensamientos - pensamiento
# y - y
# en - en
# el - el
# humo - humo
# de - de
# su - su
# cigarro - cigarro
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# II - II
#
#
#
#  -
#
#
#
# Mauricio - Mauricio
# se - se
# alejó - alejar
# con - con
# el - el
# paso - pasar
# presuroso - presuroso
# , - ,
# habitual - habitual
# en - en
# aquellos - aquel
# que - que
#
#  -
#
# tienen - tener
# contado - contar
# el - el
# tiempo - tiempo
# . - .
#
#
#  -
#
#
# Aunque - Aunque
# en - en
# la - lo
# plácida - plácido
# edad - edad
# de - de
# veinte - veinte
# años - año
# , - ,
# y - y
# bello - bello
# y - y
# apuesto - apostar
# , - ,
# hay - haber
# en - en
# la - lo
#
#  -
#
# expresion - expresion
# de - de
# su - su
# semblante - semblante
# esa - ese
# gravedad - gravedad
# melancólica - melancólico
# , - ,
# signo - signar
# de - de
# un - uno
# destino - destinar
#
#  -
#
# adverso - adverso
# . - .
#
#
#  -
#
#
# En - En
# verdad - verdad
# , - ,
# adverso - adverso
# había - haber
# sido - ser
# el - el
# destino - destinar
# para - parir
# Mauricio - Mauricio
# : - :
# adverso - adverso
# desde - desde
#
#  -
#
# la - lo
# cuna - cunar
# , - ,
# mecida - mecer
# por - por
# manos - mano
# extrañas - extraño
# , - ,
# desierta - desierto
# de - de
# cuidados - cuidar
# y - y
# caricias - caricia
# . - .
#
#
#  -
#
#
# Y - Y
# no - no
# fué - fué
# esto - este
# solo - solo
# ¡ - ¡
# ay - ay
# ! - !
# no - no
# fué - fué
# esto - este
# solo - solo
# . - .
#
#
#  -
#
#
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# subyugado - subyugar
# por - por
# una - uno
# pasion - pasion
# que - que
# causó - causar
# la - lo
# muerte - muerte
# á - á
# su - su
# esposa - esposo
# , - ,
#
#  -
#
# llevando - llevar
# todavía - todavía
# el - el
# luto - luto
# de - de
# la - lo
# viudez - viudez
# , - ,
# dió - dió
# una - uno
# sucesora - sucesor
# á - á
# la - lo
# difunta - difunto
# ; - ;
# á - á
#
#  -
#
# su - su
# hijo - hijo
# una - uno
# madrastra - madrastra
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Madrastra - Madrastra
# ! - !
# Al - Al
# solo - solo
# pronunciar - pronunciar
# esta - este
# palabra - palabra
# de - de
# aspereza - aspereza
# siniestra - siniestro
# , - ,
#
#  -
#
# compréndese - compréndese
# la - lo
# tristura - tristura
# de - de
# esos - ese
# pobres - pobre
# niños - niño
# que - que
# crecen - crecer
# temerosos - temeroso
# , - ,
#
#  -
#
# acoquinados - acoquinar
# , - ,
# bajo - bajar
# aquella - aquel
# sombra - sombrar
# fatídica - fatídico
# . - .
#
#
#  -
#
#
# Para - Para
# ellos - ellos
# no - no
# existen - existir
# las - los
# alegrías - alegría
# del - del
# hogar - hogar
# . - .
# Siempre - Siempre
# espiados - espiar
# por - por
# la - lo
#
#  -
#
# mirada - mirar
# suspicaz - suspicaz
# de - de
# un - uno
# fiscal - fiscal
# inexorable - inexorable
# que - que
# les - les
# achaca - achacar
# á - á
# delito - delito
# su - su
#
#  -
#
# gozosa - gozoso
# turbulencia - turbulencia
# , - ,
# su - su
# inocente - inocente
# espontaneidad - espontaneidad
# , - ,
# vuélvense - vuélvense
# taciturnos - taciturno
# , - ,
#
#  -
#
# desconfiados - desconfiar
# ; - ;
# ocúltanse - ocúltanse
# para - parir
# reir - reir
# ; - ;
# ocúltanse - ocúltanse
# para - parir
# llorar - llorar
# ; - ;
# y - y
# en - en
# el - el
#
#  -
#
# primer - ﻿1
# albor - albor
# de - de
# la - lo
# vida - vida
# , - ,
# aprenden - aprender
# esa - ese
# triste - triste
# ciencia - ciencia
# de - de
# la - lo
# vejez - vejez
# : - :
# el - el
#
#  -
#
# disimulo - disimular
# . - .
# ¿ - ¿
# Ni - Ni
# qué - qué
# otro - otro
# recurso - recurso
# les - les
# queda - quedo
# ? - ?
# ¿ - ¿
# A - A
# quién - quién
# volver - volver
# sus - su
# ojos - ojo
# ? - ?
#
#
#  -
#
#
# La - La
# casa - casar
# paterna - paterno
# se - se
# ha - haber
# tornado - tornar
# para - parir
# ellos - ellos
# en - en
# campo - campar
# enemigo - enemigo
# , - ,
# donde - donde
# todo - todo
#
#  -
#
# les - les
# es - ser
# hostil - hostil
# , - ,
# hasta - hasta
# su - su
# mismo - mismo
# padre - padre
# á - á
# quien - quien
# no - no
# le - le
# es - ser
# dado - dar
# mostrárseles - mostrárseles
#
#  -
#
# propicio - propiciar
# , - ,
# so - so
# pena - penar
# de - de
# despertar - despertar
# celos - celo
# retrospectivos - retrospectivo
# , - ,
# que - que
# empeoren - empeorar
# la - lo
#
#  -
#
# situacion - situacion
# tristísima - tristísima
# de - de
# esos - ese
# náufragos - náufrago
# de - de
# la - lo
# vida - vida
# . - .
#
#
#  -
#
#
# Tal - Tal
# suerte - suerte
# cupo - caber
# á - á
# Mauricio - Mauricio
# . - .
#
#
#  -
#
#
# Víctima - Víctima
# de - de
# una - uno
# semejanza - semejanza
# que - que
# importunaba - importunar
# á - á
# su - su
# padre - padre
# como - comer
# un - uno
#
#  -
#
# remordimiento - remordimiento
# , - ,
# á - á
# su - su
# madrastra - madrastra
# como - comer
# una - uno
# vision - vision
# de - de
# ultratumba - ultratumba
# , - ,
# vióse - vióse
# un - uno
#
#  -
#
# dia - dia
# arrebatado - arrebatar
# de - de
# su - su
# casa - casar
# y - y
# entregado - entregar
# al - al
# capitan - capitan
# de - de
# un - uno
# buque - buque
# inglés - inglés
# , - ,
#
#  -
#
# que - que
# lo - el
# llevó - llevar
# á - á
# Europa - Europa
# y - y
# lo - el
# encerró - encerrar
# en - en
# un - uno
# colegio - colegiar
# . - .
#
#
#  -
#
#
# Aunque - Aunque
# del - del
# hogar - hogar
# de - de
# sus - su
# padres - padre
# , - ,
# el - el
# pobre - pobre
# niño - niño
# , - ,
# solo - solo
# guardara - guardar
# crueles - cruel
#
#  -
#
# recuerdos - recuerdo
# , - ,
# la - lo
# lengua - lengua
# materna - materno
# , - ,
# el - el
# suelo - soler
# de - de
# la - lo
# patria - patrio
# , - ,
# su - su
# aire - aire
# , - ,
# su - su
# luz - luz
# , - ,
#
#  -
#
# éranle - éranle
# necesarios - necesario
# , - ,
# y - y
# languideció - languidecer
# , - ,
# echándolos - echándolos
# de - de
# menos - menos
# . - .
#
#
#  -
#
#
# Por - Por
# dicha - decir
# suya - suyo
# fué - fué
# el - el
# « - «
# bello - bello
# país - país
# de - de
# Francia - Francia
# , - ,
# » - »
# la - lo
# hospitalaria - hospitalario
# Paris - Paris
# , - ,
#
#  -
#
# el - el
# lugar - lugar
# de - de
# su - su
# destierro - desterrar
# . - .
#
#
#  -
#
#
# La - La
# bondad - bondad
# característica - característico
# de - de
# los - lo
# hijos - hijo
# de - de
# aquella - aquel
# tierra - tierra
# , - ,
# tiene - tener
# , - ,
# en - en
#
#  -
#
# todas - todo
# las - los
# clases - clase
# sociales - social
# , - ,
# desde - desde
# el - el
# aristócrata - aristócrata
# hasta - hasta
# el - el
# obrero - obrero
# , - ,
# una - uno
#
#  -
#
# gracia - gracia
# irresistible - irresistible
# que - que
# cautiva - cautivo
# el - el
# alma - alma
# y - y
# mata - matar
# toda - todo
# nostalgia - nostalgia
# . - .
#
#
#  -
#
#
# Desde - Desde
# el - el
# sábio - sábio
# Blain - Blain
# , - ,
# director - director
# del - del
# colegio - colegiar
# donde - donde
# fué - fué
# el - el
# niño - niño
#
#  -
#
# consignado - consignar
# , - ,
# hasta - hasta
# el - el
# ama - amar
# de - de
# llaves - llave
# , - ,
# la - lo
# buena - bueno
# Colombe - Colombe
# ; - ;
# desde - desde
# los - lo
# alumnos - alumno
#
#  -
#
# hasta - hasta
# los - lo
# profesores - profesor
# : - :
# todos - todo
# acogiéronlo - acogiéronlo
# con - con
# tan - tan
# benévola - benévolo
# conmiseracion - conmiseracion
# , - ,
#
#  -
#
# que - que
# primero - 1
# la - lo
# serenidad - serenidad
# y - y
# luego - luego
# la - lo
# alegría - alegría
# , - ,
# vinieron - venir
# como - comer
# nunca - nunca
# , - ,
#
#  -
#
# expansivas - expansivo
# á - á
# aquel - aquel
# pobre - pobre
# corazon - corazon
# , - ,
# por - por
# tanto - tanto
# tiempo - tiempo
# oprimido - oprimir
# . - .
#
#
#  -
#
#
# El - El
# desterrado - desterrar
# comenzó - comenzar
# á - á
# encontrarse - encontrarse
# feliz - feliz
# en - en
# su - su
# nueva - nuevo
# familia - familia
# . - .
#
#
#  -
#
#
# --¡Ah!--pensaba - --¡Ah!--pensaba
# , - ,
# recordando - recordar
# el - el
# pasado--¿así - pasado--¿así
# se - se
# ama - amar
# , - ,
# se - se
# acaricia - acariciar
# y - y
# se - se
#
#  -
#
# protege - proteger
# ? - ?
# ¿ - ¿
# Por - Por
# qué - qué
# no - no
# he - haber
# conocido - conocer
# yo - yo
# hasta - hasta
# hoy - hoy
# , - ,
# estos - este
# bienes - bien
# ? - ?
#
#
#  -
#
#
# Y - Y
# refugiábase - refugiábase
# en - en
# esa - ese
# atmósfera - atmósfera
# de - de
# calurosos - caluroso
# afectos - afecto
# ; - ;
# y - y
# sentía - sentir
# el - el
# dulce - dulce
#
#  -
#
# bienestar - bienestar
# del - del
# que - que
# renace - renacer
# á - á
# la - lo
# salud - salud
# despues - despues
# de - de
# una - uno
# larga - largo
# enfermedad - enfermedad
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# III - III
#
#
#
#  -
#
#
#
# Los - Los
# años - año
# trascurrieron - trascurrir
# así - asir
# , - ,
# con - con
# sus - su
# épocas - época
# clásicas - clásico
# , - ,
# en - en
# la - lo
# vida - vida
# del - del
#
#  -
#
# niño - niño
# . - .
# Los - Los
# exámenes - examen
# ; - ;
# los - lo
# premios - premio
# ; - ;
# el - el
# paso - pasar
# á - á
# estudios - estudio
# superiores - superior
# ; - ;
# el - el
# del - del
#
#  -
#
# vestido - vestir
# infantil - infantil
# al - al
# traje - traer
# viril - viril
# ; - ;
# la - lo
# primera - primero
# comunion - comunion
# ..... - .....
#
#
#  -
#
#
# ¡ - ¡
# Qué - Qué
# ceremonia - ceremonia
# , - ,
# á - á
# la - lo
# vez - vez
# tan - tan
# imponente - imponente
# y - y
# tierna - tierno
# ! - !
#
#
#  -
#
#
# Cumplido - Cumplido
# en - en
# él - él
# , - ,
# el - el
# divino - divino
# misterio - misterio
# , - ,
# de - de
# rodillas - rodilla
# ante - ante
# el - el
# altar - altar
# , - ,
# el - el
# niño - niño
#
#  -
#
# tiende - tender
# la - lo
# mano - manir
# sobre - sobrar
# el - el
# Sagrado - Sagrado
# Libro - Libro
# y - y
# jura - jurar
# ser - ser
# virtuoso - virtuoso
# y - y
# bueno - bueno
# . - .
#
#
#  -
#
#
# El - El
# celebrante - celebrante
# lo - el
# bendice - bendecir
# y - y
# coloca - colocar
# en - en
# su - su
# pecho - pechar
# una - uno
# reliquia - reliquia
# . - .
#
#
#  -
#
#
# La - La
# voz - voz
# del - del
# órgano - órgano
# derrama - derramar
# gozosas - gozoso
# notas - noto
# ; - ;
# nubes - nube
# de - de
# incienso - incensar
# se - se
# elevan - elevar
# á - á
#
#  -
#
# lo - el
# alto - alto
# de - de
# la - lo
# bóveda - bóveda
# ; - ;
# y - y
# en - en
# la - lo
# nave - nave
# central - central
# , - ,
# las - los
# madres - madre
# aguardan - aguardar
# con - con
# el - el
#
#  -
#
# llanto - llanto
# en - en
# los - lo
# ojos - ojo
# , - ,
# en - en
# el - el
# lábio - lábio
# la - lo
# sonrisa - sonrisa
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# vió - vió
# á - á
# sus - su
# compañeros - compañero
# ir - ir
# hácia - hácia
# ellas - ellos
# y - y
# caer - caer
# en - en
# sus - su
# brazos - brazo
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Ay - Ay
# ! - !
# ¡ - ¡
# él - él
# estaba - estar
# solo - solo
# ! - !
#
#
#  -
#
#
# Ni - Ni
# padre - padre
# ni - ni
# madre - madre
# que - que
# lo - el
# aguardaran - aguardar
# ; - ;
# solo - solo
# en - en
# esa - ese
# hora - hora
# solemne - solemne
# de - de
# la - lo
#
#  -
#
# vida - vida
# . - .
#
#
#  -
#
#
# ¿ - ¿
# Solo - Solo
# ? - ?
#
#
#  -
#
#
# No - No
# : - :
# ahí - ahí
# estaba - estar
# Mr - Mr
# . - .
# Blain - Blain
# que - que
# le - le
# sonreia - sonreia
# ; - ;
# ahí - ahí
# estaba - estar
# la - lo
# buena - bueno
# Colombe - Colombe
#
#  -
#
# que - que
# le - le
# tiende - tender
# los - lo
# brazos - brazo
# y - y
# lo - el
# contempla - contemplar
# enternecida - enternecer
# . - .
#
#
#  -
#
#
# --Ama--díjole - --Ama--díjole
# Mauricio--¿Quieres - Mauricio--¿Quieres
# que - que
# te - te
# dé - dar
# mi - mi
# reliquia - reliquia
# ? - ?
# Mírala - Mírala
# : - :
# es - ser
# muy - muy
#
#  -
#
# linda - lindo
# : - :
# _ - _
# Notre - Notre
# Dame - Dame
# du - du
# bon - bon
# Secour - Secour
# _ - _
# . - .
#
#
#  -
#
#
# --No - --No
# , - ,
# hijo - hijo
# mio--respondió - mio--respondió
# la - lo
# vieja - viejo
# sirvienta - sirviente
# , - ,
# volviendo - volver
# la - lo
# reliquia - reliquia
# al - al
#
#  -
#
# pecho - pechar
# del - del
# niño.--Este - niño.--Este
# recuerdo - recordar
# le - le
# es - ser
# debido - deber
# á - á
# mamá - mamá
# . - .
# Envíaselo - Envíaselo
# dentro - dentro
# de - de
#
#  -
#
# tu - tu
# primera - primero
# carta.-- - carta.--
#
#
#  -
#
#
# La - La
# hora - hora
# , - ,
# el - el
# lugar - lugar
# , - ,
# la - lo
# escena - escena
# imponente - imponente
# en - en
# que - que
# acababa - acabar
# de - de
# actuar - actuar
# ; - ;
# la - lo
#
#  -
#
# voz - voz
# del - del
# órgano - órgano
# ; - ;
# el - el
# humo - humo
# del - del
# incienso - incensar
# ; - ;
# las - los
# sagradas - sagrado
# preces - prez
# ; - ;
# todo - todo
# esto - este
#
#  -
#
# despertó - despertar
# en - en
# el - el
# alma - alma
# del - del
# niño - niño
# una - uno
# emocion - emocion
# profunda - profundo
# , - ,
# al - al
# oir - oir
# las - los
# palabras - palabra
#
#  -
#
# de - de
# la - lo
# vieja - viejo
# Colombe - Colombe
# . - .
# La - La
# luz - luz
# de - de
# un - uno
# lejano - lejano
# recuerdo - recordar
# brilló - brillar
# en - en
# su - su
# mente - mente
# , - ,
#
#  -
#
# mostrándole - mostrándole
# allá - allá
# , - ,
# como - comer
# entre - entrar
# las - los
# nieblas - niebla
# de - de
# un - uno
# ensueño - ensoñar
# , - ,
# la - lo
# figura - figurar
#
#  -
#
# angelical - angelical
# de - de
# una - uno
# mujer - mujer
# que - que
# lo - el
# miraba - mirar
# sonriendo - sonreír
# . - .
#
#
#  -
#
#
# Sonrióle - Sonrióle
# él - él
# tambien - tambien
# , - ,
# y - y
# dos - do
# lágrimas - lágrima
# se - se
# desprendieron - desprender
# de - de
# sus - su
# ojos - ojo
# . - .
#
#
#  -
#
#
# Colombe - Colombe
# las - los
# comprendió - comprender
# . - .
# Besó - Besó
# la - lo
# santa - santo
# imágen - imágen
# ; - ;
# guardóla - guardóla
# en - en
# su - su
# seno - seno
# ; - ;
# y - y
# en - en
#
#  -
#
# la - lo
# noche - noche
# , - ,
# á - á
# la - lo
# hora - hora
# de - de
# acostarse - acostarse
# , - ,
# Mauricio - Mauricio
# la - lo
# encontró - encontrar
# á - á
# la - lo
# cabecera - cabecera
# de - de
#
#  -
#
# su - su
# cama - cama
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# IV - IV
#
#
#
#  -
#
#
#
# Desde - Desde
# ese - ese
# dia - dia
# un - uno
# notable - notable
# cambio - cambiar
# se - se
# efectuó - efectuar
# en - en
# su - su
# carácter - carácter
# . - .
# A - A
# la - lo
#
#  -
#
# inquieta - inquieto
# turbulencia - turbulencia
# del - del
# niño - niño
# , - ,
# sucedieron - suceder
# la - lo
# mesura - mesurar
# y - y
# la - lo
# reflexion - reflexion
# del - del
#
#  -
#
# hombre - hombre
# ; - ;
# al - al
# gusto - gustar
# por - por
# los - lo
# juegos - juego
# , - ,
# el - el
# amor - amor
# al - al
# estudio - estudiar
# ; - ;
# á - á
# su - su
# indiferencia - indiferencia
#
#  -
#
# cosmopolita - cosmopolita
# , - ,
# el - el
# sentimiento - sentimiento
# exaltado - exaltar
# de - de
# la - lo
# nacionalidad - nacionalidad
# . - .
#
#
#  -
#
#
# Cuando - Cuando
# en - en
# los - lo
# dias - dias
# clásicos - clásico
# , - ,
# al - al
# flamear - flamear
# de - de
# la - lo
# bandera - bandera
# tricolor - tricolor
# , - ,
# sus - su
#
#  -
#
# compañeros - compañero
# cantaban - cantar
# : - :
# « - «
# _ - _
# Allons - Allons
# enfants - enfants
# de - de
# la - lo
# patrie - patrie
# _ - _
# , - ,
# » - »
# Mauricio - Mauricio
# buscaba - buscar
#
#  -
#
# en - en
# el - el
# cielo - cielo
# , - ,
# el - el
# azul - azul
# pabellon - pabellon
# ; - ;
# y - y
# del - del
# fondo - fondo
# de - de
# su - su
# alma - alma
# exhalábase - exhalábase
# el - el
#
#  -
#
# grito - gritar
# sagrado - sagrado
# del - del
# himno - himno
# nacional - nacional
# . - .
# Allá - Allá
# , - ,
# surgiendo - surgir
# de - de
# las - los
# brumas - brumar
# del - del
#
#  -
#
# lejano - lejano
# pasado - pasar
# , - ,
# la - lo
# imágen - imágen
# de - de
# la - lo
# patria - patrio
# aparecíale - aparecíale
# con - con
# su - su
# inmensa - inmenso
# pampa - pampa
# , - ,
#
#  -
#
# su - su
# magestuoso - magestuoso
# rio - rio
# , - ,
# sus - su
# cerúleas - cerúleo
# lontananzas - lontananza
# , - ,
# llamándolo - llamándolo
# con - con
# poderoso - poderoso
#
#  -
#
# reclamo - reclamar
# . - .
#
#
#  -
#
#
# Pero - Pero
# ¡ - ¡
# ah - ah
# ! - !
# siempre - siempre
# que - que
# estas - este
# luminosas - luminoso
# imágenes - imagen
# visitaban - visitar
# su - su
# mente - mente
# , - ,
# un - uno
#
#  -
#
# siniestro - siniestro
# recuerdo - recordar
# venía - venir
# á - á
# oscurecerlas - oscurecerlas
# . - .
#
#
#  -
#
#
# Su - Su
# madrastra - madrastra
# . - .
#
#
#  -
#
#
# Este - Este
# sentimiento - sentimiento
# de - de
# repulsion - repulsion
# creció - crecer
# más - más
# todavía - todavía
# , - ,
# cuando - cuando
# Mauricio - Mauricio
#
#  -
#
# comprendió - comprender
# por - por
# las - los
# cartas - carta
# de - de
# su - su
# padre - padre
# , - ,
# la - lo
# humillante - humillante
# dependencia - dependencia
# en - en
#
#  -
#
# que - que
# yacía - yacer
# . - .
# Cada - Cada
# frase - frase
# parecía - parecer
# consultada - consultar
# , - ,
# corregida - corregir
# ó - ó
# dictada - dictar
# por - por
# el - el
#
#  -
#
# déspota - déspota
# que - que
# leía - leer
# sobre - sobrar
# su - su
# hombro - hombro
# . - .
#
#
#  -
#
#
# El - El
# jóven - jóven
# vertía - verter
# sobre - sobrar
# ella - él
# lágrimas - lágrima
# de - de
# indignacion - indignacion
# y - y
# de - de
# dolor - dolor
# ; - ;
# y - y
# una - uno
#
#  -
#
# palabra - palabra
# de - de
# uno - unir
# ú - ú
# otro - otro
# , - ,
# contenían - contener
# sus - su
# respuestas - respuesta
# . - .
#
#
#  -
#
#
# Así - Así
# , - ,
# la - lo
# correspondencia - correspondencia
# entre - entrar
# padre - padre
# é - é
# hijo - hijo
# tomó - tomar
# un - uno
# carácter - carácter
# de - de
# acritud - acritud
#
#  -
#
# que - que
# , - ,
# poco - poco
# á - á
# poco - poco
# , - ,
# degeneró - degenerar
# en - en
# frialdad - frialdad
# . - .
#
#
#  -
#
#
# Y - Y
# , - ,
# cuando - cuando
# á - á
# la - lo
# edad - edad
# de - de
# diez - diez
# y - y
# ocho - ocho
# años - año
# , - ,
# acabados - acabar
# sus - su
# estudios - estudio
# y - y
#
#  -
#
# rendido - rendir
# con - con
# brillo - brillar
# el - el
# último - último
# exámen - exámen
# , - ,
# su - su
# padre - padre
# le - le
# habló - hablar
# de - de
# regreso - regresar
# . - .
#
#
#  -
#
#
# --Amo - --Amo
# á - á
# mi - mi
# patria - patrio
# y - y
# anhelo - anhelar
# volver - volver
# á - á
# verla--respondió - verla--respondió
# Mauricio,--amo - Mauricio,--amo
# á - á
#
#  -
#
# mi - mi
# padre - padre
# y - y
# deseo - desear
# estrecharlo - estrecharlo
# en - en
# mis - mi
# brazos - brazo
# ; - ;
# pero - pero
# no - no
# podría - poder
# presenciar - presenciar
#
#  -
#
# el - el
# espectáculo - espectáculo
# vergonzoso - vergonzoso
# de - de
# su - su
# servidumbre - servidumbre
# ; - ;
# y - y
# porque - porque
# lo - el
# amo - amar
# ; - ;
# y - y
# porque - porque
#
#  -
#
# lo - el
# respeto - respetar
# , - ,
# prefiero - preferir
# un - uno
# eterno - eterno
# destierro - desterrar
# . - .
#
#
#  -
#
#
# A - A
# esta - este
# declaracion - declaracion
# siguió - seguir
# un - uno
# profundo - profundar
# silencio - silenciar
# ; - ;
# y - y
# como - comer
# única - único
# respuesta - respuesta
#
#  -
#
# Mauricio - Mauricio
# recibió - recibir
# una - uno
# carta - carta
# que - que
# contenía - contener
# inesperadas - inesperado
# revelaciones - revelación
# . - .
#
#  -
#
# Suscribíala - Suscribíala
# el - el
# escribano - escribano
# D - D
# ... - ...
# , - ,
# uno - unir
# de - de
# los - lo
# hombres - hombre
# más - más
# honorables - honorable
# de - de
#
#  -
#
# Buenos - Buenos
# Aires - Aires
# . - .
#
#
#    -
#
#
# --«Alejados - --«Alejados
# y - y
# sin - sin
# conocernos - conocernos
# uno - unir
# á - á
# otro--decíale - otro--decíale
# éste--únenos - éste--únenos
# , - ,
#
#    -
#
# sinembargo - sinembargo
# , - ,
# el - el
# mandato - mandato
# de - de
# una - uno
# persona - personar
# que - que
# ya - ya
# no - no
# existe - existir
# ; - ;
# y - y
# que - que
# para - parir
#
#    -
#
# mí - mí
# fué - fué
# por - por
# esto - este
# , - ,
# más - más
# sagrado.--Y - sagrado.--Y
# proseguía - proseguir
# : - :
#
#
#    -
#
#
# --«Hace - --«Hace
# quince - quince
# años - año
# , - ,
# fuí - fuí
# llamado - llamar
# un - uno
# dia - dia
# á - á
# casa - casar
# del - del
# señor - señor
# Cárlos - Cárlos
#
#    -
#
# Ridel - Ridel
# , - ,
# cuya - cuyo
# esposa - esposo
# , - ,
# en - en
# trance - tranzar
# de - de
# muerte - muerte
# , - ,
# debía - deber
# otorgar - otorgar
# testamento - testamento
# . - .
#
#
#    -
#
#
# « - «
# Mi - Mi
# colega - colega
# , - ,
# el - el
# señor - señor
# R - R
# ... - ...
# , - ,
# autorizaba - autorizar
# el - el
# acto - acto
# ; - ;
# y - y
# yo - yo
# creía - creer
# haber - haber
#
#    -
#
# sido - ser
# requerido - requerir
# como - comer
# testigo - testigo
# , - ,
# cuando - cuando
# la - lo
# testante - testante
# , - ,
# habiendo - haber
# declarado - declarar
#
#    -
#
# que - que
# dejaba - dejar
# á - á
# su - su
# hijo - hijo
# único - único
# , - ,
# Mauricio - Mauricio
# Ridel - Ridel
# , - ,
# el - el
# valor - valor
# de - de
# doscientos - doscientos
#
#    -
#
# mil - mil
# pesos - peso
# en - en
# propiedades - propiedad
# urbanas - urbano
# y - y
# rurales - rural
# , - ,
# volviéndose - volviéndose
# á - á
# su - su
#
#    -
#
# esposo - esposar
# , - ,
# pidióle - pidióle
# permiso - permiso
# para - parir
# instituirme - instituirme
# á - á
# mí - mí
# , - ,
# hasta - hasta
# la - lo
# mayoría - mayoría
# de - de
#
#    -
#
# aquel - aquel
# , - ,
# guardador - guardador
# de - de
# dichos - dicho
# bienes - bien
# . - .
#
#
#    -
#
#
# « - «
# Repugnábame - Repugnábame
# una - uno
# mision - mision
# visiblemente - visiblemente
# motivada - motivar
# por - por
# disensiones - disensión
#
#    -
#
# conyugales - conyugal
# ; - ;
# pero - pero
# los - lo
# ojos - ojo
# de - de
# la - lo
# moribunda - moribundo
# enviáronme - enviáronme
# una - uno
# mirada - mirar
# de - de
#
#    -
#
# angustioso - angustioso
# ruego - rogar
# , - ,
# que - que
# me - me
# hizo - hacer
# aceptarla - aceptarla
# . - .
#
#
#    -
#
#
# « - «
# Ella - Ella
# entónces - entónces
# suspiró - suspirar
# como - comer
# aliviada - aliviar
# de - de
# una - uno
# grave - gravar
# preocupacion - preocupacion
# ; - ;
#
#    -
#
# estrechó - estrechar
# mi - mi
# mano - manir
# con - con
# gratitud - gratitud
# , - ,
# y - y
# murió - morir
# en - en
# paz - paz
# . - .
#
#
#    -
#
#
# « - «
# Yo - Yo
# he - haber
# cumplido - cumplir
# fielmente - fielmente
# el - el
# deber - deber
# que - que
# me - me
# impuse - imponer
# : - :
# he - haber
# administrado - administrar
#
#    -
#
# esos - ese
# bienes - bien
# con - con
# el - el
# acierto - acertar
# que - que
# dá - dá
# una - uno
# larga - largo
# experiencia - experiencia
# en - en
# los - lo
#
#    -
#
# negocios - negocio
# ; - ;
# los - lo
# he - haber
# conservado - conservar
# , - ,
# los - lo
# he - haber
# hecho - hacer
# fructificar - fructificar
# : - :
# pero - pero
# siempre - siempre
#
#    -
#
# en - en
# el - el
# limite - limitar
# que - que
# mi - mi
# delicadeza - delicadeza
# me - me
# prescribía - prescribir
# : - :
# no - no
# como - comer
# guardador - guardador
# , - ,
#
#    -
#
# sino - sino
# como - comer
# administrador - administrador
# , - ,
# rindiendo - rendir
# cuentas - cuenta
# de - de
# mi - mi
# cometido - cometer
# y - y
#
#    -
#
# entregando - entregar
# al - al
# señor - señor
# Ridel - Ridel
# las - los
# fuertes - fuerte
# sumas - sumo
# que - que
# producen - producir
# . - .
#
#
#    -
#
#
# « - «
# Hoy - Hoy
# me - me
# ha - haber
# hecho - hacer
# saber - saber
# que - que
# V. - V.
# se - se
# ha - haber
# emancipado - emancipar
# ; - ;
# y - y
# que - que
# , - ,
# por - por
# tanto - tanto
# , - ,
#
#    -
#
# la - lo
# ingerencia - ingerencia
# que - que
# yo - yo
# le - le
# daba - dar
# en - en
# los - lo
# asuntos - asunto
# de - de
# su - su
# hijo - hijo
# , - ,
# ha - haber
# cesado - cesar
# . - .
#
#
#    -
#
#
# « - «
# Por - Por
# consecuencia - consecuencia
# , - ,
# y - y
# persuadido - persuadir
# de - de
# que - que
# él - él
# habrá - haber
# informado - informar
# á - á
# V. - V.
# del - del
#
#    -
#
# estado - estar
# floreciente - floreciente
# de - de
# su - su
# fortuna - fortuna
# , - ,
# no - no
# solo - solo
# por - por
# mi - mi
# buena - bueno
# voluntad - voluntad
# en - en
#
#    -
#
# su - su
# administracion - administracion
# , - ,
# sino - sino
# á - á
# causa - causar
# del - del
# subido - subir
# precio - preciar
# que - que
# ha - haber
# adquirido - adquirir
#
#    -
#
# la - lo
# propiedad - propiedad
# , - ,
# réstame - réstame
# solo - solo
# ponerla - ponerla
# á - á
# su - su
# disposicion - disposicion
# , - ,
# y - y
# pedirle - pedirle
# se - se
#
#    -
#
# sirvo - servir
# impartirme - impartirme
# sus - su
# órdenes - orden
# » - »
# . - .
#
#
#  -
#
#
# Esta - Esta
# carta - carta
# de - de
# un - uno
# tutor - tutor
# hasta - hasta
# entónces - entónces
# ignorado - ignorar
# , - ,
# fué - fué
# un - uno
# rayo - rayar
# de - de
# luz - luz
# en - en
#
#  -
#
# el - el
# misterio - misterio
# que - que
# rodeaba - rodear
# el - el
# pasado - pasar
# de - de
# Mauricio - Mauricio
# , - ,
# y - y
# efectuó - efectuar
# un - uno
# cambio - cambiar
#
#  -
#
# favorable - favorable
# en - en
# su - su
# destino - destinar
# . - .
#
#
#  -
#
#
# Alejado - Alejado
# de - de
# su - su
# padre - padre
# , - ,
# por - por
# la - lo
# funesta - funesto
# influencia - influenciar
# que - que
# se - se
# alzaba - alzar
# hostil - hostil
#
#  -
#
# entre - entrar
# ambos - ambos
# , - ,
# el - el
# hijo - hijo
# desechado - desechar
# , - ,
# bendijo - bendecir
# la - lo
# ternura - ternura
# previsora - previsor
# de - de
# aquella - aquel
#
#  -
#
# madre - madre
# moribunda - moribundo
# , - ,
# que - que
# viendo - ver
# cernerse - cernerse
# la - lo
# desgracia - desgraciar
# sobre - sobrar
# la - lo
# cuna - cunar
# del - del
#
#  -
#
# niño - niño
# que - que
# le - le
# era - ser
# forzoso - forzoso
# abandonar - abandonar
# , - ,
# había - haber
# querido - querer
# , - ,
# asegurándole - asegurándole
# una - uno
#
#  -
#
# fortuna - fortuna
# independiente - independiente
# , - ,
# preservarlo - preservarlo
# en - en
# los - lo
# azares - azarar
# del - del
# porvenir - porvenir
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# expresó - expresar
# su - su
# profunda - profundo
# gratitud - gratitud
# al - al
# honrado - honrar
# escribano - escribano
# ; - ;
# confióle - confióle
#
#  -
#
# los - lo
# dolorosos - doloroso
# motivos - motivo
# de - de
# su - su
# doble - doblar
# ostracismo - ostracismo
# ; - ;
# y - y
# le - le
# suplicó - suplicar
# , - ,
# en - en
# nombre - nombrar
#
#  -
#
# de - de
# aquella - aquel
# cuyo - cuyo
# encargo - encargar
# había - haber
# tan - tan
# noblemente - noblemente
# cumplido - cumplir
# , - ,
# quisiera - querer
#
#  -
#
# favorecerlo - favorecerlo
# á - á
# él - él
# , - ,
# continuando - continuar
# en - en
# la - lo
# administracion - administracion
# de - de
# aquellos - aquel
# bienes - bien
# , - ,
#
#  -
#
# para - parir
# lo - el
# cual - cual
# le - le
# confirió - conferir
# un - uno
# pleno - pleno
# poder - poder
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# V - V
#
#
#
#  -
#
#
#
# Las - Las
# lágrimas - lágrima
# de - de
# una - uno
# infancia - infancia
# desamparada - desamparar
# y - y
# las - los
# tristezas - tristeza
# de - de
# su - su
#
#  -
#
# juventud - juventud
# , - ,
# sin - sin
# patria - patrio
# , - ,
# ni - ni
# hogar - hogar
# , - ,
# habían - haber
# dado - dar
# al - al
# carácter - carácter
# de - de
# Mauricio - Mauricio
# una - uno
#
#  -
#
# gravedad - gravedad
# melancólica - melancólico
# que - que
# , - ,
# alejándolo - alejándolo
# de - de
# los - lo
# placeres - placer
# bulliciosos - bullicioso
# de - de
# sus - su
#
#  -
#
# compañeros - compañero
# , - ,
# lo - el
# preservó - preservar
# de - de
# la - lo
# disipacion - disipacion
# . - .
#
#
#  -
#
#
# Así - Así
# , - ,
# cuando - cuando
# libre - librar
# y - y
# en - en
# posesion - posesion
# de - de
# una - uno
# fortuna - fortuna
# independiente - independiente
# , - ,
# podía - poder
#
#  -
#
# entregarse - entregarse
# á - á
# los - lo
# goces - gozar
# que - que
# Paris - Paris
# ofrece - ofrecer
# con - con
# mano - manir
# pródiga - pródigo
# , - ,
# él - él
# , - ,
# sin - sin
#
#  -
#
# esfuerzo - esforzar
# , - ,
# sin - sin
# sacrificio - sacrificio
# , - ,
# consagróse - consagróse
# , - ,
# á - á
# una - uno
# vida - vida
# de - de
# labor - labor
# intelectual - intelectual
# . - .
#
#  -
#
# Frecuentó - Frecuentó
# la - lo
# Sorbona - Sorbona
# , - ,
# los - lo
# Institutos - Institutos
# , - ,
# las - los
# academias - academia
# y - y
# las - los
# bibliotecas - biblioteca
# . - .
#
#  -
#
# Arrojóse - Arrojóse
# en - en
# el - el
# periodismo - periodismo
# y - y
# tomó - tomar
# activa - activo
# parte - partir
# en - en
# los - lo
# trabajos - trabajo
# de - de
# uno - unir
# de - de
#
#  -
#
# los - lo
# principales - principal
# diarios - diario
# de - de
# Paris - Paris
# , - ,
# haciéndose - haciéndose
# notar - notar
# por - por
# su - su
# brillante - brillante
#
#  -
#
# estilo - estilar
# y - y
# la - lo
# originalidad - originalidad
# de - de
# sus - su
# ideas - ideo
# . - .
#
#
#  -
#
#
# Ensayó - Ensayó
# la - lo
# novela - novelar
# ; - ;
# y - y
# muy - muy
# pronto - pronto
# los - lo
# folletines - folletín
# firmados - firmar
# por - por
# Valerio--su - Valerio--su
#
#  -
#
# seudónimo,--fueron - seudónimo,--fueron
# leidos - leidos
# con - con
# entusiasmo - entusiasmar
# , - ,
# sobre - sobrar
# todo - todo
# por - por
# las - los
# jóvenes - joven
# , - ,
#
#  -
#
# que - que
# encontraban - encontrar
# en - en
# sus - su
# páginas - página
# , - ,
# á - á
# vueltas - vuelta
# de - de
# los - lo
# pálidos - pálido
# excepticismos - excepticismos
#
#  -
#
# de - de
# la - lo
# época - época
# , - ,
# el - el
# color - color
# ardiente - ardiente
# de - de
# la - lo
# pasion - pasion
# . - .
#
#
#  -
#
#
# Era - Era
# que - que
# el - el
# ideal - ideal
# evocado - evocar
# en - en
# sus - su
# creaciones - creación
# despertaba - despertar
# y - y
# hacía - hacer
# palpitar - palpitar
#
#  -
#
# un - uno
# sentimiento - sentimiento
# que - que
# hasta - hasta
# entónces - entónces
# yacía - yacer
# latente - latente
# en - en
# el - el
# alma - alma
# de - de
# Mauricio - Mauricio
# : - :
#
#
#  -
#
#
# --El - --El
# amor.-- - amor.--
#
#
#  -
#
#
# Y - Y
# aunque - aunque
# más - más
# de - de
# una - uno
# vez - vez
# , - ,
# las - los
# seducciones - seducción
# de - de
# la - lo
# mujer - mujer
# habían - haber
# deslumbrado - deslumbrar
#
#  -
#
# sus - su
# ojos - ojo
# , - ,
# rozado - rozar
# su - su
# epidermis - epidermis
# , - ,
# jamás - jamás
# lograron - lograr
# llegar - llegar
# á - á
# su - su
# corazon - corazon
# . - .
#
#
#  -
#
#
# Tres - Tres
# años - año
# pasaron - pasar
# para - parir
# Mauricio - Mauricio
# en - en
# aquella - aquel
# vida - vida
# activa - activo
# del - del
# espíritu - espíritu
# . - .
#
#  -
#
# Proponíase - Proponíase
# ensancharla - ensancharla
# con - con
# viajes - viaje
# de - de
# recreo - recrear
# en - en
# torno - tornar
# á - á
# Europa - Europa
# y - y
# con - con
#
#  -
#
# la - lo
# fundacion - fundacion
# de - de
# un - uno
# periódico - periódico
# de - de
# espíritu - espíritu
# americano - americano
# , - ,
# que - que
# uniese - unir
# en - en
# un - uno
#
#  -
#
# contacto - contactar
# intelectual - intelectual
# más - más
# íntimo - íntimo
# , - ,
# los - lo
# dos - do
# continentes - continente
# ; - ;
# trasfusionando - trasfusionando
#
#  -
#
# en - en
# la - lo
# savia - savia
# cansada - cansar
# y - y
# empobrecida - empobrecer
# del - del
# uno - unir
# , - ,
# la - lo
# savia - savia
# rica - rico
# y - y
# jóven - jóven
# del - del
#
#  -
#
# otro - otro
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Ah - Ah
# ! - !
# de - de
# todas - todo
# las - los
# vanidades - vanidad
# que - que
# deplora - deplorar
# el - el
# Sagrado - Sagrado
# Libro - Libro
# , - ,
# ¡ - ¡
# ninguna - ninguno
# tan - tan
#
#  -
#
# vana - vano
# como - comer
# nuestros - nuestro
# proyectos - proyecto
# ! - !
#
#
#  -
#
#
# Creo - Creo
# haberlo - haberlo
# dicho - decir
# ya - ya
# , - ,
# en - en
# otra - otro
# ocasion - ocasion
# . - .
# No - No
# importa - importar
# : - :
# las - los
# frases - frase
# son - ser
# las - los
#
#  -
#
# mismas - mismo
# , - ,
# cuando - cuando
# es - ser
# idéntica - idéntico
# la - lo
# situacion - situacion
# . - .
#
#
#  -
#
#
# En - En
# el - el
# momento - momento
# que - que
# Mauricio - Mauricio
# preparaba - preparar
# la - lo
# realizacion - realizacion
# de - de
# tan - tan
# lisongero - lisongero
#
#  -
#
# propósito - propósito
# , - ,
# una - uno
# carta - carta
# de - de
# Buenos - Buenos
# Aires - Aires
# , - ,
# portadora - portador
# de - de
# fatales - fatal
# nuevas - nuevo
# , - ,
# vino - venir
#
#  -
#
# á - á
# destruir - destruir
# sus - su
# proyectos - proyecto
# y - y
# sus - su
# esperanzas - esperanzar
# . - .
#
#
#    -
#
#
# « - «
# Deber - Deber
# del - del
# hombre - hombre
# es - ser
# ser - ser
# fuerte - fuerte
# y - y
# resignado - resignar
# , - ,
# mi - mi
# querido - querer
#
#    -
#
# Mauricio--decía - Mauricio--decía
# el - el
# escribano - escribano
# D - D
# ... - ...
# en - en
# aquella - aquel
# carta.--Por - carta.--Por
# tanto - tanto
# , - ,
#
#    -
#
# valor - valor
# y - y
# resignacion - resignacion
# . - .
#
#
#    -
#
#
# « - «
# El - El
# padre - padre
# de - de
# Vd. - -PRON-
# ha - haber
# muerto - morir
# . - .
#
#
#    -
#
#
# « - «
# Envuelto - Envuelto
# en - en
# una - uno
# quiebra - quebrar
# producida - producir
# por - por
# la - lo
# fuga - fugar
# de - de
# un - uno
# sócio - sócio
# bribon - bribon
# , - ,
#
#    -
#
# falleció - fallecer
# víctima - víctima
# de - de
# una - uno
# congestion - congestion
# fulminante - fulminante
# . - .
#
#
#    -
#
#
# « - «
# Los - Los
# acreedores - acreedor
# se - se
# presentaron - presentar
# munidos - munidos
# de - de
# sus - su
# derechos - derecho
# , - ,
# y - y
#
#    -
#
# obtuvieron - obtener
# la - lo
# liquidacion - liquidacion
# . - .
#
#
#    -
#
#
# « - «
# Pero - Pero
# como - comer
# el - el
# sócio - sócio
# ( - (
# hermano - hermanar
# de - de
# la - lo
# señora - señor
# Ridel - Ridel
# ) - )
# había - haber
# sustraido - sustraido
#
#    -
#
# en - en
# su - su
# fuga - fugar
# todo - todo
# el - el
# numerario - numerario
# existente - existente
# en - en
# caja - caja
# , - ,
# quedó - quedar
# un - uno
# enorme - enorme
#
#    -
#
# pasivo - pasivo
# , - ,
# que - que
# toda - todo
# la - lo
# fortuna - fortuna
# particular - particular
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# no - no
# ha - haber
# sido - ser
#
#    -
#
# bastante - bastante
# á - á
# cubrir - cubrir
# . - .
#
#
#    -
#
#
# « - «
# Bajo - Bajo
# el - el
# peso - pesar
# de - de
# tres - tres
# catástrofes - catástrofe
# : - :
# la - lo
# infame - infamar
# fuga - fugar
# de - de
# aquel - aquel
# hermano - hermanar
# , - ,
#
#    -
#
# impuesto - imponer
# por - por
# ella - él
# á - á
# la - lo
# sumision - sumision
# de - de
# su - su
# marido - maridar
# ; - ;
# la - lo
# súbita - súbito
# muerte - muerte
# de - de
#
#    -
#
# éste - este
# , - ,
# y - y
# la - lo
# miseria - miseria
# que - que
# le - le
# aparecía - aparecer
# con - con
# su - su
# séquito - séquito
# de - de
# humillaciones - humillación
# , - ,
#
#    -
#
# la - lo
# desventurada - desventurado
# mujer - mujer
# enloqueció - enloquecer
# . - .
#
#
#    -
#
#
# « - «
# Silenciosa - Silenciosa
# , - ,
# sin - sin
# lágrimas - lágrima
# , - ,
# huraño - huraño
# el - el
# ademan - ademar
# y - y
# fija - fijo
# la - lo
# mirada - mirar
# , - ,
#
#    -
#
# escuchó - escuchar
# la - lo
# intimacion - intimacion
# de - de
# desalojo - desalojar
# ; - ;
# y - y
# cuando - cuando
# intentaron - intentar
# hacerla - hacerla
#
#    -
#
# salir - salir
# de - de
# su - su
# casa - casar
# , - ,
# subióse - subióse
# á - á
# lo - el
# alto - alto
# del - del
# mirador - mirador
# que - que
# coronaba - coronar
# el - el
#
#    -
#
# ...
# . - .
# Bastaría - Bastaría
# un - uno
# documento - documentar
# del - del
# señor - señor
# , - ,
# con - con
# la - lo
#
#  -
#
# declaracion - declaracion
# de - de
# único - único
# heredero - heredero
# ; - ;
# el - el
# certificado - certificar
# del - del
# médico - médico
# y - y
# la - lo
# partida - partir
#
#  -
#
# de - de
# defuncion - defuncion
# . - .
# Veremos - Veremos
# la - lo
# resolucion - resolucion
# del - del
# Directorio - Directorio
# . - .
# Si - Si
# fuera - ser
# favorable - favorable
# , - ,
#
#  -
#
# para - parir
# llenar - llenar
# ciertas - cierto
# fórmulas - fórmula
# , - ,
# se - se
# pondrán - poner
# avisos - aviso
# por - por
# seis - seis
# dias - dias
# , - ,
#
#  -
#
# solicitando - solicitar
# la - lo
# póliza - póliza
# de - de
# vida - vida
# del - del
# señor - señor
# Cárlos - Cárlos
# Ridel - Ridel
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# XXX - XXX
#
#
#
#  -
#
#
#
# Antes - Antes
# de - de
# aquel - aquel
# término - término
# el - el
# Gerente - Gerente
# de - de
# « - «
# La - La
# Buenos - Buenos
# Aires - Aires
# » - »
# recibía - recibir
# una - uno
#
#  -
#
# citacion - citacion
# del - del
# Banco - Banco
# Nacional - Nacional
# con - con
# motivo - motivar
# del - del
# aviso - avisar
# que - que
# por - por
# su - su
# órden - órden
#
#  -
#
# registraban - registrar
# « - «
# La - La
# Prensa - Prensa
# » - »
# y - y
# « - «
# La - La
# Tribuna - Tribuna
# Nacional - Nacional
# » - »
# . - .
#
#
#  -
#
#
# Acudió - Acudió
# el - el
# Gerente - Gerente
# , - ,
# y - y
# supo - saber
# que - que
# allí - allí
# se - se
# hallaba - hallar
# , - ,
# depositado - depositar
# por - por
# el - el
# señor - señor
#
#  -
#
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# un - uno
# paquete - paquete
# cerrado - cerrar
# , - ,
# que - que
# en - en
# Junio - Junio
# de - de
# 1888 - 1888
# debía - deber
# ser - ser
#
#  -
#
# entregado - entregar
# á - á
# la - lo
# Compañía - Compañía
# de - de
# Seguros - Seguros
# « - «
# La - La
# Buenos - Buenos
# Aires - Aires
# » - »
# . - .
#
#
#  -
#
#
# Abierto - Abierto
# el - el
# paquete - paquete
# , - ,
# encontráronse - encontráronse
# con - con
# la - lo
# póliza - póliza
# de - de
# seguro - seguro
# sobre - sobrar
# la - lo
# vida - vida
#
#  -
#
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# , - ,
# por - por
# 20,000 - 20,000
# $ - $
# m - metro
# / - /
# n - n
# . - .
# en - en
# 20 - 20
# años - año
# , - ,
# y - y
# en - en
# la - lo
# que - que
# constaba - constar
# el - el
#
#  -
#
# abono - abonar
# de - de
# la - lo
# primera - primero
# anualidad - anualidad
# de - de
# 792 - 792
# $ - $
# m - metro
# / - /
# n - n
# . - .
# ; - ;
# una - uno
# carta - carta
# á - á
# su - su
# esposa - esposo
# , - ,
# y - y
#
#  -
#
# en - en
# defecto - defecto
# de - de
# ésta - este
# , - ,
# á - á
# su - su
# hijo - hijo
# Mauricio - Mauricio
# ; - ;
# y - y
# una - uno
# letra - letra
# por - por
# 792 - 792
# $ - $
# m - metro
# / - /
# n - n
# . - .
# á - á
# la - lo
#
#  -
#
# órden - órden
# de - de
# Cárlos - Cárlos
# Ridel - Ridel
# y - y
# endosada - endosar
# por - por
# éste - este
# á - á
# « - «
# La - La
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
# como - comer
# la - lo
#
#  -
#
# segunda - segundar
# cuota - cuota
# que - que
# debía - deber
# pagar - pagar
# por - por
# su - su
# póliza - póliza
# . - .
#
#
#  -
#
#
# Mauricio - Mauricio
# leyó - leer
# la - lo
# carta - carta
# que - que
# acompañaba - acompañar
# estos - este
# documentos - documento
# . - .
#
#
#    -
#
#
# « - «
# Cuando - Cuando
# leas - leer
# estas - este
# líneas - líneo
# , - ,
# mi - mi
# bien - bien
# amada - amar
# Lucrecia,--decía - Lucrecia,--decía
# Ridel - Ridel
# á - á
#
#    -
#
# su - su
# esposa--muerto - esposa--muerto
# ó - ó
# vivo - vivir
# , - ,
# habrás - haber
# de - de
# perdonar - perdonar
# mi - mi
# primera - primero
# y - y
# única - único
#
#    -
#
# desobediencia - desobediencia
# , - ,
# en - en
# gracia - gracia
# del - del
# motivo - motivar
# que - que
# la - lo
# inspiró - inspirar
# ; - ;
# hélo - hélo
# aquí - aquí
# : - :
#
#
#    -
#
#
# « - «
# Tengo - Tengo
# por - por
# toda - todo
# institucion - institucion
# benéfica - benéfico
# , - ,
# la - lo
# más - más
# alta - alto
# estima - estimar
# ; - ;
# y - y
#
#    -
#
# profunda - profundo
# gratitud - gratitud
# por - por
# las - los
# que - que
# se - se
# levantan - levantar
# en - en
# nuestro - nuestro
# país - país
# . - .
#
#
#    -
#
#
# « - «
# Entre - Entre
# estas - este
# , - ,
# las - los
# Compañías - Compañías
# de - de
# Seguros - Seguros
# sónme - sónme
# especialmente - especialmente
#
#    -
#
# simpáticas - simpático
# , - ,
# sobretodo - sobretodo
# , - ,
# « - «
# La - La
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
# por - por
# su - su
# importancia - importancia
# y - y
#
#    -
#
# valiosa - valioso
# organizacion - organizacion
# . - .
#
#
#    -
#
#
# « - «
# Así - Así
# , - ,
# en - en
# tanto - tanto
# que - que
# me - me
# permitas - permitir
# ser - ser
# su - su
# accionista - accionista
# , - ,
# he - haber
# querido - querer
#
#    -
#
# pertenecerle - pertenecerle
# , - ,
# al - al
# menos - menos
# , - ,
# por - por
# un - uno
# seguro - seguro
# » - »
# ...... - ......
#
#
#  -
#
#
# Mauricio - Mauricio
# no - no
# pudo - poder
# leer - leer
# más - más
# . - .
#
#
#  -
#
#
# Una - Una
# ola - ola
# amarga - amargo
# subió - subir
# á - á
# su - su
# corazon - corazon
# despertando - despertar
# todos - todo
# los - lo
# antiguos - antiguo
#
#  -
#
# dolores - dolor
# filiales - filial
# . - .
#
#
#  -
#
#
# En - En
# la - lo
# vida - vida
# como - comer
# en - en
# la - lo
# eternidad - eternidad
# , - ,
# siempre - siempre
# la - lo
# sombra - sombrar
# fatídica - fatídico
# de - de
# su - su
#
#  -
#
# madrastra - madrastra
# venía - venir
# á - á
# colocarse - colocarse
# entre - entrar
# él - él
# y - y
# su - su
# padre - padre
# .... - ....
#
#
#  -
#
#
# Pero - Pero
# , - ,
# luego - luego
# , - ,
# la - lo
# imágen - imágen
# de - de
# Julia - Julia
# , - ,
# como - comer
# un - uno
# rayo - rayar
# de - de
# luz - luz
# , - ,
# borró - borrar
# aquella - aquel
#
#  -
#
# penosa - penoso
# impresion - impresion
# . - .
#
#
#
#
#
#  -
#
#
#
#
#
# XXXI - XXXI
#
#
#
#  -
#
#
#
# --La - --La
# Capilla - Capilla
# de - de
# Nuestra - Nuestra
# Señora - Señora
# de - de
# las - los
# Victorias - Victorias
# tenía - tener
# hoy - hoy
# un - uno
# aspecto - aspecto
#
#  -
#
# imponente - imponente
# . - .
# Llenábala - Llenábala
# el - el
# cortejo - cortejar
# de - de
# una - uno
# boda.-- - boda.--
#
#
#  -
#
#
# Así - Así
# llegaron - llegar
# diciendo - decir
# las - los
# jóvenes - joven
# de - de
# vuelta - volver
# de - de
# misa - misa
# de - de
# ocho - ocho
# . - .
#
#
#  -
#
#
# ¡ - ¡
# Una - Una
# boda - boda
# ! - !
# Suena - Suena
# tan - tan
# bien - bien
# esta - este
# mágica - mágico
# palabra - palabra
# , - ,
# que - que
# muy - muy
# luego - luego
# tuvo - tener
# toda - todo
#
#  -
#
# la - lo
# casa - casar
# por - por
# auditorio - auditorio
# . - .
#
#
#  -
#
#
# Y - Y
# las - los
# jóvenes - joven
# continuaban - continuar
# , - ,
# y - y
# en - en
# su - su
# entusiasta - entusiasta
# lenguaje - lenguaje
# : - :
#
#
#  -
#
#
# --¡Qué - --¡Qué
# bella - bello
# pareja!--decían - pareja!--decían
# . - .
#
#
#  -
#
#
# --El - --El
# , - ,
# todo - todo
# un - uno
# buen - bueno
# mozo - mozo
# ; - ;
# con - con
# un - uno
# aire - aire
# tan - tan
# sério - sério
# y - y
# distinguido - distinguir
# . - .
#
#
#  -
#
#
# --¡Ella - --¡Ella
# ! - !
# ¡ - ¡
# morena - moreno
# más - más
# linda - lindo
# ! - !
# Qué - Qué
# alianza - alianza
# encantadora - encantador
# de - de
# lo - el
# blanco - blanco
# de - de
# la - lo
#
#  -
#
# piel - piel
# y - y
# lo - el
# negro - negro
# de - de
# ojos - ojo
# y - y
# cabellos - cabello
# ! - !
#
#
#  -
#
#
# --¡Muchachas - --¡Muchachas
# ! - !
# ¡ - ¡
# no - no
# hay - haber
# que - que
# exagerar - exagerar
# ! - !
#
#
#  -
#
#
# --¡Oh - --¡Oh
# ! - !
# si - si
# nada - nadar
# hemos - hemo
# dicho - decir
# todavía - todavía
# . - .
# Escucha.-- - Escucha.--
#
#
#  -
#
#
# Y - Y
# dejando - dejar
# por - por
# aquí - aquí
# y - y
# por - por
# allí - allí
# , - ,
# sombreros - sombrero
# , - ,
# guantes - guante
# y - y
# abanicos - abanico
# , - ,
#
#  -
#
# continuaron - continuar
# , - ,
# quitándose - quitándose
# unas - uno
# á - á
# otras - otro
# la - lo
# palabra - palabra
# : - :
#
#
#  -
#
#
# --Que - --Que
# bien - bien
# estaba - estar
# la - lo
# linda - lindo
# morocha - morocha
# , - ,
# en - en
# su - su
# vestido - vestir
# de - de
# faya - faya
# , - ,
# tan - tan
# sencillo - sencillo
#
#  -
#
# como - comer
# elegante - elegante
# , - ,
# y - y
# su - su
# velo - velar
# de - de
# tul - tul
# de - de
# seda - sedar
# liso - liso
# : - :
# el - el
# todo - todo
# sin - sin
# más - más
# adornos - adorno
#
#  -
#
# que - que
# azahares - azahar
# naturales - natural
# . - .
#
#
#  -
#
#
# --Un - --Un
# pié - piar
# de - de
# Cendrillon - Cendrillon
# calzando - calzar
# un - uno
# zapatito - zapatito
# de - de
# raso - rasar
# blanco - blanco
# , - ,
# adornado - adornar
#
#  -
#
# tambien - tambien
# con - con
# azahares - azahar
# . - .
#
#
#  -
#
#
# --Un - --Un
# precioso - precioso
# abanico - abanicar
# formado - formar
# de - de
# mariposas - mariposa
# trasparentes - trasparente
# : - :
# y - y
# chico - chico
# , - ,
# á - á
# la - lo
#
#  -
#
# última - último
# moda - moda
# . - .
#
#
#  -
#
#
# --Pocas - --Pocas
# señoras - señor
# ; - ;
# muy - muy
# elegantes - elegante
# todas - todo
# . - .
#
#
#  -
#
#
# --Pero - --Pero
# ¡ - ¡
# qué - qué
# gran - gran
# séquito - séquito
# de - de
# caballeros - caballero
# ! - !
# Toda - Toda
# la - lo
# prensa - prensar
# : - :
# el - el
# general - general
#
#  -
#
# Mitre - Mitre
# , - ,
# Bartolito - Bartolito
# , - ,
# Dávila - Dávila
# , - ,
# Lainez - Lainez
# , - ,
# Vedia - Vedia
# , - ,
# Laurencena - Laurencena
# , - ,
# Lalanne - Lalanne
# , - ,
# Walls - Walls
# , - ,
#
#  -
#
# Ribaumont - Ribaumont
# , - ,
# Ortega - Ortega
# , - ,
# Alberú - Alberú
# , - ,
# Mulhall - Mulhall
# y - y
# tantos - tanto
# otros - otro
# . - .
#
#
#  -
#
#
# --Estaban - --Estaban
# tambien - tambien
# Eduardo - Eduardo
# Coll - Coll
# y - y
# Emilio - Emilio
# Casares - Casares
# que - que
# fué - fué
# el - el
# padrino - padrino
# y - y
#
#  -
#
# que - que
# dicen - decir
# ha - haber
# hecho - hacer
# un - uno
# régio - régio
# obsequio - obsequiar
# á - á
# la - lo
# novia - novio
# . - .
#
#
#  -
#
#
# --Muchos - --Muchos
# literatos - literato
# ; - ;
# el - el
# general - general
# Sarmiento - Sarmiento
# , - ,
# Santiago - Santiago
# Estrada - Estrada
# , - ,
# José - José
# María - María
#
#  -
#
# Zuviría - Zuviría
# , - ,
# el - el
# ministro - ministro
# de - de
# Bolivia - Bolivia
# doctor - doctor
# Vaca - Vaca
# Guzman - Guzman
# y - y
# tantos - tanto
# otros - otro
# , - ,
#
#  -
#
# hija - hijo
# , - ,
# que - que
# yo - yo
# no - no
# conozco - conocer
# . - .
# Apenas - Apenas
# cabíamos - caber
# en - en
# la - lo
# capilla - capilla
# . - .
#
#
#  -
#
#
# --El - --El
# celebrante - celebrante
# , - ,
# que - que
# era - ser
# el - el
# elocuentísimo - elocuentísimo
# padre - padre
# Pera - Pera
# unió - unir
# á - á
# los - lo
#
#  -
#
# contrayentes - contrayente
# con - con
# las - los
# palabras - palabra
# sacramentales - sacramental
# , - ,
# pronunciadas - pronunciar
# con - con
# uncion - uncion
#
#  -
#
# conmovedora - conmovedor
# . - .
#
#
#  -
#
#
# Despues - Despues
# , - ,
# volviéndose - volviéndose
# al - al
# auditorio - auditorio
# , - ,
# habló - hablar
# de - de
# la - lo
# excelencia - excelencia
# del - del
#
#  -
#
# matrimonio - matrimoniar
# , - ,
# de - de
# su - su
# orígen - orígen
# divino - divino
# , - ,
# de - de
# su - su
# utilidad - utilidad
# en - en
# la - lo
# comunion - comunion
# humana - humano
# , - ,
#
#  -
#
# de - de
# la - lo
# santidad - santidad
# de - de
# su - su
# fin - fin
# , - ,
# del - del
# viático - viático
# de - de
# virtudes - virtud
# que - que
# á - á
# él - él
# debe - deber
#
#  -
#
# llevarse - llevarse
# . - .
#
#
#  -
#
#
# --Señores,--añadió--permitidme - --Señores,--añadió--permitidme
# presentaros - presentaros
# un - uno
# modelo - modelar
# de - de
# esas - ese
# virtudes - virtud
#
#  -
#
# en - en
# los - lo
# cónyugues - cónyugues
# que - que
# acabo - acabar
# de - de
# unir - unir
# : - :
# dos - do
# hijos - hijo
# animosos - animoso
# del - del
# trabajo - trabajar
# . - .
#
#  -
#
# El - El
# uno - unir
# , - ,
# despojándose - despojándose
# de - de
# una - uno
# gran - gran
# fortuna - fortuna
# para - parir
# salvar - salvar
# de - de
# la - lo
# deshonra - deshonrar
#
#  -
#
# la - lo
# memoria - memoria
# de - de
# un - uno
# padre - padre
# ; - ;
# el - el
# otro - otro
# , - ,
# en - en
# la - lo
# débil - débil
# adolescencia - adolescencia
# , - ,
# luchando - luchar
#
#  -
#
# valerosamente - valerosamente
# con - con
# las - los
# dificultades - dificultad
# de - de
# la - lo
# vida - vida
# y - y
# el - el
# desamparo - desamparar
# de - de
# la - lo
#
#  -
#
# orfandad - orfandad
# . - .
#
#
#  -
#
#
# Se - Se
# amaban - amar
# . - .
# Libres - Libres
# , - ,
# podían - poder
# unirse - unirse
# el - el
# uno - unir
# al - al
# otro - otro
# . - .
#
#
#  -
#
#
# Pero - Pero
# eran - ser
# pobres - pobre
# ; - ;
# y - y
# en - en
# la - lo
# rectitud - rectitud
# de - de
# su - su
# corazon - corazon
# , - ,
# querían - querer
# preparar - preparar
# el - el
#
#  -
#
# hogar - hogar
# , - ,
# antes - antes
# de - de
# traer - traer
# la - lo
# familia - familia
# ; - ;
# y - y
# dados - dar
# al - al
# trabajo - trabajar
# , - ,
# aguardaban - aguardar
# , - ,
# en - en
#
#  -
#
# ese - ese
# penoso - penoso
# retardo - retardar
# á - á
# su - su
# dicha - decir
# , - ,
# resignados - resignar
# , - ,
# confiando - confiar
# en - en
# Dios - Dios
# y - y
# en - en
# la - lo
#
#  -
#
# fortaleza - fortaleza
# de - de
# sus - su
# almas - alma
# . - .
#
#
#  -
#
#
# Mas - Mas
# , - ,
# no - no
# en - en
# vano - vano
# confiaron - confiar
# en - en
# « - «
# Aquel - Aquel
# que - que
# forma - formar
# de - de
# las - los
# piedras - piedra
# hijos - hijo
# á - á
#
#  -
#
# Abraham - Abraham
# » - »
# .... - ....
#
#
#  -
#
#
# Existen - Existen
# varias - varios
# instituciones - institución
# creadas - crear
# con - con
# capitales - capital
# formados - formar
# por - por
# la - lo
#
#  -
#
# honradez - honradez
# y - y
# el - el
# trabajo - trabajar
# , - ,
# que - que
# con - con
# el - el
# modesto - modesto
# nombre - nombrar
# de - de
# Compañías - Compañías
# de - de
#
#  -
#
# Seguros - Seguros
# , - ,
# ejercen - ejercer
# la - lo
# más - más
# benéfica - benéfico
# influencia - influenciar
# en - en
# la - lo
# vida - vida
# económica - económico
# de - de
# los - lo
#
#  -
#
# pueblos - pueblo
# ; - ;
# porque - porque
# , - ,
# cualquiera - cualquiera
# que - que
# sea - ser
# la - lo
# forma - formar
# en - en
# que - que
# se - se
# tome - tomar
# , - ,
# el - el
# seguro - seguro
#
#  -
#
# encierra - encerrar
# el - el
# bienestar - bienestar
# futuro - futuro
# de - de
# la - lo
# familia - familia
# . - .
#
#
#  -
#
#
# En - En
# el - el
# seno - seno
# de - de
# una - uno
# de - de
# esas - ese
# asociaciones - asociación
# tutelares - tutelar
# , - ,
# « - «
# La - La
# Buenos - Buenos
# Aires - Aires
# » - »
# , - ,
#
#  -
#
# la - lo
# Providencia - Providencia
# guardaba - guardar
# un - uno
# tesoro - tesoro
# que - que
# á - á
# su - su
# hora - hora
# , - ,
# hizo - hacer
# surgir - surgir
# para - parir
#
#  -
#
# recompensar - recompensar
# la - lo
# abnegacion - abnegacion
# filial - filial
# y - y
# dar - dar
# la - lo
# felicidad - felicidad
# á - á
# los - lo
# que - que
# , - ,
#
#  -
#
# creyendo - creer
# en - en
# ella - él
# , - ,
# esperaban - esperar
# . - .
#
#
#  -
#
#
# --¡Que - --¡Que
# el - el
# Altísimo - Altísimo
# os - o
# bendiga!-- - bendiga!--
#
#
#  -
#
#
# Y - Y
# cayendo - caer
# de - de
# rodillas - rodilla
# , - ,
# el - el
# hombre - hombre
# de - de
# Dios - Dios
# se - se
# absorbió - absorber
# en - en
# mental - mental
#
#  -
#
# plegaria - plegaria
# .... - ....
#
#
#  -
#
#
# --Corrimos - --Corrimos
# al - al
# pórtico - pórtico
# para - parir
# ver - ver
# el - el
# desfile - desfilar
# de - de
# la - lo
# comitiva - comitiva
# . - .
#
#
#  -
#
#
# Veinte - Veinte
# carruajes - carruaje
# aguardaban - aguardar
# alineados - alinear
# , - ,
# al - al
# borde - bordar
# de - de
# la - lo
# vereda - vereda
# . - .
#
#
#  -
#
#
# Los - Los
# esposos - esposo
# , - ,
# entrelazados - entrelazar
# los - lo
# brazos - brazo
# , - ,
# salieron - salir
# seguidos - seguir
# del - del
# cortejo - cortejar
# , - ,
#
#  -
#
# que - que
# se - se
# reunió - reunir
# delante - delante
# del - del
# coche - coche
# nupcial - nupcial
# . - .
#
#
#  -
#
#
# El - El
# novio - novio
# estrechando - estrechar
# con - con
# efusion - efusion
# la - lo
# mano - manir
# á - á
# Coll - Coll
# . - .
#
#
#  -
#
#
# --¡Noble - --¡Noble
# corazon!--le - corazon!--le
# dijo--¡que - dijo--¡que
# el - el
# espectáculo - espectáculo
# de - de
# nuestra - nuestro
# felicidad - felicidad
#
#  -
#
# sea - ser
# su - su
# recompensa - recompensar
# ! - !
#
#
#  -
#
#
# Y - Y
# volviéndose - volviéndose
# á - á
# la - lo
# comitiva - comitiva
# cambió - cambiar
# con - con
# ella - él
# una - uno
# mirada - mirar
# de - de
# inteligencia - inteligencia
# ; - ;
#
#  -
#
# luego - luego
# dirigiéndose - dirigiéndose
# al - al
# cochero - cochero
# . - .
#
#
#  -
#
#
# --¡Al - --¡Al
# muelle - muelle
# de - de
# pasageros!--ordenó - pasageros!--ordenó
# . - .
#
#
#  -
#
#
# La - La
# novia - novio
# mirándolo - mirándolo
# sorprendida - sorprender
# . - .
#
#
#  -
#
#
# --¡Al - --¡Al
# muelle - muelle
# de - de
# pasageros!--repitió--¿Dónde - pasageros!--repitió--¿Dónde
# vamos - ir
# , - ,
# pues - pues
# ? - ?
#
#
#  -
#
#
# --A - --A
# Francia - Francia
# , - ,
# amada - amar
# mia - mia
# , - ,
# para - parir
# pedir - pedir
# al - al
# sepulcro - sepulcro
# los - lo
# restos - resto
# que - que
# lloras - llorar
# y - y
#
#  -
#
# devolverlos - devolverlos
# á - á
# la - lo
# tierra - tierra
# de - de
# la - lo
# patria - patrio
# . - .
#
#
#  -
#
#
# La - La
# jóven - jóven
# exhaló - exhalar
# un - uno
# gemido - gemir
# y - y
# arrojándose - arrojándose
# en - en
# los - lo
# brazos - brazo
# del - del
# esposo - esposar
# , - ,
#
#  -
#
# escondió - esconder
# la - lo
# frente - frente
# en - en
# su - su
# seno - seno
# . - .
#
#
#  -
#
#
# Todos - Todos
# lloramos - llorar
# .... - ....
#
#
#  -
#
#
# Yo - Yo
# tambien - tambien
# lloraba - llorar
# . - .
