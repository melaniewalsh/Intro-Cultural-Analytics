# %% [markdown]
# # Part-of-Speech Tagging for Spanish

# %% [markdown]
# <div class="admonition note" name="html-admonition" style="background: lightblue; padding: 10px">
# <p class="title">Note</p>
# This section, "Working in Languages Beyond English," is authored by <a href="https://dlcl.stanford.edu/people/quinn-dombrowski/">Quinn Dombrowski</a>, the Academic Technology Specialist at Stanford University and a leading voice in multilingual digital humanities. I'm grateful to Quinn for helping expand this textbook to serve languages beyond English.
# </div>

# %% [markdown]
# In this lesson, we're going to learn about the textual analysis methods *part-of-speech tagging* and *keyword extraction*. These methods will help us computationally parse sentences and better understand words in context.

# %% [markdown]
# ---

# %% [markdown]
# ## spaCy and Natural Language Processing (NLP)

# %% [markdown]
# To computationally identify parts of speech, we're going to use the natural language processing library spaCy. For a more extensive introduction to NLP and spaCy, see the previous lesson.
#
# To parse sentences, spaCy relies on machine learning models that were trained on large amounts of labeled text data. If you've used the preprocessing or named entity recognition notebooks for this language, you can skip the steps for installing spaCy and downloading the language model.

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.

# %%
# !pip install -U spacy

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# We're also going to import the `Counter` module for counting nouns, verbs, adjectives, etc., and the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the Spanish-language model (`es_core_news_md`), which will be processing and making predictions about our texts. This is the model that was trained on the annotated ["AnCora" corpus](http://clic.ub.edu/corpus/). You can download the `es_core_news_md` model by running the cell below:

# %%
# !python -m spacy download es_core_news_md

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Italian, Dutch, Greek, Norwegian, and Lithuanian. Languages such as Russian, Ukrainian, Thai, Chinese, Japanese, Korean and Vietnamese don't currently have their own NLP models. However, spaCy offers language and tokenization support for many of these language with external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean or [Jieba](https://github.com/fxsjy/jieba) for Chinese.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('es_core_news_md')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# Whenever we use spaCy, our first step will be to create a processed spaCy `document` with the loaded NLP model `nlp()`. Most of the heavy NLP lifting is done in this line of code. After processing, the `document` object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.

# %%
filepath = '../texts/other-languages/es.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %% [markdown]
# ## spaCy Part-of-Speech Tagging
# The tags that spaCy uses for part-of-speech are based on work done by [Universal Dependencies](https://universaldependencies.org/), an effort to create a set of part-of-speech tags that work across many different languages. Texts from various languages are annotated using this common set of tags, and contributed to a common repository that can be used to train models like spaCy.
#
# The Universal Dependencies page has information about the annotated corpora available for each language; it's worth looking into the corpora that were annotated for your language.

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# Above is a POS chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different parts of speech that spaCy can identify as well as their corresponding labels. To quickly see spaCy's POS tagging in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) on our sample `document` with the `style=` parameter set to "dep" (short for dependency parsing):

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.lemma_` attribute for each token, which gives us the un-inflected version of the word. We'll also pull out the  `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.lemma_, token.pos_, token.dep_)
# Out:
# ﻿INTRODUCCION PROPN ROOT
# . PUNCT punct
#
#
#
#  SPACE
# ECONOMÍA NOUN ROOT
# POLÍTICA ADV flat
# . PUNCT punct
#
#
#  SPACE
# El DET det
# sombrío ADJ amod
# Prudhon PROPN nsubj
# , PUNCT punct
# imbuído ADJ ROOT
# , PUNCT punct
# sin ADP advmod
# dudar INTJ fixed
# , PUNCT punct
# en ADP case
# los DET det
# ideo NOUN obl
# de ADP case
# lo DET det
# Santos PROPN nmod
#
#  SPACE
# Padres NOUN flat
# de ADP case
# lo DET det
# Iglesia PROPN nmod
# que SCONJ nsubj
# predicar AUX acl
# el DET det
# desden ADP obj
# por ADP case
# lo DET det
# bien NOUN obl
#
#  SPACE
# terrenal ADJ amod
# , PUNCT punct
# decir AUX conj
# que SCONJ mark
# lo DET det
# pobreza NOUN nsubj
# ser AUX cop
# uno DET det
# ley NOUN ccomp
# de ADP case
# nuestro DET det
# naturaleza NOUN nmod
# , PUNCT punct
#
#  SPACE
# ley NOUN appos
# bajar ADP case
# lo DET det
# cual PRON obl
# hemo AUX aux
# ser VERB aux
# constituídos VERB acl
# , PUNCT punct
# de ADP case
# donde PRON obl
# se PRON obj
# deducir VERB advcl
# que SCONJ mark
# el DET det
#
#  SPACE
# pauperismo NOUN nsubj
# ser AUX cop
# mal ADJ ccomp
# que SCONJ mark
# no ADV advmod
# tener VERB csubj
# remediar NOUN obj
# ni CCONJ cc
# curar NOUN conj
# . PUNCT punct
#
#
#  SPACE
# Muy ADV advmod
# desconsolar ADJ advmod
# deber VERB aux
# quedar VERB ROOT
# lo DET det
# menesteroso ADJ obj
# con ADP case
# tan ADV advmod
# ingrato ADJ amod
#
#  SPACE
# noticiar NOUN obj
# , PUNCT punct
# pero CCONJ cc
# lo DET det
# actividad NOUN nsubj
# humano ADJ amod
# , PUNCT punct
# que SCONJ nsubj
# no ADV advmod
# siempre ADV advmod
# se PRON obj
# llevar VERB acl
# de ADP case
# teoría NOUN obl
# , PUNCT punct
#
#  SPACE
# haber AUX aux
# venir VERB conj
# á ADP mark
# confortar VERB xcomp
# á ADP case
# lo DET det
# aflijidos NOUN obj
# trayéndoles ADJ advcl
# más ADV advmod
# plausible ADJ obj
# nuevo ADJ amod
#
#  SPACE
# y CCONJ cc
# muy ADV advmod
# eficaz ADJ amod
# promesa NOUN conj
# . PUNCT punct
# La DET det
# industriar NOUN nsubj
# , PUNCT punct
# con ADP case
# su DET det
# innúmero ADJ amod
# palanca NOUN nmod
# de ADP case
#
#  SPACE
# impulsion PROPN nmod
# ; PUNCT punct
# los DET det
# ciencia NOUN appos
# , PUNCT punct
# con ADP case
# su DET det
# multiplicar ADJ amod
# alfiler NOUN nmod
# de ADP case
# exámen NOUN nmod
# ; PUNCT punct
# el DET det
#
#  SPACE
# cálculo NOUN appos
# , PUNCT punct
# con ADP case
# su DET det
# prevision NOUN nmod
# y CCONJ cc
# su DET det
# aritmético NOUN conj
# ; PUNCT punct
# todo DET det
# este DET det
# agente NOUN appos
# de ADP case
# lo DET det
#
#  SPACE
# vitalidad NOUN nmod
# social ADJ amod
# , PUNCT punct
# haber VERB aux
# venir VERB ROOT
# á ADP mark
# operar VERB xcomp
# el DET det
# milagro NOUN obj
# de ADP case
# lo DET det
# multiplicacion PROPN nmod
#
#  SPACE
# del ADP case
# pan NOUN nmod
# y CCONJ cc
# el DET det
# aumentar NOUN conj
# del ADP case
# venir NOUN nmod
# , PUNCT punct
# sustentar VERB advcl
# anchamente ADV advmod
# á ADP case
# lo DET det
# hambriento NOUN obj
#
#  SPACE
# y CCONJ cc
# engordar VERB conj
# , PUNCT punct
# hasta ADP case
# más ADV advmod
# no ADV advmod
# poder VERB advcl
# , PUNCT punct
# á ADP case
# lo DET det
# harto NOUN obl
# . PUNCT punct
#
#
#  SPACE
# La DET det
# manera NOUN nsubj
# de ADP mark
# realizar VERB acl
# el DET det
# prodigio NOUN obj
# el PRON obj
# haber AUX aux
# dar VERB ROOT
# á ADP case
# conocer VERB compound
# ese DET det
# venerable ADJ amod
#
#  SPACE
# matrona NOUN nsubj
# , PUNCT punct
# que SCONJ mark
# lo DET det
# entendido ADJ nsubj
# en ADP case
# materia NOUN obl
# grave ADJ amod
# creer VERB advcl
# que SCONJ mark
# denominar AUX ccomp
#
#  SPACE
# _ NUM obj
# Economía PROPN nsubj
# político ADJ flat
# _ NUM nsubj
# . PUNCT punct
# Esta DET det
# tutriz NOUN nsubj
# moralizador ADJ amod
# de ADP case
# lo DET det
# sociedad NOUN nmod
# , PUNCT punct
#
#  SPACE
# evidenciar VERB advcl
# lo DET det
# fecundidad NOUN obj
# del ADP case
# trabajar NOUN nmod
# y CCONJ cc
# lo DET det
# beneficio NOUN conj
# del ADP case
# ahorrar NOUN nmod
# , PUNCT punct
# se PRON iobj
#
#  SPACE
# haber AUX aux
# proponer VERB ROOT
# dignificar VERB xcomp
# al ADP case
# hombre NOUN obj
# otorgándole VERB xcomp
# lo DET det
# medio NOUN obj
# de ADP mark
# sacudir VERB acl
# el DET det
#
#  SPACE
# vasallaje NOUN obj
# servil NOUN nmod
# de ADP case
# lo DET det
# indigencia NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# El DET det
# ahorrar NOUN nsubj
# , PUNCT punct
# tomar VERB acl
# formar NOUN obj
# colectivo ADJ amod
# , PUNCT punct
# haber AUX aux
# dar VERB ROOT
# orígen NOUN obj
# á ADP case
# lo DET det
# más ADV advmod
# precioso ADJ obj
# de ADP case
#
#  SPACE
# los DET det
# combinación NOUN nmod
# especulativo ADJ amod
# : PUNCT punct
# á ADP mark
# lo DET det
# que SCONJ nsubj
# tener VERB advcl
# por ADP case
# objetar NOUN obl
# asegurar VERB xcomp
# el DET det
#
#  SPACE
# bienestar NOUN obj
# individual ADJ amod
# en ADP case
# vida NOUN obl
# y CCONJ cc
# garantir VERB conj
# el DET det
# porvenir NOUN obj
# de ADP mark
# lo DET det
# que SCONJ nsubj
# quedar AUX acl
# , PUNCT punct
#
#  SPACE
# despues PROPN obl
# de ADP case
# concluir ADJ obj
# lo DET det
# jornada NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Este DET det
# temer NOUN nsubj
# , PUNCT punct
# abstracto ADJ amod
# de ADP case
# suyo DET nmod
# , PUNCT punct
# y CCONJ cc
# que SCONJ nsubj
# parecer AUX conj
# ageno NOUN xcomp
# al ADP case
# dominio NOUN obj
# del ADP case
# arte NOUN nmod
# , PUNCT punct
#
#  SPACE
# acabar AUX ROOT
# de ADP mark
# ser VERB aux
# desenvolver VERB xcomp
# por ADP case
# lo DET det
# ilustrar ADJ amod
# escritor NOUN obj
# cuyo PRON nmod
# nombrar NOUN nsubj
# ocupar VERB acl
# tan ADV advmod
#
#  SPACE
# elevar ADJ amod
# rango NOUN obj
# en ADP case
# lo DET det
# gerarquía PROPN obl
# del ADP case
# movimiento NOUN nmod
# intelectual ADJ amod
# americano ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Es AUX cop
# atributo NOUN ROOT
# de ADP case
# los DET det
# inteligencia NOUN nmod
# creador ADJ amod
# trasformar VERB advcl
# y CCONJ cc
# embellecer VERB conj
#
#  SPACE
# los DET det
# ideo NOUN obj
# que SCONJ nsubj
# pasar AUX acl
# por ADP case
# su DET det
# espíritu NOUN obj
# ; PUNCT punct
# parecer VERB advcl
# que SCONJ mark
# poseer VERB ccomp
# ese DET det
# don NOUN nsubj
#
#  SPACE
# vivificador NOUN flat
# de ADP case
# lo DET det
# lujurioso ADJ amod
# primavera NOUN nmod
# que SCONJ nsubj
# todo PRON det
# el PRON obj
# hermosear VERB nmod
# , PUNCT punct
# el PRON obj
# cubrir VERB advcl
# de ADP case
#
#  SPACE
# flor NOUN obl
# y CCONJ cc
# el PRON det
# esmaltar VERB conj
# de ADP case
# celaje NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Por ADP mark
# si SCONJ mark
# existir VERB ROOT
# incrédulo NOUN nsubj
# que SCONJ obj
# poner VERB acl
# en ADP case
# dudar NOUN compound
# el DET det
# aserto NOUN nsubj
# , PUNCT punct
# invocar ADJ amod
# por ADP case
#
#  SPACE
# testigo NOUN nmod
# , PUNCT punct
# en ADP case
# mi DET det
# abonar NOUN obl
# , PUNCT punct
# el DET det
# presentar ADJ amod
# librar NOUN appos
# . PUNCT punct
#
#
#  SPACE
# Su DET det
# autor NOUN nsubj
# comprobar VERB ROOT
# , PUNCT punct
# bajar ADP case
# lo DET det
# formar NOUN obl
# atrayente ADJ amod
# de ADP case
# lo DET det
# novelar NOUN nmod
# , PUNCT punct
# lo DET det
#
#  SPACE
# beneficio NOUN obj
# que SCONJ nsubj
# reportar AUX acl
# el DET det
# trabajar NOUN obj
# , PUNCT punct
# lo DET det
# perseverancia NOUN appos
# y CCONJ cc
# el DET det
# ahorrar NOUN conj
# ; PUNCT punct
# nunca ADV advmod
#
#  SPACE
# uno DET det
# temer NOUN nsubj
# económico ADJ amod
# haber AUX aux
# ser VERB aux
# tratar VERB advcl
# con ADP case
# más ADV advmod
# galanura NOUN obl
# , PUNCT punct
# con ADP case
# más ADV advmod
# gracia NOUN obl
#
#  SPACE
# picarezca PROPN amod
# , PUNCT punct
# ni CCONJ cc
# con ADP case
# más ADV advmod
# natural ADJ conj
# é CCONJ cc
# ingénua ADJ conj
# intrigar NOUN amod
# . PUNCT punct
#
#
#  SPACE
# Despues PROPN nsubj
# de ADP mark
# recorrer VERB acl
# este DET det
# trozar NOUN obj
# de ADP case
# historia NOUN nmod
# social ADJ amod
# , PUNCT punct
# cuyo PRON nmod
# tramar NOUN iobj
# lo PRON obj
# formar AUX acl
#
#  SPACE
# los DET det
# peripecia NOUN nsubj
# de ADP case
# do NUM nummod
# caractéres NOUN nmod
# noble ADJ amod
# y CCONJ cc
# fuerte ADJ conj
# , PUNCT punct
# se PRON obj
# encontrar VERB advcl
# no ADV advmod
# ser VERB ROOT
#
#  SPACE
# qué PRON obj
# de ADP case
# consolatorio NOUN nmod
# , PUNCT punct
# de ADP case
# purificador NOUN conj
# , PUNCT punct
# en ADP case
# mediar INTJ fixed
# de ADP fixed
# lo DET det
# arenoso NOUN amod
# senda NOUN obl
# por ADP case
#
#  SPACE
# donde PRON obl
# no PRON obj
# conducir VERB acl
# diariamente ADV advmod
# lo DET det
# manir NOUN nsubj
# de ADP case
# lo DET det
# tristeza NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Si SCONJ mark
# lo DET det
# mision NOUN nsubj
# de ADP case
# lo DET det
# cultores NOUN nmod
# privilegiar ADJ amod
# del ADP case
# arte NOUN nmod
# ser AUX cop
# lo DET ROOT
# de ADP mark
# alentar VERB acl
# , PUNCT punct
#
#  SPACE
# lo DET det
# de ADP case
# consolar NOUN dep
# , PUNCT punct
# lo DET det
# de ADP mark
# dilatar VERB acl
# el DET det
# horizonte NOUN obj
# de ADP case
# lo DET det
# esperanzar NOUN nmod
# , PUNCT punct
# lo DET det
#
#  SPACE
# prestigioso ADJ amod
# autor NOUN nsubj
# de ADP case
# este DET det
# página NOUN nmod
# haber AUX aux
# saber VERB advcl
# encerrar VERB xcomp
# en ADP case
# ellos PRON obl
# , PUNCT punct
#
#  SPACE
# suficiente ADJ amod
# rayo NOUN nsubj
# de ADP case
# luz NOUN nmod
# parir ADP mark
# satisfacer VERB acl
# lo DET det
# ansiedad NOUN obj
# de ADP case
# los DET det
# alma NOUN nmod
#
#  SPACE
# soñador ADJ amod
# , PUNCT punct
# y CCONJ cc
# bastante DET det
# rosa NOUN conj
# parir ADP mark
# coronar VERB acl
# , PUNCT punct
# aunque SCONJ mark
# ellos PRON nsubj
# no ADV advmod
# el PRON obj
# querer VERB advcl
# , PUNCT punct
#
#  SPACE
# lo DET det
# adusto ADJ amod
# efigie NOUN obj
# de ADP case
# lo DET det
# más ADV advmod
# hipocondríaco NOUN amod
# economista ADJ nmod
# . PUNCT punct
#
#
#                                                 SPACE
# S. PROPN ROOT
# VACA-GUZMAN PROPN flat
# . PUNCT punct
#
#
#      SPACE
# Diciembre INTJ ROOT
# 22 NUM compound
# de ADP case
# 1887 NUM compound
# . PUNCT punct
#
#
#
#
#
#                        SPACE
# OASIS NOUN ROOT
# EN ADP case
# LA DET det
# VIDA PROPN nmod
# . PUNCT punct
#
#
#                       SPACE
# Á INTJ cc
# « PUNCT punct
# LA DET det
# BUENOS PROPN ROOT
# AIRES PROPN flat
# » PUNCT punct
#
#
#                                        SPACE
# _ NUM ROOT
# LA DET det
# AUTORA NOUN nsubj
# . PUNCT punct
# _ VERB ROOT
#
#
#
#
#
#  SPACE
# OASIS NOUN appos
# EN ADP case
# LA DET det
# VIDA PROPN nmod
# . PUNCT punct
#
#
#
#
#
#  SPACE
# I CCONJ ROOT
#
#
#
#  SPACE
# --¡Bah!--exclamó PROPN flat
# Mauricio PROPN flat
# Ridel PROPN flat
# , PUNCT punct
# arrojar VERB acl
# lo DET det
# pluma NOUN obj
# despues INTJ amod
# de ADP mark
# escribir VERB acl
#
#  SPACE
# lo DET det
# palabra NOUN obj
# Fin PROPN appos
# bajar ADP case
# lo DET det
# último ADJ amod
# líneo NOUN obl
# de ADP case
# uno DET det
# cuartilla NOUN nmod
# marcar ADJ amod
# con ADP case
# el DET det
#
#  SPACE
# guarismo NOUN obj
# 60 NUM nummod
# . PUNCT punct
#
#
#  SPACE
# --¿Qué PROPN nsubj
# ser AUX cop
# eso?--interrogó NUM ROOT
# uno DET det
# jóven NOUN nsubj
# que SCONJ nsubj
# escribir AUX acl
# allí ADV advmod
# cercar ADV advmod
# . PUNCT punct
#
#
#  SPACE
# --El DET det
# postrer NOUN ROOT
# párrafo NOUN amod
# del ADP case
# folletin--respondió PROPN nmod
# Mauricio PROPN flat
# , PUNCT punct
# alargar VERB acl
# lo DET det
#
#  SPACE
# hoja NOUN obj
# á ADP case
# uno DET det
# cajista NOUN obj
# que SCONJ nsubj
# aguardar AUX acl
# . PUNCT punct
#
#
#  SPACE
# --¡Cómo NUM ROOT
# ! PUNCT punct
# ¿ PUNCT punct
# Mañana ADV advmod
# acabar VERB ROOT
# CHAMUSQUINAS ADJ nsubj
# DE ADP case
# AMOR PROPN obl
# ? PUNCT punct
# Hoy ADV advmod
# quedar AUX ROOT
# su DET det
# héroe NOUN nsubj
#
#  SPACE
# en ADP case
# uno DET det
# situacion NOUN obl
# extremo ADJ amod
# : PUNCT punct
# lo DET det
# manir NOUN nsubj
# armar ADJ amod
# de ADP case
# uno DET det
# revólver NOUN nmod
# , PUNCT punct
# esperar VERB advcl
#
#  SPACE
# parir ADP mark
# morir VERB advcl
# el DET det
# ﻿1 ADJ amod
# rayar NOUN obj
# de ADP case
# sol NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# ya ADV advmod
# , PUNCT punct
# este PRON nsubj
# comenzar VERB advcl
# á ADP mark
# dorar VERB xcomp
# los DET det
#
#  SPACE
# copar NOUN nsubj
# de ADP case
# lo DET det
# árbol NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# al ADP mark
# verlo VERB advcl
# , PUNCT punct
# « PUNCT punct
# Enrique PROPN nsubj
# apoyar VERB conj
# el DET det
# armar NOUN obj
# contra ADP case
# el DET det
#
#  SPACE
# corazon PROPN nmod
# , PUNCT punct
# enviar VERB advcl
# á ADP case
# María PROPN obj
# su DET det
# último ADJ amod
# pensamiento NOUN obj
# ; PUNCT punct
# á ADP case
# Dios PROPN obj
# su DET det
# último ADJ amod
#
#  SPACE
# plegaria ADJ flat
# . PUNCT punct
# »--¿Muere INTJ ROOT
# ? PUNCT punct
#
#
#  SPACE
# --No ADV ROOT
# ; PUNCT punct
# porque--«De INTJ advmod
# repente INTJ fixed
# , PUNCT punct
# uno DET det
# brazo NOUN nsubj
# cariñoso ADJ amod
# rodear VERB conj
# su DET det
# cuello NOUN obj
# ; PUNCT punct
# uno DET det
# rostro NOUN nsubj
#
#  SPACE
# pálido ADJ amod
# y CCONJ cc
# mojar ADJ conj
# de ADP case
# lágrima NOUN nmod
# se PRON obj
# apoyar VERB advcl
# en ADP case
# su DET det
# rostro NOUN obl
# ... PUNCT punct
#
#
#  SPACE
# --¡Perdon NUM obj
# ! PUNCT punct
#
#
#  SPACE
# --¡Perdon!--se PUNCT obj
# oír VERB ROOT
# á ADP case
# lo DET fixed
# vez INTJ obl
# ... PUNCT punct
#
#
#  SPACE
# « PUNCT ROOT
# Y CCONJ cc
# el DET det
# ﻿1 ADJ amod
# rayar NOUN conj
# de ADP case
# sol NOUN nmod
# aguardar ADJ amod
# comer SCONJ mark
# uno DET det
# señal NOUN obl
# de ADP case
# muerte NOUN nmod
# , PUNCT punct
# fué AUX cop
# lo DET det
#
#  SPACE
# aurora ADJ dep
# de ADP case
# su DET det
# felicidad NOUN nmod
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE
# --¡Bien NUM dep
# ! PUNCT punct
# ¡ PUNCT punct
# oh INTJ dep
# ! PUNCT ROOT
# ¡ PUNCT punct
# Qué PRON obj
# bien!--aplaudió VERB ROOT
# el DET det
# otro PRON nsubj
# ; PUNCT punct
# y CCONJ cc
# añadir VERB conj
# con ADP case
# dramático ADJ amod
#
#  SPACE
# ademar PROPN obj
# : PUNCT punct
#
#
#  SPACE
# --¡Ah VERB advmod
# ! PUNCT punct
# que SCONJ mark
# no ADV advmod
# haber VERB advcl
# parir ADP case
# nosotros PRON obl
# , PUNCT punct
# párias ADJ obl
# del ADP case
# destinar NOUN nmod
# , PUNCT punct
# ¡ PUNCT punct
# uno DET det
# rayar NOUN obj
# de ADP case
# sol NOUN nmod
#
#  SPACE
# que SCONJ nsubj
# venir VERB acl
# á ADP mark
# redimirnos VERB advcl
# ! PUNCT punct
#
#
#  SPACE
# --Sí PRON ROOT
# : PUNCT punct
# y CCONJ cc
# más ADV advmod
# que SCONJ fixed
# unir PRON conj
# : PUNCT punct
# dos--repuso NOUN dep
# Mauricio.--La PROPN case
# resignacion PROPN nmod
# y CCONJ cc
# el DET det
# trabajar NOUN conj
# . PUNCT punct
#
#
#  SPACE
# --¡La NOUN det
# resignacion PROPN nsubj
# ! PUNCT punct
# ¡ PUNCT punct
# el DET det
# trabajo!--replicó VERB appos
# el DET det
# interlocutor NOUN obj
# con ADP case
# forzar ADJ amod
#
#  SPACE
# risa.--Solo PUNCT flat
# tú PRON nmod
# poder AUX aux
# decir VERB ROOT
# ese PRON obj
# ; PUNCT punct
# tú PRON nsubj
# , PUNCT punct
# que SCONJ nsubj
# no ADV advmod
# contentar VERB acl
# con ADP case
# lo DET det
# tarea NOUN obl
#
#  SPACE
# diario ADJ amod
# , PUNCT punct
# lo DET obj
# haber AUX aux
# subir VERB advcl
# á ADP case
# catorce NUM nummod
# hora NOUN obl
# . PUNCT punct
# Catorce NUM nummod
# hora NOUN ROOT
# , PUNCT punct
# pluma NOUN appos
# en ADP case
# manir INTJ nmod
# , PUNCT punct
#
#  SPACE
# encorvar ADJ amod
# sobrar ADP case
# lo DET det
# implacable ADJ amod
# cuartilla NOUN obl
# , PUNCT punct
# y CCONJ cc
# precisamente ADV conj
# , PUNCT punct
# apenar ADV advmod
# en ADP case
#
#  SPACE
# convalecencia NOUN nmod
# de ADP case
# lo DET det
# terrible ADJ amod
# herir NOUN nmod
# que SCONJ nsubj
# casi ADV advmod
# te PRON obj
# llevar VERB acl
# al ADP case
# sepulcro NOUN obl
# . PUNCT punct
#
#
#  SPACE
# --Sin NUM det
# embargar NOUN nsubj
# , PUNCT punct
# ya ADV advmod
# el PRON det
# vés PROPN ROOT
# : PUNCT punct
# estar AUX cop
# sanar ADJ advcl
# y CCONJ cc
# fuerte ADJ conj
# . PUNCT punct
# Un DET det
# poco PRON ROOT
# de ADP case
# soñar NOUN nmod
# ; PUNCT punct
# á ADP case
#
#  SPACE
# vez NOUN fixed
# , PUNCT punct
# uno DET det
# poco PRON fixed
# de ADP case
# fatigar NOUN conj
# ; PUNCT punct
# pero CCONJ cc
# se PRON obj
# pensar VERB conj
# en ADP case
# el DET det
# fin NOUN obl
# proponer ADJ amod
# , PUNCT punct
# y CCONJ cc
# todo PRON det
#
#  SPACE
# ese PRON nsubj
# volar VERB conj
# y CCONJ cc
# se PRON obj
# desvanece.-- NOUN conj
#
#
#  SPACE
# Hablando VERB advcl
# asir ADV advmod
# , PUNCT punct
# Mauricio PROPN nsubj
# consultar VERB ROOT
# su DET det
# reloj NOUN obj
# . PUNCT punct
#
#
#  SPACE
# --Las VERB nsubj
# siete--Y NOUN punct
# levantándose VERB advcl
# , PUNCT punct
# fué AUX aux
# á ADP mark
# tomar VERB ROOT
# de ADP case
# uno DET det
# perchar NOUN obj
# su DET det
# sombrero NOUN obj
# . PUNCT punct
#
#
#  SPACE
# --¡Las VERB punct
# siete NUM ROOT
# ! PUNCT punct
# ¡ PUNCT punct
# Con ADP case
# qué DET det
# desenfadar NOUN obl
# el PRON obj
# decir VERB ROOT
# ! PUNCT punct
# ¿ PUNCT punct
# Sabes VERB ROOT
# que SCONJ mark
# haber AUX aux
# estar VERB cop
#
#  SPACE
# sentar ADJ ccomp
# ahí ADV advmod
# , PUNCT punct
# escribir VERB advcl
# desde ADP case
# los DET det
# nueve NOUN obl
# ? PUNCT punct
# ¡ PUNCT punct
# Diez NUM nummod
# hora NOUN ROOT
# ! PUNCT punct
# ¡ PUNCT punct
# Ah INTJ det
# ! PUNCT punct
# hombre NOUN nsubj
#
#  SPACE
# comer SCONJ mark
# este PRON nmod
# ser VERB cop
# uno DET det
# malo ADJ amod
# ejemplo NOUN ROOT
# en ADP case
# lo DET det
# Redaccion PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# --Y INTJ det
# tú PRON nsubj
# , PUNCT punct
# que SCONJ nsubj
# asir ADV advmod
# hablar VERB acl
# , PUNCT punct
# querer ADJ amod
# Emilio PROPN obj
# , PUNCT punct
# ser AUX cop
# unir PRON ROOT
# de ADP case
# su DET det
# mejorar ADJ amod
# obrero NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# --A ADP advmod
# más ADV fixed
# no ADV advmod
# poder VERB ROOT
# : PUNCT punct
# Sábelo PROPN obj
# . PUNCT punct
#
#
#  SPACE
# --Notificado--dijo VERB punct
# Mauricio PROPN ROOT
# , PUNCT punct
# sonriendo.--Ruégote NOUN appos
# que SCONJ nsubj
# al ADP mark
# salir VERB advcl
# decir VERB acl
# al ADP case
#
#  SPACE
# Regente PROPN obj
# que SCONJ mark
# me PRON obj
# tener VERB ccomp
# listo NOUN obj
# los DET det
# prueba NOUN obj
# parir ADP case
# los DET det
# once NUM nmod
# . PUNCT punct
#
#
#  SPACE
# --Y AUX det
# correccion PROPN ROOT
# hasta ADP case
# los DET det
# do NUM nummod
# de ADP case
# lo DET det
# mañana NOUN nmod
# . PUNCT punct
# Suma VERB ROOT
# : PUNCT punct
# ¡ PUNCT punct
# catorce NUM nummod
# hora NOUN obl
# ! PUNCT punct
# ... PUNCT punct
#
#  SPACE
# ¡ PUNCT punct
# Adios NOUN ROOT
# , PUNCT punct
# escribir INTJ conj
# ! PUNCT punct
#
#
#  SPACE
# --Adios NOUN ROOT
# , PUNCT punct
# fariseo.-- PROPN conj
#
#
#  SPACE
# Y CCONJ advmod
# ambos NUM nsubj
# reír VERB conj
# . PUNCT punct
#
#
#  SPACE
# Mauricio PROPN nsubj
# cerrar VERB ROOT
# su DET det
# carpeta NOUN obj
# y CCONJ cc
# se PRON obj
# fué VERB conj
# . PUNCT punct
#
#
#  SPACE
# Emilio PROPN nsubj
# se PRON obj
# extender VERB ROOT
# perezosamente ADV advmod
# en ADP case
# su DET det
# silla NOUN obl
# ; PUNCT punct
# encender VERB advcl
# uno DET det
# cigarro NOUN obj
# , PUNCT punct
# que SCONJ nsubj
#
#  SPACE
# aspirar VERB acl
# con ADP case
# ánsia NOUN obl
# ; PUNCT punct
# y CCONJ cc
# arrojar VERB conj
# uno DET det
# largo ADJ amod
# espiral NOUN obj
# de ADP case
# humo NOUN nmod
# , PUNCT punct
# entornar AUX advcl
#
#  SPACE
# lo DET det
# ojos--¡Deliciosa NUM nsubj
# fruicion!--exclamó:--¿qué PROPN compound
# no ADV advmod
# haz VERB ccomp
# tú PRON obj
# olvidar VERB xcomp
# ? PUNCT punct
# ... PUNCT punct
#
#  SPACE
# Y CCONJ advmod
# sin ADP advmod
# embargar NOUN fixed
# , PUNCT punct
# Mauricio PROPN nsubj
# te PRON obj
# desdeñar VERB ROOT
# . PUNCT punct
# Uncido ADJ ROOT
# á ADP case
# uno DET det
# rudo ADJ amod
# trabajar NOUN nmod
# , PUNCT punct
# pegar ADJ amod
#
#  SPACE
# ahí ADV advmod
# , PUNCT punct
# á ADP case
# ese DET det
# mesar NOUN obl
# de ADP case
# redaccion PROPN nmod
# , PUNCT punct
# hasta ADP case
# lo DET det
# codo NOUN obl
# en ADP case
# lo DET det
# seccion PROPN nmod
# editorial ADJ amod
# ; PUNCT punct
#
#  SPACE
# cronista ADJ amod
# , PUNCT punct
# traductor NOUN conj
# , PUNCT punct
# folletinista ADJ amod
# , PUNCT punct
# corrector ADJ amod
# de ADP case
# prueba NOUN nmod
# : PUNCT punct
# ¿ PUNCT punct
# á ADP case
# qué PRON det
#
#  SPACE
# móvil NOUN nsubj
# obedecer VERB acl
# ese DET det
# anhelar NOUN obj
# de ADP mark
# aglomerar VERB acl
# sueldo NOUN obj
# ? PUNCT punct
# Él PRON nsubj
# , PUNCT punct
# no ADV advmod
# ser AUX cop
# avaro ADJ ROOT
# ni CCONJ cc
#
#  SPACE
# derrochador NOUN conj
# ; PUNCT punct
# no ADV advmod
# frecuentar VERB amod
# club NOUN obl
# ni CCONJ cc
# baile NOUN conj
# ; PUNCT punct
# por ADP advmod
# tanto INTJ fixed
# , PUNCT punct
# ni CCONJ cc
# jugar VERB conj
# ni CCONJ advmod
#
#  SPACE
# galantear PROPN nsubj
# . PUNCT punct
# En ADP case
# lo DET det
# teatro NOUN obl
# tener VERB ROOT
# los DET det
# entrar NOUN obj
# de ADP case
# periodista NOUN nmod
# . PUNCT punct
# ¿ PUNCT punct
# A ADP case
# qué DET obl
# tanto ADV fixed
#
#  SPACE
# afan NOUN ROOT
# de ADP mark
# ganar VERB acl
# dinero NOUN obj
# ? PUNCT punct
# ¿ PUNCT punct
# qué PRON obj
# hacer VERB ROOT
# de ADP case
# él PRON obj
# ? PUNCT punct
# No ADV advmod
# ser AUX cop
# mucho ADV ROOT
# , PUNCT punct
# en ADP advmod
# verdad INTJ fixed
# ; PUNCT punct
# pero CCONJ cc
#
#  SPACE
# ¿ PUNCT punct
# qué PRON obj
# hacer VERB conj
# de ADP case
# él PRON obj
# ? PUNCT punct
# Enigma VERB nsubj
# insoluble ADJ amod
# ser AUX cop
# parir ADP case
# mí PRON obl
# este DET det
# jóven NOUN ROOT
# , PUNCT punct
# tan ADV advmod
# franco ADJ amod
# , PUNCT punct
#
#  SPACE
# sin ADP advmod
# embargar NOUN fixed
# , PUNCT punct
# y CCONJ cc
# tan ADV advmod
# bueno ADJ conj
# ... PUNCT punct
#
#
#  SPACE
# Y CCONJ advmod
# Emilio PROPN nsubj
# dejar VERB advcl
# lo DET det
# pluma NOUN obj
# en ADP case
# largar ADJ amod
# holgorio NOUN obl
# , PUNCT punct
# quedóse VERB ROOT
# engolfar ADJ obj
# en ADP case
# su DET det
#
#  SPACE
# pensamiento NOUN obl
# y CCONJ cc
# en ADP case
# el DET det
# humo NOUN conj
# de ADP case
# su DET det
# cigarro NOUN nmod
# . PUNCT punct
#
#
#
#
#
#  SPACE
# II PROPN nsubj
#
#
#
#  SPACE
# Mauricio PROPN flat
# se PRON obj
# alejar VERB ROOT
# con ADP case
# el DET det
# pasar NOUN obl
# presuroso ADJ amod
# , PUNCT punct
# habitual ADJ amod
# en ADP case
# aquel PRON nmod
# que SCONJ nsubj
#
#  SPACE
# tener AUX acl
# contar ADJ obj
# el DET det
# tiempo NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Aunque SCONJ mark
# en ADP case
# lo DET det
# plácido ADJ amod
# edad NOUN obl
# de ADP case
# veinte NUM nummod
# año NOUN nmod
# , PUNCT punct
# y CCONJ cc
# bello ADJ conj
# y CCONJ cc
# apostar ADJ conj
# , PUNCT punct
# haber AUX ROOT
# en ADP case
# lo DET det
#
#  SPACE
# expresion NOUN obl
# de ADP case
# su DET det
# semblante NOUN nmod
# ese DET det
# gravedad NOUN obj
# melancólico ADJ amod
# , PUNCT punct
# signar NOUN appos
# de ADP case
# uno DET det
# destinar NOUN nmod
#
#  SPACE
# adverso ADJ amod
# . PUNCT punct
#
#
#  SPACE
# En ADP advmod
# verdad INTJ fixed
# , PUNCT punct
# adverso ADJ nsubj
# haber VERB aux
# ser VERB cop
# el DET det
# destinar NOUN ROOT
# parir ADP case
# Mauricio PROPN nmod
# : PUNCT punct
# adverso ADJ amod
# desde ADP case
#
#  SPACE
# lo DET det
# cunar NOUN nmod
# , PUNCT punct
# mecer ADJ amod
# por ADP case
# mano NOUN obl
# extraño ADJ amod
# , PUNCT punct
# desierto NOUN conj
# de ADP case
# cuidar NOUN nmod
# y CCONJ cc
# caricia NOUN conj
# . PUNCT punct
#
#
#  SPACE
# Y CCONJ advmod
# no ADV advmod
# fué AUX cop
# este PRON ROOT
# solo ADJ fixed
# ¡ PUNCT punct
# ay INTJ dep
# ! PUNCT punct
# no ADV advmod
# fué AUX ROOT
# este PRON nsubj
# solo ADJ advmod
# . PUNCT punct
#
#
#  SPACE
# Cárlos PROPN advcl
# Ridel PROPN nsubj
# , PUNCT punct
# subyugar ADJ amod
# por ADP case
# uno DET det
# pasion PROPN obj
# que SCONJ nsubj
# causar VERB acl
# lo DET det
# muerte NOUN obj
# á ADP case
# su DET det
# esposo NOUN nmod
# , PUNCT punct
#
#  SPACE
# llevar VERB advcl
# todavía ADV advmod
# el DET det
# luto NOUN obj
# de ADP case
# lo DET det
# viudez NOUN nmod
# , PUNCT punct
# dió VERB ROOT
# uno DET det
# sucesor NOUN obj
# á ADP case
# lo DET det
# difunto NOUN obj
# ; PUNCT punct
# á ADP advmod
#
#  SPACE
# su DET det
# hijo NOUN obj
# uno DET det
# madrastra NOUN appos
# . PUNCT punct
#
#
#  SPACE
# ¡ PUNCT punct
# Madrastra PROPN ROOT
# ! PUNCT punct
# Al ADP mark
# solo INTJ fixed
# pronunciar VERB ROOT
# este DET det
# palabra NOUN obj
# de ADP case
# aspereza NOUN nmod
# siniestro ADJ amod
# , PUNCT punct
#
#  SPACE
# compréndese AUX advcl
# lo DET det
# tristura NOUN obj
# de ADP case
# ese DET det
# pobre ADJ amod
# niño NOUN nmod
# que SCONJ nsubj
# crecer AUX acl
# temeroso ADJ obj
# , PUNCT punct
#
#  SPACE
# acoquinar ADJ advmod
# , PUNCT punct
# bajar ADP case
# aquel DET det
# sombrar NOUN obl
# fatídico ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Para ADP case
# ellos PRON obl
# no ADV advmod
# existir AUX ROOT
# los DET det
# alegría NOUN nsubj
# del ADP case
# hogar NOUN nmod
# . PUNCT punct
# Siempre ADV advmod
# espiar ADJ ROOT
# por ADP case
# lo DET det
#
#  SPACE
# mirar NOUN obj
# suspicaz ADJ amod
# de ADP case
# uno DET det
# fiscal NOUN nmod
# inexorable ADJ amod
# que SCONJ nsubj
# les PRON obj
# achacar VERB acl
# á ADP case
# delito NOUN obl
# su DET det
#
#  SPACE
# gozoso ADJ amod
# turbulencia NOUN obj
# , PUNCT punct
# su DET det
# inocente ADJ amod
# espontaneidad NOUN appos
# , PUNCT punct
# vuélvense ADJ conj
# taciturno ADJ flat
# , PUNCT punct
#
#  SPACE
# desconfiar ADJ amod
# ; PUNCT punct
# ocúltanse PROPN conj
# parir ADP mark
# reir VERB advcl
# ; PUNCT punct
# ocúltanse PROPN conj
# parir ADP mark
# llorar VERB advcl
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# el DET det
#
#  SPACE
# ﻿1 ADJ amod
# albor NOUN conj
# de ADP case
# lo DET det
# vida NOUN nmod
# , PUNCT punct
# aprender AUX advcl
# ese DET det
# triste ADJ amod
# ciencia NOUN obj
# de ADP case
# lo DET det
# vejez NOUN nmod
# : PUNCT punct
# el DET det
#
#  SPACE
# disimular NOUN appos
# . PUNCT punct
# ¿ PUNCT punct
# Ni CCONJ advmod
# qué PRON det
# otro DET det
# recurso NOUN nsubj
# les PRON obj
# quedo VERB ROOT
# ? PUNCT punct
# ¿ PUNCT punct
# A ADP case
# quién PRON obj
# volver VERB ROOT
# su DET det
# ojo NOUN obj
# ? PUNCT punct
#
#
#  SPACE
# La DET det
# casar NOUN nsubj
# paterno ADJ amod
# se PRON obj
# haber AUX aux
# tornar VERB ROOT
# parir ADP case
# ellos PRON obl
# en ADP case
# campar NOUN obl
# enemigo ADJ amod
# , PUNCT punct
# donde PRON obl
# todo PRON nsubj
#
#  SPACE
# les PRON obj
# ser AUX cop
# hostil ADJ acl
# , PUNCT punct
# hasta ADP case
# su DET det
# mismo DET det
# padre NOUN obl
# á ADP case
# quien PRON obj
# no ADV advmod
# le PRON obj
# ser AUX aux
# dar VERB acl
# mostrárseles ADJ obj
#
#  SPACE
# propiciar ADJ amod
# , PUNCT punct
# so ADP obj
# penar NOUN fixed
# de ADP mark
# despertar VERB acl
# celo NOUN obj
# retrospectivo ADJ amod
# , PUNCT punct
# que SCONJ nsubj
# empeorar VERB acl
# lo DET det
#
#  SPACE
# situacion PROPN obj
# tristísima PROPN amod
# de ADP case
# ese DET det
# náufrago NOUN nmod
# de ADP case
# lo DET det
# vida NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Tal DET det
# suerte NOUN ROOT
# caber NOUN amod
# á ADP case
# Mauricio PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# Víctima PROPN nsubj
# de ADP case
# uno DET det
# semejanza NOUN nmod
# que SCONJ nsubj
# importunar AUX acl
# á ADP case
# su DET det
# padre NOUN obj
# comer SCONJ mark
# uno DET det
#
#  SPACE
# remordimiento NOUN obl
# , PUNCT punct
# á ADP case
# su DET det
# madrastra NOUN nmod
# comer SCONJ mark
# uno DET det
# vision PROPN nmod
# de ADP case
# ultratumba PROPN nmod
# , PUNCT punct
# vióse ADP case
# uno DET det
#
#  SPACE
# dia NOUN appos
# arrebatar ADJ amod
# de ADP case
# su DET det
# casar NOUN obl
# y CCONJ cc
# entregar ADJ conj
# al ADP case
# capitan PROPN obj
# de ADP case
# uno DET det
# buque NOUN nmod
# inglés ADJ amod
# , PUNCT punct
#
#  SPACE
# que SCONJ nsubj
# el PRON obj
# llevar VERB ROOT
# á ADP case
# Europa PROPN obl
# y CCONJ cc
# el PRON obj
# encerrar VERB conj
# en ADP case
# uno DET det
# colegiar NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Aunque SCONJ mark
# del ADP case
# hogar NOUN obl
# de ADP case
# su DET det
# padre NOUN nmod
# , PUNCT punct
# el DET det
# pobre ADJ amod
# niño NOUN appos
# , PUNCT punct
# solo ADV advmod
# guardar AUX ROOT
# cruel ADJ obj
#
#  SPACE
# recuerdo NOUN obj
# , PUNCT punct
# lo DET det
# lengua NOUN obj
# materno ADJ amod
# , PUNCT punct
# el DET det
# soler NOUN obj
# de ADP case
# lo DET det
# patrio NOUN nmod
# , PUNCT punct
# su DET det
# aire NOUN appos
# , PUNCT punct
# su DET det
# luz NOUN appos
# , PUNCT punct
#
#  SPACE
# éranle NOUN obj
# necesario ADJ amod
# , PUNCT punct
# y CCONJ cc
# languidecer VERB conj
# , PUNCT punct
# echándolos VERB advcl
# de ADP case
# menos ADV advmod
# . PUNCT punct
#
#
#  SPACE
# Por ADP case
# decir ADJ obl
# suyo DET det
# fué AUX cop
# el DET det
# « PUNCT punct
# bello ADJ amod
# país NOUN ROOT
# de ADP case
# Francia PROPN nmod
# , PUNCT punct
# » PUNCT punct
# lo DET det
# hospitalario NOUN appos
# Paris PROPN appos
# , PUNCT punct
#
#  SPACE
# el DET det
# lugar NOUN appos
# de ADP case
# su DET det
# desterrar NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# La DET det
# bondad NOUN nsubj
# característico ADJ amod
# de ADP case
# lo DET det
# hijo NOUN nmod
# de ADP case
# aquel DET det
# tierra NOUN nmod
# , PUNCT punct
# tener VERB ROOT
# , PUNCT punct
# en ADP case
#
#  SPACE
# todo DET det
# los DET det
# clase NOUN obl
# social ADJ amod
# , PUNCT punct
# desde ADP case
# el DET det
# aristócrata NOUN obl
# hasta ADP case
# el DET det
# obrero NOUN nmod
# , PUNCT punct
# uno DET det
#
#  SPACE
# gracia NOUN obj
# irresistible ADJ amod
# que SCONJ nsubj
# cautivo VERB acl
# el DET det
# alma NOUN obj
# y CCONJ cc
# matar VERB conj
# todo DET det
# nostalgia NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Desde ADP case
# el DET det
# sábio NOUN obl
# Blain PROPN appos
# , PUNCT punct
# director NOUN appos
# del ADP case
# colegiar NOUN nmod
# donde PRON obl
# fué VERB acl
# el DET det
# niño NOUN nsubj
#
#  SPACE
# consignar ADJ amod
# , PUNCT punct
# hasta ADP case
# el DET det
# amar NOUN conj
# de ADP case
# llave NOUN nmod
# , PUNCT punct
# lo DET det
# bueno ADJ amod
# Colombe PROPN appos
# ; PUNCT punct
# desde ADP case
# lo DET det
# alumno NOUN obl
#
#  SPACE
# hasta ADP case
# lo DET det
# profesor NOUN nmod
# : PUNCT punct
# todo PRON appos
# acogiéronlo PROPN amod
# con ADP case
# tan ADV advmod
# benévolo ADJ amod
# conmiseracion PROPN nmod
# , PUNCT punct
#
#  SPACE
# que SCONJ nsubj
# 1 ADV advmod
# lo DET det
# serenidad NOUN conj
# y CCONJ cc
# luego ADV advmod
# lo DET det
# alegría NOUN conj
# , PUNCT punct
# venir VERB ROOT
# comer SCONJ mark
# nunca ADV advmod
# , PUNCT punct
#
#  SPACE
# expansivo ADJ advmod
# á ADP case
# aquel DET det
# pobre ADJ amod
# corazon NOUN obl
# , PUNCT punct
# por ADP case
# tanto DET fixed
# tiempo NOUN obl
# oprimir ADJ amod
# . PUNCT punct
#
#
#  SPACE
# El DET det
# desterrar NOUN nsubj
# comenzar AUX ROOT
# á ADP mark
# encontrarse VERB xcomp
# feliz ADJ obj
# en ADP case
# su DET det
# nuevo ADJ amod
# familia NOUN obl
# . PUNCT punct
#
#
#  SPACE
# --¡Ah!--pensaba NUM nsubj
# , PUNCT punct
# recordar VERB advcl
# el DET det
# pasado--¿así INTJ obj
# se PRON obj
# amar VERB ROOT
# , PUNCT punct
# se PRON obj
# acariciar VERB advcl
# y CCONJ cc
# se PRON obj
#
#  SPACE
# proteger VERB conj
# ? PUNCT punct
# ¿ PUNCT punct
# Por ADP case
# qué PRON obl
# no ADV advmod
# haber AUX aux
# conocer VERB ROOT
# yo PRON nsubj
# hasta ADP case
# hoy ADV advmod
# , PUNCT punct
# este DET det
# bien NOUN obj
# ? PUNCT punct
#
#
#  SPACE
# Y CCONJ cc
# refugiábase AUX ROOT
# en ADP case
# ese DET det
# atmósfera NOUN nmod
# de ADP case
# caluroso ADJ amod
# afecto NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# sentir AUX conj
# el DET det
# dulce ADJ amod
#
#  SPACE
# bienestar NOUN obj
# del ADP case
# que SCONJ obj
# renacer VERB acl
# á ADP case
# lo DET det
# salud NOUN obj
# despues PROPN nmod
# de ADP case
# uno DET det
# largo ADJ amod
# enfermedad NOUN obl
# . PUNCT punct
#
#
#
#
#
#  SPACE
# III PROPN ROOT
#
#
#
#  SPACE
# Los DET det
# año NOUN nsubj
# trascurrir VERB ROOT
# asir ADV advmod
# , PUNCT punct
# con ADP case
# su DET det
# época NOUN obl
# clásico ADJ amod
# , PUNCT punct
# en ADP case
# lo DET det
# vida NOUN obl
# del ADP case
#
#  SPACE
# niño NOUN nmod
# . PUNCT punct
# Los DET det
# examen NOUN ROOT
# ; PUNCT punct
# lo DET det
# premio NOUN appos
# ; PUNCT punct
# el DET det
# pasar NOUN appos
# á ADP case
# estudio NOUN nmod
# superior ADJ amod
# ; PUNCT punct
# el DET det
# del ADP case
#
#  SPACE
# vestir ADJ amod
# infantil ADJ amod
# al ADP case
# traer NOUN nmod
# viril ADJ amod
# ; PUNCT punct
# lo DET det
# primero ADJ amod
# comunion NOUN appos
# ..... PUNCT appos
#
#
#  SPACE
# ¡ PUNCT punct
# Qué DET det
# ceremonia NOUN ROOT
# , PUNCT punct
# á ADP advmod
# lo DET fixed
# vez INTJ fixed
# tan ADV advmod
# imponente ADJ amod
# y CCONJ cc
# tierno ADJ conj
# ! PUNCT punct
#
#
#  SPACE
# Cumplido ADJ advmod
# en ADP case
# él PRON obj
# , PUNCT punct
# el DET det
# divino ADJ amod
# misterio NOUN appos
# , PUNCT punct
# de ADP case
# rodilla NOUN obl
# ante ADP case
# el DET det
# altar NOUN nmod
# , PUNCT punct
# el DET det
# niño NOUN nsubj
#
#  SPACE
# tender VERB ROOT
# lo DET det
# manir NOUN obj
# sobrar ADP case
# el DET det
# Sagrado PROPN nmod
# Libro PROPN flat
# y CCONJ cc
# jurar PROPN conj
# ser VERB cop
# virtuoso ADJ advcl
# y CCONJ cc
# bueno ADJ conj
# . PUNCT punct
#
#
#  SPACE
# El DET det
# celebrante NOUN iobj
# el PRON det
# bendecir NOUN ROOT
# y CCONJ cc
# colocar VERB conj
# en ADP case
# su DET det
# pechar NOUN obl
# uno DET det
# reliquia PROPN obj
# . PUNCT punct
#
#
#  SPACE
# La DET det
# voz NOUN nsubj
# del ADP case
# órgano NOUN nmod
# derramar INTJ appos
# gozoso ADJ amod
# noto NOUN appos
# ; PUNCT punct
# nube NOUN nsubj
# de ADP case
# incensar NOUN nmod
# se PRON obj
# elevar AUX ROOT
# á ADP case
#
#  SPACE
# el PRON det
# alto ADJ obj
# de ADP case
# lo DET det
# bóveda NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# lo DET det
# nave NOUN obl
# central ADJ amod
# , PUNCT punct
# los DET det
# madre NOUN nsubj
# aguardar AUX conj
# con ADP case
# el DET det
#
#  SPACE
# llanto NOUN obl
# en ADP case
# lo DET det
# ojo NOUN nmod
# , PUNCT punct
# en ADP case
# el DET det
# lábio NOUN obl
# lo DET det
# sonrisa NOUN appos
# . PUNCT punct
#
#
#  SPACE
# Mauricio PROPN nsubj
# vió VERB ROOT
# á ADP case
# su DET det
# compañero NOUN obj
# ir VERB ccomp
# hácia ADP obj
# ellos PRON appos
# y CCONJ cc
# caer VERB conj
# en ADP case
# su DET det
# brazo NOUN obl
# . PUNCT punct
#
#
#  SPACE
# ¡ PUNCT punct
# Ay INTJ ROOT
# ! PUNCT punct
# ¡ PUNCT punct
# él PRON nsubj
# estar VERB cop
# solo ADJ ROOT
# ! PUNCT punct
#
#
#  SPACE
# Ni CCONJ cc
# padre NOUN ROOT
# ni CCONJ cc
# madre NOUN conj
# que SCONJ nsubj
# el PRON obj
# aguardar AUX acl
# ; PUNCT punct
# solo ADV advmod
# en ADP case
# ese DET det
# hora NOUN nmod
# solemne ADJ amod
# de ADP case
# lo DET det
#
#  SPACE
# vida NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# ¿ PUNCT punct
# Solo ADJ ROOT
# ? PUNCT punct
#
#
#  SPACE
# No ADV advmod
# : PUNCT punct
# ahí ADV advmod
# estar AUX ROOT
# Mr PROPN nsubj
# . PUNCT punct
# Blain PROPN ROOT
# que SCONJ nsubj
# le PRON obj
# sonreia VERB acl
# ; PUNCT punct
# ahí ADV advmod
# estar AUX advcl
# lo DET det
# bueno ADJ amod
# Colombe PROPN nsubj
#
#  SPACE
# que SCONJ nsubj
# le PRON obj
# tender VERB acl
# lo DET det
# brazo NOUN obj
# y CCONJ cc
# el PRON obj
# contemplar VERB conj
# enternecer ADJ obj
# . PUNCT punct
#
#
#  SPACE
# --Ama--díjole VERB obj
# Mauricio--¿Quieres ADJ ROOT
# que SCONJ mark
# te PRON obj
# dar VERB ccomp
# mi DET det
# reliquia NOUN obj
# ? PUNCT punct
# Mírala PROPN ROOT
# : PUNCT punct
# ser AUX cop
# muy ADV advmod
#
#  SPACE
# lindo ADJ acl
# : PUNCT punct
# _ NUM obj
# Notre NUM appos
# Dame PROPN flat
# du PROPN flat
# bon PROPN flat
# Secour PROPN flat
# _ PROPN flat
# . PUNCT punct
#
#
#  SPACE
# --No ADV advmod
# , PUNCT punct
# hijo NOUN dep
# mio--respondió VERB punct
# lo DET det
# viejo ADJ amod
# sirviente NOUN appos
# , PUNCT punct
# volver VERB csubj
# lo DET det
# reliquia PROPN obj
# al ADP case
#
#  SPACE
# pechar NOUN obj
# del ADP case
# niño.--Este NOUN obl
# recordar NOUN flat
# le PRON obj
# ser AUX cop
# deber ADJ case
# á ADP fixed
# mamá NOUN ROOT
# . PUNCT punct
# Envíaselo NOUN ROOT
# dentro ADV advmod
# de ADP case
#
#  SPACE
# tu DET det
# primero ADJ amod
# carta.-- NOUN obl
#
#
#  SPACE
# La DET det
# hora NOUN appos
# , PUNCT punct
# el DET det
# lugar NOUN appos
# , PUNCT punct
# lo DET det
# escena NOUN appos
# imponente ADJ amod
# en ADP case
# que SCONJ obl
# acabar VERB acl
# de ADP mark
# actuar VERB xcomp
# ; PUNCT punct
# lo DET det
#
#  SPACE
# voz NOUN appos
# del ADP case
# órgano NOUN nmod
# ; PUNCT punct
# el DET det
# humo NOUN appos
# del ADP case
# incensar NOUN nmod
# ; PUNCT punct
# los DET det
# sagrado ADJ amod
# prez NOUN appos
# ; PUNCT punct
# todo DET det
# este PRON nsubj
#
#  SPACE
# despertar VERB advcl
# en ADP case
# el DET det
# alma NOUN obl
# del ADP case
# niño NOUN nmod
# uno DET det
# emocion PROPN obj
# profundo PROPN amod
# , PUNCT punct
# al ADP mark
# oir VERB advcl
# los DET det
# palabra NOUN nsubj
#
#  SPACE
# de ADP case
# lo DET det
# viejo ADJ amod
# Colombe PROPN nmod
# . PUNCT punct
# La DET det
# luz NOUN nsubj
# de ADP case
# uno DET det
# lejano ADJ amod
# recordar NOUN nmod
# brillar VERB ROOT
# en ADP case
# su DET det
# mente NOUN obl
# , PUNCT punct
#
#  SPACE
# mostrándole VERB advcl
# allá ADV advmod
# , PUNCT punct
# comer SCONJ mark
# entrar ADP case
# los DET det
# niebla NOUN obl
# de ADP case
# uno DET det
# ensoñar NOUN nmod
# , PUNCT punct
# lo DET det
# figurar NOUN obj
#
#  SPACE
# angelical ADJ amod
# de ADP case
# uno DET det
# mujer NOUN nmod
# que SCONJ nsubj
# el PRON obj
# mirar AUX acl
# sonreír VERB xcomp
# . PUNCT punct
#
#
#  SPACE
# Sonrióle PROPN ROOT
# él PRON flat
# tambien NOUN flat
# , PUNCT punct
# y CCONJ cc
# do NUM nummod
# lágrima NOUN nsubj
# se PRON obj
# desprender VERB conj
# de ADP case
# su DET det
# ojo NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Colombe PROPN nsubj
# los PRON obj
# comprender VERB ROOT
# . PUNCT punct
# Besó VERB ROOT
# lo DET det
# santo ADJ amod
# imágen NOUN obj
# ; PUNCT punct
# guardóla PROPN advcl
# en ADP case
# su DET det
# seno NOUN obl
# ; PUNCT punct
# y CCONJ cc
# en ADP case
#
#  SPACE
# lo DET det
# noche NOUN conj
# , PUNCT punct
# á ADP case
# lo DET det
# hora NOUN obl
# de ADP mark
# acostarse VERB acl
# , PUNCT punct
# Mauricio PROPN nsubj
# lo PRON obj
# encontrar VERB advcl
# á ADP case
# lo DET det
# cabecera NOUN obl
# de ADP case
#
#  SPACE
# su DET det
# cama NOUN nmod
# . PUNCT punct
#
#
#
#
#
#  SPACE
# IV PROPN nsubj
#
#
#
#  SPACE
# Desde ADP case
# ese DET det
# dia NOUN nmod
# uno DET det
# notable ADJ amod
# cambiar NOUN appos
# se PRON obj
# efectuar VERB ROOT
# en ADP case
# su DET det
# carácter NOUN obl
# . PUNCT punct
# A ADP case
# lo DET det
#
#  SPACE
# inquieto ADJ amod
# turbulencia NOUN obj
# del ADP case
# niño NOUN nmod
# , PUNCT punct
# suceder VERB ROOT
# lo DET det
# mesurar NOUN nsubj
# y CCONJ cc
# lo DET det
# reflexion NOUN conj
# del ADP case
#
#  SPACE
# hombre NOUN nmod
# ; PUNCT punct
# al ADP case
# gustar NOUN obl
# por ADP case
# lo DET det
# juego NOUN nmod
# , PUNCT punct
# el DET det
# amor NOUN appos
# al ADP case
# estudiar NOUN nmod
# ; PUNCT punct
# á ADP case
# su DET det
# indiferencia NOUN obl
#
#  SPACE
# cosmopolita ADJ amod
# , PUNCT punct
# el DET det
# sentimiento NOUN appos
# exaltar ADJ amod
# de ADP case
# lo DET det
# nacionalidad NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Cuando SCONJ mark
# en ADP case
# lo DET det
# dias NOUN obl
# clásico ADJ amod
# , PUNCT punct
# al ADP mark
# flamear VERB advcl
# de ADP case
# lo DET det
# bandera NOUN obl
# tricolor ADJ amod
# , PUNCT punct
# su DET det
#
#  SPACE
# compañero NOUN nsubj
# cantar AUX ROOT
# : PUNCT punct
# « PUNCT punct
# _ NUM nsubj
# Allons PROPN flat
# enfants INTJ flat
# de ADP case
# lo DET det
# patrie PROPN nmod
# _ PROPN flat
# , PUNCT punct
# » PUNCT punct
# Mauricio PROPN nsubj
# buscar AUX ccomp
#
#  SPACE
# en ADP case
# el DET det
# cielo NOUN obl
# , PUNCT punct
# el DET det
# azul ADJ amod
# pabellon PROPN obj
# ; PUNCT punct
# y CCONJ cc
# del ADP case
# fondo NOUN obl
# de ADP case
# su DET det
# alma NOUN nmod
# exhalábase AUX conj
# el DET det
#
#  SPACE
# gritar NOUN nsubj
# sagrado ADJ amod
# del ADP case
# himno NOUN nmod
# nacional ADJ amod
# . PUNCT punct
# Allá ADV advmod
# , PUNCT punct
# surgir VERB advcl
# de ADP case
# los DET det
# brumar NOUN obl
# del ADP case
#
#  SPACE
# lejano ADJ nmod
# pasar ADJ amod
# , PUNCT punct
# lo DET det
# imágen NOUN ROOT
# de ADP case
# lo DET det
# patrio NOUN nmod
# aparecíale PROPN amod
# con ADP case
# su DET det
# inmenso ADJ amod
# pampa NOUN nmod
# , PUNCT punct
#
#  SPACE
# su DET det
# magestuoso ADJ amod
# rio NOUN appos
# , PUNCT punct
# su DET det
# cerúleo NOUN appos
# lontananza NOUN flat
# , PUNCT punct
# llamándolo VERB acl
# con ADP case
# poderoso ADJ amod
#
#  SPACE
# reclamar NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Pero CCONJ advmod
# ¡ PUNCT punct
# ah INTJ ROOT
# ! PUNCT punct
# siempre ADV mark
# que SCONJ fixed
# este DET det
# luminoso ADJ amod
# imagen NOUN nsubj
# visitar AUX advcl
# su DET det
# mente NOUN obj
# , PUNCT punct
# uno DET det
#
#  SPACE
# siniestro ADJ nsubj
# recordar NOUN nsubj
# venir AUX ROOT
# á ADP case
# oscurecerlas VERB advcl
# . PUNCT punct
#
#
#  SPACE
# Su DET det
# madrastra NOUN ROOT
# . PUNCT punct
#
#
#  SPACE
# Este DET det
# sentimiento NOUN nsubj
# de ADP case
# repulsion PROPN nmod
# crecer VERB ROOT
# más ADV advmod
# todavía ADV advmod
# , PUNCT punct
# cuando SCONJ mark
# Mauricio PROPN nsubj
#
#  SPACE
# comprender VERB advcl
# por ADP case
# los DET det
# carta NOUN obl
# de ADP case
# su DET det
# padre NOUN nmod
# , PUNCT punct
# lo DET det
# humillante ADJ amod
# dependencia NOUN obj
# en ADP case
#
#  SPACE
# que SCONJ nsubj
# yacer AUX acl
# . PUNCT punct
# Cada DET det
# frase NOUN nsubj
# parecer VERB ROOT
# consultar ADJ xcomp
# , PUNCT punct
# corregir ADJ advmod
# ó CCONJ cc
# dictar ADJ conj
# por ADP case
# el DET det
#
#  SPACE
# déspota ADJ obj
# que SCONJ nsubj
# leer AUX advcl
# sobrar ADP case
# su DET det
# hombro NOUN obl
# . PUNCT punct
#
#
#  SPACE
# El DET det
# jóven NOUN nsubj
# verter AUX ROOT
# sobrar ADP case
# él PRON obl
# lágrima NOUN obj
# de ADP case
# indignacion PROPN nmod
# y CCONJ cc
# de ADP case
# dolor NOUN conj
# ; PUNCT punct
# y CCONJ cc
# uno DET det
#
#  SPACE
# palabra NOUN conj
# de ADP case
# unir PRON nmod
# ú ADP cc
# otro PRON conj
# , PUNCT punct
# contener AUX advcl
# su DET det
# respuesta NOUN obj
# . PUNCT punct
#
#
#  SPACE
# Así ADV advmod
# , PUNCT punct
# lo DET det
# correspondencia NOUN nsubj
# entrar ADP case
# padre NOUN nmod
# é CCONJ cc
# hijo NOUN conj
# tomar VERB ROOT
# uno DET det
# carácter NOUN obj
# de ADP case
# acritud NOUN nmod
#
#  SPACE
# que SCONJ nsubj
# , PUNCT punct
# poco ADV advmod
# á ADP advmod
# poco ADV fixed
# , PUNCT punct
# degenerar VERB conj
# en ADP case
# frialdad NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Y CCONJ advmod
# , PUNCT punct
# cuando SCONJ mark
# á ADP case
# lo DET det
# edad NOUN obl
# de ADP case
# diez NUM nummod
# y CCONJ cc
# ocho NUM conj
# año NOUN nmod
# , PUNCT punct
# acabar ADJ advcl
# su DET det
# estudio NOUN obj
# y CCONJ cc
#
#  SPACE
# rendir ADJ conj
# con ADP case
# brillar NOUN obl
# el DET det
# último ADJ amod
# exámen NOUN obj
# , PUNCT punct
# su DET det
# padre NOUN nsubj
# le PRON obj
# hablar VERB ROOT
# de ADP case
# regresar NOUN obj
# . PUNCT punct
#
#
#  SPACE
# --Amo PUNCT nsubj
# á ADP case
# mi DET det
# patrio NOUN nmod
# y CCONJ cc
# anhelar NOUN conj
# volver VERB xcomp
# á ADP case
# verla--respondió VERB obl
# Mauricio,--amo PROPN flat
# á ADP case
#
#  SPACE
# mi DET det
# padre NOUN obj
# y CCONJ cc
# desear VERB conj
# estrecharlo VERB ROOT
# en ADP case
# mi DET det
# brazo NOUN obl
# ; PUNCT punct
# pero CCONJ cc
# no ADV advmod
# poder AUX aux
# presenciar VERB conj
#
#  SPACE
# el DET det
# espectáculo NOUN obj
# vergonzoso ADJ amod
# de ADP case
# su DET det
# servidumbre NOUN nmod
# ; PUNCT punct
# y CCONJ cc
# porque SCONJ mark
# el PRON obj
# amar VERB conj
# ; PUNCT punct
# y CCONJ cc
# porque SCONJ mark
#
#  SPACE
# el PRON det
# respetar VERB nsubj
# , PUNCT punct
# preferir VERB conj
# uno DET det
# eterno ADJ amod
# desterrar NOUN obj
# . PUNCT punct
#
#
#  SPACE
# A ADP case
# este DET det
# declaracion NOUN obl
# seguir VERB ROOT
# uno DET det
# profundar ADJ amod
# silenciar NOUN nsubj
# ; PUNCT punct
# y CCONJ cc
# comer SCONJ mark
# único ADJ amod
# respuesta NOUN nsubj
#
#  SPACE
# Mauricio PROPN appos
# recibir VERB advcl
# uno DET det
# carta NOUN obj
# que SCONJ nsubj
# contener AUX acl
# inesperado DET amod
# revelación NOUN obj
# . PUNCT punct
#
#  SPACE
# Suscribíala PROPN ROOT
# el DET det
# escribano NOUN nsubj
# D PROPN appos
# ... PUNCT punct
# , PUNCT punct
# unir PRON appos
# de ADP case
# lo DET det
# hombre NOUN nmod
# más ADV advmod
# honorable ADJ amod
# de ADP case
#
#  SPACE
# Buenos PROPN nmod
# Aires PROPN flat
# . PUNCT punct
#
#
#    SPACE
# --«Alejados ADJ nsubj
# y CCONJ cc
# sin ADP mark
# conocernos VERB conj
# unir PRON obj
# á ADP case
# otro--decíale PROPN obl
# éste--únenos PROPN flat
# , PUNCT punct
#
#    SPACE
# sinembargo PROPN conj
# , PUNCT punct
# el DET det
# mandato NOUN nsubj
# de ADP case
# uno DET det
# personar NOUN nmod
# que SCONJ nsubj
# ya ADV advmod
# no ADV advmod
# existir VERB acl
# ; PUNCT punct
# y CCONJ cc
# que SCONJ mark
# parir ADP mark
#
#    SPACE
# mí PRON nsubj
# fué AUX advcl
# por ADP case
# este PRON obl
# , PUNCT punct
# más ADV advmod
# sagrado.--Y NOUN obj
# proseguir AUX conj
# : PUNCT punct
#
#
#    SPACE
# --«Hace VERB nsubj
# quince NUM nummod
# año NOUN obl
# , PUNCT punct
# fuí VERB aux
# llamar VERB ROOT
# uno DET det
# dia NOUN obl
# á ADP case
# casar NOUN obl
# del ADP case
# señor NOUN nmod
# Cárlos PROPN appos
#
#    SPACE
# Ridel PROPN appos
# , PUNCT punct
# cuyo PRON nmod
# esposo NOUN nsubj
# , PUNCT punct
# en ADP case
# tranzar NOUN obl
# de ADP case
# muerte NOUN nmod
# , PUNCT punct
# deber VERB aux
# otorgar VERB acl
# testamento NOUN obj
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Mi DET det
# colega NOUN nsubj
# , PUNCT punct
# el DET det
# señor NOUN appos
# R PROPN appos
# ... PUNCT punct
# , PUNCT punct
# autorizar AUX ROOT
# el DET det
# acto NOUN obj
# ; PUNCT punct
# y CCONJ cc
# yo PRON nsubj
# creer AUX conj
# haber VERB aux
#
#    SPACE
# ser VERB aux
# requerir VERB ccomp
# comer SCONJ mark
# testigo NOUN obl
# , PUNCT punct
# cuando SCONJ mark
# lo DET det
# testante NOUN punct
# , PUNCT punct
# haber AUX aux
# declarar VERB advmod
#
#    SPACE
# que SCONJ nsubj
# dejar AUX ccomp
# á ADP case
# su DET det
# hijo NOUN obj
# único ADJ amod
# , PUNCT punct
# Mauricio PROPN appos
# Ridel PROPN flat
# , PUNCT punct
# el DET det
# valor NOUN obj
# de ADP case
# doscientos NUM nmod
#
#    SPACE
# mil NUM nummod
# peso NOUN appos
# en ADP case
# propiedad NOUN nmod
# urbano ADJ amod
# y CCONJ cc
# rural ADJ conj
# , PUNCT punct
# volviéndose VERB advcl
# á ADP case
# su DET det
#
#    SPACE
# esposar ADJ obj
# , PUNCT punct
# pidióle PROPN appos
# permiso NOUN amod
# parir ADP mark
# instituirme VERB advcl
# á ADP case
# mí PRON obj
# , PUNCT punct
# hasta ADP case
# lo DET det
# mayoría NOUN nmod
# de ADP case
#
#    SPACE
# aquel PRON nmod
# , PUNCT punct
# guardador NOUN advcl
# de ADP case
# dicho ADJ amod
# bien NOUN nmod
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Repugnábame VERB nsubj
# uno DET det
# mision NOUN obj
# visiblemente ADV advmod
# motivar ADJ amod
# por ADP case
# disensión NOUN obj
#
#    SPACE
# conyugal ADJ amod
# ; PUNCT punct
# pero CCONJ cc
# lo DET det
# ojo NOUN nsubj
# de ADP case
# lo DET det
# moribundo ADJ nmod
# enviáronme PROPN conj
# uno DET det
# mirar NOUN obj
# de ADP case
#
#    SPACE
# angustioso ADJ acl
# rogar NOUN ROOT
# , PUNCT punct
# que SCONJ mark
# me PRON obj
# hacer VERB ccomp
# aceptarla VERB xcomp
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Ella PRON nsubj
# entónces ADV advmod
# suspirar VERB ROOT
# comer SCONJ mark
# aliviar ADJ obj
# de ADP case
# uno DET det
# gravar ADJ amod
# preocupacion NOUN nmod
# ; PUNCT punct
#
#    SPACE
# estrechar VERB advcl
# mi DET det
# manir NOUN obj
# con ADP case
# gratitud NOUN nmod
# , PUNCT punct
# y CCONJ cc
# morir VERB conj
# en ADP case
# paz NOUN obl
# . PUNCT punct
#
#
#    SPACE
# « PUNCT nsubj
# Yo PRON nsubj
# haber AUX aux
# cumplir VERB ROOT
# fielmente ADV advmod
# el DET det
# deber NOUN obj
# que SCONJ nsubj
# me PRON obj
# imponer AUX acl
# : PUNCT punct
# haber AUX aux
# administrar VERB advcl
#
#    SPACE
# ese DET det
# bien NOUN obj
# con ADP case
# el DET det
# acertar NOUN nmod
# que SCONJ nsubj
# dá VERB acl
# uno DET det
# largo ADJ amod
# experiencia NOUN obj
# en ADP case
# lo DET det
#
#    SPACE
# negocio NOUN nmod
# ; PUNCT punct
# lo PRON obj
# haber AUX aux
# conservar VERB advcl
# , PUNCT punct
# lo PRON iobj
# haber AUX aux
# hacer VERB advcl
# fructificar VERB xcomp
# : PUNCT punct
# pero CCONJ cc
# siempre ADV advmod
#
#    SPACE
# en ADP case
# el DET det
# limitar NOUN conj
# que SCONJ mark
# mi DET det
# delicadeza NOUN nsubj
# me PRON obj
# prescribir AUX acl
# : PUNCT punct
# no ADV advmod
# comer SCONJ fixed
# guardador NOUN obl
# , PUNCT punct
#
#    SPACE
# sino CCONJ cc
# comer SCONJ mark
# administrador NOUN obj
# , PUNCT punct
# rendir VERB acl
# cuenta NOUN obj
# de ADP case
# mi DET det
# cometer NOUN nmod
# y CCONJ cc
#
#    SPACE
# entregar VERB conj
# al ADP case
# señor NOUN obj
# Ridel PROPN appos
# los DET det
# fuerte ADJ amod
# sumo NOUN obj
# que SCONJ obj
# producir AUX acl
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Hoy ADV advmod
# me PRON iobj
# haber AUX aux
# hacer VERB ROOT
# saber VERB csubj
# que SCONJ mark
# V. PROPN nsubj
# se PRON obj
# haber AUX aux
# emancipar VERB ccomp
# ; PUNCT punct
# y CCONJ cc
# que SCONJ nsubj
# , PUNCT punct
# por ADP advmod
# tanto INTJ fixed
# , PUNCT punct
#
#    SPACE
# lo DET det
# ingerencia NOUN nsubj
# que SCONJ obj
# yo PRON nsubj
# le PRON obj
# dar AUX acl
# en ADP case
# lo DET det
# asunto NOUN obl
# de ADP case
# su DET det
# hijo NOUN nmod
# , PUNCT punct
# haber AUX aux
# cesar VERB conj
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Por ADP advmod
# consecuencia INTJ fixed
# , PUNCT punct
# y CCONJ cc
# persuadir ADJ conj
# de ADP mark
# que SCONJ mark
# él PRON nsubj
# haber VERB aux
# informar VERB ccomp
# á ADP case
# V. PROPN obj
# del ADP mark
#
#    SPACE
# estar NOUN cop
# floreciente ADJ ROOT
# de ADP case
# su DET det
# fortuna NOUN nmod
# , PUNCT punct
# no PART cc
# solo INTJ fixed
# por ADP case
# mi DET det
# bueno ADJ amod
# voluntad NOUN conj
# en ADP case
#
#    SPACE
# su DET det
# administracion PROPN nmod
# , PUNCT punct
# sino CCONJ cc
# á ADP case
# causar INTJ fixed
# del ADP fixed
# subir ADJ amod
# preciar NOUN conj
# que SCONJ obj
# haber AUX aux
# adquirir VERB acl
#
#    SPACE
# lo DET det
# propiedad NOUN appos
# , PUNCT punct
# réstame VERB conj
# solo ADV obj
# ponerla VERB xcomp
# á ADP case
# su DET det
# disposicion NOUN obl
# , PUNCT punct
# y CCONJ cc
# pedirle VERB conj
# se PRON obj
#
#    SPACE
# servir VERB ccomp
# impartirme VERB xcomp
# su DET det
# orden NOUN obj
# » PUNCT punct
# . PUNCT punct
#
#
#  SPACE
# Esta DET det
# carta NOUN nsubj
# de ADP case
# uno DET det
# tutor NOUN nmod
# hasta ADP case
# entónces ADV advmod
# ignorar ADJ amod
# , PUNCT punct
# fué AUX cop
# uno DET det
# rayar NOUN ROOT
# de ADP case
# luz NOUN nmod
# en ADP case
#
#  SPACE
# el DET det
# misterio NOUN nmod
# que SCONJ nsubj
# rodear AUX acl
# el DET det
# pasar NOUN obj
# de ADP case
# Mauricio PROPN nmod
# , PUNCT punct
# y CCONJ cc
# efectuar VERB conj
# uno DET det
# cambiar NOUN obj
#
#  SPACE
# favorable ADJ amod
# en ADP case
# su DET det
# destinar NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Alejado ADJ case
# de ADP case
# su DET det
# padre NOUN obl
# , PUNCT punct
# por ADP case
# lo DET det
# funesto ADJ amod
# influenciar NOUN obl
# que SCONJ nsubj
# se PRON obj
# alzar AUX acl
# hostil ADJ obj
#
#  SPACE
# entrar ADP case
# ambos NUM obl
# , PUNCT punct
# el DET det
# hijo NOUN appos
# desechar ADJ amod
# , PUNCT punct
# bendecir VERB nsubj
# lo DET det
# ternura NOUN amod
# previsor ADJ obj
# de ADP case
# aquel DET det
#
#  SPACE
# madre NOUN nmod
# moribundo ADJ amod
# , PUNCT punct
# que SCONJ nsubj
# ver VERB acl
# cernerse VERB xcomp
# lo DET det
# desgraciar NOUN obj
# sobrar ADP case
# lo DET det
# cunar NOUN nmod
# del ADP case
#
#  SPACE
# niño NOUN nmod
# que SCONJ nsubj
# le PRON obj
# ser VERB cop
# forzoso ADJ acl
# abandonar VERB csubj
# , PUNCT punct
# haber VERB aux
# querer VERB ROOT
# , PUNCT punct
# asegurándole VERB advcl
# uno DET det
#
#  SPACE
# fortuna NOUN obj
# independiente ADJ amod
# , PUNCT punct
# preservarlo VERB xcomp
# en ADP case
# lo DET det
# azarar NOUN obl
# del ADP case
# porvenir NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Mauricio PROPN nsubj
# expresar VERB ROOT
# su DET det
# ...
# leer VERB ROOT
# lo DET det
# carta NOUN obj
# que SCONJ obj
# acompañar AUX acl
# este DET det
# documento NOUN nsubj
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Cuando SCONJ mark
# leer VERB dep
# este DET det
# líneo NOUN obj
# , PUNCT punct
# mi DET det
# bien ADV obl
# amar ADJ amod
# Lucrecia,--decía PROPN nsubj
# Ridel PROPN flat
# á ADP case
#
#    SPACE
# su DET det
# esposa--muerto ADJ conj
# ó CCONJ cc
# vivir ADJ conj
# , PUNCT punct
# haber VERB aux
# de ADP mark
# perdonar VERB ROOT
# mi DET det
# primero ADJ amod
# y CCONJ cc
# único ADJ conj
#
#    SPACE
# desobediencia NOUN obj
# , PUNCT punct
# en ADP case
# gracia INTJ nmod
# del ADP case
# motivar NOUN nmod
# que SCONJ nsubj
# lo PRON obj
# inspirar VERB acl
# ; PUNCT punct
# hélo PROPN advcl
# aquí ADV advmod
# : PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Tengo VERB advcl
# por ADP case
# todo DET det
# institucion NOUN obj
# benéfico ADJ amod
# , PUNCT punct
# lo DET det
# más ADV advmod
# alto ADJ nsubj
# estimar VERB advcl
# ; PUNCT punct
# y CCONJ cc
#
#    SPACE
# profundo ADJ amod
# gratitud NOUN conj
# por ADP case
# los DET det
# que SCONJ obl
# se PRON obj
# levantar AUX acl
# en ADP case
# nuestro DET det
# país NOUN obl
# . PUNCT punct
#
#
#    SPACE
# « PUNCT ROOT
# Entre ADP case
# este PRON obl
# , PUNCT punct
# los DET det
# Compañías NOUN nsubj
# de ADP case
# Seguros PROPN flat
# sónme PROPN flat
# especialmente ADV advmod
#
#    SPACE
# simpático ADJ obj
# , PUNCT punct
# sobretodo ADV conj
# , PUNCT punct
# « PUNCT punct
# La DET det
# Buenos PROPN conj
# Aires PROPN flat
# » PUNCT punct
# , PUNCT punct
# por ADP case
# su DET det
# importancia NOUN obl
# y CCONJ cc
#
#    SPACE
# valioso ADJ amod
# organizacion PROPN conj
# . PUNCT punct
#
#
#    SPACE
# « PUNCT punct
# Así ADV advmod
# , PUNCT punct
# en ADP mark
# tanto INTJ fixed
# que SCONJ fixed
# me PRON iobj
# permitir VERB ROOT
# ser VERB cop
# su DET det
# accionista NOUN xcomp
# , PUNCT punct
# haber AUX aux
# querer VERB conj
#
#    SPACE
# pertenecerle VERB xcomp
# , PUNCT punct
# al ADP advmod
# menos ADV fixed
# , PUNCT punct
# por ADP case
# uno DET det
# seguro NOUN obl
# » PUNCT punct
# ...... PUNCT punct
#
#
#  SPACE
# Mauricio PROPN nsubj
# no ADV advmod
# poder AUX aux
# leer VERB ROOT
# más ADV advmod
# . PUNCT punct
#
#
#  SPACE
# Una DET det
# ola NOUN nsubj
# amargo ADJ amod
# subir VERB ROOT
# á ADP case
# su DET det
# corazon NOUN obl
# despertar VERB advcl
# todo DET det
# lo DET det
# antiguo ADJ amod
#
#  SPACE
# dolor NOUN obj
# filial ADJ amod
# . PUNCT punct
#
#
#  SPACE
# En ADP case
# lo DET det
# vida NOUN obl
# comer SCONJ cc
# en ADP case
# lo DET det
# eternidad NOUN conj
# , PUNCT punct
# siempre ADV advmod
# lo DET det
# sombrar NOUN nsubj
# fatídico ADJ amod
# de ADP case
# su DET det
#
#  SPACE
# madrastra NOUN nmod
# venir VERB ROOT
# á ADP mark
# colocarse VERB xcomp
# entrar ADP case
# él PRON obl
# y CCONJ cc
# su DET det
# padre NOUN conj
# .... PUNCT appos
#
#
#  SPACE
# Pero CCONJ advmod
# , PUNCT punct
# luego ADV advmod
# , PUNCT punct
# lo DET det
# imágen NOUN nsubj
# de ADP case
# Julia PROPN nmod
# , PUNCT punct
# comer SCONJ mark
# uno DET det
# rayar NOUN nmod
# de ADP case
# luz NOUN nmod
# , PUNCT punct
# borrar VERB ROOT
# aquel DET det
#
#  SPACE
# penoso ADJ amod
# impresion NOUN obj
# . PUNCT punct
#
#
#
#
#
#  SPACE
# XXXI PROPN nsubj
#
#
#
#  SPACE
# --La DET punct
# Capilla PROPN flat
# de ADP case
# Nuestra PROPN det
# Señora PROPN flat
# de ADP case
# los DET det
# Victorias PROPN flat
# tener AUX ROOT
# hoy ADV advmod
# uno DET det
# aspecto NOUN obj
#
#  SPACE
# imponente ADJ amod
# . PUNCT punct
# Llenábala VERB nsubj
# el DET det
# cortejar NOUN obj
# de ADP case
# uno DET det
# boda.-- PROPN nmod
#
#
#  SPACE
# Así ADV advmod
# llegar VERB ROOT
# decir VERB xcomp
# los DET det
# joven NOUN obj
# de ADP case
# volver NOUN nmod
# de ADP case
# misa NOUN nmod
# de ADP case
# ocho NUM nummod
# . PUNCT punct
#
#
#  SPACE
# ¡ PUNCT punct
# Una DET det
# boda NOUN nsubj
# ! PUNCT punct
# Suena VERB ROOT
# tan ADV advmod
# bien ADV advmod
# este DET det
# mágico ADJ amod
# palabra NOUN nsubj
# , PUNCT punct
# que SCONJ obj
# muy ADV advmod
# luego ADV advmod
# tener VERB acl
# todo DET det
#
#  SPACE
# lo DET det
# casar NOUN obj
# por ADP case
# auditorio NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Y CCONJ advmod
# los DET det
# joven NOUN nsubj
# continuar AUX ROOT
# , PUNCT punct
# y CCONJ cc
# en ADP case
# su DET det
# entusiasta ADJ amod
# lenguaje NOUN conj
# : PUNCT punct
#
#
#  SPACE
# --¡Qué PROPN ROOT
# bello PROPN flat
# pareja!--decían PROPN flat
# . PUNCT punct
#
#
#  SPACE
# --El DET ROOT
# , PUNCT punct
# todo DET det
# uno DET det
# bueno ADJ amod
# mozo NOUN appos
# ; PUNCT punct
# con ADP case
# uno DET det
# aire NOUN obl
# tan ADV advmod
# sério ADJ amod
# y CCONJ cc
# distinguir ADJ conj
# . PUNCT punct
#
#
#  SPACE
# --¡Ella NUM punct
# ! PUNCT punct
# ¡ PUNCT punct
# moreno NOUN ROOT
# más ADV advmod
# lindo ADJ amod
# ! PUNCT punct
# Qué DET det
# alianza NOUN ROOT
# encantador ADJ amod
# de ADP case
# el PRON det
# blanco ADJ amod
# de ADP case
# lo DET det
#
#  SPACE
# piel NOUN nmod
# y CCONJ cc
# el PRON det
# negro NOUN conj
# de ADP case
# ojo NOUN nmod
# y CCONJ cc
# cabello NOUN conj
# ! PUNCT punct
#
#
#  SPACE
# --¡Muchachas NUM nsubj
# ! PUNCT punct
# ¡ PUNCT punct
# no ADV advmod
# haber AUX ROOT
# que SCONJ cc
# exagerar VERB conj
# ! PUNCT punct
#
#
#  SPACE
# --¡Oh PRON ROOT
# ! PUNCT punct
# si SCONJ mark
# nadar PRON nsubj
# hemo AUX aux
# decir VERB ROOT
# todavía ADV advmod
# . PUNCT punct
# Escucha.-- NOUN ROOT
#
#
#  SPACE
# Y CCONJ advmod
# dejar VERB advcl
# por ADP case
# aquí ADV advmod
# y CCONJ cc
# por ADP case
# allí ADV conj
# , PUNCT punct
# sombrero NOUN obj
# , PUNCT punct
# guante NOUN conj
# y CCONJ cc
# abanico ADJ conj
# , PUNCT punct
#
#  SPACE
# continuar VERB ROOT
# , PUNCT punct
# quitándose VERB advcl
# uno PRON obj
# á ADP case
# otro PRON det
# lo DET det
# palabra NOUN nmod
# : PUNCT punct
#
#
#  SPACE
# --Que NUM nsubj
# bien ADV advmod
# estar AUX cop
# lo DET det
# lindo ADJ amod
# morocha NOUN advcl
# , PUNCT punct
# en ADP case
# su DET det
# vestir NOUN nmod
# de ADP case
# faya NOUN nmod
# , PUNCT punct
# tan ADV advmod
# sencillo ADJ amod
#
#  SPACE
# comer SCONJ mark
# elegante NOUN amod
# , PUNCT punct
# y CCONJ cc
# su DET det
# velar NOUN conj
# de ADP case
# tul PROPN nmod
# de ADP case
# sedar NOUN nmod
# liso ADJ amod
# : PUNCT punct
# el DET det
# todo PRON appos
# sin ADP case
# más ADV advmod
# adorno NOUN nmod
#
#  SPACE
# que SCONJ mark
# azahar NOUN acl
# natural ADJ amod
# . PUNCT punct
#
#
#  SPACE
# --Un VERB punct
# piar NOUN nsubj
# de ADP case
# Cendrillon PROPN nmod
# calzar VERB ROOT
# uno DET det
# zapatito NOUN obj
# de ADP case
# rasar PROPN nmod
# blanco PROPN amod
# , PUNCT punct
# adornar ADJ amod
#
#  SPACE
# tambien NOUN advmod
# con ADP case
# azahar NOUN obl
# . PUNCT punct
#
#
#  SPACE
# --Un VERB punct
# precioso ADJ ROOT
# abanicar NOUN amod
# formar ADJ amod
# de ADP case
# mariposa NOUN obj
# trasparente ADJ amod
# : PUNCT punct
# y CCONJ cc
# chico ADJ conj
# , PUNCT punct
# á ADP case
# lo DET det
#
#  SPACE
# último ADJ amod
# moda NOUN conj
# . PUNCT punct
#
#
#  SPACE
# --Pocas PUNCT det
# señor NOUN ROOT
# ; PUNCT punct
# muy ADV advmod
# elegante ADJ amod
# todo PRON appos
# . PUNCT punct
#
#
#  SPACE
# --Pero PUNCT cc
# ¡ PUNCT punct
# qué DET det
# gran ADJ amod
# séquito NOUN ROOT
# de ADP case
# caballero NOUN nmod
# ! PUNCT punct
# Toda DET det
# lo DET det
# prensar NOUN ROOT
# : PUNCT punct
# el DET det
# general NOUN appos
#
#  SPACE
# Mitre PROPN appos
# , PUNCT punct
# Bartolito PROPN appos
# , PUNCT punct
# Dávila PROPN conj
# , PUNCT punct
# Lainez PROPN conj
# , PUNCT punct
# Vedia PROPN conj
# , PUNCT punct
# Laurencena PROPN appos
# , PUNCT punct
# Lalanne PROPN conj
# , PUNCT punct
# Walls PROPN conj
# , PUNCT punct
#
#  SPACE
# Ribaumont PROPN flat
# , PUNCT punct
# Ortega PROPN conj
# , PUNCT punct
# Alberú PROPN conj
# , PUNCT punct
# Mulhall PROPN conj
# y CCONJ cc
# tanto DET det
# otro PRON conj
# . PUNCT punct
#
#
#  SPACE
# --Estaban AUX nsubj
# tambien NOUN advmod
# Eduardo PROPN dep
# Coll PROPN flat
# y CCONJ cc
# Emilio PROPN conj
# Casares PROPN flat
# que SCONJ nsubj
# fué AUX cop
# el DET det
# padrino NOUN acl
# y CCONJ cc
#
#  SPACE
# que SCONJ nsubj
# decir AUX conj
# haber AUX aux
# hacer VERB ROOT
# uno DET det
# régio NOUN amod
# obsequiar PROPN obj
# á ADP case
# lo DET det
# novio NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# --Muchos NUM det
# literato NOUN ROOT
# ; PUNCT punct
# el DET det
# general NOUN appos
# Sarmiento PROPN appos
# , PUNCT punct
# Santiago PROPN appos
# Estrada PROPN flat
# , PUNCT punct
# José PROPN appos
# María PROPN flat
#
#  SPACE
# Zuviría PROPN flat
# , PUNCT punct
# el DET det
# ministro NOUN appos
# de ADP case
# Bolivia PROPN nmod
# doctor NOUN flat
# Vaca PROPN flat
# Guzman PROPN flat
# y CCONJ cc
# tanto DET det
# otro PRON conj
# , PUNCT punct
#
#  SPACE
# hijo NOUN appos
# , PUNCT punct
# que SCONJ obj
# yo PRON nsubj
# no ADV advmod
# conocer VERB acl
# . PUNCT punct
# Apenas ADV advmod
# caber AUX ROOT
# en ADP case
# lo DET det
# capilla NOUN obl
# . PUNCT punct
#
#
#  SPACE
# --El DET det
# celebrante NOUN nsubj
# , PUNCT punct
# que SCONJ nsubj
# ser VERB cop
# el DET det
# elocuentísimo ADJ amod
# padre NOUN nsubj
# Pera PROPN appos
# unir VERB ROOT
# á ADP case
# lo DET det
#
#  SPACE
# contrayente ADJ obj
# con ADP case
# los DET det
# palabra NOUN obl
# sacramental ADJ amod
# , PUNCT punct
# pronunciar ADJ amod
# con ADP case
# uncion PROPN obl
#
#  SPACE
# conmovedor ADJ amod
# . PUNCT punct
#
#
#  SPACE
# Despues PROPN nsubj
# , PUNCT punct
# volviéndose VERB advcl
# al ADP case
# auditorio NOUN obl
# , PUNCT punct
# hablar VERB ROOT
# de ADP case
# lo DET det
# excelencia NOUN obj
# del ADP case
#
#  SPACE
# matrimoniar NOUN nmod
# , PUNCT punct
# de ADP case
# su DET det
# orígen NOUN nmod
# divino ADJ amod
# , PUNCT punct
# de ADP case
# su DET det
# utilidad NOUN nmod
# en ADP case
# lo DET det
# comunion NOUN nmod
# humano ADJ amod
# , PUNCT punct
#
#  SPACE
# de ADP case
# lo DET det
# santidad NOUN nmod
# de ADP case
# su DET det
# fin NOUN nmod
# , PUNCT punct
# del ADP case
# viático NOUN conj
# de ADP case
# virtud NOUN nmod
# que SCONJ obj
# á ADP case
# él PRON obj
# deber AUX aux
#
#  SPACE
# llevarse VERB acl
# . PUNCT punct
#
#
#  SPACE
# --Señores,--añadió--permitidme NUM ROOT
# presentaros VERB xcomp
# uno DET det
# modelar NOUN obj
# de ADP case
# ese DET det
# virtud NOUN nmod
#
#  SPACE
# en ADP case
# lo DET det
# cónyugues NOUN obl
# que SCONJ nsubj
# acabar AUX acl
# de ADP mark
# unir VERB xcomp
# : PUNCT punct
# do NUM nummod
# hijo NOUN appos
# animoso ADJ amod
# del ADP case
# trabajar NOUN nmod
# . PUNCT punct
#
#  SPACE
# El DET det
# unir PRON ROOT
# , PUNCT punct
# despojándose VERB acl
# de ADP case
# uno DET det
# gran ADJ amod
# fortuna NOUN obj
# parir ADP mark
# salvar VERB acl
# de ADP case
# lo DET det
# deshonrar PROPN obj
#
#  SPACE
# lo DET det
# memoria NOUN obj
# de ADP case
# uno DET det
# padre NOUN nmod
# ; PUNCT punct
# el DET det
# otro PRON appos
# , PUNCT punct
# en ADP case
# lo DET det
# débil ADJ amod
# adolescencia NOUN obl
# , PUNCT punct
# luchar VERB advcl
#
#  SPACE
# valerosamente ADV advmod
# con ADP case
# los DET det
# dificultad NOUN obj
# de ADP case
# lo DET det
# vida NOUN nmod
# y CCONJ cc
# el DET det
# desamparar NOUN conj
# de ADP case
# lo DET det
#
#  SPACE
# orfandad NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Se PRON obj
# amar AUX ROOT
# . PUNCT punct
# Libres ADJ nsubj
# , PUNCT punct
# poder VERB aux
# unirse VERB ROOT
# el DET det
# unir PRON obj
# al ADP case
# otro PRON obl
# . PUNCT punct
#
#
#  SPACE
# Pero CCONJ advmod
# ser VERB cop
# pobre ADJ ROOT
# ; PUNCT punct
# y CCONJ cc
# en ADP case
# lo DET det
# rectitud NOUN obl
# de ADP case
# su DET det
# corazon NOUN nmod
# , PUNCT punct
# querer AUX conj
# preparar VERB xcomp
# el DET det
#
#  SPACE
# hogar NOUN obj
# , PUNCT punct
# antes ADV advmod
# de ADP mark
# traer VERB advcl
# lo DET det
# familia NOUN obj
# ; PUNCT punct
# y CCONJ cc
# dar ADJ conj
# al ADP case
# trabajar NOUN obj
# , PUNCT punct
# aguardar AUX advcl
# , PUNCT punct
# en ADP case
#
#  SPACE
# ese DET det
# penoso ADJ amod
# retardar NOUN obl
# á ADP case
# su DET det
# decir NOUN nmod
# , PUNCT punct
# resignar ADJ amod
# , PUNCT punct
# confiar VERB advcl
# en ADP case
# Dios PROPN obl
# y CCONJ cc
# en ADP case
# lo DET det
#
#  SPACE
# fortaleza NOUN conj
# de ADP case
# su DET det
# alma NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Mas PROPN nsubj
# , PUNCT punct
# no ADV advmod
# en ADP advmod
# vano INTJ fixed
# confiar VERB ROOT
# en ADP case
# « PUNCT punct
# Aquel PROPN obj
# que SCONJ mark
# formar VERB ccomp
# de ADP case
# los DET det
# piedra NOUN nmod
# hijo NOUN amod
# á ADP case
#
#  SPACE
# Abraham PROPN obj
# » PROPN punct
# .... PUNCT obj
#
#
#  SPACE
# Existen AUX ROOT
# varios DET det
# institución NOUN nsubj
# crear ADJ amod
# con ADP case
# capital NOUN obl
# formar ADJ amod
# por ADP case
# lo DET det
#
#  SPACE
# honradez NOUN obj
# y CCONJ cc
# el DET det
# trabajar NOUN conj
# , PUNCT punct
# que SCONJ nsubj
# con ADP case
# el DET det
# modesto ADJ amod
# nombrar NOUN obl
# de ADP case
# Compañías PROPN nmod
# de ADP case
#
#  SPACE
# Seguros PROPN flat
# , PUNCT punct
# ejercer AUX acl
# lo DET det
# más ADV advmod
# benéfico ADJ amod
# influenciar NOUN obj
# en ADP case
# lo DET det
# vida NOUN nmod
# económico ADJ amod
# de ADP case
# lo DET det
#
#  SPACE
# pueblo NOUN nmod
# ; PUNCT punct
# porque SCONJ mark
# , PUNCT punct
# cualquiera PRON obl
# que SCONJ nsubj
# ser VERB cop
# lo DET det
# formar NOUN acl
# en ADP case
# que SCONJ obl
# se PRON obj
# tomar VERB acl
# , PUNCT punct
# el DET det
# seguro ADJ nsubj
#
#  SPACE
# encerrar VERB advcl
# el DET det
# bienestar NOUN obj
# futuro ADJ amod
# de ADP case
# lo DET det
# familia NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# En ADP case
# el DET det
# seno NOUN obl
# de ADP case
# uno PRON nmod
# de ADP case
# ese DET det
# asociación NOUN nmod
# tutelar ADJ amod
# , PUNCT punct
# « PUNCT punct
# La DET det
# Buenos PROPN appos
# Aires PROPN flat
# » PROPN punct
# , PUNCT punct
#
#  SPACE
# lo DET det
# Providencia PROPN nsubj
# guardar AUX ROOT
# uno DET det
# tesoro NOUN obj
# que SCONJ nsubj
# á ADP case
# su DET det
# hora NOUN obl
# , PUNCT punct
# hacer AUX acl
# surgir VERB xcomp
# parir ADP mark
#
#  SPACE
# recompensar VERB advcl
# lo DET det
# abnegacion PROPN obj
# filial PROPN amod
# y CCONJ cc
# dar VERB conj
# lo DET det
# felicidad NOUN obj
# á ADP case
# lo DET det
# que SCONJ nsubj
# , PUNCT punct
#
#  SPACE
# creer VERB advcl
# en ADP case
# él PRON obj
# , PUNCT punct
# esperar AUX acl
# . PUNCT punct
#
#
#  SPACE
# --¡Que DET punct
# el DET det
# Altísimo PROPN nsubj
# o PRON obj
# bendiga!-- PROPN ROOT
#
#
#  SPACE
# Y CCONJ advmod
# caer VERB advcl
# de ADP case
# rodilla NOUN obl
# , PUNCT punct
# el DET det
# hombre NOUN nsubj
# de ADP case
# Dios PROPN nmod
# se PRON obj
# absorber VERB ROOT
# en ADP case
# mental ADJ obl
#
#  SPACE
# plegaria ADJ flat
# .... PUNCT obl
#
#
#  SPACE
# --Corrimos VERB ROOT
# al ADP case
# pórtico NOUN nmod
# parir ADP mark
# ver VERB acl
# el DET det
# desfilar NOUN obj
# de ADP case
# lo DET det
# comitiva NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# Veinte NUM nummod
# carruaje NOUN nsubj
# aguardar AUX ROOT
# alinear ADJ advmod
# , PUNCT punct
# al ADP case
# bordar INTJ fixed
# de ADP fixed
# lo DET det
# vereda NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Los DET det
# esposo NOUN nsubj
# , PUNCT punct
# entrelazar ADJ amod
# lo DET det
# brazo NOUN obj
# , PUNCT punct
# salir VERB ROOT
# seguir ADJ obj
# del ADP case
# cortejar NOUN obl
# , PUNCT punct
#
#  SPACE
# que SCONJ nsubj
# se PRON obj
# reunir VERB advcl
# delante ADV advmod
# del ADP case
# coche NOUN obl
# nupcial PROPN amod
# . PUNCT punct
#
#
#  SPACE
# El DET det
# novio NOUN ROOT
# estrechar VERB acl
# con ADP case
# efusion PROPN obl
# lo DET det
# manir NOUN obj
# á ADP case
# Coll PROPN obj
# . PUNCT punct
#
#
#  SPACE
# --¡Noble ADP nsubj
# corazon!--le NOUN flat
# dijo--¡que VERB flat
# el DET det
# espectáculo NOUN nsubj
# de ADP case
# nuestro DET det
# felicidad NOUN nmod
#
#  SPACE
# ser VERB cop
# su DET det
# recompensar NOUN ROOT
# ! PUNCT punct
#
#
#  SPACE
# Y CCONJ advmod
# volviéndose VERB csubj
# á ADP case
# lo DET det
# comitiva NOUN obj
# cambiar VERB ROOT
# con ADP case
# él PRON obl
# uno DET det
# mirar NOUN obj
# de ADP case
# inteligencia NOUN nmod
# ; PUNCT punct
#
#  SPACE
# luego ADV advmod
# dirigiéndose VERB advcl
# al ADP case
# cochero NOUN obj
# . PUNCT punct
#
#
#  SPACE
# --¡Al PUNCT amod
# muelle NOUN ROOT
# de ADP case
# pasageros!--ordenó PROPN nmod
# . PUNCT punct
#
#
#  SPACE
# La DET det
# novio NOUN nsubj
# mirándolo PROPN ROOT
# sorprender ADJ obj
# . PUNCT punct
#
#
#  SPACE
# --¡Al PUNCT nsubj
# muelle PROPN flat
# de ADP case
# pasageros!--repitió--¿Dónde NUM nummod
# ir AUX ROOT
# , PUNCT punct
# pues SCONJ mark
# ? PUNCT punct
#
#
#  SPACE
# --A ADP case
# Francia PROPN ROOT
# , PUNCT punct
# amar ADJ amod
# mia PROPN obj
# , PUNCT punct
# parir ADP mark
# pedir VERB acl
# al ADP case
# sepulcro NOUN obl
# lo DET det
# resto NOUN obj
# que SCONJ obj
# llorar VERB acl
# y CCONJ cc
#
#  SPACE
# devolverlos VERB conj
# á ADP case
# lo DET det
# tierra NOUN obj
# de ADP case
# lo DET det
# patrio NOUN nmod
# . PUNCT punct
#
#
#  SPACE
# La DET det
# jóven NOUN nsubj
# exhalar VERB ROOT
# uno DET det
# gemir NOUN obj
# y CCONJ cc
# arrojándose VERB conj
# en ADP case
# lo DET det
# brazo NOUN obl
# del ADP case
# esposar NOUN nmod
# , PUNCT punct
#
#  SPACE
# esconder VERB advcl
# lo DET det
# frente INTJ obj
# en ADP case
# su DET det
# seno NOUN obl
# . PUNCT punct
#
#
#  SPACE
# Todos PRON nsubj
# llorar VERB ROOT
# .... PUNCT obj
#
#
#  SPACE
# Yo PRON nsubj
# tambien PROPN flat
# llorar AUX ROOT
# . PUNCT punct

# %% [markdown]
# ## Practicing with the example text
# When working with languages that have inflection, we typically use `token.lemma_` instead of `token.text` like you'll find in the English examples. This is important when we're counting, so that differently-inflected forms of a word (e.g. masculine vs. feminine or singular vs. plural) aren't counted as if they were different words.

# %%
filepath = "../texts/other-languages/es.txt"
document = nlp(open(filepath, encoding="utf-8").read())

# %% [markdown]
# ## Get Adjectives

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |

# %% [markdown]
# To extract and count the adjectives in the example text, we will follow the same model as above, except we'll add an `if` statement that will pull out words only if their POS label matches "ADJ."

# %% [markdown]
# ```{admonition} Python Review!
# :class: pythonreview
# While we demonstrate how to extract parts of speech in the sections below, we're also going to reinforce some integral Python skills. Notice how we use `for` loops and `if` statements to `.append()` specific words to a list. Then we count the words in the list and make a pandas dataframe from the list.
# ```

# %% [markdown]
# Here we make a list of the adjectives identified in the example text:

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.lemma_)

# %%
adjs
# Out:
# ['sombrío',
#  'imbuído',
#  'terrenal',
#  'mal',
#  'desconsolar',
#  'menesteroso',
#  'ingrato',
#  'humano',
#  'trayéndoles',
#  'plausible',
#  'nuevo',
#  'eficaz',
#  'innúmero',
#  'multiplicar',
#  'social',
#  'venerable',
#  'entendido',
#  'grave',
#  'político',
#  'moralizador',
#  'colectivo',
#  'precioso',
#  'especulativo',
#  'individual',
#  'concluir',
#  'abstracto',
#  'ilustrar',
#  'elevar',
#  'intelectual',
#  'americano',
#  'creador',
#  'lujurioso',
#  'invocar',
#  'presentar',
#  'atrayente',
#  'económico',
#  'natural',
#  'ingénua',
#  'social',
#  'noble',
#  'fuerte',
#  'privilegiar',
#  'prestigioso',
#  'suficiente',
#  'soñador',
#  'adusto',
#  'economista',
#  'último',
#  'marcar',
#  'CHAMUSQUINAS',
#  'extremo',
#  'armar',
#  '\ufeff1',
#  'último',
#  'último',
#  'plegaria',
#  'cariñoso',
#  'pálido',
#  'mojar',
#  '\ufeff1',
#  'aguardar',
#  'aurora',
#  'dramático',
#  'párias',
#  'forzar',
#  'diario',
#  'encorvar',
#  'implacable',
#  'terrible',
#  'sanar',
#  'fuerte',
#  'proponer',
#  'sentar',
#  'malo',
#  'querer',
#  'mejorar',
#  'largo',
#  'Uncido',
#  'rudo',
#  'pegar',
#  'editorial',
#  'cronista',
#  'folletinista',
#  'corrector',
#  'avaro',
#  'insoluble',
#  'franco',
#  'bueno',
#  'largar',
#  'engolfar',
#  'presuroso',
#  'habitual',
#  'contar',
#  'plácido',
#  'bello',
#  'apostar',
#  'melancólico',
#  'adverso',
#  'adverso',
#  'adverso',
#  'mecer',
#  'extraño',
#  'solo',
#  'solo',
#  'subyugar',
#  'siniestro',
#  'pobre',
#  'temeroso',
#  'acoquinar',
#  'fatídico',
#  'espiar',
#  'suspicaz',
#  'inexorable',
#  'gozoso',
#  'inocente',
#  'vuélvense',
#  'taciturno',
#  'desconfiar',
#  '\ufeff1',
#  'triste',
#  'paterno',
#  'enemigo',
#  'hostil',
#  'mostrárseles',
#  'propiciar',
#  'retrospectivo',
#  'arrebatar',
#  'entregar',
#  'inglés',
#  'pobre',
#  'cruel',
#  'materno',
#  'necesario',
#  'decir',
#  'bello',
#  'característico',
#  'social',
#  'irresistible',
#  'consignar',
#  'bueno',
#  'benévolo',
#  'expansivo',
#  'pobre',
#  'oprimir',
#  'feliz',
#  'nuevo',
#  'caluroso',
#  'dulce',
#  'largo',
#  'clásico',
#  'superior',
#  'vestir',
#  'infantil',
#  'viril',
#  'primero',
#  'imponente',
#  'tierno',
#  'Cumplido',
#  'divino',
#  'virtuoso',
#  'bueno',
#  'gozoso',
#  'alto',
#  'central',
#  'solo',
#  'solemne',
#  'Solo',
#  'bueno',
#  'enternecer',
#  'Mauricio--¿Quieres',
#  'lindo',
#  'viejo',
#  'deber',
#  'primero',
#  'imponente',
#  'sagrado',
#  'viejo',
#  'lejano',
#  'angelical',
#  'santo',
#  'notable',
#  'inquieto',
#  'cosmopolita',
#  'exaltar',
#  'clásico',
#  'tricolor',
#  'azul',
#  'sagrado',
#  'nacional',
#  'lejano',
#  'pasar',
#  'inmenso',
#  'magestuoso',
#  'poderoso',
#  'luminoso',
#  'siniestro',
#  'humillante',
#  'consultar',
#  'corregir',
#  'dictar',
#  'déspota',
#  'acabar',
#  'rendir',
#  'último',
#  'vergonzoso',
#  'eterno',
#  'profundar',
#  'único',
#  'honorable',
#  '--«Alejados',
#  'único',
#  'urbano',
#  'rural',
#  'esposar',
#  'dicho',
#  'motivar',
#  'conyugal',
#  'moribundo',
#  'angustioso',
#  'aliviar',
#  'gravar',
#  'largo',
#  'fuerte',
#  'persuadir',
#  'floreciente',
#  'bueno',
#  'subir',
#  'ignorar',
#  'favorable',
#  'Alejado',
#  'funesto',
#  'hostil',
#  'desechar',
#  'previsor',
#  'moribundo',
#  'forzoso',
#  'independiente',
#  'profundo',
#  'honrar',
#  'doloroso',
#  'doblar',
#  'cumplir',
#  'pleno',
#  'desamparar',
#  'melancólico',
#  'bullicioso',
#  'librar',
#  'independiente',
#  'pródigo',
#  'intelectual',
#  'activo',
#  'principal',
#  'brillante',
#  'firmar',
#  'pálido',
#  'excepticismos',
#  'ardiente',
#  'evocar',
#  'latente',
#  'activo',
#  'americano',
#  'intelectual',
#  'íntimo',
#  'cansar',
#  'empobrecer',
#  'rico',
#  'jóven',
#  'vano',
#  'idéntico',
#  'lisongero',
#  'nuevo',
#  'fuerte',
#  'resignar',
#  'querer',
#  'producir',
#  'fulminante',
#  'munidos',
#  'numerario',
#  'existente',
#  'enorme',
#  'pasivo',
#  'particular',
#  'infamar',
#  'imponer',
#  'súbito',
#  'desventurado',
#  'morir',
#  'cuidar',
#  'verdadero',
#  'humano',
#  'acompañar',
#  'especial',
#  'bueno',
#  'nacional',
#  'cobrar',
#  'nacional',
#  'adjunto',
#  'noble',
#  'raro',
#  'inmenso',
#  'nacional',
#  'puro',
#  'ardiente',
#  'severo',
#  'desterrar',
#  'desamparar',
#  'tutelar',
#  'intelectual',
#  'riente',
#  'antiguo',
#  'bueno',
#  'bueno',
#  'maternal',
#  'helar',
#  'pobre',
#  'pequeño',
#  'largar',
#  'inglés',
#  'largo',
#  'inmenso',
#  'desconocer',
#  'gris',
#  'piadoso',
#  'tratar',
#  'cuidar',
#  'reconcentrar',
#  'entumecer',
#  'dulce',
#  'plácido',
#  'necesario',
#  'amable',
#  'anciano',
#  'dignar',
#  'argentino',
#  'halagar',
#  'francés',
#  'caballeroso',
#  'distinguir',
#  'cariñoso',
#  'conocido',
#  'noble',
#  'neutral',
#  'militar',
#  'fuerte',
#  'fuerte',
#  'privar',
#  'jóven',
#  'musical',
#  'pariente',
#  'lejano',
#  'europeo',
#  'llegar',
#  'pobre',
#  'solo',
#  'hundir',
#  'Rendidos',
#  'último',
#  'viejo',
#  'útil',
#  'solo',
#  'agradable',
#  'malo',
#  'fuerte',
#  'imponer',
#  'mayor',
#  'enternecer',
#  'noble',
#  'servicial',
#  'benéfico',
#  'venir',
#  'solo',
#  'sentar',
#  'jóven',
#  'vestir',
#  'largar',
#  'negro',
#  'grande',
#  'negro',
#  'fijo',
#  'lejano',
#  'caluroso',
#  'patrio',
#  'tristísima',
#  'angustiar',
#  'inglés',
#  'desconocer',
#  'volvíanse',
#  'lloroso',
#  'azular',
#  'perpétua',
#  'lento',
#  'bullicioso',
#  'despabilar',
#  'doloroso',
#  'oculto',
#  'ruidoso',
#  'insignificante',
#  'solitario',
#  'incierto',
#  'enlutar',
#  'nocturno',
#  'jóven',
#  'tambien',
#  'indiscreto',
#  'sagrado',
#  'solitario',
#  'cubrir',
#  'largar',
#  'sentar',
#  'primero',
#  'propio',
#  'interesante',
#  'jóven',
#  'anciano',
#  'implacable',
#  'temible',
#  'nublar',
#  'natal',
#  'extrañar',
#  'forastero',
#  'forastero',
#  'Gran',
#  'bueno',
#  'Gran',
#  'mejor',
#  'Gran',
#  'triste',
#  'desvanecíanse',
#  'grandioso',
#  'grande',
#  'bello',
#  'nivelar',
#  'lleno',
#  'surcar',
#  'férreo',
#  'rico',
#  'renovar',
#  'transformar',
#  'adornar',
#  'fabuloso',
#  'suntuoso',
#  'visitar',
#  'primero',
#  'esquisito',
#  'régia',
#  'tutelar',
#  'aglomerar',
#  'vasto',
#  'placa',
#  'poderoso',
#  'fuerte',
#  'nacional',
#  'extranjero',
#  'desterrar',
#  'solo',
#  'pobre',
#  'desconocer',
#  'nacional',
#  'efectuar',
#  'suntuoso',
#  'hacer',
#  'lúgubre',
#  'triste',
#  'solo',
#  'colocar',
#  'amargo',
#  'encerrar',
#  'oponer',
#  'aislar',
#  'solitario',
#  'severo',
#  'siguiente',
#  'caro',
#  'indicar',
#  'instalar',
#  'acreditar',
#  'literato',
#  'amable',
#  'alentador',
#  'importante',
#  'editorial',
#  'frecuente',
#  'material',
#  'intimar',
#  'nuevo',
#  'pensionar',
#  'francés',
#  'cercano',
#  'Contento',
#  'interior',
#  'francés',
#  'amable',
#  'viejo',
#  'gran',
#  'imposible',
#  'pensionar',
#  'femenino',
#  'general',
#  'excluir',
#  'verdadero',
#  'antiguar',
#  'célebre',
#  'querido',
#  'contínua',
#  'invisible',
#  'terrible',
#  'invisible',
#  'fuerte',
#  'solicitante',
#  'exponer',
#  'mañana.--',
#  'espontáneo',
#  'francés',
#  '--Reunido',
#  'atenuante',
#  'viejo',
#  'rigoroso',
#  'de--forzosa',
#  'primero',
#  'único',
#  'verdadero',
#  'pequeño',
#  'asear',
#  'cubrir',
#  'azular',
#  'blanco',
#  'empapelar',
#  'clavar',
#  'oculto',
#  'azul',
#  'vecino',
#  'blanco',
#  'cómodo',
#  'central',
#  'gozoso',
#  'modesto',
#  'pequeño',
#  'deficiente',
#  'bueno',
#  'parisiense',
#  'encantar',
#  'nuevo',
#  'encender',
#  'cristal',
#  'abrir',
#  'mullir',
#  'sahumado',
#  'alhucema',
#  'preparar',
#  'azul',
#  'cómodo',
#  'blanco',
#  'benéfico',
#  'lindar',
#  'pobre',
#  'proscribir',
#  'distraido',
#  'largo',
#  'reunir',
#  'casual',
#  'humano',
#  'esperar',
#  'fortuito',
#  'solemne',
#  'trivial',
#  'enterar',
#  'silencioso',
#  'ligero',
#  'experto',
#  'suavísima',
#  'ténue',
#  'seguir',
#  'primero',
#  'inmóvil',
#  'misterioso',
#  'léjos',
#  'primaveral',
#  'fantástico',
#  'aéreo',
#  'misterioso',
#  'cuartar',
#  'silencioso',
#  'tierno',
#  'encantar',
#  'bello',
#  'Cierto',
#  'encargar',
#  'necesario',
#  'Encerrado',
#  'establecer',
#  'baja--soy',
#  'camarero',
#  'bello',
#  '--Pido',
#  'bueno',
#  'encerrar',
#  'rigoroso',
#  'proscribir',
#  'tonto',
#  'vosotros',
#  'malo',
#  'ideal',
#  'gran',
#  'tranquilo',
#  'enterar',
#  'normando',
#  'espiritual',
#  'suscribir',
#  'principal',
#  'oculto',
#  'pobre',
#  'mísero',
#  'camarero',
#  'ocupar',
#  'vecino',
#  'lábios',
#  'pesar',
#  'quejumbroso',
#  'dulcísima',
#  'pesar',
#  'brutal',
#  'delicado',
#  'insoportable',
#  'necesario',
#  'precisar',
#  'loco',
#  'dulce',
#  'jóven',
#  'florido',
#  'bendecir',
#  'lijeras',
#  'sencillo',
#  'liviano',
#  'mismo',
#  'lindo!--añado',
#  'último',
#  'odioso',
#  'único',
#  'mismo',
#  'bueno',
#  'malo',
#  'prevencion',
#  'cambiar',
#  'vestir',
#  'largo',
#  'abullonar',
#  'teatral',
#  'interior',
#  'joven',
#  'entero',
#  'excelente',
#  'pintoresco',
#  'gracioso',
#  'sencillo',
#  'caprichoso',
#  'griego',
#  'romano',
#  'castellano',
#  'llenéla',
#  'condensar',
#  'mágico',
#  'maravilloso',
#  'emporio',
#  'rico',
#  'suculento',
#  'bello',
#  'grande',
#  'acreditar',
#  'magnífico',
#  'destinar',
#  'decorar',
#  'reservar',
#  'amable',
#  'insoportable',
#  'pestilente',
#  'frecuentar',
#  'cuartar',
#  'profundo',
#  'inclinar',
#  'azul',
#  'servir',
#  'dorar',
#  'apetitoso',
#  'frio',
#  'exquisito',
#  'resentir',
#  'ofender',
#  'primaveral',
#  'agrupar',
#  'bueno',
#  'Avergonzado',
#  'nuevo',
#  'agachar',
#  'fisgón',
#  'francés',
#  'solomito!--decía;--¡lástima',
#  'dorar',
#  'lábio',
#  'pegar',
#  'entender',
#  'pegar',
#  'morir',
#  'quietecito',
#  'absortar',
#  'gran',
#  'desear',
#  'bueno',
#  'inocente',
#  'escuchar',
#  'dulcísimo',
#  'cierto',
#  'ocupar',
#  'extático',
#  'cierto',
#  'excelente',
#  'jóven',
#  'verdadero',
#  'francés',
#  'honrar',
#  'natural',
#  'solo',
#  'encerrar',
#  'fresco',
#  'femenino',
#  '--Querida',
#  'penoso',
#  'confuso',
#  'avergonzar',
#  'íntimo',
#  '--Usted',
#  'misterioso',
#  'sirviente',
#  'ideal',
#  'dulcísimo',
#  'ruidoso',
#  'inmediato',
#  'inteligente',
#  'otra--esa',
#  'único',
#  'francés',
#  'temblón',
#  'picar',
#  'ruidoso',
#  'precioso',
#  'limeño',
#  'partidario',
#  'firmar',
#  'literario',
#  'comun',
#  '\ufeff1',
#  'equivocar',
#  'pleno',
#  'evangélico',
#  'multiplicaos»--del',
#  'teólogo',
#  '--Emancipada',
#  'remoto',
#  'presentar',
#  'humanar',
#  'último',
#  'repugnante',
#  'odioso',
#  'alto',
#  'doblar',
#  'culpable',
#  'largar',
#  'femenil',
#  'mismo',
#  'solo',
#  'angosto',
#  'mayor',
#  'mismo',
#  'autoritario',
#  'eterno',
#  'desventurado',
#  'triste',
#  'solo',
#  'vilo',
#  'gozoso',
#  'alegrar',
#  'contentar',
#  'seguro',
#  'bueno',
#  'mejor',
#  'poderoso',
#  'querido',
#  'piadoso',
#  'hacer',
#  'explícito',
#  'implícito',
#  'integrante',
#  'destinar',
#  'humanar',
#  'delicioso',
#  'mismo',
#  'radioso',
#  'apasionar',
#  'encarnar',
#  'misterioso',
#  'elevar',
#  'concluir',
#  'enrollar',
#  'Avergonzado',
#  'urgente',
#  'central',
#  'cuartar',
#  'cerrar',
#  'misterioso',
#  'insoluble',
#  'claro',
#  'sencillo',
#  'seguir',
#  'biográfico',
#  'cronológico',
#  'vivo',
#  'alegrísimo',
#  'viudo',
#  'rico',
#  'estanciero',
#  'innumerable',
#  'referente',
#  'desordenar',
#  'inagotable',
#  'antiguo',
#  'fundar',
#  'servir',
#  'recto',
#  'justiciero',
#  'limpio',
#  'siguiente',
#  'delatar',
#  'profesor',
#  'tranquilo',
#  'viejo',
#  'profundo',
#  'abrir',
#  'dulcísimo',
#  'lindo',
#  'grande',
#  'pálido',
#  'rubio',
#  'último',
#  'jóven',
#  'moreno',
#  'oval',
#  'elevar',
#  'abundoso',
#  'elegante',
#  'severo',
#  'cruzar',
#  'grande',
#  'negro',
#  'léjos',
#  'ténue',
#  'juvenil',
#  'reflexivo',
#  'indefinible',
#  'negro',
#  'alzáronse',
#  'tímido',
#  'desnudo',
#  'angustioso',
#  'guiar',
#  'ahogar',
#  'cerrar',
#  'encarar',
#  '3',
#  'primero',
#  'librar',
#  'guiar',
#  'herir',
#  'empecinar',
#  'acostar',
#  'cubrir',
#  'punzar',
#  'sordo',
#  'persistente',
#  'espeso',
#  'sentar',
#  'gran',
#  'negro',
#  'único',
#  'sentar',
#  'blanco',
#  'fino',
#  'satinar',
#  'rosado',
#  'transparente',
#  'bello',
#  'presentar',
#  '\ufeff1',
#  'agudo',
#  'dulce',
#  'amoroso',
#  'desconocer',
#  'aterrar',
#  'largar',
#  'inmóvil',
#  'entregar',
#  'dulce',
#  'desvariar',
#  'enfermo?--preguntó',
#  'solo',
#  'automático',
#  'inmóvil',
#  'herir',
#  'natural',
#  'necesario',
#  'completo',
#  'hábil',
#  'bueno',
#  'radioso',
#  'adorable',
#  'feliz!--concluyó--¡rodeado',
#  'bello',
#  'desalmar',
#  'nacional',
#  'central',
#  'femenil',
#  'claro',
#  'oscuro',
#  'blanco',
#  'pálido',
#  'extraidas',
#  'sedar',
#  'abrir',
#  'traido',
#  'convertir',
#  'grande',
#  'Encantados',
#  'natal',
#  'gran',
#  'necesario',
#  'mismo',
#  'amante',
#  'fúnebre',
#  'junto',
#  'manos--¡quién',
#  'amar',
#  'desaparecer',
#  'mecer',
#  'misia',
#  'mejor',
#  'delicioso',
#  'delicioso',
#  'malsano',
#  'mejor',
#  'orchata',
#  'almendra',
#  'esquisita',
#  'magnífico',
#  'delicado',
#  'afable',
#  'cortés',
#  'emplear',
#  'precisar',
#  'distinguir',
#  'femenino',
#  'galante',
#  'solo',
#  'Grande',
#  'rodear',
#  'amable',
#  'verdadero',
#  'fuerte',
#  'espiritual',
#  'editorial',
#  'furtivo',
#  'dulcísimo',
#  'final',
#  'misterioso',
#  'volviéronse',
#  'alto',
#  'juvenil',
#  'fortificante',
#  'delicioso',
#  'solo',
#  'primero',
#  'bueno',
#  'jóven',
#  'Magnífico',
#  'cicatrizar',
#  'increible',
#  'bueno',
#  'excelente',
#  'decaido',
#  'comprender',
#  'aceptar',
#  'profundar',
#  'inmenso',
#  'bajo',
#  'solo',
#  'mirada!--',
#  'blanco',
#  'fino',
#  'satinar',
#  'trasparente',
#  'rosado',
#  'junto',
#  'silencioso',
#  ...]

# %% [markdown]
# Then we count the unique adjectives in this list with the `Counter()` module:

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('bueno', 20),
#  ('solo', 15),
#  ('último', 11),
#  ('bello', 11),
#  ('fuerte', 10),
#  ('pobre', 10),
#  ('primero', 10),
#  ('único', 9),
#  ('jóven', 9),
#  ('gran', 8),
#  ('misterioso', 8),
#  ('mismo', 8),
#  ('nuevo', 7),
#  ('dulce', 7),
#  ('viejo', 7),
#  ('nacional', 7),
#  ('francés', 7),
#  ('blanco', 7),
#  ('\ufeff1', 6),
#  ('largo', 6),
#  ('largar', 6),
#  ('necesario', 6),
#  ('verdadero', 6),
#  ('desconocer', 6),
#  ('negro', 6),
#  ('grande', 6),
#  ('natural', 5),
#  ('sentar', 5),
#  ('amable', 5),
#  ('mejor', 5),
#  ('amar', 5),
#  ('humano', 4),
#  ('social', 4),
#  ('intelectual', 4),
#  ('noble', 4),
#  ('pálido', 4),
#  ('malo', 4),
#  ('gozoso', 4),
#  ('triste', 4),
#  ('alto', 4),
#  ('central', 4),
#  ('lindo', 4),
#  ('lejano', 4),
#  ('azul', 4),
#  ('inmenso', 4),
#  ('profundo', 4),
#  ('rico', 4),
#  ('antiguo', 4),
#  ('benéfico', 4),
#  ('cuartar', 4),
#  ('sencillo', 4),
#  ('dulcísimo', 4),
#  ('delicioso', 4),
#  ('cerrar', 4),
#  ('precioso', 3),
#  ('elevar', 3),
#  ('presentar', 3),
#  ('querer', 3),
#  ('pegar', 3),
#  ('editorial', 3),
#  ('plácido', 3),
#  ('adverso', 3),
#  ('entregar', 3),
#  ('inglés', 3),
#  ('feliz', 3),
#  ('vestir', 3),
#  ('imponente', 3),
#  ('divino', 3),
#  ('solemne', 3),
#  ('sagrado', 3),
#  ('poderoso', 3),
#  ('eterno', 3),
#  ('particular', 3),
#  ('imponer', 3),
#  ('severo', 3),
#  ('tutelar', 3),
#  ('helar', 3),
#  ('pequeño', 3),
#  ('distinguir', 3),
#  ('oculto', 3),
#  ('ruidoso', 3),
#  ('solitario', 3),
#  ('cubrir', 3),
#  ('Gran', 3),
#  ('lleno', 3),
#  ('encerrar', 3),
#  ('femenino', 3),
#  ('querido', 3),
#  ('rigoroso', 3),
#  ('abrir', 3),
#  ('proscribir', 3),
#  ('silencioso', 3),
#  ('seguir', 3),
#  ('inmóvil', 3),
#  ('primaveral', 3),
#  ('excelente', 3),
#  ('dorar', 3),
#  ('penoso', 3),
#  ('seguro', 3),
#  ('radioso', 3),
#  ('junto', 3),
#  ('concluir', 2),
#  ('americano', 2),
#  ('económico', 2),
#  ('plegaria', 2),
#  ('cariñoso', 2),
#  ('implacable', 2),
#  ('terrible', 2),
#  ('sanar', 2),
#  ('insoluble', 2),
#  ('melancólico', 2),
#  ('mecer', 2),
#  ('siniestro', 2),
#  ('fatídico', 2),
#  ('inocente', 2),
#  ('hostil', 2),
#  ('cruel', 2),
#  ('benévolo', 2),
#  ('caluroso', 2),
#  ('clásico', 2),
#  ('tierno', 2),
#  ('Solo', 2),
#  ('enternecer', 2),
#  ('profundar', 2),
#  ('moribundo', 2),
#  ('angustioso', 2),
#  ('gravar', 2),
#  ('persuadir', 2),
#  ('favorable', 2),
#  ('independiente', 2),
#  ('honrar', 2),
#  ('doloroso', 2),
#  ('doblar', 2),
#  ('pleno', 2),
#  ('desamparar', 2),
#  ('bullicioso', 2),
#  ('librar', 2),
#  ('activo', 2),
#  ('principal', 2),
#  ('firmar', 2),
#  ('ardiente', 2),
#  ('íntimo', 2),
#  ('idéntico', 2),
#  ('resignar', 2),
#  ('desventurado', 2),
#  ('morir', 2),
#  ('cuidar', 2),
#  ('acompañar', 2),
#  ('desterrar', 2),
#  ('piadoso', 2),
#  ('anciano', 2),
#  ('dignar', 2),
#  ('mayor', 2),
#  ('azular', 2),
#  ('lento', 2),
#  ('natal', 2),
#  ('forastero', 2),
#  ('adornar', 2),
#  ('suntuoso', 2),
#  ('hacer', 2),
#  ('amargo', 2),
#  ('siguiente', 2),
#  ('acreditar', 2),
#  ('pensionar', 2),
#  ('interior', 2),
#  ('antiguar', 2),
#  ('invisible', 2),
#  ('vecino', 2),
#  ('cómodo', 2),
#  ('modesto', 2),
#  ('encantar', 2),
#  ('enterar', 2),
#  ('suavísima', 2),
#  ('ténue', 2),
#  ('léjos', 2),
#  ('camarero', 2),
#  ('ideal', 2),
#  ('tranquilo', 2),
#  ('espiritual', 2),
#  ('ocupar', 2),
#  ('pesar', 2),
#  ('delicado', 2),
#  ('insoportable', 2),
#  ('precisar', 2),
#  ('odioso', 2),
#  ('griego', 2),
#  ('mágico', 2),
#  ('magnífico', 2),
#  ('destinar', 2),
#  ('servir', 2),
#  ('Avergonzado', 2),
#  ('cierto', 2),
#  ('humanar', 2),
#  ('femenil', 2),
#  ('claro', 2),
#  ('elegante', 2),
#  ('juvenil', 2),
#  ('guiar', 2),
#  ('herir', 2),
#  ('fino', 2),
#  ('satinar', 2),
#  ('rosado', 2),
#  ('hábil', 2),
#  ('trasparente', 2),
#  ('encantador', 2),
#  ('curioso', 2),
#  ('simpático', 2),
#  ('formar', 2),
#  ('sombrío', 1),
#  ('imbuído', 1),
#  ('terrenal', 1),
#  ('mal', 1),
#  ('desconsolar', 1),
#  ('menesteroso', 1),
#  ('ingrato', 1),
#  ('trayéndoles', 1),
#  ('plausible', 1),
#  ('eficaz', 1),
#  ('innúmero', 1),
#  ('multiplicar', 1),
#  ('venerable', 1),
#  ('entendido', 1),
#  ('grave', 1),
#  ('político', 1),
#  ('moralizador', 1),
#  ('colectivo', 1),
#  ('especulativo', 1),
#  ('individual', 1),
#  ('abstracto', 1),
#  ('ilustrar', 1),
#  ('creador', 1),
#  ('lujurioso', 1),
#  ('invocar', 1),
#  ('atrayente', 1),
#  ('ingénua', 1),
#  ('privilegiar', 1),
#  ('prestigioso', 1),
#  ('suficiente', 1),
#  ('soñador', 1),
#  ('adusto', 1),
#  ('economista', 1),
#  ('marcar', 1),
#  ('CHAMUSQUINAS', 1),
#  ('extremo', 1),
#  ('armar', 1),
#  ('mojar', 1),
#  ('aguardar', 1),
#  ('aurora', 1),
#  ('dramático', 1),
#  ('párias', 1),
#  ('forzar', 1),
#  ('diario', 1),
#  ('encorvar', 1),
#  ('proponer', 1),
#  ('mejorar', 1),
#  ('Uncido', 1),
#  ('rudo', 1),
#  ('cronista', 1),
#  ('folletinista', 1),
#  ('corrector', 1),
#  ('avaro', 1),
#  ('franco', 1),
#  ('engolfar', 1),
#  ('presuroso', 1),
#  ('habitual', 1),
#  ('contar', 1),
#  ('apostar', 1),
#  ('extraño', 1),
#  ('subyugar', 1),
#  ('temeroso', 1),
#  ('acoquinar', 1),
#  ('espiar', 1),
#  ('suspicaz', 1),
#  ('inexorable', 1),
#  ('vuélvense', 1),
#  ('taciturno', 1),
#  ('desconfiar', 1),
#  ('paterno', 1),
#  ('enemigo', 1),
#  ('mostrárseles', 1),
#  ('propiciar', 1),
#  ('retrospectivo', 1),
#  ('arrebatar', 1),
#  ('materno', 1),
#  ('decir', 1),
#  ('característico', 1),
#  ('irresistible', 1),
#  ('consignar', 1),
#  ('expansivo', 1),
#  ('oprimir', 1),
#  ('superior', 1),
#  ('infantil', 1),
#  ('viril', 1),
#  ('Cumplido', 1),
#  ('virtuoso', 1),
#  ('Mauricio--¿Quieres', 1),
#  ('deber', 1),
#  ('angelical', 1),
#  ('santo', 1),
#  ('notable', 1),
#  ('inquieto', 1),
#  ('cosmopolita', 1),
#  ('exaltar', 1),
#  ('tricolor', 1),
#  ('pasar', 1),
#  ('magestuoso', 1),
#  ('luminoso', 1),
#  ('humillante', 1),
#  ('consultar', 1),
#  ('corregir', 1),
#  ('dictar', 1),
#  ('déspota', 1),
#  ('acabar', 1),
#  ('rendir', 1),
#  ('vergonzoso', 1),
#  ('honorable', 1),
#  ('--«Alejados', 1),
#  ('urbano', 1),
#  ('rural', 1),
#  ('esposar', 1),
#  ('dicho', 1),
#  ('motivar', 1),
#  ('conyugal', 1),
#  ('aliviar', 1),
#  ('floreciente', 1),
#  ('subir', 1),
#  ('ignorar', 1),
#  ('Alejado', 1),
#  ('funesto', 1),
#  ('desechar', 1),
#  ('previsor', 1),
#  ('forzoso', 1),
#  ('cumplir', 1),
#  ('pródigo', 1),
#  ('brillante', 1),
#  ('excepticismos', 1),
#  ('evocar', 1),
#  ('latente', 1),
#  ('cansar', 1),
#  ('empobrecer', 1),
#  ('vano', 1),
#  ('lisongero', 1),
#  ('producir', 1),
#  ('fulminante', 1),
#  ('munidos', 1),
#  ('numerario', 1),
#  ('existente', 1),
#  ('enorme', 1),
#  ('pasivo', 1),
#  ('infamar', 1),
#  ('súbito', 1),
#  ('especial', 1),
#  ('cobrar', 1),
#  ('adjunto', 1),
#  ('raro', 1),
#  ('puro', 1),
#  ('riente', 1),
#  ('maternal', 1),
#  ('gris', 1),
#  ('tratar', 1),
#  ('reconcentrar', 1),
#  ('entumecer', 1),
#  ('argentino', 1),
#  ('halagar', 1),
#  ('caballeroso', 1),
#  ('conocido', 1),
#  ('neutral', 1),
#  ('militar', 1),
#  ('privar', 1),
#  ('musical', 1),
#  ('pariente', 1),
#  ('europeo', 1),
#  ('llegar', 1),
#  ('hundir', 1),
#  ('Rendidos', 1),
#  ('útil', 1),
#  ('agradable', 1),
#  ('servicial', 1),
#  ('venir', 1),
#  ('fijo', 1),
#  ('patrio', 1),
#  ('tristísima', 1),
#  ('angustiar', 1),
#  ('volvíanse', 1),
#  ('lloroso', 1),
#  ('perpétua', 1),
#  ('despabilar', 1),
#  ('insignificante', 1),
#  ('incierto', 1),
#  ('enlutar', 1),
#  ('nocturno', 1),
#  ('tambien', 1),
#  ('indiscreto', 1),
#  ('propio', 1),
#  ('interesante', 1),
#  ('temible', 1),
#  ('nublar', 1),
#  ('extrañar', 1),
#  ('desvanecíanse', 1),
#  ('grandioso', 1),
#  ('nivelar', 1),
#  ('surcar', 1),
#  ('férreo', 1),
#  ('renovar', 1),
#  ('transformar', 1),
#  ('fabuloso', 1),
#  ('visitar', 1),
#  ('esquisito', 1),
#  ('régia', 1),
#  ('aglomerar', 1),
#  ('vasto', 1),
#  ('placa', 1),
#  ('extranjero', 1),
#  ('efectuar', 1),
#  ('lúgubre', 1),
#  ('colocar', 1),
#  ('oponer', 1),
#  ('aislar', 1),
#  ('caro', 1),
#  ('indicar', 1),
#  ('instalar', 1),
#  ('literato', 1),
#  ('alentador', 1),
#  ('importante', 1),
#  ('frecuente', 1),
#  ('material', 1),
#  ('intimar', 1),
#  ('cercano', 1),
#  ('Contento', 1),
#  ('imposible', 1),
#  ('general', 1),
#  ('excluir', 1),
#  ('célebre', 1),
#  ('contínua', 1),
#  ('solicitante', 1),
#  ('exponer', 1),
#  ('mañana.--', 1),
#  ('espontáneo', 1),
#  ('--Reunido', 1),
#  ('atenuante', 1),
#  ('de--forzosa', 1),
#  ('asear', 1),
#  ('empapelar', 1),
#  ('clavar', 1),
#  ('deficiente', 1),
#  ('parisiense', 1),
#  ('encender', 1),
#  ('cristal', 1),
#  ('mullir', 1),
#  ('sahumado', 1),
#  ('alhucema', 1),
#  ('preparar', 1),
#  ('lindar', 1),
#  ('distraido', 1),
#  ('reunir', 1),
#  ('casual', 1),
#  ('esperar', 1),
#  ('fortuito', 1),
#  ('trivial', 1),
#  ('ligero', 1),
#  ('experto', 1),
#  ('fantástico', 1),
#  ('aéreo', 1),
#  ('Cierto', 1),
#  ('encargar', 1),
#  ('Encerrado', 1),
#  ('establecer', 1),
#  ('baja--soy', 1),
#  ('--Pido', 1),
#  ('tonto', 1),
#  ('vosotros', 1),
#  ('normando', 1),
#  ('suscribir', 1),
#  ('mísero', 1),
#  ('lábios', 1),
#  ('quejumbroso', 1),
#  ('dulcísima', 1),
#  ('brutal', 1),
#  ('loco', 1),
#  ('florido', 1),
#  ('bendecir', 1),
#  ('lijeras', 1),
#  ('liviano', 1),
#  ('lindo!--añado', 1),
#  ('prevencion', 1),
#  ('cambiar', 1),
#  ('abullonar', 1),
#  ('teatral', 1),
#  ('joven', 1),
#  ('entero', 1),
#  ('pintoresco', 1),
#  ('gracioso', 1),
#  ('caprichoso', 1),
#  ('romano', 1),
#  ('castellano', 1),
#  ('llenéla', 1),
#  ('condensar', 1),
#  ('maravilloso', 1),
#  ('emporio', 1),
#  ('suculento', 1),
#  ('decorar', 1),
#  ('reservar', 1),
#  ('pestilente', 1),
#  ('frecuentar', 1),
#  ('inclinar', 1),
#  ('apetitoso', 1),
#  ('frio', 1),
#  ('exquisito', 1),
#  ('resentir', 1),
#  ('ofender', 1),
#  ('agrupar', 1),
#  ('agachar', 1),
#  ('fisgón', 1),
#  ('solomito!--decía;--¡lástima', 1),
#  ('lábio', 1),
#  ('entender', 1),
#  ('quietecito', 1),
#  ('absortar', 1),
#  ('desear', 1),
#  ('escuchar', 1),
#  ('extático', 1),
#  ('fresco', 1),
#  ('--Querida', 1),
#  ('confuso', 1),
#  ('avergonzar', 1),
#  ('--Usted', 1),
#  ('sirviente', 1),
#  ('inmediato', 1),
#  ('inteligente', 1),
#  ('otra--esa', 1),
#  ('temblón', 1),
#  ('picar', 1),
#  ('limeño', 1),
#  ('partidario', 1),
#  ('literario', 1),
#  ('comun', 1),
#  ('equivocar', 1),
#  ('evangélico', 1),
#  ('multiplicaos»--del', 1),
#  ('teólogo', 1),
#  ('--Emancipada', 1),
#  ('remoto', 1),
#  ('repugnante', 1),
#  ('culpable', 1),
#  ('angosto', 1),
#  ('autoritario', 1),
#  ('vilo', 1),
#  ('alegrar', 1),
#  ('contentar', 1),
#  ('explícito', 1),
#  ('implícito', 1),
#  ('integrante', 1),
#  ('apasionar', 1),
#  ('encarnar', 1),
#  ('enrollar', 1),
#  ('urgente', 1),
#  ('biográfico', 1),
#  ('cronológico', 1),
#  ('vivo', 1),
#  ('alegrísimo', 1),
#  ('viudo', 1),
#  ('estanciero', 1),
#  ('innumerable', 1),
#  ('referente', 1),
#  ('desordenar', 1),
#  ('inagotable', 1),
#  ('fundar', 1),
#  ('recto', 1),
#  ('justiciero', 1),
#  ('limpio', 1),
#  ('delatar', 1),
#  ('profesor', 1),
#  ('rubio', 1),
#  ('moreno', 1),
#  ('oval', 1),
#  ('abundoso', 1),
#  ('cruzar', 1),
#  ('reflexivo', 1),
#  ('indefinible', 1),
#  ('alzáronse', 1),
#  ('tímido', 1),
#  ('desnudo', 1),
#  ('ahogar', 1),
#  ('encarar', 1),
#  ('3', 1),
#  ('empecinar', 1),
#  ('acostar', 1),
#  ('punzar', 1),
#  ('sordo', 1),
#  ('persistente', 1),
#  ('espeso', 1),
#  ('transparente', 1),
#  ('agudo', 1),
#  ('amoroso', 1),
#  ('aterrar', 1),
#  ('desvariar', 1),
#  ('enfermo?--preguntó', 1),
#  ('automático', 1),
#  ('completo', 1),
#  ('adorable', 1),
#  ('feliz!--concluyó--¡rodeado', 1),
#  ('desalmar', 1),
#  ('oscuro', 1),
#  ('extraidas', 1),
#  ('sedar', 1),
#  ('traido', 1),
#  ('convertir', 1),
#  ('Encantados', 1),
#  ('amante', 1),
#  ('fúnebre', 1),
#  ('manos--¡quién', 1),
#  ('desaparecer', 1),
#  ('misia', 1),
#  ('malsano', 1),
#  ('orchata', 1),
#  ('almendra', 1),
#  ('esquisita', 1),
#  ('afable', 1),
#  ('cortés', 1),
#  ('emplear', 1),
#  ('galante', 1),
#  ('Grande', 1),
#  ('rodear', 1),
#  ('furtivo', 1),
#  ('final', 1),
#  ('volviéronse', 1),
#  ('fortificante', 1),
#  ('Magnífico', 1),
#  ('cicatrizar', 1),
#  ('increible', 1),
#  ('decaido', 1),
#  ('comprender', 1),
#  ('aceptar', 1),
#  ('bajo', 1),
#  ('mirada!--', 1),
#  ('sobrenatural', 1),
#  ('terrestre', 1),
#  ('visible', 1),
#  ('sobrefalda', 1),
#  ('hermoso', 1),
#  ('Sanabria.--Seguid', 1),
#  ('conmovido--¡cuánta', 1),
#  ('pícaro', 1),
#  ('--Condenado', 1),
#  ('negar', 1),
#  ('sentenciar', 1),
#  ('manecitas', 1),
#  ('discreto', 1),
#  ('declarar', 1),
#  ('perdido', 1),
#  ('fleco', 1),
#  ('--Bandas', 1),
#  ('posible', 1),
#  ('perifolladas', 1),
#  ('comensal', 1),
#  ('cegar', 1),
#  ('ausentar', 1),
#  ('listar', 1),
#  ('tender', 1),
#  ('inundar', 1),
#  ('semejante', 1),
#  ('novio', 1),
#  ('inminente', 1),
#  ('médico', 1),
#  ('rápido', 1),
#  ('holgar', 1),
#  ('idolatrar', 1),
#  ('audaz', 1),
#  ('tenebroso', 1),
#  ('autoridad--nunca', 1),
#  ('áspero', 1),
#  ('restante', 1),
#  ('presente', 1),
#  ('caracterizar', 1),
#  ('atraido', 1),
#  ('ocurrir', 1),
#  ('accionista', 1),
#  ('Presentado', 1),
#  ('demandar', 1),
#  ('perteneciente', 1),
#  ('gratar', 1),
#  ('aviso', 1),
#  ('depositar', 1),
#  ('órden', 1),
#  ('endosar', 1),
#  ('segundar', 1),
#  ('esposa--muerto', 1),
#  ('vivir', 1),
#  ('valioso', 1),
#  ('filial', 1),
#  ('entusiasta', 1),
#  ('sério', 1),
#  ('abanico', 1),
#  ('liso', 1),
#  ('chico', 1),
#  ('elocuentísimo', 1),
#  ('contrayente', 1),
#  ('sacramental', 1),
#  ('pronunciar', 1),
#  ('conmovedor', 1),
#  ('animoso', 1),
#  ('débil', 1),
#  ('Libres', 1),
#  ('dar', 1),
#  ('crear', 1),
#  ('futuro', 1),
#  ('mental', 1),
#  ('alinear', 1),
#  ('entrelazar', 1),
#  ('sorprender', 1)]

# %% [markdown]
# Then we make a dataframe from this list:

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#             adj  count
# 0         bueno     20
# 1          solo     15
# 2        último     11
# 3         bello     11
# 4        fuerte     10
# 5         pobre     10
# 6       primero     10
# 7         único      9
# 8         jóven      9
# 9          gran      8
# 10   misterioso      8
# 11        mismo      8
# 12        nuevo      7
# 13        dulce      7
# 14        viejo      7
# 15     nacional      7
# 16      francés      7
# 17       blanco      7
# 18           ﻿1      6
# 19        largo      6
# 20       largar      6
# 21    necesario      6
# 22    verdadero      6
# 23   desconocer      6
# 24        negro      6
# 25       grande      6
# 26      natural      5
# 27       sentar      5
# 28       amable      5
# 29        mejor      5
# 30         amar      5
# 31       humano      4
# 32       social      4
# 33  intelectual      4
# 34        noble      4
# 35       pálido      4
# 36         malo      4
# 37       gozoso      4
# 38       triste      4
# 39         alto      4
# 40      central      4
# 41        lindo      4
# 42       lejano      4
# 43         azul      4
# 44      inmenso      4
# 45     profundo      4
# 46         rico      4
# 47      antiguo      4
# 48     benéfico      4
# 49      cuartar      4
# 50     sencillo      4
# 51    dulcísimo      4
# 52    delicioso      4
# 53       cerrar      4
# 54     precioso      3
# 55       elevar      3
# 56    presentar      3
# 57       querer      3
# 58        pegar      3
# 59    editorial      3
# 60      plácido      3
# 61      adverso      3
# 62     entregar      3
# 63       inglés      3
# 64        feliz      3
# 65       vestir      3
# 66    imponente      3
# 67       divino      3
# 68      solemne      3
# 69      sagrado      3
# 70     poderoso      3
# 71       eterno      3
# 72   particular      3
# 73      imponer      3
# 74       severo      3
# 75      tutelar      3
# 76        helar      3
# 77      pequeño      3
# 78   distinguir      3
# 79       oculto      3
# 80      ruidoso      3
# 81    solitario      3
# 82       cubrir      3
# 83         Gran      3
# 84        lleno      3
# 85     encerrar      3
# 86     femenino      3
# 87      querido      3
# 88     rigoroso      3
# 89        abrir      3
# 90   proscribir      3
# 91   silencioso      3
# 92       seguir      3
# 93      inmóvil      3
# 94   primaveral      3
# 95    excelente      3
# 96        dorar      3
# 97       penoso      3
# 98       seguro      3
# 99      radioso      3

# %% [markdown]
# ## Get Nouns

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |

# %% [markdown]
# To extract and count nouns, we can follow the same model as above, except we will change our `if` statement to check for POS labels that match "NOUN".

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.lemma_)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#            noun  count
# 0         señor     55
# 1         manir     37
# 2         casar     30
# 3          hora     28
# 4          vida     24
# 5         padre     23
# 6        hombre     22
# 7          hijo     22
# 8           voz     22
# 9      trabajar     21
# 10         alma     20
# 11          ojo     20
# 12          dia     17
# 13        mujer     17
# 14          vez     16
# 15          año     16
# 16        mirar     15
# 17         niño     14
# 18       puerta     14
# 19      corazon     13
# 20        carta     13
# 21      palabra     12
# 22     señorito     12
# 23      nombrar     11
# 24      lágrima     11
# 25       muerte     11
# 26       tiempo     11
# 27         mano     11
# 28      tambien     11
# 29        dolor     11
# 30       doctor     11
# 31          luz     10
# 32        brazo     10
# 33     destinar     10
# 34     embargar     10
# 35        noche     10
# 36  sentimiento     10
# 37        joven     10
# 38      cuartar     10
# 39        mesar      9
# 40       diario      9
# 41         ideo      8
# 42        venir      8
# 43        jóven      8
# 44    felicidad      8
# 45    semblante      8
# 46       patrio      8
# 47      familia      8
# 48        madre      8
# 49         cama      8
# 50      fortuna      8
# 51       partir      8
# 52         bien      7
# 53       esposo      7
# 54        mente      7
# 55       gustar      7
# 56         amor      7
# 57    silenciar      7
# 58      momento      7
# 59        rayar      6
# 60     sepulcro      6
# 61         aire      6
# 62       pechar      6
# 63    compañero      6
# 64     personar      6
# 65        valor      6
# 66     gratitud      6
# 67        órden      6
# 68        velar      6
# 69        helar      6
# 70     camarero      6
# 71         dedo      6
# 72       vecino      6
# 73      paquete      6
# 74       médico      6
# 75     enfermar      6
# 76       póliza      6
# 77          pan      5
# 78    bienestar      5
# 79     espíritu      5
# 80       página      5
# 81  pensamiento      5
# 82       cuello      5
# 83       rostro      5
# 84        soñar      5
# 85        pasar      5
# 86        hogar      5
# 87     colegiar      5
# 88         país      5
# 89        lugar      5
# 90        clase      5
# 91     recordar      5
# 92       imágen      5
# 93         seno      5
# 94     carácter      5
# 95        cielo      5
# 96  espectáculo      5
# 97    escribano      5
# 98  influenciar      5
# 99        poder      5

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %% [markdown]
# To extract and count works of art, we can follow a similar-ish model to the examples above. This time, however, we're going to make our code even more economical and efficient (while still changing our `if` statement to match the POS label "VERB").

# %% [markdown]
# ```{admonition} Python Review!
# :class: pythonreview
# We can use a [*list comprehension*](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Python/More-Lists-Loops.html#List-Comprehensions) to get our list of verbs in a single line of code! Closely examine the first line of code below:
# ```

# %%
verbs = [token.lemma_ for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#                 verb  count
# 0                ser     69
# 1              haber     52
# 2              hacer     42
# 3              decir     29
# 4              estar     25
# 5                dar     18
# 6              tener     15
# 7              tomar     15
# 8              dejar     15
# 9                 ir     15
# 10            llegar     15
# 11             venir     14
# 12         encontrar     13
# 13            querer     13
# 14             --¡Ah     13
# 15             poder     12
# 16            volver     12
# 17            llevar     11
# 18             deber     10
# 19             creer     10
# 20             saber     10
# 21             salir     10
# 22               ver     10
# 23             abrir     10
# 24              leer     10
# 25            quedar      9
# 26           parecer      9
# 27          escuchar      9
# 28            sentir      9
# 29             poner      8
# 30            hablar      8
# 31            buscar      8
# 32           conocer      7
# 33              reír      7
# 34         despertar      7
# 35           recibir      7
# 36            entrar      7
# 37            vestir      7
# 38          comenzar      6
# 39            pensar      6
# 40            llorar      6
# 41              caer      6
# 42               Era      6
# 43             pedir      6
# 44          escribir      5
# 45               oír      5
# 46            cerrar      5
# 47        comprender      5
# 48            seguir      5
# 49            llamar      5
# 50       volviéndose      5
# 51         estrechar      5
# 52          entregar      5
# 53         presentar      5
# 54             vivir      5
# 55           guardar      5
# 56           arrojar      4
# 57             morir      4
# 58            apoyar      4
# 59            alejar      4
# 60          recordar      4
# 61            tender      4
# 62            servir      4
# 63            lograr      4
# 64             pasar      4
# 65        encontróse      4
# 66        sorprender      4
# 67           habíase      4
# 68       interrumpir      4
# 69            llenar      4
# 70              unir      4
# 71          realizar      3
# 72            cubrir      3
# 73           existir      3
# 74          recorrer      3
# 75          encerrar      3
# 76            acabar      3
# 77               fué      3
# 78          obedecer      3
# 79               dió      3
# 80            tornar      3
# 81              amar      3
# 82           colocar      3
# 83               oir      3
# 84          preferir      3
# 85          alejarse      3
# 86             echar      3
# 87             verla      3
# 88             bajar      3
# 89           divisar      3
# 90           anhelar      3
# 91           dirijió      3
# 92             tocar      3
# 93           visitar      3
# 94              huir      3
# 95            -PRON-      3
# 96  señor--respondió      3
# 97          almorzar      3
# 98          inspirar      3
# 99             mirar      3

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ## Get Sentences with Keyword

# %% [markdown]
# spaCy can also identify sentences in a document. To access sentences, we can iterate through `document.sents` and pull out the `.text` of each sentence.

# %% [markdown]
# We can use spaCy's sentence-parsing capabilities to extract sentences that contain particular keywords, such as in the function below. Note that the function assumes that the keyword provided will be exactly the same as it appears in the text (e.g. matching all inflection for case, number, gender, etc. As a Spanish example, if you use `bueno` as the keyboard, it won't match `buena` or `buenos`.)
#
# With the function `find_sentences_with_keyword()`, we will iterate through `document.sents` and pull out any sentence that contains a particular "keyword." Then we will display these sentence with the keywords bolded.

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="bueno", document=document)
# Out:
# Á «LA **bueno**S AIRES»
# Enigma insoluble es para mí este jóven, tan franco, sin embargo, y tan **bueno**...
# Cumplido en él, el divino misterio, de rodillas ante el altar, el niño tiende la mano sobre el Sagrado Libro y jura ser virtuoso y **bueno**.
# Suscribíala el escribano D..., uno de los hombres más honorables de **bueno**s Aires.
# En el momento que Mauricio preparaba la realizacion de tan lisongero propósito, una carta de **bueno**s Aires, portadora de fatales nuevas, vino á destruir sus proyectos y sus esperanzas.
# Además, en **bueno**s Aires que se agita á   impulsos de un inmenso progreso, podrá Vd. con el trabajo rehacer   su fortuna».
# Por los diarios de **bueno**s Aires y su propia correspondencia, éranle conocidas sus desgracias y su noble abnegacion.
# hé ahí, por ejemplo, un modelo de valor y de resignacion: esta jóven hija de **bueno**s Aires, vino hace tres años para perfeccionarse en sus estudios musicales.
# Su padre, ingeniero en comision, regresó á **bueno**s Aires dejándola en casa de una parienta lejana.
# Rendidos al padre los últimos deberes, vuelve á **bueno**s Aires, donde vá á buscar en el trabajo la subsistencia......
# De la **bueno**s Aires de sus recuerdos, solo reconocía el nombre: tan grande y bella, la gloriosa metrópoli habíase tornado.
# La **bueno**s Aires», poderosa asociacion que cuenta en su seno á los más fuertes capitalistas nacionales y extranjeros.
# Una vez instalado, buscó trabajo en uno de los diarios más acreditados de **bueno**s Aires.
# --**bueno** ó malo, déjelas Vd. en él.
# --El señor Eduardo M. Coll, hijo mio, es Gerente de «La **bueno**s Aires», Compañía de Seguros en la que yo mismo soy accionista ¿qué será ello?
# XXX   Antes de aquel término el Gerente de «La **bueno**s Aires» recibía una citacion del Banco Nacional con motivo del aviso que por su órden registraban «La Prensa» y «La Tribuna Nacional».
# Acudió el Gerente, y supo que allí se hallaba, depositado por el señor Cárlos Ridel, un paquete cerrado, que en Junio de 1888 debía ser entregado á la Compañía de Seguros «La **bueno**s Aires».
# á la órden de Cárlos Ridel y endosada por éste á «La **bueno**s Aires», como la segunda cuota que debía pagar por su póliza.
# «Entre estas, las Compañías de Seguros sónme especialmente   simpáticas, sobretodo, «La **bueno**s Aires», por su importancia y   valiosa organizacion.
# En el seno de una de esas asociaciones tutelares, «La **bueno**s Aires», la Providencia guardaba un tesoro que á su hora, hizo surgir para recompensar la abnegacion filial y dar la felicidad á los que, creyendo en ella, esperaban.

# %% [markdown]
# ## Get Keyword in Context

# %% [markdown]
# We can also find out about a keyword's more immediate context — its neighboring words to the left and right — and we can fine-tune our search with POS tagging.
#
# To do so, we will first create a list of what's called *ngrams*. "Ngrams" are any sequence of *n* tokens in a text. They're an important concept in computational linguistics and NLP. (Have you ever played with [Google's *Ngram* Viewer](https://books.google.com/ngrams)?)
#
# Below we're going to make a list of *bigrams*, that is, all the two-word combinations from the sample text. We're going to use these bigrams to find the neighboring words that appear alongside particular keywords.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %% [markdown]
# Let's take a peek at the bigrams:

# %%
bigrams[5:20]
# Out:
# [[('imbuído', 'ADJ'), ('sin', 'ADP')],
#  [('sin', 'ADP'), ('duda', 'INTJ')],
#  [('duda', 'INTJ'), ('en', 'ADP')],
#  [('en', 'ADP'), ('las', 'DET')],
#  [('las', 'DET'), ('ideas', 'NOUN')],
#  [('ideas', 'NOUN'), ('de', 'ADP')],
#  [('de', 'ADP'), ('los', 'DET')],
#  [('los', 'DET'), ('Santos', 'PROPN')],
#  [('Santos', 'PROPN'), ('Padres', 'NOUN')],
#  [('Padres', 'NOUN'), ('de', 'ADP')],
#  [('de', 'ADP'), ('la', 'DET')],
#  [('la', 'DET'), ('Iglesia', 'PROPN')],
#  [('Iglesia', 'PROPN'), ('que', 'SCONJ')],
#  [('que', 'SCONJ'), ('predicaban', 'AUX')],
#  [('predicaban', 'AUX'), ('el', 'DET')]]

# %% [markdown]
# Now that we have our list of bigrams, we're going to make a function `get_neighbor_words()`. This function will return the most frequent words that appear next to a particular keyword. The function can also be fine-tuned to return neighbor words that match a certain part of speech by changing the `pos_label` parameter.

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("bien", bigrams)
# Out:
# [('más', 2),
#  ('que', 2),
#  ('así', 1),
#  ('fuerte', 1),
#  ('y', 1),
#  ('ya', 1),
#  ('invisible', 1),
#  ('pudiera', 1),
#  ('distraido', 1),
#  ('lo', 1),
#  ('te', 1),
#  ('cosa', 1),
#  ('duerme', 1),
#  ('charlábamos', 1),
#  ('vá', 1),
#  ('no', 1),
#  ('si', 1),
#  ('seguro', 1),
#  ('mi', 1),
#  ('amada', 1),
#  ('tan', 1),
#  ('esta', 1),
#  ('palabra', 1),
#  ('estaba', 1)]

# %%
get_neighbor_words("bien", bigrams, pos_label='VERB')
# Out:
# [('pudiera', 1), ('duerme', 1)]

# %% [markdown]
# ## Your Turn!

# %% [markdown]
# Try out `find_sentences_with_keyword()` and `get_neighbor_words` with your own keywords of interest.

# %%
find_sentences_with_keyword(keyword="YOUR KEY WORD", document=document)

# %%
get_neighbor_words(keyword="YOUR KEY WORD", bigrams, pos_label=None)
