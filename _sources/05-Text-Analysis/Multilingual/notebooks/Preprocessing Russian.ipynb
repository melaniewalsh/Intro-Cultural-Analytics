# %% [markdown]
# # Russian pre-processing
# This notebook is for anyone who wants to try the TF-IDF or Topic Modeling lessons on Russian text. Before continuing with those lessons, you need to create a *lemmatized derivative* of your original Russian text, which replaces all the words with their dictionary form, which will work much better with the word-count based methods.

# %% [markdown]
# ## Install spaCy
# Russian models are only available starting in spaCy 3.0.
#
# If you run into errors because spaCy 2.x is installed, you can run `!pip uninstall spacy -y` first, then run the cell below.

# %%
# !pip install -U spacy>=3.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# zh-core-web-md 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# pt-core-news-sm 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# pt-core-news-md 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# prodigy 1.10.7 requires catalogue<1.1.0,>=0.0.8, but you have catalogue 2.0.1 which is incompatible.
# prodigy 1.10.7 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# prodigy 1.10.7 requires srsly<1.1.0,>=0.0.6, but you have srsly 2.4.0 which is incompatible.
# kindred 2.7.2 requires sphinx==1.5.5, but you have sphinx 3.4.3 which is incompatible.
# it-core-news-sm 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# es-core-news-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# es-core-news-md 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# es-core-news-lg 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# en-vectors-web-lg 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# en-core-web-sm 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# en-core-web-md 2.3.1 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# de-core-news-sm 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.
# da-core-news-lg 2.3.0 requires spacy<2.4.0,>=2.3.0, but you have spacy 3.0.5 which is incompatible.

# %% [markdown]
# ## Download Language Model

# %%
# !python -m spacy download ru_core_news_md
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <frozen importlib._bootstrap>:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.8
# <frozen importlib._bootstrap>:219: RuntimeWarning: builtins.type size changed, may indicate binary incompatibility. Expected 880, got 864
# Collecting ru-core-news-md==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_md-3.0.0/ru_core_news_md-3.0.0-py3-none-any.whl (43.9 MB)
#      |████████████████████████████████| 43.9 MB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: pymorphy2>=0.9 in /opt/anaconda3/lib/python3.8/site-packages (from ru-core-news-md==3.0.0) (0.9.1)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from ru-core-news-md==3.0.0) (3.0.5)
# Requirement already satisfied: dawg-python>=0.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from pymorphy2>=0.9->ru-core-news-md==3.0.0) (0.7.2)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /opt/anaconda3/lib/python3.8/site-packages (from pymorphy2>=0.9->ru-core-news-md==3.0.0) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /opt/anaconda3/lib/python3.8/site-packages (from pymorphy2>=0.9->ru-core-news-md==3.0.0) (0.6.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (49.2.0.post20200714)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (3.0.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (3.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (0.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (0.3.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.18.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.0.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.18.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (4.56.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.11.2)
# Requirement already satisfied: pathy>=0.3.5 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (0.3.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.7.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (20.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.0.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (8.0.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.4.7)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.15.0)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (3.0.0)
# Requirement already satisfied: idna<2.6,>=2.5 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.22)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->ru-core-news-md==3.0.0) (1.1.1)
# Installing collected packages: ru-core-news-md
# Successfully installed ru-core-news-md-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_md')

# %% [markdown]
# ## Import Libraries

# %%
import spacy
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <frozen importlib._bootstrap>:219: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.8
# <frozen importlib._bootstrap>:219: RuntimeWarning: builtins.type size changed, may indicate binary incompatibility. Expected 880, got 864

# %% [markdown]
# ## Load Language Model
# Once the model is downloaded, we need to load it. There are two ways to load a spaCy language model.

# %% [markdown]
# 1. We can import the model as a module and then load it from the module.

# %%
import ru_core_news_md
nlp = ru_core_news_md.load()

# %% [markdown]
# 2. We can load the model by name.

# %%
#nlp = spacy.load('ru_core_news_md')

# %% [markdown]
# If you just downloaded the model for the first time, it’s advisable to use Option 1. Then you can use the model immediately. Otherwise, you’ll likely need to restart your Jupyter kernel (which you can do by clicking Kernel -> Restart Kernel… in the Jupyter Lab menu).

# %% [markdown]
# ## Process Document
# To create a derivative text file that we can use with TF-IDF, topic modeling, or other word-count based methods, we need to use spaCy to *lemmatize* the text, replacing each word with its dictionary form. The result will be an ungrammatical text that will produce better results than the original version when used with word-count methods.
#
# The example text for Russian is *Яблони цветут* from *Новые люди* by Зинаида Николаевна Гиппиус [from Библиотека русской и советской классики](https://ruslit.traumlibrary.net/book/gippius-ss15-01/gippius-ss15-01.html). (Thanks to Katherine Bowers for the text referral.)

# %%
filepath = '../texts/other-languages/ru.txt'
text = open(filepath, encoding='utf-8').read()
document = nlp(text)

# %%
outname = filepath.replace('.txt', '-lemmatized.txt')
with open(outname, 'w', encoding='utf8') as out:
    for token in document:
        out.write(token.lemma_.lower())
        out.write(' ')

# %% [markdown]
# ## Examine Differences
# The code cell below prints the original word in the text, a dash, then the lemmatized form that was written to the derivative text document that you'll use for TF-IDF and topic modeling. It's a good idea to take a look at this so you can see if there are places where the model consistently makes mistakes, and also to understand what lemmatization is doing.
#
# For instance, an earlier version of spaCy often associated the Spanish preposition `para` 'for' with the verb `parar` 'to stop'. If you just took that derivative file and used it for TF-IDF or topic modeling without realizing what was happening, you might reach the surprising conclusion that "stop" is a very frequent word in your text, when actually it's lemmatization problem.
#
# Also, keep in mind that lemmatization removes both case and and gender (from adjectives and verbs). So if you want to look at how often a particular adjective or past-tense verb is applied to masculine things or characters vs. feminine,  you'll need to prepare your text another way. (Be careful using the unlemmatized version, though: if you do, be sure to account for -- and count -- all of the adjectival declensions for each gender.)

# %%
for token in document:
    print(token.text + ' - ' + token.lemma_)
# Out:
# Яблони - яблони
# цветут - цвести
# * - *
#
#
#  -
#
#
# I - i
#
#  -
#
# Зачем - зачем
# она - она
# так - так
# сделала - сделать
# , - ,
# что - что
# я - я
# не - не
# умею - уметь
# жить - жить
# без - без
# нее - нее
# ? - ?
# Это - это
# она - она
# сделала - сделать
# , - ,
# я - я
# не - не
# виноват - виноватый
# … - …
#
#
#  -
#
#
# Я - я
# написал - написать
# это - это
# – - –
# и - и
# мне - мне
# стало - стать
# странно - странный
# . - .
# Говорю - говорить
# точно - точно
# о - о
# возлюбленной - возлюбленной
# . - .
# Но - но
# возлюбленной - возлюбленной
# у - у
# меня - меня
# нет - нет
# . - .
# Это - это
# моя - мой
# мать - мать
# сделала - сделать
# так - так
# , - ,
# что - что
# я - я
# умираю - умирать
# без - без
# нее - нее
# . - .
# Если - если
# человека - человек
# держать - держать
# в - в
# тепле - тепло
# всю - весь
# жизнь - жизнь
# , - ,
# а - а
# потом - потом
# неодетого - неодетый
# выгнать - выгнать
# на - на
# двадцатиградусный - двадцатиградусный
# мороз - мороз
# , - ,
# он - он
# непременно - непременно
# умрет - умереть
# . - .
# И - и
# я - я
# умру - умереть
# . - .
# Умру - умру
# из - из
# - - -
# за - за
# нее - нее
# . - .
#
#
#  -
#
#
# Давно - давно
# уж - уж
# мне - мне
# хочется - хотеться
# рассказать - рассказать
# кому - кто
# - - -
# нибудь - нибудь
# все - все
# , - ,
# о - о
# чем - что
# я - я
# думаю - думать
# , - ,
# или - или
# хоть - хоть
# написать - написать
# . - .
# Рассказать - рассказать
# некому - некому
# , - ,
# никто - никто
# не - не
# хочет - хотеть
# , - ,
# чтобы - чтобы
# я - я
# рассказывал - рассказывать
# , - ,
# так - так
# уж - уж
# лучше - хороший
# я - я
# напишу - написать
# . - .
# Все - все
# - - -
# таки - таки
# легче - лёгкий
# . - .
#
#
#  -
#
#
# Мне - мне
# кажется - казаться
# , - ,
# что - что
# эти - этот
# последние - последний
# дни - день
# – - –
# важные - важный
# и - и
# значительные - значительный
# дни - день
# для - для
# меня - меня
# . - .
# Я - я
# до - до
# чего - что
# - - -
# то - то
# дошел - дойти
# , - ,
# кончил - кончить
# половину - половина
# моей - мой
# жизни - жизнь
# , - ,
# а - а
# дальше - дальше
# дорога - дорога
# прямая - прямой
# , - ,
# унылая - унылый
# , - ,
# быстрая - быстрый
# и - и
# такая - такой
# однообразная - однообразный
# , - ,
# что - что
# уже - уже
# нельзя - нельзя
# будет - будет
# заметить - заметить
# , - ,
# идешь - идти
# ли - ли
# вперед - вперед
# или - или
# назад - назад
# , - ,
# вверх - вверх
# или - или
# вниз - вниз
# . - .
# И - и
# не - не
# знаю - знать
# , - ,
# нужно - нужный
# ли - ли
# покориться - покориться
# , - ,
# как - как
# всегда - всегда
# , - ,
# и - и
# идти - идти
# по - по
# ней - ней
# . - .
#
#
#  -
#
#
# Мне - мне
# теперь - теперь
# двадцать - двадцать
# восемь - восемь
# лет - год
# , - ,
# но - но
# никто - никто
# этому - это
# не - не
# верит - верить
# , - ,
# таким - такой
# старым - старый
# я - я
# кажусь - казаться
# . - .
# Я - я
# сам - сам
# знаю - знать
# , - ,
# что - что
# я - я
# старик - старик
# . - .
# У - у
# меня - меня
# было - быть
# прежде - прежде
# красивое - красивый
# и - и
# нежное - нежный
# лицо - лицо
# , - ,
# как - как
# у - у
# мамы - мама
# , - ,
# мы - мы
# с - с
# ней - ней
# часто - часто
# вместе - вместе
# смотрелись - смотрелись
# в - в
# зеркало - зеркало
# , - ,
# и - и
# нам - нам
# казалось - казаться
# , - ,
# что - что
# мы - мы
# удивительно - удивительно
# похожи - похожий
# друг - друг
# на - на
# друга - друга
# . - .
#
#
#  -
#
#
# Теперь - теперь
# она - она
# не - не
# узнала - узнать
# бы - бы
# меня - меня
# . - .
# Я - я
# согнулся - согнуться
# , - ,
# глаза - глаз
# потускли - потускнуть
# , - ,
# борода - борода
# выросла - вырасти
# большая - больший
# , - ,
# лицо - лицо
# стало - стать
# желтое - жёлтый
# , - ,
# темное - тёмный
# . - .
# Я - я
# думаю - думать
# , - ,
# что - что
# я - я
# скоро - скоро
# умру - умереть
# . - .
# У - у
# меня - меня
# нет - нет
# , - ,
# кажется - казаться
# , - ,
# никакой - никакой
# болезни - болезнь
# , - ,
# но - но
# я - я
# должен - должный
# умереть - умереть
# , - ,
# потому - потому
# что - что
# живет - жить
# тот - тот
# , - ,
# кто - кто
# хочет - хотеть
# , - ,
# кто - кто
# имеет - иметь
# волю - воля
# жить - жить
# , - ,
# а - а
# у - у
# меня - меня
# нет - нет
# воли - воля
# . - .
# В - в
# последние - последний
# дни - день
# , - ,
# когда - когда
# я - я
# это - это
# сознал - сознал
# и - и
# увидел - увидеть
# , - ,
# что - что
# мне - мне
# больше - больше
# и - и
# ждать - ждать
# нечего - нечего
# – - –
# я - я
# даже - даже
# думал - думать
# о - о
# самоубийстве - самоубийство
# . - .
# Но - но
# я - я
# не - не
# могу - мочь
# . - .
# Я - я
# боюсь - бояться
# . - .
# Я - я
# знаю - знать
# , - ,
# что - что
# у - у
# меня - меня
# пошлое - пошлый
# и - и
# трусливое - трусливый
# сердце - сердце
# . - .
# Я - я
# боюсь - бояться
# . - .
#
#
#  -
#
#
# Все - весь
# это - это
# она - она
# сделала - сделать
# . - .
# Правда - правда
# , - ,
# я - я
# думаю - думать
# – - –
# что - что
# от - от
# нее - нее
# же - же
# у - у
# меня - меня
# то - тот
# чувство - чувство
# , - ,
# которое - которое
# совсем - совсем
# не - не
# пошло - пойти
# , - ,
# и - и
# одно - одно
# давало - давать
# мне - мне
# счастие - счастие
# жизни - жизнь
# – - –
# сентиментальность - сентиментальность
# . - .
# Я - я
# не - не
# стыжусь - стыжусь
# этого - этот
# слова - слово
# , - ,
# как - как
# все - все
# стыдятся - стыдиться
# . - .
# Да - да
# , - ,
# все - все
# стыдятся - стыдиться
# , - ,
# потому - потому
# что - что
# у - у
# всех - всех
# оно - оно
# есть - быть
# … - …
#
#
#  -
#
#
# Я - я
# музыкант - музыкант
# и - и
# если - если
# не - не
# хороший - хороший
# , - ,
# то - то
# порядочный - порядочный
# , - ,
# как - как
# говорят - говорить
# . - .
# Думаю - думать
# , - ,
# хорошим - хороший
# я - я
# и - и
# не - не
# могу - мочь
# быть - быть
# , - ,
# потому - потому
# что - что
# , - ,
# когда - когда
# играю - играть
# длинные - длинный
# , - ,
# трудные - трудный
# рапсодии - рапсодия
# и - и
# фуги - фуга
# , - ,
# даже - даже
# сонаты - сонаты
# , - ,
# я - я
# совершенно - совершенно
# холоден - холодный
# , - ,
# и - и
# мысли - мысль
# у - у
# меня - меня
# самые - самые
# обыденные - обыденный
# , - ,
# скучные - скучный
# . - .
# Чувство - чувство
# прекрасного - прекрасный
# редко - редко
# бывало - бывать
# у - у
# меня - меня
# ; - ;
# это - это
# – - –
# совсем - совсем
# не - не
# сентиментальное - сентиментальный
# чувство - чувство
# , - ,
# оно - оно
# захватывает - захватывать
# и - и
# зовет - звать
# вперед - вперед
# , - ,
# а - а
# мне - мне
# это - это
# трудно - трудный
# ; - ;
# я - я
# люблю - любить
# тихое - тихий
# умиление - умиление
# , - ,
# воспоминания - воспоминание
# , - ,
# когда - когда
# так - так
# сладко - сладко
# болит - болеть
# сердце - сердце
# , - ,
# и - и
# в - в
# душе - душа
# глубокая - глубокий
# тишина - тишина
# . - .
#
#
#  -
#
#
# Бывало - бывать
# , - ,
# играя - играть
# блестящую - блестеть
# прелюдию - прелюдия
# в - в
# концерте - концерт
# ( - (
# теперь - теперь
# уж - уж
# давно - давно
# я - я
# не - не
# выходил - выходить
# на - на
# эстраду - эстрада
# ) - )
# , - ,
# я - я
# взглядываю - взглядывать
# на - на
# какого - какой
# - - -
# нибудь - нибудь
# пожилого - пожилой
# господина - господин
# в - в
# первом - первый
# ряду - ряд
# и - и
# думаю - думать
# : - :
# « - "
# Вот - вот
# ты - ты
# смотришь - смотреть
# на - на
# меня - меня
# , - ,
# слушаешь - слушать
# внимательно - внимательно
# и - и
# знаешь - знать
# , - ,
# что - что
# я - я
# играю - играть
# , - ,
# потом - потом
# будешь - будешь
# делать - делать
# толковые - толковый
# замечания - замечание
# о - о
# моей - мой
# „ - „
# технике - техника
# “ - “
# и - и
# „ - „
# экспрессии - экспрессия
# … - …
# “ - “
# А - а
# если - если
# бы - бы
# я - я
# бросил - бросить
# теперь - теперь
# эту - этот
# прелюдию - прелюдия
# и - и
# сыграл - сыграть
# маленькую - маленький
# , - ,
# простую - простой
# малороссийскую - малороссийский
# песенку - песенка
# , - ,
# которая - которая
# напомнила - напомнить
# бы - бы
# тебе - тебе
# далекие - далёкий
# годы - год
# , - ,
# темный - тёмный
# , - ,
# теплый - тёплый
# сад - сад
# и - и
# , - ,
# может - мочь
# быть - быть
# , - ,
# чьи - чей
# - - -
# нибудь - нибудь
# милые - милый
# , - ,
# забытые - забыть
# глаза - глаз
# – - –
# ты - ты
# встал - встать
# бы - бы
# и - и
# ушел - уйти
# , - ,
# чтобы - чтобы
# скрыть - скрыть
# невольные - невольный
# слезы - слеза
# , - ,
# радостную - радостный
# грусть - грусть
# и - и
# счастье - счастие
# , - ,
# которого - которого
# не - не
# дает - давать
# тебе - тебе
# блестящая - блестеть
# прелюдия - прелюдия
# . - .
# И - и
# непременно - непременно
# ты - ты
# хотел - хотеть
# бы - бы
# скрыть - скрыть
# это - этот
# счастие - счастие
# , - ,
# потому - потому
# что - что
# тебе - тебе
# стыдно - стыдно
# и - и
# кажется - казаться
# , - ,
# что - что
# ты - ты
# один - один
# так - так
# чувствуешь - чувствовать
# и - и
# другие - другие
# не - не
# поймут - понять
# , - ,
# а - а
# между - между
# тем - тем
# все - все
# так - так
# же - же
# чувствуют - чувствовать
# – - –
# и - и
# каждый - каждый
# стыдится - стыдиться
# , - ,
# думая - думать
# , - ,
# что - что
# он - он
# один - один
# . - .
# У - у
# каждого - каждый
# есть - быть
# светлое - светлый
# облако - облако
# в - в
# прошлом - прошлое
# . - .
#
#
#  -
#
#
# И - и
# у - у
# меня - меня
# оно - оно
# есть - быть
# , - ,
# как - как
# у - у
# всех - всех
# » - "
# . - .
#
#
#  -
#
#
# II - ii
#
#  -
#
# Скучно - скучный
# рассказывать - рассказывать
# с - с
# самого - самого
# начала - начало
# , - ,
# с - с
# тех - тот
# пор - пора
# , - ,
# как - как
# я - я
# был - был
# ребенком - ребёнок
# . - .
# Да - да
# и - и
# в - в
# двадцать - двадцать
# лет - год
# я - я
# жил - жить
# так - так
# же - же
# , - ,
# как - как
# в - в
# десять - десять
# . - .
# Только - только
# в - в
# двадцать - двадцать
# я - я
# был - был
# счастливее - счастливый
# , - ,
# потому - потому
# что - что
# перерос - перерасти
# маму - мама
# и - и
# мог - мочь
# гулять - гулять
# с - с
# ней - ней
# под - под
# руку - рука
# . - .
# Отношения - отношение
# же - же
# наши - наш
# не - не
# изменялись - изменяться
# . - .
# Бывало - бывать
# , - ,
# мальчиком - мальчик
# я - я
# часто - часто
# делал - делать
# ей - ей
# сцены - сцена
# , - ,
# когда - когда
# она - она
# уезжала - уезжать
# в - в
# театр - театр
# без - без
# меня - меня
# , - ,
# говорил - говорить
# , - ,
# что - что
# она - она
# не - не
# имеет - иметь
# права - право
# веселиться - веселиться
# , - ,
# когда - когда
# я - я
# должен - должный
# учить - учить
# уроки - урок
# . - .
# Она - она
# серьезно - серьезно
# умоляла - умоляла
# простить - простить
# ее - ее
# , - ,
# даже - даже
# делалась - делаться
# печальна - печальный
# , - ,
# если - если
# я - я
# дулся - дулся
# . - .
# Нам - нам
# нельзя - нельзя
# было - было
# ссориться - ссориться
# . - .
# У - у
# нее - нее
# не - не
# было - быть
# никого - никто
# , - ,
# кроме - кроме
# меня - меня
# . - .
# И - и
# у - у
# меня - меня
# была - быть
# она - она
# одна - один
# . - .
#
#
#  -
#
#
# С - с
# отцом - отец
# я - я
# даже - даже
# не - не
# разговаривал - разговаривать
# никогда - никогда
# . - .
# Пожилой - пожилой
# господин - господин
# , - ,
# вечно - вечно
# занятый - занять
# какими - какой
# - - -
# то - то
# постройками - постройка
# , - ,
# живший - жить
# в - в
# другой - другой
# половине - половина
# дома - дом
# , - ,
# он - он
# совсем - совсем
# не - не
# интересовал - интересовать
# меня - меня
# . - .
# А - а
# мама - мама
# была - была
# такая - такой
# молодая - молодой
# , - ,
# тоненькая - тоненький
# , - ,
# как - как
# девочка - девочка
# , - ,
# с - с
# большими - больший
# черными - чёрный
# глазами - глаз
# , - ,
# свежая - свежий
# , - ,
# блестящая - блестящий
# ; - ;
# платье - платье
# ее - ее
# шумело - шуметь
# при - при
# быстрых - быстрый
# движениях - движение
# , - ,
# и - и
# веяло - веять
# от - от
# нее - нее
# какими - какой
# - - -
# то - то
# странными - странный
# духами - духами
# , - ,
# – - –
# я - я
# так - так
# и - и
# не - не
# узнал - узнать
# , - ,
# как - как
# они - они
# называются - называться
# . - .
# Запах - запах
# их - их
# напоминал - напоминать
# самую - самую
# раннюю - ранний
# весну - весна
# . - .
#
#
#  -
#
#
# Конечно - конечно
# , - ,
# мы - мы
# жили - жить
# в - в
# Петербурге - петербург
# . - .
# Я - я
# говорил - говорить
# , - ,
# что - что
# у - у
# всех - всех
# есть - быть
# что - что
# - - -
# то - то
# необычное - необычный
# , - ,
# светлое - светлый
# в - в
# прошлом - прошлое
# . - .
# Но - но
# я - я
# не - не
# знаю - знать
# и - и
# сомневаюсь - сомневаться
# , - ,
# что - что
# может - мочь
# быть - быть
# у - у
# людей - человек
# , - ,
# которые - которые
# родились - родиться
# в - в
# Петербурге - петербург
# и - и
# не - не
# видали - видали
# другого - другого
# солнца - солнце
# . - .
# Хорошо - хороший
# , - ,
# если - если
# я - я
# ошибаюсь - ошибаться
# и - и
# сужу - сужу
# по - по
# себе - себя
# . - .
# Но - но
# я - я
# никогда - никогда
# не - не
# примирюсь - примирюсь
# с - с
# этим - этот
# низким - низкий
# небом - нёбо
# и - и
# темным - тёмный
# воздухом - воздух
# , - ,
# с - с
# этой - этот
# квартирой - квартира
# , - ,
# где - где
# я - я
# один - один
# . - .
# Впрочем - впрочем
# , - ,
# об - об
# этом - это
# впереди - впереди
# . - .
# И - и
# все - все
# равно - равный
# , - ,
# я - я
# один - один
# в - в
# целом - целое
# свете - свет
# , - ,
# как - как
# же - же
# мне - мне
# не - не
# быть - быть
# одному - одному
# в - в
# этой - этот
# квартире - квартира
# ? - ?
#
#
#  -
#
#
# Мы - мы
# жили - жить
# в - в
# большом - большой
# городе - город
# на - на
# юге - юг
# , - ,
# в - в
# своем - свой
# доме - дом
# . - .
# Дом - дом
# был - был
# новый - новый
# , - ,
# выстроенный - выстроить
# отцом - отец
# , - ,
# неудобный - неудобный
# и - и
# холодный - холодный
# . - .
# Во - во
# дворе - двор
# был - был
# небольшой - небольшой
# , - ,
# но - но
# чистый - чистый
# сад - сад
# , - ,
# к - к
# которому - которому
# со - со
# всех - весь
# сторон - сторона
# примыкали - примыкать
# чужие - чужой
# сады - сад
# , - ,
# а - а
# потому - потому
# он - он
# казался - казаться
# мне - мне
# бесконечным - бесконечный
# . - .
# Отец - отец
# все - все
# хотел - хотеть
# его - его
# вырубить - вырубить
# и - и
# построить - построить
# два - два
# флигеля - флигель
# и - и
# сарай - сарай
# , - ,
# но - но
# так - так
# и - и
# не - не
# собрался - собраться
# . - .
# Не - не
# знаю - знать
# , - ,
# впрочем - впрочем
# , - ,
# может - мочь
# быть - быть
# , - ,
# теперь - теперь
# уж - уж
# и - и
# нет - нет
# нашего - наш
# сада - сад
# . - .
# Не - не
# знаю - знать
# , - ,
# да - да
# и - и
# знать - знать
# не - не
# хочу - хотеть
# . - .
#
#
#  -
#
#
# Я - я
# никогда - никогда
# не - не
# был - был
# в - в
# гимназии - гимназия
# . - .
# В - в
# самом - самом
# деле - дело
# , - ,
# с - с
# кем - кто
# бы - бы
# мама - мама
# оставалась - оставаться
# ? - ?
# У - у
# нее - нее
# было - быть
# много - много
# знакомых - знакомых
# , - ,
# но - но
# никто - никто
# никогда - никогда
# за - за
# ней - ней
# не - не
# ухаживал - ухаживать
# серьезно - серьезно
# , - ,
# хотя - хотя
# и - и
# знали - знать
# ее - её
# отношения - отношение
# к - к
# отцу - отец
# . - .
# Я - я
# думаю - думать
# , - ,
# она - она
# сама - сама
# не - не
# хотела - хотеть
# . - .
#
#
#  -
#
#
# У - у
# меня - меня
# были - быть
# лучшие - хороший
# гимназические - гимназический
# учителя - учитель
# , - ,
# и - и
# я - я
# учился - учиться
# недурно - недурно
# . - .
# Мама - мама
# , - ,
# конечно - конечно
# , - ,
# училась - учиться
# со - со
# мною - мною
# , - ,
# но - но
# ей - ей
# часто - часто
# надоедало - надоедать
# , - ,
# и - и
# она - она
# говорила - говорить
# : - :
#
#
#  -
#
#
# – - –
# Володя - володя
# , - ,
# бросим - бросим
# книги - книга
# , - ,
# пойдем - пойти
# гулять - гулять
# , - ,
# а - а
# ? - ?
#
#
#  -
#
#
# И - и
# мы - мы
# шли - идти
# , - ,
# – - –
# она - она
# нарядная - нарядный
# , - ,
# веселая - весёлый
# , - ,
# а - а
# я - я
# счастливый - счастливый
# , - ,
# что - что
# у - у
# меня - меня
# такая - такой
# хорошенькая - хорошенький
# мама - мама
# , - ,
# и - и
# я - я
# так - так
# на - на
# нее - нее
# похож - похожий
# . - .
#
#
#  -
#
#
# Она - она
# совсем - совсем
# не - не
# изменялась - изменяться
# , - ,
# не - не
# старела - стареть
# , - ,
# и - и
# скоро - скоро
# нас - нас
# стали - стать
# принимать - принимать
# за - за
# брата - брат
# и - и
# сестру - сестра
# , - ,
# особенно - особенно
# когда - когда
# у - у
# меня - меня
# выросли - вырасти
# усы - ус
# и - и
# маленькая - маленький
# борода - борода
# . - .
# Мне - мне
# казалось - казаться
# , - ,
# что - что
# и - и
# я - я
# не - не
# изменился - измениться
# внутренне - внутренне
# . - .
# Только - только
# к - к
# двадцати - двадцать
# годам - год
# я - я
# серьезно - серьезно
# стал - стать
# заниматься - заниматься
# музыкой - музыка
# и - и
# мечтал - мечтать
# о - о
# консерватории - консерватория
# . - .
# Гимназический - гимназический
# экзамен - экзамен
# я - я
# сдал - сдать
# хорошо - хорошо
# , - ,
# и - и
# надо - надо
# было - было
# на - на
# что - что
# - - -
# нибудь - нибудь
# решаться - решаться
# . - .
#
#
#  -
#
#
# – - –
# Ты - ты
# поедешь - поехать
# в - в
# консерваторию - консерватория
# , - ,
# в - в
# Москву - москва
# , - ,
# непременно - непременно
# , - ,
# – - –
# говорила - говорить
# мама - мама
# . - .
# – - –
# Надо - надо
# скорее - скорее
# , - ,
# тебе - тебе
# уже - уже
# двадцать - двадцать
# лет - год
# . - .
# Ты - ты
# будешь - будешь
# знаменитым - знаменитый
# , - ,
# вот - вот
# увидишь - увидеть
# . - .
#
#
#  -
#
#
# – - –
# А - а
# когда - когда
# же - же
# мы - мы
# поедем - поехать
# ? - ?
#
#
#  -
#
#
# – - –
# Осенью - осень
# , - ,
# я - я
# думаю - думать
# . - .
# Хорошо - хороший
# ? - ?
#
#
#  -
#
#
# Не - не
# было - быть
# и - и
# речи - речь
# о - о
# том - том
# , - ,
# чтобы - чтобы
# мне - мне
# ехать - ехать
# без - без
# мамы - мама
# . - .
# С - с
# кем - кто
# бы - бы
# я - я
# стал - стать
# говорить - говорить
# ? - ?
# Кто - кто
# бы - бы
# ласкал - ласкать
# меня - меня
# и - и
# ходил - ходить
# со - со
# мною - мною
# гулять - гулять
# ? - ?
# А - а
# кто - кто
# бы - бы
# ухаживал - ухаживать
# за - за
# мною - мною
# , - ,
# когда - когда
# я - я
# заболею - заболею
# ? - ?
# Да - да
# разве - разве
# возможно - возможный
# ей - ей
# оставаться - оставаться
# без - без
# меня - меня
# , - ,
# когда - когда
# мы - мы
# ни - ни
# на - на
# один - один
# день - день
# не - не
# расставались - расставаться
# , - ,
# все - все
# делали - делать
# и - и
# обсуждали - обсуждать
# сообща - сообща
# ? - ?
# Я - я
# и - и
# заниматься - заниматься
# не - не
# стал - стать
# бы - бы
# без - без
# нее - нее
# . - .
#
#
#  -
#
#
# Так - так
# же - же
# , - ,
# как - как
# бывало - бывать
# ребенком - ребёнок
# , - ,
# – - –
# я - я
# садился - садиться
# по - по
# вечерам - вечер
# у - у
# огня - огонь
# в - в
# ее - её
# комнате - комната
# , - ,
# на - на
# полу - пол
# , - ,
# около - около
# ее - её
# ног - нога
# , - ,
# и - и
# рассказывал - рассказывать
# ей - ей
# , - ,
# как - как
# та - тот
# и - и
# та - тот
# барышня - барышня
# в - в
# меня - меня
# влюблены - влюблены
# , - ,
# как - как
# я - я
# за - за
# ними - ними
# ухаживаю - ухаживать
# , - ,
# и - и
# какая - какой
# мне - мне
# больше - больше
# нравится - нравиться
# . - .
# Мне - мне
# в - в
# это - этот
# время - время
# казалось - казаться
# , - ,
# что - что
# все - весь
# барышни - барышня
# должны - должный
# быть - быть
# в - в
# меня - меня
# влюблены - влюблены
# , - ,
# потому - потому
# что - что
# я - я
# такой - такой
# красивый - красивый
# и - и
# так - так
# хорошо - хорошо
# играю - играть
# на - на
# фортепиано - фортепиано
# . - .
#
#
#  -
#
#
# – - –
# Знаешь - знать
# , - ,
# Володя - володя
# , - ,
# – - –
# сказала - сказать
# мне - мне
# раз - раз
# мама - мама
# , - ,
# – - –
# ведь - ведь
# ты - ты
# совсем - совсем
# не - не
# похож - похожий
# на - на
# мужчину - мужчина
# , - ,
# ты - ты
# совершенно - совершенно
# женщина - женщина
# , - ,
# оттого - оттого
# , - ,
# должно - должный
# быть - быть
# , - ,
# мы - мы
# с - с
# тобой - тобой
# так - так
# и - и
# сошлись - сойтись
# … - …
# Или - или
# это - это
# я - я
# сама - сама
# так - так
# сделала - сделать
# , - ,
# – - –
# прибавила - прибавить
# она - она
# подумав - подумать
# . - .
# – - –
# Ты - ты
# , - ,
# например - например
# , - ,
# в - в
# мужском - мужской
# обществе - общество
# и - и
# не - не
# бываешь - бывать
# никогда - никогда
# ; - ;
# а - а
# среди - среди
# женщин - женщина
# я - я
# тебя - тебя
# видела - видеть
# – - –
# там - там
# ты - ты
# тоже - тоже
# как - как
# - - -
# то - то
# не - не
# ухаживаешь - ухаживать
# , - ,
# а - а
# кокетничаешь - кокетничать
# . - .
# Не - не
# знаю - знать
# … - …
# но - но
# мне - мне
# кажется - казаться
# , - ,
# будь - будь
# ты - ты
# мне - мне
# чужой - чужой
# – - –
# ты - ты
# мне - мне
# не - не
# понравился - понравиться
# бы - бы
# . - .
#
#
#  -
#
#
# Я - я
# страшно - страшно
# обиделся - обидеться
# и - и
# надулся - надуться
# . - .
# Как - как
# ! - !
# Сама - сама
# же - же
# она - она
# говорила - говорить
# , - ,
# что - что
# я - я
# похож - похожий
# на - на
# нее - нее
# , - ,
# а - а
# теперь - теперь
# я - я
# ей - ей
# не - не
# нравлюсь - нравиться
# ! - !
# Если - если
# это - это
# и - и
# не - не
# хорошо - хороший
# , - ,
# что - что
# я - я
# похож - похожий
# на - на
# женщину - женщина
# , - ,
# то - то
# ведь - ведь
# она - она
# же - же
# сама - сама
# прежде - прежде
# этого - это
# не - не
# боялась - бояться
# ? - ?
#
#
#  -
#
#
# Да - да
# и - и
# что - что
# тут - тут
# нехорошего - нехороший
# ? - ?
# Пусть - пусть
# я - я
# похож - похожий
# на - на
# женщину - женщина
# ! - !
# Я - я
# люблю - любить
# прежде - прежде
# всего - всего
# все - весь
# красивое - красивый
# – - –
# но - но
# без - без
# суровости - суровость
# , - ,
# без - без
# силы - сила
# , - ,
# а - а
# нежное - нежный
# и - и
# простое - простой
# . - .
# Я - я
# не - не
# виноват - виноватый
# , - ,
# что - что
# я - я
# такой - такой
# … - …
#
#
#  -
#
#
# Мама - мама
# долго - долго
# просила - просить
# у - у
# меня - меня
# прощения - прощение
# , - ,
# и - и
# мы - мы
# помирились - помириться
# . - .
# Но - но
# я - я
# не - не
# забыл - забыть
# ее - её
# слов - слово
# и - и
# часто - часто
# потом - потом
# говорил - говорить
# ей - ей
# : - :
#
#
#  -
#
#
# – - –
# Вот - вот
# Сыромятников - сыромятников
# , - ,
# или - или
# Маремьянов - маремьянов
# , - ,
# правда - правда
# , - ,
# какие - какой
# мужественные - мужественный
# ? - ?
# Правда - правда
# , - ,
# они - они
# должны - должный
# нравиться - нравиться
# женщинам - женщина
# ? - ?
#
#
#  -
#
#
# Мама - мама
# улыбалась - улыбаться
# и - и
# зажимала - зажимала
# мне - мне
# рот - рот
# своей - свой
# большой - большой
# , - ,
# но - но
# красивой - красивый
# рукой - рука
# с - с
# бесчисленными - бесчисленный
# звенящими - звенящий
# браслетами - браслет
# . - .
#
#
#  -
#
#
# Я - я
# знал - знать
# , - ,
# что - что
# делался - делаться
# фатом - фат
# , - ,
# потому - потому
# что - что
# я - я
# все - все
# - - -
# таки - таки
# очень - очень
# нравился - нравиться
# тамошним - тамошний
# барышням - барышня
# , - ,
# знал - знать
# – - –
# жизнь - жизнь
# проходила - проходить
# пусто - пусто
# , - ,
# и - и
# сердце - сердце
# делалось - делаться
# пошлым - пошлый
# от - от
# этой - этот
# вечной - вечный
# рисовки - рисовка
# и - и
# бесцельного - бесцельный
# желания - желание
# нравиться - нравиться
# . - .
# Сам - сам
# я - я
# ни - ни
# разу - разу
# не - не
# влюблялся - влюбляться
# . - .
# Нравились - нравиться
# многие - многие
# , - ,
# но - но
# не - не
# сильно - сильно
# . - .
# В - в
# сущности - сущность
# , - ,
# я - я
# был - был
# очень - очень
# чистым - чистый
# в - в
# то - тот
# время - время
# , - ,
# как - как
# редкие - редкий
# , - ,
# но - но
# мысленно - мысленно
# я - я
# оказывался - оказываться
# не - не
# лучше - хороший
# других - других
# . - .
# Говорят - говорить
# , - ,
# что - что
# всегда - всегда
# чистые - чистый
# люди - человек
# – - –
# не - не
# чисты - чистый
# в - в
# мыслях - мысль
# ; - ;
# но - но
# мне - мне
# кажется - казаться
# , - ,
# что - что
# это - это
# неправда - неправда
# . - .
# И - и
# у - у
# меня - меня
# это - это
# было - было
# временно - временно
# и - и
# , - ,
# я - я
# думаю - думать
# , - ,
# от - от
# робости - робость
# , - ,
# от - от
# пошлой - пошлый
# и - и
# праздной - праздный
# жизни - жизнь
# , - ,
# и - и
# оттого - оттого
# , - ,
# что - что
# меня - меня
# портили - портить
# и - и
# баловали - баловать
# . - .
#
#
#  -
#
#
# III - iii
#
#  -
#
# Удивительно - удивительный
# , - ,
# как - как
# мало - мало
# меня - меня
# интересовали - интересовать
# книги - книга
# . - .
# Я - я
# их - их
# читал - читать
# , - ,
# пока - пока
# не - не
# сдал - сдать
# экзамена - экзамен
# . - .
# А - а
# с - с
# тех - тот
# пор - пора
# я - я
# занимался - заниматься
# только - только
# музыкой - музыка
# . - .
# Она - она
# одна - один
# меня - меня
# волновала - волновать
# и - и
# заставляла - заставлять
# вспоминать - вспоминать
# то - то
# , - ,
# чего - что
# не - не
# было - быть
# . - .
# Для - для
# музыки - музыка
# я - я
# мог - мочь
# забыть - забыть
# многое - многое
# . - .
#
#
#  -
#
#
# Наконец - наконец
# , - ,
# мы - мы
# поехали - поехать
# в - в
# Москву - москва
# . - .
# И - и
# я - я
# был - был
# рад - рад
# . - .
# Я - я
# инстинктивно - инстинктивно
# чувствовал - чувствовать
# , - ,
# что - что
# надо - надо
# все - все
# переменить - переменить
# . - .
#
#
#  -
#
#
# С - с
# нами - нами
# поехала - поехать
# наша - наш
# старая - старый
# экономка - экономка
# , - ,
# без - без
# нее - нее
# мы - мы
# совсем - совсем
# пропали - пропасть
# бы - бы
# . - .
# Я - я
# в - в
# Москве - москва
# никогда - никогда
# не - не
# был - быть
# , - ,
# а - а
# мама - мама
# хотя - хотя
# и - и
# жила - жить
# там - там
# прежде - прежде
# , - ,
# однако - однако
# ничего - ничто
# не - не
# знала - знать
# и - и
# не - не
# умела - уметь
# . - .
# Может - мочь
# быть - быть
# , - ,
# и - и
# сумела - суметь
# бы - бы
# , - ,
# но - но
# ей - ей
# было - было
# скучно - скучный
# заботиться - заботиться
# и - и
# суетиться - суетиться
# , - ,
# и - и
# я - я
# это - это
# отлично - отлично
# понимал - понимать
# . - .
#
#
#  -
#
#
# Мы - мы
# наняли - нанять
# хорошенькую - хорошенький
# квартирку - квартирка
# на - на
# Малой - малый
# Никитской - никитский
# и - и
# зажили - зажить
# припеваючи - припеваючи
# , - ,
# по - по
# - - -
# товарищески - товарищески
# . - .
# Ездили - ездить
# в - в
# театр - театр
# , - ,
# кататься - кататься
# . - .
# Скоро - скоро
# явились - явиться
# знакомые - знакомые
# , - ,
# нашлись - найтись
# родственники - родственник
# . - .
# Но - но
# я - я
# стал - стать
# заниматься - заниматься
# ревностно - ревностно
# и - и
# даже - даже
# редко - редко
# выходил - выходить
# , - ,
# когда - когда
# у - у
# мамы - мама
# были - быть
# гости - гость
# . - .
#
#
#  -
#
#
# В - в
# консерватории - консерватория
# я - я
# ни - ни
# с - с
# кем - кто
# не - не
# сошелся - сошелся
# , - ,
# кроме - кроме
# своего - свой
# профессора - профессор
# , - ,
# еще - еще
# молодого - молодой
# человека - человек
# . - .
#
#
#  -
#
#
# Я - я
# ему - ему
# казался - казаться
# странным - странный
# , - ,
# хотя - хотя
# , - ,
# как - как
# он - он
# говорил - говорить
# , - ,
# очень - очень
# талантливым - талантливый
# . - .
# Он - он
# , - ,
# однако - однако
# , - ,
# угадал - угадать
# меня - меня
# только - только
# после - после
# того - того
# , - ,
# как - как
# я - я
# его - его
# ввел - ввести
# к - к
# нам - нам
# , - ,
# и - и
# он - он
# увидал - увидать
# мою - мой
# маму - мама
# . - .
# Нас - нас
# друг - друг
# без - без
# друга - друга
# понять - понять
# было - было
# нельзя - нельзя
# , - ,
# а - а
# вместе - вместе
# , - ,
# как - как
# говорили - говорить
# , - ,
# мы - мы
# составляли - составлять
# одно - одно
# целое - целое
# . - .
#
#
#  -
#
#
# – - –
# Смотрите - смотреть
# , - ,
# молодой - молодой
# человек - человек
# , - ,
# – - –
# сказал - сказать
# мне - мне
# раз - раз
# профессор - профессор
# , - ,
# – - –
# занимайтесь - заниматься
# хорошенько - хорошенько
# . - .
# Из - из
# вас - вас
# должно - должный
# выйти - выйти
# что - что
# - - -
# нибудь - нибудь
# , - ,
# или - или
# вы - вы
# совсем - совсем
# пропадете - пропасть
# . - .
#
#
#  -
#
#
# И - и
# я - я
# занимался - заниматься
# . - .
# Даже - даже
# лень - лень
# свою - свой
# забыл - забыть
# , - ,
# не - не
# заботился - заботиться
# о - о
# волосах - волос
# и - и
# об - об
# одежде - одежда
# , - ,
# редко - редко
# выезжал - выезжать
# и - и
# все - все
# играл - играть
# свои - свой
# гаммы - гамма
# . - .
# Я - я
# их - их
# не - не
# любил - любить
# и - и
# терпел - терпеть
# только - только
# , - ,
# как - как
# трудную - трудный
# лестницу - лестница
# , - ,
# по - по
# которой - которой
# нужно - нужный
# взбираться - взбираться
# наверх - наверх
# . - .
# Как - как
# я - я
# тосковал - тосковать
# о - о
# синем - синий
# небе - нёбо
# , - ,
# о - о
# земле - земля
# , - ,
# о - о
# цветах - цвет
# ! - !
# Я - я
# ни - ни
# о - о
# чем - что
# так - так
# не - не
# тосковал - тосковать
# , - ,
# я - я
# не - не
# думал - думать
# , - ,
# что - что
# будет - будет
# тоска - тоска
# . - .
# Мама - мама
# утешала - утешала
# меня - меня
# , - ,
# но - но
# … - …
# это - это
# было - было
# мое - мой
# больное - больной
# место - место
# . - .
# Я - я
# знал - знать
# , - ,
# что - что
# тут - тут
# мы - мы
# не - не
# понимаем - понимать
# друг - друг
# друга - друга
# , - ,
# только - только
# тут - тут
# . - .
# Она - она
# даже - даже
# сада - сад
# нашего - наш
# не - не
# любила - любить
# , - ,
# – - –
# гулять - гулять
# ходила - ходить
# по - по
# улицам - улица
# , - ,
# говорила - говорить
# , - ,
# что - что
# солнечный - солнечный
# свет - свет
# гораздо - гораздо
# беспокойнее - беспокойный
# полутьмы - полутьма
# гостиной - гостиная
# , - ,
# а - а
# ее - её
# духи - дух
# лучше - хороший
# запаха - запах
# настоящей - настоящий
# весны - весна
# . - .
#
#
#  -
#
#
# Когда - когда
# я - я
# об - об
# этом - это
# думал - думать
# , - ,
# приходило - приходило
# невольное - невольный
# чувство - чувство
# на - на
# минуту - минута
# , - ,
# что - что
# она - она
# не - не
# молода - молодой
# , - ,
# что - что
# она - она
# не - не
# может - мочь
# быть - быть
# вполне - вполне
# моим - мой
# товарищем - товарищ
# , - ,
# что - что
# в - в
# глубине - глубина
# души - душа
# – - –
# между - между
# нами - нами
# преграда - преграда
# . - .
#
#
#  -
#
#
# Но - но
# это - это
# были - были
# только - только
# минуты - минута
# … - …
#
#
#  -
#
#
# Я - я
# говорил - говорить
# , - ,
# что - что
# не - не
# сошелся - сойтись
# ни - ни
# с - с
# кем - кто
# . - .
# Близко - близко
# не - не
# сходился - сходился
# , - ,
# но - но
# знакомился - знакомиться
# и - и
# несколько - несколько
# раз - раз
# попадал - попадать
# на - на
# кутежи - кутёж
# , - ,
# не - не
# ночевал - ночевать
# дома - дома
# … - …
#
#
#  -
#
#
# Мама - мама
# расспрашивала - расспрашивала
# меня - меня
# с - с
# любопытством - любопытство
# и - и
# без - без
# всяких - всякий
# упреков - упрёк
# , - ,
# но - но
# я - я
# был - был
# как - как
# - - -
# то - то
# недоволен - недовольный
# и - и
# рассказывал - рассказывать
# подробно - подробно
# с - с
# омерзением - омерзение
# , - ,
# хотя - хотя
# не - не
# без - без
# гордости - гордость
# . - .
#
#
#  -
#
#
# – - –
# Это - это
# неважно - неважный
# , - ,
# Володя - володя
# , - ,
# – - –
# говорили - говорить
# мама - мама
# . - .
# – - –
# Это - это
# я - я
# все - все
# так - так
# и - и
# думала - думать
# . - .
# Ты - ты
# только - только
# меня - меня
# не - не
# должен - должный
# забывать - забывать
# . - .
# Понимаешь - понимать
# , - ,
# чтобы - чтобы
# я - я
# была - была
# у - у
# тебя - тебя
# первой - первый
# , - ,
# и - и
# всегда - всегда
# , - ,
# как - как
# ты - ты
# у - у
# меня - меня
# . - .
# Понимаешь - понимать
# ? - ?
# Иначе - иначе
# жить - жить
# нельзя - нельзя
# . - .
# Понимаешь - понимать
# ? - ?
#
#
#  -
#
#
# Я - я
# только - только
# улыбался - улыбаться
# и - и
# обнимал - обнимал
# ее - ее
# . - .
# Как - как
# же - же
# она - она
# может - мочь
# быть - быть
# не - не
# первой - первый
# ? - ?
# Кто - кто
# же - же
# тогда - тогда
# ? - ?
#
#
#  -
#
#
# IV - iv
#
#  -
#
# Прошло - пройти
# несколько - несколько
# лет - год
# . - .
# Я - я
# кончал - кончать
# консерваторию - консерватория
# , - ,
# выступал - выступать
# в - в
# концертах - концерт
# – - –
# и - и
# с - с
# успехом - успех
# . - .
# Но - но
# я - я
# сам - сам
# был - был
# не - не
# совсем - совсем
# доволен - довольный
# . - .
# Что - что
# мне - мне
# в - в
# этих - этот
# трескучих - трескучий
# пьесах - пьесах
# , - ,
# где - где
# я - я
# так - так
# быстро - быстро
# перебираю - перебирать
# пальцами - палец
# , - ,
# и - и
# все - все
# удивляются - удивляться
# и - и
# хвалят - хвалить
# меня - меня
# ? - ?
# Когда - когда
# же - же
# я - я
# смогу - смочь
# сыграть - сыграть
# то - то
# , - ,
# что - что
# слышу - слышать
# часто - часто
# – - –
# но - но
# что - что
# ускользает - ускользать
# от - от
# меня - меня
# ? - ?
# Если - если
# сумею - суметь
# , - ,
# если - если
# найду - найду
# – - –
# то - то
# все - все
# сразу - сразу
# изменится - измениться
# , - ,
# и - и
# я - я
# буду - буду
# одно - одно
# чувствовать - чувствовать
# с - с
# теми - тот
# , - ,
# кто - кто
# слушает - слушать
# . - .
# Мы - мы
# вместе - вместе
# будем - будем
# плакать - плакать
# , - ,
# потому - потому
# что - что
# оно - оно
# пройдет - пройти
# не - не
# мимо - мимо
# , - ,
# а - а
# заденет - задеть
# , - ,
# зацепит - зацепить
# самое - самое
# тайное - тайный
# , - ,
# самое - самое
# тайное - тайный
# , - ,
# самое - самое
# глубокое - глубокий
# , - ,
# одно - одно
# для - для
# всех - всех
# … - …
# Да - да
# , - ,
# мы - мы
# будем - будем
# плакать - плакать
# ; - ;
# потом - потом
# … - …
# потом - потом
# все - все
# равно - равный
# , - ,
# ну - ну
# – - –
# умрем - умереть
# . - .
# Все - все
# равно - равный
# … - …
# Я - я
# знал - знать
# , - ,
# что - что
# , - ,
# пока - пока
# я - я
# сам - сам
# не - не
# чувствую - чувствовать
# – - –
# ничего - ничто
# не - не
# будет - будет
# ; - ;
# и - и
# верил - верить
# без - без
# сомнений - сомнение
# , - ,
# что - что
# если - если
# придет - прийти
# ко - ко
# мне - мне
# – - –
# то - то
# и - и
# ко - ко
# всем - всем
# придет - прийти
# , - ,
# кому - кто
# я - я
# буду - буду
# « - "
# говорить - говорить
# » - "
# . - .
# Я - я
# всегда - всегда
# мысленно - мысленно
# вместо - вместо
# « - "
# играть - играть
# » - "
# употреблял - употреблять
# выражение - выражение
# « - "
# говорить - говорить
# с - с
# людьми - человек
# » - "
# . - .
#
#
#  -
#
#
# Может - мочь
# быть - быть
# , - ,
# все - весь
# это - это
# было - было
# не - не
# умно - умный
# . - .
# Но - но
# я - я
# никогда - никогда
# не - не
# считал - считать
# себя - себя
# умным - умный
# человеком - человек
# . - .
# У - у
# меня - меня
# и - и
# самолюбия - самолюбия
# тут - тут
# не - не
# было - быть
# . - .
# Я - я
# знал - знать
# , - ,
# что - что
# я - я
# не - не
# развит - развить
# и - и
# мало - мало
# образован - образовать
# . - .
# Да - да
# и - и
# пусть - пусть
# . - .
# Я - я
# не - не
# к - к
# этому - это
# шел - идти
# , - ,
# у - у
# меня - меня
# другое - другое
# счастье - счастие
# , - ,
# другая - другая
# дорога - дорога
# меня - меня
# поведет - повести
# наверх - наверх
# . - .
#
#
#  -
#
#
# Мама - мама
# раза - раз
# два - два
# меня - меня
# оставляла - оставлять
# одного - одного
# на - на
# несколько - несколько
# недель - неделя
# , - ,
# ей - ей
# необходимо - необходимый
# было - было
# уехать - уехать
# домой - домой
# . - .
# И - и
# каждый - каждый
# раз - раз
# я - я
# умирал - умирать
# , - ,
# бросал - бросать
# заниматься - заниматься
# , - ,
# почти - почти
# не - не
# ел - есть
# . - .
# У - у
# меня - меня
# являлся - являться
# какой - какой
# - - -
# то - то
# нервный - нервный
# ужас - ужас
# , - ,
# мне - мне
# казалось - казаться
# , - ,
# что - что
# я - я
# один - один
# на - на
# свете - свет
# , - ,
# ее - ее
# нет - нет
# и - и
# не - не
# было - быть
# . - .
# Главное - главный
# – - –
# не - не
# было - быть
# ! - !
# А - а
# если - если
# не - не
# было - быть
# , - ,
# – - –
# значит - значить
# , - ,
# и - и
# не - не
# будет - будет
# … - …
#
#
#  -
#
#
# Зачем - зачем
# она - она
# так - так
# связала - связать
# меня - меня
# с - с
# собою - собою
# , - ,
# что - что
# жизнь - жизнь
# без - без
# нее - нее
# не - не
# могла - мочь
# длиться - длиться
# ? - ?
# Если - если
# я - я
# скажу - сказать
# , - ,
# что - что
# любил - любить
# ее - ее
# – - –
# это - это
# будет - будет
# не - не
# то - тот
# слово - слово
# : - :
# не - не
# люблю - любить
# я - я
# воздух - воздух
# , - ,
# пищу - пища
# , - ,
# – - –
# а - а
# жить - жить
# без - без
# них - них
# не - не
# могу - мочь
# . - .
# Я - я
# знаю - знать
# , - ,
# что - что
# я - я
# слабый - слабый
# , - ,
# слабый - слабый
# человек - человек
# . - .
# У - у
# меня - меня
# нет - нет
# силы - сила
# сделать - сделать
# против - против
# себя - себя
# , - ,
# не - не
# страдать - страдать
# , - ,
# когда - когда
# я - я
# страдаю - страдать
# … - …
#
#
#  -
#
#
# Я - я
# был - был
# последний - последний
# год - год
# в - в
# Москве - москва
# , - ,
# когда - когда
# заболел - заболеть
# отец - отец
# , - ,
# и - и
# мама - мама
# уехала - уехать
# перед - перед
# Рождеством - рождество
# . - .
# А - а
# в - в
# конце - конец
# января - январь
# я - я
# заболел - заболеть
# сам - сам
# , - ,
# бросил - бросить
# все - все
# и - и
# приехал - приехать
# домой - домой
# . - .
# Что - что
# ж - ж
# , - ,
# лишний - лишний
# год - год
# – - –
# так - так
# лишний - лишний
# год - год
# , - ,
# а - а
# заниматься - заниматься
# без - без
# нее - нее
# я - я
# все - все
# равно - равный
# не - не
# могу - мочь
# . - .
# Я - я
# приехал - приехать
# , - ,
# и - и
# мы - мы
# целый - целый
# вечер - вечер
# просидели - просидеть
# вместе - вместе
# на - на
# диванчике - диванчик
# в - в
# ее - её
# комнате - комната
# и - и
# молчали - молчать
# … - …
# Но - но
# я - я
# знал - знать
# , - ,
# что - что
# она - она
# довольна - довольный
# . - .
# Она - она
# так - так
# же - же
# не - не
# могла - мочь
# жить - жить
# без - без
# меня - меня
# , - ,
# как - как
# я - я
# без - без
# нее - нее
# … - …
#
#
#  -
#
#
# V - v
#
#  -
#
# Я - я
# проводил - проводить
# дни - день
# дома - дом
# и - и
# много - много
# играл - играть
# . - .
# У - у
# меня - меня
# была - быть
# небольшая - небольшой
# комната - комната
# в - в
# одно - одно
# окно - окно
# , - ,
# и - и
# окно - окно
# это - это
# выходило - выходить
# на - на
# двор - двор
# , - ,
# к - к
# саду - сад
# . - .
# Я - я
# поставил - поставить
# свой - свой
# рояль - рояль
# к - к
# окну - окно
# и - и
# смотрел - смотреть
# на - на
# небо - нёбо
# и - и
# на - на
# деревья - дерево
# , - ,
# когда - когда
# играл - играть
# . - .
#
#
#  -
#
#
# В - в
# середине - середина
# февраля - февраль
# стало - стать
# совсем - совсем
# уж - уж
# тепло - тепло
# . - .
# Я - я
# ходил - ходить
# в - в
# сад - сад
# и - и
# смотрел - смотреть
# на - на
# голубое - голубой
# небо - нёбо
# между - между
# голыми - голый
# ветвями - ветвями
# черешен - черешен
# и - и
# яблонь - яблоня
# . - .
# Какое - какой
# оно - оно
# было - было
# веселое - весёлый
# , - ,
# золотое - золотое
# между - между
# черными - чёрный
# сучьями - сучьями
# ! - !
# А - а
# на - на
# дальних - дальний
# горах - гора
# чуть - чуть
# желтела - желтеть
# , - ,
# даже - даже
# еще - еще
# не - не
# зеленела - зеленеть
# , - ,
# а - а
# желтела - желтеть
# первая - первый
# травка - травка
# . - .
# Она - она
# всегда - всегда
# из - из
# земли - земля
# выходит - выходить
# такая - такой
# светлая - светлый
# и - и
# молодая - молодой
# , - ,
# что - что
# кажется - казаться
# желтой - жёлтый
# . - .
# Люблю - любить
# я - я
# эти - этот
# крошечные - крошечный
# травинки - травинка
# , - ,
# первые - первый
# ; - ;
# они - они
# – - –
# точно - точно
# дети - ребёнок
# , - ,
# любопытные - любопытный
# и - и
# неловкие - неловкий
# , - ,
# подымают - подымать
# серый - серый
# комок - комок
# земли - земля
# и - и
# глядят - глядеть
# на - на
# солнце - солнце
# . - .
# Ах - ах
# , - ,
# мама - мама
# … - …
# Зачем - зачем
# она - она
# не - не
# ходила - ходить
# со - со
# мной - мной
# в - в
# сад - сад
# и - и
# не - не
# любила - любить
# того - того
# , - ,
# что - что
# я - я
# любил - любить
# ? - ?
# И - и
# опять - опять
# холодная - холодный
# струя - струя
# пробиралась - пробиралась
# в - в
# мое - мой
# сердце - сердце
# , - ,
# опять - опять
# отчужденность - отчуждённость
# … - …
#
#
#  -
#
#
# Как - как
# это - это
# странно - странный
# ! - !
# И - и
# как - как
# больно - больно
# … - …
#
#
#  -
#
#
# Чем - что
# дальше - дальше
# шла - идти
# весна - весна
# , - ,
# тем - тем
# больше - больше
# я - я
# сидел - сидеть
# в - в
# саду - сад
# , - ,
# и - и
# тем - тем
# радостнее - радостнее
# мне - мне
# становилось - становиться
# . - .
# Точно - точно
# я - я
# сам - сам
# рос - расти
# вместе - вместе
# с - с
# желтыми - жёлтый
# цветами - цвет
# . - .
# Свои - свой
# фуги - фуга
# я - я
# забросил - забросить
# ; - ;
# опять - опять
# я - я
# слышал - слышать
# в - в
# душе - душа
# что - что
# - - -
# то - то
# такое - такой
# , - ,
# что - что
# светлее - светлый
# всяких - всякий
# фуг - фуга
# , - ,
# опять - опять
# я - я
# искал - искать
# – - –
# и - и
# не - не
# мог - мочь
# найти - найти
# . - .
# Оно - оно
# было - было
# тут - тут
# , - ,
# близко - близко
# , - ,
# в - в
# весеннем - весенний
# шуме - шум
# , - ,
# в - в
# весеннем - весенний
# запахе - запах
# … - …
# И - и
# как - как
# оно - оно
# далеко - далеко
# от - от
# меня - меня
# теперь - теперь
# ! - !
# .. - ..
#
#
#  -
#
#
# Листьев - листьев
# не - не
# было - было
# видно - видно
# , - ,
# но - но
# на - на
# яблонях - яблоня
# и - и
# черешнях - черешня
# розовели - розовели
# круглые - круглый
# , - ,
# крепкие - крепкий
# почки - почка
# , - ,
# совсем - совсем
# еще - еще
# закрытые - закрыть
# , - ,
# точно - точно
# спящие - спать
# . - .
# Мне - мне
# один - один
# раз - раз
# пришло - прийти
# в - в
# голову - голов
# : - :
# откуда - откуда
# они - они
# , - ,
# эти - этот
# почки - почка
# , - ,
# зачем - зачем
# они - они
# ? - ?
# Зачем - зачем
# это - этот
# небо - нёбо
# , - ,
# эта - этот
# весна - весна
# ? - ?
# Отчего - отчего
# я - я
# ничего - ничто
# не - не
# знаю - знать
# ? - ?
# Но - но
# я - я
# испугался - испугаться
# . - .
# Не - не
# надо - надо
# , - ,
# не - не
# надо - надо
# вопросов - вопрос
# , - ,
# не - не
# нужно - нужный
# думать - думать
# , - ,
# нужно - нужный
# покориться - покориться
# и - и
# отдаться - отдаться
# всему - всему
# , - ,
# и - и
# тогда - тогда
# будет - будет
# не - не
# страшно - страшный
# и - и
# просто - просто
# … - …
#
#
#  -
#
#
# Я - я
# сидел - сидеть
# в - в
# конце - конец
# узенькой - узенький
# , - ,
# сырой - сырой
# дорожки - дорожка
# , - ,
# на - на
# низкой - низкий
# скамеечке - скамеечка
# у - у
# самого - самого
# дальнего - дальний
# забора - забор
# моего - мой
# сада - сад
# . - .
# Это - это
# был - был
# не - не
# забор - забор
# , - ,
# а - а
# живая - живой
# изгородь - изгородь
# , - ,
# пока - пока
# еще - еще
# черная - чёрный
# . - .
# Я - я
# никогда - никогда
# не - не
# горевал - горевать
# , - ,
# что - что
# мой - мой
# сад - сад
# не - не
# тянулся - тянуться
# далеко - далеко
# , - ,
# а - а
# кончался - кончался
# здесь - здесь
# , - ,
# у - у
# этой - этот
# изгороди - изгородь
# . - .
# Всюду - всюду
# , - ,
# куда - куда
# я - я
# ни - ни
# смотрел - смотреть
# – - –
# были - быть
# деревья - дерево
# , - ,
# трава - трава
# и - и
# земля - земля
# , - ,
# а - а
# над - над
# ними - ними
# небо - нёбо
# . - .
# Какое - какой
# мне - мне
# дело - дело
# до - до
# того - того
# , - ,
# что - что
# это - это
# деревья - дерево
# чужих - чужой
# садов - сад
# , - ,
# когда - когда
# они - они
# такие - такой
# же - же
# , - ,
# как - как
# и - и
# мои - мой
# ? - ?
# Все - все
# мое - мой
# , - ,
# на - на
# что - что
# я - я
# смотрю - смотреть
# и - и
# что - что
# меня - меня
# радует - радовать
# . - .
# И - и
# те - тот
# обрывистые - обрывистый
# горы - гора
# с - с
# глубокими - глубокий
# , - ,
# сизыми - сизый
# тенями - тень
# – - –
# далеко - далёкий
# на - на
# небе - нёбо
# – - –
# они - они
# тоже - тоже
# мои - мой
# . - .
# Солнце - солнце
# шло - идти
# к - к
# западу - запад
# , - ,
# и - и
# лучи - луч
# его - его
# делались - делаться
# холоднее - холоднее
# . - .
# Я - я
# знал - знать
# , - ,
# что - что
# мне - мне
# пора - пора
# идти - идти
# домой - домой
# , - ,
# но - но
# не - не
# мог - мочь
# расстаться - расстаться
# со - со
# своей - свой
# скамейкой - скамейка
# . - .
# Вдруг - вдруг
# позади - позади
# меня - меня
# кто - кто
# - - -
# то - то
# прошел - пройти
# , - ,
# тихо - тихо
# так - так
# , - ,
# что - что
# я - я
# едва - едва
# услышал - услышать
# . - .
# Я - я
# обернулся - обернуться
# : - :
# шаги - шаг
# слышались - слышаться
# за - за
# изгородью - изгородь
# , - ,
# в - в
# чужом - чужой
# саду - сад
# . - .
# Это - это
# были - были
# даже - даже
# не - не
# шаги - шаг
# , - ,
# а - а
# какой - какой
# - - -
# то - то
# связный - связный
# шорох - шорох
# , - ,
# точно - точно
# что - что
# - - -
# то - то
# проволоклось - проволочься
# по - по
# земле - земля
# – - –
# и - и
# затихло - затихнуть
# . - .
# Я - я
# мог - мочь
# бы - бы
# встать - встать
# и - и
# посмотреть - посмотреть
# , - ,
# что - что
# это - это
# такое - такой
# , - ,
# – - –
# изгородь - изгородь
# приходилась - приходиться
# мне - мне
# в - в
# одном - одном
# месте - место
# чуть - чуть
# выше - высоко
# пояса - пояс
# , - ,
# – - –
# но - но
# я - я
# подумал - подумать
# : - :
# « - "
# Ну - ну
# , - ,
# все - все
# равно - равный
# , - ,
# не - не
# стоит - стоить
# » - "
# . - .
# Весенний - весенний
# воздух - воздух
# утомил - утомить
# меня - меня
# , - ,
# мне - мне
# хотелось - хотеться
# быть - быть
# спокойным - спокойный
# и - и
# дремать - дремать
# . - .
#
#
#  -
#
#
# Но - но
# опять - опять
# повторился - повториться
# шорох - шорох
# и - и
# умолк - умолкнуть
# сразу - сразу
# . - .
# Я - я
# поднял - поднять
# глаза - глаз
# и - и
# встретился - встретиться
# с - с
# чужими - чужой
# глазами - глаз
# , - ,
# которые - которые
# пристально - пристально
# и - и
# зло - зло
# смотрели - смотреть
# на - на
# меня - меня
# . - .
# Я - я
# почувствовал - почувствовать
# , - ,
# что - что
# они - они
# смотрели - смотреть
# зло - зло
# , - ,
# потому - потому
# что - что
# мне - мне
# стало - стать
# беспокойно - беспокойно
# . - .
# Потом - потом
# сразу - сразу
# выражение - выражение
# глаз - глаз
# изменилось - измениться
# и - и
# стало - стать
# равнодушным - равнодушный
# . - .
# За - за
# изгородью - изгородь
# стояла - стоять
# незнакомая - незнакомый
# мне - мне
# девушка - девушка
# . - .
# Несколько - несколько
# времени - время
# мы - мы
# молчали - молчать
# и - и
# смотрели - смотреть
# друг - друг
# на - на
# друга - друга
# . - .
# Я - я
# думал - думать
# , - ,
# что - что
# она - она
# уйдет - уйти
# . - .
# Но - но
# она - она
# заговорила - заговорить
# . - .
#
#
#  -
#
#
# – - –
# Здравствуйте - здравствовать
# , - ,
# – - –
# сказала - сказать
# она - она
# неприветливо - неприветливо
# . - .
# – - –
# Я - я
# вас - вас
# давно - давно
# вижу - видеть
# . - .
# Зачем - зачем
# вы - вы
# вечно - вечно
# здесь - здесь
# сидите - сидеть
# ? - ?
#
#
#  -
#
#
# – - –
# Тут - тут
# хорошо - хорошо
# , - ,
# – - –
# отвечал - отвечать
# я - я
# как - как
# - - -
# то - то
# робко - робко
# , - ,
# точно - точно
# извиняясь - извиняться
# . - .
# – - –
# А - а
# я - я
# вас - вас
# никогда - никогда
# не - не
# видел - видеть
# . - .
#
#
#  -
#
#
# – - –
# Я - я
# смотрела - смотреть
# издали - издать
# . - .
# Я - я
# живу - жить
# вон - вон
# там - там
# , - ,
# – - –
# и - и
# она - она
# указала - указать
# на - на
# чуть - чуть
# видный - видный
# за - за
# деревьями - дерево
# дом - дом
# , - ,
# далеко - далеко
# от - от
# изгороди - изгородь
# . - .
#
#
#  -
#
#
# Когда - когда
# она - она
# сделала - сделать
# движение - движение
# рукой - рука
# , - ,
# я - я
# в - в
# первый - первый
# раз - раз
# заметил - заметить
# , - ,
# что - что
# одежда - одежда
# ее - ее
# была - была
# странная - странный
# , - ,
# непохожая - непохожая
# на - на
# обыкновенные - обыкновенный
# платья - платье
# барышень - барышня
# . - .
# То - то
# она - она
# мне - мне
# казалась - казаться
# маскарадной - маскарадный
# , - ,
# то - то
# совсем - совсем
# простой - простой
# и - и
# даже - даже
# единственно - единственно
# возможной - возможный
# . - .
# Это - это
# было - было
# широкое - широкий
# платье - платье
# из - из
# мягкой - мягкий
# белой - белый
# материи - материя
# , - ,
# но - но
# одинаково - одинаково
# широкое - широкий
# вверху - вверху
# и - и
# в - в
# подоле - подол
# ( - (
# я - я
# видел - видеть
# теперь - теперь
# ее - ее
# всю - весь
# , - ,
# потому - потому
# что - что
# стоял - стоять
# у - у
# изгородим - изгородим
# с - с
# другой - другой
# стороны - сторона
# ) - )
# , - ,
# с - с
# узким - узкий
# темно - темно
# - - -
# красным - красный
# поясом - пояс
# . - .
# Я - я
# понял - понять
# , - ,
# почему - почему
# был - быть
# такой - такой
# странный - странный
# шорох - шорох
# , - ,
# когда - когда
# она - она
# шла - идти
# : - :
# платье - платье
# кончалось - кончаться
# длинным - длинный
# шлейфом - шлейф
# , - ,
# и - и
# даже - даже
# не - не
# шлейфом - шлейф
# , - ,
# а - а
# просто - просто
# падающим - падать
# сзади - сзади
# куском - кусок
# материи - материя
# , - ,
# небрежным - небрежный
# и - и
# красивым - красивый
# . - .
# Рукава - рукав
# были - были
# узкие - узкий
# и - и
# длинные - длинный
# , - ,
# почти - почти
# до - до
# пальцев - палец
# . - .
#
#
#  -
#
#
# Я - я
# , - ,
# хорошо - хорошо
# воспитанный - воспитанный
# молодой - молодой
# человек - человек
# , - ,
# умел - уметь
# держать - держать
# себя - себя
# с - с
# барышнями - барышня
# . - .
# Но - но
# тут - тут
# ни - ни
# на - на
# одну - одну
# минуту - минута
# я - я
# не - не
# подумал - подумать
# , - ,
# что - что
# это - это
# барышня - барышня
# и - и
# с - с
# ней - ней
# надо - надо
# вести - вести
# себя - себя
# , - ,
# как - как
# с - с
# другими - другими
# . - .
# Я - я
# спросил - спросить
# ее - ее
# : - :
#
#
#  -
#
#
# – - –
# Отчего - отчего
# это - это
# на - на
# вас - вас
# такое - такой
# странное - странный
# платье - платье
# ? - ?
# Она - она
# не - не
# удивилась - удивиться
# . - .
#
#
#  -
#
#
# – - –
# Оно - оно
# красивее - красивый
# . - .
# Меня - меня
# никто - никто
# не - не
# видит - видеть
# , - ,
# и - и
# потому - потому
# я - я
# забочусь - забочусь
# , - ,
# чтобы - чтобы
# я - я
# сама - сама
# себе - себя
# нравилась - нравиться
# . - .
#
#
#  -
#
#
# – - –
# И - и
# мне - мне
# нравится - нравиться
# , - ,
# – - –
# сказал - сказать
# я - я
# . - .
# – - –
# А - а
# как - как
# вас - вас
# зовут - звать
# ? - ?
#
#
#  -
#
#
# – - –
# Марта - марта
# . - .
#
#
#  -
#
#
# – - –
# Марта - марта
# ? - ?
# Разве - разве
# вы - вы
# не - не
# русская - русский
# ? - ?
#
#
#  -
#
#
# – - –
# Нет - нет
# , - ,
# русская - русский
# . - .
# Моя - мой
# фамилия - фамилия
# Коренева - коренев
# , - ,
# я - я
# живу - жить
# здесь - здесь
# с - с
# матерью - мать
# . - .
# Разве - разве
# вы - вы
# не - не
# слышали - слышать
# ? - ?
# Слепая - слепая
# Коренева - коренев
# ? - ?
# Богачка - богачка
# ? - ?
#
#
#  -
#
#
# Я - я
# вспомнил - вспомнить
# , - ,
# что - что
# точно - точно
# слышал - слышать
# что - что
# - - -
# то - то
# о - о
# слепой - слепой
# старухе - старухе
# Кореневой - коренев
# , - ,
# очень - очень
# богатой - богатый
# , - ,
# и - и
# о - о
# ее - её
# молоденькой - молоденький
# дочери - дочь
# , - ,
# которая - которая
# много - много
# учится - учиться
# и - и
# нигде - нигде
# не - не
# бывает - бывать
# . - .
#
#
#  -
#
#
# – - –
# Да - да
# , - ,
# я - я
# слышал - слышать
# , - ,
# – - –
# медленно - медленно
# проговорил - проговорить
# я - я
# . - .
# – - –
# Как - как
# странно - странный
# , - ,
# мы - мы
# соседи - сосед
# , - ,
# а - а
# я - я
# только - только
# теперь - теперь
# вас - вас
# вижу - видеть
# … - …
#
#
#  -
#
#
# – - –
# Я - я
# не - не
# люблю - любить
# выходить - выходить
# , - ,
# – - –
# поспешно - поспешно
# сказала - сказать
# она - она
# . - .
# – - –
# Да - да
# , - ,
# так - так
# вы - вы
# удивились - удивиться
# , - ,
# что - что
# я - я
# Марта - марта
# . - .
# Я - я
# – - –
# Марфа - марфа
# , - ,
# но - но
# Марта - марта
# красивее - красивый
# , - ,
# и - и
# потому - потому
# меня - меня
# так - так
# называют - называть
# . - .
#
#
#  -
#
#
# – - –
# Да - да
# … - …
# Вы - вы
# вообще - вообще
# красивы - красивый
# , - ,
# – - –
# сказал - сказать
# я - я
# в - в
# раздумьи - раздумьи
# , - ,
# почти - почти
# про - про
# себя - себя
# . - .
#
#
#  -
#
#
# – - –
# Правда - правда
# ? - ?
# – - –
# просто - просто
# ответила - ответить
# она - она
# . - .
# – - –
# Вот - вот
# я - я
# тоже - тоже
# нахожу - находить
# , - ,
# что - что
# я - я
# красива - красивый
# . - .
# А - а
# многие - многие
# говорят - говорить
# , - ,
# что - что
# нет - нет
# . - .
# Я - я
# думаю - думать
# , - ,
# что - что
# они - они
# не - не
# понимают - понимать
# . - .
#
#
#  -
#
#
# Меня - меня
# не - не
# удивлял - удивлять
# наш - наш
# разговор - разговор
# . - .
# Я - я
# не - не
# мог - мочь
# убедить - убедить
# себя - себя
# , - ,
# что - что
# Марта - марта
# – - –
# барышня - барышня
# , - ,
# а - а
# я - я
# ей - ей
# говорю - говорить
# комплименты - комплимент
# . - .
# Она - она
# казалась - казаться
# мне - мне
# красивой - красивый
# , - ,
# как - как
# небо - нёбо
# сквозь - сквозь
# деревья - дерево
# , - ,
# как - как
# нежный - нежный
# , - ,
# душистый - душистый
# воздух - воздух
# , - ,
# как - как
# розовые - розовый
# облака - облако
# около - около
# уходящего - уходить
# солнца - солнце
# . - .
# Она - она
# так - так
# подходила - подходить
# ко - ко
# всему - всему
# , - ,
# даже - даже
# к - к
# этому - этот
# предвечернему - предвечерний
# часу - час
# , - ,
# что - что
# мне - мне
# не - не
# хотелось - хотеться
# ни - ни
# разговаривать - разговаривать
# , - ,
# ни - ни
# удивляться - удивляться
# , - ,
# а - а
# просто - просто
# радоваться - радоваться
# всему - всему
# вместе - вместе
# . - .
#
#
#  -
#
#
# И - и
# она - она
# замолчала - замолчать
# . - .
#
#
#  -
#
#
# – - –
# Ну - ну
# , - ,
# теперь - теперь
# прощайте - прощать
# , - ,
# – - –
# сказала - сказать
# она - она
# наконец - наконец
# . - .
# – - –
# Вы - вы
# можете - мочь
# приходить - приходить
# сюда - сюда
# , - ,
# – - –
# прибавила - прибавить
# она - она
# чуть - чуть
# - - -
# чуть - чуть
# высокомерно - высокомерный
# , - ,
# но - но
# снисходительно - снисходительно
# . - .
# – - –
# Вы - вы
# не - не
# портите - портите
# сада - сад
# . - .
#
#
#  -
#
#
# И - и
# опять - опять
# я - я
# услышал - услышать
# связный - связный
# шорох - шорох
# ее - её
# платья - платье
# , - ,
# она - она
# ушла - уйти
# . - .
# Я - я
# не - не
# удивился - удивиться
# и - и
# ее - её
# последним - последний
# словам - слово
# : - :
# она - она
# думала - думать
# почти - почти
# о - о
# том - том
# же - же
# , - ,
# о - о
# чем - что
# я - я
# . - .
# Удивляешься - удивляешься
# тому - тому
# , - ,
# что - что
# еще - еще
# чуждо - чуждо
# , - ,
# что - что
# вне - вне
# тебя - тебя
# , - ,
# а - а
# ...
# белый - белый
# , - ,
# как - как
# маленькое - маленький
# облачко - облачко
# ? - ?
# Когда - когда
# он - он
# станет - стать
# светлеть - светлеть
# , - ,
# а - а
# небо - нёбо
# станет - стать
# выше - высоко
# – - –
# тогда - тогда
# они - они
# распустятся - распустятся
# . - .
#
#
#  -
#
#
# – - –
# Отчего - отчего
# вы - вы
# такая - такой
# , - ,
# Марта - марта
# ? - ?
# – - –
# спросил - спросить
# я - я
# . - .
# – - –
# Вы - вы
# точно - точно
# сами - сами
# с - с
# ними - ними
# . - .
#
#
#  -
#
#
# – - –
# А - а
# вы - вы
# разве - разве
# не - не
# такой - такой
# ? - ?
# И - и
# вы - вы
# такой - такой
# , - ,
# и - и
# вы - вы
# также - также
# любите - любить
# , - ,
# оттого - оттого
# я - я
# и - и
# рада - рад
# , - ,
# что - что
# вы - вы
# со - со
# мной - мной
# , - ,
# и - и
# люблю - любить
# вас - вас
# . - .
#
#
#  -
#
#
# – - –
# И - и
# я - я
# люблю - любить
# вас - вас
# , - ,
# Марта - марта
# , - ,
# – - –
# сказал - сказать
# я - я
# . - .
# – - –
# Как - как
# сад - сад
# , - ,
# как - как
# все - все
# . - .
#
#
#  -
#
#
# Она - она
# повторила - повторить
# : - :
# « - "
# как - как
# все - все
# » - "
# … - …
# и - и
# задумалась - задуматься
# . - .
#
#
#  -
#
#
# Короткие - короткий
# сумерки - сумерки
# пролетели - пролететь
# . - .
# Месяц - месяц
# сверкнул - сверкнуть
# и - и
# бросил - бросить
# робкий - робкий
# , - ,
# неумелый - неумелый
# и - и
# неясный - неясный
# свет - свет
# на - на
# дорожку - дорожка
# . - .
# Сильнее - сильнее
# запахло - запахнуть
# землей - земля
# и - и
# анемонами - анемон
# . - .
# Крепкие - крепкий
# ветки - ветка
# яблони - яблони
# кинули - кинуть
# тень - тень
# . - .
# И - и
# точно - точно
# все - все
# , - ,
# до - до
# тех - тот
# пор - пора
# безмолвное - безмолвный
# и - и
# неподвижное - неподвижный
# , - ,
# зашепталось - зашептаться
# и - и
# зашевелилось - зашевелиться
# . - .
# Чуть - чуть
# видный - видный
# , - ,
# почти - почти
# невидный - невидный
# , - ,
# пар - пар
# , - ,
# или - или
# дым - дым
# , - ,
# скользил - скользить
# по - по
# лунному - лунный
# свету - свет
# . - .
# Тени - тень
# набегали - набегать
# и - и
# сбегали - сбегать
# с - с
# цветов - цвет
# . - .
# Небо - небо
# вместе - вместе
# с - с
# месяцем - месяц
# становились - становиться
# все - все
# выше - высоко
# , - ,
# все - все
# дальше - дальше
# и - и
# холоднее - холодный
# . - .
#
#
#  -
#
#
# Мне - мне
# было - было
# страшно - страшный
# и - и
# жутко - жуткий
# . - .
# Я - я
# ждал - ждать
# чего - что
# - - -
# то - то
# , - ,
# весь - весь
# ушел - уйти
# в - в
# это - этот
# ожидание - ожидание
# . - .
# Марта - марта
# не - не
# смотрела - смотреть
# на - на
# меня - меня
# . - .
# Ей - ей
# было - было
# холодно - холодный
# . - .
# Она - она
# подвинулась - подвинуться
# ко - ко
# мне - мне
# , - ,
# я - я
# бессознательно - бессознательно
# обнял - обнять
# ее - ее
# , - ,
# просто - просто
# , - ,
# чтоб - чтоб
# быть - быть
# ближе - близкий
# и - и
# вместе - вместе
# ждать - ждать
# . - .
#
#
#  -
#
#
# – - –
# Надо - надо
# спокойнее - спокойный
# , - ,
# спокойнее - спокойный
# , - ,
# – - –
# проговорила - проговорить
# Марта - марта
# , - ,
# положив - положить
# бледную - бледный
# руку - рука
# на - на
# мою - мой
# . - .
# – - –
# Мы - мы
# не - не
# должны - должный
# волноваться - волноваться
# . - .
# Мы - мы
# должны - должный
# так - так
# тихо - тихо
# , - ,
# совсем - совсем
# тихо - тихо
# ждать - ждать
# . - .
# Без - без
# тишины - тишина
# в - в
# душе - душа
# нельзя - нельзя
# быть - быть
# близкими - близкий
# ей - ей
# . - .
#
#
#  -
#
#
# Я - я
# понял - понять
# , - ,
# что - что
# она - она
# хотела - хотеть
# сказать - сказать
# – - –
# « - "
# природе - природа
# » - "
# . - .
#
#
#  -
#
#
# – - –
# А - а
# мы - мы
# будем - будем
# близки - близкий
# , - ,
# правда - правда
# , - ,
# мы - мы
# будем - будем
# ? - ?
# – - –
# продолжала - продолжать
# она - она
# торопливо - торопливо
# , - ,
# заглядывая - заглядывать
# мне - мне
# в - в
# глаза - глаз
# . - .
# – - –
# И - и
# я - я
# , - ,
# и - и
# ты - ты
# , - ,
# мы - мы
# оба - оба
# – - –
# с - с
# ней - ней
# вместе - вместе
# … - …
#
#
#  -
#
#
# Никогда - никогда
# больше - больше
# , - ,
# никогда - никогда
# сильнее - сильнее
# я - я
# не - не
# чувствовал - чувствовать
# , - ,
# что - что
# я - я
# – - –
# « - "
# с - с
# ней - ней
# вместе - вместе
# » - "
# , - ,
# и - и
# что - что
# в - в
# этом - этот
# счастье - счастие
# , - ,
# если - если
# это - это
# может - мочь
# длиться - длиться
# . - .
#
#
#  -
#
#
# Какой - какой
# - - -
# то - то
# новый - новый
# , - ,
# неясный - неясный
# запах - запах
# дошел - дойти
# до - до
# нас - нас
# . - .
# Мы - мы
# оба - оба
# сразу - сразу
# его - его
# услышали - услышать
# и - и
# оба - оба
# вместе - вместе
# поняли - понять
# через - через
# минуту - минута
# , - ,
# откуда - откуда
# он - он
# . - .
#
#
#  -
#
#
# – - –
# Первый - первый
# цветок - цветок
# распустился - распустился
# , - ,
# – - –
# сказала - сказать
# Марта - марта
# . - .
# – - –
# Оставь - оставь
# , - ,
# не - не
# смотри - смотреть
# на - на
# него - него
# . - .
# Погоди - погоди
# , - ,
# сейчас - сейчас
# другие - другие
# … - …
#
#
#  -
#
#
# Она - она
# говорила - говорить
# шепотом - шёпот
# , - ,
# но - но
# торжественно - торжественно
# и - и
# серьезно - серьезно
# , - ,
# и - и
# крепче - крепче
# прижималась - прижималась
# ко - ко
# мне - мне
# . - .
# Я - я
# хотел - хотеть
# что - что
# - - -
# то - то
# сказать - сказать
# , - ,
# но - но
# она - она
# шепнула - шепнуть
# : - :
# « - "
# ни - ни
# слова - слово
# » - "
# … - …
# – - –
# и - и
# посмотрела - посмотреть
# умоляюще - умоляюще
# . - .
# Я - я
# замолчал - замолчать
# – - –
# и - и
# рад - рад
# был - был
# молчать - молчать
# . - .
# Мне - мне
# больше - больше
# ничего - ничто
# не - не
# хотелось - хотеться
# , - ,
# кроме - кроме
# того - того
# , - ,
# что - что
# было - быть
# . - .
# Я - я
# думаю - думать
# , - ,
# это - это
# и - и
# есть - есть
# счастье - счастие
# . - .
# Весь - весь
# сад - сад
# наполнялся - наполнялся
# новым - новый
# , - ,
# сильным - сильный
# ароматом - аромат
# . - .
# Месяц - месяц
# никнул - никнул
# и - и
# уходил - уходить
# с - с
# неба - нёбо
# , - ,
# но - но
# яблони - яблони
# не - не
# темнели - темнеть
# . - .
# Они - они
# были - были
# белые - белый
# не - не
# от - от
# лунного - лунный
# света - свет
# . - .
#
#
#  -
#
#
# Когда - когда
# прошло - пройти
# время - время
# , - ,
# и - и
# все - весь
# кругом - круг
# нас - нас
# стало - стать
# яснее - ясный
# и - и
# холоднее - холодный
# , - ,
# небо - нёбо
# позеленело - позеленело
# , - ,
# и - и
# утренние - утренний
# сумерки - сумерки
# спустились - спуститься
# , - ,
# – - –
# я - я
# взглянул - взглянуть
# близко - близко
# в - в
# лицо - лицо
# Марты - марта
# , - ,
# Марта - марта
# сидела - сидеть
# все - все
# в - в
# том - тот
# же - же
# положении - положение
# , - ,
# прижавшись - прижаться
# ко - ко
# мне - мне
# . - .
# Она - она
# подняла - поднять
# глаза - глаз
# и - и
# улыбнулась - улыбнуться
# . - .
#
#
#  -
#
#
# – - –
# Пора - пора
# , - ,
# – - –
# сказала - сказать
# она - она
# . - .
# – - –
# Сейчас - сейчас
# будет - будет
# солнце - солнце
# . - .
# Яблони - яблони
# цветут - цвести
# . - .
#
#
#  -
#
#
# Что - что
# - - -
# то - то
# ударило - ударить
# меня - меня
# в - в
# сердце - сердце
# . - .
# Я - я
# вспомнил - вспомнить
# . - .
# Я - я
# побледнел - побледнеть
# , - ,
# в - в
# груди - грудь
# стало - стать
# тяжело - тяжёлый
# и - и
# холодно - холодный
# . - .
# Марта - марта
# тревожно - тревожно
# взглянула - взглянуть
# . - .
#
#
#  -
#
#
# – - –
# Что - что
# с - с
# тобой - тобой
# ? - ?
#
#
#  -
#
#
# – - –
# Марта - марта
# . - .
# Я - я
# стал - стать
# несчастен - несчастный
# … - …
# Пожалей - пожалей
# меня - меня
# … - …
# Я - я
# уезжаю - уезжать
# … - …
#
#
#  -
#
#
# – - –
# Уезжаешь - уезжать
# ? - ?
# – - –
# проговорила - проговорить
# она - она
# медленно - медленно
# , - ,
# без - без
# удивленья - удивление
# . - .
# – - –
# Так - так
# рано - рано
# ? - ?
# Подожди - подождать
# . - .
# Еще - еще
# есть - быть
# время - время
# . - .
# Подожди - подождать
# , - ,
# пока - пока
# они - они
# начнут - начать
# осыпаться - осыпаться
# . - .
#
#
#  -
#
#
# – - –
# Не - не
# могу - мочь
# , - ,
# не - не
# могу - мочь
# … - …
# Я - я
# не - не
# сам - сам
# … - …
# меня - меня
# … - …
#
#
#  -
#
#
# – - –
# Ах - ах
# , - ,
# другие - другие
# , - ,
# – - –
# сказала - сказать
# она - она
# спокойно - спокойно
# . - .
# – - –
# Они - они
# всегда - всегда
# мешают - мешать
# , - ,
# всегда - всегда
# , - ,
# во - во
# всем - всем
# . - .
# Ступай - ступай
# , - ,
# не - не
# будь - будь
# несчастен - несчастный
# . - .
# Только - только
# я - я
# не - не
# хотела - хотеть
# так - так
# рано - рано
# … - …
#
#
#  -
#
#
# Я - я
# с - с
# тоской - тоска
# взглянул - взглянуть
# в - в
# ее - её
# глаза - глаз
# . - .
# Они - они
# были - были
# широко - широко
# раскрыты - раскрыть
# и - и
# покойны - покойный
# , - ,
# только - только
# совсем - совсем
# , - ,
# до - до
# краев - край
# , - ,
# полны - полный
# слезами - слеза
# . - .
# Казалось - казаться
# , - ,
# если - если
# она - она
# чуть - чуть
# пошевельнет - пошевельнуть
# ресницами - ресница
# или - или
# переведет - перевести
# взгляд - взгляд
# , - ,
# слезы - слеза
# прольются - прольются
# . - .
#
#
#  -
#
#
# Я - я
# встал - встать
# . - .
# Она - она
# осталась - остаться
# на - на
# скамейке - скамейка
# и - и
# не - не
# смотрела - смотреть
# на - на
# меня - меня
# . - .
#
#
#  -
#
#
# – - –
# Прощай - прощать
# , - ,
# Марта - марта
# , - ,
# – - –
# сказал - сказать
# я - я
# . - .
#
#
#  -
#
#
# – - –
# Прощай - прощать
# . - .
# Ты - ты
# не - не
# забудь - забудь
# … - …
#
#
#  -
#
#
# – - –
# Чего - что
# ? - ?
#
#
#  -
#
#
# – - –
# Всего - всего
# . - .
# Я - я
# не - не
# забуду - забыть
# . - .
# Мы - мы
# оба - оба
# теперь - теперь
# знаем - знать
# , - ,
# как - как
# нужно - нужный
# жить - жить
# . - .
#
#
#  -
#
#
# – - –
# Марта - марта
# ! - !
# Но - но
# ведь - ведь
# другие - другие
# … - …
#
#
#  -
#
#
# – - –
# Да - да
# , - ,
# другие - другие
# ! - !
# А - а
# ты - ты
# не - не
# можешь - мочь
# , - ,
# ты - ты
# не - не
# сумеешь - суметь
# … - …
# Все - все
# - - -
# таки - таки
# не - не
# забудь - забудь
# . - .
#
#
#  -
#
#
# Я - я
# взглянул - взглянуть
# на - на
# нее - нее
# , - ,
# на - на
# зеленое - зелёный
# , - ,
# совсем - совсем
# светлое - светлый
# , - ,
# небо - нёбо
# , - ,
# яблони - яблони
# , - ,
# точно - точно
# осыпанные - осыпать
# снегом - снег
# , - ,
# и - и
# сказал - сказать
# : - :
#
#
#  -
#
#
# – - –
# Не - не
# забуду - забыть
# . - .
# Прощай - прощать
# . - .
#
#
#  -
#
#
# Она - она
# кивнула - кивнуть
# мне - мне
# головой - голов
# . - .
# Я - я
# ушел - уйти
# . - .
#
#
#  -
#
#
# X - x
#
#  -
#
# Что - что
# случилось - случиться
# дальше - дальше
# – - –
# я - я
# расскажу - рассказать
# коротко - коротко
# и - и
# скоро - скоро
# , - ,
# мне - мне
# слишком - слишком
# тяжело - тяжёлый
# . - .
# Она - она
# , - ,
# мама - мама
# , - ,
# сделала - сделать
# все - все
# нарочно - нарочно
# , - ,
# чтобы - чтобы
# отомстить - отомстить
# мне - мне
# , - ,
# я - я
# знаю - знать
# . - .
# Правда - правда
# , - ,
# она - она
# сама - сама
# в - в
# эту - этот
# ночь - ночь
# похудела - похудеть
# и - и
# осунулась - осунуться
# , - ,
# но - но
# я - я
# думаю - думать
# , - ,
# от - от
# сильной - сильный
# ненависти - ненависть
# ко - ко
# мне - мне
# . - .
# Все - все
# тут - тут
# сошлось - сойтись
# . - .
# Да - да
# я - я
# и - и
# знал - знать
# , - ,
# что - что
# она - она
# не - не
# простит - простить
# . - .
# Она - она
# не - не
# могла - мочь
# простить - простить
# . - .
# Я - я
# и - и
# не - не
# говорил - говорить
# ей - ей
# ничего - ничто
# . - .
# Я - я
# был - был
# , - ,
# как - как
# мертвый - мёртвый
# . - .
# Если - если
# б - б
# она - она
# велела - велеть
# мне - мне
# взять - взять
# револьвер - револьвер
# и - и
# застрелиться - застрелиться
# – - –
# я - я
# бы - бы
# , - ,
# молча - молча
# , - ,
# взял - взять
# револьвер - револьвер
# и - и
# застрелился - застрелиться
# . - .
# Она - она
# велела - велеть
# мне - мне
# уехать - уехать
# одному - одному
# , - ,
# сказала - сказать
# , - ,
# что - что
# никогда - никогда
# не - не
# увидит - увидеть
# меня - меня
# и - и
# не - не
# простит - простить
# . - .
# Но - но
# я - я
# думаю - думать
# , - ,
# она - она
# чувствовала - чувствовать
# , - ,
# что - что
# не - не
# выдержит - выдержать
# и - и
# простит - простить
# , - ,
# когда - когда
# увидит - увидеть
# , - ,
# что - что
# я - я
# не - не
# могу - мочь
# жить - жить
# ; - ;
# поэтому - поэтому
# , - ,
# чтобы - чтобы
# не - не
# изменить - изменить
# себе - себя
# , - ,
# она - она
# умерла - умереть
# нарочно - нарочно
# . - .
# Да - да
# , - ,
# да - да
# , - ,
# я - я
# не - не
# сомневаюсь - сомневаться
# , - ,
# что - что
# она - она
# это - это
# сделала - сделать
# нарочно - нарочно
# . - .
# Доктора - доктор
# говорят - говорить
# , - ,
# что - что
# у - у
# нее - нее
# был - быть
# дифтерит - дифтерит
# , - ,
# но - но
# что - что
# ж - ж
# из - из
# этого - это
# ? - ?
# Дифтерит - дифтерит
# мог - мочь
# быть - быть
# , - ,
# а - а
# все - все
# - - -
# таки - таки
# она - она
# бы - бы
# верно - верно
# не - не
# умерла - умереть
# , - ,
# если - если
# б - б
# сильно - сильно
# хотела - хотеть
# не - не
# умереть - умереть
# . - .
# Я - я
# приехал - приехать
# из - из
# Москвы - москва
# на - на
# третий - третий
# день - день
# после - после
# смерти - смерть
# . - .
# Она - она
# уже - уже
# стала - стать
# разлагаться - разлагаться
# . - .
# Такой - такой
# уксусный - уксусный
# и - и
# страшный - страшный
# запах - запах
# шел - идти
# от - от
# нее - нее
# . - .
# Я - я
# посмотрел - посмотреть
# ей - ей
# в - в
# лицо - лицо
# и - и
# ничего - ничто
# не - не
# сказал - сказать
# . - .
#
#
#  -
#
#
# Какой - какой
# - - -
# то - то
# господин - господин
# подошел - подойти
# ко - ко
# мне - мне
# , - ,
# долго - долго
# жал - жать
# руку - рука
# , - ,
# просил - просить
# подкрепиться - подкрепиться
# и - и
# сказал - сказать
# : - :
#
#
#  -
#
#
# – - –
# Да - да
# , - ,
# ваша - ваш
# матушка - матушка
# была - была
# удивительная - удивительный
# женщина - женщина
# . - .
# Как - как
# вы - вы
# должны - должный
# быть - быть
# потрясены - потрясти
# ! - !
# У - у
# вас - вас
# были - были
# с - с
# нею - нею
# удивительные - удивительный
# отношения - отношение
# … - …
#
#
#  -
#
#
# Я - я
# неестественно - неестественно
# рассмеялся - рассмеяться
# и - и
# сказал - сказать
# : - :
#
#
#  -
#
#
# – - –
# Да - да
# , - ,
# да - да
# , - ,
# вы - вы
# правы - правый
# … - …
#
#
#  -
#
#
# И - и
# сам - сам
# пожал - пожать
# руку - рука
# господину - господин
# . - .
#
#
#  -
#
#
# Потом - потом
# ее - ее
# похоронили - похоронить
# , - ,
# и - и
# я - я
# уехал - уехать
# . - .
# Зачем - зачем
# бы - бы
# я - я
# там - там
# остался - остаться
# ? - ?
# О - о
# Марте - март
# я - я
# не - не
# спросил - спросить
# , - ,
# в - в
# сад - сад
# не - не
# заходил - заходить
# … - …
#
#
#  -
#
#
# И - и
# прошло - пройти
# сколько - сколько
# - - -
# то - то
# лет - год
# . - .
# Я - я
# не - не
# помню - помнить
# теперь - теперь
# хорошо - хороший
# – - –
# сколько - сколько
# . - .
# Я - я
# не - не
# помню - помнить
# , - ,
# как - как
# я - я
# жил - жить
# . - .
# Я - я
# все - все
# стал - стать
# забывать - забывать
# . - .
# Порой - порой
# , - ,
# впрочем - впрочем
# , - ,
# я - я
# вспоминаю - вспоминать
# ту - тот
# ночь - ночь
# , - ,
# когда - когда
# распускались - распускались
# яблони - яблони
# . - .
# Сажусь - сажусь
# за - за
# рояль - рояль
# и - и
# играю - играть
# маленькую - маленький
# песенку - песенка
# : - :
# « - "
# ни - ни
# слова - слово
# , - ,
# о - о
# друг - друг
# мой - мой
# » - "
# … - …
# Мне - мне
# делается - делаться
# светлее - светлее
# . - .
#
#
#  -
#
#
# Но - но
# это - это
# редко - редко
# ; - ;
# я - я
# редко - редко
# могу - мочь
# вспоминать - вспоминать
# … - …
# И - и
# с - с
# каждым - каждый
# часом - час
# прибавляется - прибавляться
# тяжесть - тяжесть
# жизни - жизнь
# . - .
# Я - я
# живу - жить
# , - ,
# потому - потому
# что - что
# не - не
# имею - иметь
# силы - сила
# даже - даже
# умереть - умереть
# . - .
# Живу - жить
# в - в
# Петербурге - петербург
# , - ,
# один - один
# , - ,
# в - в
# темной - тёмный
# и - и
# пропахшей - пропахшей
# кухней - кухня
# квартире - квартира
# , - ,
# даю - давать
# свои - свой
# ненужные - ненужный
# уроки - урок
# музыки - музыка
# и - и
# ненужно - ненужно
# возвращаюсь - возвращаться
# домой - домой
# . - .
# Сколько - сколько
# времени - время
# это - это
# еще - еще
# будет - будет
# продолжаться - продолжаться
# ? - ?
#
#
#  -
#
#
# Посредине - посредине
# потолка - потолок
# , - ,
# в - в
# большой - большой
# комнате - комната
# , - ,
# есть - быть
# крюк - крюк
# … - …
# Я - я
# уж - уж
# говорил - говорить
# о - о
# нем - нем
# . - .
# Так - так
# вот - вот
# мне - мне
# приходит - приходить
# мысль - мысль
# : - :
# что - что
# , - ,
# если - если
# я - я
# принесу - принесу
# из - из
# передней - передний
# веревку - верёвка
# от - от
# чемодана - чемодан
# и - и
# закину - закину
# ее - ее
# на - на
# крюк - крюк
# ? - ?
# Ведь - ведь
# никто - никто
# даже - даже
# и - и
# не - не
# узнает - узнавать
# , - ,
# особенно - особенно
# теперь - теперь
# , - ,
# ночью - ночь
# … - …
# Старуха - старуха
# , - ,
# моя - мой
# кухарка - кухарка
# , - ,
# спит - спать
# . - .
# И - и
# главное - главный
# , - ,
# ничего - ничто
# не - не
# сделается - сделаться
# от - от
# того - того
# , - ,
# что - что
# я - я
# закину - закинуть
# веревку - верёвка
# на - на
# крюк - крюк
# . - .
# Ее - ее
# можно - можно
# снять - снять
# и - и
# снести - снести
# обратно - обратно
# в - в
# переднюю - передний
# . - .
# Даже - даже
# если - если
# я - я
# петлю - петлю
# сделаю - сделать
# – - –
# и - и
# то - то
# ничего - ничто
# ровно - ровно
# не - не
# случится - случиться
# , - ,
# ведь - ведь
# не - не
# повешусь - повеситься
# же - же
# , - ,
# ведь - ведь
# не - не
# должен - должный
# же - же
# я - я
# , - ,
# оттого - оттого
# что - что
# сделаю - сделать
# петлю - петля
# , - ,
# непременно - непременно
# повеситься - повеситься
# ? - ?
# Это - это
# так - так
# ужасно - ужасный
# , - ,
# так - так
# некрасиво - некрасивый
# … - …
# Как - как
# я - я
# далеко - далеко
# от - от
# Марты - марта
# ! - !
# .. - ..
# Но - но
# разве - разве
# я - я
# в - в
# самом - самом
# деле - дело
# ? - ?
# .. - ..
# Нет - нет
# , - ,
# нет - нет
# , - ,
# я - я
# только - только
# попробую - попробую
# , - ,
# никто - никто
# не - не
# узнает - узнавать
# , - ,
# а - а
# я - я
# попробую - попробовать
# … - …
