# %% [markdown]
# # TF-IDF with HathiTrust Data

# %% [markdown]
# In this lesson, we're going to learn about a text analysis method called *term frequency–inverse document frequency*, often abbreviated *tf-idf*.
#
# While calculating the most frequent words in a text can be useful, the most frequent words in a text usually aren't the most interesting words in a text, even if we get rid of stop words ("the, "and," "to," etc.). Tf-idf is a method that builds off word frequency but it more specifically tries to identify rare or unique words.
#
# In this lesson, we will cover how to:
# - Calculate and normalize tf-idf scores for each short story in Edward P. Jones's *Lost in the City*
# - Download and process HathiTrust extracted features — that is, word frequencies for books in the HathiTrust Digital Library (including in-copyright books like *Lost in the City*)
# - Prepare HathiTrust extracted features for tf-idf analysis

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### *Lost in the City* by Edward P. Jones
#
# ```{epigraph}
#  [T]he pigeon had taken a step and dropped from the ledge. He caught an upwind that took him nearly as high as the tops of the empty K Street houses. He flew farther into Northeast, into the color and sounds of the city's morning. She did nothing, aside from following him, with her eyes, with her heart, as far as she could.
#
# --  Edward P. Jones, "The Girl Who Raised Pigeons," *Lost in the City* (1993)
# ```

# %% [markdown]
# Edward P. Jones's *Lost in the City* (1993) is a collection of 14 short stories set in Washington D.C. The first short story, "The Girl Who Raised Pigeons," begins with a young girl raising homing pigeons on her roof.
#
# How rare is a "pigeon" in the world of *Lost in the City*? What does this rarity (or lackthereof) tell us about the meaning of pigeons in first short story "The Girl Who Raised Pigeons" and the collection as a whole? These are just a few of the questions that we're going to try to answer with tf-idf.

# %% [markdown]
# If you already have a collection of plain text (.txt) files that you'd like to analyze, one of the easiest ways to calculate tf-idf scores is to use the Python library scikit-learn. It has a quick and nifty module called [TfidfVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html), which does all the math for you behind the scenes. We will cover how to use the TfidfVectorizer in the next lesson.
#
# In this lesson, however, we're going to calculate tf-idf scores manually because *Lost in the City* is still in-copyright, which means that, for legal reasons, we can't easily share or access plain text files of the book.
#
# Luckily, the [HathiTrust Digital Library](https://www.hathitrust.org/)—which contains digitized books from Google Books as well as many university libraries—has released word frequencies per page for all 17 million books in its catalog. These word frequencies (plus part of speech tags) are otherwise known as "extracted features." There's a lot of text analysis that we can do with extracted features alone, including tf-idf.
#
# So to calculate tf-idf scores for *Lost in the City*, we're going to use HathiTrust extracted features. That's why we're not using sci-kit learn's TfidfVectorizer. It works great with plain text files but not so great with extracted features.

# %% [markdown]
# ## Breaking Down the TF-IDF Formula

# %% [markdown]
# But first, let's quickly discuss the tf-idf formula. The idea is pretty simple.

# %% [markdown]
# **tf-idf = term_frequency * inverse_document_frequency**

# %% [markdown]
# **term_frequency** = number of times a given term appears in document

# %% [markdown]
# **inverse_document_frequency** = log(total number of documents / number of documents with term) + 1**\***

# %% [markdown]
# You take the number of times a term occurs in a document (term frequency). Then you take the number of documents in which the same term occurs at least once divided by the total number of documents (document frequency), and you flip that fraction on its head (inverse document frequency). Then you multiply the two numbers together (term_frequency * inverse_document_frequency).
#
# The reason we take the *inverse*, or flipped fraction, of document frequency is to boost the rarer words that occur in relatively few documents. Think about the inverse document frequency for the word "said" vs the word "pigeon." The term "said" appears in 13 (document frequency) of 14 (total documents) *Lost in the City* stories (14 / 13 --> a smaller inverse document frequency) while the term "pigeons" only occurs in 2 (document frequency) of the 14 stories (total documents) (14 / 2 --> a bigger inverse document frequency, a bigger tf-idf boost).

# %% [markdown]
# *There are a bunch of slightly different ways that you can calculate inverse document frequency. The version of idf that we're going to use is the [scikit-learn default](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer), which uses "smoothing" aka it adds a "1" to the numerator and denominator:

# %% [markdown]
# **inverse_document_frequency**  = log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %% [markdown]
# ```{margin}
# > If smooth_idf=True (the default), the constant “1” is added to the numerator and denominator of the idf as if an extra document was seen containing every term in the collection exactly once, which prevents zero divisions: idf(t) = log [ (1 + n) / (1 + df(t)) ] + 1.
# > -[scikit-learn documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer)
# ```

# %% [markdown]
# ### Let's test it out

# %% [markdown]
# We need the `log()` function for our calculation, otherwise known as [logarithm](https://en.wikipedia.org/wiki/Logarithm), so we're going to import the `numpy` package.

# %%
import numpy as np

# %% [markdown]
# **"said"**

# %%
total_number_of_documents = 14 ##total number of short stories in *Lost in the City*
number_of_documents_with_term = 13 ##number of short stories the contain the word "said"

# %%
term_frequency = 47 ##number of times "said" appears in "The Girl Who Raised Pigeons"
inverse_document_frequency = np.log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %%
term_frequency * inverse_document_frequency
# Out:
# 50.24266495988672

# %% [markdown]
# **"pigeons"**

# %%
total_number_of_documents = 14 ##total number of short stories in *Lost in the City*
number_of_documents_with_term = 2 ##number of short stories the contain the word "pigeons"

# %%
term_frequency = 30 ##number of times "pigeons" appears in "The Girl Who Raised Pigeons"
inverse_document_frequency = np.log((1 + total_number_of_documents) / (number_of_documents_with_term +1)) + 1

# %%
term_frequency * inverse_document_frequency
# Out:
# 78.28313737302301

# %% [markdown]
# **tf–idf scores for "The Girl Who Raised Pigeons"**
#
# "said" = 50.48<br>
# "pigeons" = 78.28

# %% [markdown]
# Though the word "said" appears 47 times in "The Girl Who Raised Pigeons" and the word "pigeons" only appears 30 times, "pigeons" has a higher tf–idf score than "said" because it's a rarer word. The word "pigeons" appears in 2 of 14 stories, while "said" appears in 13 of 14 stories, almost all of them.

# %% [markdown]
# ## Get HathiTrust Extracted Features

# %% [markdown]
# Now let's try to calculate tf-idf scores for all the words in all the short stories in *Lost in the City*. To do so, we need word counts, or HathiTrust extracted features, for each story in the collection.

# %% [markdown]
# To work with HathiTrust's extracted features, we first need to install and import the [HathiTrust Feature Reader](https://github.com/htrc/htrc-feature-reader).

# %% [markdown]
# Install HathiTrust Feature Reader

# %%
# !pip install htrc-feature-reader

# %% [markdown]
# Import necessary libraries

# %%
from htrc_features import Volume
import pandas as pd

# %% [markdown]
# Then we need to locate the the HathiTrust volume ID for *Lost in the City*. If we search the HathiTrust catalog for this book and then click on "Limited (search only)," it will take us to the following web page: https://babel.hathitrust.org/cgi/pt?id=mdp.39015029970129.
#
# The HathiTrust Volume ID for *Lost in the City* is located after `id=` this URL: `mdp.39015029970129`.

# %% [markdown]
# ### Make DataFrame of Word Frequencies From Volume(s)

# %% [markdown]
# #### Single Volume

# %% [markdown]
# To get HathiTrust extracted features for a single volume, we can create a `[Volume` object](https://github.com/htrc/htrc-feature-reader#volume) and use the `.tokenlist()` method.

# %%
Volume('mdp.39015029970129').tokenlist()
# Out:
#                           count
# page section token   pos
# 1    body    ,       ,        1
#              .046    CD       1
#              1993    CD       1
#              3560    CD       1
#              AWARD   NN       1
# ...                         ...
# 260  body    world   NN       2
#              would   MD       1
#              writers NNS      1
#              written VBN      1
#              •       SYM      1
#
# [51297 rows x 1 columns]

# %% [markdown]
# For each page in *Lost in the City*, this DataFrame displays the page number and section type as well as every word/token that appears on the page, its part-of-speech, and the number of times that word/token occurs on the page. As you can see, there are 51,297 rows in this DataFrame — one for each token that appears on each page.
#
# Let's look at a sample of just 20 words from page 11.

# %%
Volume('mdp.39015029970129').tokenlist()[500:520]
# Out:
#                                    count
# page section token            pos
# 11   body    out              RP       1
#              over             IN       1
#              part             NN       1
#              past             IN       1
#              pee              VB       1
#              pigeon           NN       1
#              pigeons          NNS      1
#              reach            VB       1
#              remained         VBD      1
#              roof             NN       1
#              room             NN       2
#              say              VB       1
#              seemed           VBD      1
#              set              VBN      1
#              share            VB       1
#              she              PRP      7
#              silenccBometimes NNS      1
#              silence          NN       1
#              simple           JJ       1
#              slats            NNS      1

# %% [markdown]
# We can also get metadata for a HathiTrust volume by asking for [certain attributes](https://github.com/htrc/htrc-feature-reader#volume).

# %%
Volume('mdp.39015029970129').year
# Out:
# 1993

# %%
Volume('mdp.39015029970129').page_count
# Out:
# 260

# %%
Volume('mdp.39015029970129').publisher
# Out:
# 'HarperPerennial'

# %% [markdown]
# #### Multiple Volumes

# %% [markdown]
# We might want to get extracted features for multiple volumes at the same time, so we're also going to practice a workflow that will allow us to read in multiple HathiTrust books, even though we're only reading in one book at this moment.

# %% [markdown]
# Insert list of desired HathiTrust volume(s)

# %%
volume_ids = ['mdp.39015029970129']

# %% [markdown]
# Loop through this list of volume IDs and make a DataFrame that includes extracted features, book title, and publication year, then make a list of all DataFrames.

# %%
all_tokens = []

for hathi_id in volume_ids:
    
    #Read in HathiTrust volume
    volume = Volume(hathi_id)
    
    #Make dataframe from token list -- do not include part of speech, sections, or case sensitivity
    token_df = volume.tokenlist(case=False, pos=False, drop_section=True)
    
    #Add book column
    token_df['book'] = volume.title
    
    #Add publication year column
    token_df['year'] = volume.year
    
    all_tokens.append(token_df)

# %% [markdown]
# Concatenate the list of DataFrames

# %%
lost_df = pd.concat(all_tokens)

# %% [markdown]
# Preview the DataFrame

# %%
lost_df
# Out:
#                 count                          book  year
# page lowercase
# 1    ,              1  Lost in the city : stories /  1993
#      .046           1  Lost in the city : stories /  1993
#      1993           1  Lost in the city : stories /  1993
#      3560           1  Lost in the city : stories /  1993
#      a              1  Lost in the city : stories /  1993
# ...               ...                           ...   ...
# 260  would          1  Lost in the city : stories /  1993
#      writers        1  Lost in the city : stories /  1993
#      written        1  Lost in the city : stories /  1993
#      york           1  Lost in the city : stories /  1993
#      •              1  Lost in the city : stories /  1993
#
# [47307 rows x 3 columns]

# %% [markdown]
# Change from multi-level index to regular index with `reset_index()`

# %%
lost_df_flattened = lost_df.reset_index()

# %%
lost_df_flattened
# Out:
#        page lowercase  count                          book  year
# 0         1         ,      1  Lost in the city : stories /  1993
# 1         1      .046      1  Lost in the city : stories /  1993
# 2         1      1993      1  Lost in the city : stories /  1993
# 3         1      3560      1  Lost in the city : stories /  1993
# 4         1         a      1  Lost in the city : stories /  1993
# ...     ...       ...    ...                           ...   ...
# 47302   260     would      1  Lost in the city : stories /  1993
# 47303   260   writers      1  Lost in the city : stories /  1993
# 47304   260   written      1  Lost in the city : stories /  1993
# 47305   260      york      1  Lost in the city : stories /  1993
# 47306   260         •      1  Lost in the city : stories /  1993
#
# [47307 rows x 5 columns]

# %% [markdown]
# Nice! We now have a DataFrame of word counts per page for *Lost in the City*.
#
# But what we need to move forward with tf-idf is a way of splitting this collection into its individual stories. Remember: to use tf-idf, we need a *collection* of texts because we need to compare word frequency for one document with all the other documents in the collection.

# %% [markdown]
# ## Add story titles

# %% [markdown]
# How can we split up *Lost in the City* into individual stories?
#
# Sometimes HathiTrust Extracted Features helpfully include "section" information for a book, such as chapter titles. Unfortunately, the extracted features for *Lost in the City* do not include chapter or story titles.
#
# They do, however, include page numbers and, if you ask for it, words with case sensitivity turned on (lowercase, uppercase, title case). When I manually combed through the HTRC token list with case sensitivity turned on, I noticed that the title page for each short story seemed to format the title in all-caps. So I searched for all-caps words from the story titles and noted down the page number. This should give us a marker (at an least approximate one) of where every story begins and ends.

# %% [markdown]
# The function below will add in *Lost in the City*'s story titles for the correct page numbers and corresponding words.

# %%
def add_story_titles(page):
    if page >= 0 and page < 11:
        return "Front Matter"
    if page >= 11 and page < 35:
        return "01: The Girl Who Raised Pigeons"
    elif page >= 35 and page < 41:
        return "02: The First Day"
    elif page >= 41 and page < 63:
        return "03: The Night Rhonda Ferguson Was Killed"
    elif page >= 63 and page < 85:
        return "04: Young Lions"
    elif page >= 85 and page < 113:
        return "05: The Store"
    elif page >= 113 and page < 125:
        return "06: An Orange Line Train to Ballston"
    elif page >= 125 and page < 149:
        return "07: The Sunday Following Mother's Day"
    elif page >= 149 and page < 159:
        return "08: Lost in the City"
    elif page >= 159 and page < 184:
        return "09: His Mother's House"
    elif page >= 184 and page < 191:
        return "10: A Butterfly on F Street"
    elif page >= 191 and page < 209:
        return "11: Gospel"
    elif page >= 209 and page < 225:
        return "12: A New Man"
    elif page >= 225 and page < 237:
        return "13: A Dark Night"
    elif page >= 237 and page <= 252:
        return "14: Marie"
    elif page > 252:
        return "Back Matter"

# %% [markdown]
# Below we add a new column of story titles to the DataFrame by `apply()`ing our function to the "page" column and dumping the results to `lost_df_flattened['story']`. You can read more about applying functions in ["Pandas Basics - Part 3"](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Analysis/Pandas-Basics-Part3.html#applying-functions).

# %%
lost_df_flattened['story'] = lost_df_flattened['page'].apply(add_story_titles)

# %% [markdown]
# ## Sum Word Counts For Each Story

# %% [markdown]
# Page-level information is great! But for tf-idf purposes, we really only care about the frequency of words for every story. Below we group by story and calculate the sum of word frequencies for every page in that story.

# %%
lost_df_flattened.groupby(['story', 'lowercase'])[['count']].sum().reset_index()
# Out:
#                                  story lowercase  count
# 0      01: The Girl Who Raised Pigeons         !      8
# 1      01: The Girl Who Raised Pigeons         '      4
# 2      01: The Girl Who Raised Pigeons        ''    111
# 3      01: The Girl Who Raised Pigeons        'd      1
# 4      01: The Girl Who Raised Pigeons       'll      5
# ...                                ...       ...    ...
# 18656                     Front Matter         ©      4
# 18657                     Front Matter         °      1
# 18658                     Front Matter         •      2
# 18659                     Front Matter      •*♦:      1
# 18660                     Front Matter         ■     14
#
# [18661 rows x 3 columns]

# %% [markdown]
# Notice how the "page" column no longer exists in the DataFrame and our rows have slimmed down from more than 40,000 to 18,000.

# %%
word_frequency_df = lost_df_flattened.groupby(['story', 'lowercase'])[['count']].sum().reset_index()

# %% [markdown]
# ## Remove Infrequent Words, Stopwords, & Punctuation

# %% [markdown]
# We will conclude with some final pre-processing steps. We will remove the list of stopwords defined below.

# %% [markdown]
# Make list of stopwords

# %%
STOPS = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours',
         'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers',
         'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves',
         'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are',
         'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does',
         'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
         'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into',
         'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down',
         'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here',
         'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',
         'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so',
         'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 've', 'll', 'amp', "!"]

# %% [markdown]
# Remove stopwords

# %%
word_frequency_df = word_frequency_df.drop(word_frequency_df[word_frequency_df['lowercase'].isin(STOPS)].index)

# %% [markdown]
# We will also remove punctuation.

# %%
word_frequency_df = word_frequency_df.drop(word_frequency_df[word_frequency_df['lowercase'].str.contains('[^A-Za-z\s]', regex=True)].index)

# %%
#Remove words that appear less than 5 times in a book
#word_frequency_df_test = word_frequency_df[word_frequency_df['count'] > 5]

# %%
word_frequency_df
# Out:
#                                  story  lowercase  count
# 36     01: The Girl Who Raised Pigeons  abandoned      2
# 37     01: The Girl Who Raised Pigeons       able      2
# 40     01: The Girl Who Raised Pigeons   absently      1
# 41     01: The Girl Who Raised Pigeons   absolute      1
# 42     01: The Girl Who Raised Pigeons   accepted      1
# ...                                ...        ...    ...
# 18648                     Front Matter    without      1
# 18649                     Front Matter      words      2
# 18650                     Front Matter      write      1
# 18651                     Front Matter    written      1
# 18652                     Front Matter       york      2
#
# [16074 rows x 3 columns]

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# Let's rename the columns so that they're consistent with the tf-idf vocabulary that we've been using.

# %%
word_frequency_df = word_frequency_df.rename(columns={'lowercase': 'term','count': 'term_frequency'})

# %%
word_frequency_df
# Out:
#                                  story       term  term_frequency
# 36     01: The Girl Who Raised Pigeons  abandoned               2
# 37     01: The Girl Who Raised Pigeons       able               2
# 40     01: The Girl Who Raised Pigeons   absently               1
# 41     01: The Girl Who Raised Pigeons   absolute               1
# 42     01: The Girl Who Raised Pigeons   accepted               1
# ...                                ...        ...             ...
# 18648                     Front Matter    without               1
# 18649                     Front Matter      words               2
# 18650                     Front Matter      write               1
# 18651                     Front Matter    written               1
# 18652                     Front Matter       york               2
#
# [16074 rows x 3 columns]

# %% [markdown]
# ### Calculate Document Frequency

# %% [markdown]
# To calculate the number of documents or stories each term appears, we're going to do some Pandas manipulation and calculation.

# %%
document_frequency_df = (word_frequency_df.groupby(['story','term']).size().unstack()).sum().reset_index()

# %% [markdown]
# If you inspect parts of the complex chain of Pandas methods above (which is always a great way to learn!), you will see that we're momentarily reshaping the DataFrame to see if the terms appear in each story...

# %%
word_frequency_df.groupby(['story','term']).size().unstack()
# Out:
# term                                      abandoned  abhored  abide  ability  \
# story
# 01: The Girl Who Raised Pigeons                 1.0      NaN    NaN      NaN
# 02: The First Day                               NaN      NaN    NaN      NaN
# 03: The Night Rhonda Ferguson Was Killed        NaN      NaN    NaN      NaN
# 04: Young Lions                                 NaN      NaN    NaN      NaN
# 05: The Store                                   NaN      NaN    NaN      1.0
# 06: An Orange Line Train to Ballston            NaN      NaN    NaN      NaN
# 07: The Sunday Following Mother's Day           1.0      1.0    1.0      NaN
# 08: Lost in the City                            NaN      NaN    NaN      NaN
# 09: His Mother's House                          1.0      NaN    NaN      NaN
# 10: A Butterfly on F Street                     NaN      NaN    NaN      NaN
# 11: Gospel                                      NaN      NaN    NaN      NaN
# 12: A New Man                                   NaN      NaN    NaN      NaN
# 13: A Dark Night                                NaN      NaN    NaN      NaN
# 14: Marie                                       NaN      NaN    NaN      NaN
# Back Matter                                     NaN      NaN    NaN      NaN
# Front Matter                                    NaN      NaN    NaN      NaN
#
# term                                      able  abomination  aboum  \
# story
# 01: The Girl Who Raised Pigeons            1.0          NaN    NaN
# 02: The First Day                          NaN          NaN    NaN
# 03: The Night Rhonda Ferguson Was Killed   1.0          NaN    NaN
# 04: Young Lions                            1.0          NaN    1.0
# 05: The Store                              1.0          1.0    NaN
# 06: An Orange Line Train to Ballston       1.0          NaN    NaN
# 07: The Sunday Following Mother's Day      1.0          NaN    NaN
# 08: Lost in the City                       NaN          NaN    NaN
# 09: His Mother's House                     1.0          NaN    NaN
# 10: A Butterfly on F Street                1.0          NaN    NaN
# 11: Gospel                                 1.0          NaN    NaN
# 12: A New Man                              1.0          NaN    NaN
# 13: A Dark Night                           1.0          NaN    NaN
# 14: Marie                                  1.0          NaN    NaN
# Back Matter                                NaN          NaN    NaN
# Front Matter                               NaN          NaN    NaN
#
# term                                      aboutfcfteen  abqu  absently  ...  \
# story                                                                   ...
# 01: The Girl Who Raised Pigeons                    NaN   NaN       1.0  ...
# 02: The First Day                                  NaN   NaN       1.0  ...
# 03: The Night Rhonda Ferguson Was Killed           NaN   NaN       NaN  ...
# 04: Young Lions                                    NaN   NaN       NaN  ...
# 05: The Store                                      1.0   NaN       NaN  ...
# 06: An Orange Line Train to Ballston               NaN   NaN       NaN  ...
# 07: The Sunday Following Mother's Day              NaN   1.0       NaN  ...
# 08: Lost in the City                               NaN   NaN       NaN  ...
# 09: His Mother's House                             NaN   NaN       NaN  ...
# 10: A Butterfly on F Street                        NaN   NaN       NaN  ...
# 11: Gospel                                         NaN   NaN       1.0  ...
# 12: A New Man                                      NaN   NaN       1.0  ...
# 13: A Dark Night                                   NaN   NaN       NaN  ...
# 14: Marie                                          NaN   NaN       NaN  ...
# Back Matter                                        NaN   NaN       NaN  ...
# Front Matter                                       NaN   NaN       NaN  ...
#
# term                                      ypu   yr  ysirs  ythe  yuddini  \
# story
# 01: The Girl Who Raised Pigeons           NaN  1.0    NaN   1.0      NaN
# 02: The First Day                         NaN  NaN    NaN   NaN      NaN
# 03: The Night Rhonda Ferguson Was Killed  NaN  NaN    NaN   NaN      NaN
# 04: Young Lions                           1.0  NaN    NaN   NaN      NaN
# 05: The Store                             NaN  NaN    NaN   NaN      1.0
# 06: An Orange Line Train to Ballston      NaN  NaN    NaN   NaN      NaN
# 07: The Sunday Following Mother's Day     NaN  NaN    1.0   NaN      NaN
# 08: Lost in the City                      NaN  NaN    NaN   NaN      NaN
# 09: His Mother's House                    NaN  NaN    NaN   NaN      NaN
# 10: A Butterfly on F Street               NaN  NaN    NaN   NaN      NaN
# 11: Gospel                                NaN  NaN    NaN   NaN      NaN
# 12: A New Man                             NaN  NaN    NaN   NaN      NaN
# 13: A Dark Night                          NaN  NaN    NaN   NaN      NaN
# 14: Marie                                 NaN  NaN    NaN   NaN      NaN
# Back Matter                               NaN  NaN    NaN   NaN      NaN
# Front Matter                              NaN  NaN    NaN   NaN      NaN
#
# term                                      zigzagging  zion  zipped  zippers  \
# story
# 01: The Girl Who Raised Pigeons                  NaN   NaN     NaN      NaN
# 02: The First Day                                NaN   NaN     NaN      NaN
# 03: The Night Rhonda Ferguson Was Killed         NaN   NaN     NaN      NaN
# 04: Young Lions                                  NaN   NaN     NaN      1.0
# 05: The Store                                    NaN   NaN     NaN      NaN
# 06: An Orange Line Train to Ballston             NaN   NaN     NaN      NaN
# 07: The Sunday Following Mother's Day            NaN   NaN     NaN      NaN
# 08: Lost in the City                             NaN   NaN     NaN      NaN
# 09: His Mother's House                           NaN   NaN     1.0      NaN
# 10: A Butterfly on F Street                      1.0   NaN     NaN      NaN
# 11: Gospel                                       NaN   1.0     NaN      NaN
# 12: A New Man                                    NaN   1.0     NaN      NaN
# 13: A Dark Night                                 NaN   NaN     NaN      NaN
# 14: Marie                                        NaN   NaN     NaN      NaN
# Back Matter                                      NaN   NaN     NaN      NaN
# Front Matter                                     NaN   NaN     NaN      NaN
#
# term                                      zoo
# story
# 01: The Girl Who Raised Pigeons           NaN
# 02: The First Day                         NaN
# 03: The Night Rhonda Ferguson Was Killed  NaN
# 04: Young Lions                           NaN
# 05: The Store                             NaN
# 06: An Orange Line Train to Ballston      1.0
# 07: The Sunday Following Mother's Day     NaN
# 08: Lost in the City                      NaN
# 09: His Mother's House                    NaN
# 10: A Butterfly on F Street               NaN
# 11: Gospel                                NaN
# 12: A New Man                             NaN
# 13: A Dark Night                          NaN
# 14: Marie                                 NaN
# Back Matter                               NaN
# Front Matter                              NaN
#
# [16 rows x 6357 columns]

# %% [markdown]
# Then we're adding up how many stories each term appears in (`.sum()`) and resetting the index (`.reset_index()`) to make a DataFrame.

# %% [markdown]
# Finally, we will rename the column in this document frequency DataFrame and merge it into our word frequency DataFrame.

# %%
document_frequency_df = document_frequency_df.rename(columns={0:'document_frequency'})

# %%
word_frequency_df = word_frequency_df.merge(document_frequency_df)

# %%
word_frequency_df
# Out:
#                                           story          term  term_frequency  \
# 0               01: The Girl Who Raised Pigeons     abandoned               2
# 1         07: The Sunday Following Mother's Day     abandoned               1
# 2                        09: His Mother's House     abandoned               1
# 3               01: The Girl Who Raised Pigeons          able               2
# 4      03: The Night Rhonda Ferguson Was Killed          able               3
# ...                                         ...           ...             ...
# 16069                              Front Matter           ugl               1
# 16070                              Front Matter  unauthorized               2
# 16071                              Front Matter   unichappell               2
# 16072                              Front Matter        uospel               1
# 16073                              Front Matter           vol               2
#
#        document_frequency
# 0                     3.0
# 1                     3.0
# 2                     3.0
# 3                    12.0
# 4                    12.0
# ...                   ...
# 16069                 1.0
# 16070                 1.0
# 16071                 1.0
# 16072                 1.0
# 16073                 1.0
#
# [16074 rows x 4 columns]

# %% [markdown]
# As you can see in the DataFrame above, the term "abandoned" appears 2 times in the story "The Girl Who Raised Pigeons" (term frequency), and it appears in 3 different stories in the collection overall (document frequency).

# %% [markdown]
# ### Calculate Total Number of Documents

# %% [markdown]
# To calculate the total number of documents are in the collection, we count how many unique values are in the "story" column (we know the answer should be 14!).

# %%
total_number_of_documents = lost_df_flattened['story'].nunique()

# %%
total_number_of_documents
# Out:
# 16

# %% [markdown]
# ### Calculate TFIDF

# %% [markdown]
# There are a lot of slightly different versions of the tf-idf formula, but we're going to use the default version from the [scikit-learn library](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html#sklearn.feature_extraction.text.TfidfTransformer).

# %% [markdown]
# ```
# inverse_document_frequency = log [ (1 + total number of docs) / (1 + document frequency) ] + 1
# ```

# %%
import numpy as np

# %%
word_frequency_df['tfidf'] = word_frequency_df['term_frequency']  *  \
((numpy.log((1 + total_number_of_documents) / (1 + word_frequency_df['document_frequency']))) + 1)

# %%
#word_frequency_df['tfidf_standardized']= (word_frequency_df['tfidf'] - word_frequency_df['tfidf'].mean())/word_frequency_df['tfidf'].std()

# %% [markdown]
# Finally, we will normalize these values with the scikit-learn library.

# %%
from sklearn import preprocessing

# %%
word_frequency_df['tfidf_normalized'] = sklearn.preprocessing.normalize(word_frequency_df[['tfidf']], axis=0, norm='l2')

# %% [markdown]
# We did it! Now let's inspect the top 15 words with the highest tfidf scores for each story in the collection

# %%
word_frequency_df.sort_values(by=['story','tfidf_normalized'], ascending=[True,False]).groupby(['story']).head(15)
# Out:
#                                        chapter          term  term_frequency  \
# 492            01: The Girl Who Raised Pigeons          miss              46
# 13             01: The Girl Who Raised Pigeons           ann              45
# 78             01: The Girl Who Raised Pigeons         betsy              44
# 350            01: The Girl Who Raised Pigeons         jenny              42
# 623            01: The Girl Who Raised Pigeons        robert              36
# 602            01: The Girl Who Raised Pigeons       pigeons              30
# 910            01: The Girl Who Raised Pigeons         would              84
# 81             01: The Girl Who Raised Pigeons         birds              29
# 140            01: The Girl Who Raised Pigeons          coop              28
# 488            01: The Girl Who Raised Pigeons         miles              21
# 127            01: The Girl Who Raised Pigeons         clara              17
# 634            01: The Girl Who Raised Pigeons          said              47
# 351            01: The Girl Who Raised Pigeons       kitchen              16
# 621            01: The Girl Who Raised Pigeons         ralph              17
# 722            01: The Girl Who Raised Pigeons        street              37
# 503                          02: The First Day        mother              42
# 882                          02: The First Day         woman              23
# 942                          02: The First Day          says               7
# 943                          02: The First Day         takes               7
# 664                          02: The First Day        school              10
# 935                          02: The First Day          form               6
# 936                          02: The First Day         looks               6
# 937                          02: The First Day           new               9
# 271                          02: The First Day          girl               8
# 932                          02: The First Day        avenue               6
# 578                          02: The First Day           one              12
# 320                          02: The First Day          hand               8
# 114                          02: The First Day         child               6
# 277                          02: The First Day            go               8
# 668                          02: The First Day           see               6
# 981   03: The Night Rhonda Ferguson Was Killed     cassandra             130
# 1014  03: The Night Rhonda Ferguson Was Killed       melanie              65
# 945   03: The Night Rhonda Ferguson Was Killed         anita              68
# 1030  03: The Night Rhonda Ferguson Was Killed        rhonda              42
# 635   03: The Night Rhonda Ferguson Was Killed          said             109
# 1003  03: The Night Rhonda Ferguson Was Killed        gladys              38
# 976   03: The Night Rhonda Ferguson Was Killed           car              42
# 223   03: The Night Rhonda Ferguson Was Killed        father              32
# 724   03: The Night Rhonda Ferguson Was Killed        street              42
# 261   03: The Night Rhonda Ferguson Was Killed           get              36
# 997   03: The Night Rhonda Ferguson Was Killed         girls              17
# 46    03: The Night Rhonda Ferguson Was Killed          back              39
# 1094  03: The Night Rhonda Ferguson Was Killed        wesley              13
# 343   03: The Night Rhonda Ferguson Was Killed         house              23
# 362   03: The Night Rhonda Ferguson Was Killed          know              28
# 1107                           04: Young Lions        caesar              75
# 1148                           04: Young Lions       sherman              60
# 1123                           04: Young Lions         manny              44
# 1108                           04: Young Lions         carol              29
# 636                            04: Young Lions          said              71
# 912                            04: Young Lions         would              57
# 1145                           04: Young Lions      retarded              22
# 1118                           04: Young Lions           heh              17
# 884                            04: Young Lions         woman              44
# 224                            04: Young Lions        father              28
# 479                            04: Young Lions           man              34
# 1102                           04: Young Lions          anna              13
# 47                             04: Young Lions          back              35
# 826                            04: Young Lions           two              30
# 147                            04: Young Lions         could              29
# 1252                             05: The Store         penny              57
# 1258                             05: The Store         store              51
# 637                              05: The Store          said              79
# 913                              05: The Store         would              79
# 1227                             05: The Store      kentucky              23
# 1099                             05: The Store        always              28
# 1224                             05: The Store       jenkins              19
# 1173                             05: The Store          week              24
# 48                               05: The Store          back              50
# 581                              05: The Store           one              48
# 1239                             05: The Store        lonney              17
# 165                              05: The Store           day              40
# 225                              05: The Store        father              32
# 506                              05: The Store        mother              42
# 781                              05: The Store          time              42
# 1290      06: An Orange Line Train to Ballston        marcus              38
# 1282      06: An Orange Line Train to Ballston          avis              26
# 481       06: An Orange Line Train to Ballston           man              63
# 1298      06: An Orange Line Train to Ballston         train              25
# 1292      06: An Orange Line Train to Ballston        marvin              24
# 1291      06: An Orange Line Train to Ballston      marvella              23
# 638       06: An Orange Line Train to Ballston          said              64
# 1238      06: An Orange Line Train to Ballston          line              18
# 1297      06: An Orange Line Train to Ballston        subway              15
# 1286      06: An Orange Line Train to Ballston    dreadlocks              11
# 1287      06: An Orange Line Train to Ballston          hair              11
# 1293      06: An Orange Line Train to Ballston        orange              11
# 1151      06: An Orange Line Train to Ballston          stop              11
# 1288      06: An Orange Line Train to Ballston          mama              11
# 1285      06: An Orange Line Train to Ballston     dreadlock               8
# 1319     07: The Sunday Following Mother's Day     madeleine              74
# 1318     07: The Sunday Following Mother's Day        maddie              62
# 1326     07: The Sunday Following Mother's Day        samuel              41
# 1325     07: The Sunday Following Mother's Day           sam              34
# 639      07: The Sunday Following Mother's Day          said              81
# 915      07: The Sunday Following Mother's Day         would              71
# 1321     07: The Sunday Following Mother's Day        pookie              21
# 1308     07: The Sunday Following Mother's Day        curtis              16
# 978      07: The Sunday Following Mother's Day           car              25
# 167      07: The Sunday Following Mother's Day           day              35
# 122      07: The Sunday Following Mother's Day      children              26
# 149      07: The Sunday Following Mother's Day         could              33
# 1302     07: The Sunday Following Mother's Day        arnisa              13
# 482      07: The Sunday Following Mother's Day           man              32
# 1340     07: The Sunday Following Mother's Day      williams              12
# 1347                      08: Lost in the City         lydia              32
# 1345                      08: Lost in the City       georgia              19
# 509                       08: Lost in the City        mother              44
# 640                       08: Lost in the City          said              46
# 1342                      08: Lost in the City           cab              13
# 1348                      08: Lost in the City         sorry               9
# 1344                      08: Lost in the City        driver               8
# 1343                      08: Lost in the City          died               7
# 931                       08: Lost in the City           yes               8
# 265                       08: Lost in the City           get              14
# 763                       08: Lost in the City       thought              14
# 1346                      08: Lost in the City          lost               6
# 1349                      08: Lost in the City          town               6
# 367                       08: Lost in the City          know              15
# 483                       08: Lost in the City           man              14
# 1012                    09: His Mother's House         joyce              84
# 1379                    09: His Mother's House        rickey              64
# 1381                    09: His Mother's House      santiago              54
# 641                     09: His Mother's House          said              96
# 1370                    09: His Mother's House      humphrey              33
# 1289                    09: His Mother's House          mama              23
# 1023                    09: His Mother's House         money              25
# 1028                    09: His Mother's House         pearl              22
# 1153                    09: His Mother's House         table              29
# 1380                    09: His Mother's House         sandy              18
# 585                     09: His Mother's House           one              50
# 347                     09: His Mother's House         house              35
# 917                     09: His Mother's House         would              49
# 1384                    09: His Mother's House        smokey              16
# 411                     09: His Mother's House          like              38
# 1394               10: A Butterfly on F Street       mildred              27
# 889                10: A Butterfly on F Street         woman              29
# 1392               10: A Butterfly on F Street     butterfly               7
# 1393               10: A Butterfly on F Street     mansfield               6
# 642                10: A Butterfly on F Street          said              16
# 731                10: A Butterfly on F Street        street              14
# 1333               10: A Butterfly on F Street           son               6
# 658                10: A Butterfly on F Street           say               9
# 53                 10: A Butterfly on F Street          back              10
# 546                10: A Butterfly on F Street          next               6
# 170                10: A Butterfly on F Street           day               8
# 918                10: A Butterfly on F Street         would               8
# 135                10: A Butterfly on F Street          come               6
# 1426                                11: Gospel        vivian              68
# 1399                                11: Gospel         diane              42
# 1413                                11: Gospel         maude              32
# 643                                 11: Gospel          said              77
# 1397                                11: Gospel        church              26
# 1404                                11: Gospel         group              26
# 1180                                11: Gospel         women              31
# 946                                 11: Gospel         anita              25
# 1420                                11: Gospel      reverend              18
# 152                                 11: Gospel         could              39
# 1403                                11: Gospel   gospelteers              15
# 1412                                11: Gospel           mae              15
# 919                                 11: Gospel         would              42
# 1060                                11: Gospel          sing              16
# 485                                 11: Gospel           man              31
# 1447                             12: A New Man       woodrow              57
# 1446                             12: A New Man          rita              22
# 920                              12: A New Man         would              37
# 162                              12: A New Man      daughter              16
# 644                              12: A New Man          said              33
# 229                              12: A New Man        father              22
# 486                              12: A New Man           man              27
# 1441                             12: A New Man          doin              10
# 94                               12: A New Man          boys              11
# 153                              12: A New Man         could              23
# 1144                             12: A New Man          read              12
# 1442                             12: A New Man        elaine               9
# 1444                             12: A New Man       friends               9
# 587                              12: A New Man           one              23
# 575                              12: A New Man           old              16
# 1458                          13: A Dark Night       garrett              38
# 1450                          13: A Dark Night      beatrice              31
# 1453                          13: A Dark Night       carmena              20
# 645                           13: A Dark Night          said              49
# 158                           13: A Dark Night         daddy              17
# 1467                          13: A Dark Night         uncle              14
# 194                           13: A Dark Night          door              27
# 1466                          13: A Dark Night       thunder              12
# 1267                          13: A Dark Night            us              14
# 1459                          13: A Dark Night         henry              10
# 1454                          13: A Dark Night       company               9
# 1465                          13: A Dark Night        sittin               9
# 1461                          13: A Dark Night          john              10
# 588                           13: A Dark Night           one              23
# 1460                          13: A Dark Night           joe               8
# 1480                                 14: Marie         marie              49
# 1487                                 14: Marie      vernelle              30
# 1488                                 14: Marie      wilamena              20
# 646                                  14: Marie          said              51
# 922                                  14: Marie         would              37
# 1482                                 14: Marie      security              13
# 487                                  14: Marie           man              32
# 892                                  14: Marie         woman              31
# 805                                  14: Marie          told              25
# 1481                                 14: Marie  receptionist              10
# 1485                                 14: Marie        social              10
# 599                                  14: Marie        people              20
# 589                                  14: Marie           one              26
# 1274                                 14: Marie    washington              13
# 1474                                 14: Marie         knife               9
#
#       document_frequency       tfidf  tfidf_normalized
# 492                  1.0  138.685539          0.104647
# 13                   1.0  135.670636          0.102372
# 78                   1.0  132.655733          0.100097
# 350                  1.0  126.625927          0.095547
# 623                  1.0  108.536509          0.081897
# 602                  1.0   90.447091          0.068248
# 910                 13.0   89.795401          0.067756
# 81                   1.0   87.432188          0.065973
# 140                  1.0   84.417285          0.063698
# 488                  1.0   63.312963          0.047773
# 127                  1.0   51.253351          0.038674
# 634                 13.0   50.242665          0.037911
# 351                  1.0   48.238448          0.036399
# 621                  2.0   44.360445          0.033473
# 722                 12.0   42.294731          0.031914
# 503                 12.0   48.010235          0.036227
# 882                 12.0   26.291319          0.019838
# 942                  1.0   21.104321          0.015924
# 943                  1.0   21.104321          0.015924
# 664                  4.0   20.986123          0.015835
# 935                  1.0   18.089418          0.013650
# 936                  1.0   18.089418          0.013650
# 937                  5.0   17.246617          0.013014
# 271                  6.0   14.097120          0.010637
# 932                  3.0   13.930535          0.010511
# 578                 13.0   12.827914          0.009679
# 320                  8.0   12.086605          0.009120
# 114                  5.0   11.497744          0.008676
# 277                 11.0    9.785148          0.007383
# 668                 12.0    6.858605          0.005175
# 981                  1.0  391.937393          0.295741
# 1014                 1.0  195.968696          0.147870
# 945                  2.0  177.441778          0.133891
# 1030                 1.0  126.625927          0.095547
# 635                 13.0  116.520223          0.087922
# 1003                 1.0  114.566315          0.086447
# 976                  5.0   80.484211          0.060730
# 223                  8.0   48.346420          0.036480
# 724                 12.0   48.010235          0.036227
# 261                 10.0   47.165577          0.035589
# 997                  2.0   44.360445          0.033473
# 46                  13.0   41.690722          0.031458
# 1094                 1.0   39.193739          0.029574
# 343                  8.0   34.748989          0.026220
# 362                 12.0   32.006824          0.024151
# 1107                 1.0  226.117727          0.170620
# 1148                 1.0  180.894181          0.136496
# 1123                 1.0  132.655733          0.100097
# 1108                 1.0   87.432188          0.065973
# 636                 13.0   75.898494          0.057270
# 912                 13.0   60.932594          0.045977
# 1145                 2.0   57.407634          0.043318
# 1118                 1.0   51.253351          0.038674
# 884                 12.0   50.296437          0.037952
# 224                  8.0   42.303117          0.031920
# 479                 11.0   41.586881          0.031380
# 1102                 1.0   39.193739          0.029574
# 47                  13.0   37.414751          0.028232
# 826                 11.0   36.694307          0.027688
# 147                 11.0   35.471163          0.026765
# 1252                 1.0  171.849472          0.129671
# 1258                 1.0  153.760054          0.116021
# 637                 13.0   84.450437          0.063723
# 913                 13.0   84.450437          0.063723
# 1227                 1.0   69.342769          0.052323
# 1099                 3.0   65.009164          0.049053
# 1224                 1.0   57.283157          0.043224
# 1173                 3.0   55.722140          0.042046
# 48                  13.0   53.449644          0.040331
# 581                 13.0   51.311658          0.038718
# 1239                 1.0   51.253351          0.038674
# 165                 11.0   48.925742          0.036917
# 225                  8.0   48.346420          0.036480
# 506                 12.0   48.010235          0.036227
# 781                 12.0   48.010235          0.036227
# 1290                 1.0  114.566315          0.086447
# 1282                 1.0   78.387479          0.059148
# 481                 11.0   77.058044          0.058145
# 1298                 1.0   75.372576          0.056873
# 1292                 1.0   72.357672          0.054598
# 1291                 1.0   69.342769          0.052323
# 638                 13.0   68.415544          0.051624
# 1238                 2.0   46.969882          0.035442
# 1297                 1.0   45.223545          0.034124
# 1286                 1.0   33.163933          0.025024
# 1287                 1.0   33.163933          0.025024
# 1293                 1.0   33.163933          0.025024
# 1151                 2.0   28.703817          0.021659
# 1288                 2.0   28.703817          0.021659
# 1285                 1.0   24.119224          0.018199
# 1319                 1.0  223.102824          0.168345
# 1318                 1.0  186.923987          0.141046
# 1326                 1.0  123.611024          0.093272
# 1325                 1.0  102.506703          0.077348
# 639                 13.0   86.588423          0.065336
# 915                 13.0   75.898494          0.057270
# 1321                 1.0   63.312963          0.047773
# 1308                 1.0   48.238448          0.036399
# 978                  5.0   47.907268          0.036149
# 167                 11.0   42.810024          0.032303
# 122                  7.0   42.343825          0.031951
# 149                 11.0   40.363737          0.030457
# 1302                 1.0   39.193739          0.029574
# 482                 11.0   39.140594          0.029534
# 1340                 1.0   36.178836          0.027299
# 1347                 1.0   96.476897          0.072798
# 1345                 1.0   57.283157          0.043224
# 509                 12.0   50.296437          0.037952
# 640                 13.0   49.173672          0.037105
# 1342                 1.0   39.193739          0.029574
# 1348                 1.0   27.134127          0.020474
# 1344                 1.0   24.119224          0.018199
# 1343                 1.0   21.104321          0.015924
# 931                  2.0   20.875503          0.015752
# 265                 10.0   18.342169          0.013840
# 763                 10.0   18.342169          0.013840
# 1346                 1.0   18.089418          0.013650
# 1349                 1.0   18.089418          0.013650
# 367                 12.0   17.146513          0.012938
# 483                 11.0   17.124010          0.012921
# 1012                 2.0  219.192785          0.165394
# 1379                 1.0  192.953793          0.145595
# 1381                 1.0  162.804763          0.122846
# 641                 13.0  102.623316          0.077436
# 1370                 1.0   99.491800          0.075073
# 1289                 2.0   60.017072          0.045287
# 1023                 3.0   58.043896          0.043798
# 1028                 2.0   57.407634          0.043318
# 1153                 5.0   55.572431          0.041933
# 1380                 1.0   54.268254          0.040949
# 585                 13.0   53.449644          0.040331
# 347                  8.0   52.878897          0.039900
# 917                 13.0   52.380651          0.039524
# 1384                 1.0   48.238448          0.036399
# 411                 12.0   43.437832          0.032776
# 1394                 1.0   81.402382          0.061423
# 889                 12.0   33.149924          0.025014
# 1392                 1.0   21.104321          0.015924
# 1393                 1.0   18.089418          0.013650
# 642                 13.0   17.103886          0.012906
# 731                 12.0   16.003412          0.012076
# 1333                 4.0   12.591674          0.009501
# 658                 10.0   11.791394          0.008897
# 53                  13.0   10.689929          0.008066
# 546                  6.0   10.572840          0.007978
# 170                 11.0    9.785148          0.007383
# 918                 13.0    8.551943          0.006453
# 135                 12.0    6.858605          0.005175
# 1426                 1.0  205.013405          0.154695
# 1399                 1.0  126.625927          0.095547
# 1413                 1.0   96.476897          0.072798
# 643                 13.0   82.312451          0.062110
# 1397                 1.0   78.387479          0.059148
# 1404                 1.0   78.387479          0.059148
# 1180                 3.0   71.974431          0.054309
# 946                  2.0   65.235948          0.049225
# 1420                 1.0   54.268254          0.040949
# 152                 11.0   47.702599          0.035995
# 1403                 1.0   45.223545          0.034124
# 1412                 1.0   45.223545          0.034124
# 919                 13.0   44.897701          0.033878
# 1060                 2.0   41.751007          0.031504
# 485                 11.0   37.917450          0.028611
# 1447                 1.0  171.849472          0.129671
# 1446                 1.0   66.327866          0.050048
# 920                 13.0   39.552736          0.029845
# 162                  3.0   37.148093          0.028031
# 644                 13.0   35.276765          0.026618
# 229                  8.0   33.238164          0.025080
# 486                 11.0   33.024876          0.024919
# 1441                 1.0   30.149030          0.022749
# 94                   2.0   28.703817          0.021659
# 153                 11.0   28.132302          0.021228
# 1144                 3.0   27.861070          0.021023
# 1442                 1.0   27.134127          0.020474
# 1444                 1.0   27.134127          0.020474
# 587                 13.0   24.586836          0.018552
# 575                  8.0   24.173210          0.018240
# 1458                 1.0  114.566315          0.086447
# 1450                 1.0   93.461994          0.070523
# 1453                 1.0   60.298060          0.045499
# 645                 13.0   52.380651          0.039524
# 158                  2.0   44.360445          0.033473
# 1467                 1.0   42.208642          0.031849
# 194                  9.0   37.947558          0.028634
# 1466                 1.0   36.178836          0.027299
# 1267                 3.0   32.504582          0.024527
# 1459                 1.0   30.149030          0.022749
# 1454                 1.0   27.134127          0.020474
# 1465                 1.0   27.134127          0.020474
# 1461                 2.0   26.094379          0.019690
# 588                 13.0   24.586836          0.018552
# 1460                 1.0   24.119224          0.018199
# 1480                 1.0  147.730248          0.111471
# 1487                 1.0   90.447091          0.068248
# 1488                 1.0   60.298060          0.045499
# 646                 13.0   54.518636          0.041138
# 922                 13.0   39.552736          0.029845
# 1482                 1.0   39.193739          0.029574
# 487                 11.0   39.140594          0.029534
# 892                 12.0   35.436126          0.026739
# 805                 11.0   30.578589          0.023073
# 1481                 1.0   30.149030          0.022749
# 1485                 1.0   30.149030          0.022749
# 599                  9.0   28.109302          0.021210
# 589                 13.0   27.793815          0.020972
# 1274                 4.0   27.281960          0.020586
# 1474                 1.0   27.134127          0.020474

# %% [markdown]
# ## Further Resources

# %% [markdown]
# - Peter Organisciak and Boris Capitanu, ["Text Mining in Python through the HTRC Feature Reader,"](https://programminghistorian.org/en/lessons/text-mining-with-extracted-features) *The Programming Historian*
