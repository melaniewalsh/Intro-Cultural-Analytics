# %% [markdown]
# # Mapping

# %% [markdown]
# This series of lessons introduces basic mapping with Python:

# %% [markdown]
# ```{tableofcontents}
# ```

# %% [markdown]
# ## Learn How to Create

# %% [markdown]
# Here's a sample of an interactive map created in these lessons with the Python library Folium

# %% [markdown]
# <iframe src="../_static/Ithaca-map.html" width="100%" height="500" style="border:none;"></iframe>
