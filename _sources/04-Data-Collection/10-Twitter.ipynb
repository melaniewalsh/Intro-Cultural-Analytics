# %% [markdown]
# ## Twitter Data
#
# ```{admonition} Important Update
# :class: warning
# In 2023, Twitter (now X) dramatically restricted access to its API, effectively ending free academic research access. The Twitter Academic Research track, which previously allowed researchers to collect historical tweets, is no longer available. The lessons below were written when the API was still accessible and are preserved here for reference, but the code examples will no longer work without a paid API subscription.
#
# For social media data collection alternatives, consider exploring the [Bluesky API](https://docs.bsky.app/) or platform-specific archives.
# ```

# %% [markdown]
# This series of lessons covers how to collect and analyze Twitter data:

# %% [markdown]
# ```{tableofcontents}
# ```
