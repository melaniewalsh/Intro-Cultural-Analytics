# %% [markdown]
# ## Song Genius Data Collection

# %% [markdown]
# This series of lessons covers how to collect and analyze song lyrics from Genius.com:

# %% [markdown]
# ```{admonition} Deprecation Warning
# :class: warning
# The Genius API and the [LyricsGenius](https://github.com/johnwmillr/LyricsGenius) Python library have become unreliable due to changes in Genius's API access policies and scraping protections. You may encounter 403 Forbidden errors, rate limiting, or other issues when trying to collect lyrics. The code examples in this section may not work as expected. Consider exploring alternative approaches for collecting song lyrics data.
# ```

# %% [markdown]
# ```{tableofcontents}
# ```
