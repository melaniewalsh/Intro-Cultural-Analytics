# %% [markdown]
# # Twitter Data Sharing

# %% [markdown]
# In this lesson, we're going to learn how to share Twitter data and access Twitter data that has been shared by others with the Python/command line tool [twarc](https://github.com/DocNow/twarc). This tool was developed by a project called [Documenting the Now](https://www.docnow.io/). The DocNow team develops tools and ethical frameworks for social media research.
#
# This lesson presumes that you've already installed and configured twarc, which was covered in [a previous lesson](https://melaniewalsh.github.io/Intro-Cultural-Analytics/Collecting-Cultural-Data/Twitter-Data.html#Install-and-Configure-Twarc)).

# %% [markdown]
# ## Tweet IDs

# %% [markdown]
# Twitter discourages developers and researchers from sharing full Twitter data openly on the web. They instead encourage developers and researchers to share *tweet IDs*:
#
# > [If you provide Twitter Content to third parties, including downloadable datasets or via an API, you may only distribute **Tweet IDs**, Direct Message IDs, and/or User IDs.](https://developer.twitter.com/en/developer-terms/policy#4-e)
#
# Tweet IDs are unique identifiers assigned to every tweet. They look like a random string of numbers: 1189206626135355397. Each tweet ID can be used to download the full data associated with that tweet (if the tweet still exists). This is a process called "hydration."

# %% [markdown]
# <img src="https://cdn.pixabay.com/photo/2013/07/12/19/24/sapling-154734_960_720.png" width=100% >

# %% [markdown]
# **Hydration: a young tweet ID sprouts into a full tweet (to be read in David Attenborough's voice)**

# %% [markdown]
# There are actually two reasons that you might want to dehydrate tweets and/or hydrate tweet IDs: first, to responsibly share Twitter data with others and/or access Twitter data shared by others; second, to get more information about the Twitter data that you yourself collected.
#
# If you collected tweets in real time, for example, you collected those tweets immediately after they were published, which means that they will not contain any retweet or favorite count information. Nobody's had time to retweet them yet! So if you'd like to retroactively get retweet and favorite count information about your tweets, then you would want to dehydrate and rehydrate them.

# %% [markdown]
# ## Dehydrate Tweets

# %% [markdown]
# `twarc2 dehydrate tweets.jsonl > tweet_ids.txt`

# %% [markdown]
# To transform your Twitter data into a list of tweet IDs (so that you can share your data openly on the web), you can run the twarc command `twarc dehydrate` with the name of your JSONL file followed by the output operator `>` and the desired name of your tweet ID text file.
#
# > tweet ID —> tweet = hydration <br>
# > tweet ID <— tweet = dehydration

# %% [markdown]
# Let's dehydrate the Twitter data that we collected about "Infinite Jest" from only verified Twitter accounts.

# %%
# !twarc2 dehydrate twitter-data/infinite_jest_verified_tweets.jsonl > twitter-data/infinite_jest_verified_tweets.txt

# %% [markdown]
# If we `open()` and `.read()` the tweet IDs file that we just created, it looks something like this:

# %%
tweet_ids = open("twitter-data/infinite_jest_verified_tweets.txt", encoding="utf-8").read()

# %%
print(tweet_ids)
# Out:
# 1298279565932900354
# 1298267213544058885
# 1298263845320798212
# 1298258323364405251
# 1298256212849393664
# 1298255758027440129
# 1298253692995399680
# 1298252102918115328
# 1298248048506744835
# 1298247922035970048
# 1298245254156636161
# 1298240308308840448
# 1298239661987573763
# 1298230417137586177
# 1298226636115017728
# 1298221655765004291
# 1298214719178838016
# 1298212546646769672
# 1298206253487984640
# 1298204812375396353
# 1298191515408310277
# 1298191332482007040
# 1298176670323671042
# 1297937648888303618
# 1297937619930820609
# 1297936368149188608
# 1297935144389664768
# 1297934655350611969
# 1297933203387416578
# 1297931536139001857
# 1297928155668283397
# 1297926835909599234
# 1297916415878606854
# 1297910431886061568
# 1297908630986076166
# 1297838527095418880
# 1297754910054731777
# 1297696965648498689
# 1297321315615928320
# 1297029671503224833
# 1296826595009875974
# 1296478494055170050
# 1296466668898717696
# 1295840249763917824
# 1295735067227172873
# 1295490951599677440
# 1295424750181707777
# 1295417500453097472
# 1295358693828042753
# 1295299423312982017

# %% [markdown]
# ## Hydrate Tweets

# %% [markdown]
# `twarc2 hydrate tweet_ids.txt > tweets.jsonl`

# %% [markdown]
# To transform a list of tweet IDs into full Twitter data, you can run the twarc command `twarc hydrate` with the name of your tweet IDs text file followed by the output operator `>` and the desired name of your JSONL file.
#
# > tweet ID —> tweet = hydration <br>
# > tweet ID <— tweet = dehydration

# %% [markdown]
# Now let's re-hydrate the Twitter data that we collected a few weeks ago based on the tweet IDs that we just dehydrated.

# %%
# !twarc2 hydrate twitter-data/infinite_jest_verified_tweets.txt > twitter-data/infinite_jest_verified_tweets_REHYDRATED.jsonl

# %%
tweet_json = open("twitter-data/infinite_jest_verified_tweets_REHYDRATED.jsonl", encoding="utf-8").read()

# %%
print(tweet_json)
# Out:
# {"data": [{"text": "@JustinCChang Avoid the man who wants to put up a bookshelf solely for his copy of Infinite Jest but can't because, his Wallace? Not big enough.", "created_at": "2020-08-25T15:22:24.000Z", "lang": "en", "possibly_sensitive": false, "conversation_id": "1298276549062307841", "reply_settings": "everyone", "referenced_tweets": [{"type": "replied_to", "id": "1298276549062307841"}], "entities": {"annotations": [{"start": 83, "end": 95, "probability": 0.5711, "type": "Person", "normalized_text": "Infinite Jest"}, {"start": 120, "end": 126, "probability": 0.9347, "type": "Person", "normalized_text": "Wallace"}], "mentions": [{"start": 0, "end": 13, "username": "JustinCChang", "id": "96683173"}]}, "public_metrics": {"retweet_count": 0, "reply_count": 1, "like_count": 4, "quote_count": 0}, "source": "Twitter Web App", "id": "1298279565932900354", "author_id": "60200577", "in_reply_to_user_id": "96683173"}, {"text": "RT @bugposting: \"all boys love infinite jest\" is just a misconception. all boys have a copy of infinite jest due to its large size, which m\u2026", "created_at": "2020-08-25T14:19:55.000Z", "lang": "en", "possibly_sensitive": false, "conversation_id": "1298263845320798212", "reply_settings": "everyone", "referenced_tweets": [{"type": "retweeted", "id": "1298106737791307777"}], "public_metrics": {"retweet_count": 1143, "reply_count": 0, "like_count": 0, "quote_count": 0}, "source": "Twitter for iPhone", "id": "1298263845320798212", "entities": {"mentions": [{"start": 3, "end": 14, "username": "bugposting", "id": "630523185"}]}, "author_id": "219718241"}, {"text": "infinite jest is the radiohead of books.", "created_at": "2020-08-25T13:47:47.000Z", "lang": "en", "possibly_sensitive": false, "conversation_id": "1298255758027440129", "reply_settings": "everyone", "public_metrics": {"retweet_count": 26, "reply_count": 17, "like_count": 398, "quote_count": 7}, "context_annotations": [{"domain": {"id": "10", "name": "Person", "description": "Named people in the world like Nelson Mandela"}, "entity": {"id": "821793300172505088", "name": "Radiohead", "description": "Radiohead"}}, {"domain": {"id": "54", "name": "Musician", "description": "A musician in the world, like Adele or Bob Dylan"}, "entity": {"id": "821793300172505088", "name": "Radiohead", "description": "Radiohead"}}, {"domain": {"id": "55", "name": "Music Genre", "description": "A category for a musical style, like Pop, Rock, or Rap"}, "entity": {"id": "849684194242338816", "name": "Alternative rock", "description": "Alternative"}}], "source": "Twitter Web App", "id": "1298255758027440129", "author_id": "49465042"}, {"text": "The Books subreddit is sort of like Book Twitter, but with much less arguing about Infinite Jest. https://t.co/cWzKusvNct", "created_at": "2020-08-25T13:39:35.000Z", "lang": "en", "possibly_sensitive": false, "conversation_id": "1298253692995399680", "reply_settings": "everyone", "entities": {"urls": [{"start": 98, "end": 121, "url": "https://t.co/cWzKusvNct", "expanded_url": "https://lithub.com/everything-is-terrible-except-the-books-subreddit/", "display_url": "lithub.com/everything-is-\u2026", "status": 200, "unwound_url": "https://lithub.com/everything-is-terrible-except-the-books-subreddit/"}], "annotations": [{"start": 41, "end": 47, "probability": 0.6521, "type": "Product", "normalized_text": "Twitter"}, {"start": 83, "end": 95, "probability": 0.2957, "type": "Person", "normalized_text": "Infinite Jest"}]}, "public_metrics": {"retweet_count": 7, "reply_count": 2, "like_count": 53, "quote_count": 2}, "context_annotations": [{"domain": {"id": "46", "name": "Brand Category", "description": "Categories within Brand Verticals that narrow down the scope of Brands"}, "entity": {"id": "781974596752842752", "name": "Services"}}, {"domain": {"id": "47", "name": "Brand", "description": "Brands and Companies"}, "entity": {"id": "10045225402", "name": "Twitter"}}], "source": "Twitter Web App", "id": "1298253692995399680", "author_id":  ...
# {"data": [{"public_metrics": {"retweet_count": 57, "reply_count": 0, "like_count": 0, "quote_count": 0}, "id": "1297993190537138177", "lang": "en", "entities": {"mentions": [{"start": 3, "end": 16, "username": "mollylambert", "id": "136220221"}]}, "reply_settings": "everyone", "source": "Twitter Web App", "referenced_tweets": [{"type": "retweeted", "id": "1297989674271563776"}], "text": "RT @mollylambert: I have never dated the Infinite Jest man, I am the Infinite Jest man", "created_at": "2020-08-24T20:24:26.000Z", "author_id": "16194566", "conversation_id": "1297993190537138177", "possibly_sensitive": false}, {"public_metrics": {"retweet_count": 0, "reply_count": 0, "like_count": 2, "quote_count": 0}, "id": "1297992956885041160", "lang": "en", "in_reply_to_user_id": "14708533", "entities": {"mentions": [{"start": 0, "end": 14, "username": "RaquelMDillon", "id": "14708533"}, {"start": 15, "end": 28, "username": "bookhoarding", "id": "36502863"}, {"start": 29, "end": 36, "username": "pws_la", "id": "994404745"}], "annotations": [{"start": 63, "end": 68, "probability": 0.7511, "type": "Person", "normalized_text": "Lolita"}, {"start": 74, "end": 86, "probability": 0.5487, "type": "Person", "normalized_text": "Infinite Jest"}]}, "reply_settings": "everyone", "source": "Twitter Web App", "referenced_tweets": [{"type": "replied_to", "id": "1297992091172184064"}], "text": "@RaquelMDillon @bookhoarding @pws_la I  was obsessed with both Lolita and Infinite Jest when I read them. Feel weird about it now!", "created_at": "2020-08-24T20:23:31.000Z", "author_id": "3225077806", "conversation_id": "1297989134166798336", "possibly_sensitive": false}, {"public_metrics": {"retweet_count": 0, "reply_count": 5, "like_count": 19, "quote_count": 0}, "id": "1297991753258217474", "lang": "en", "reply_settings": "everyone", "source": "Twitter for Android", "text": "As the only person you know who has actually read Infinite Jest, let me tell you: it's a mess", "created_at": "2020-08-24T20:18:44.000Z", "author_id": "2988601", "conversation_id": "1297991753258217474", "entities": {"annotations": [{"start": 50, "end": 62, "probability": 0.5123, "type": "Person", "normalized_text": "Infinite Jest"}]}, "possibly_sensitive": false}, {"public_metrics": {"retweet_count": 4, "reply_count": 3, "like_count": 140, "quote_count": 0}, "id": "1297991559837708289", "lang": "en", "reply_settings": "everyone", "source": "Twitter Web App", "text": "I keep my copy of Infinite Jest where it belongs, with the other male authors on my \u201cmale authors\u201d shelf", "created_at": "2020-08-24T20:17:58.000Z", "author_id": "136220221", "conversation_id": "1297991559837708289", "entities": {"annotations": [{"start": 18, "end": 30, "probability": 0.337, "type": "Other", "normalized_text": "Infinite Jest"}]}, "possibly_sensitive": false}, {"public_metrics": {"retweet_count": 57, "reply_count": 24, "like_count": 1211, "quote_count": 16}, "id": "1297989674271563776", "lang": "en", "reply_settings": "everyone", "source": "Twitter Web App", "text": "I have never dated the Infinite Jest man, I am the Infinite Jest man", "created_at": "2020-08-24T20:10:28.000Z", "author_id": "136220221", "conversation_id": "1297989674271563776", "possibly_sensitive": false}, {"public_metrics": {"retweet_count": 1, "reply_count": 0, "like_count": 0, "quote_count": 0}, "id": "1297984102583287809", "lang": "en", "entities": {"mentions": [{"start": 3, "end": 18, "username": "matthewfennell", "id": "31290136"}], "annotations": [{"start": 56, "end": 68, "probability": 0.4707, "type": "Person", "normalized_text": "Infinite Jest"}, {"start": 71, "end": 79, "probability": 0.8655, "type": "Person", "normalized_text": "Hemingway"}, {"start": 85, "end": 90, "probability": 0.9534, "type": "Person", "normalized_text": "Lolita"}]}, "reply_settings": "everyone", "source": "Twitter Web App", "referenced_tweets": [{"type": "retweeted", "id": "1297982794598174720"}], "text": "RT @matthewfennell: Tweeting your hot take t ...

# %% [markdown]
# ## Deleted Tweets & The Right To Be Forgotten

# %% [markdown]
# What happens if someone decides to delete their tweet between the time when the tweet is first collected and the time when the tweet is "hydrated"? The deleted tweet will **not** be hydrated. The deleted tweet is no longer be accessible.

# %% [markdown]
# ## Where to Find Tweet IDs

# %% [markdown]
# - DocNow Catalog: https://catalog.docnow.io/
#
# - George Washington University Tweet IDs: https://dataverse.harvard.edu/dataverse/gwu-libraries
