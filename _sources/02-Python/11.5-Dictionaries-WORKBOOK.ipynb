# %% [markdown]
# # Dictionaries — Workbook

# %% [markdown]
# *If you want to save your work from this notebook, you should be sure to make a copy of it on your own computer!!!*
#
# *You can right-click the file in the file browser, select "Rename," then add your initials or last name.*

# %% [markdown]
# ## Key-Value

# %% [markdown]
# A dictionary is made up of "key"-"value" pairs, which are separated by a colon `:` and separated from other key-value pairs by a comma `,`. A dictionary is always enclosed by curly brackets `{}`.

# %%
person1 = {"name": "Mary Gallagher",
             "age": 28,
             "profession": "married"}

# %% [markdown]
# You can check all the keys in a dictionary by using the `.keys()` method or all the values in a dictionary by using the `.values()` method.

# %%
person1.keys()

# %%
person1.values()

# %% [markdown]
# ## Access Items

# %% [markdown]
# You can access a value in a dictionary by using square brackets `[]` and its key name (kind of like how we indexed a string or a list).

# %%
person1["name"]

# %%
person1["age"]

# %%
person1["profession"]

# %% [markdown]
# ## Change Item

# %% [markdown]
# You can change a value in a dictionary by re-assigning a new value to a dictionary key.

# %%
person1["age"] = 100

# %%
person1

# %% [markdown]
# ## Loop through items

# %%
person1.items()

# %%
for item in person1.items():
    print(item)

# %%
for key, value in person1.items():
    print(f"{key} // {value}")

# %% [markdown]
# ## Excercise 1

# %%
movie = {'title': 'Selma',
         'site': 'http://www.imdb.com/title/tt1020072/',
         'country': 'US/UK',
         'year_release': 2014,
         'box_office': '$52.1M',
         'director': 'Ava DuVernay',
         'number_of_subjects': 1,
         'subject': 'Martin Luther King, Jr',
         'type_of_subject': 'Activist',
         'race_known': 'Known',
         'subject_race': 'African American',
         'person_of_color': 1,
         'subject_sex': 'Male', 
        'lead_actor_actress': 'David Oyelowo'}

# %%
type(selma)
# Out:
# dict

# %% [markdown]
# Print out all the "keys" in the dictionary `movie`

# %%
movie

# %% [markdown]
# Print out all the "values" in the dictionary `movie`

# %%
movie

# %% [markdown]
# Access the value for the key "director"

# %%
movie

# %% [markdown]
# Access the value for the key "subject_race"

# %%
movie

# %% [markdown]
# ## Excercise 2

# %% [markdown]
# By using the Python library called pandas, we can read in the entire "biopics.csv" data from the 538 project and make it into a list of dictionaries.
#
# Don't worry about the pandas code at this point. We will get to it in a couple of weeks.

# %%
import pandas as pd
biopics_df = pd.read_csv('biopics.csv', encoding='utf-8')
biopics_list = biopics_df.to_dict('records')

# %%
biopics_list
# Out:
# [{'title': '10 Rillington Place',
#   'site': 'http://www.imdb.com/title/tt0066730/',
#   'country': 'UK',
#   'year_release': 1971,
#   'box_office': '-0',
#   'director': 'Richard Fleischer',
#   'number_of_subjects': 1,
#   'subject': 'John Christie',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Richard Attenborough'},
#  {'title': '12 Years a Slave',
#   'site': 'http://www.imdb.com/title/tt2024544/',
#   'country': 'US/UK',
#   'year_release': 2013,
#   'box_office': '$56.7M',
#   'director': 'Steve McQueen',
#   'number_of_subjects': 1,
#   'subject': ' Solomon Northup',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Chiwetel Ejiofor'},
#  {'title': '127 Hours',
#   'site': 'http://www.imdb.com/title/tt1542344/',
#   'country': 'US/UK',
#   'year_release': 2010,
#   'box_office': '$18.3M',
#   'director': 'Danny Boyle',
#   'number_of_subjects': 1,
#   'subject': 'Aron Ralston',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'James Franco'},
#  {'title': '1987',
#   'site': 'http://www.imdb.com/title/tt2833074/',
#   'country': 'Canada',
#   'year_release': 2014,
#   'box_office': '-0',
#   'director': 'Ricardo Trogi',
#   'number_of_subjects': 1,
#   'subject': 'Ricardo Trogi',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jean-Carl Boucher'},
#  {'title': '20 Dates',
#   'site': 'http://www.imdb.com/title/tt0138987/',
#   'country': 'US',
#   'year_release': 1998,
#   'box_office': '$537K',
#   'director': 'Myles Berkowitz',
#   'number_of_subjects': 1,
#   'subject': 'Myles Berkowitz',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Myles Berkowitz'},
#  {'title': '21',
#   'site': 'http://www.imdb.com/title/tt0478087/',
#   'country': 'US',
#   'year_release': 2008,
#   'box_office': '$81.2M',
#   'director': 'Robert Luketic',
#   'number_of_subjects': 1,
#   'subject': 'Jeff Ma',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'Asian American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jim Sturgess'},
#  {'title': '24 Hour Party People',
#   'site': 'http://www.imdb.com/title/tt0274309/',
#   'country': 'UK',
#   'year_release': 2002,
#   'box_office': '$1.13M',
#   'director': 'Michael Winterbottom',
#   'number_of_subjects': 1,
#   'subject': 'Tony Wilson',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Steve Coogan'},
#  {'title': '42',
#   'site': 'http://www.imdb.com/title/tt0453562/',
#   'country': 'US',
#   'year_release': 2013,
#   'box_office': '$95M',
#   'director': ' Brian Helgeland',
#   'number_of_subjects': 1,
#   'subject': 'Jackie Robinson',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Chadwick Boseman'},
#  {'title': '8 Seconds',
#   'site': 'http://www.imdb.com/title/tt0109021/',
#   'country': 'US',
#   'year_release': 1994,
#   'box_office': '$19.6M',
#   'director': 'John G. Avildsen',
#   'number_of_subjects': 1,
#   'subject': 'Lane Frost',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Luke Perry'},
#  {'title': '84 Charing Cross Road',
#   'site': 'http://www.imdb.com/title/tt0090570/',
#   'country': 'US/UK',
#   'year_release': 1987,
#   'box_office': '$1.08M',
#   'director': 'David Hugh Jones',
#   'number_of_subjects': 2,
#   'subject': 'Frank Doel',
#   'type_of_subject': 'Author',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Anthony Hopkins'},
#  {'title': '84 Charing Cross Road',
#   'site': 'http://www.imdb.com/title/tt0090570/',
#   'country': 'US/UK',
#   'year_release': 1987,
#   'box_office': '$1.08M',
#   'director': 'David Hugh Jones',
#   'number_of_subjects': 2,
#   'subject': 'Helene Hanff',
#   'type_of_subject': 'Author',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Anne Bancroft'},
#  {'title': 'A Beautiful Mind',
#   'site': 'http://www.imdb.com/title/tt0268978/',
#   'country': 'US',
#   'year_release': 2001,
#   'box_office': '$171M',
#   'director': 'Ron Howard',
#   'number_of_subjects': 1,
#   'subject': 'John Nash',
#   'type_of_subject': 'Academic',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Russell Crowe'},
#  {'title': 'A Dangerous Method',
#   'site': 'http://www.imdb.com/title/tt1571222/',
#   'country': 'Canada/UK',
#   'year_release': 2011,
#   'box_office': '$5.7M',
#   'director': 'David Cronenberg',
#   'number_of_subjects': 3,
#   'subject': 'Carl Gustav Jung',
#   'type_of_subject': 'Academic',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Michael Fassbender'},
#  {'title': 'A Dangerous Method',
#   'site': 'http://www.imdb.com/title/tt1571222/',
#   'country': 'Canada/UK',
#   'year_release': 2011,
#   'box_office': '$5.7M',
#   'director': 'David Cronenberg',
#   'number_of_subjects': 3,
#   'subject': 'Sigmund Freud',
#   'type_of_subject': 'Academic',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Viggo Mortensen'},
#  {'title': 'A Dangerous Method',
#   'site': 'http://www.imdb.com/title/tt1571222/',
#   'country': 'Canada/UK',
#   'year_release': 2011,
#   'box_office': '$5.7M',
#   'director': 'David Cronenberg',
#   'number_of_subjects': 3,
#   'subject': 'Sabina Spielrein',
#   'type_of_subject': 'Academic',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Keira Knightley'},
#  {'title': 'A Home of Our Own',
#   'site': 'http://www.imdb.com/title/tt0107130/',
#   'country': 'US',
#   'year_release': 1993,
#   'box_office': '$1.7M',
#   'director': 'Tony Bill',
#   'number_of_subjects': 1,
#   'subject': 'Frances Lacey',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Kathy Bates'},
#  {'title': 'A Man Called Peter',
#   'site': 'http://www.imdb.com/title/tt0048337/',
#   'country': 'US',
#   'year_release': 1955,
#   'box_office': '-0',
#   'director': 'Henry Koster',
#   'number_of_subjects': 1,
#   'subject': 'Peter Marshall',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Richard Todd'},
#  {'title': 'A Man for All Seasons',
#   'site': 'http://www.imdb.com/title/tt0060665/',
#   'country': 'UK',
#   'year_release': 1966,
#   'box_office': '-0',
#   'director': 'Fred Zinnemann',
#   'number_of_subjects': 1,
#   'subject': 'Thomas More',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Paul Scofield'},
#  {'title': "A Matador's Mistress",
#   'site': 'http://www.imdb.com/title/tt0491046/',
#   'country': 'US/UK',
#   'year_release': 2008,
#   'box_office': '-0',
#   'director': 'Menno Meyjes',
#   'number_of_subjects': 2,
#   'subject': 'Lupe Sino',
#   'type_of_subject': 'Actress ',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (White)',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Pen̩lope Cruz'},
#  {'title': "A Matador's Mistress",
#   'site': 'http://www.imdb.com/title/tt0491046/',
#   'country': 'US/UK',
#   'year_release': 2008,
#   'box_office': '-0',
#   'director': 'Menno Meyjes',
#   'number_of_subjects': 2,
#   'subject': 'Manuel Rodr�_guez S��nchez',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (White)',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Adrien Brody'},
#  {'title': 'A Mighty Heart',
#   'site': 'http://www.imdb.com/title/tt0829459/',
#   'country': 'US/UK',
#   'year_release': 2007,
#   'box_office': '$9.17M',
#   'director': 'Michael Winterbottom',
#   'number_of_subjects': 2,
#   'subject': 'Daniel Pearl',
#   'type_of_subject': 'Journalist',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Dan Futterman'},
#  {'title': 'A Mighty Heart',
#   'site': 'http://www.imdb.com/title/tt0829459/',
#   'country': 'US/UK',
#   'year_release': 2007,
#   'box_office': '$9.17M',
#   'director': 'Michael Winterbottom',
#   'number_of_subjects': 2,
#   'subject': 'Mariane Pearl',
#   'type_of_subject': 'Journalist',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Angelina Jolie'},
#  {'title': 'A Song to Remember',
#   'site': 'http://www.imdb.com/title/tt0038104/',
#   'country': 'US',
#   'year_release': 1945,
#   'box_office': '-0',
#   'director': 'Charles Vidor',
#   'number_of_subjects': 1,
#   'subject': 'Frederic Chopin',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Cornel Wilde'},
#  {'title': 'Abe Lincoln in Illinois',
#   'site': 'http://www.imdb.com/title/tt0032181/',
#   'country': 'US',
#   'year_release': 1940,
#   'box_office': '-0',
#   'director': 'John Cromwell',
#   'number_of_subjects': 1,
#   'subject': 'Abraham Lincoln',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Raymond Massey'},
#  {'title': 'Above and Beyond',
#   'site': 'http://www.imdb.com/title/tt0044324/',
#   'country': 'US',
#   'year_release': 1952,
#   'box_office': '-0',
#   'director': 'Melvin Frank, Norman Panama',
#   'number_of_subjects': 1,
#   'subject': 'Paul Tibbets',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Robert Taylor'},
#  {'title': 'Abraham Lincoln',
#   'site': 'http://www.imdb.com/title/tt0020620/',
#   'country': 'US',
#   'year_release': 1930,
#   'box_office': '-0',
#   'director': 'D.W. Griffith',
#   'number_of_subjects': 1,
#   'subject': 'Abraham Lincoln',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Walter Huston'},
#  {'title': 'Against the Ropes',
#   'site': 'http://www.imdb.com/title/tt0312329/',
#   'country': 'US',
#   'year_release': 2004,
#   'box_office': '$5.88M',
#   'director': 'Charles S. Dutton',
#   'number_of_subjects': 1,
#   'subject': 'Jackie Kallen',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Meg Ryan'},
#  {'title': 'Al Capone',
#   'site': 'http://www.imdb.com/title/tt0052543/',
#   'country': 'US',
#   'year_release': 1959,
#   'box_office': '-0',
#   'director': 'Richard Wilson',
#   'number_of_subjects': 1,
#   'subject': 'Al Capone',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Rod Steiger'},
#  {'title': 'Alexander',
#   'site': 'http://www.imdb.com/title/tt0346491/',
#   'country': 'US/UK',
#   'year_release': 2004,
#   'box_office': '$34.3M',
#   'director': 'Oliver Stone',
#   'number_of_subjects': 1,
#   'subject': 'Alexander the Great',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Colin Farrell'},
#  {'title': 'Alexander the Great',
#   'site': 'http://www.imdb.com/title/tt0048937/',
#   'country': 'US',
#   'year_release': 1956,
#   'box_office': '-0',
#   'director': 'Robert Rossen',
#   'number_of_subjects': 1,
#   'subject': 'Alexander the Great',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Richard Burton'},
#  {'title': 'Ali',
#   'site': 'http://www.imdb.com/title/tt0248667/',
#   'country': 'US',
#   'year_release': 2001,
#   'box_office': '$58.2M',
#   'director': 'Michael Mann',
#   'number_of_subjects': 1,
#   'subject': 'Muhammad Ali',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Will Smith'},
#  {'title': 'Alpha Dog',
#   'site': 'http://www.imdb.com/title/tt0426883/',
#   'country': 'US',
#   'year_release': 2006,
#   'box_office': '$15.2M',
#   'director': 'Nick Cassavetes',
#   'number_of_subjects': 1,
#   'subject': 'Jesse James Hollywood',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Emile Hirsch'},
#  {'title': 'Amadeus',
#   'site': 'http://www.imdb.com/title/tt0086879/',
#   'country': 'US',
#   'year_release': 1984,
#   'box_office': '$366K',
#   'director': 'Milos Forman',
#   'number_of_subjects': 2,
#   'subject': 'Antonio Salieri',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'F. Murray Abraham'},
#  {'title': 'Amadeus',
#   'site': 'http://www.imdb.com/title/tt0086879/',
#   'country': 'US',
#   'year_release': 1984,
#   'box_office': '$366K',
#   'director': 'Milos Forman',
#   'number_of_subjects': 2,
#   'subject': 'Wolfgang Amadeus Mozart',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tom Hulce'},
#  {'title': 'Amazing Grace',
#   'site': 'http://www.imdb.com/title/tt0454776/',
#   'country': 'US/UK',
#   'year_release': 2006,
#   'box_office': '$21.2M',
#   'director': 'Michael Apted',
#   'number_of_subjects': 1,
#   'subject': 'William Wilberforce',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ioan Gruffudd'},
#  {'title': 'Amelia',
#   'site': 'http://www.imdb.com/title/tt1129445/',
#   'country': 'US/Canada',
#   'year_release': 2009,
#   'box_office': '$14.2M',
#   'director': 'Mira Nair',
#   'number_of_subjects': 1,
#   'subject': 'Amelia Earhart',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Hilary Swank'},
#  {'title': 'American Gangster',
#   'site': 'http://www.imdb.com/title/tt0765429/',
#   'country': 'US/UK',
#   'year_release': 2007,
#   'box_office': '$130M',
#   'director': 'Ridley Scott',
#   'number_of_subjects': 1,
#   'subject': 'Frank Lucas',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Denzel Washington'},
#  {'title': 'American Me',
#   'site': 'http://www.imdb.com/title/tt0103671/',
#   'country': 'US',
#   'year_release': 1992,
#   'box_office': '$13.1M',
#   'director': 'Edward James Olmos',
#   'number_of_subjects': 1,
#   'subject': 'Rodolfo Cadena',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (Latino)',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Edward James Olmos'},
#  {'title': 'American Sniper',
#   'site': 'http://www.imdb.com/title/tt2179136/',
#   'country': 'US',
#   'year_release': 2014,
#   'box_office': '$350M',
#   'director': 'Clint Eastwood',
#   'number_of_subjects': 1,
#   'subject': 'Chris Kyle',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Bradley Cooper'},
#  {'title': 'American Splendor',
#   'site': 'http://www.imdb.com/title/tt0305206/',
#   'country': 'US',
#   'year_release': 2003,
#   'box_office': '$6M',
#   'director': 'Shari Springer Berman, Robert Pulcini',
#   'number_of_subjects': 1,
#   'subject': 'Harvey Pekar',
#   'type_of_subject': 'Comedian',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Paul Giamatti'},
#  {'title': 'An American Crime',
#   'site': 'http://www.imdb.com/title/tt0802948/',
#   'country': 'US',
#   'year_release': 2007,
#   'box_office': '-0',
#   'director': "Tommy O'Haver",
#   'number_of_subjects': 2,
#   'subject': 'Gertrude Baniszewski',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Catherine Keener'},
#  {'title': 'An American Crime',
#   'site': 'http://www.imdb.com/title/tt0802948/',
#   'country': 'US',
#   'year_release': 2007,
#   'box_office': '-0',
#   'director': "Tommy O'Haver",
#   'number_of_subjects': 2,
#   'subject': 'Sylvia Likens',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Ellen Page'},
#  {'title': 'An Angel at My Table',
#   'site': 'http://www.imdb.com/title/tt0099040/',
#   'country': 'UK',
#   'year_release': 1990,
#   'box_office': '$1.1M',
#   'director': 'Jane Campion',
#   'number_of_subjects': 1,
#   'subject': 'Janet Frame',
#   'type_of_subject': 'Author',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Kerry Fox'},
#  {'title': 'Anastasia',
#   'site': 'http://www.imdb.com/title/tt0048947/',
#   'country': 'US',
#   'year_release': 1956,
#   'box_office': '-0',
#   'director': 'Anatole Litvak',
#   'number_of_subjects': 1,
#   'subject': 'Anna Anderson / Anastasia',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Ingrid Bergman'},
#  {'title': 'Anna and the King of Siam',
#   'site': 'http://www.imdb.com/title/tt0038303/',
#   'country': 'US',
#   'year_release': 1946,
#   'box_office': '-0',
#   'director': 'John Cromwell',
#   'number_of_subjects': 1,
#   'subject': 'Anna Leonowens',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Irene Dunne'},
#  {'title': 'Annie Get Your Gun',
#   'site': 'http://www.imdb.com/title/tt0042200/',
#   'country': 'US',
#   'year_release': 1950,
#   'box_office': '$8M',
#   'director': 'George Sidney',
#   'number_of_subjects': 1,
#   'subject': 'Annie Oakley',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Betty Hutton'},
#  {'title': 'Annie Oakley',
#   'site': 'http://www.imdb.com/title/tt0026073/',
#   'country': 'US',
#   'year_release': 1935,
#   'box_office': '-0',
#   'director': 'George Stevens',
#   'number_of_subjects': 1,
#   'subject': 'Annie Oakley',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Barbara Stanwyck'},
#  {'title': 'Another Country',
#   'site': 'http://www.imdb.com/title/tt0086904/',
#   'country': 'UK',
#   'year_release': 1984,
#   'box_office': '-0',
#   'director': 'Marek Kanievska',
#   'number_of_subjects': 1,
#   'subject': 'Guy Burgess',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Rupert Everett'},
#  {'title': 'Antwone Fisher',
#   'site': 'http://www.imdb.com/title/tt0168786/',
#   'country': 'US',
#   'year_release': 2002,
#   'box_office': '$21.1M',
#   'director': 'Denzel Washington',
#   'number_of_subjects': 1,
#   'subject': 'Antwone Fisher',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Derek Luke'},
#  {'title': 'Auto Focus',
#   'site': 'http://www.imdb.com/title/tt0298744/',
#   'country': 'US',
#   'year_release': 2002,
#   'box_office': '$2.06M',
#   'director': 'Paul Schrader',
#   'number_of_subjects': 1,
#   'subject': 'Robert Edward "Bob" Crane',
#   'type_of_subject': 'Actor',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Greg Kinnear'},
#  {'title': 'Awakenings',
#   'site': 'http://www.imdb.com/title/tt0099077/',
#   'country': 'US',
#   'year_release': 1990,
#   'box_office': '$52.1M',
#   'director': 'Penny Marshall',
#   'number_of_subjects': 1,
#   'subject': 'Oliver Sacks',
#   'type_of_subject': 'Medicine',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Robin Williams'},
#  {'title': 'Baadasssss!',
#   'site': 'http://www.imdb.com/title/tt0367790/',
#   'country': 'US',
#   'year_release': 2003,
#   'box_office': '$365K',
#   'director': 'Mario Van Peebles',
#   'number_of_subjects': 1,
#   'subject': 'Melvin Van Peebles',
#   'type_of_subject': 'Actor',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Mario Van Peebles'},
#  {'title': 'Baader',
#   'site': 'http://www.imdb.com/title/tt0309320/',
#   'country': 'UK',
#   'year_release': 2002,
#   'box_office': '-0',
#   'director': 'Christopher Roth',
#   'number_of_subjects': 1,
#   'subject': 'Andreas Baader',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Frank Giering'},
#  {'title': 'Backbeat',
#   'site': 'http://www.imdb.com/title/tt0106339/',
#   'country': 'UK',
#   'year_release': 1994,
#   'box_office': '$2.39M',
#   'director': 'Iain Softley',
#   'number_of_subjects': 2,
#   'subject': 'John Lennon',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ian Hart'},
#  {'title': 'Backbeat',
#   'site': 'http://www.imdb.com/title/tt0106339/',
#   'country': 'UK',
#   'year_release': 1994,
#   'box_office': '$2.39M',
#   'director': 'Iain Softley',
#   'number_of_subjects': 2,
#   'subject': 'Stuart Sutcliffe',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Stephen Dorff'},
#  {'title': 'Bandit Queen',
#   'site': 'http://www.imdb.com/title/tt0109206/',
#   'country': 'UK',
#   'year_release': 1994,
#   'box_office': '$400K',
#   'director': 'Shekhar Kapur',
#   'number_of_subjects': 1,
#   'subject': 'Phoolan Devi ',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'Indian',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Seema Biswas'},
#  {'title': 'Barabbas',
#   'site': 'http://www.imdb.com/title/tt0055774/',
#   'country': 'US',
#   'year_release': 1961,
#   'box_office': '-0',
#   'director': 'Richard Fleischer',
#   'number_of_subjects': 1,
#   'subject': 'Barabbas',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Anthony Quinn'},
#  {'title': 'Basquiat',
#   'site': 'http://www.imdb.com/title/tt0115632/',
#   'country': 'US',
#   'year_release': 1996,
#   'box_office': '$2.96M',
#   'director': 'Julian Schnabel',
#   'number_of_subjects': 1,
#   'subject': 'Jean-Michel Basquiat',
#   'type_of_subject': 'Artist',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jeffrey Wright'},
#  {'title': 'Bathory: Countess of Blood',
#   'site': 'http://www.imdb.com/title/tt0469640/',
#   'country': 'UK',
#   'year_release': 2008,
#   'box_office': '-0',
#   'director': 'Juraj Jakubisko',
#   'number_of_subjects': 1,
#   'subject': 'Elizabeth Bathory',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Anna Friel'},
#  {'title': 'Battle Hymn',
#   'site': 'http://www.imdb.com/title/tt0050171/',
#   'country': 'US',
#   'year_release': 1957,
#   'box_office': '-0',
#   'director': 'Douglas Sirk',
#   'number_of_subjects': 1,
#   'subject': 'Dean Hess',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Rock Hudson'},
#  {'title': 'Beau Brummell',
#   'site': 'http://www.imdb.com/title/tt0046759/',
#   'country': 'US',
#   'year_release': 1954,
#   'box_office': '-0',
#   'director': 'Curtis Bernhardt',
#   'number_of_subjects': 1,
#   'subject': 'George Brummell',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Stewart Granger'},
#  {'title': 'Becket',
#   'site': 'http://www.imdb.com/title/tt0057877/',
#   'country': 'US/UK',
#   'year_release': 1964,
#   'box_office': '-0',
#   'director': 'Peter Glenville',
#   'number_of_subjects': 2,
#   'subject': 'King Henry II',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': "Peter O'Toole"},
#  {'title': 'Becket',
#   'site': 'http://www.imdb.com/title/tt0057877/',
#   'country': 'US/UK',
#   'year_release': 1964,
#   'box_office': '-0',
#   'director': 'Peter Glenville',
#   'number_of_subjects': 2,
#   'subject': 'Thomas Becket',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': nan},
#  {'title': 'Becoming Jane',
#   'site': 'http://www.imdb.com/title/tt0416508/',
#   'country': 'UK',
#   'year_release': 2007,
#   'box_office': '$18.7M',
#   'director': 'Julian Jarrold',
#   'number_of_subjects': 1,
#   'subject': 'Jane Austen',
#   'type_of_subject': 'Author',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Anne Hathaway'},
#  {'title': 'Before Night Falls',
#   'site': 'http://www.imdb.com/title/tt0247196/',
#   'country': 'US',
#   'year_release': 2000,
#   'box_office': '$4.22M',
#   'director': 'Julian Schnabel',
#   'number_of_subjects': 1,
#   'subject': 'Reinaldo Arenas',
#   'type_of_subject': 'Activist',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (Latin American)',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Javier Bardem'},
#  {'title': 'Behind the Lines',
#   'site': 'http://www.imdb.com/title/tt0120001/',
#   'country': 'Canada/UK',
#   'year_release': 1997,
#   'box_office': '$19.3K',
#   'director': 'Gillies MacKinnon',
#   'number_of_subjects': 1,
#   'subject': 'Siegfried Loraine Sassoon',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'James Wilby'},
#  {'title': 'Bernard and Doris',
#   'site': 'http://www.imdb.com/title/tt0470732/',
#   'country': 'US',
#   'year_release': 2006,
#   'box_office': '-0',
#   'director': 'Bob Balaban',
#   'number_of_subjects': 2,
#   'subject': 'Bernard Lafferty',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ralph Fiennes'},
#  {'title': 'Bernard and Doris',
#   'site': 'http://www.imdb.com/title/tt0470732/',
#   'country': 'US/UK',
#   'year_release': 2006,
#   'box_office': '-0',
#   'director': 'Bob Balaban',
#   'number_of_subjects': 2,
#   'subject': 'Doris Duke',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Susan Sarandon'},
#  {'title': 'Best',
#   'site': 'http://www.imdb.com/title/tt0181311/',
#   'country': 'UK',
#   'year_release': 2000,
#   'box_office': '-0',
#   'director': 'Mary McGuckian',
#   'number_of_subjects': 1,
#   'subject': 'George Best',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'John Lynch'},
#  {'title': 'Beyond the Law',
#   'site': 'http://www.imdb.com/title/tt0103805/',
#   'country': 'US',
#   'year_release': 1993,
#   'box_office': '-0',
#   'director': 'Larry Ferguson',
#   'number_of_subjects': 1,
#   'subject': 'Dan Black',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Charlie Sheen'},
#  {'title': 'Beyond the Sea',
#   'site': 'http://www.imdb.com/title/tt0363473/',
#   'country': 'US/UK',
#   'year_release': 2004,
#   'box_office': '$6.14M',
#   'director': 'Kevin Spacey',
#   'number_of_subjects': 1,
#   'subject': 'Bobby Darin ',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Kevin Spacey'},
#  {'title': 'Big Eyes',
#   'site': 'http://www.imdb.com/title/tt1126590/',
#   'country': 'US/Canada',
#   'year_release': 2014,
#   'box_office': '$14.5M',
#   'director': 'Tim Burton',
#   'number_of_subjects': 1,
#   'subject': 'Margaret Keane',
#   'type_of_subject': 'Artist',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Amy Adams'},
#  {'title': 'Billy the Kid',
#   'site': 'http://www.imdb.com/title/tt0033389/',
#   'country': 'US',
#   'year_release': 1941,
#   'box_office': '-0',
#   'director': 'David Miller',
#   'number_of_subjects': 1,
#   'subject': 'Henry McCarty (Billy the Kid)',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Robert Taylor'},
#  {'title': 'Bird',
#   'site': 'http://www.imdb.com/title/tt0094747/',
#   'country': 'US',
#   'year_release': 1988,
#   'box_office': '$2.18M',
#   'director': 'Clint Eastwood',
#   'number_of_subjects': 1,
#   'subject': 'Charlie "Bird" Parker',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Forest Whitaker'},
#  {'title': 'Birdman of Alcatraz',
#   'site': 'http://www.imdb.com/title/tt0055798/',
#   'country': 'US',
#   'year_release': 1962,
#   'box_office': '-0',
#   'director': 'John Frankenheimer',
#   'number_of_subjects': 1,
#   'subject': 'Robert Franklin Stroud',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Burt Lancaster'},
#  {'title': 'Blaze',
#   'site': 'http://www.imdb.com/title/tt0096943/',
#   'country': 'US',
#   'year_release': 1989,
#   'box_office': '$19.1M',
#   'director': 'Ron Shelton',
#   'number_of_subjects': 1,
#   'subject': 'Earl Long',
#   'type_of_subject': 'Politician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Paul Newman'},
#  {'title': 'Bloodsport',
#   'site': 'http://www.imdb.com/title/tt0092675/',
#   'country': 'US',
#   'year_release': 1988,
#   'box_office': '$11.8M',
#   'director': 'Newt Arnold',
#   'number_of_subjects': 1,
#   'subject': 'Frank Dux',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jean-Claude Van Damme'},
#  {'title': 'Blossoms in the Dust',
#   'site': 'http://www.imdb.com/title/tt0033407/',
#   'country': 'US',
#   'year_release': 1941,
#   'box_office': '-0',
#   'director': 'Mervyn LeRoy',
#   'number_of_subjects': 1,
#   'subject': 'Edna Gladney',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Greer Garson'},
#  {'title': 'Blow',
#   'site': 'http://www.imdb.com/title/tt0221027/',
#   'country': 'US',
#   'year_release': 2001,
#   'box_office': '$52.9M',
#   'director': 'Ted Demme',
#   'number_of_subjects': 1,
#   'subject': 'George Jung',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Johnny Depp'},
#  {'title': 'Blue',
#   'site': 'http://www.imdb.com/title/tt0106438/',
#   'country': 'UK',
#   'year_release': 1993,
#   'box_office': '$1.72M',
#   'director': 'Derek Jarman',
#   'number_of_subjects': 1,
#   'subject': 'Derek Jarman',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Derek Jarman'},
#  {'title': 'Blue Caprice',
#   'site': 'http://www.imdb.com/title/tt2027064/',
#   'country': 'US',
#   'year_release': 2013,
#   'box_office': '$86.7K',
#   'director': 'Alexandre Moors',
#   'number_of_subjects': 1,
#   'subject': 'John Allen Muhammad',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Isaiah Washington'},
#  {'title': 'Bobby Jones: Stroke of Genius',
#   'site': 'http://www.imdb.com/title/tt0375104/',
#   'country': 'US',
#   'year_release': 2004,
#   'box_office': '$2.69M',
#   'director': 'Rowdy Herrington',
#   'number_of_subjects': 1,
#   'subject': 'Bobby Jones',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jim Caviezel'},
#  {'title': 'Bonnie and Clyde',
#   'site': 'http://www.imdb.com/title/tt0061418/',
#   'country': 'US',
#   'year_release': 1967,
#   'box_office': '-0',
#   'director': 'Arthur Penn',
#   'number_of_subjects': 2,
#   'subject': 'Clyde Barrow',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Warren Beatty'},
#  {'title': 'Bonnie and Clyde',
#   'site': 'http://www.imdb.com/title/tt0061418/',
#   'country': 'US',
#   'year_release': 1967,
#   'box_office': '-0',
#   'director': 'Arthur Penn',
#   'number_of_subjects': 2,
#   'subject': 'Bonnie Parker',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Faye Dunaway'},
#  {'title': 'Born on the Fourth of July',
#   'site': 'http://www.imdb.com/title/tt0096969/',
#   'country': 'US',
#   'year_release': 1989,
#   'box_office': '$70M',
#   'director': 'Oliver Stone',
#   'number_of_subjects': 1,
#   'subject': 'Ron Kovic',
#   'type_of_subject': 'Military / activist',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tom Cruise'},
#  {'title': 'Bound for Glory',
#   'site': 'http://www.imdb.com/title/tt0074235/',
#   'country': 'US',
#   'year_release': 1976,
#   'box_office': '-0',
#   'director': 'Hal Ashby',
#   'number_of_subjects': 1,
#   'subject': 'Woody Guthrie',
#   'type_of_subject': 'Singer',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'David Carradine'},
#  {'title': "Boys Don't Cry",
#   'site': 'http://www.imdb.com/title/tt0171804/',
#   'country': 'US',
#   'year_release': 1999,
#   'box_office': '$11.5M',
#   'director': 'Kimberly Peirce',
#   'number_of_subjects': 1,
#   'subject': 'Brandon Teena',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Hilary Swank'},
#  {'title': 'Boys Town',
#   'site': 'http://www.imdb.com/title/tt0029942/',
#   'country': 'US',
#   'year_release': 1938,
#   'box_office': '-0',
#   'director': 'Norman Taurog',
#   'number_of_subjects': 1,
#   'subject': 'Father Edward Flanagan',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Spencer Tracy'},
#  {'title': 'Braveheart',
#   'site': 'http://www.imdb.com/title/tt0112573/',
#   'country': 'US',
#   'year_release': 1995,
#   'box_office': '$75.6M',
#   'director': 'Mel Gibson',
#   'number_of_subjects': 1,
#   'subject': 'William Wallace',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Mel Gibson'},
#  {'title': 'Breach',
#   'site': 'http://www.imdb.com/title/tt0401997/',
#   'country': 'US',
#   'year_release': 2007,
#   'box_office': '$33M',
#   'director': 'Billy Ray',
#   'number_of_subjects': 1,
#   'subject': 'Robert Hanssen',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Chris Cooper'},
#  {'title': 'Brigham Young',
#   'site': 'http://www.imdb.com/title/tt0032281/',
#   'country': 'US',
#   'year_release': 1940,
#   'box_office': '-0',
#   'director': 'Henry Hathaway',
#   'number_of_subjects': 1,
#   'subject': 'Brigham Young',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Dean Jagger'},
#  {'title': 'Bright Star',
#   'site': 'http://www.imdb.com/title/tt0810784/',
#   'country': 'UK',
#   'year_release': 2009,
#   'box_office': '$4.44M',
#   'director': 'Jane Campion',
#   'number_of_subjects': 2,
#   'subject': 'John Keats',
#   'type_of_subject': 'Author (poet)',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ben Whishaw'},
#  {'title': 'Bright Star',
#   'site': 'http://www.imdb.com/title/tt0810784/',
#   'country': 'UK',
#   'year_release': 2009,
#   'box_office': '$4.44M',
#   'director': 'Jane Campion',
#   'number_of_subjects': 2,
#   'subject': 'Fanny Brawne',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Abbie Cornish'},
#  {'title': 'Bronson',
#   'site': 'http://www.imdb.com/title/tt1172570/',
#   'country': 'UK',
#   'year_release': 2008,
#   'box_office': '$105K',
#   'director': 'Nicolas Winding Refn',
#   'number_of_subjects': 1,
#   'subject': 'Charles Bronson',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tom Hardy'},
#  {'title': 'Brother Sun, Sister Moon',
#   'site': 'http://www.imdb.com/title/tt0069824/',
#   'country': 'UK',
#   'year_release': 1972,
#   'box_office': '-0',
#   'director': 'Franco Zeffirelli',
#   'number_of_subjects': 1,
#   'subject': 'St. Francis of Assisi ',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Graham Faulkner'},
#  {'title': 'Bubble Boy',
#   'site': 'http://www.imdb.com/title/tt0258470/',
#   'country': 'US',
#   'year_release': 2001,
#   'box_office': '$5M',
#   'director': 'Blair Hayes',
#   'number_of_subjects': 1,
#   'subject': 'David Vetter',
#   'type_of_subject': 'Medicine',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jake Gyllenhaal'},
#  {'title': 'Buffalo Bill',
#   'site': 'http://www.imdb.com/title/tt0036677/',
#   'country': 'US',
#   'year_release': 1944,
#   'box_office': '-0',
#   'director': 'William A. Wellman',
#   'number_of_subjects': 1,
#   'subject': 'William Cody',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Joel McCrea'},
#  {'title': 'Bugsy',
#   'site': 'http://www.imdb.com/title/tt0101516/',
#   'country': 'US',
#   'year_release': 1991,
#   'box_office': '$49.1M',
#   'director': 'Barry Levinson',
#   'number_of_subjects': 1,
#   'subject': "Ben 'Bugsy' Siegel",
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Warren Beatty'},
#  {'title': 'Burning Blue',
#   'site': 'http://www.imdb.com/title/tt1811307/',
#   'country': 'US',
#   'year_release': 2013,
#   'box_office': '-0',
#   'director': 'D.M.W. Greer With: Trent Ford, Tammy Blanchard, Morgan Spector',
#   'number_of_subjects': 1,
#   'subject': 'DMW Greer',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Trent Ford'},
#  {'title': 'Buster',
#   'site': 'http://www.imdb.com/title/tt0094819/',
#   'country': 'UK',
#   'year_release': 1988,
#   'box_office': '$540K',
#   'director': 'David Green',
#   'number_of_subjects': 1,
#   'subject': 'Buster Edwards',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Phil Collins'},
#  {'title': 'Butch Cassidy and the Sundance Kid',
#   'site': 'http://www.imdb.com/title/tt0064115/',
#   'country': 'US',
#   'year_release': 1969,
#   'box_office': '$102M',
#   'director': 'George Roy Hill',
#   'number_of_subjects': 2,
#   'subject': 'Butch Cassidy (Robert Leroy Parker)',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Paul Newman'},
#  {'title': 'Butch Cassidy and the Sundance Kid',
#   'site': 'http://www.imdb.com/title/tt0064115/',
#   'country': 'US',
#   'year_release': 1969,
#   'box_office': '$102M',
#   'director': 'George Roy Hill',
#   'number_of_subjects': 2,
#   'subject': 'Harry Longabaugh',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Robert Redford'},
#  {'title': 'Cadillac Records',
#   'site': 'http://www.imdb.com/title/tt1042877/',
#   'country': 'US',
#   'year_release': 2008,
#   'box_office': '$8.13M',
#   'director': 'Darnell Martin',
#   'number_of_subjects': 3,
#   'subject': 'Etta James',
#   'type_of_subject': 'Singer',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Beyonc̩ Knowles'},
#  {'title': 'Cadillac Records',
#   'site': 'http://www.imdb.com/title/tt1042877/',
#   'country': 'US',
#   'year_release': 2008,
#   'box_office': '$8.13M',
#   'director': 'Darnell Martin',
#   'number_of_subjects': 3,
#   'subject': 'Muddy Water',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jeffrey Wright'},
#  {'title': 'Cadillac Records',
#   'site': 'http://www.imdb.com/title/tt1042877/',
#   'country': 'US',
#   'year_release': 2008,
#   'box_office': '$8.13M',
#   'director': 'Darnell Martin',
#   'number_of_subjects': 3,
#   'subject': 'Leonard Chess',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Adrien Brody'},
#  {'title': 'Caesar and Cleopatra',
#   'site': 'http://www.imdb.com/title/tt0038390/',
#   'country': 'UK',
#   'year_release': 1945,
#   'box_office': '-0',
#   'director': 'Gabriel Pascal',
#   'number_of_subjects': 2,
#   'subject': 'Julius Caesar',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Claude Rains'},
#  {'title': 'Caesar and Cleopatra',
#   'site': 'http://www.imdb.com/title/tt0038390/',
#   'country': 'UK',
#   'year_release': 1945,
#   'box_office': '-0',
#   'director': 'Gabriel Pascal',
#   'number_of_subjects': 2,
#   'subject': 'Cleopatra',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'Middle Eastern',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Vivien Leigh'},
#  {'title': 'Callas Forever',
#   'site': 'http://www.imdb.com/title/tt0274407/',
#   'country': 'UK',
#   'year_release': 2002,
#   'box_office': '$446K',
#   'director': 'Franco Zeffirelli',
#   'number_of_subjects': 1,
#   'subject': 'Maria Callas',
#   'type_of_subject': 'Singer',
#   'race_known': 'Known',
#   'subject_race': 'Mediterranean',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Fanny Ardant'},
#  {'title': 'Cannibal! The Musical',
#   'site': 'http://www.imdb.com/title/tt0115819/',
#   'country': 'US',
#   'year_release': 1993,
#   'box_office': '-0',
#   'director': 'Trey Parker',
#   'number_of_subjects': 1,
#   'subject': 'Alferd Packer',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Trey Parker'},
#  {'title': 'Capone',
#   'site': 'http://www.imdb.com/title/tt0072761/',
#   'country': 'US',
#   'year_release': 1975,
#   'box_office': '-0',
#   'director': 'Steve Carver',
#   'number_of_subjects': 1,
#   'subject': 'Al Capone',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ben Gazzara'},
#  {'title': 'Capote',
#   'site': 'http://www.imdb.com/title/tt0379725/',
#   'country': 'US/Canada',
#   'year_release': 2005,
#   'box_office': '$28.7M',
#   'director': 'Bennett Miller',
#   'number_of_subjects': 1,
#   'subject': 'Truman Capote ',
#   'type_of_subject': 'Author',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Philip Seymour Hoffman'},
#  {'title': 'Captain Kidd',
#   'site': 'http://www.imdb.com/title/tt0037576/',
#   'country': 'US',
#   'year_release': 1945,
#   'box_office': '-0',
#   'director': 'Rowland V. Lee',
#   'number_of_subjects': 1,
#   'subject': 'William Kidd',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Charles Laughton'},
#  {'title': 'Captain Phillips',
#   'site': 'http://www.imdb.com/title/tt1535109/',
#   'country': 'US',
#   'year_release': 2013,
#   'box_office': '$107M',
#   'director': 'Paul Greengrass',
#   'number_of_subjects': 1,
#   'subject': 'Richard Phillips',
#   'type_of_subject': 'Military',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tom Hanks'},
#  {'title': 'Caravaggio',
#   'site': 'http://www.imdb.com/title/tt0090798/',
#   'country': 'UK',
#   'year_release': 1986,
#   'box_office': '$3.15K',
#   'director': 'Derek Jarman',
#   'number_of_subjects': 1,
#   'subject': 'Michelangelo Merisi de Caravaggio',
#   'type_of_subject': 'Artist',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Multiple'},
#  {'title': 'Carbine Williams',
#   'site': 'http://www.imdb.com/title/tt0044480/',
#   'country': 'US',
#   'year_release': 1952,
#   'box_office': '-0',
#   'director': 'Richard Thorpe',
#   'number_of_subjects': 1,
#   'subject': 'David Marshall Williams',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'James Stewart'},
#  {'title': 'Carrington',
#   'site': 'http://www.imdb.com/title/tt0112637/',
#   'country': 'UK',
#   'year_release': 1995,
#   'box_office': '$3.24M',
#   'director': 'Christopher Hampton',
#   'number_of_subjects': 2,
#   'subject': 'Lytton Strachey',
#   'type_of_subject': 'Author',
#   'race_known': 'Known',
#   'subject_race': 'White',
# ...
#   'country': 'US/UK',
#   'year_release': 2003,
#   'box_office': '$1.57M',
#   'director': 'Joel Schumacher',
#   'number_of_subjects': 1,
#   'subject': 'Veronica Guerin',
#   'type_of_subject': 'Media',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Cate Blanchett'},
#  {'title': 'Vincent & Theo',
#   'site': 'http://www.imdb.com/title/tt0100873/',
#   'country': 'UK',
#   'year_release': 1990,
#   'box_office': '$2.23M',
#   'director': 'Robert Altman',
#   'number_of_subjects': 2,
#   'subject': 'Theo van Gogh',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Paul Rhys'},
#  {'title': 'Vincent & Theo',
#   'site': 'http://www.imdb.com/title/tt0100873/',
#   'country': 'UK',
#   'year_release': 1990,
#   'box_office': '$2.23M',
#   'director': 'Robert Altman',
#   'number_of_subjects': 2,
#   'subject': 'Vincent Van Gogh',
#   'type_of_subject': 'Artist',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tim Roth'},
#  {'title': 'VIPs',
#   'site': 'http://www.imdb.com/title/tt1235548/',
#   'country': 'US',
#   'year_release': 2010,
#   'box_office': '-0',
#   'director': 'Toniko Melo',
#   'number_of_subjects': 1,
#   'subject': 'Marcelo Nascimento da Rocha',
#   'type_of_subject': 'Criminal',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Wagner Moura'},
#  {'title': 'Viva Knievel!',
#   'site': 'http://www.imdb.com/title/tt0076890/',
#   'country': 'US',
#   'year_release': 1977,
#   'box_office': '-0',
#   'director': 'Gordon Douglas',
#   'number_of_subjects': 1,
#   'subject': 'Evel Knievel',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Evel Knievel'},
#  {'title': 'Viva Villa!',
#   'site': 'http://www.imdb.com/title/tt0025948/',
#   'country': 'US',
#   'year_release': 1934,
#   'box_office': '$1.11M',
#   'director': 'Jack Conway',
#   'number_of_subjects': 1,
#   'subject': 'Pancho Villa',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (Latin American)',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Wallace Beery'},
#  {'title': 'Viva Zapata!',
#   'site': 'http://www.imdb.com/title/tt0045296/',
#   'country': 'US',
#   'year_release': 1952,
#   'box_office': '-0',
#   'director': 'Elia Kazan',
#   'number_of_subjects': 1,
#   'subject': 'Emiliano Zapata',
#   'type_of_subject': 'Activist',
#   'race_known': 'Known',
#   'subject_race': 'Hispanic (Latin American)',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Marlon Brando'},
#  {'title': 'Von Richthofen and Brown',
#   'site': 'http://www.imdb.com/title/tt0067658/',
#   'country': 'US',
#   'year_release': 1971,
#   'box_office': '-0',
#   'director': 'Roger Corman',
#   'number_of_subjects': 2,
#   'subject': 'Manfred von Richtofen',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'John Phillip Law'},
#  {'title': 'Von Richthofen and Brown',
#   'site': 'http://www.imdb.com/title/tt0067658/',
#   'country': 'US',
#   'year_release': 1971,
#   'box_office': '-0',
#   'director': 'Roger Corman',
#   'number_of_subjects': 2,
#   'subject': 'Roy Brown',
#   'type_of_subject': 'Military',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Don Stroud'},
#  {'title': 'W.',
#   'site': 'http://www.imdb.com/title/tt1175491/',
#   'country': 'US',
#   'year_release': 2008,
#   'box_office': '$25.5M',
#   'director': 'Oliver Stone',
#   'number_of_subjects': 1,
#   'subject': 'George W. Bush',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Josh Brolin'},
#  {'title': 'Walk the Line',
#   'site': 'http://www.imdb.com/title/tt0358273/',
#   'country': 'US',
#   'year_release': 2005,
#   'box_office': '$120M',
#   'director': 'James Mangold',
#   'number_of_subjects': 1,
#   'subject': 'Johnny Cash',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Joaquin Phoenix'},
#  {'title': 'Walker',
#   'site': 'http://www.imdb.com/title/tt0096409/',
#   'country': 'US',
#   'year_release': 1987,
#   'box_office': '$257K',
#   'director': 'Alex Cox',
#   'number_of_subjects': 1,
#   'subject': 'William Walker',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Ed Harris'},
#  {'title': 'Walking Tall Part II',
#   'site': 'http://www.imdb.com/title/tt0073880/',
#   'country': 'US',
#   'year_release': 1975,
#   'box_office': '-0',
#   'director': 'Earl Bellamy',
#   'number_of_subjects': 1,
#   'subject': 'Buford Pusser',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Bo Svenson'},
#  {'title': 'What We Do Is Secret',
#   'site': 'http://www.imdb.com/title/tt0384683/',
#   'country': 'US',
#   'year_release': 2007,
#   'box_office': '$58.8K',
#   'director': 'Rodger Grossman',
#   'number_of_subjects': 1,
#   'subject': 'Darby Crash',
#   'type_of_subject': 'Singer',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Shane West'},
#  {'title': "What's Love Got to Do with It",
#   'site': 'http://www.imdb.com/title/tt0108551/',
#   'country': 'US',
#   'year_release': 1993,
#   'box_office': '$39.1M',
#   'director': 'Brian Gibson',
#   'number_of_subjects': 1,
#   'subject': 'Anna Mae Bullock (Tina Turner)',
#   'type_of_subject': 'Singer',
#   'race_known': 'Known',
#   'subject_race': 'Multi racial',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Angela Bassett'},
#  {'title': 'When Did You Last See Your Father?',
#   'site': 'http://www.imdb.com/title/tt0829098/',
#   'country': 'UK',
#   'year_release': 2007,
#   'box_office': '$1.07M',
#   'director': 'Anand Tucker',
#   'number_of_subjects': 1,
#   'subject': 'Blake Morrison',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Colin Firth'},
#  {'title': 'Where the Buffalo Roam',
#   'site': 'http://www.imdb.com/title/tt0081748/',
#   'country': 'US',
#   'year_release': 1980,
#   'box_office': '-0',
#   'director': 'Art Linson',
#   'number_of_subjects': 1,
#   'subject': 'Hunter S. Thompson',
#   'type_of_subject': 'Media',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Bill Murray'},
#  {'title': "WhiteLightnin'",
#   'site': 'http://www.imdb.com/title/tt1034419/',
#   'country': 'UK',
#   'year_release': 2009,
#   'box_office': '-0',
#   'director': 'Dominic Murphy',
#   'number_of_subjects': 1,
#   'subject': 'Jesco White',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Edward Hogg'},
#  {'title': 'Why Do Fools Fall in Love',
#   'site': 'http://www.imdb.com/title/tt0123324/',
#   'country': 'US',
#   'year_release': 1998,
#   'box_office': '$12.4M',
#   'director': 'Gregory Nava',
#   'number_of_subjects': 1,
#   'subject': 'Frankie Lymon',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'African American',
#   'person_of_color': 1,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Larenz Tate'},
#  {'title': 'Wild',
#   'site': 'http://www.imdb.com/title/tt2305051/',
#   'country': 'US',
#   'year_release': 2014,
#   'box_office': '$37.9M',
#   'director': 'Jean-Marc Vall̩e',
#   'number_of_subjects': 1,
#   'subject': 'Cheryl Strayed',
#   'type_of_subject': 'Other',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Reese Witherspoon'},
#  {'title': 'Wild Bill',
#   'site': 'http://www.imdb.com/title/tt0114938/',
#   'country': 'US',
#   'year_release': 1995,
#   'box_office': '$2.17M',
#   'director': 'Walter Hill',
#   'number_of_subjects': 1,
#   'subject': 'Wild Bill Hickok',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Jeff Bridges'},
#  {'title': 'Wilde',
#   'site': 'http://www.imdb.com/title/tt0120514/',
#   'country': 'UK',
#   'year_release': 1997,
#   'box_office': '$2.16M',
#   'director': 'Brian Gilbert',
#   'number_of_subjects': 1,
#   'subject': 'Oscar Wilde',
#   'type_of_subject': 'Author',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Stephen Fry'},
#  {'title': 'Wilson',
#   'site': 'http://www.imdb.com/title/tt0037465/',
#   'country': 'US',
#   'year_release': 1944,
#   'box_office': '$2M',
#   'director': 'Henry King',
#   'number_of_subjects': 1,
#   'subject': 'Woodrow Wilson',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Alexander Knox'},
#  {'title': 'Winnie Mandela',
#   'site': 'http://www.imdb.com/title/tt1551641/',
#   'country': 'Canada',
#   'year_release': 2011,
#   'box_office': '-0',
#   'director': 'Darrell Roodt',
#   'number_of_subjects': 1,
#   'subject': 'Winnie Mandela',
#   'type_of_subject': 'Government',
#   'race_known': 'Known',
#   'subject_race': 'African',
#   'person_of_color': 1,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Jennifer Hudson'},
#  {'title': 'Wired',
#   'site': 'http://www.imdb.com/title/tt0098660/',
#   'country': 'US',
#   'year_release': 1989,
#   'box_office': '$1.09M',
#   'director': 'Larry Peerce',
#   'number_of_subjects': 1,
#   'subject': 'John Belushi',
#   'type_of_subject': 'Comedian',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Michael Chiklis'},
#  {'title': 'With a Song in My Heart',
#   'site': 'http://www.imdb.com/title/tt0045333/',
#   'country': 'US',
#   'year_release': 1952,
#   'box_office': '-0',
#   'director': 'Walter Lang',
#   'number_of_subjects': 1,
#   'subject': 'Jane Froman',
#   'type_of_subject': 'Musician',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Susan Hayward'},
#  {'title': 'Without Limits',
#   'site': 'http://www.imdb.com/title/tt0119934/',
#   'country': 'US',
#   'year_release': 1998,
#   'box_office': '$777K',
#   'director': 'Robert Towne',
#   'number_of_subjects': 1,
#   'subject': 'Steve Prefontaine',
#   'type_of_subject': 'Athlete',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Billy Crudup'},
#  {'title': 'Wittgenstein',
#   'site': 'http://www.imdb.com/title/tt0108583/',
#   'country': 'UK',
#   'year_release': 1993,
#   'box_office': '-0',
#   'director': 'Derek Jarman',
#   'number_of_subjects': 1,
#   'subject': 'Ludwig Wittgenstein',
#   'type_of_subject': 'Academic (Philosopher)',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Clancy Chassay'},
#  {'title': 'Words and Music',
#   'site': 'http://www.imdb.com/title/tt0040976/',
#   'country': 'US',
#   'year_release': 1948,
#   'box_office': '-0',
#   'director': 'Norman Taurog',
#   'number_of_subjects': 2,
#   'subject': 'Lorenz Hart',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Mickey Rooney'},
#  {'title': 'Words and Music',
#   'site': 'http://www.imdb.com/title/tt0040976/',
#   'country': 'US',
#   'year_release': 1948,
#   'box_office': '-0',
#   'director': 'Norman Taurog',
#   'number_of_subjects': 2,
#   'subject': 'Richard Rogers',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Tom Drake'},
#  {'title': 'Wyatt Earp',
#   'site': 'http://www.imdb.com/title/tt0111756/',
#   'country': 'US',
#   'year_release': 1994,
#   'box_office': '$25.1M',
#   'director': 'Lawrence Kasdan',
#   'number_of_subjects': 1,
#   'subject': 'Wyatt Earp ',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Kevin Costner'},
#  {'title': 'Yankee Doodle Dandy',
#   'site': 'http://www.imdb.com/title/tt0035575/',
#   'country': 'US',
#   'year_release': 1942,
#   'box_office': '-0',
#   'director': 'Michael Curtiz',
#   'number_of_subjects': 1,
#   'subject': 'George M. Cohan',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'James Cagney'},
#  {'title': 'Young Bess',
#   'site': 'http://www.imdb.com/title/tt0046564/',
#   'country': 'US',
#   'year_release': 1953,
#   'box_office': '-0',
#   'director': 'George Sidney',
#   'number_of_subjects': 1,
#   'subject': 'Elizabeth I',
#   'type_of_subject': 'Historical',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Female',
#   'lead_actor_actress': 'Jean Simmons'},
#  {'title': 'Young Cassidy',
#   'site': 'http://www.imdb.com/title/tt0059930/',
#   'country': 'UK',
#   'year_release': 1965,
#   'box_office': '-0',
#   'director': 'Jack Cardiff',
#   'number_of_subjects': 1,
#   'subject': "Sean O'Casey",
#   'type_of_subject': 'Author',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Rod Taylor'},
#  {'title': 'Young Man with a Horn',
#   'site': 'http://www.imdb.com/title/tt0043153/',
#   'country': 'US',
#   'year_release': 1950,
#   'box_office': '-0',
#   'director': 'Michael Curtiz',
#   'number_of_subjects': 1,
#   'subject': 'Bix Beiderbecke',
#   'type_of_subject': 'Musician',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Kirk Douglas'},
#  {'title': 'Young Mr. Lincoln',
#   'site': 'http://www.imdb.com/title/tt0032155/',
#   'country': 'US',
#   'year_release': 1939,
#   'box_office': '-0',
#   'director': 'John Ford',
#   'number_of_subjects': 1,
#   'subject': 'Abraham Lincoln',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Henry Fonda'},
#  {'title': 'Young Tom Edison',
#   'site': 'http://www.imdb.com/title/tt0033289/',
#   'country': 'US',
#   'year_release': 1940,
#   'box_office': '-0',
#   'director': 'Norman Taurog',
#   'number_of_subjects': 1,
#   'subject': 'Thomas Edison',
#   'type_of_subject': 'Other',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Mickey Rooney'},
#  {'title': 'Young Winston',
#   'site': 'http://www.imdb.com/title/tt0069528/',
#   'country': 'US',
#   'year_release': 1972,
#   'box_office': '-0',
#   'director': 'Richard Attenborough',
#   'number_of_subjects': 1,
#   'subject': 'Winston Churchill',
#   'type_of_subject': 'World leader',
#   'race_known': 'Known',
#   'subject_race': 'White',
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'Simon Ward'},
#  {'title': "Your Cheatin' Heart",
#   'site': 'http://www.imdb.com/title/tt0058765/',
#   'country': 'US',
#   'year_release': 1964,
#   'box_office': '-0',
#   'director': 'Gene Nelson',
#   'number_of_subjects': 1,
#   'subject': 'Hank Williams',
#   'type_of_subject': 'Musician',
#   'race_known': 'Unknown',
#   'subject_race': nan,
#   'person_of_color': 0,
#   'subject_sex': 'Male',
#   'lead_actor_actress': 'George Hamilton'}]

# %%
type(biopics_list)
# Out:
# list

# %%
type(biopics_list[0])
# Out:
# dict

# %% [markdown]
# Loop through this list of dictionaries and print out the movie title and release year for all the movies that featured an African American subject. Print out the movie title and release year with a "//" in between them.

# %%
for biopic_dict in biopics_list...
    #Your code here
        #Your code here
# Out:
# 12 Years a Slave // 2013
# 42 // 2013
# Ali // 2001
# American Gangster // 2007
# Antwone Fisher // 2002
# Baadasssss! // 2003
# Blue Caprice // 2013
# Cadillac Records // 2008
# Cadillac Records // 2008
# Frankie & Alice // 2010
# Fruitvale Station // 2013
# Get on Up // 2014
# Get Rich or Die Tryin' // 2005
# Greased Lightning // 1977
# Jo Jo Dancer, Your Life Is Calling // 1986
# Lady Sings the Blues // 1972
# Lee Daniels' The Butler // 2013
# Malcolm X // 1992
# Men of Honor // 2000
# Phantom Punch // 2008
# Radio // 2003
# Ray // 2004
# Remember the Titans // 2000
# Selma // 2014
# Talk to Me // 2007
# The Blind Side // 2009
# The Express // 2008
# The Great Debaters // 2007
# The Greatest // 1977
# The Hurricane // 1999
# The Jackie Robinson Story // 1950
# The Longshots // 2008
# The Pursuit of Happyness // 2006
# The Soloist // 2009
# Why Do Fools Fall in Love // 1998

# %% [markdown]
# Choose a different "subject_race" and print out all the titles and release years for those movies. Print out the movie title and release year with a "//" in between them.

# %% [markdown]
# - White
# - [blank]
# - African American
# - Multi racial
# - Hispanic (Latin American)
# - Middle Eastern (White)
# - Middle Eastern
# - African
# - Hispanic (White)
# - Hispanic (Latino)
# - Asian
# - Native American
# - Asian American
# - Indian
# - Caribbean
# - Mediterranean
# - Eurasian
# - Hispanic (Latina)

# %%
#Your code here
    #Your code here
        #Your code here

# %% [markdown]
# ## Excercise 3

# %% [markdown]
# The Eviction Lab makes its data [available for download here](https://data-downloads.evictionlab.org/). By using the Python library called pandas, we can read in eviction data about cities in the state of New York and make it into a list of dictionaries.
#
# Don't worry about the pandas code at this point. We will get to it in a couple of weeks.

# %%
cities_df = pd.read_csv('ny_cities_eviction.csv', encoding='utf-8')
cities_list = counties_df.to_dict('records')

# %%
cities_list
# Out:
# [{'GEOID': 3600155,
#   'year': 2000,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 622.0,
#   'poverty-rate': 4.15,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 27.88,
#   'median-gross-rent': 650.0,
#   'median-household-income': 52083.0,
#   'median-property-value': 98700.0,
#   'rent-burden': 19.0,
#   'pct-white': 90.19,
#   'pct-af-am': 2.41,
#   'pct-hispanic': 3.86,
#   'pct-am-ind': 0.64,
#   'pct-asian': 1.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.45,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2001,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 622.0,
#   'poverty-rate': 4.15,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 27.88,
#   'median-gross-rent': 650.0,
#   'median-household-income': 52083.0,
#   'median-property-value': 98700.0,
#   'rent-burden': 19.0,
#   'pct-white': 90.19,
#   'pct-af-am': 2.41,
#   'pct-hispanic': 3.86,
#   'pct-am-ind': 0.64,
#   'pct-asian': 1.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.45,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2002,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 622.0,
#   'poverty-rate': 4.15,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 27.88,
#   'median-gross-rent': 650.0,
#   'median-household-income': 52083.0,
#   'median-property-value': 98700.0,
#   'rent-burden': 19.0,
#   'pct-white': 90.19,
#   'pct-af-am': 2.41,
#   'pct-hispanic': 3.86,
#   'pct-am-ind': 0.64,
#   'pct-asian': 1.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.45,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2003,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 622.0,
#   'poverty-rate': 4.15,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 27.88,
#   'median-gross-rent': 650.0,
#   'median-household-income': 52083.0,
#   'median-property-value': 98700.0,
#   'rent-burden': 19.0,
#   'pct-white': 90.19,
#   'pct-af-am': 2.41,
#   'pct-hispanic': 3.86,
#   'pct-am-ind': 0.64,
#   'pct-asian': 1.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.45,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2004,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 622.0,
#   'poverty-rate': 4.15,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 27.88,
#   'median-gross-rent': 650.0,
#   'median-household-income': 52083.0,
#   'median-property-value': 98700.0,
#   'rent-burden': 19.0,
#   'pct-white': 90.19,
#   'pct-af-am': 2.41,
#   'pct-hispanic': 3.86,
#   'pct-am-ind': 0.64,
#   'pct-asian': 1.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.45,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2005,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 644.0,
#   'poverty-rate': 52.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 59.07,
#   'median-gross-rent': 735.0,
#   'median-household-income': 30597.0,
#   'median-property-value': 119000.0,
#   'rent-burden': 38.5,
#   'pct-white': 100.0,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2006,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 644.0,
#   'poverty-rate': 52.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 59.07,
#   'median-gross-rent': 735.0,
#   'median-household-income': 30597.0,
#   'median-property-value': 119000.0,
#   'rent-burden': 38.5,
#   'pct-white': 100.0,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2007,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 644.0,
#   'poverty-rate': 52.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 59.07,
#   'median-gross-rent': 735.0,
#   'median-household-income': 30597.0,
#   'median-property-value': 119000.0,
#   'rent-burden': 38.5,
#   'pct-white': 100.0,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2008,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 644.0,
#   'poverty-rate': 52.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 59.07,
#   'median-gross-rent': 735.0,
#   'median-household-income': 30597.0,
#   'median-property-value': 119000.0,
#   'rent-burden': 38.5,
#   'pct-white': 100.0,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2009,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 644.0,
#   'poverty-rate': 52.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 59.07,
#   'median-gross-rent': 735.0,
#   'median-household-income': 30597.0,
#   'median-property-value': 119000.0,
#   'rent-burden': 38.5,
#   'pct-white': 100.0,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2010,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 562.0,
#   'poverty-rate': 52.08,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.24,
#   'median-gross-rent': 956.0,
#   'median-household-income': 65577.0,
#   'median-property-value': 318200.0,
#   'rent-burden': 37.6,
#   'pct-white': 86.3,
#   'pct-af-am': 2.67,
#   'pct-hispanic': 7.12,
#   'pct-am-ind': 1.07,
#   'pct-asian': 0.89,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.78,
#   'pct-other': 0.18,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2011,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2012,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2013,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2014,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2015,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600155,
#   'year': 2016,
#   'name': 'Accord',
#   'parent-location': 'New York',
#   'population': 762.0,
#   'poverty-rate': 6.29,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 28.49,
#   'median-gross-rent': 1360.0,
#   'median-household-income': 112083.0,
#   'median-property-value': nan,
#   'rent-burden': 13.2,
#   'pct-white': 79.27,
#   'pct-af-am': 1.97,
#   'pct-hispanic': 2.36,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 16.4,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2000,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1624.0,
#   'poverty-rate': 15.33,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 41.84,
#   'median-gross-rent': 408.0,
#   'median-household-income': 30677.0,
#   'median-property-value': 64900.0,
#   'rent-burden': 26.8,
#   'pct-white': 97.11,
#   'pct-af-am': 0.74,
#   'pct-hispanic': 1.11,
#   'pct-am-ind': 0.12,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.8,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2001,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1624.0,
#   'poverty-rate': 15.33,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 41.84,
#   'median-gross-rent': 408.0,
#   'median-household-income': 30677.0,
#   'median-property-value': 64900.0,
#   'rent-burden': 26.8,
#   'pct-white': 97.11,
#   'pct-af-am': 0.74,
#   'pct-hispanic': 1.11,
#   'pct-am-ind': 0.12,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.8,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2002,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1624.0,
#   'poverty-rate': 15.33,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 41.84,
#   'median-gross-rent': 408.0,
#   'median-household-income': 30677.0,
#   'median-property-value': 64900.0,
#   'rent-burden': 26.8,
#   'pct-white': 97.11,
#   'pct-af-am': 0.74,
#   'pct-hispanic': 1.11,
#   'pct-am-ind': 0.12,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.8,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2003,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1624.0,
#   'poverty-rate': 15.33,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 41.84,
#   'median-gross-rent': 408.0,
#   'median-household-income': 30677.0,
#   'median-property-value': 64900.0,
#   'rent-burden': 26.8,
#   'pct-white': 97.11,
#   'pct-af-am': 0.74,
#   'pct-hispanic': 1.11,
#   'pct-am-ind': 0.12,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.8,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2004,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1624.0,
#   'poverty-rate': 15.33,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 41.84,
#   'median-gross-rent': 408.0,
#   'median-household-income': 30677.0,
#   'median-property-value': 64900.0,
#   'rent-burden': 26.8,
#   'pct-white': 97.11,
#   'pct-af-am': 0.74,
#   'pct-hispanic': 1.11,
#   'pct-am-ind': 0.12,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.8,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2005,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1969.0,
#   'poverty-rate': 11.39,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 46.69,
#   'median-gross-rent': 559.0,
#   'median-household-income': 39226.0,
#   'median-property-value': 99500.0,
#   'rent-burden': 26.6,
#   'pct-white': 95.12,
#   'pct-af-am': 0.76,
#   'pct-hispanic': 0.56,
#   'pct-am-ind': 0.1,
#   'pct-asian': 0.15,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 3.3,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2006,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1969.0,
#   'poverty-rate': 11.39,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 46.69,
#   'median-gross-rent': 559.0,
#   'median-household-income': 39226.0,
#   'median-property-value': 99500.0,
#   'rent-burden': 26.6,
#   'pct-white': 95.12,
#   'pct-af-am': 0.76,
#   'pct-hispanic': 0.56,
#   'pct-am-ind': 0.1,
#   'pct-asian': 0.15,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 3.3,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2007,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1969.0,
#   'poverty-rate': 11.39,
#   'renter-occupied-households': 213.63,
#   'pct-renter-occupied': 46.69,
#   'median-gross-rent': 559.0,
#   'median-household-income': 39226.0,
#   'median-property-value': 99500.0,
#   'rent-burden': 26.6,
#   'pct-white': 95.12,
#   'pct-af-am': 0.76,
#   'pct-hispanic': 0.56,
#   'pct-am-ind': 0.1,
#   'pct-asian': 0.15,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 3.3,
#   'pct-other': 0.0,
#   'eviction-filings': 0.54,
#   'evictions': 0.54,
#   'eviction-rate': 0.25,
#   'eviction-filing-rate': 0.25,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2008,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1969.0,
#   'poverty-rate': 11.39,
#   'renter-occupied-households': 214.97,
#   'pct-renter-occupied': 46.69,
#   'median-gross-rent': 559.0,
#   'median-household-income': 39226.0,
#   'median-property-value': 99500.0,
#   'rent-burden': 26.6,
#   'pct-white': 95.12,
#   'pct-af-am': 0.76,
#   'pct-hispanic': 0.56,
#   'pct-am-ind': 0.1,
#   'pct-asian': 0.15,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 3.3,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2009,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1969.0,
#   'poverty-rate': 11.39,
#   'renter-occupied-households': 216.29,
#   'pct-renter-occupied': 46.69,
#   'median-gross-rent': 559.0,
#   'median-household-income': 39226.0,
#   'median-property-value': 99500.0,
#   'rent-burden': 26.6,
#   'pct-white': 95.12,
#   'pct-af-am': 0.76,
#   'pct-hispanic': 0.56,
#   'pct-am-ind': 0.1,
#   'pct-asian': 0.15,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 3.3,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2010,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1775.0,
#   'poverty-rate': 7.5,
#   'renter-occupied-households': 217.62,
#   'pct-renter-occupied': 44.11,
#   'median-gross-rent': 642.0,
#   'median-household-income': 42222.0,
#   'median-property-value': 126700.0,
#   'rent-burden': 26.9,
#   'pct-white': 96.79,
#   'pct-af-am': 0.73,
#   'pct-hispanic': 0.73,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.45,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.24,
#   'pct-other': 0.06,
#   'eviction-filings': 2.7,
#   'evictions': 2.7,
#   'eviction-rate': 1.24,
#   'eviction-filing-rate': 1.24,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2011,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 219.5,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2012,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 222.17,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.54,
#   'evictions': 0.54,
#   'eviction-rate': 0.24,
#   'eviction-filing-rate': 0.24,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2013,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 224.04,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2014,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 225.36,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2015,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 228.03,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600199,
#   'year': 2016,
#   'name': 'Adams',
#   'parent-location': 'New York',
#   'population': 1717.0,
#   'poverty-rate': 13.08,
#   'renter-occupied-households': 229.9,
#   'pct-renter-occupied': 45.55,
#   'median-gross-rent': 670.0,
#   'median-household-income': 40341.0,
#   'median-property-value': 144300.0,
#   'rent-burden': 32.6,
#   'pct-white': 91.15,
#   'pct-af-am': 0.93,
#   'pct-hispanic': 5.01,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.34,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.57,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2000,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1500.0,
#   'poverty-rate': 6.88,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 19.82,
#   'median-gross-rent': 527.0,
#   'median-household-income': 41938.0,
#   'median-property-value': 75000.0,
#   'rent-burden': 22.7,
#   'pct-white': 98.33,
#   'pct-af-am': 0.07,
#   'pct-hispanic': 0.47,
#   'pct-am-ind': 0.2,
#   'pct-asian': 0.27,
#   'pct-nh-pi': 0.07,
#   'pct-multiple': 0.6,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2001,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1500.0,
#   'poverty-rate': 6.88,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 19.82,
#   'median-gross-rent': 527.0,
#   'median-household-income': 41938.0,
#   'median-property-value': 75000.0,
#   'rent-burden': 22.7,
#   'pct-white': 98.33,
#   'pct-af-am': 0.07,
#   'pct-hispanic': 0.47,
#   'pct-am-ind': 0.2,
#   'pct-asian': 0.27,
#   'pct-nh-pi': 0.07,
#   'pct-multiple': 0.6,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2002,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1500.0,
#   'poverty-rate': 6.88,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 19.82,
#   'median-gross-rent': 527.0,
#   'median-household-income': 41938.0,
#   'median-property-value': 75000.0,
#   'rent-burden': 22.7,
#   'pct-white': 98.33,
#   'pct-af-am': 0.07,
#   'pct-hispanic': 0.47,
#   'pct-am-ind': 0.2,
#   'pct-asian': 0.27,
#   'pct-nh-pi': 0.07,
#   'pct-multiple': 0.6,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2003,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1500.0,
#   'poverty-rate': 6.88,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 19.82,
#   'median-gross-rent': 527.0,
#   'median-household-income': 41938.0,
#   'median-property-value': 75000.0,
#   'rent-burden': 22.7,
#   'pct-white': 98.33,
#   'pct-af-am': 0.07,
#   'pct-hispanic': 0.47,
#   'pct-am-ind': 0.2,
#   'pct-asian': 0.27,
#   'pct-nh-pi': 0.07,
#   'pct-multiple': 0.6,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2004,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1500.0,
#   'poverty-rate': 6.88,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 19.82,
#   'median-gross-rent': 527.0,
#   'median-household-income': 41938.0,
#   'median-property-value': 75000.0,
#   'rent-burden': 22.7,
#   'pct-white': 98.33,
#   'pct-af-am': 0.07,
#   'pct-hispanic': 0.47,
#   'pct-am-ind': 0.2,
#   'pct-asian': 0.27,
#   'pct-nh-pi': 0.07,
#   'pct-multiple': 0.6,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2005,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1742.0,
#   'poverty-rate': 1.57,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 14.29,
#   'median-gross-rent': 668.0,
#   'median-household-income': 54550.0,
#   'median-property-value': 115300.0,
#   'rent-burden': 37.0,
#   'pct-white': 95.58,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 1.55,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 2.87,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2006,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1742.0,
#   'poverty-rate': 1.57,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 14.29,
#   'median-gross-rent': 668.0,
#   'median-household-income': 54550.0,
#   'median-property-value': 115300.0,
#   'rent-burden': 37.0,
#   'pct-white': 95.58,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 1.55,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 2.87,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2007,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1742.0,
#   'poverty-rate': 1.57,
#   'renter-occupied-households': 126.37,
#   'pct-renter-occupied': 14.29,
#   'median-gross-rent': 668.0,
#   'median-household-income': 54550.0,
#   'median-property-value': 115300.0,
#   'rent-burden': 37.0,
#   'pct-white': 95.58,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 1.55,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 2.87,
#   'pct-other': 0.0,
#   'eviction-filings': 0.2,
#   'evictions': 0.2,
#   'eviction-rate': 0.16,
#   'eviction-filing-rate': 0.16,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2008,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1742.0,
#   'poverty-rate': 1.57,
#   'renter-occupied-households': 128.91,
#   'pct-renter-occupied': 14.29,
#   'median-gross-rent': 668.0,
#   'median-household-income': 54550.0,
#   'median-property-value': 115300.0,
#   'rent-burden': 37.0,
#   'pct-white': 95.58,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 1.55,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 2.87,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2009,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1742.0,
#   'poverty-rate': 1.57,
#   'renter-occupied-households': 131.65,
#   'pct-renter-occupied': 14.29,
#   'median-gross-rent': 668.0,
#   'median-household-income': 54550.0,
#   'median-property-value': 115300.0,
#   'rent-burden': 37.0,
#   'pct-white': 95.58,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 1.55,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 2.87,
#   'pct-other': 0.0,
#   'eviction-filings': 0.65,
#   'evictions': 0.65,
#   'eviction-rate': 0.49,
#   'eviction-filing-rate': 0.49,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2010,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1568.0,
#   'poverty-rate': 4.36,
#   'renter-occupied-households': 134.19,
#   'pct-renter-occupied': 20.14,
#   'median-gross-rent': 733.0,
#   'median-household-income': 58219.0,
#   'median-property-value': 138200.0,
#   'rent-burden': 35.1,
#   'pct-white': 94.64,
#   'pct-af-am': 1.47,
#   'pct-hispanic': 1.28,
#   'pct-am-ind': 0.13,
#   'pct-asian': 0.26,
#   'pct-nh-pi': 0.26,
#   'pct-multiple': 1.79,
#   'pct-other': 0.19,
#   'eviction-filings': 0.8,
#   'evictions': 0.8,
#   'eviction-rate': 0.6,
#   'eviction-filing-rate': 0.6,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2011,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 136.93,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2012,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 139.4,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.2,
#   'evictions': 0.2,
#   'eviction-rate': 0.14,
#   'eviction-filing-rate': 0.14,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2013,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 142.14,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2014,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 144.23,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.65,
#   'evictions': 0.65,
#   'eviction-rate': 0.45,
#   'eviction-filing-rate': 0.45,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2015,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 147.35,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600232,
#   'year': 2016,
#   'name': 'Adams Center',
#   'parent-location': 'New York',
#   'population': 1865.0,
#   'poverty-rate': 12.26,
#   'renter-occupied-households': 149.44,
#   'pct-renter-occupied': 34.02,
#   'median-gross-rent': 757.0,
#   'median-household-income': 33849.0,
#   'median-property-value': 108600.0,
#   'rent-burden': 30.7,
#   'pct-white': 97.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 1.07,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.29,
#   'pct-other': 0.0,
#   'eviction-filings': 0.65,
#   'evictions': 0.65,
#   'eviction-rate': 0.44,
#   'eviction-filing-rate': 0.44,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2000,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1797.0,
#   'poverty-rate': 17.54,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 36.74,
#   'median-gross-rent': 428.0,
#   'median-household-income': 31532.0,
#   'median-property-value': 53400.0,
#   'rent-burden': 29.3,
#   'pct-white': 98.22,
#   'pct-af-am': 0.17,
#   'pct-hispanic': 0.45,
#   'pct-am-ind': 0.39,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.78,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2001,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1797.0,
#   'poverty-rate': 17.54,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 36.74,
#   'median-gross-rent': 428.0,
#   'median-household-income': 31532.0,
#   'median-property-value': 53400.0,
#   'rent-burden': 29.3,
#   'pct-white': 98.22,
#   'pct-af-am': 0.17,
#   'pct-hispanic': 0.45,
#   'pct-am-ind': 0.39,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.78,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2002,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1797.0,
#   'poverty-rate': 17.54,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 36.74,
#   'median-gross-rent': 428.0,
#   'median-household-income': 31532.0,
#   'median-property-value': 53400.0,
#   'rent-burden': 29.3,
#   'pct-white': 98.22,
#   'pct-af-am': 0.17,
#   'pct-hispanic': 0.45,
#   'pct-am-ind': 0.39,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.78,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2003,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1797.0,
#   'poverty-rate': 17.54,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 36.74,
#   'median-gross-rent': 428.0,
#   'median-household-income': 31532.0,
#   'median-property-value': 53400.0,
#   'rent-burden': 29.3,
#   'pct-white': 98.22,
#   'pct-af-am': 0.17,
#   'pct-hispanic': 0.45,
#   'pct-am-ind': 0.39,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.78,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2004,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1797.0,
#   'poverty-rate': 17.54,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 36.74,
#   'median-gross-rent': 428.0,
#   'median-household-income': 31532.0,
#   'median-property-value': 53400.0,
#   'rent-burden': 29.3,
#   'pct-white': 98.22,
#   'pct-af-am': 0.17,
#   'pct-hispanic': 0.45,
#   'pct-am-ind': 0.39,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.78,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2005,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1697.0,
#   'poverty-rate': 9.55,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.51,
#   'median-gross-rent': 537.0,
#   'median-household-income': 36563.0,
#   'median-property-value': 66800.0,
#   'rent-burden': 36.7,
#   'pct-white': 97.41,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.59,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2006,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1697.0,
#   'poverty-rate': 9.55,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.51,
#   'median-gross-rent': 537.0,
#   'median-household-income': 36563.0,
#   'median-property-value': 66800.0,
#   'rent-burden': 36.7,
#   'pct-white': 97.41,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.59,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2007,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1697.0,
#   'poverty-rate': 9.55,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.51,
#   'median-gross-rent': 537.0,
#   'median-household-income': 36563.0,
#   'median-property-value': 66800.0,
#   'rent-burden': 36.7,
#   'pct-white': 97.41,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.59,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2008,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1697.0,
#   'poverty-rate': 9.55,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.51,
#   'median-gross-rent': 537.0,
#   'median-household-income': 36563.0,
#   'median-property-value': 66800.0,
#   'rent-burden': 36.7,
#   'pct-white': 97.41,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.59,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2009,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1697.0,
#   'poverty-rate': 9.55,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.51,
#   'median-gross-rent': 537.0,
#   'median-household-income': 36563.0,
#   'median-property-value': 66800.0,
#   'rent-burden': 36.7,
#   'pct-white': 97.41,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.59,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2010,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1763.0,
#   'poverty-rate': 7.98,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 34.29,
#   'median-gross-rent': 523.0,
#   'median-household-income': 55326.0,
#   'median-property-value': 76300.0,
#   'rent-burden': 30.3,
#   'pct-white': 95.8,
#   'pct-af-am': 0.51,
#   'pct-hispanic': 1.76,
#   'pct-am-ind': 0.11,
#   'pct-asian': 0.74,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.02,
#   'pct-other': 0.06,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2011,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2012,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2013,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2014,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2015,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600276,
#   'year': 2016,
#   'name': 'Addison',
#   'parent-location': 'New York',
#   'population': 1788.0,
#   'poverty-rate': 11.16,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 30.4,
#   'median-gross-rent': 561.0,
#   'median-household-income': 49821.0,
#   'median-property-value': 80100.0,
#   'rent-burden': 28.1,
#   'pct-white': 96.59,
#   'pct-af-am': 0.62,
#   'pct-hispanic': 1.45,
#   'pct-am-ind': 0.56,
#   'pct-asian': 0.39,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.39,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600342,
#   'year': 2000,
#   'name': 'Afton',
#   'parent-location': 'New York',
#   'population': 836.0,
#   'poverty-rate': 9.85,
#   'renter-occupied-households': 64.97,
#   'pct-renter-occupied': 34.7,
#   'median-gross-rent': 405.0,
#   'median-household-income': 34412.0,
#   'median-property-value': 63500.0,
#   'rent-burden': 26.1,
#   'pct-white': 97.13,
#   'pct-af-am': 0.12,
#   'pct-hispanic': 1.32,
#   'pct-am-ind': 1.08,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.24,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600342,
#   'year': 2001,
#   'name': 'Afton',
#   'parent-location': 'New York',
#   'population': 836.0,
#   'poverty-rate': 9.85,
#   'renter-occupied-households': 66.15,
#   'pct-renter-occupied': 34.7,
#   'median-gross-rent': 405.0,
#   'median-household-income': 34412.0,
#   'median-property-value': 63500.0,
#   'rent-burden': 26.1,
#   'pct-white': 97.13,
#   'pct-af-am': 0.12,
#   'pct-hispanic': 1.32,
#   'pct-am-ind': 1.08,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.24,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600342,
#   'year': 2002,
#   'name': 'Afton',
#   'parent-location': 'New York',
#   'population': 836.0,
#   'poverty-rate': 9.85,
#   'renter-occupied-households': 67.19,
#   'pct-renter-occupied': 34.7,
#   'median-gross-rent': 405.0,
#   'median-household-income': 34412.0,
#   'median-property-value': 63500.0,
#   'rent-burden': 26.1,
#   'pct-white': 97.13,
#   'pct-af-am': 0.12,
#   'pct-hispanic': 1.32,
#   'pct-am-ind': 1.08,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.24,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600342,
#   'year': 2003,
#   'name': 'Afton',
#   'parent-location': 'New York',
#   'population': 836.0,
#   'poverty-rate': 9.85,
#   'renter-occupied-households': 68.22,
#   'pct-renter-occupied': 34.7,
#   'median-gross-rent': 405.0,
#   'median-household-income': 34412.0,
#   'median-property-value': 63500.0,
#   'rent-burden': 26.1,
#   'pct-white': 97.13,
#   'pct-af-am': 0.12,
#   'pct-hispanic': 1.32,
#   'pct-am-ind': 1.08,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.24,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3600342,
#   'year': 2004,
#   'name': 'Afton',
#   'parent-location': 'New York',
#   'population': 836.0,
#   'poverty-rate': 9.85,
#   'renter-occupied-households': 69.26,
#   'pct-renter-occupied': 34.7,
#   'median-gross-rent': 405.0,
#   'median-household-income': 34412.0,
#   'median-property-value': 63500.0,
#   'rent-burden': 26.1,
#   'pct-white': 97.13,
#   'pct-af-am': 0.12,
#   'pct-hispanic': 1.32,
#   'pct-am-ind': 1.08,
#   'pct-asian': 0.12,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.24,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
# ...
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.27,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2007,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 629.0,
#   'poverty-rate': 12.71,
#   'renter-occupied-households': 70.0,
#   'pct-renter-occupied': 21.05,
#   'median-gross-rent': 471.0,
#   'median-household-income': 49018.0,
#   'median-property-value': 92900.0,
#   'rent-burden': 39.5,
#   'pct-white': 93.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 5.09,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.27,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2008,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 629.0,
#   'poverty-rate': 12.71,
#   'renter-occupied-households': 69.0,
#   'pct-renter-occupied': 21.05,
#   'median-gross-rent': 471.0,
#   'median-household-income': 49018.0,
#   'median-property-value': 92900.0,
#   'rent-burden': 39.5,
#   'pct-white': 93.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 5.09,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.27,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2009,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 629.0,
#   'poverty-rate': 12.71,
#   'renter-occupied-households': 69.0,
#   'pct-renter-occupied': 21.05,
#   'median-gross-rent': 471.0,
#   'median-household-income': 49018.0,
#   'median-property-value': 92900.0,
#   'rent-burden': 39.5,
#   'pct-white': 93.64,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 5.09,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.27,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2010,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 533.0,
#   'poverty-rate': 12.43,
#   'renter-occupied-households': 68.0,
#   'pct-renter-occupied': 32.38,
#   'median-gross-rent': 552.0,
#   'median-household-income': 47045.0,
#   'median-property-value': 90100.0,
#   'rent-burden': 22.5,
#   'pct-white': 90.62,
#   'pct-af-am': 0.19,
#   'pct-hispanic': 7.13,
#   'pct-am-ind': 0.94,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 1.13,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2011,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 67.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2012,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 65.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2013,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 64.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2014,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 62.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 1.0,
#   'evictions': 1.0,
#   'eviction-rate': 1.61,
#   'eviction-filing-rate': 1.61,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2015,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 61.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604440,
#   'year': 2016,
#   'name': 'Barker',
#   'parent-location': 'New York',
#   'population': 738.0,
#   'poverty-rate': 14.12,
#   'renter-occupied-households': 59.0,
#   'pct-renter-occupied': 34.84,
#   'median-gross-rent': 612.0,
#   'median-household-income': 41458.0,
#   'median-property-value': 90000.0,
#   'rent-burden': 29.5,
#   'pct-white': 77.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 22.22,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.0,
#   'pct-other': 0.0,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2000,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 332.0,
#   'poverty-rate': 4.76,
#   'renter-occupied-households': 20.23,
#   'pct-renter-occupied': 39.68,
#   'median-gross-rent': 475.0,
#   'median-household-income': 41071.0,
#   'median-property-value': 83000.0,
#   'rent-burden': 19.2,
#   'pct-white': 97.59,
#   'pct-af-am': 0.9,
#   'pct-hispanic': 0.3,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.3,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.3,
#   'pct-other': 0.6,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2001,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 332.0,
#   'poverty-rate': 4.76,
#   'renter-occupied-households': 20.08,
#   'pct-renter-occupied': 39.68,
#   'median-gross-rent': 475.0,
#   'median-household-income': 41071.0,
#   'median-property-value': 83000.0,
#   'rent-burden': 19.2,
#   'pct-white': 97.59,
#   'pct-af-am': 0.9,
#   'pct-hispanic': 0.3,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.3,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.3,
#   'pct-other': 0.6,
#   'eviction-filings': 0.15,
#   'evictions': 0.15,
#   'eviction-rate': 0.75,
#   'eviction-filing-rate': 0.75,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2002,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 332.0,
#   'poverty-rate': 4.76,
#   'renter-occupied-households': 19.93,
#   'pct-renter-occupied': 39.68,
#   'median-gross-rent': 475.0,
#   'median-household-income': 41071.0,
#   'median-property-value': 83000.0,
#   'rent-burden': 19.2,
#   'pct-white': 97.59,
#   'pct-af-am': 0.9,
#   'pct-hispanic': 0.3,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.3,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.3,
#   'pct-other': 0.6,
#   'eviction-filings': 0.0,
#   'evictions': 0.0,
#   'eviction-rate': 0.0,
#   'eviction-filing-rate': 0.0,
#   'low-flag': 1,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2003,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 332.0,
#   'poverty-rate': 4.76,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 39.68,
#   'median-gross-rent': 475.0,
#   'median-household-income': 41071.0,
#   'median-property-value': 83000.0,
#   'rent-burden': 19.2,
#   'pct-white': 97.59,
#   'pct-af-am': 0.9,
#   'pct-hispanic': 0.3,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.3,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.3,
#   'pct-other': 0.6,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2004,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 332.0,
#   'poverty-rate': 4.76,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 39.68,
#   'median-gross-rent': 475.0,
#   'median-household-income': 41071.0,
#   'median-property-value': 83000.0,
#   'rent-burden': 19.2,
#   'pct-white': 97.59,
#   'pct-af-am': 0.9,
#   'pct-hispanic': 0.3,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.3,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.3,
#   'pct-other': 0.6,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2005,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 291.0,
#   'poverty-rate': 0.0,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 20.66,
#   'median-gross-rent': 465.0,
#   'median-household-income': 61932.0,
#   'median-property-value': 131300.0,
#   'rent-burden': 37.5,
#   'pct-white': 92.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 5.84,
#   'pct-other': 1.37,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2006,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 291.0,
#   'poverty-rate': 0.0,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 20.66,
#   'median-gross-rent': 465.0,
#   'median-household-income': 61932.0,
#   'median-property-value': 131300.0,
#   'rent-burden': 37.5,
#   'pct-white': 92.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 5.84,
#   'pct-other': 1.37,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2007,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 291.0,
#   'poverty-rate': 0.0,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 20.66,
#   'median-gross-rent': 465.0,
#   'median-household-income': 61932.0,
#   'median-property-value': 131300.0,
#   'rent-burden': 37.5,
#   'pct-white': 92.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 5.84,
#   'pct-other': 1.37,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2008,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 291.0,
#   'poverty-rate': 0.0,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 20.66,
#   'median-gross-rent': 465.0,
#   'median-household-income': 61932.0,
#   'median-property-value': 131300.0,
#   'rent-burden': 37.5,
#   'pct-white': 92.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 5.84,
#   'pct-other': 1.37,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2009,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 291.0,
#   'poverty-rate': 0.0,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 20.66,
#   'median-gross-rent': 465.0,
#   'median-household-income': 61932.0,
#   'median-property-value': 131300.0,
#   'rent-burden': 37.5,
#   'pct-white': 92.78,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 0.0,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 5.84,
#   'pct-other': 1.37,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2010,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 284.0,
#   'poverty-rate': 5.17,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 33.91,
#   'median-gross-rent': 538.0,
#   'median-household-income': 53125.0,
#   'median-property-value': 113800.0,
#   'rent-burden': 22.9,
#   'pct-white': 95.42,
#   'pct-af-am': 0.35,
#   'pct-hispanic': 2.46,
#   'pct-am-ind': 1.06,
#   'pct-asian': 0.35,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 0.35,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2011,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 221.0,
#   'poverty-rate': 6.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 34.34,
#   'median-gross-rent': 700.0,
#   'median-household-income': 57292.0,
#   'median-property-value': 111800.0,
#   'rent-burden': 18.9,
#   'pct-white': 90.05,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.71,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 7.24,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2012,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 221.0,
#   'poverty-rate': 6.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 34.34,
#   'median-gross-rent': 700.0,
#   'median-household-income': 57292.0,
#   'median-property-value': 111800.0,
#   'rent-burden': 18.9,
#   'pct-white': 90.05,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.71,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 7.24,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  {'GEOID': 3604528,
#   'year': 2013,
#   'name': 'Barneveld',
#   'parent-location': 'New York',
#   'population': 221.0,
#   'poverty-rate': 6.25,
#   'renter-occupied-households': nan,
#   'pct-renter-occupied': 34.34,
#   'median-gross-rent': 700.0,
#   'median-household-income': 57292.0,
#   'median-property-value': 111800.0,
#   'rent-burden': 18.9,
#   'pct-white': 90.05,
#   'pct-af-am': 0.0,
#   'pct-hispanic': 2.71,
#   'pct-am-ind': 0.0,
#   'pct-asian': 0.0,
#   'pct-nh-pi': 0.0,
#   'pct-multiple': 7.24,
#   'pct-other': 0.0,
#   'eviction-filings': nan,
#   'evictions': nan,
#   'eviction-rate': nan,
#   'eviction-filing-rate': nan,
#   'low-flag': 0,
#   'imputed': 0,
#   'subbed': 0},
#  ...]

# %% [markdown]
# Loop through this list of dictionaries and print out the year and number of evictions for the city of "Ithaca."
#
# Print out the year and number of evictions with a custom f-string.

# %%
#Your code here
    #Your code here
        #Your code here
# Out:
# In 2000, the city of Syracuse had nan evictions.
# In 2001, the city of Syracuse had nan evictions.
# In 2002, the city of Syracuse had nan evictions.
# In 2003, the city of Syracuse had nan evictions.
# In 2004, the city of Syracuse had nan evictions.
# In 2005, the city of Syracuse had nan evictions.
# In 2006, the city of Syracuse had nan evictions.
# In 2007, the city of Syracuse had nan evictions.
# In 2008, the city of Syracuse had nan evictions.
# In 2009, the city of Syracuse had nan evictions.
# In 2010, the city of Syracuse had nan evictions.
# In 2011, the city of Syracuse had 158.0 evictions.
# In 2012, the city of Syracuse had 203.0 evictions.
# In 2013, the city of Syracuse had 189.0 evictions.
# In 2014, the city of Syracuse had 214.0 evictions.
# In 2015, the city of Syracuse had 222.0 evictions.
# In 2016, the city of Syracuse had 256.0 evictions.
