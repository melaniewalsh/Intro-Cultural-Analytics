# %% [markdown]
# ## HW 4 – Practice with Pandas

# %% [markdown]
# [Download relevant files here](https://melaniewalsh.org/Pandas.zip)

# %% [markdown]
# Follow the instructions in the assignment below. Then save your file as "Your-Last-Name-HW-4-Pandas.ipynb" and submit it to Canvas by Tuesday at 9am.

# %% [markdown]
# <img src="../images/Intra-American.png" width=100% >

# %% [markdown]
# >Computation
# could not, it seemed, capture the violent quandary that was the nation’s
# history of and relationship to human bondage. Contemporary encounters
# with digital technology have inherited this tension, with researchers
# struggling to appreciate the inhumanity of bondage and the attendant
# dehumanization of black lives while also responding to the need for critical,
# rigorous, and engaged histories of slavery as histories of the present (18).
#
# > [D]isplaying data
# alone could not and did not offer the atonement descendants of slaves
# sought or capture the inhumanity of this archive’s formation. Culling
# the lives of women and children from the data set required approaching
# the data with intention. It required a methodology attuned to black life
# and to dismantling the methods used to create the manifests in the first
# place, then designing and launching an interface responsive to the desire
# of descendants of slaves for reparation and redress (65).
#
# > Jessica Marie Johnson, ["Markup Bodies: Black [Life] Studies and Slavery [Death] Studies at the Digital Crossroads"](https://read.dukeupress.edu/social-text/article/36/4%20(137)/57/137032/Markup-BodiesBlack-Life-Studies-and-Slavery-Death)

# %% [markdown]
# The dataset that you're going to be working with in this homework assignment is taken from [The Intra-American Slave Trade Database](https://www.slavevoyages.org/american/database), part of the [*Slave Voyages* project](https://www.slavevoyages.org/). This dataset was filtered to include only North American disembarkation locations and to include data about the percentage of men, women, and children on the voyages. Some column names have been altered or modified.

# %% [markdown]
# ## Required Reading

# %% [markdown]
# Before beginning this homework assignment, read through the short ["Introduction"](https://www.slavevoyages.org/american/about) to the Intra-American Slave Trade Database as well as the post ["Voyages and Applied History"](https://www.slavevoyages.org/voyage/essays). You will return to answer some questions about these readings at the end of the assignment.

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# **1.**

# %%
# Your Code Here

# %% [markdown]
# ## Read in CSV File

# %% [markdown]
# **2.**

# %% [markdown]
# Make a dataframe called `slave_intra_american_df` and read in the CSV file "Slave-Voyages-Intra-American-North-America.csv". Note that the rows in this CSV file are separated by tabs `\t`, not commas. They will thus require a different delimiter.

# %%
# Your Code Here

# %% [markdown]
# ## Display the Data

# %% [markdown]
# **3.**

# %% [markdown]
# Display the first 15 rows of the data.

# %%
# Your Code Here
# Out:
#     voyage_id       vessel_name             flag      place_of_slave_purchase  \
# 0      100026            Desire    Great Britain            Providence Island
# 1      100027           Rebecca    Great Britain    Jamaica, port unspecified
# 2      100028           Dolphin    Great Britain  St. Kitts, port unspecified
# 3      100029       Orange Tree    Great Britain                 Speightstown
# 4      100031     Saint Anthoni  Spain / Uruguay    Jamaica, port unspecified
# 5      100032       Spera Mundi      Netherlands                      Curacao
# 6      100033   Musch [Sparrow}      Netherlands                      Curacao
# 7      100034            Gideon      Netherlands                      Curacao
# 8      100035             Berry    Great Britain    Jamaica, port unspecified
# 9      100036                      Great Britain    Jamaica, port unspecified
# 10     100037  William and Mary    Great Britain   Barbados, port unspecified
# 11     100039             Molly    Great Britain   Barbados, port unspecified
# 12     100040             Molly    Great Britain   Barbados, port unspecified
# 13     100044             Nancy    Great Britain                     Kingston
# 14     100045            Vulcan    Great Britain                     Kingston
#
#        place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 0                             Boston               8                  7
# 1                             Boston               8                  7
# 2                             Boston               8                  7
# 3                             Boston              21                 20
# 4                           New York              44                 44
# 5                           New York               5                  4
# 6                           New York              40                 40
# 7                           New York             300                291
# 8                           New York              48                 46
# 9                           New York              92                 90
# 10                    Delaware River               4                  3
# 11                        Charleston             100                100
# 12                        Charleston              12                 11
# 13  South Carolina, port unspecified              11                 11
# 14  South Carolina, port unspecified               5                  5
#
#     year_of_arrival  percent_men  percent_women  percent_children  \
# 0              1638          NaN            NaN               NaN
# 1              1706          NaN            NaN               NaN
# 2              1726          NaN            NaN               NaN
# 3              1733          NaN            NaN               NaN
# 4              1652          NaN            NaN               NaN
# 5              1659          NaN            NaN               NaN
# 6              1664          NaN            NaN               NaN
# 7              1664          NaN            NaN               NaN
# 8              1711          NaN            NaN               NaN
# 9              1714          NaN            NaN               NaN
# 10             1761     0.333333            0.0          0.666667
# 11             1752     0.480000            0.2          0.320000
# 12             1753          NaN            NaN               NaN
# 13             1765          NaN            NaN               NaN
# 14             1765          NaN            NaN               NaN
#
#               captain's_name resistance_label
# 0            Pierce, William              NaN
# 1                Pitts, John              NaN
# 2         Millekin, Benjamin              NaN
# 3            Sheffield, John              NaN
# 4           Peres, Silvester              NaN
# 5             Pietersen, Jan              NaN
# 6       Pietersen Groot, Jan              NaN
# 7   Gilde, Simon Cornelissen              NaN
# 8              Scott, Walter              NaN
# 9            Vial, Nathaniel              NaN
# 10         Nicholson, George              NaN
# 11            Watts, Richard              NaN
# 12                     Watts              NaN
# 13          Jardine, William              NaN
# 14          Barger, Nicholas              NaN

# %% [markdown]
# Look at a random sample of 7 rows.

# %%
# Your Code Here
# Out:
#       voyage_id       vessel_name           flag  \
# 2275     106673             Sally         U.S.A.
# 3039     107520  Wheel of Fortune  Great Britain
# 1258     101312               Ann  Great Britain
# 1886     103963                    Great Britain
# 2687     107149              Hope  Great Britain
# 86       100117            Palmer  Great Britain
# 3366     107851            Hester  Great Britain
#
#              place_of_slave_purchase place_of_slave_disembarkation  \
# 2275       Jamaica, port unspecified                     Brunswick
# 3039  Rhode Island, port unspecified                      New York
# 1258      Barbados, port unspecified                       Hampton
# 1886      Americas, port unspecified                  Cecil County
# 2687       Jamaica, port unspecified                   Perth Amboy
# 86         Jamaica, port unspecified                    Charleston
# 3366                      St. Thomas                      New York
#
#       total_embarked  total_disembarked  year_of_arrival  percent_men  \
# 2275               6                  5             1786          NaN
# 3039               3                  2             1725          NaN
# 1258              19                 18             1749          NaN
# 1886               2                  1             1701          0.0
# 2687              33                 32             1734          NaN
# 86                 7                  6             1727          NaN
# 3366               2                  1             1737          NaN
#
#       percent_women  percent_children       captain's_name resistance_label
# 2275            NaN               NaN     Jocelin, Amaziah              NaN
# 3039            NaN               NaN         Bush, Jesper              NaN
# 1258            NaN               NaN        Miller, Mason              NaN
# 1886            1.0               0.0         Gray, Thomas              NaN
# 2687            NaN               NaN        Bedford, John              NaN
# 86              NaN               NaN       Palmer, Robert              NaN
# 3366            NaN               NaN  Garretson, Nicholas              NaN

# %% [markdown]
# ## Examine the Data

# %% [markdown]
# **4.**

# %%
# Your Code Here
# Out:
# (3575, 13)

# %% [markdown]
# **How many rows does this dataset include?**

# %% [markdown]
# **#** Type Your Answer Here

# %% [markdown]
# Check the data types of the columns in your dataset

# %%
# Your Code Here
# Out:
# voyage_id                          int64
# vessel_name                       object
# flag                              object
# place_of_slave_purchase           object
# place_of_slave_disembarkation     object
# total_embarked                     int64
# total_disembarked                  int64
# year_of_arrival                    int64
# percent_men                      float64
# percent_women                    float64
# percent_children                 float64
# captain's_name                    object
# resistance_label                  object
# dtype: object

# %% [markdown]
# ## Rename Column

# %% [markdown]
# **5.**

# %% [markdown]
# Rename the "flag" column as "national_affiliation." Don't forget to assign it to your original `slave_intra_american_df` dataframe so that the renamed column is saved. Display the first 5 rows of the `slave_intra_american_df` to check your work.

# %%
# Your Code Here

# %%
# Your Code Here
# Out:
#    voyage_id    vessel_name national_affiliation      place_of_slave_purchase  \
# 0     100026         Desire        Great Britain            Providence Island
# 1     100027        Rebecca        Great Britain    Jamaica, port unspecified
# 2     100028        Dolphin        Great Britain  St. Kitts, port unspecified
# 3     100029    Orange Tree        Great Britain                 Speightstown
# 4     100031  Saint Anthoni      Spain / Uruguay    Jamaica, port unspecified
#
#   place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 0                        Boston               8                  7
# 1                        Boston               8                  7
# 2                        Boston               8                  7
# 3                        Boston              21                 20
# 4                      New York              44                 44
#
#    year_of_arrival  percent_men  percent_women  percent_children  \
# 0             1638          NaN            NaN               NaN
# 1             1706          NaN            NaN               NaN
# 2             1726          NaN            NaN               NaN
# 3             1733          NaN            NaN               NaN
# 4             1652          NaN            NaN               NaN
#
#        captain's_name resistance_label
# 0     Pierce, William              NaN
# 1         Pitts, John              NaN
# 2  Millekin, Benjamin              NaN
# 3     Sheffield, John              NaN
# 4    Peres, Silvester              NaN

# %% [markdown]
# ## Select and Count Columns

# %% [markdown]
# **6.**

# %% [markdown]
# Select and display the column "place_of_slave_disembarkation"

# %%
# Your Code Here
# Out:
# 0            Boston
# 1            Boston
# 2            Boston
# 3            Boston
# 4          New York
#            ...
# 3570    New Orleans
# 3571    New Orleans
# 3572    New Orleans
# 3573    New Orleans
# 3574     Charleston
# Name: place_of_slave_disembarkation, Length: 3575, dtype: object

# %% [markdown]
# **7.**

# %% [markdown]
# Count the values in the column "place_of_slave_disembarkation"

# %%
# Your Code Here
# Out:
# Charleston                          875
# New York                            664
# Hampton                             334
# Savannah                            182
# Lower James River                   149
# Virginia, port unspecified          145
# New Orleans                         135
# North Carolina, port unspecified    126
# Philadelphia                        102
# South Carolina, port unspecified     90
# Upper James River                    75
# York River                           68
# Annapolis                            60
# Brunswick                            53
# Georgia, port unspecified            51
# Rappahannock                         43
# Cecil County                         42
# Patuxent                             36
# Maryland, port unspecified           29
# Louisiana                            27
# Perth Amboy                          26
# Boston                               26
# Oxford                               25
# Roanoke                              22
# St. Augustine                        21
# Sunbury                              16
# Potomac river                        15
# Mississippi                          15
# New Bern                             13
# Cape Fear                            11
# North Potomac                        10
# Beaufort                              9
# New London                            8
# Florida, port unspecified             7
# South Potomac                         7
# Pensacola                             7
# Georgetown                            7
# Pocomoke                              7
# Providence                            6
# Piscataqua                            6
# Accomac                               4
# Halifax                               3
# Carolinas                             3
# Mobile                                2
# USA, location unspecified             2
# Kittery Point                         1
# Newfoundland                          1
# Pennsylvania, port unspecified        1
# Amelia Island                         1
# Wilmington                            1
# Delaware River                        1
# Choptank                              1
# Nova Scotia                           1
# St. Mary's River                      1
# Rhode Island, port unspecified        1
# Pamunkey                              1
# Name: place_of_slave_disembarkation, dtype: int64

# %% [markdown]
# ## Filter Data

# %% [markdown]
# **8.**

# %% [markdown]
# Filter the dataset and display only the rows that included "New York" as their "place_of_slave_disembarkation". Save this data into a new variable called `new_york`

# %%
# Your Code Here
# Out:
#       voyage_id      vessel_name national_affiliation  \
# 4        100031    Saint Anthoni      Spain / Uruguay
# 5        100032      Spera Mundi          Netherlands
# 6        100033  Musch [Sparrow}          Netherlands
# 7        100034           Gideon          Netherlands
# 8        100035            Berry        Great Britain
# ...         ...              ...                  ...
# 3501     111475        Speedwell                  NaN
# 3502     111608      Don Charlos                  NaN
# 3503     111628   Jamaica Packet                  NaN
# 3504     111773           Ranger                  NaN
# 3505     111935                                   NaN
#
#         place_of_slave_purchase place_of_slave_disembarkation  total_embarked  \
# 4     Jamaica, port unspecified                      New York              44
# 5                       Curacao                      New York               5
# 6                       Curacao                      New York              40
# 7                       Curacao                      New York             300
# 8     Jamaica, port unspecified                      New York              48
# ...                         ...                           ...             ...
# 3501                    Curacao                      New York               1
# 3502                    Curacao                      New York               1
# 3503                    Curacao                      New York               1
# 3504                    Curacao                      New York               2
# 3505                    Curacao                      New York               3
#
#       total_disembarked  year_of_arrival  percent_men  percent_women  \
# 4                    44             1652          NaN            NaN
# 5                     4             1659          NaN            NaN
# 6                    40             1664          NaN            NaN
# 7                   291             1664          NaN            NaN
# 8                    46             1711          NaN            NaN
# ...                 ...              ...          ...            ...
# 3501                  1             1741          NaN            NaN
# 3502                  1             1745          0.0            1.0
# 3503                  1             1746          NaN            NaN
# 3504                  2             1755          NaN            NaN
# 3505                  2             1766          NaN            NaN
#
#       percent_children            captain's_name resistance_label
# 4                  NaN          Peres, Silvester              NaN
# 5                  NaN            Pietersen, Jan              NaN
# 6                  NaN      Pietersen Groot, Jan              NaN
# 7                  NaN  Gilde, Simon Cornelissen              NaN
# 8                  NaN             Scott, Walter              NaN
# ...                ...                       ...              ...
# 3501               NaN             Bayer, Samuel              NaN
# 3502               0.0              Kip, Abraham              NaN
# 3503               NaN            Righton, James              NaN
# 3504               NaN          Bethel, Benjamin              NaN
# 3505               NaN                       NaN              NaN
#
# [664 rows x 13 columns]

# %%
# Your Code Here

# %% [markdown]
# ## Sort Data

# %% [markdown]
# **9.**

# %% [markdown]
# Sort your smaller `new_york` dataframe by the "year_of_arrival", from the latest date to the earliest date

# %%
# Your Code Here
# Out:
#       voyage_id       vessel_name national_affiliation  \
# 3505     111935                                    NaN
# 3470     107956           Abraham        Great Britain
# 3469     107955              Hawk        Great Britain
# 3468     107954  General Monckton        Great Britain
# 2726     107193          Stamford        Great Britain
# ...         ...               ...                  ...
# 4        100031     Saint Anthoni      Spain / Uruguay
# 3229     107713         Tamandare          Netherlands
# 3471     107958          La Garce               France
# 3230     107714                          Great Britain
# 3495     107994        Bruynvisch          Netherlands
#
#            place_of_slave_purchase place_of_slave_disembarkation  \
# 3505                       Curacao                      New York
# 3470    Barbados, port unspecified                      New York
# 3469    Barbados, port unspecified                      New York
# 3468  Montserrat, port unspecified                      New York
# 2726                        Boston                      New York
# ...                            ...                           ...
# 4        Jamaica, port unspecified                      New York
# 3229      Brazil, port unspecified                      New York
# 3471    Americas, port unspecified                      New York
# 3230         Prize (unknown place)                      New York
# 3495  Pernambuco, port unspecified                      New York
#
#       total_embarked  total_disembarked  year_of_arrival  percent_men  \
# 3505               3                  2             1766          NaN
# 3470               9                  8             1764          NaN
# 3469               6                  5             1763          NaN
# 3468               5                  4             1763          NaN
# 2726               6                  6             1762          NaN
# ...              ...                ...              ...          ...
# 4                 44                 44             1652          NaN
# 3229              13                 12             1646          NaN
# 3471              59                 57             1642          NaN
# 3230               4                  3             1636          NaN
# 3495              52                 50             1630          NaN
#
#       percent_women  percent_children    captain's_name resistance_label
# 3505            NaN               NaN               NaN              NaN
# 3470            NaN               NaN   Henderson, John              NaN
# 3469            NaN               NaN  Jenkins, Charles              NaN
# 3468            NaN               NaN  Campbell, Andrew              NaN
# 2726            NaN               NaN   Wimble, William              NaN
# ...             ...               ...               ...              ...
# 4               NaN               NaN  Peres, Silvester              NaN
# 3229            NaN               NaN               NaN              NaN
# 3471            NaN               NaN               NaN              NaN
# 3230            NaN               NaN     Ax, [Samuel?]              NaN
# 3495            NaN               NaN               NaN              NaN
#
# [664 rows x 13 columns]

# %% [markdown]
# ## Groupby and Plot

# %% [markdown]
# **10.**

# %% [markdown]
# Calculate how many enslaved people were transported by each nation. Group your `new_york` dataframe by "national_affiliation" and then calculate the sum of "total_disembarked". Then save this data into a variable called `national_totals`

# %%
# Your Code Here
# Out:
# national_affiliation
# France               57
# Great Britain      3486
# Netherlands         397
# Spain / Uruguay      44
# Name: total_disembarked, dtype: int64

# %%
# Your Code Here

# %% [markdown]
# **11.**

# %% [markdown]
# Make a bar chart out of the `national_totals` data

# %%
# Your Code Here

# %% [markdown]
# ## Think Intentionally With The Data

# %% [markdown]
# **12.**

# %% [markdown]
# Re-read or re-skim the short ["Introduction"](https://www.slavevoyages.org/american/about) to the Intra-American Slave Trade Database as well as the post ["Voyages and Applied History"](https://www.slavevoyages.org/voyage/essays). Drawing on these readings and your experience working with the data above, write a 100-word response about how you or another researcher might use this data *intentionally* — in a way that resists the dehumanizing quantification that created it in the first place and contributes to efforts toward justice.

# %% [markdown]
# **#** Type Your 100-Word Response Here
#
#
# ...
#
#
# ...
#
# ...
