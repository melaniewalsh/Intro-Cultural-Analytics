# %% [markdown]
# ## Part-of-Speech Tagging & Keyword Extraction — Code

# %% [markdown]
# [Download relevant files](https://melaniewalsh.org/spacy.zip)

# %% [markdown]
# This notebook is a streamlined version of a previous lesson on **part-of-speech tagging**. It is primarily intended for those who want to reuse the code without the previous lessons' overview and explanations.

# %% [markdown]
# <img src="../images/Ada-Lovelace-NER.png" >

# %% [markdown]
# ## Install spaCy

# %% [markdown]
# To use spaCy, we first need to install the library.

# %%
# !pip install -U spacy

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Then we're going to import `spacy` and `displacy`, a special spaCy module for visualization.

# %%
import spacy
from spacy import displacy

# %% [markdown]
# We're also going to import the `Counter` module for counting people, places, and things later on; the `pandas` library for organizing and displaying data (we're also changing the pandas default max row and column width display setting).

# %%
from collections import Counter

# %%
import pandas as pd
pd.set_option("max_rows", 400)
pd.set_option("max_colwidth", 400)

# %% [markdown]
# ## Download Language Model

# %% [markdown]
# Next we need to download the English-language model (`en_core_web_sm`), which will be processing and making predictions about our texts. This is the model that was trained on the annotated "OntoNotes" corpus. You can download the `en_core_web_sm` model by running the cell below:

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /Users/melaniewalsh/anaconda3/lib/python3.7/site-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %% [markdown]
# *Note: spaCy offers [models for other languages](https://spacy.io/usage/models#languages) including German, French, Spanish, Portuguese, Italian, Dutch, Greek, Norwegian, and Lithuanian. Languages such as Russian, Ukrainian, Thai, Chinese, Japanese, Korean and Vietnamese don't currently have their own NLP models. However, spaCy offers language and tokenization support for many of these language with external dependencies — such as [PyviKonlpy](https://github.com/konlpy/konlpy) for Korean or [Jieba](https://github.com/fxsjy/jieba) for Chinese.*

# %% [markdown]
# ## Load Language Model

# %% [markdown]
# Once the model is downloaded, we need to load it with `spacy.load()` and assign it to the variable `nlp`.

# %%
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## Create a Processed spaCy Document

# %% [markdown]
# `document = nlp(open(filepath, , encoding='utf-8').read())`

# %%
filepath = "../texts/history/NYT-Obituaries/1852-Ada-Lovelace.txt"

document = nlp(open(filepath, encoding='utf-8').read())

# %% [markdown]
# ## Get Part-Of-Speech Tags

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# To get part of speech tags for every word in a document, we have to iterate through all the tokens in the document and pull out the `.pos_` attribute for each token. We can get even finer-grained dependency information with the attribute `.dep_`.

# %%
for token in document:
    print(token.text, token.pos_, token.dep_)
# Out:
# A DET det
# gifted ADJ amod
# mathematician NOUN ROOT
# who PRON nsubjpass
# is VERB auxpass
# now ADV advmod
# recognized VERB relcl
# as ADP prep
# the DET det
# first ADJ amod
# computer NOUN compound
# programmer NOUN pobj
# . PUNCT punct
# By ADP ROOT
# CLAIRE PROPN pobj
# CAIN PROPN compound
# MILLER ADV pobj
#
#
#   SPACE
# A DET det
# century NOUN npadvmod
# before ADP prep
# the DET det
# dawn NOUN pobj
# of ADP prep
# the DET det
# computer NOUN compound
# age NOUN pobj
# , PUNCT punct
# Ada PROPN compound
# Lovelace PROPN nsubj
# imagined VERB ROOT
# the DET det
# modern ADJ amod
# - PUNCT punct
# day NOUN nmod
# , PUNCT punct
# general ADJ amod
# - PUNCT punct
# purpose NOUN compound
# computer NOUN dobj
# . PUNCT punct
# It PRON nsubjpass
# could VERB aux
# be VERB auxpass
# programmed VERB ccomp
# to PART aux
# follow VERB xcomp
# instructions NOUN dobj
# , PUNCT punct
# she PRON nsubj
# wrote VERB ROOT
# in ADP prep
# 1843 NUM pobj
# . PUNCT punct
# It PRON nsubj
# could VERB aux
# not ADV neg
# just ADV advmod
# calculate VERB ROOT
# but CCONJ cc
# also ADV advmod
# create VERB conj
# , PUNCT punct
# as ADP mark
# it PRON nsubj
# “ PUNCT nsubj
# weaves VERB advcl
# algebraic ADJ compound
# patterns NOUN dobj
# just ADV advmod
# as ADP mark
# the DET det
# Jacquard PROPN nsubj
# loom NOUN advcl
# weaves VERB compound
# flowers NOUN dobj
# and CCONJ cc
# leaves NOUN conj
# . PUNCT punct
# ” PUNCT ROOT
# The DET det
# computer NOUN nsubjpass
# she PRON nsubj
# was VERB aux
# writing VERB relcl
# about ADP prep
# , PUNCT punct
# the DET det
# British ADJ amod
# inventor NOUN nsubjpass
# Charles PROPN compound
# Babbage PROPN compound
# ’s PROPN compound
# Analytical PROPN compound
# Engine PROPN appos
# , PUNCT punct
# was VERB auxpass
# never ADV neg
# built VERB ROOT
# . PUNCT punct
# But CCONJ cc
# her DET poss
# writings NOUN nsubj
# about ADP prep
# computing VERB pobj
# have VERB aux
# earned VERB ROOT
# Lovelace PROPN compound
# — PUNCT dobj
# who PRON nsubj
# died VERB relcl
# of ADP prep
# uterine ADJ amod
# cancer NOUN pobj
# in ADP prep
# 1852 NUM pobj
# at ADP prep
# 36 NUM nummod
# — NUM compound
# recognition NOUN pobj
# as ADP prep
# the DET det
# first ADJ amod
# computer NOUN compound
# programmer NOUN pobj
# . PUNCT punct
#
#
#   SPACE
# The DET det
# program NOUN nsubj
# she PRON nsubj
# wrote VERB relcl
# for ADP dative
# the DET det
# Analytical PROPN compound
# Engine PROPN pobj
# was VERB ROOT
# to PART aux
# calculate VERB xcomp
# the DET det
# seventh ADJ amod
# Bernoulli PROPN compound
# number NOUN dobj
# . PUNCT punct
# ( PUNCT punct
# Bernoulli PROPN compound
# numbers NOUN nsubjpass
# , PUNCT punct
# named VERB acl
# after ADP prep
# the DET det
# Swiss ADJ amod
# mathematician NOUN amod
# Jacob PROPN compound
# Bernoulli PROPN pobj
# , PUNCT punct
# are VERB auxpass
# used VERB ROOT
# in ADP prep
# many ADJ amod
# different ADJ amod
# areas NOUN pobj
# of ADP prep
# mathematics NOUN pobj
# . PUNCT punct
# ) PUNCT punct
# But CCONJ cc
# her DET poss
# deeper ADJ amod
# influence NOUN nsubj
# was VERB ROOT
# to PART aux
# see VERB xcomp
# the DET det
# potential NOUN dobj
# of ADP prep
# computing NOUN pobj
# . PUNCT punct
# The DET det
# machines NOUN nsubj
# could VERB aux
# go VERB ROOT
# beyond ADP prep
# calculating VERB amod
# numbers NOUN pobj
# , PUNCT punct
# she PRON nsubj
# said VERB parataxis
# , PUNCT punct
# to PART aux
# understand VERB advcl
# symbols NOUN dobj
# and CCONJ cc
# be VERB auxpass
# used VERB conj
# to PART aux
# create VERB xcomp
# music NOUN dobj
# or CCONJ cc
# art NOUN conj
# . PUNCT punct
#
#
#   SPACE
# “ PUNCT ROOT
# This DET det
# insight NOUN nsubj
# would VERB aux
# become VERB ccomp
# the DET det
# core NOUN compound
# concept NOUN attr
# of ADP prep
# the DET det
# digital ADJ amod
# age NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# Walter PROPN compound
# Isaacson PROPN nsubj
# wrote VERB ROOT
# in ADP prep
# his DET poss
# book NOUN pobj
# “ PROPN punct
# The DET det
# Innovators PROPN appos
# . PUNCT punct
# ” PUNCT punct
# “ PUNCT ROOT
# Any DET det
# piece NOUN nsubjpass
# of ADP prep
# content NOUN pobj
# , PUNCT punct
# data NOUN conj
# or CCONJ cc
# information NOUN compound
# — CCONJ compound
# music NOUN conj
# , PUNCT punct
# text NOUN conj
# , PUNCT punct
# pictures NOUN conj
# , PUNCT punct
# numbers NOUN conj
# , PUNCT punct
# symbols NOUN conj
# , PUNCT punct
# sounds NOUN conj
# , PUNCT punct
# video NOUN compound
# — PUNCT conj
# could VERB aux
# be VERB auxpass
# expressed VERB ROOT
# in ADP prep
# digital ADJ amod
# form NOUN pobj
# and CCONJ cc
# manipulated VERB conj
# by ADP agent
# machines NOUN pobj
# . PUNCT punct
# ” PUNCT ROOT
# She PRON nsubj
# also ADV advmod
# explored VERB ROOT
# the DET det
# ramifications NOUN dobj
# of ADP prep
# what PRON dobj
# a DET det
# computer NOUN nsubj
# could VERB aux
# do VERB pcomp
# , PUNCT punct
# writing VERB advcl
# about ADP prep
# the DET det
# responsibility NOUN pobj
# placed VERB acl
# on ADP prep
# the DET det
# person NOUN pobj
# programming VERB acl
# the DET det
# machine NOUN dobj
# , PUNCT punct
# and CCONJ cc
# raising VERB conj
# and CCONJ cc
# then ADV advmod
# dismissing VERB conj
# the DET det
# notion NOUN dobj
# that ADP mark
# computers NOUN nsubj
# could VERB aux
# someday ADV advmod
# think VERB acl
# and CCONJ cc
# create VERB conj
# on ADP prep
# their DET poss
# own ADJ amod
# — PUNCT pobj
# what PRON dobj
# we PRON nsubj
# now ADV advmod
# call VERB ccomp
# artificial ADJ amod
# intelligence NOUN oprd
# . PUNCT punct
#
#
#   SPACE
# “ PUNCT ROOT
# The DET det
# Analytical PROPN compound
# Engine PROPN nsubj
# has VERB ccomp
# no DET det
# pretensions NOUN dobj
# whatever DET dep
# to PART aux
# originate VERB acl
# any DET det
# thing NOUN dobj
# , PUNCT punct
# ” PUNCT punct
# she PRON nsubj
# wrote VERB ROOT
# . PUNCT punct
# “ NOUN ROOT
# It PRON nsubj
# can VERB aux
# do VERB ROOT
# whatever DET nsubj
# we PRON nsubj
# know VERB ccomp
# how ADV advmod
# to PART aux
# order VERB xcomp
# it PRON dobj
# to PART aux
# perform VERB xcomp
# . PUNCT punct
# ” PUNCT ROOT
#
#
#   SPACE
# Lovelace PROPN nsubj
# , PUNCT punct
# a DET det
# British ADJ amod
# socialite NOUN appos
# who PRON nsubj
# was VERB relcl
# the DET det
# daughter NOUN attr
# of ADP prep
# Lord PROPN compound
# Byron PROPN pobj
# , PUNCT punct
# the DET det
# Romantic ADJ amod
# poet NOUN appos
# , PUNCT punct
# had VERB ccomp
# a DET det
# gift NOUN dobj
# for ADP prep
# combining VERB pcomp
# art NOUN dobj
# and CCONJ cc
# science NOUN conj
# , PUNCT punct
# one NUM appos
# of ADP prep
# her DET poss
# biographers NOUN pobj
# , PUNCT punct
# Betty PROPN compound
# Alexandra PROPN compound
# Toole PROPN appos
# , PUNCT punct
# has VERB aux
# written VERB ROOT
# . PUNCT punct
# She PRON nsubj
# thought VERB ROOT
# of ADP prep
# math NOUN pobj
# and CCONJ cc
# logic NOUN conj
# as ADP prep
# creative ADJ amod
# and CCONJ cc
# imaginative ADJ conj
# , PUNCT punct
# and CCONJ cc
# called VERB conj
# it PRON dobj
# “ PUNCT oprd
# poetical ADJ amod
# science NOUN oprd
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# Math PROPN compound
# “ PROPN nsubj
# constitutes VERB ccomp
# the DET det
# language NOUN dobj
# through ADP prep
# which DET pobj
# alone ADV advmod
# we PRON nsubj
# can VERB aux
# adequately ADV advmod
# express VERB relcl
# the DET det
# great ADJ amod
# facts NOUN dobj
# of ADP prep
# the DET det
# natural ADJ amod
# world NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# Lovelace PROPN nsubj
# wrote VERB ROOT
# . PUNCT punct
#
#
#   SPACE
# Her DET poss
# work NOUN nsubj
# , PUNCT punct
# which DET nsubjpass
# was VERB auxpass
# rediscovered VERB relcl
# in ADP prep
# the DET det
# mid-20th PROPN nummod
# century NOUN pobj
# , PUNCT punct
# inspired VERB ROOT
# the DET det
# Defense PROPN compound
# Department PROPN dobj
# to PART aux
# name VERB xcomp
# a DET det
# programming NOUN compound
# language NOUN dobj
# after ADP mark
# her PRON nsubj
# and CCONJ cc
# each DET det
# October PROPN compound
# Ada PROPN compound
# Lovelace PROPN compound
# Day PROPN conj
# signifies VERB advcl
# a DET det
# celebration NOUN dobj
# of ADP prep
# women NOUN pobj
# in ADP prep
# technology NOUN pobj
# . PUNCT punct
# Lovelace PROPN nsubj
# lived VERB ROOT
# when ADV advmod
# women NOUN nsubjpass
# were VERB auxpass
# not ADV neg
# considered VERB advcl
# to PART aux
# be VERB xcomp
# prominent ADJ amod
# scientific ADJ amod
# thinkers NOUN attr
# , PUNCT punct
# and CCONJ cc
# her DET poss
# skills NOUN nsubjpass
# were VERB auxpass
# often ADV advmod
# described VERB conj
# as ADP prep
# masculine ADJ pobj
# . PUNCT punct
#
#
#   SPACE
# “ PROPN ROOT
# With ADP prep
# an DET det
# understanding NOUN pobj
# thoroughly ADV advmod
# masculine NOUN amod
# in ADP prep
# solidity NOUN pobj
# , PUNCT punct
# grasp NOUN conj
# and CCONJ cc
# firmness NOUN conj
# , PUNCT punct
# Lady PROPN compound
# Lovelace PROPN nsubj
# had VERB ccomp
# all DET predet
# the DET det
# delicacies NOUN dobj
# of ADP prep
# the DET det
# most ADV advmod
# refined VERB amod
# female ADJ amod
# character NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# said VERB ROOT
# an DET det
# obituary NOUN nsubj
# in ADP prep
# The DET det
# London PROPN compound
# Examiner PROPN pobj
# . PUNCT punct
#
#
#   SPACE
# Babbage PROPN nsubj
# , PUNCT punct
# who PRON nsubj
# called VERB relcl
# her PRON dobj
# the DET det
# “ NOUN compound
# enchantress NOUN oprd
# of ADP prep
# numbers NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# once ADV advmod
# wrote VERB ROOT
# that ADP mark
# she PRON nsubj
# “ PROPN nsubj
# has VERB aux
# thrown VERB ccomp
# her DET poss
# magical ADJ amod
# spell NOUN dobj
# around ADP prep
# the DET det
# most ADV amod
# abstract ADJ pobj
# of ADP prep
# Sciences PROPN pobj
# and CCONJ cc
# has VERB aux
# grasped VERB conj
# it PRON dobj
# with ADP prep
# a DET det
# force NOUN pobj
# which DET det
# few ADJ amod
# masculine ADJ amod
# intellects NOUN relcl
# ( PUNCT punct
# in ADP prep
# our DET poss
# own ADJ amod
# country NOUN pobj
# at ADP advmod
# least ADV advmod
# ) PUNCT punct
# could VERB aux
# have VERB aux
# exerted VERB ccomp
# over ADP prep
# it PRON pobj
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# Augusta PROPN compound
# Ada PROPN compound
# Byron PROPN nsubjpass
# was VERB auxpass
# born VERB ccomp
# on ADP prep
# Dec. PROPN pobj
# 10 NUM nummod
# , PUNCT punct
# 1815 NUM nummod
# , PUNCT punct
# in ADP prep
# London PROPN pobj
# , PUNCT punct
# to ADP prep
# Lord PROPN compound
# Byron PROPN pobj
# and CCONJ cc
# Annabella PROPN compound
# Milbanke PROPN conj
# . PUNCT punct
# Her DET poss
# parents NOUN nsubj
# separated VERB ROOT
# when ADV advmod
# she PRON nsubj
# was VERB advcl
# an DET det
# infant NOUN attr
# , PUNCT punct
# and CCONJ cc
# her DET poss
# father NOUN nsubj
# died VERB conj
# when ADV advmod
# she PRON nsubj
# was VERB advcl
# 8 NUM attr
# . PUNCT punct
# Her DET poss
# mother NOUN nsubj
# — PUNCT ROOT
# whom PRON dobj
# Lord PROPN compound
# Byron PROPN nsubj
# called VERB ccomp
# the DET det
# “ PROPN compound
# princess NOUN oprd
# of ADP prep
# parallelograms NOUN pobj
# ” PUNCT punct
# and CCONJ cc
# , PUNCT punct
# after ADP prep
# their DET poss
# falling VERB pcomp
# out PART prt
# , PUNCT punct
# a DET det
# “ PROPN nmod
# mathematical ADJ amod
# Medea PROPN nmod
# ” PUNCT punct
# — PROPN nsubj
# was VERB conj
# a DET det
# social ADJ amod
# reformer NOUN attr
# from ADP prep
# a DET det
# wealthy ADJ amod
# family NOUN pobj
# who PRON nsubj
# had VERB relcl
# a DET det
# deep ADJ amod
# interest NOUN dobj
# in ADP prep
# mathematics NOUN pobj
# . PUNCT punct
#
#
#   SPACE
# An DET det
# etching NOUN ROOT
# from ADP prep
# a DET det
# portrait NOUN pobj
# of ADP prep
# Lovelace PROPN pobj
# as ADP prep
# a DET det
# child NOUN pobj
# . PUNCT punct
# She PRON nsubjpass
# is VERB auxpass
# said VERB ROOT
# to PART aux
# have VERB aux
# had VERB xcomp
# a DET det
# gift NOUN dobj
# for ADP prep
# combining VERB pcomp
# art NOUN dobj
# and CCONJ cc
# science NOUN conj
# . PUNCT punct
# Smith PROPN compound
# Collection PROPN nmod
# / SYM punct
# Gado PROPN nmod
# / SYM punct
# Getty PROPN compound
# Images PROPN nmod
#
#
#   SPACE
# Lovelace PROPN nsubj
# showed VERB ROOT
# a DET det
# passion NOUN dobj
# for ADP prep
# math NOUN pobj
# and CCONJ cc
# mechanics NOUN conj
# from ADP prep
# a DET det
# young ADJ amod
# age NOUN pobj
# , PUNCT punct
# encouraged VERB conj
# by ADP agent
# her DET poss
# mother NOUN pobj
# . PUNCT punct
# Because ADP prep
# of ADP pcomp
# her DET poss
# class NOUN pobj
# , PUNCT punct
# she PRON nsubj
# had VERB ROOT
# access NOUN dobj
# to ADP prep
# private ADJ amod
# tutors NOUN pobj
# and CCONJ cc
# to ADP conj
# intellectuals NOUN pobj
# in ADP prep
# British ADJ amod
# scientific ADJ amod
# and CCONJ cc
# literary ADJ conj
# society NOUN pobj
# . PUNCT punct
# She PRON nsubj
# was VERB ROOT
# insatiably ADV advmod
# curious ADJ acomp
# and CCONJ cc
# surrounded VERB conj
# herself PRON dobj
# with ADP prep
# big ADJ amod
# thinkers NOUN pobj
# of ADP prep
# the DET det
# day NOUN pobj
# , PUNCT punct
# including VERB prep
# Mary PROPN compound
# Somerville PROPN pobj
# , PUNCT punct
# a DET det
# scientist NOUN appos
# and CCONJ cc
# writer NOUN conj
# . PUNCT punct
#
#
#   SPACE
# It PRON nsubj
# was VERB ROOT
# Somerville PROPN attr
# who PRON nsubj
# introduced VERB relcl
# Lovelace PROPN dobj
# to ADP prep
# Babbage PROPN pobj
# when ADV advmod
# she PRON nsubj
# was VERB advcl
# 17 NUM attr
# , PUNCT punct
# at ADP prep
# a DET det
# salon NOUN pobj
# he PRON nsubj
# hosted VERB relcl
# soon ADV advmod
# after ADP mark
# she PRON nsubj
# made VERB advcl
# her DET poss
# society NOUN nsubj
# debut NOUN dobj
# . PUNCT punct
# He PRON nsubj
# showed VERB ROOT
# her PRON dative
# a DET det
# two NUM nummod
# - PUNCT punct
# foot NOUN npadvmod
# high ADJ amod
# , PUNCT punct
# brass NOUN nmod
# mechanical ADJ amod
# calculator NOUN dobj
# he PRON nsubj
# had VERB aux
# built VERB relcl
# , PUNCT punct
# and CCONJ cc
# it PRON nsubj
# gripped VERB conj
# her DET poss
# imagination NOUN dobj
# . PUNCT punct
# They PRON nsubj
# began VERB ROOT
# a DET det
# correspondence NOUN dobj
# about ADP prep
# math NOUN pobj
# and CCONJ cc
# science NOUN conj
# that DET nsubj
# lasted VERB relcl
# almost ADV advmod
# two NUM nummod
# decades NOUN npadvmod
# . PUNCT punct
#
#
#   SPACE
# She PRON nsubj
# also ADV advmod
# met VERB ROOT
# her DET poss
# husband NOUN dobj
# , PUNCT punct
# William PROPN compound
# King PROPN appos
# , PUNCT punct
# through ADP prep
# Somerville PROPN pobj
# . PUNCT punct
# They PRON nsubj
# married VERB ROOT
# in ADP prep
# 1835 NUM pobj
# , PUNCT punct
# when ADV advmod
# she PRON nsubj
# was VERB relcl
# 19 NUM attr
# . PUNCT punct
# He PRON nsubj
# soon ADV advmod
# became VERB ROOT
# an DET det
# earl NOUN attr
# , PUNCT punct
# and CCONJ cc
# she PRON nsubj
# became VERB conj
# the DET det
# Countess PROPN attr
# of ADP prep
# Lovelace PROPN pobj
# . PUNCT punct
# By ADP prep
# 1839 NUM pobj
# , PUNCT punct
# she PRON nsubj
# had VERB aux
# given VERB ROOT
# birth NOUN dobj
# to ADP prep
# two NUM nummod
# sons NOUN pobj
# and CCONJ cc
# a DET det
# daughter NOUN conj
# . PUNCT punct
#
#
#   SPACE
# She PRON nsubj
# was VERB ROOT
# determined VERB acomp
# , PUNCT punct
# however ADV advmod
# , PUNCT punct
# not ADV neg
# to PART aux
# let VERB xcomp
# her DET poss
# family NOUN compound
# life NOUN nsubj
# slow VERB ccomp
# her DET poss
# work NOUN dobj
# . PUNCT punct
# The DET det
# year NOUN npadvmod
# she PRON nsubj
# was VERB relcl
# married VERB acomp
# , PUNCT punct
# she PRON nsubj
# wrote VERB ROOT
# to ADP prep
# Somerville PROPN pobj
# : PUNCT punct
# “ PUNCT ROOT
# I PRON nsubj
# now ADV advmod
# read VERB ROOT
# Mathematics PROPN dobj
# every DET det
# day NOUN npadvmod
# and CCONJ cc
# am VERB auxpass
# occupied VERB conj
# in ADP prep
# Trigonometry PROPN pobj
# and CCONJ cc
# in ADP conj
# preliminaries NOUN pobj
# to ADP prep
# Cubic PROPN nmod
# and CCONJ cc
# Biquadratic PROPN conj
# Equations PROPN pobj
# . PUNCT punct
# So ADV advmod
# you PRON nsubj
# see VERB ROOT
# that DET det
# matrimony NOUN nsubj
# has VERB aux
# by ADP prep
# no DET det
# means NOUN pobj
# lessened VERB ccomp
# my DET poss
# taste NOUN dobj
# for ADP prep
# these DET det
# pursuits NOUN pobj
# , PUNCT punct
# nor CCONJ cc
# my DET poss
# determination NOUN conj
# to PART aux
# carry VERB acl
# them PRON dobj
# on PART prt
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# In ADP prep
# 1840 NUM pobj
# , PUNCT punct
# Lovelace PROPN nsubj
# asked VERB ROOT
# Augustus PROPN compound
# De PROPN compound
# Morgan PROPN dobj
# , PUNCT punct
# a DET det
# math NOUN compound
# professor NOUN appos
# in ADP prep
# London PROPN pobj
# , PUNCT punct
# to PART aux
# tutor VERB xcomp
# her PRON dobj
# . PUNCT punct
# Through ADP prep
# exchanging VERB pcomp
# letters NOUN dobj
# , PUNCT punct
# he PRON nsubj
# taught VERB ROOT
# her DET poss
# university NOUN compound
# - PUNCT punct
# level NOUN compound
# math NOUN dobj
# . PUNCT punct
# He PRON nsubj
# later ADV advmod
# wrote VERB ROOT
# to ADP dative
# her DET poss
# mother NOUN pobj
# that ADP mark
# if ADP mark
# a DET det
# young ADJ amod
# male NOUN compound
# student NOUN nsubj
# had VERB aux
# shown VERB advcl
# her DET poss
# skill NOUN dobj
# , PUNCT punct
# “ PROPN punct
# they PRON nsubj
# would VERB aux
# have VERB aux
# certainly ADV advmod
# made VERB ccomp
# him PRON nsubj
# an DET det
# original ADJ amod
# mathematical ADJ amod
# investigator NOUN ccomp
# , PUNCT punct
# perhaps ADV advmod
# of ADP prep
# first ADJ amod
# - PUNCT punct
# rate NOUN compound
# eminence NOUN pobj
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# It PRON nsubj
# was VERB ROOT
# in ADP prep
# 1843 NUM pobj
# , PUNCT punct
# when ADV advmod
# she PRON nsubj
# was VERB relcl
# 27 NUM attr
# , PUNCT punct
# that ADP mark
# Lovelace PROPN nsubj
# wrote VERB ccomp
# her PRON poss
# most ADV advmod
# lasting ADJ amod
# contribution NOUN dobj
# to ADP prep
# computer NOUN compound
# science NOUN pobj
# . PUNCT punct
#
#
#   SPACE
# She PRON nsubj
# published VERB ROOT
# her DET poss
# translation NOUN dobj
# of ADP prep
# an DET det
# academic ADJ amod
# paper NOUN pobj
# about ADP prep
# the DET det
# Babbage PROPN compound
# Analytical PROPN compound
# Engine PROPN pobj
# and CCONJ cc
# added VERB conj
# a DET det
# section NOUN dobj
# , PUNCT punct
# nearly ADV advmod
# three NUM nummod
# times NOUN quantmod
# the DET det
# length NOUN appos
# of ADP prep
# the DET det
# paper NOUN pobj
# , PUNCT punct
# titled VERB acl
# , PUNCT punct
# “ PROPN compound
# Notes NOUN oprd
# . PUNCT punct
# ” PUNCT ROOT
# Here ADV advmod
# , PUNCT punct
# she PRON nsubj
# described VERB ROOT
# how ADV advmod
# the DET det
# computer NOUN nsubj
# would VERB aux
# work VERB ccomp
# , PUNCT punct
# imagined VERB conj
# its DET poss
# potential NOUN dobj
# and CCONJ cc
# wrote VERB conj
# the DET det
# first ADJ amod
# program NOUN dobj
# . PUNCT punct
#
#
#   SPACE
# Researchers NOUN nsubj
# have VERB aux
# come VERB ccomp
# to PART aux
# see VERB advcl
# it PRON dobj
# as ADP prep
# “ PUNCT pobj
# an DET det
# extraordinary ADJ amod
# document NOUN dobj
# , PUNCT punct
# ” PUNCT punct
# said VERB ROOT
# Ursula PROPN compound
# Martin PROPN nsubj
# , PUNCT punct
# a DET det
# computer NOUN compound
# scientist NOUN appos
# at ADP prep
# the DET det
# University PROPN pobj
# of ADP prep
# Oxford PROPN pobj
# who PRON nsubj
# has VERB aux
# studied VERB relcl
# Lovelace PROPN compound
# ’s PROPN dobj
# life NOUN dobj
# and CCONJ cc
# work NOUN conj
# . PUNCT punct
# “ PUNCT ROOT
# She PRON compound
# ’s PROPN nsubj
# talking VERB ROOT
# about ADP prep
# the DET det
# abstract ADJ amod
# principles NOUN pobj
# of ADP prep
# computation NOUN pobj
# , PUNCT punct
# how ADV advmod
# you PRON nsubj
# could VERB aux
# program VERB ccomp
# it PRON dobj
# , PUNCT punct
# and CCONJ cc
# big ADJ amod
# ideas NOUN conj
# like ADP prep
# maybe ADV advmod
# it PRON nsubj
# could VERB aux
# compose VERB ccomp
# music NOUN dobj
# , PUNCT punct
# maybe ADV advmod
# it PRON nsubj
# could VERB aux
# think VERB ROOT
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# Lovelace PROPN nsubj
# died VERB ROOT
# less ADJ advmod
# than ADP prep
# a DET det
# decade NOUN npadvmod
# later ADV pcomp
# , PUNCT punct
# on ADP prep
# Nov. PROPN pobj
# 27 NUM nummod
# , PUNCT punct
# 1852 NUM nummod
# . PUNCT punct
# In ADP prep
# the DET det
# “ PROPN compound
# Notes PROPN pobj
# , PUNCT punct
# ” PUNCT punct
# she PRON nsubj
# imagined VERB ROOT
# a DET det
# future NOUN dobj
# in ADP prep
# which DET pobj
# computers NOUN nsubj
# could VERB aux
# do VERB relcl
# more ADV advmod
# powerful ADJ amod
# and CCONJ cc
# faster ADJ conj
# analysis NOUN dobj
# than ADP prep
# humans NOUN pobj
# . PUNCT punct
#
#
#   SPACE
# “ PROPN ROOT
# A DET det
# new ADJ nsubjpass
# , PUNCT punct
# a DET det
# vast ADJ conj
# and CCONJ cc
# a DET det
# powerful ADJ amod
# language NOUN conj
# is VERB auxpass
# developed VERB ccomp
# for ADP prep
# the DET det
# future ADJ amod
# use NOUN pobj
# of ADP prep
# analysis NOUN pobj
# , PUNCT punct
# ” PUNCT punct
# she PRON nsubj
# wrote VERB ROOT
# , PUNCT punct
# “ PROPN punct
# in ADP prep
# which DET pobj
# to PART aux
# wield VERB ccomp
# its DET poss
# truths NOUN dobj
# so ADP mark
# that ADP mark
# these DET nsubj
# may VERB aux
# become VERB advcl
# of ADP prep
# more ADV advmod
# speedy ADJ amod
# and CCONJ cc
# accurate ADJ conj
# practical ADJ amod
# application NOUN pobj
# for ADP prep
# the DET det
# purposes NOUN pobj
# of ADP prep
# mankind NOUN pobj
# . PUNCT punct
# ” PUNCT punct
#
#
#   SPACE
# Claire PROPN compound
# Cain PROPN compound
# Miller PROPN nsubj
# writes VERB ROOT
# about ADP prep
# gender NOUN pobj
# for ADP prep
# The DET det
# Upshot PROPN pobj
# . PUNCT punct
# She PRON nsubj
# first ADV advmod
# learned VERB ROOT
# about ADP prep
# Ada PROPN compound
# Lovelace PROPN pobj
# while ADP mark
# covering VERB advcl
# the DET det
# tech NOUN compound
# industry NOUN dobj
# , PUNCT punct
# where ADV advmod
# women NOUN nsubj
# are VERB relcl
# severely ADV advmod
# underrepresented ADJ acomp
# . PUNCT punct

# %% [markdown]
# ## Get Verbs

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |

# %%
verbs = [token.text for token in document if token.pos_ == 'VERB']
verbs_tally = Counter(verbs)
df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#             verb  count
# 0            was     18
# 1          could     11
# 2          wrote     11
# 3            had      8
# 4            has      6
# 5           have      5
# 6             be      4
# 7           said      4
# 8             is      3
# 9       imagined      3
# 10        create      3
# 11          died      3
# 12           see      3
# 13         would      3
# 14            do      3
# 15        called      3
# 16     calculate      2
# 17        weaves      2
# 18       writing      2
# 19         built      2
# 20           are      2
# 21          used      2
# 22        become      2
# 23         think      2
# 24           can      2
# 25     combining      2
# 26          were      2
# 27     described      2
# 28        showed      2
# 29          made      2
# 30       married      2
# 31        became      2
# 32    recognized      1
# 33    programmed      1
# 34        follow      1
# 35     computing      1
# 36        earned      1
# 37         named      1
# 38            go      1
# 39   calculating      1
# 40    understand      1
# 41     expressed      1
# 42   manipulated      1
# 43      explored      1
# 44        placed      1
# 45   programming      1
# 46       raising      1
# 47    dismissing      1
# 48          call      1
# 49     originate      1
# 50          know      1
# 51         order      1
# 52       perform      1
# 53       written      1
# 54       thought      1
# 55   constitutes      1
# 56       express      1
# 57  rediscovered      1
# 58      inspired      1
# 59          name      1
# 60     signifies      1
# 61         lived      1
# 62    considered      1
# 63       refined      1
# 64        thrown      1
# 65       grasped      1
# 66       exerted      1
# 67          born      1
# 68     separated      1
# 69       falling      1
# 70    encouraged      1
# 71    surrounded      1
# 72     including      1
# 73    introduced      1
# 74        hosted      1
# 75       gripped      1
# 76         began      1
# 77        lasted      1
# 78           met      1
# 79         given      1
# 80    determined      1
# 81           let      1
# 82          slow      1
# 83          read      1
# 84            am      1
# 85      occupied      1
# 86      lessened      1
# 87         carry      1
# 88         asked      1
# 89         tutor      1
# 90    exchanging      1
# 91        taught      1
# 92         shown      1
# 93     published      1
# 94         added      1
# 95        titled      1
# 96          work      1
# 97          come      1
# 98       studied      1
# 99       talking      1

# %% [markdown]
# To write this dataframe to a CSV file, we can use `df.to_csv()`:

# %%
#df.to_csv("Lovelace-verbs.csv", encoding='utf-8', index=False)

# %% [markdown]
# ## Get Keyword in Context

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
def get_keyword_in_context(keyword, word_list, number_surrounding_words, pos_label=None):
    
    ngrams = []
    words_around_keyword = []
    adj_length_of_word_list = len(word_list) - (number_surrounding_words)
    
    keyword = keyword.lower()
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + (number_surrounding_words + 1)]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
    
    
    for word_label_pair in ngrams:
    
        words = [word.lower() for word, label in word_label_pair]
        labels = [label for word, label in word_label_pair if word != keyword]

        if keyword in words:

            if pos_label in labels or pos_label == None:
                if keyword in words[0]:
                    words_around_keyword.append(" ".join(words[1:]))

                elif keyword in words[number_surrounding_words]:
                    words_around_keyword.append(" ".join(words[:number_surrounding_words]))
    
    words_around_keyword = [word.lower() for word in words_around_keyword]
    
    return Counter(words_around_keyword).most_common()

# %%
get_keyword_in_context("computer", tokens_and_labels, number_surrounding_words=2)
# Out:
# [('the first', 2),
#  ('programmer by', 1),
#  ('of the', 1),
#  ('age ada', 1),
#  ('general purpose', 1),
#  ('it could', 1),
#  ('leaves the', 1),
#  ('she was', 1),
#  ('programmer the', 1),
#  ('what a', 1),
#  ('could do', 1),
#  ('contribution to', 1),
#  ('science she', 1),
#  ('how the', 1),
#  ('would work', 1),
#  ('martin a', 1),
#  ('scientist at', 1)]

# %%
get_keyword_in_context("computer", tokens_and_labels, number_surrounding_words=2, pos_label="ADJ")
# Out:
# [('the first', 2), ('general purpose', 1)]

# %%
get_keyword_in_context("women", tokens_and_labels, number_surrounding_words=2)
# Out:
# [('celebration of', 1),
#  ('in technology', 1),
#  ('lived when', 1),
#  ('were not', 1),
#  ('industry where', 1),
#  ('are severely', 1)]
