# %% [markdown]
# # Pandas

# %% [markdown]
# In this lesson, we're going to learn about [Pandas](https://pandas.pydata.org/pandas-docs/stable/getting_started/overview.html), a powerful Python library for working with tabular data like CSV files. Things that were kind of clunky to accomplish with the CSV module are much easier to accomplish with Pandas.
#
# Here are some of the things you can do with Pandas:
#
# * Easily read and write CSV files
# * Sort and filter data
# * Analyze data
# * Combine datasets
# * Create data visualizations

# %% [markdown]
# ## Our Dataset

# %% [markdown]
# <img src="../images/Slave-Voyages.png" width=100%>

# %% [markdown]
# > [D]isplaying data
# alone could not and did not offer the atonement descendants of slaves
# sought or capture the inhumanity of this archive’s formation. Culling
# the lives of women and children from the data set required approaching
# the data with intention. It required a methodology attuned to black life
# and to dismantling the methods used to create the manifests in the first
# place, then designing and launching an interface responsive to the desire
# of descendants of slaves for reparation and redress (65).
#
# > Jessica Marie Johnson,
# <a href="https://read.dukeupress.edu/social-text/article/36/4%20(137)/57/137032/Markup-BodiesBlack-Life-Studies-and-Slavery-Death">“Markup Bodies: Black [Life] Studies and Slavery [Death] Studies at the Digital Crossroads”</a>

# %% [markdown]
# The dataset that we're going to be working with in this lesson is taken from [The Trans-Atlantic Slave Trade Database](https://www.slavevoyages.org/voyage/database), part of the [*Slave Voyages* project](https://www.slavevoyages.org/). This dataset was filtered to include only North American disembarkation locations and to include data about the percentage of enslaved men, women, and children on the voyages. Some column names have been altered or modified.
#
# We're working with this data for a number of reasons. First, the *Slave Voyages* project is a major data-driven contribution to the history of slavery and to the field of the digital humanities. Second, working with this data makes clear that, as Johnson writes, computation and data alone cannot capture "the violent quandary" of slavery or bring about justice. As we learn how to manipulate and analyze this dataset with Pandas, we should be reminded, at every step, of the challenges that are involved in using this data responsibly and intentionally.

# %% [markdown]
# ## Import Pandas

# %% [markdown]
# To use the Pandas library, we first need to `import` it, as below. This `import` statement not only imports the library but also gives it a nickname: `as` "pd" instead of "pandas." You'll run across this alias convention a lot. It's a way to save time and not have to write the entire word "pandas" over and over again.

# %%
import pandas as pd

# %% [markdown]
# ## Read in CSV File

# %% [markdown]
# To read in a CSV file, you use the function `pd.read_csv()` and insert the name of your desired file path. You can also add the "delimiter" argument to specify the delimiter for your file.

# %%
slave_voyages_df = pd.read_csv('../data/Slave-Voyages-Trans-Atlantic-North-America.csv', delimiter=",")

# %% [markdown]
# ```{tip}
# If you use the `help()` function, you can see the documentation for almost any bit of code. If we run it on `pd.read_csv()`, we can see all the possible parameters that can be used with `pd.read_csv()`.
# help(pd.read_csv)
# ```

# %% [markdown]
# **Pro tip!** If you use the `help()` function, you can see the documentation for almost any bit of code. If we run it on `pd.read_csv()`, we can see all the possible parameters that can be used with `pd.read_csv()`.
# help(pd.read_csv)

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
#     Also supports optionally iterating or breaking of the file
#     into chunks.
#
#     Additional help can be found in the online docs for
#     `IO Tools <https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html>`_.
#
#     Parameters
#     ----------
#     filepath_or_buffer : str, path object or file-like object
#         Any valid string path is acceptable. The string could be a URL. Valid
#         URL schemes include http, ftp, s3, and file. For file URLs, a host is
#         expected. A local file could be: file://localhost/path/to/table.csv.
#
#         If you want to pass in a path object, pandas accepts any ``os.PathLike``.
#
#         By file-like object, we refer to objects with a ``read()`` method, such as
#         a file handler (e.g. via builtin ``open`` function) or ``StringIO``.
#     sep : str, default ','
#         Delimiter to use. If sep is None, the C engine cannot automatically detect
#         the separator, but the Python parsing engine can, meaning the latter will
#         be used and automatically detect the separator by Python's builtin sniffer
#         tool, ``csv.Sniffer``. In addition, separators longer than 1 character and
#         different from ``'\s+'`` will be interpreted as regular expressions and
#         will also force the use of the Python parsing engine. Note that regex
#         delimiters are prone to ignoring quoted data. Regex example: ``'\r\t'``.
#     delimiter : str, default ``None``
#         Alias for sep.
#     header : int, list of int, default 'infer'
#         Row number(s) to use as the column names, and the start of the
#         data.  Default behavior is to infer the column names: if no names
#         are passed the behavior is identical to ``header=0`` and column
#         names are inferred from the first line of the file, if column
#         names are passed explicitly then the behavior is identical to
#         ``header=None``. Explicitly pass ``header=0`` to be able to
#         replace existing names. The header can be a list of integers that
#         specify row locations for a multi-index on the columns
#         e.g. [0,1,3]. Intervening rows that are not specified will be
#         skipped (e.g. 2 in this example is skipped). Note that this
#         parameter ignores commented lines and empty lines if
#         ``skip_blank_lines=True``, so ``header=0`` denotes the first line of
#         data rather than the first line of the file.
#     names : array-like, optional
#         List of column names to use. If the file contains a header row,
#         then you should explicitly pass ``header=0`` to override the column names.
#         Duplicates in this list are not allowed.
#     index_col : int, str, sequence of int / str, or False, default ``None``
#       Column(s) to use as the row labels of the ``DataFrame``, either given as
#       string name or column index. If a sequence of int / str is given, a
#       MultiIndex is used.
#
#       Note: ``index_col=False`` can be used to force pandas to *not* use the first
#       column as the index, e.g. when you have a malformed file with delimiters at
#       the end of each line.
#     usecols : list-like or callable, optional
#         Return a subset of the columns. If list-like, all elements must either
#         be positional (i.e. integer indices into the document columns) or strings
#         that correspond to column names provided either by the user in `names` or
#         inferred from the document header row(s). For example, a valid list-like
#         `usecols` parameter would be ``[0, 1, 2]`` or ``['foo', 'bar', 'baz']``.
#         Element order is ignored, so ``usecols=[0, 1]`` is the same as ``[1, 0]``.
#         To instantiate a DataFrame from ``data`` with element order preserved use
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['foo', 'bar']]`` for columns
#         in ``['foo', 'bar']`` order or
#         ``pd.read_csv(data, usecols=['foo', 'bar'])[['bar', 'foo']]``
#         for ``['bar', 'foo']`` order.
#
#         If callable, the callable function will be evaluated against the column
#         names, returning names where the callable function evaluates to True. An
#         example of a valid callable argument would be ``lambda x: x.upper() in
#         ['AAA', 'BBB', 'DDD']``. Using this parameter results in much faster
#         parsing time and lower memory usage.
#     squeeze : bool, default False
#         If the parsed data only contains one column then return a Series.
#     prefix : str, optional
#         Prefix to add to column numbers when no header, e.g. 'X' for X0, X1, ...
#     mangle_dupe_cols : bool, default True
#         Duplicate columns will be specified as 'X', 'X.1', ...'X.N', rather than
#         'X'...'X'. Passing in False will cause data to be overwritten if there
#         are duplicate names in the columns.
#     dtype : Type name or dict of column -> type, optional
#         Data type for data or columns. E.g. {'a': np.float64, 'b': np.int32,
#         'c': 'Int64'}
#         Use `str` or `object` together with suitable `na_values` settings
#         to preserve and not interpret dtype.
#         If converters are specified, they will be applied INSTEAD
#         of dtype conversion.
#     engine : {'c', 'python'}, optional
#         Parser engine to use. The C engine is faster while the python engine is
#         currently more feature-complete.
#     converters : dict, optional
#         Dict of functions for converting values in certain columns. Keys can either
#         be integers or column labels.
#     true_values : list, optional
#         Values to consider as True.
#     false_values : list, optional
#         Values to consider as False.
#     skipinitialspace : bool, default False
#         Skip spaces after delimiter.
#     skiprows : list-like, int or callable, optional
#         Line numbers to skip (0-indexed) or number of lines to skip (int)
#         at the start of the file.
#
#         If callable, the callable function will be evaluated against the row
#         indices, returning True if the row should be skipped and False otherwise.
#         An example of a valid callable argument would be ``lambda x: x in [0, 2]``.
#     skipfooter : int, default 0
#         Number of lines at bottom of file to skip (Unsupported with engine='c').
#     nrows : int, optional
#         Number of rows of file to read. Useful for reading pieces of large files.
#     na_values : scalar, str, list-like, or dict, optional
#         Additional strings to recognize as NA/NaN. If dict passed, specific
#         per-column NA values.  By default the following values are interpreted as
#         NaN: '', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan',
#         '1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NA', 'NULL', 'NaN', 'n/a',
#         'nan', 'null'.
#     keep_default_na : bool, default True
#         Whether or not to include the default NaN values when parsing the data.
#         Depending on whether `na_values` is passed in, the behavior is as follows:
#
#         * If `keep_default_na` is True, and `na_values` are specified, `na_values`
#           is appended to the default NaN values used for parsing.
#         * If `keep_default_na` is True, and `na_values` are not specified, only
#           the default NaN values are used for parsing.
#         * If `keep_default_na` is False, and `na_values` are specified, only
#           the NaN values specified `na_values` are used for parsing.
#         * If `keep_default_na` is False, and `na_values` are not specified, no
#           strings will be parsed as NaN.
#
#         Note that if `na_filter` is passed in as False, the `keep_default_na` and
#         `na_values` parameters will be ignored.
#     na_filter : bool, default True
#         Detect missing value markers (empty strings and the value of na_values). In
#         data without any NAs, passing na_filter=False can improve the performance
#         of reading a large file.
#     verbose : bool, default False
#         Indicate number of NA values placed in non-numeric columns.
#     skip_blank_lines : bool, default True
#         If True, skip over blank lines rather than interpreting as NaN values.
#     parse_dates : bool or list of int or names or list of lists or dict, default False
#         The behavior is as follows:
#
#         * boolean. If True -> try parsing the index.
#         * list of int or names. e.g. If [1, 2, 3] -> try parsing columns 1, 2, 3
#           each as a separate date column.
#         * list of lists. e.g.  If [[1, 3]] -> combine columns 1 and 3 and parse as
#           a single date column.
#         * dict, e.g. {'foo' : [1, 3]} -> parse columns 1, 3 as date and call
#           result 'foo'
#
#         If a column or index cannot be represented as an array of datetimes,
#         say because of an unparseable value or a mixture of timezones, the column
#         or index will be returned unaltered as an object data type. For
#         non-standard datetime parsing, use ``pd.to_datetime`` after
#         ``pd.read_csv``. To parse an index or column with a mixture of timezones,
#         specify ``date_parser`` to be a partially-applied
#         :func:`pandas.to_datetime` with ``utc=True``. See
#         :ref:`io.csv.mixed_timezones` for more.
#
#         Note: A fast-path exists for iso8601-formatted dates.
#     infer_datetime_format : bool, default False
#         If True and `parse_dates` is enabled, pandas will attempt to infer the
#         format of the datetime strings in the columns, and if it can be inferred,
#         switch to a faster method of parsing them. In some cases this can increase
#         the parsing speed by 5-10x.
#     keep_date_col : bool, default False
#         If True and `parse_dates` specifies combining multiple columns then
#         keep the original columns.
#     date_parser : function, optional
#         Function to use for converting a sequence of string columns to an array of
#         datetime instances. The default uses ``dateutil.parser.parser`` to do the
#         conversion. Pandas will try to call `date_parser` in three different ways,
#         advancing to the next if an exception occurs: 1) Pass one or more arrays
#         (as defined by `parse_dates`) as arguments; 2) concatenate (row-wise) the
#         string values from the columns defined by `parse_dates` into a single array
#         and pass that; and 3) call `date_parser` once for each row using one or
#         more strings (corresponding to the columns defined by `parse_dates`) as
#         arguments.
#     dayfirst : bool, default False
#         DD/MM format dates, international and European format.
#     cache_dates : bool, default True
#         If True, use a cache of unique, converted dates to apply the datetime
#         conversion. May produce significant speed-up when parsing duplicate
#         date strings, especially ones with timezone offsets.
#
#         .. versionadded:: 0.25.0
#     iterator : bool, default False
#         Return TextFileReader object for iteration or getting chunks with
#         ``get_chunk()``.
#     chunksize : int, optional
#         Return TextFileReader object for iteration.
#         See the `IO Tools docs
#         <https://pandas.pydata.org/pandas-docs/stable/io.html#io-chunking>`_
#         for more information on ``iterator`` and ``chunksize``.
#     compression : {'infer', 'gzip', 'bz2', 'zip', 'xz', None}, default 'infer'
#         For on-the-fly decompression of on-disk data. If 'infer' and
#         `filepath_or_buffer` is path-like, then detect compression from the
#         following extensions: '.gz', '.bz2', '.zip', or '.xz' (otherwise no
#         decompression). If using 'zip', the ZIP file must contain only one data
#         file to be read in. Set to None for no decompression.
#     thousands : str, optional
#         Thousands separator.
#     decimal : str, default '.'
#         Character to recognize as decimal point (e.g. use ',' for European data).
#     lineterminator : str (length 1), optional
#         Character to break file into lines. Only valid with C parser.
#     quotechar : str (length 1), optional
#         The character used to denote the start and end of a quoted item. Quoted
#         items can include the delimiter and it will be ignored.
#     quoting : int or csv.QUOTE_* instance, default 0
#         Control field quoting behavior per ``csv.QUOTE_*`` constants. Use one of
#         QUOTE_MINIMAL (0), QUOTE_ALL (1), QUOTE_NONNUMERIC (2) or QUOTE_NONE (3).
#     doublequote : bool, default ``True``
#        When quotechar is specified and quoting is not ``QUOTE_NONE``, indicate
#        whether or not to interpret two consecutive quotechar elements INSIDE a
#        field as a single ``quotechar`` element.
#     escapechar : str (length 1), optional
#         One-character string used to escape other characters.
#     comment : str, optional
#         Indicates remainder of line should not be parsed. If found at the beginning
#         of a line, the line will be ignored altogether. This parameter must be a
#         single character. Like empty lines (as long as ``skip_blank_lines=True``),
#         fully commented lines are ignored by the parameter `header` but not by
#         `skiprows`. For example, if ``comment='#'``, parsing
#         ``#empty\na,b,c\n1,2,3`` with ``header=0`` will result in 'a,b,c' being
#         treated as the header.
#     encoding : str, optional
#         Encoding to use for UTF when reading/writing (ex. 'utf-8'). `List of Python
#         standard encodings
#         <https://docs.python.org/3/library/codecs.html#standard-encodings>`_ .
#     dialect : str or csv.Dialect, optional
#         If provided, this parameter will override values (default or not) for the
#         following parameters: `delimiter`, `doublequote`, `escapechar`,
#         `skipinitialspace`, `quotechar`, and `quoting`. If it is necessary to
#         override values, a ParserWarning will be issued. See csv.Dialect
#         documentation for more details.
#     error_bad_lines : bool, default True
#         Lines with too many fields (e.g. a csv line with too many commas) will by
#         default cause an exception to be raised, and no DataFrame will be returned.
#         If False, then these "bad lines" will dropped from the DataFrame that is
#         returned.
#     warn_bad_lines : bool, default True
#         If error_bad_lines is False, and warn_bad_lines is True, a warning for each
#         "bad line" will be output.
#     delim_whitespace : bool, default False
#         Specifies whether or not whitespace (e.g. ``' '`` or ``'    '``) will be
#         used as the sep. Equivalent to setting ``sep='\s+'``. If this option
#         is set to True, nothing should be passed in for the ``delimiter``
#         parameter.
#     low_memory : bool, default True
#         Internally process the file in chunks, resulting in lower memory use
#         while parsing, but possibly mixed type inference.  To ensure no mixed
#         types either set False, or specify the type with the `dtype` parameter.
#         Note that the entire file is read into a single DataFrame regardless,
#         use the `chunksize` or `iterator` parameter to return the data in chunks.
#         (Only valid with C parser).
#     memory_map : bool, default False
#         If a filepath is provided for `filepath_or_buffer`, map the file object
#         directly onto memory and access the data directly from there. Using this
#         option can improve performance because there is no longer any I/O overhead.
#     float_precision : str, optional
#         Specifies which converter the C engine should use for floating-point
#         values. The options are `None` for the ordinary converter,
#         `high` for the high-precision converter, and `round_trip` for the
#         round-trip converter.
#
#     Returns
#     -------
#     DataFrame or TextParser
#         A comma-separated values (csv) file is returned as two-dimensional
#         data structure with labeled axes.
#
#     See Also
#     --------
#     to_csv : Write DataFrame to a comma-separated values (csv) file.
#     read_csv : Read a comma-separated values (csv) file into DataFrame.
#     read_fwf : Read a table of fixed-width formatted lines into DataFrame.
#
#     Examples
#     --------
#     >>> pd.read_csv('data.csv')  # doctest: +SKIP

# %% [markdown]
# When you read in a CSV file with Pandas, you transform it into a Pandas object called a dataframe.

# %%
type(slave_voyages_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Display the Data

# %% [markdown]
# In a Jupyter notebook, you can display a dataframe simply by running a cell with the name of the dataframe. The `NaN` value is the Pandas value for any missing data (`NaN` values have special properties that we'll get to later).

# %%
slave_voyages_df
# Out:
#       voyage_id        vessel_name             flag  \
# 0           971  Fenix (a) Phoenix  Spain / Uruguay
# 1          4362           Wildfire           U.S.A.
# 2          4363             Bogota           France
# 3          4364            William           U.S.A.
# 4          4974           Wanderer           U.S.A.
# ...         ...                ...              ...
# 1756      94777    Gambia Merchant    Great Britain
# 1757      94793           Carolina    Great Britain
# 1758      94819     Charming Jenny    Great Britain
# 1759      94846      Three Sisters    Great Britain
# 1760     900206             Málaga              NaN
#
#            place_of_slave_purchase place_of_slave_disembarkation  \
# 0        Africa., port unspecified                   New Orleans
# 1                      Congo River                      Key West
# 2                           Whydah                      Key West
# 3                      Congo River                      Key West
# 4                      Congo River     Georgia, port unspecified
# ...                            ...                           ...
# 1756                        Gambia    Maryland, port unspecified
# 1757     Africa., port unspecified     USA, location unspecified
# 1758  Gold Coast, port unspecified     USA, location unspecified
# 1759             Cape Coast Castle                    York River
# 1760                        Ambriz     USA, location unspecified
#
#       total_embarked  total_disembarked  year_of_arrival  percent_men  \
# 0               95.0               82.0             1830          NaN
# 1              650.0              507.0             1860          NaN
# 2              418.0              411.0             1860          NaN
# 3              744.0              513.0             1860          NaN
# 4              487.0              407.0             1858          NaN
# ...              ...                ...              ...          ...
# 1756           172.0              153.0             1743          NaN
# 1757           172.0              153.0             1742          NaN
# 1758           172.0              153.0             1743          NaN
# 1759           126.0              109.0             1717          NaN
# 1760           490.0              444.0             1844          NaN
#
#       percent_women  percent_children  \
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
# ...             ...               ...
# 1756            NaN               NaN
# 1757            NaN               NaN
# 1758            NaN               NaN
# 1759            NaN               NaN
# 1760            NaN               NaN
#
#                                          captain's_name resistance_label  \
# 0        Torre, Francisco de la<br/> Torre, Pablo de la              NaN
# 1                                     Stanhope, William              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
# ...                                                 ...              ...
# 1756                                    Cutler, Egerton              NaN
# 1757                                     Thompson, John              NaN
# 1758                                     Stewart, James              NaN
# 1759                                       Hughes, John              NaN
# 1760                                                NaN              NaN
#
#                                                 sources
# 0     [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...
# 1     [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2     [u'HED,36-2,7:450,517,621<>United States Congr...
# 3     [u'HED,36-2,7:454,517<>United States Congress,...
# 4     [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...
# ...                                                 ...
# 1756  [u'ADM7/83<><p><em>British National Archives</...
# 1757  [u'ADM7/83<><p><em>British National Archives</...
# 1758  [u'ADM7/84<><p><em>British National Archives</...
# 1759  [u'Donnan,IV,176<><p>Donnan, Elizabeth (ed.),&...
# 1760  [u'AHNA, Cod. E-4-4 (Benguela)<><i>Arquivo His...
#
# [1761 rows x 14 columns]

# %% [markdown]
# You should always eyeball your dataset either by looking at the first few rows or by looking at a few random rows. To look at the first few rows, you can use a method called `.head()` (very similar to the `head` command on the command line).

# %%
slave_voyages_df.head(10)
# Out:
#    voyage_id          vessel_name             flag    place_of_slave_purchase  \
# 0        971    Fenix (a) Phoenix  Spain / Uruguay  Africa., port unspecified
# 1       4362             Wildfire           U.S.A.                Congo River
# 2       4363               Bogota           France                     Whydah
# 3       4364              William           U.S.A.                Congo River
# 4       4974             Wanderer           U.S.A.                Congo River
# 5       5050            Isabelita              NaN  Africa., port unspecified
# 6       7632               Africa           U.S.A.                Congo River
# 7       9661  Thomas and Susannah    Great Britain                    Calabar
# 8       9835            Speedwell    Great Britain                     Gambia
# 9       9863            Speedwell    Great Britain                     Gambia
#
#   place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 0                   New Orleans            95.0               82.0
# 1                      Key West           650.0              507.0
# 2                      Key West           418.0              411.0
# 3                      Key West           744.0              513.0
# 4     Georgia, port unspecified           487.0              407.0
# 5     Georgia, port unspecified           112.0               95.0
# 6                    Charleston           326.0              307.0
# 7    Maryland, port unspecified           251.0              174.0
# 8    Virginia, port unspecified           233.0              206.0
# 9    Maryland, port unspecified           217.0              192.0
#
#    year_of_arrival  percent_men  percent_women  percent_children  \
# 0             1830          NaN            NaN               NaN
# 1             1860          NaN            NaN               NaN
# 2             1860          NaN            NaN               NaN
# 3             1860          NaN            NaN               NaN
# 4             1858          NaN            NaN               NaN
# 5             1818          NaN            NaN               NaN
# 6             1808          NaN            NaN               NaN
# 7             1689          NaN            NaN               NaN
# 8             1688          NaN            NaN               NaN
# 9             1686      0.80184        0.17051           0.02765
#
#                                       captain's_name resistance_label  \
# 0     Torre, Francisco de la<br/> Torre, Pablo de la              NaN
# 1                                  Stanhope, William              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
# 5                       Freire, Francisco<br/> Moore              NaN
# 6             Connelly, John<br/> Connelly, Jeremiah              NaN
# 7                                    Everard, Thomas              NaN
# 8                                Goodhand, Marmaduke              NaN
# 9                                Goodhand, Marmaduke              NaN
#
#                                              sources
# 0  [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...
# 1  [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2  [u'HED,36-2,7:450,517,621<>United States Congr...
# 3  [u'HED,36-2,7:454,517<>United States Congress,...
# 4  [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...
# 5  [u'Catterall,III,11<><p>Catterall, Helen Tunni...
# 6  [u'Donnan,IV,531,551-70<><p>Donnan, Elizabeth ...
# 7  [u'T70/915<><p><em>British National Archive</e...
# 8  [u'T70/943,35<><p><em>British National Archive...
# 9  [u'T70/11,59<><p><em>British National Archive<...

# %% [markdown]
# To look at a random sample of rows, you can use the `.sample()` method. You might run this cell a few times to make sure everything looks ok.

# %%
slave_voyages_df.sample(10)
# Out:
#       voyage_id      vessel_name           flag  \
# 204       16819          Bridget  Great Britain
# 567       25179         Poultney         U.S.A.
# 35        15208  John and Robert  Great Britain
# 362       17744           Betsey  Great Britain
# 1072      36993  Martha and Jane         U.S.A.
# 613       25341           Warren         U.S.A.
# 184       16780              Ann  Great Britain
# 71        16241         Commerce  Great Britain
# 131       16492    Mediterranean  Great Britain
# 1443      80474          Bellona  Great Britain
#
#                                 place_of_slave_purchase  \
# 204                                             Cabinda
# 567                           Africa., port unspecified
# 35                            Africa., port unspecified
# 362   West Central Africa and St. Helena, port unspe...
# 1072                          Africa., port unspecified
# 613                           Africa., port unspecified
# 184                           Africa., port unspecified
# 71                                              Calabar
# 131                           Africa., port unspecified
# 1443  West Central Africa and St. Helena, port unspe...
#
#      place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 204                  South Potomac           165.0              150.0
# 567                         Boston           123.0              101.0
# 35      Virginia, port unspecified           237.0              190.0
# 362                     Charleston           308.0              280.0
# 1072                    Middletown           149.0              126.0
# 613                       New York           123.0              101.0
# 184                   Rappahannock           271.0              222.0
# 71                      York River           171.0              130.0
# 131                     Charleston           271.0              217.0
# 1443                    Charleston           310.0              279.0
#
#       year_of_arrival  percent_men  percent_women  percent_children  \
# 204              1736          NaN            NaN               NaN
# 567              1740          NaN            NaN               NaN
# 35               1710          NaN            NaN               NaN
# 362              1771          NaN            NaN               NaN
# 1072             1738          NaN            NaN               NaN
# 613              1751          NaN            NaN               NaN
# 184              1735          NaN            NaN               NaN
# 71               1720          NaN            NaN               NaN
# 131              1727          NaN            NaN               NaN
# 1443             1806          NaN            NaN               NaN
#
#         captain's_name resistance_label  \
# 204    Clarke, William              NaN
# 567                NaN              NaN
# 35     Collins, Robert              NaN
# 362    Morgan, William              NaN
# 1072               NaN              NaN
# 613    Grennel, Thomas              NaN
# 184   Prothero, Philip              NaN
# 71         Moor, David              NaN
# 131     Dolman, Thomas              NaN
# 1443     Lace, William              NaN
#
#                                                 sources
# 204   [u'Richardson,II<><p>Richardson, David, <em>Br...
# 567   [u'Donnan,III,50<><p>Donnan, Elizabeth (ed.),&...
# 35    [u'Donnan,II,117<><p>Donnan, Elizabeth (ed.),&...
# 362   [u'Richardson,IV<><p>Richardson, David, <em>Br...
# 1072  [u'Donnan,III,134<><p>Donnan, Elizabeth (ed.),...
# 613   [u'Donnan,III,451<><p>Donnan, Elizabeth (ed.),...
# 184   [u'Richardson,II<><p>Richardson, David, <em>Br...
# 71    [u'Richardson,I<><p>Richardson, David, <em>Bri...
# 131   [u'Richardson,I<><p>Richardson, David, <em>Bri...
# 1443  [u"LR1807<><i>Lloyd's Register of Shipping</i>...

# %% [markdown]
# ## Examine the Data

# %% [markdown]
# You can check the dataframe's "shape" or how many rows vs columns it contains with `.shape` (number of rows, number of columns)

# %%
slave_voyages_df.shape
# Out:
# (1761, 14)

# %% [markdown]
# You can (and always should) check the data types that each column contains with `.dtypes`

# %% [markdown]
# | **Pandas dtypes** |                                                                                    |
# |:-------------:|:---------------------------------------------------------------------------------------------------:|
# | `object`         | string                                                                               |
# | `float64`         | float                                               |
# | `int64`       | integer                                                        |
# | `datetime64`       |  date time

# %%
slave_voyages_df.dtypes
# Out:
# voyage_id                          int64
# vessel_name                       object
# flag                              object
# place_of_slave_purchase           object
# place_of_slave_disembarkation     object
# total_embarked                   float64
# total_disembarked                float64
# year_of_arrival                    int64
# percent_men                      float64
# percent_women                    float64
# percent_children                 float64
# captain's_name                    object
# resistance_label                  object
# sources                           object
# dtype: object

# %% [markdown]
# It's important to always check the data types in your dataframe. For example, sometimes numeric values, which you want to do mathematical calculations with, will accidentally be interpreted as a string object. To perform calculations on this data, you would need to first convert that column from a string to an integer.
#
# The data types in our Trans-Atlantic Slave Trade dataset look ok, except the column "year_of_arrival," which is currently interpreted as an integer value when ideally it should be a datetime value.

# %% [markdown]
# You can also check the column names of your dataframe with `.columns`

# %%
slave_voyages_df.columns
# Out:
# Index(['voyage_id', 'vessel_name', 'flag', 'place_of_slave_purchase',
#        'place_of_slave_disembarkation', 'total_embarked', 'total_disembarked',
#        'year_of_arrival', 'percent_men', 'percent_women', 'percent_children',
#        'captain's_name', 'resistance_label', 'sources'],
#       dtype='object')

# %% [markdown]
# ## Rename and Drop Columns

# %% [markdown]
# Let's say we wanted to rename the "flag" column as "national_affiliation." One way to approach this goal would be to make a new column identical to the "flag" column but with a different name.
#
# Making a new column with Pandas is very similar to making a new Python variable. You simply type the name of the dataframe with square brackets `[]` and include the name of your new desired column that doesn't exist yet. Then you assign it the value of the already existing flag column.

# %%
slave_voyages_df['national_affiliation'] = slave_voyages_df['flag']

# %% [markdown]
# If you scroll all the way to the end of the dataframe, you can see that we added a new column called "national_affiliation" that's exactly the same as the flag column.

# %%
slave_voyages_df.head()
# Out:
#    voyage_id        vessel_name             flag    place_of_slave_purchase  \
# 0        971  Fenix (a) Phoenix  Spain / Uruguay  Africa., port unspecified
# 1       4362           Wildfire           U.S.A.                Congo River
# 2       4363             Bogota           France                     Whydah
# 3       4364            William           U.S.A.                Congo River
# 4       4974           Wanderer           U.S.A.                Congo River
#
#   place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 0                   New Orleans            95.0               82.0
# 1                      Key West           650.0              507.0
# 2                      Key West           418.0              411.0
# 3                      Key West           744.0              513.0
# 4     Georgia, port unspecified           487.0              407.0
#
#    year_of_arrival  percent_men  percent_women  percent_children  \
# 0             1830          NaN            NaN               NaN
# 1             1860          NaN            NaN               NaN
# 2             1860          NaN            NaN               NaN
# 3             1860          NaN            NaN               NaN
# 4             1858          NaN            NaN               NaN
#
#                                       captain's_name resistance_label  \
# 0     Torre, Francisco de la<br/> Torre, Pablo de la              NaN
# 1                                  Stanhope, William              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
#
#                                              sources national_affiliation
# 0  [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...      Spain / Uruguay
# 1  [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...               U.S.A.
# 2  [u'HED,36-2,7:450,517,621<>United States Congr...               France
# 3  [u'HED,36-2,7:454,517<>United States Congress,...               U.S.A.
# 4  [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...               U.S.A.

# %% [markdown]
# But what if we don't want multiple columns with the same information? What if we just want to rename the "flag" column?

# %% [markdown]
# First, let's get rid of the "national_affiliation" column so we can try again. To remove columns, you can use the `.drop()` method and the `columns=` parameter, followed by the column you'd like to drop.

# %%
slave_voyages_df = slave_voyages_df.drop(columns='national_affiliation')

# %%
slave_voyages_df.columns
# Out:
# Index(['voyage_id', 'vessel_name', 'flag', 'place_of_slave_purchase',
#        'place_of_slave_disembarkation', 'total_embarked', 'total_disembarked',
#        'year_of_arrival', 'percent_men', 'percent_women', 'percent_children',
#        'captain's_name', 'resistance_label', 'sources'],
#       dtype='object')

# %% [markdown]
# A better way to rename columns is with the `.rename()` method and the `columns=` parameter that includes the original name of the column followed by a colon and the new desired name of the column.

# %%
slave_voyages_df.rename(columns={'flag': 'national_affiliation'})
# Out:
#       voyage_id        vessel_name national_affiliation  \
# 0           971  Fenix (a) Phoenix      Spain / Uruguay
# 1          4362           Wildfire               U.S.A.
# 2          4363             Bogota               France
# 3          4364            William               U.S.A.
# 4          4974           Wanderer               U.S.A.
# ...         ...                ...                  ...
# 1756      94777    Gambia Merchant        Great Britain
# 1757      94793           Carolina        Great Britain
# 1758      94819     Charming Jenny        Great Britain
# 1759      94846      Three Sisters        Great Britain
# 1760     900206             Málaga                  NaN
#
#            place_of_slave_purchase place_of_slave_disembarkation  \
# 0        Africa., port unspecified                   New Orleans
# 1                      Congo River                      Key West
# 2                           Whydah                      Key West
# 3                      Congo River                      Key West
# 4                      Congo River     Georgia, port unspecified
# ...                            ...                           ...
# 1756                        Gambia    Maryland, port unspecified
# 1757     Africa., port unspecified     USA, location unspecified
# 1758  Gold Coast, port unspecified     USA, location unspecified
# 1759             Cape Coast Castle                    York River
# 1760                        Ambriz     USA, location unspecified
#
#       total_embarked  total_disembarked  year_of_arrival  percent_men  \
# 0               95.0               82.0             1830          NaN
# 1              650.0              507.0             1860          NaN
# 2              418.0              411.0             1860          NaN
# 3              744.0              513.0             1860          NaN
# 4              487.0              407.0             1858          NaN
# ...              ...                ...              ...          ...
# 1756           172.0              153.0             1743          NaN
# 1757           172.0              153.0             1742          NaN
# 1758           172.0              153.0             1743          NaN
# 1759           126.0              109.0             1717          NaN
# 1760           490.0              444.0             1844          NaN
#
#       percent_women  percent_children  \
# 0               NaN               NaN
# 1               NaN               NaN
# 2               NaN               NaN
# 3               NaN               NaN
# 4               NaN               NaN
# ...             ...               ...
# 1756            NaN               NaN
# 1757            NaN               NaN
# 1758            NaN               NaN
# 1759            NaN               NaN
# 1760            NaN               NaN
#
#                                          captain's_name resistance_label  \
# 0        Torre, Francisco de la<br/> Torre, Pablo de la              NaN
# 1                                     Stanhope, William              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
# ...                                                 ...              ...
# 1756                                    Cutler, Egerton              NaN
# 1757                                     Thompson, John              NaN
# 1758                                     Stewart, James              NaN
# 1759                                       Hughes, John              NaN
# 1760                                                NaN              NaN
#
#                                                 sources
# 0     [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...
# 1     [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2     [u'HED,36-2,7:450,517,621<>United States Congr...
# 3     [u'HED,36-2,7:454,517<>United States Congress,...
# 4     [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...
# ...                                                 ...
# 1756  [u'ADM7/83<><p><em>British National Archives</...
# 1757  [u'ADM7/83<><p><em>British National Archives</...
# 1758  [u'ADM7/84<><p><em>British National Archives</...
# 1759  [u'Donnan,IV,176<><p>Donnan, Elizabeth (ed.),&...
# 1760  [u'AHNA, Cod. E-4-4 (Benguela)<><i>Arquivo His...
#
# [1761 rows x 14 columns]

# %% [markdown]
# Renaming the "flag" column as we did above will only momentarily change that column's name. If we display our dataframe, we'll see that the column name has *not* changed permamently.

# %%
slave_voyages_df.head(5)
# Out:
#    voyage_id        vessel_name             flag    place_of_slave_purchase  \
# 0        971  Fenix (a) Phoenix  Spain / Uruguay  Africa., port unspecified
# 1       4362           Wildfire           U.S.A.                Congo River
# 2       4363             Bogota           France                     Whydah
# 3       4364            William           U.S.A.                Congo River
# 4       4974           Wanderer           U.S.A.                Congo River
#
#   place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 0                   New Orleans            95.0               82.0
# 1                      Key West           650.0              507.0
# 2                      Key West           418.0              411.0
# 3                      Key West           744.0              513.0
# 4     Georgia, port unspecified           487.0              407.0
#
#    year_of_arrival  percent_men  percent_women  percent_children  \
# 0             1830          NaN            NaN               NaN
# 1             1860          NaN            NaN               NaN
# 2             1860          NaN            NaN               NaN
# 3             1860          NaN            NaN               NaN
# 4             1858          NaN            NaN               NaN
#
#                                       captain's_name resistance_label  \
# 0     Torre, Francisco de la<br/> Torre, Pablo de la              NaN
# 1                                  Stanhope, William              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
#
#                                              sources
# 0  [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...
# 1  [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2  [u'HED,36-2,7:450,517,621<>United States Congr...
# 3  [u'HED,36-2,7:454,517<>United States Congress,...
# 4  [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...

# %% [markdown]
# To save changes in your dataframe, you need to keep re-assigning your dataframe, as below.

# %%
slave_voyages_df = slave_voyages_df.rename(columns={'flag': 'national_affiliation'})

# %%
slave_voyages_df.head(5)
# Out:
#    voyage_id        vessel_name national_affiliation  \
# 0        971  Fenix (a) Phoenix      Spain / Uruguay
# 1       4362           Wildfire               U.S.A.
# 2       4363             Bogota               France
# 3       4364            William               U.S.A.
# 4       4974           Wanderer               U.S.A.
#
#      place_of_slave_purchase place_of_slave_disembarkation  total_embarked  \
# 0  Africa., port unspecified                   New Orleans            95.0
# 1                Congo River                      Key West           650.0
# 2                     Whydah                      Key West           418.0
# 3                Congo River                      Key West           744.0
# 4                Congo River     Georgia, port unspecified           487.0
#
#    total_disembarked  year_of_arrival  percent_men  percent_women  \
# 0               82.0             1830          NaN            NaN
# 1              507.0             1860          NaN            NaN
# 2              411.0             1860          NaN            NaN
# 3              513.0             1860          NaN            NaN
# 4              407.0             1858          NaN            NaN
#
#    percent_children                                     captain's_name  \
# 0               NaN     Torre, Francisco de la<br/> Torre, Pablo de la
# 1               NaN                                  Stanhope, William
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN  Corrie, William G.<br/> Farnum, Charles Egbert...
#
#   resistance_label                                            sources
# 0              NaN  [u'PP,1845,XLIX:593-633<>Great Britain, <i>Par...
# 1              NaN  [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2              NaN  [u'HED,36-2,7:450,517,621<>United States Congr...
# 3              NaN  [u'HED,36-2,7:454,517<>United States Congress,...
# 4              NaN  [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...

# %% [markdown]
# ## Select Columns

# %% [markdown]
# To isolate a column with the csv module was kind of a pain. We had to loop through each row and index a certain value in each row's list. But with Pandas it's very simple to select a column. You can do so by typing the name of the dataframe accompanied by square brackets `[]` with the name of the column in quotation marks.

# %%
slave_voyages_df['vessel_name']
# Out:
# 0       Fenix (a) Phoenix
# 1                Wildfire
# 2                  Bogota
# 3                 William
# 4                Wanderer
#               ...
# 1756      Gambia Merchant
# 1757             Carolina
# 1758       Charming Jenny
# 1759        Three Sisters
# 1760               Málaga
# Name: vessel_name, Length: 1761, dtype: object

# %%
type(slave_voyages_df['vessel_name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Each column in a dataframe is technically a Pandas object called a "Series." We won't worry too much about the "Series" object right now, except to note that a Series object does not display as nicely as a DataFrame. To select a column as a dataframe, you can use two square brackets `[[]]`

# %%
slave_voyages_df[['vessel_name']]
# Out:
#             vessel_name
# 0     Fenix (a) Phoenix
# 1              Wildfire
# 2                Bogota
# 3               William
# 4              Wanderer
# ...                 ...
# 1756    Gambia Merchant
# 1757           Carolina
# 1758     Charming Jenny
# 1759      Three Sisters
# 1760             Málaga
#
# [1761 rows x 1 columns]

# %%
type(slave_voyages_df[['vessel_name']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# With two square brackets, you can also select and isolate multiple columns at the same time.

# %%
slave_voyages_df[['vessel_name', 'national_affiliation', 'year_of_arrival']]
# Out:
#             vessel_name national_affiliation  year_of_arrival
# 0     Fenix (a) Phoenix      Spain / Uruguay             1830
# 1              Wildfire               U.S.A.             1860
# 2                Bogota               France             1860
# 3               William               U.S.A.             1860
# 4              Wanderer               U.S.A.             1858
# ...                 ...                  ...              ...
# 1756    Gambia Merchant        Great Britain             1743
# 1757           Carolina        Great Britain             1742
# 1758     Charming Jenny        Great Britain             1743
# 1759      Three Sisters        Great Britain             1717
# 1760             Málaga                  NaN             1844
#
# [1761 rows x 3 columns]

# %% [markdown]
# ## Filter Data

# %% [markdown]
# You can also filter data based on different criteria. For example, let's say we wanted to look at the slave voyages whose national affiliation was American. You can evaluate each row in a column by isolating that column and then using the comparison operators that we discussed a few lessons ago, such as equals `==`.

# %%
slave_voyages_df['national_affiliation'] == "U.S.A."
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4        True
#         ...
# 1756    False
# 1757    False
# 1758    False
# 1759    False
# 1760    False
# Name: national_affiliation, Length: 1761, dtype: bool

# %% [markdown]
# The output above is an evaluation of whether each row in the "flag" column equals "U.S.A." or not. This function becomes much more helpful when we use this comparison as a selection criteria in its own right.
#
# Just as we can select a column by placing its name inside square brackets, we can select filtered data by placing a filter inside square brackets `[]`. Essentially, the line below is saying give me all the rows in the dataframe that match `slave_voyages_df['flag'] == "U.S.A."`

# %%
slave_voyages_df[slave_voyages_df['national_affiliation'] == "U.S.A."]
# Out:
#       voyage_id vessel_name national_affiliation place_of_slave_purchase  \
# 1          4362    Wildfire               U.S.A.             Congo River
# 3          4364     William               U.S.A.             Congo River
# 4          4974    Wanderer               U.S.A.             Congo River
# 6          7632      Africa               U.S.A.             Congo River
# 18        14138       Sally               U.S.A.             Congo River
# ...         ...         ...                  ...                     ...
# 1512      83158   Port Mary               U.S.A.             Congo River
# 1516      83432        Ruby               U.S.A.             Congo River
# 1517      83439        Ruby               U.S.A.             Congo River
# 1518      83440        Ruby               U.S.A.             Congo River
# 1529      83989  Washington               U.S.A.                   Bonny
#
#      place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 1                         Key West           650.0              507.0
# 3                         Key West           744.0              513.0
# 4        Georgia, port unspecified           487.0              407.0
# 6                       Charleston           326.0              307.0
# 18                     New Orleans           213.0              174.0
# ...                            ...             ...                ...
# 1512                    Charleston           423.0              380.0
# 1516                    Charleston           389.0              350.0
# 1517                    Charleston           412.0              391.0
# 1518                    Charleston           389.0              350.0
# 1529                    Charleston           590.0              530.0
#
#       year_of_arrival  percent_men  percent_women  percent_children  \
# 1                1860          NaN            NaN               NaN
# 3                1860          NaN            NaN               NaN
# 4                1858          NaN            NaN               NaN
# 6                1808          NaN            NaN               NaN
# 18               1803      0.49425        0.28161           0.22414
# ...               ...          ...            ...               ...
# 1512             1807          NaN            NaN               NaN
# 1516             1807          NaN            NaN               NaN
# 1517             1804          NaN            NaN               NaN
# 1518             1806          NaN            NaN               NaN
# 1529             1805          NaN            NaN               NaN
#
#                                          captain's_name resistance_label  \
# 1                                     Stanhope, William              NaN
# 3                                                   NaN              NaN
# 4     Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
# 6                Connelly, John<br/> Connelly, Jeremiah              NaN
# 18                 Edwards, Henry<br/> Guibert, Auguste              NaN
# ...                                                 ...              ...
# 1512                                           Bowes, J              NaN
# 1516                        Shaw, Alexander<br/> Caruth              NaN
# 1517                          Shaw, Alexander<br/> Keer              NaN
# 1518                                            Shaw, A              NaN
# 1529                                 Belcher<br/> Waldo              NaN
#
#                                                 sources
# 1     [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 3     [u'HED,36-2,7:454,517<>United States Congress,...
# 4     [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...
# 6     [u'Donnan,IV,531,551-70<><p>Donnan, Elizabeth ...
# 18    [u'ANC,ML, 2486<><p><em>Archivo Nacional de Cu...
# ...                                                 ...
# 1512  [u'Donnan,IV,522<><p>Donnan, Elizabeth (ed.),&...
# 1516  [u'Donnan,IV,522-23<><p>Donnan, Elizabeth (ed....
# 1517  [u'Madison, 7: 230<><p>Mattern, David, JCA Sta...
# 1518  [u'Donnan,IV,514,516<><p>Donnan, Elizabeth (ed...
# 1529  [u'Donnan,IV,508-09<><p>Donnan, Elizabeth (ed....
#
# [558 rows x 14 columns]

# %% [markdown]
# You can do the same thing with integers and other comparison operators. For example, if we wanted to filter for only the slave voyages that arrived after 1830, we could do so with `slave_voyages_df['year_of_arrival'] > 1830`

# %%
slave_voyages_df['year_of_arrival'] > 1830
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1756    False
# 1757    False
# 1758    False
# 1759    False
# 1760     True
# Name: year_of_arrival, Length: 1761, dtype: bool

# %%
slave_voyages_df[slave_voyages_df['year_of_arrival'] > 1830]
# Out:
#       voyage_id vessel_name national_affiliation place_of_slave_purchase  \
# 1          4362    Wildfire               U.S.A.             Congo River
# 2          4363      Bogota               France                  Whydah
# 3          4364     William               U.S.A.             Congo River
# 4          4974    Wanderer               U.S.A.             Congo River
# 1069      36990    Clotilda               U.S.A.                  Whydah
# 1760     900206      Málaga                  NaN                  Ambriz
#
#      place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 1                         Key West           650.0              507.0
# 2                         Key West           418.0              411.0
# 3                         Key West           744.0              513.0
# 4        Georgia, port unspecified           487.0              407.0
# 1069                        Mobile           110.0              110.0
# 1760     USA, location unspecified           490.0              444.0
#
#       year_of_arrival  percent_men  percent_women  percent_children  \
# 1                1860          NaN            NaN               NaN
# 2                1860          NaN            NaN               NaN
# 3                1860          NaN            NaN               NaN
# 4                1858          NaN            NaN               NaN
# 1069             1860          NaN            NaN               NaN
# 1760             1844          NaN            NaN               NaN
#
#                                          captain's_name resistance_label  \
# 1                                     Stanhope, William              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     Corrie, William G.<br/> Farnum, Charles Egbert...              NaN
# 1069                                    Foster, William              NaN
# 1760                                                NaN              NaN
#
#                                                 sources
# 1     [u'IUP,ST,47/B/107<>Great Britain, <i>Irish Un...
# 2     [u'HED,36-2,7:450,517,621<>United States Congr...
# 3     [u'HED,36-2,7:454,517<>United States Congress,...
# 4     [u'Jordan, 272-90<><p>Jordan, Jim "Charles Aug...
# 1069  [u'Howard, p. 301-02<>Howard, Warren S. <i>Ame...
# 1760  [u'AHNA, Cod. E-4-4 (Benguela)<><i>Arquivo His...

# %% [markdown]
# ## Sort Columns

# %% [markdown]
# You can sort a dataframe with the `.sort_values()` method, inside of which you include the parameter `by=` and indicate the name of the column you want to sort by (written in quotation marks).

# %%
slave_voyages_df.sort_values(by='total_disembarked')
# Out:
#       voyage_id          vessel_name national_affiliation  \
# 1510      83086               Phoebe        Great Britain
# 1348      77222          Two Sisters        Great Britain
# 798       25870                Betty        Great Britain
# 913       36201              Venture               U.S.A.
# 623       25370  Sarah and Elizabeth               U.S.A.
# ...         ...                  ...                  ...
# 1580      90684                Glory        Great Britain
# 165       16727                 Hill        Great Britain
# 558       25153            Elizabeth               U.S.A.
# 720       25512                Emily                  NaN
# 724       25520            Semiramis               U.S.A.
#
#                                 place_of_slave_purchase  \
# 1510                        Bance Island (Ben's Island)
# 1348                                        Saint-Louis
# 798                           Africa., port unspecified
# 913                                              Gambia
# 623                           Africa., port unspecified
# ...                                                 ...
# 1580  West Central Africa and St. Helena, port unspe...
# 165                                              Loango
# 558                                                 NaN
# 720                                              Loango
# 724                                               Bonny
#
#          place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 1510                        Charleston            45.0                3.0
# 1348                            Oxford             6.0                5.0
# 798                  Upper James River             9.0                8.0
# 913     Rhode Island, port unspecified            10.0                8.0
# 623                           New York            11.0                9.0
# ...                                ...             ...                ...
# 1580                        Charleston           936.0              764.0
# 165   South Carolina, port unspecified             NaN                NaN
# 558                            Newport             NaN                NaN
# 720                         Charleston             NaN                NaN
# 724                         Charleston           268.0                NaN
#
#       year_of_arrival  percent_men  percent_women  percent_children  \
# 1510             1799          NaN            NaN               NaN
# 1348             1763          NaN            NaN               NaN
# 798              1734          NaN            NaN               NaN
# 913              1757          NaN            NaN               NaN
# 623              1754          NaN            NaN               NaN
# ...               ...          ...            ...               ...
# 1580             1758          NaN            NaN               NaN
# 165              1733          NaN            NaN               NaN
# 558              1681          NaN            NaN               NaN
# 720              1807          NaN            NaN               NaN
# 724              1807          NaN            NaN               NaN
#
#                     captain's_name resistance_label  \
# 1510                           NaN              NaN
# 1348             Banning, Jeremiah              NaN
# 798                Bannerman, John              NaN
# 913                 Thurston, John              NaN
# 623                   Corne, Peter              NaN
# ...                            ...              ...
# 1580                Clemens, James              NaN
# 165                   Cole, Robert              NaN
# 558                     Warren, Wm              NaN
# 720                         Brooks              NaN
# 724   Collins, Charles<br/> Slocum              NaN
#
#                                                 sources
# 1510  [u'Donnan,IV,494<><p>Donnan, Elizabeth (ed.),&...
# 1348  [u"LR1764<><i>Lloyd's Register of Shipping</i>...
# 798   [u'ADM68/196,170v<><p><em>British National Arc...
# 913   [u'Coughtry, 241-85<><p>Coughtry, Jay, <em>The...
# 623   [u'Donnan,III,509<><p>Donnan, Elizabeth (ed.),...
# ...                                                 ...
# 1580  [u'LST,1744-1786<>Richardson, David, Katherine...
# 165   [u'NJHS, mss group 49, Journal of the Catherin...
# 558   [u'Donnan,III,15-16<><p>Donnan, Elizabeth (ed....
# 720   [u'SC,Equity, reel 178, Bill 22<><p><em>South ...
# 724   [u'ANC,IH, v. 1052/23<><p><span class="source_...
#
# [1761 rows x 14 columns]

# %% [markdown]
# Take a look at the way the dataframe above is sorted. Do you notice that something seems a bit off?
#
# By default, Pandas will sort in "ascending" order, from the smallest value to the largest value. If you want to sort the largest values first, you need to include another parameter `ascending=False`.

# %%
slave_voyages_df.sort_values(by='total_disembarked', ascending=False)
# Out:
#       voyage_id     vessel_name national_affiliation  \
# 1580      90684           Glory        Great Britain
# 1453      80917  Comte du Norde        Great Britain
# 1529      83989      Washington               U.S.A.
# 1626      91056          Marton        Great Britain
# 3          4364         William               U.S.A.
# ...         ...             ...                  ...
# 1510      83086          Phoebe        Great Britain
# 165       16727            Hill        Great Britain
# 558       25153       Elizabeth               U.S.A.
# 720       25512           Emily                  NaN
# 724       25520       Semiramis               U.S.A.
#
#                                 place_of_slave_purchase  \
# 1580  West Central Africa and St. Helena, port unspe...
# 1453                                            Malembo
# 1529                                              Bonny
# 1626  West Central Africa and St. Helena, port unspe...
# 3                                           Congo River
# ...                                                 ...
# 1510                        Bance Island (Ben's Island)
# 165                                              Loango
# 558                                                 NaN
# 720                                              Loango
# 724                                               Bonny
#
#          place_of_slave_disembarkation  total_embarked  total_disembarked  \
# 1580                        Charleston           936.0              764.0
# 1453                        Charleston           674.0              611.0
# 1529                        Charleston           590.0              530.0
# 1626                        Charleston           636.0              519.0
# 3                             Key West           744.0              513.0
# ...                                ...             ...                ...
# 1510                        Charleston            45.0                3.0
# 165   South Carolina, port unspecified             NaN                NaN
# 558                            Newport             NaN                NaN
# 720                         Charleston             NaN                NaN
# 724                         Charleston           268.0                NaN
#
#       year_of_arrival  percent_men  percent_women  percent_children  \
# 1580             1758          NaN            NaN               NaN
# 1453             1784      0.29307        0.14387           0.56306
# 1529             1805          NaN            NaN               NaN
# 1626             1764          NaN            NaN               NaN
# 3                1860          NaN            NaN               NaN
# ...               ...          ...            ...               ...
# 1510             1799          NaN            NaN               NaN
# 165              1733          NaN            NaN               NaN
# 558              1681          NaN            NaN               NaN
# 720              1807          NaN            NaN               NaN
# 724              1807          NaN            NaN               NaN
#
#                     captain's_name resistance_label  \
# 1580                Clemens, James              NaN
# 1453                  Penny, James              NaN
# 1529            Belcher<br/> Waldo              NaN
# 1626               Wilkinson, John              NaN
# 3                              NaN              NaN
# ...                            ...              ...
# 1510                           NaN              NaN
# 165                   Cole, Robert              NaN
# 558                     Warren, Wm              NaN
# 720                         Brooks              NaN
# 724   Collins, Charles<br/> Slocum              NaN
#
#                                                 sources
# 1580  [u'LST,1744-1786<>Richardson, David, Katherine...
# 1453  [u"LR1784<><i>Lloyd's Register of Shipping</i>...
# 1529  [u'Donnan,IV,508-09<><p>Donnan, Elizabeth (ed....
# 1626  [u'LST,1744-1786<>Richardson, David, Katherine...
# 3     [u'HED,36-2,7:454,517<>United States Congress,...
# ...                                                 ...
# 1510  [u'Donnan,IV,494<><p>Donnan, Elizabeth (ed.),&...
# 165   [u'NJHS, mss group 49, Journal of the Catherin...
# 558   [u'Donnan,III,15-16<><p>Donnan, Elizabeth (ed....
# 720   [u'SC,Equity, reel 178, Bill 22<><p><em>South ...
# 724   [u'ANC,IH, v. 1052/23<><p><span class="source_...
#
# [1761 rows x 14 columns]

# %% [markdown]
# If you want to sort a Series object, you don't need to use the `by=` paramter.

# %%
slave_voyages_df['total_disembarked'].sort_values(ascending=False)
# Out:
# 1580    764.0
# 1453    611.0
# 1529    530.0
# 1626    519.0
# 3       513.0
#         ...
# 1510      3.0
# 165       NaN
# 558       NaN
# 720       NaN
# 724       NaN
# Name: total_disembarked, Length: 1761, dtype: float64

# %% [markdown]
# ## Count Values in Columns

# %% [markdown]
# To count the unique values in a column, you can use the `.value_counts()` method.

# %%
slave_voyages_df['national_affiliation'].value_counts()
# Out:
# Great Britain        1142
# U.S.A.                558
# France                 31
# Spain / Uruguay        11
# Denmark / Baltic        6
# Portugal / Brazil       4
# Netherlands             3
# Name: national_affiliation, dtype: int64

# %%
slave_voyages_df['vessel_name'].value_counts()
# Out:
#                      60
# Mary                 28
# Nancy                27
# Africa               23
# Molly                19
#                      ..
# Alcide (a) Alcade     1
# John and Francis      1
# Little Sally          1
# Virginia              1
# Ida                   1
# Name: vessel_name, Length: 765, dtype: int64

# %%
slave_voyages_df['place_of_slave_disembarkation'].value_counts()
# Out:
# Charleston                          811
# York River                          163
# Virginia, port unspecified          120
# Savannah                            116
# Upper James River                    72
# New York                             70
# Maryland, port unspecified           64
# Rappahannock                         62
# Rhode Island, port unspecified       27
# Boston                               24
# New Orleans                          20
# Annapolis                            19
# Patuxent                             19
# Florida, port unspecified            17
# South Carolina, port unspecified     13
# South Potomac                        12
# La Balise                            10
# Philadelphia                         10
# USA, location unspecified             9
# North Carolina, port unspecified      9
# Louisiana                             9
# St. Augustine                         8
# Lower James River                     8
# North Potomac                         7
# Hampton                               6
# Mississippi                           5
# Eastern New Jersey                    5
# Biloxi                                5
# Oxford                                4
# Newport                               4
# Beaufort                              4
# Pensacola                             4
# Georgia, port unspecified             3
# Key West                              3
# Londontowne                           3
# Middletown                            2
# Perth Amboy                           2
# Delaware River                        2
# Amelia Island                         2
# Tybee Island                          2
# New London                            1
# Piscataqua                            1
# Potomac river                         1
# Roanoke                               1
# Baltimore                             1
# Mobile                                1
# Name: place_of_slave_disembarkation, dtype: int64

# %% [markdown]
# ## Calculate Columns

# %% [markdown]
# | Pandas calculations | Explanation                         |
# |----------|-------------------------------------|
# | `.count()`    | Number of observations    |
# | `.sum()`      | Sum of values                       |
# | `.mean()`     | Mean of values                      |
# | `.median()`   | Median of values         |
# | `.min()`      | Minimum                             |
# | `.max()`      | Maximum                             |
# | `.mode()`     | Mode                                |
# | `.std()`      | Unbiased standard deviation         |

# %% [markdown]
# You can do different calculations on columns with built-in Pandas functions, such as `.sum()` and `.max()

# %%
slave_voyages_df['total_disembarked'].sum()
# Out:
# 306903.0

# %%
slave_voyages_df['total_embarked'].sum()
# Out:
# 365916.0

# %%
slave_voyages_df['total_embarked'].sum() - slave_voyages_df['total_disembarked'].sum()
# Out:
# 59013.0

# %%
slave_voyages_df['total_disembarked'].mean()
# Out:
# 174.67444507683553

# %%
slave_voyages_df['total_disembarked'].max()
# Out:
# 764.0

# %% [markdown]
# ## Groupby Columns

# %% [markdown]
# One powerful Pandas function is called `.groupby()`, which allows you to aggregate data and perform calculations on it. For example, if we wanted to see how many enslaved people were transported by each nation, we could group by, or aggregate our data based on, "national_affiliation". The first step to using groupby is to type the name of your dataframe followed by `.groupby()` with the column you'd like to aggregate based on.

# %%
slave_voyages_df.groupby('national_affiliation')

# %% [markdown]
# This action will created a "groupby" object, which you won't be able to access unless you perform a calculation on it, such as `.sum()`

# %%
slave_voyages_df.groupby('national_affiliation').sum()
# Out:
#                       voyage_id  total_embarked  total_disembarked  \
# national_affiliation
# Denmark / Baltic         160604          1417.0             1106.0
# France                   997824          9335.0             8351.0
# Great Britain          57089458        269716.0           226192.0
# Netherlands               34121           977.0              824.0
# Portugal / Brazil        183872           909.0              790.0
# Spain / Uruguay          419914          2366.0             2027.0
# U.S.A.                 18296731         80017.0            66588.0
#
#                       year_of_arrival  percent_men  percent_women  \
# national_affiliation
# Denmark / Baltic                10791     0.978480       0.446840
# France                          54107     5.932353       2.624607
# Great Britain                 1995812    25.509599      10.059908
# Netherlands                      4982     0.533330       0.466670
# Portugal / Brazil                7240     0.000000       0.000000
# Spain / Uruguay                 19940     0.493560       0.411730
# U.S.A.                         995452     8.011650       4.312030
#
#                       percent_children
# national_affiliation
# Denmark / Baltic              0.574680
# France                        1.794657
# Great Britain                14.979793
# Netherlands                   0.000000
# Portugal / Brazil             0.000000
# Spain / Uruguay               1.094710
# U.S.A.                        5.700530

# %% [markdown]
# If we want to isolate only the "total_disembarked" column from this groupby calculation, then we can add in "total_disembarked" in square brackets `[]`

# %%
slave_voyages_df.groupby('national_affiliation')['total_disembarked'].sum().sort_values(ascending=False)
# Out:
# national_affiliation
# Great Britain        226192.0
# U.S.A.                66588.0
# France                 8351.0
# Spain / Uruguay        2027.0
# Denmark / Baltic       1106.0
# Netherlands             824.0
# Portugal / Brazil       790.0
# Name: total_disembarked, dtype: float64

# %%
slave_voyages_df.groupby('national_affiliation')[['total_disembarked']].sum().sort_values(by='total_disembarked', ascending=False)
# Out:
#                       total_disembarked
# national_affiliation
# Great Britain                  226192.0
# U.S.A.                          66588.0
# France                           8351.0
# Spain / Uruguay                  2027.0
# Denmark / Baltic                 1106.0
# Netherlands                       824.0
# Portugal / Brazil                 790.0

# %% [markdown]
# Let's save this groupby calculation into a new variable called `national_totals`

# %%
national_totals = slave_voyages_df.groupby('national_affiliation')[['total_disembarked']].sum().sort_values(by='total_disembarked', ascending=False)

# %% [markdown]
# ## Make Plots

# %% [markdown]
# We're going to talk about making plots and data visualizations more extensively later. But for now we're going to introduce the fact that you can make simple plots simply by using the [`.plot()` method](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html) that's built into Pandas.

# %%
national_totals.plot(kind='bar')

# %%
national_totals.plot(kind='barh')

# %% [markdown]
# ## Time Series

# %%
slave_voyages_df['year_of_arrival'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# Transform an integer into a datetime

# %%
slave_voyages_df['year_of_arrival'] = pd.to_datetime(slave_voyages_df['year_of_arrival'], format='%Y',errors='coerce')

# %% [markdown]
# Number of voyages over time

# %%
slave_voyages_df['year_of_arrival'].value_counts().plot()

# %% [markdown]
# Total number of enslaved people disembarked over time

# %%
slave_voyages_df.groupby('year_of_arrival')['total_disembarked'].sum().plot()

# %%
usa_slave_voyages = slave_voyages_df[slave_voyages_df['national_affiliation']=='U.S.A.']

# %%
usa_slave_voyages.groupby('year_of_arrival')['total_disembarked'].sum().plot()

# %%
gb_slave_voyages = slave_voyages_df[slave_voyages_df['national_affiliation']=='Great Britain']

# %%
gb_slave_voyages.groupby('year_of_arrival')['total_disembarked'].sum().plot()
